# %%
import pandas as pd
from feature_selector import FeatureSelector

# %%
train = pd.read_hdf('../input/user_features.h5')

train = train[train.label.notna()]
test = train[train.label.isna()]

train.shape, test.shape
# Out:
# ((6106, 85), (0, 85))

# %%
train_labels = train['label']
train.head()
# Out:
#                                           phone_no_m  city_name  county_name  \
# 0  672ddbf02a5544d32e4ecc9433b1981bffe23bf912273a...         16           97
# 1  5e1272273e041e82cb275ae877710be98cdaf5b0a8f34d...         10           82
# 2  eaab3472ec87b076e69e6e8bb62b14341638fc63661a6c...         11          160
# 3  0ce1bb415704178bf44e9c9b431a39b083a132c8e6d99f...         11          181
# 4  28b87f35f63f65096a53e3a4c97eaffd4a6c43ffa7e92d...         10           82
#
#    idcard_cnt  label  arpu_202004  city_name_county_name  \
# 0           1    0.0    45.000000                    141
# 1           1    0.0    60.000000                     80
# 2           2    0.0    63.000000                    101
# 3           2    0.0    23.203125                    106
# 4           1    0.0    50.000000                     80
#
#    idcard_cnt*arpu_202004  arpu_202004/idcard_cnt  city_name_idcard_cnt_max  \
# 0                45.00000               44.995500                         5
# 1                60.00000               59.994001                         5
# 2               126.00000               31.498425                         7
# 3                46.40625               11.600982                         7
# 4                50.00000               49.995000                         5
#
#    ...  city_name_county_name_arpu_202004/idcard_cnt_max  \
# 0  ...                                      60000.000000
# 1  ...                                        114.869257
# 2  ...                                        257.474253
# 3  ...                                        231.488426
# 4  ...                                        114.869257
#
#    city_name_county_name_arpu_202004/idcard_cnt_min  \
# 0                                          0.333322
# 1                                          0.333322
# 2                                          0.333322
# 3                                          0.249994
# 4                                          0.333322
#
#    city_name_county_name_arpu_202004/idcard_cnt_median  \
# 0                                          24.599726
# 1                                          13.468301
# 2                                          24.498775
# 3                                          22.588975
# 4                                          13.468301
#
#    city_name_county_name_arpu_202004/idcard_cnt_mean  \
# 0                                         606.375977
# 1                                          22.458818
# 2                                          36.008967
# 3                                          35.978017
# 4                                          22.458818
#
#    city_name_county_name_arpu_202004/idcard_cnt_skew  \
# 0                                          10.294616
# 1                                           1.735547
# 2                                           3.320340
# 3                                           2.016172
# 4                                           1.735547
#
#    city_name_county_name_arpu_202004/idcard_cnt_nunique  city_name_count  \
# 0                                                 91            0.080726
# 1                                                 43            0.029935
# 2                                                 68            0.375537
# 3                                                114            0.375537
# 4                                                 43            0.029935
#
#    county_name_count  city_name_county_name_count  idcard_cnt_count
# 0           0.016685                     0.016685          0.463133
# 1           0.006625                     0.006625          0.463133
# 2           0.008956                     0.008956          0.249295
# 3           0.026868                     0.018771          0.249295
# 4           0.006625                     0.006625          0.463133
#
# [5 rows x 85 columns]

# %%
train = train.drop(['phone_no_m', 'label'], axis=1)

# %%
fs = FeatureSelector(data=train, labels=train_labels)

# %%
fs.identify_missing(missing_threshold=0.9)
missing_features = fs.ops['missing']
missing_features
# Out:
# 6 features with greater than 0.90 missing values.
# ['city_name_arpu_202004_skew',
#  'city_name_idcard_cnt*arpu_202004_skew',
#  'county_name_arpu_202004_skew',
#  'county_name_idcard_cnt*arpu_202004_skew',
#  'city_name_county_name_arpu_202004_skew',
#  'city_name_county_name_idcard_cnt*arpu_202004_skew']

# %%
train.drop(missing_features, axis=1, inplace=True)

# %%
fs.plot_missing()

# %%
fs.missing_stats.head(10)
# Out:
#                                                    missing_fraction
# city_name_idcard_cnt*arpu_202004_skew                      1.000000
# city_name_arpu_202004_skew                                 1.000000
# city_name_county_name_idcard_cnt*arpu_202004_skew          0.991320
# county_name_idcard_cnt*arpu_202004_skew                    0.991320
# county_name_arpu_202004_skew                               0.910907
# city_name_county_name_arpu_202004_skew                     0.910907
# arpu_202004                                                0.120701
# idcard_cnt*arpu_202004                                     0.120701
# arpu_202004/idcard_cnt                                     0.120701
# city_name_county_name_arpu_202004/idcard_cnt_skew          0.004749

# %%
fs.identify_single_unique()
# Out:
# 0 features with a single unique value.

# %%
single_unique = fs.ops['single_unique']
single_unique
# Out:
# []

# %%
fs.plot_unique()

# %%
fs.unique_stats.sample(5)
# Out:
#                                                   nunique
# county_name_idcard_cnt_skew                           159
# city_name_county_name_arpu_202004/idcard_cnt_max      176
# city_name_idcard_cnt*arpu_202004_mean                  23
# county_name_arpu_202004_min                            61
# city_name_county_name_arpu_202004_max                 173

# %%
fs.identify_collinear(correlation_threshold=0.975)
# Out:
# 27 features with a correlation magnitude greater than 0.97.

# %%
correlated_features = fs.ops['collinear']
correlated_features[:5]
# Out:
# ['city_name_county_name',
#  'city_name_idcard_cnt*arpu_202004_nunique',
#  'city_name_arpu_202004/idcard_cnt_min',
#  'city_name_arpu_202004/idcard_cnt_nunique',
#  'county_name_idcard_cnt*arpu_202004_nunique']

# %%
fs.plot_collinear()

# %%
fs.plot_collinear(plot_all=True)

# %%
fs.identify_collinear(correlation_threshold=0.98)
fs.plot_collinear()
# Out:
# 27 features with a correlation magnitude greater than 0.98.

# %%
fs.record_collinear.head()
# Out:
#                                drop_feature  \
# 0                     city_name_county_name
# 1  city_name_idcard_cnt*arpu_202004_nunique
# 2      city_name_arpu_202004/idcard_cnt_min
# 3  city_name_arpu_202004/idcard_cnt_nunique
# 4  city_name_arpu_202004/idcard_cnt_nunique
#
#                                corr_feature  corr_value
# 0                                 city_name    0.993237
# 1             city_name_arpu_202004_nunique    0.999981
# 2                 city_name_arpu_202004_min    0.988776
# 3             city_name_arpu_202004_nunique    0.999873
# 4  city_name_idcard_cnt*arpu_202004_nunique    0.999924

# %%
fs.identify_zero_importance(task='classification',
                            eval_metric='auc', 
                            n_iterations=10,
                            early_stopping=True)
# Out:
# Training Gradient Boosting Model
#
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [44]	valid_0's auc: 0.89035	valid_0's binary_logloss: 0.34622
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [35]	valid_0's auc: 0.880181	valid_0's binary_logloss: 0.382179
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [87]	valid_0's auc: 0.868528	valid_0's binary_logloss: 0.361729
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [78]	valid_0's auc: 0.881401	valid_0's binary_logloss: 0.363765
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [23]	valid_0's auc: 0.882858	valid_0's binary_logloss: 0.402039
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [101]	valid_0's auc: 0.881201	valid_0's binary_logloss: 0.357046
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [14]	valid_0's auc: 0.860894	valid_0's binary_logloss: 0.463963
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [17]	valid_0's auc: 0.853906	valid_0's binary_logloss: 0.455072
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [71]	valid_0's auc: 0.891977	valid_0's binary_logloss: 0.346259
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [52]	valid_0's auc: 0.854991	valid_0's binary_logloss: 0.390608
#
# 1 features with zero importance after one-hot encoding.

# %%
one_hot_features = fs.one_hot_features
base_features = fs.base_features
print('There are %d original features' % len(base_features))
print('There are %d one-hot features' % len(one_hot_features))
# Out:
# There are 83 original features
# There are 0 one-hot features

# %%
fs.data_all.head(10)
# Out:
#    city_name  county_name  idcard_cnt  arpu_202004  city_name_county_name  \
# 0         16           97           1    45.000000                    141
# 1         10           82           1    60.000000                     80
# 2         11          160           2    63.000000                    101
# 3         11          181           2    23.203125                    106
# 4         10           82           1    50.000000                     80
# 5         19           53           2    59.656250                    160
# 6         11          157           1          NaN                     99
# 7          1          111           4          NaN                     10
# 8         10          128           2    16.218750                     82
# 9         11           30           2    14.632812                     83
#
#    idcard_cnt*arpu_202004  arpu_202004/idcard_cnt  city_name_idcard_cnt_max  \
# 0               45.000000               44.995500                         5
# 1               60.000000               59.994001                         5
# 2              126.000000               31.498425                         7
# 3               46.406250               11.600982                         7
# 4               50.000000               49.995000                         5
# 5              119.312500               29.826634                         5
# 6                     NaN                     NaN                         7
# 7                     NaN                     NaN                         5
# 8               32.437500                8.108970                         5
# 9               29.265625                7.316040                         7
#
#    city_name_idcard_cnt_min  city_name_idcard_cnt_median  ...  \
# 0                         0                            2  ...
# 1                         0                            2  ...
# 2                         0                            2  ...
# 3                         0                            2  ...
# 4                         0                            2  ...
# 5                         1                            1  ...
# 6                         0                            2  ...
# 7                         1                            1  ...
# 8                         0                            2  ...
# 9                         0                            2  ...
#
#    city_name_county_name_arpu_202004/idcard_cnt_max  \
# 0                                      60000.000000
# 1                                        114.869257
# 2                                        257.474253
# 3                                        231.488426
# 4                                        114.869257
# 5                                        160.983902
# 6                                     390000.000000
# 7                                       1242.875712
# 8                                      17001.953125
# 9                                        159.234077
#
#    city_name_county_name_arpu_202004/idcard_cnt_min  \
# 0                                          0.333322
# 1                                          0.333322
# 2                                          0.333322
# 3                                          0.249994
# 4                                          0.333322
# 5                                          0.999900
# 6                                          0.219917
# 7                                          0.499975
# 8                                          0.499975
# 9                                          0.249994
#
#    city_name_county_name_arpu_202004/idcard_cnt_median  \
# 0                                          24.599726
# 1                                          13.468301
# 2                                          24.498775
# 3                                          22.588975
# 4                                          13.468301
# 5                                          30.090741
# 6                                          23.997600
# 7                                          14.030782
# 8                                          13.600202
# 9                                          41.746938
#
#    city_name_county_name_arpu_202004/idcard_cnt_mean  \
# 0                                         606.375977
# 1                                          22.458818
# 2                                          36.008967
# 3                                          35.978017
# 4                                          22.458818
# 5                                          41.407583
# 6                                        3016.240342
# 7                                          70.424899
# 8                                        5181.684517
# 9                                          45.714591
#
#    city_name_county_name_arpu_202004/idcard_cnt_skew  \
# 0                                          10.294616
# 1                                           1.735547
# 2                                           3.320340
# 3                                           2.016172
# 4                                           1.735547
# 5                                           1.346641
# 6                                          11.445491
# 7                                           5.109142
# 8                                           0.910937
# 9                                           1.050542
#
#    city_name_county_name_arpu_202004/idcard_cnt_nunique  city_name_count  \
# 0                                                 91            0.080726
# 1                                                 43            0.029935
# 2                                                 68            0.375537
# 3                                                114            0.375537
# 4                                                 43            0.029935
# 5                                                 69            0.044902
# 6                                                112            0.375537
# 7                                                 31            0.034352
# 8                                                 16            0.029935
# 9                                                 36            0.375537
#
#    county_name_count  city_name_county_name_count  idcard_cnt_count
# 0           0.016685                     0.016685          0.463133
# 1           0.006625                     0.006625          0.463133
# 2           0.008956                     0.008956          0.249295
# 3           0.026868                     0.018771          0.249295
# 4           0.006625                     0.006625          0.463133
# 5           0.008711                     0.008711          0.249295
# 6           0.021224                     0.021224          0.463133
# 7           0.005030                     0.005030          0.075696
# 8           0.002822                     0.002822          0.249295
# 9           0.015949                     0.004417          0.249295
#
# [10 rows x 77 columns]

# %%
zero_importance_features = fs.ops['zero_importance']
zero_importance_features
# Out:
# ['city_name_county_name_idcard_cnt_min']

# %%
fs.plot_feature_importances(threshold=0.99,
                            plot_n=20)
# Out:
# 62 features required for 0.99 of cumulative importance

# %%
fs.feature_importances.head(20)
# Out:
#                                       feature  importance  \
# 0                                 arpu_202004       251.9
# 1                      idcard_cnt*arpu_202004       187.8
# 2                      arpu_202004/idcard_cnt       152.3
# 3                 county_name_idcard_cnt_skew        76.6
# 4                            idcard_cnt_count        52.0
# 5      county_name_idcard_cnt*arpu_202004_max        46.2
# 6                                 county_name        36.9
# 7     county_name_arpu_202004/idcard_cnt_skew        34.1
# 8              county_name_arpu_202004_median        34.0
# 9                       city_name_county_name        33.7
# 10    county_name_idcard_cnt*arpu_202004_mean        33.0
# 11                county_name_idcard_cnt_mean        32.1
# 12                                 idcard_cnt        31.6
# 13  county_name_idcard_cnt*arpu_202004_median        29.1
# 14               county_name_arpu_202004_mean        27.6
# 15      city_name_county_name_idcard_cnt_skew        23.4
# 16    county_name_arpu_202004/idcard_cnt_mean        23.3
# 17            county_name_arpu_202004_nunique        23.2
# 18  county_name_arpu_202004/idcard_cnt_median        21.7
# 19                county_name_arpu_202004_max        21.2
#
#     normalized_importance  cumulative_importance
# 0                0.160856               0.160856
# 1                0.119923               0.280779
# 2                0.097254               0.378033
# 3                0.048914               0.426948
# 4                0.033206               0.460153
# 5                0.029502               0.489655
# 6                0.023563               0.513218
# 7                0.021775               0.534994
# 8                0.021711               0.556705
# 9                0.021520               0.578225
# 10               0.021073               0.599298
# 11               0.020498               0.619796
# 12               0.020179               0.639974
# 13               0.018582               0.658557
# 14               0.017625               0.676181
# 15               0.014943               0.691124
# 16               0.014879               0.706003
# 17               0.014815               0.720817
# 18               0.013857               0.734674
# 19               0.013538               0.748212

# %%
one_hundred_features = list(fs.feature_importances.loc[:99, 'feature'])
len(one_hundred_features)
# Out:
# 77

# %%
fs.identify_low_importance(cumulative_importance = 0.99)
# Out:
# 61 features required for cumulative importance of 0.99 after one hot encoding.
# 16 features do not contribute to cumulative importance of 0.99.

# %%
low_importance_features = fs.ops['low_importance']
low_importance_features
# Out:
# ['city_name_county_name_arpu_202004_min',
#  'city_name_county_name_idcard_cnt*arpu_202004_min',
#  'city_name_arpu_202004_min',
#  'city_name_idcard_cnt*arpu_202004_nunique',
#  'city_name_county_name_idcard_cnt*arpu_202004_nunique',
#  'city_name_idcard_cnt_median',
#  'city_name_county_name_idcard_cnt_max',
#  'city_name_idcard_cnt*arpu_202004_min',
#  'county_name_arpu_202004/idcard_cnt_nunique',
#  'city_name_idcard_cnt_max',
#  'county_name_idcard_cnt_min',
#  'city_name_idcard_cnt_min',
#  'city_name_idcard_cnt_nunique',
#  'city_name_county_name_arpu_202004/idcard_cnt_nunique',
#  'city_name_arpu_202004/idcard_cnt_nunique',
#  'city_name_county_name_idcard_cnt_min']

# %%
train_no_missing = fs.remove(methods = ['missing'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-dfe11336853b> in <module>
# ----> 1 train_no_missing = fs.remove(methods = ['missing'])
#
# ~\Python\Competition\OPENDATA\诈骗电话识别\train\feature_selector.py in remove(self, methods, keep_one_hot)
#     500
#     501         # Remove the features and return the data
# --> 502         data = data.drop(columns = features_to_drop)
#     503         self.removed_features = features_to_drop
#     504
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3968                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3969             else:
# -> 3970                 new_axis = axis.drop(labels, errors=errors)
#    3971             result = self.reindex(**{axis_name: new_axis})
#    3972
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5015         if mask.any():
#    5016             if errors != "ignore":
# -> 5017                 raise KeyError(f"{labels[mask]} not found in axis")
#    5018             indexer = indexer[~mask]
#    5019         return self.delete(indexer)
#
# KeyError: "['county_name_arpu_202004_skew' 'county_name_idcard_cnt*arpu_202004_skew'\n 'city_name_county_name_arpu_202004_skew'\n 'city_name_idcard_cnt*arpu_202004_skew'\n 'city_name_county_name_idcard_cnt*arpu_202004_skew'\n 'city_name_arpu_202004_skew'] not found in axis"

# %%
train_removed = fs.remove(methods = 'all')
# Out:
# ['missing', 'single_unique', 'collinear', 'zero_importance', 'low_importance'] methods have been run
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-0e0f91cdd6c2> in <module>
# ----> 1 train_removed = fs.remove(methods = 'all')
#
# ~\Python\Competition\OPENDATA\诈骗电话识别\train\feature_selector.py in remove(self, methods, keep_one_hot)
#     500
#     501         # Remove the features and return the data
# --> 502         data = data.drop(columns = features_to_drop)
#     503         self.removed_features = features_to_drop
#     504
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3968                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3969             else:
# -> 3970                 new_axis = axis.drop(labels, errors=errors)
#    3971             result = self.reindex(**{axis_name: new_axis})
#    3972
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5015         if mask.any():
#    5016             if errors != "ignore":
# -> 5017                 raise KeyError(f"{labels[mask]} not found in axis")
#    5018             indexer = indexer[~mask]
#    5019         return self.delete(indexer)
#
# KeyError: "['county_name_idcard_cnt*arpu_202004_skew'\n 'city_name_county_name_idcard_cnt*arpu_202004_skew'\n 'city_name_arpu_202004_skew' 'county_name_arpu_202004_skew'\n 'city_name_idcard_cnt*arpu_202004_skew'\n 'city_name_county_name_arpu_202004_skew'] not found in axis"

# %%
fs = FeatureSelector(data = train, labels = train_labels)

fs.identify_all(selection_params = {'missing_threshold': 0.6, 'correlation_threshold': 0.98, 
                                    'task': 'classification', 'eval_metric': 'auc', 
                                     'cumulative_importance': 0.99})
# Out:
# 0 features with greater than 0.60 missing values.
#
# 0 features with a single unique value.
#
# 27 features with a correlation magnitude greater than 0.98.
#
# Training Gradient Boosting Model
#
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [108]	valid_0's auc: 0.881368	valid_0's binary_logloss: 0.358107
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [96]	valid_0's auc: 0.874128	valid_0's binary_logloss: 0.368078
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [74]	valid_0's auc: 0.86122	valid_0's binary_logloss: 0.379603
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [78]	valid_0's auc: 0.865693	valid_0's binary_logloss: 0.379188
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [85]	valid_0's auc: 0.889314	valid_0's binary_logloss: 0.346452
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [33]	valid_0's auc: 0.887427	valid_0's binary_logloss: 0.378418
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [135]	valid_0's auc: 0.901976	valid_0's binary_logloss: 0.324175
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [69]	valid_0's auc: 0.899201	valid_0's binary_logloss: 0.332239
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [35]	valid_0's auc: 0.868129	valid_0's binary_logloss: 0.390249
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [23]	valid_0's auc: 0.868689	valid_0's binary_logloss: 0.411131
#
# 1 features with zero importance after one-hot encoding.
#
# 62 features required for cumulative importance of 0.99 after one hot encoding.
# 15 features do not contribute to cumulative importance of 0.99.
#
# 33 total features out of 77 identified for removal after one-hot encoding.
