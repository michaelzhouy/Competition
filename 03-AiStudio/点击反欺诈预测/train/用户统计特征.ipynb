# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, roc_auc_score
from sklearn.preprocessing import LabelEncoder
import lightgbm as lgb
from scipy.misc import derivative
import time
import gc
import warnings

# %matplotlib inline
warnings.filterwarnings('ignore')
pd.set_option('max_columns', None)
pd.set_option('max_rows', None)

# %%
train = pd.read_hdf('../input/train.h5')
train.head()
# Out:
#    android_id  apptype  carrier  dev_height  dev_ppi  dev_width  label  lan  \
# 0      316361     1199      1.0         NaN      NaN        NaN      1  NaN
# 1      135939      893      NaN         NaN      NaN        NaN      1  NaN
# 2      399254      821      NaN       760.0      NaN      360.0      1  NaN
# 3       68983     1004      1.0      2214.0      NaN     1080.0      0  NaN
# 4      288999     1076      1.0      2280.0      NaN     1080.0      1  1.0
#
#    media_id  ntt  osv  package      sid            timestamp  version  \
# 0       104  6.0  9.0       18  1438873  2019-06-07 15:32:01        8
# 1        19  6.0  8.0        0  1185582  2019-06-08 19:40:40        4
# 2       559  NaN  8.0        0  1555716  2019-06-06 23:59:13        0
# 3       129  2.0  8.0        0  1093419  2019-06-09 09:00:12        0
# 4        64  2.0  8.0        0  1400089  2019-06-07 08:28:13        5
#
#        fea_hash  location   fea1_hash  cus_type
# 0  2.135019e+09         0  2329670524       601
# 1  2.782306e+09         1  2864801071      1000
# 2  1.392806e+09         2   628911675       696
# 3  3.562553e+09         3  1283809327       753
# 4  2.364522e+09         4  1510695983       582

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500000 entries, 0 to 499999
# Data columns (total 19 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   android_id  500000 non-null  int32
#  1   apptype     500000 non-null  int16
#  2   carrier     435093 non-null  float64
#  3   dev_height  392986 non-null  float16
#  4   dev_ppi     116709 non-null  float16
#  5   dev_width   392989 non-null  float16
#  6   label       500000 non-null  int8
#  7   lan         316720 non-null  float64
#  8   media_id    500000 non-null  int16
#  9   ntt         479383 non-null  float16
#  10  osv         493439 non-null  float64
#  11  package     500000 non-null  int16
#  12  sid         500000 non-null  int32
#  13  timestamp   500000 non-null  object
#  14  version     500000 non-null  int64
#  15  fea_hash    499910 non-null  float64
#  16  location    500000 non-null  int16
#  17  fea1_hash   500000 non-null  int64
#  18  cus_type    500000 non-null  int16
# dtypes: float16(4), float64(4), int16(5), int32(2), int64(2), int8(1), object(1)
# memory usage: 43.4+ MB

# %%
test1 = pd.read_hdf('../input/test2.h5')
test1.head()
# Out:
#    android_id  apptype  carrier  dev_height  dev_ppi  dev_width  lan  \
# 0           0     1001      1.0       640.0      NaN      360.0  1.0
# 1           0     1106      1.0         NaN      NaN        NaN  NaN
# 2           0     1001      1.0       640.0      NaN      360.0  1.0
# 3      196009     1001      1.0      2016.0      NaN     1080.0  1.0
# 4       80444     1076      1.0      2280.0      NaN     1080.0  1.0
#
#    media_id  ntt  osv  package      sid            timestamp  version  \
# 0        29  5.0  8.0        4  1177564  2019-06-08 15:18:31      0.0
# 1        39  2.0  8.0       65  1822122  2019-06-04 21:53:18      0.0
# 2        29  2.0  6.0        4  1178302  2019-06-08 20:28:43      0.0
# 3        29  6.0  7.0        4  1269787  2019-06-08 15:51:17      3.0
# 4        64  2.0  9.0        0  1604520  2019-06-05 23:22:29      5.0
#
#        fea_hash  location   fea1_hash  cus_type
# 0  3.426912e+09        34  2694799399       411
# 1  1.331186e+09        48  4190764663       411
# 2  1.118061e+09        25  2610913319       411
# 3  3.780086e+09         3  2711576615       905
# 4  1.274342e+09       108    51536943       734

# %%
test1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 150000 entries, 0 to 149999
# Data columns (total 18 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   android_id  150000 non-null  int32
#  1   apptype     150000 non-null  int16
#  2   carrier     130369 non-null  float64
#  3   dev_height  117568 non-null  float16
#  4   dev_ppi     34910 non-null   float16
#  5   dev_width   117571 non-null  float16
#  6   lan         94563 non-null   float64
#  7   media_id    150000 non-null  int16
#  8   ntt         143774 non-null  float16
#  9   osv         148095 non-null  float64
#  10  package     150000 non-null  int16
#  11  sid         150000 non-null  int32
#  12  timestamp   150000 non-null  object
#  13  version     149999 non-null  float64
#  14  fea_hash    149968 non-null  float64
#  15  location    150000 non-null  int16
#  16  fea1_hash   150000 non-null  int64
#  17  cus_type    150000 non-null  int16
# dtypes: float16(4), float64(5), int16(5), int32(2), int64(1), object(1)
# memory usage: 12.9+ MB

# %%
data = pd.concat([train, test1])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 650000 entries, 0 to 149999
# Data columns (total 19 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   android_id  650000 non-null  int32
#  1   apptype     650000 non-null  int16
#  2   carrier     565462 non-null  float64
#  3   dev_height  510554 non-null  float16
#  4   dev_ppi     151619 non-null  float16
#  5   dev_width   510560 non-null  float16
#  6   label       500000 non-null  float64
#  7   lan         411283 non-null  float64
#  8   media_id    650000 non-null  int16
#  9   ntt         623157 non-null  float16
#  10  osv         641534 non-null  float64
#  11  package     650000 non-null  int16
#  12  sid         650000 non-null  int32
#  13  timestamp   650000 non-null  object
#  14  version     649999 non-null  float64
#  15  fea_hash    649878 non-null  float64
#  16  location    650000 non-null  int16
#  17  fea1_hash   650000 non-null  int64
#  18  cus_type    650000 non-null  int16
# dtypes: float16(4), float64(6), int16(5), int32(2), int64(1), object(1)
# memory usage: 60.7+ MB

# %% [markdown]
# 发现：android_id为0的有165013个，比其他的特征要高出了100多个数量级，猜测，0可能是缺失值的一种编码方式

# %%
data['android_id'].value_counts()[:10]
# Out:
# 0         165013
# 1190         272
# 6964         117
# 16662         39
# 2604          38
# 8183          36
# 44716         26
# 43274         26
# 19949         24
# 114020        23
# Name: android_id, dtype: int64

# %%
data['dev_height*dev_width'] = data['dev_height'] * data['dev_width']

# %%
data['apptype_media_id'] = data['apptype'].astype(str) + '_' + data['media_id'].astype(str)
# data['apptype_media_id_location'] = data['apptype'].astype(str) + '_' + data['media_id'].astype(str) + '_' + data['location'].astype(str)

data['apptype_osv'] = data['apptype'].astype(str) + '_' + data['osv'].astype(str)
data['apptype_osv'] = data['apptype'].astype(str) + '_' + data['package'].astype(str)

data['media_id_osv'] = data['media_id'].astype(str) + '_' + data['osv'].astype(str)
data['media_id_osv'] = data['media_id'].astype(str) + '_' + data['package'].astype(str)

data['apptype_osv'] = data['apptype'].astype(str) + '_' + data['media_id'].astype(str) + '_'+ data['osv'].astype(str)
data['apptype_osv'] = data['apptype'].astype(str) + '_' + data['media_id'].astype(str) + '_'+ data['osv'].astype(str) + '_' + data['package'].astype(str)

# %%
cate_cols = ['android_id', 'apptype', 'carrier', 'lan', 'media_id', 'ntt', 'osv',
             'version', 'location', 'cus_type', 'package', 'apptype_media_id']

print('There are about {} categorical features.'.format(len(cate_cols)))
# Out:
# There are about 12 categorical features.

# %%
for i in ['apptype', 'media_id', 'osv', 'package', 'apptype_media_id']:
    for j in ['dev_height', 'dev_width', 'fea1_hash']:
        df_tmp = data.groupby(i, as_index=False)[j].agg({
            '{}_{}_min'.format(i, j): 'min',
            '{}_{}_max'.format(i, j): 'max',
            '{}_{}_median'.format(i, j): 'median',
            '{}_{}_mean'.format(i, j): 'mean',
            '{}_{}_sum'.format(i, j): 'sum',
            '{}_{}_count'.format(i, j): 'count',
            '{}_{}_std'.format(i, j): 'std',
            '{}_{}_nunique'.format(i, j): 'nunique',
            '{}_{}_skew'.format(i, j): 'skew'
        })
        data = pd.merge(data, df_tmp, on=i, how='left')
        del df_tmp
        gc.collect()

# %%
# count编码
for col in cate_cols: 
    print(col)
    # data[col] = data[col].astype('category')
    data[col + '_cnt_code'] = data[col].map(data[col].value_counts())
# Out:
# android_id
# apptype
# carrier
# lan
# media_id
# ntt
# osv
# version
# location
# cus_type
# package
# apptype_media_id

# %%
data['user_id'] = (data['package'].astype(str) + '_' + data['version'].astype(str) + '_' + data['android_id'].astype(str)
                   + '_' + data['carrier'].astype(str) + '_' + data['osv'].astype(str) + '_' + data['lan'].astype(str))

# %%
data['day'] = data['timestamp'].astype('datetime64').dt.day
data['hour'] = data['timestamp'].astype('datetime64').dt.hour
data['dayofweek'] = data['timestamp'].astype('datetime64').dt.dayofweek

data['time'] = (data['day'] - data['day'].min()) * 24 + data['hour']

# %%
train['day'] = train['timestamp'].astype('datetime64').dt.day
train['day'].unique()
# Out:
# array([ 7,  8,  6,  9,  3,  4,  5, 10], dtype=int64)

# %%
test1['day'] = test1['timestamp'].astype('datetime64').dt.day
test1['day'].unique()
# Out:
# array([ 8,  4,  5,  9,  6,  3,  7, 10], dtype=int64)

# %%
data['day'].unique()
# Out:
# array([ 7,  8,  6,  9,  3,  4,  5, 10], dtype=int64)

# %%
time_cols = ['day', 'hour', 'dayofweek', 'time']

# count编码
for col in time_cols: 
    print(col)
    data[col + '_cnt_code'] = data[col].map(data[col].value_counts())
# Out:
# day
# hour
# dayofweek
# time

# %% [markdown]
# ## 用户特征1
# 1. 用户每天在某个app上出现的次数
# 2. 用户每天，每小时出现的次数
# 3. 用户距上次出现的时间差

# %%
# 用户每天/每小时在某个app上出现的次数
for i in ['day', 'time']:
    print('user_id_' + i + '_media')
    data['user_id_' + i + '_media'] = data['user_id'] + '_' + data[i].astype(str) + '_' + data['media_id'].astype(str)
    dic_ = data['user_id_' + i + '_media'].value_counts().to_dict()
    data['user_id_' + i + '_media_count'] = data['user_id_' + i + '_media'].apply(lambda x: dic_[x])
    data.drop('user_id_' + i + '_media', axis=1, inplace = True)
# Out:
# user_id_day_media
# user_id_time_media

# %%
# 用户每天/每小时在某个app上出现的次数
for i in ['day', 'time']:
    print('user_id_' + i + '_app')
    data['user_id_' + i + '_app'] = data['user_id'] + '_' + data[i].astype(str) + '_' + data['apptype'].astype(str)
    dic_ = data['user_id_' + i + '_app'].value_counts().to_dict()
    data['user_id_' + i + '_app_count'] = data['user_id_' + i + '_app'].apply(lambda x: dic_[x])
    data.drop('user_id_' + i + '_app', axis=1, inplace = True)
# Out:
# user_id_day_app
# user_id_time_app

# %%
# 用户每天,每个小时出现的次数
for i in ['day', 'time']:
    print('user_id_' + i)
    data['user_id_' + i] = data['user_id'] + '_' + data[i].astype(str)
    dic_ = data['user_id_' + i].value_counts().to_dict()
    data['user_id_' + i + '_count'] = data['user_id_' + i].apply(lambda x: dic_[x])
    data.drop('user_id_' + i, axis=1, inplace=True)
# Out:
# user_id_day
# user_id_time

# %%
# 用户本次出现距上次时间差
# data['user_to_lasttime'] = data.groupby('user_id')['time'].diff().values

# %%
for col in data.columns:
    if col not in ['sid', 'label', 'timestamp']: 
        if data[col].dtypes == 'O':
            print(col)
            data[col+'_labelencode'] = LabelEncoder().fit_transform(data[col].values)
# Out:
# apptype_media_id
# apptype_osv
# media_id_osv
# user_id

# %%
# 用户每天/每小时在某个app上出现的次数
for i in ['day','time']:
    for c in ['fea_hash', 'fea1_hash']:
        print('user_id_'+ i +'_' +c)
        data['user_id_'+ i + '_' +c] = data['user_id']  + '_' + data[i].astype(str) + '_' + data[c].astype(str)
        dic_ = data['user_id_'+ i +'_' +c].value_counts().to_dict()
        data['user_id_'+ i + '_' + c + '_count'] = data['user_id_'+ i +'_' + c].apply(lambda x: dic_[x])
        data.drop('user_id_'+ i +'_' + c, axis=1,inplace = True)
# Out:
# user_id_day_fea_hash
# user_id_day_fea1_hash
# user_id_time_fea_hash
# user_id_time_fea1_hash

# %%
from sklearn.model_selection import StratifiedKFold, KFold
from itertools import product
class MeanEncoder:
    def __init__(self, categorical_features, n_splits=10, target_type='classification', prior_weight_func=None):
        """
        :param categorical_features: list of str, the name of the categorical columns to encode
 
        :param n_splits: the number of splits used in mean encoding
 
        :param target_type: str, 'regression' or 'classification'
 
        :param prior_weight_func:
        a function that takes in the number of observations, and outputs prior weight
        when a dict is passed, the default exponential decay function will be used:
        k: the number of observations needed for the posterior to be weighted equally as the prior
        f: larger f --> smaller slope
        """
 
        self.categorical_features = categorical_features
        self.n_splits = n_splits
        self.learned_stats = {}
 
        if target_type == 'classification':
            self.target_type = target_type
            self.target_values = []
        else:
            self.target_type = 'regression'
            self.target_values = None
 
        if isinstance(prior_weight_func, dict):
            self.prior_weight_func = eval('lambda x: 1 / (1 + np.exp((x - k) / f))', dict(prior_weight_func, np=np))
        elif callable(prior_weight_func):
            self.prior_weight_func = prior_weight_func
        else:
            self.prior_weight_func = lambda x: 1 / (1 + np.exp((x - 2) / 1))
 
    @staticmethod
    def mean_encode_subroutine(X_train, y_train, X_test, variable, target, prior_weight_func):
        X_train = X_train[[variable]].copy()
        X_test = X_test[[variable]].copy()
 
        if target is not None:
            nf_name = '{}_pred_{}'.format(variable, target)
            X_train['pred_temp'] = (y_train == target).astype(int)  # classification
        else:
            nf_name = '{}_pred'.format(variable)
            X_train['pred_temp'] = y_train  # regression
        prior = X_train['pred_temp'].mean()
 
        col_avg_y = X_train.groupby(by=variable, axis=0)['pred_temp'].agg(['mean', 'size'])
        col_avg_y['size'] = prior_weight_func(col_avg_y['size'])
        col_avg_y[nf_name] = col_avg_y['size'] * prior + (1 - col_avg_y['size']) * col_avg_y['mean']
        col_avg_y.drop(['size', 'mean'], axis=1, inplace=True)
 
        nf_train = X_train.join(col_avg_y, on=variable)[nf_name].values
        nf_test = X_test.join(col_avg_y, on=variable).fillna(prior, inplace=False)[nf_name].values
 
        return nf_train, nf_test, prior, col_avg_y
 
    def fit_transform(self, X, y):
        """
        :param X: pandas DataFrame, n_samples * n_features
        :param y: pandas Series or numpy array, n_samples
        :return X_new: the transformed pandas DataFrame containing mean-encoded categorical features
        """
        X_new = X.copy()
        if self.target_type == 'classification':
            skf = StratifiedKFold(self.n_splits)
        else:
            skf = KFold(self.n_splits)
 
        if self.target_type == 'classification':
            self.target_values = sorted(set(y))
            self.learned_stats = {'{}_pred_{}'.format(variable, target): [] for variable, target in
                                  product(self.categorical_features, self.target_values)}
            for variable, target in product(self.categorical_features, self.target_values):
                nf_name = '{}_pred_{}'.format(variable, target)
                X_new.loc[:, nf_name] = np.nan
                for large_ind, small_ind in skf.split(X, y):
                    nf_large, nf_small, prior, col_avg_y = MeanEncoder.mean_encode_subroutine(
                        X_new.iloc[large_ind], y.iloc[large_ind], X_new.iloc[small_ind], variable, target, self.prior_weight_func)
                    X_new.iloc[small_ind, -1] = nf_small
                    self.learned_stats[nf_name].append((prior, col_avg_y))
        else:
            self.learned_stats = {'{}_pred'.format(variable): [] for variable in self.categorical_features}
            for variable in self.categorical_features:
                nf_name = '{}_pred'.format(variable)
                X_new.loc[:, nf_name] = np.nan
                for large_ind, small_ind in skf.split(X, y):
                    nf_large, nf_small, prior, col_avg_y = MeanEncoder.mean_encode_subroutine(
                        X_new.iloc[large_ind], y.iloc[large_ind], X_new.iloc[small_ind], variable, None, self.prior_weight_func)
                    X_new.iloc[small_ind, -1] = nf_small
                    self.learned_stats[nf_name].append((prior, col_avg_y))
        return X_new
 
    def transform(self, X):
        """
        :param X: pandas DataFrame, n_samples * n_features
        :return X_new: the transformed pandas DataFrame containing mean-encoded categorical features
        """
        X_new = X.copy()
 
        if self.target_type == 'classification':
            for variable, target in product(self.categorical_features, self.target_values):
                nf_name = '{}_pred_{}'.format(variable, target)
                X_new[nf_name] = 0
                for prior, col_avg_y in self.learned_stats[nf_name]:
                    X_new[nf_name] += X_new[[variable]].join(col_avg_y, on=variable).fillna(prior, inplace=False)[
                        nf_name]
                X_new[nf_name] /= self.n_splits
        else:
            for variable in self.categorical_features:
                nf_name = '{}_pred'.format(variable)
                X_new[nf_name] = 0
                for prior, col_avg_y in self.learned_stats[nf_name]:
                    X_new[nf_name] += X_new[[variable]].join(col_avg_y, on=variable).fillna(prior, inplace=False)[
                        nf_name]
                X_new[nf_name] /= self.n_splits
 
        return X_new

# %%
train_data = data.iloc[:train.shape[0], :]
test1_data = data.iloc[train.shape[0]:, :]

train_data_y = train_data['label']
train_data_X = train_data.drop('label', axis=1)

test1_data_y = test1_data['label']
test1_data_X = test1_data.drop('label', axis=1)

# %%
ME = MeanEncoder(categorical_features=cate_cols, n_splits=5, target_type='classification', prior_weight_func=None)
train_data_X = ME.fit_transform(train_data_X, train_data_y)
test1_data_X = ME.transform(test1_data_X)

# %%
train_data_X_train, train_data_X_val, train_data_y_train, train_data_y_val = train_test_split(train_data_X, train_data_y,
                                                                                              random_state=2020)

# %%
train_cols = [i for i in train_data_X_train.columns if i not in ['sid', 'label'] and train_data_X_train[i].dtypes != 'O']

# %%
params = {'task': 'train',
          'boosting_type': 'gbdt',
          'objective': 'binary',
          'metric': 'auc',
          'num_leaves': 256,
          'learning_rate': 0.05,
          'feature_fraction': 0.95,
          'bagging_fraction': 0.85,
          'bagging_freq': 5, 
          'min_data_in_leaf': 15}

# %%
use_cols = []
useless_cols = []

for i in train_cols:
    print(i)
    
    lgb_train = lgb.Dataset(train_data_X_train[[i]].values, train_data_y_train) 
    lgb_eval= lgb.Dataset(train_data_X_val[[i]].values, train_data_y_val, reference=lgb_train)
    lgb_test = lgb.train(params,
                         lgb_train,
                         num_boost_round=100,
                         valid_sets=[lgb_eval, lgb_train],
                         early_stopping_rounds=20,
                         verbose_eval=10)
    
    print('*' * 5)
    print(lgb_test.best_score['valid_0']['auc'])
    if lgb_test.best_score['valid_0']['auc'] > 0.52:
        use_cols.append(i)
    else:
        useless_cols.append(i)
    print('*' * 20)
    print('\n')
# Out:
# android_id
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.565548	valid_0's auc: 0.556563
# [20]	training's auc: 0.565756	valid_0's auc: 0.556471
# Early stopping, best iteration is:
# [1]	training's auc: 0.565314	valid_0's auc: 0.556797
# *****
# 0.5567967800195105
# ********************
#
#
# apptype
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.818892	valid_0's auc: 0.81912
# [20]	training's auc: 0.8189	valid_0's auc: 0.819136
# [30]	training's auc: 0.8189	valid_0's auc: 0.819139
# [40]	training's auc: 0.818901	valid_0's auc: 0.819132
# [50]	training's auc: 0.8189	valid_0's auc: 0.819171
# [60]	training's auc: 0.818901	valid_0's auc: 0.819168
# [70]	training's auc: 0.818901	valid_0's auc: 0.819139
# Early stopping, best iteration is:
# [50]	training's auc: 0.8189	valid_0's auc: 0.819171
# *****
# 0.8191705067485104
# ********************
#
#
# carrier
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.543381	valid_0's auc: 0.541281
# [20]	training's auc: 0.543381	valid_0's auc: 0.541281
# Early stopping, best iteration is:
# [1]	training's auc: 0.543381	valid_0's auc: 0.541281
# *****
# 0.5412813170021665
# ********************
#
#
# dev_height
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.80711	valid_0's auc: 0.806581
# [20]	training's auc: 0.807117	valid_0's auc: 0.806585
# [30]	training's auc: 0.807132	valid_0's auc: 0.806597
# [40]	training's auc: 0.807137	valid_0's auc: 0.806586
# Early stopping, best iteration is:
# [26]	training's auc: 0.807133	valid_0's auc: 0.806598
# *****
# 0.8065983516683942
# ********************
#
#
# dev_ppi
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.521534	valid_0's auc: 0.522592
# [20]	training's auc: 0.521534	valid_0's auc: 0.522592
# Early stopping, best iteration is:
# [1]	training's auc: 0.521533	valid_0's auc: 0.522592
# *****
# 0.5225922585230195
# ********************
#
#
# dev_width
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.705025	valid_0's auc: 0.702294
# [20]	training's auc: 0.705027	valid_0's auc: 0.702331
# [30]	training's auc: 0.705068	valid_0's auc: 0.702379
# [40]	training's auc: 0.705067	valid_0's auc: 0.702357
# Early stopping, best iteration is:
# [22]	training's auc: 0.705065	valid_0's auc: 0.702386
# *****
# 0.702385728992039
# ********************
#
#
# lan
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.67739	valid_0's auc: 0.675126
# [20]	training's auc: 0.67739	valid_0's auc: 0.675126
# Early stopping, best iteration is:
# [8]	training's auc: 0.67739	valid_0's auc: 0.675126
# *****
# 0.6751258487025812
# ********************
#
#
# media_id
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.872912	valid_0's auc: 0.870736
# [20]	training's auc: 0.872923	valid_0's auc: 0.87075
# [30]	training's auc: 0.872927	valid_0's auc: 0.870776
# [40]	training's auc: 0.872928	valid_0's auc: 0.870761
# Early stopping, best iteration is:
# [29]	training's auc: 0.872925	valid_0's auc: 0.87078
# *****
# 0.8707798411917735
# ********************
#
#
# ntt
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.589989	valid_0's auc: 0.587131
# [20]	training's auc: 0.589989	valid_0's auc: 0.587131
# Early stopping, best iteration is:
# [1]	training's auc: 0.589989	valid_0's auc: 0.587131
# *****
# 0.5871310958812972
# ********************
#
#
# osv
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.766947	valid_0's auc: 0.765808
# [20]	training's auc: 0.766947	valid_0's auc: 0.765808
# Early stopping, best iteration is:
# [1]	training's auc: 0.766947	valid_0's auc: 0.765808
# *****
# 0.7658075270804243
# ********************
#
#
# package
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.835421	valid_0's auc: 0.833089
# [20]	training's auc: 0.835429	valid_0's auc: 0.833129
# [30]	training's auc: 0.83543	valid_0's auc: 0.833123
# [40]	training's auc: 0.83543	valid_0's auc: 0.833122
# Early stopping, best iteration is:
# [20]	training's auc: 0.835429	valid_0's auc: 0.833129
# *****
# 0.8331292788087886
# ********************
#
#
# version
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.61494	valid_0's auc: 0.61632
# [20]	training's auc: 0.61494	valid_0's auc: 0.61632
# Early stopping, best iteration is:
# [1]	training's auc: 0.614939	valid_0's auc: 0.616322
# *****
# 0.6163223033669579
# ********************
#
#
# fea_hash
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.515538	valid_0's auc: 0.502514
# [20]	training's auc: 0.515745	valid_0's auc: 0.502486
# [30]	training's auc: 0.515857	valid_0's auc: 0.502655
# [40]	training's auc: 0.515916	valid_0's auc: 0.502833
# [50]	training's auc: 0.515925	valid_0's auc: 0.502497
# Early stopping, best iteration is:
# [37]	training's auc: 0.515918	valid_0's auc: 0.502941
# *****
# 0.5029406102231206
# ********************
#
#
# location
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.562608	valid_0's auc: 0.55931
# [20]	training's auc: 0.56266	valid_0's auc: 0.559496
# [30]	training's auc: 0.562691	valid_0's auc: 0.559408
# Early stopping, best iteration is:
# [17]	training's auc: 0.562665	valid_0's auc: 0.559516
# *****
# 0.559515677293068
# ********************
#
#
# fea1_hash
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.83299	valid_0's auc: 0.831802
# [20]	training's auc: 0.833	valid_0's auc: 0.831761
# Early stopping, best iteration is:
# [1]	training's auc: 0.832965	valid_0's auc: 0.831828
# *****
# 0.8318275432289988
# ********************
#
#
# cus_type
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.557997	valid_0's auc: 0.55381
# [20]	training's auc: 0.558062	valid_0's auc: 0.553438
# [30]	training's auc: 0.558072	valid_0's auc: 0.55339
# Early stopping, best iteration is:
# [10]	training's auc: 0.557997	valid_0's auc: 0.55381
# *****
# 0.5538102795758836
# ********************
#
#
# dev_height*dev_width
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.589363	valid_0's auc: 0.587196
# [20]	training's auc: 0.589363	valid_0's auc: 0.587196
# [30]	training's auc: 0.589363	valid_0's auc: 0.587196
# [40]	training's auc: 0.589363	valid_0's auc: 0.587196
# Early stopping, best iteration is:
# [23]	training's auc: 0.589363	valid_0's auc: 0.587196
# *****
# 0.5871959577269393
# ********************
#
#
# apptype_dev_height_min
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.774756	valid_0's auc: 0.773498
# [20]	training's auc: 0.774757	valid_0's auc: 0.773507
# Early stopping, best iteration is:
# [1]	training's auc: 0.774754	valid_0's auc: 0.77355
# *****
# 0.7735496438616526
# ********************
#
#
# apptype_dev_height_max
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.652714	valid_0's auc: 0.651324
# [20]	training's auc: 0.652711	valid_0's auc: 0.651318
# Early stopping, best iteration is:
# [6]	training's auc: 0.65271	valid_0's auc: 0.651332
# *****
# 0.6513321746421075
# ********************
#
#
# apptype_dev_height_median
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.768079	valid_0's auc: 0.768088
# [20]	training's auc: 0.76808	valid_0's auc: 0.768099
# Early stopping, best iteration is:
# [1]	training's auc: 0.768073	valid_0's auc: 0.768117
# *****
# 0.7681170073572336
# ********************
#
#
# apptype_dev_height_mean
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.817716	valid_0's auc: 0.818063
# [20]	training's auc: 0.817725	valid_0's auc: 0.818083
# [30]	training's auc: 0.817725	valid_0's auc: 0.81808
# [40]	training's auc: 0.817726	valid_0's auc: 0.818065
# Early stopping, best iteration is:
# [27]	training's auc: 0.817725	valid_0's auc: 0.818083
# *****
# 0.8180833352655763
# ********************
#
#
# apptype_dev_height_sum
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.524143	valid_0's auc: 0.524751
# [20]	training's auc: 0.524143	valid_0's auc: 0.524751
# Early stopping, best iteration is:
# [1]	training's auc: 0.524143	valid_0's auc: 0.524751
# *****
# 0.5247511558009429
# ********************
#
#
# apptype_dev_height_count
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.817863	valid_0's auc: 0.818386
# [20]	training's auc: 0.817869	valid_0's auc: 0.818405
# [30]	training's auc: 0.817869	valid_0's auc: 0.818405
# [40]	training's auc: 0.81787	valid_0's auc: 0.818392
# [50]	training's auc: 0.817869	valid_0's auc: 0.818433
# [60]	training's auc: 0.817869	valid_0's auc: 0.818435
# [70]	training's auc: 0.81787	valid_0's auc: 0.818401
# Early stopping, best iteration is:
# [53]	training's auc: 0.817869	valid_0's auc: 0.818435
# *****
# 0.81843497969882
# ********************
#
#
# apptype_dev_height_std
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.561471	valid_0's auc: 0.56207
# [20]	training's auc: 0.561471	valid_0's auc: 0.56207
# Early stopping, best iteration is:
# [1]	training's auc: 0.561471	valid_0's auc: 0.56207
# *****
# 0.5620700860032154
# ********************
#
#
# apptype_dev_height_nunique
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.81618	valid_0's auc: 0.816656
# [20]	training's auc: 0.816182	valid_0's auc: 0.816668
# [30]	training's auc: 0.816184	valid_0's auc: 0.816665
# [40]	training's auc: 0.816183	valid_0's auc: 0.816659
# Early stopping, best iteration is:
# [23]	training's auc: 0.816183	valid_0's auc: 0.816669
# *****
# 0.8166693168481562
# ********************
#
#
# apptype_dev_height_skew
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.5	valid_0's auc: 0.5
# [20]	training's auc: 0.5	valid_0's auc: 0.5
# Early stopping, best iteration is:
# [1]	training's auc: 0.5	valid_0's auc: 0.5
# *****
# 0.5
# ********************
#
#
# apptype_dev_width_min
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.741067	valid_0's auc: 0.739101
# [20]	training's auc: 0.741067	valid_0's auc: 0.739101
# Early stopping, best iteration is:
# [1]	training's auc: 0.741067	valid_0's auc: 0.739101
# *****
# 0.7391013444765284
# ********************
#
#
# apptype_dev_width_max
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.730128	valid_0's auc: 0.729829
# [20]	training's auc: 0.730129	valid_0's auc: 0.729829
# [30]	training's auc: 0.730149	valid_0's auc: 0.730293
# [40]	training's auc: 0.730149	valid_0's auc: 0.730293
# Early stopping, best iteration is:
# [26]	training's auc: 0.730149	valid_0's auc: 0.730293
# *****
# 0.7302928943820235
# ********************
#
#
# apptype_dev_width_median
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.684705	valid_0's auc: 0.682698
# [20]	training's auc: 0.684705	valid_0's auc: 0.682698
# Early stopping, best iteration is:
# [1]	training's auc: 0.684693	valid_0's auc: 0.682742
# *****
# 0.6827424938501246
# ********************
#
#
# apptype_dev_width_mean
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.815617	valid_0's auc: 0.815829
# [20]	training's auc: 0.815623	valid_0's auc: 0.815846
# [30]	training's auc: 0.815624	valid_0's auc: 0.815842
# Early stopping, best iteration is:
# [19]	training's auc: 0.815623	valid_0's auc: 0.815846
# *****
# 0.8158460828314518
# ********************
#
#
# apptype_dev_width_sum
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.524368	valid_0's auc: 0.524913
# [20]	training's auc: 0.524368	valid_0's auc: 0.524913
# Early stopping, best iteration is:
# [1]	training's auc: 0.524368	valid_0's auc: 0.524913
# *****
# 0.5249126445698078
# ********************
#
#
# apptype_dev_width_count
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.817863	valid_0's auc: 0.818386
# [20]	training's auc: 0.817869	valid_0's auc: 0.818405
# [30]	training's auc: 0.817869	valid_0's auc: 0.818405
# [40]	training's auc: 0.81787	valid_0's auc: 0.818392
# [50]	training's auc: 0.817869	valid_0's auc: 0.818433
# [60]	training's auc: 0.817869	valid_0's auc: 0.818435
# [70]	training's auc: 0.81787	valid_0's auc: 0.818401
# Early stopping, best iteration is:
# [53]	training's auc: 0.817869	valid_0's auc: 0.818435
# *****
# 0.81843497969882
# ********************
#
#
# apptype_dev_width_std
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.779365	valid_0's auc: 0.779161
# [20]	training's auc: 0.779365	valid_0's auc: 0.779174
# Early stopping, best iteration is:
# [6]	training's auc: 0.779363	valid_0's auc: 0.77919
# *****
# 0.7791901523179219
# ********************
#
#
# apptype_dev_width_nunique
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.797029	valid_0's auc: 0.796427
# [20]	training's auc: 0.79703	valid_0's auc: 0.796438
# Early stopping, best iteration is:
# [2]	training's auc: 0.797026	valid_0's auc: 0.796446
# *****
# 0.7964456018611306
# ********************
#
#
# apptype_dev_width_skew
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.5	valid_0's auc: 0.5
# [20]	training's auc: 0.5	valid_0's auc: 0.5
# Early stopping, best iteration is:
# [1]	training's auc: 0.5	valid_0's auc: 0.5
# *****
# 0.5
# ********************
#
#
# apptype_fea1_hash_min
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.813798	valid_0's auc: 0.813915
# [20]	training's auc: 0.813803	valid_0's auc: 0.813925
# [30]	training's auc: 0.813804	valid_0's auc: 0.813921
# [40]	training's auc: 0.813805	valid_0's auc: 0.813929
# Early stopping, best iteration is:
# [24]	training's auc: 0.813804	valid_0's auc: 0.813935
# *****
# 0.8139350959742949
# ********************
#
#
# apptype_fea1_hash_max
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.814367	valid_0's auc: 0.814536
# [20]	training's auc: 0.814374	valid_0's auc: 0.814558
# [30]	training's auc: 0.814374	valid_0's auc: 0.814551
# [40]	training's auc: 0.814374	valid_0's auc: 0.814551
# Early stopping, best iteration is:
# [20]	training's auc: 0.814374	valid_0's auc: 0.814558
# *****
# 0.8145583208419336
# ********************
#
#
# apptype_fea1_hash_median
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.81408	valid_0's auc: 0.8141
# [20]	training's auc: 0.814085	valid_0's auc: 0.814111
# [30]	training's auc: 0.81409	valid_0's auc: 0.814157
# [40]	training's auc: 0.814094	valid_0's auc: 0.814157
# [50]	training's auc: 0.814094	valid_0's auc: 0.814174
# [60]	training's auc: 0.814094	valid_0's auc: 0.814171
# Early stopping, best iteration is:
# [44]	training's auc: 0.814094	valid_0's auc: 0.81418
# *****
# 0.8141804615146961
# ********************
#
#
# apptype_fea1_hash_mean
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.817608	valid_0's auc: 0.817645
# [20]	training's auc: 0.817614	valid_0's auc: 0.81766
# [30]	training's auc: 0.817614	valid_0's auc: 0.817657
# Early stopping, best iteration is:
# [16]	training's auc: 0.817614	valid_0's auc: 0.817662
# *****
# 0.8176620392566576
# ********************
#
#
# apptype_fea1_hash_sum
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.818888	valid_0's auc: 0.819121
# [20]	training's auc: 0.818895	valid_0's auc: 0.81914
# [30]	training's auc: 0.818895	valid_0's auc: 0.819138
# Early stopping, best iteration is:
# [16]	training's auc: 0.818894	valid_0's auc: 0.819141
# *****
# 0.8191406440859021
# ********************
#
#
# apptype_fea1_hash_count
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.818807	valid_0's auc: 0.819103
# [20]	training's auc: 0.818814	valid_0's auc: 0.819121
# [30]	training's auc: 0.818814	valid_0's auc: 0.819123
# [40]	training's auc: 0.818815	valid_0's auc: 0.81911
# [50]	training's auc: 0.818814	valid_0's auc: 0.819151
# [60]	training's auc: 0.818814	valid_0's auc: 0.819153
# [70]	training's auc: 0.818815	valid_0's auc: 0.819119
# [80]	training's auc: 0.818815	valid_0's auc: 0.819119
# Early stopping, best iteration is:
# [60]	training's auc: 0.818814	valid_0's auc: 0.819153
# *****
# 0.8191531966938926
# ********************
#
#
# apptype_fea1_hash_std
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.816045	valid_0's auc: 0.816213
# [20]	training's auc: 0.816052	valid_0's auc: 0.816218
# Early stopping, best iteration is:
# [1]	training's auc: 0.816036	valid_0's auc: 0.816229
# *****
# 0.8162292566221718
# ********************
#
#
# apptype_fea1_hash_nunique
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.810455	valid_0's auc: 0.810846
# [20]	training's auc: 0.81046	valid_0's auc: 0.810855
# Early stopping, best iteration is:
# [1]	training's auc: 0.81045	valid_0's auc: 0.810961
# *****
# 0.8109613162173416
# ********************
#
#
# apptype_fea1_hash_skew
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.816041	valid_0's auc: 0.816226
# [20]	training's auc: 0.816048	valid_0's auc: 0.816243
# [30]	training's auc: 0.816048	valid_0's auc: 0.816237
# [40]	training's auc: 0.816048	valid_0's auc: 0.81624
# Early stopping, best iteration is:
# [20]	training's auc: 0.816048	valid_0's auc: 0.816243
# *****
# 0.81624257442374
# ********************
#
#
# media_id_dev_height_min
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.771242	valid_0's auc: 0.767542
# [20]	training's auc: 0.771244	valid_0's auc: 0.767417
# Early stopping, best iteration is:
# [7]	training's auc: 0.771242	valid_0's auc: 0.767542
# *****
# 0.7675421933779126
# ********************
#
#
# media_id_dev_height_max
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.694694	valid_0's auc: 0.693824
# [20]	training's auc: 0.694695	valid_0's auc: 0.693823
# Early stopping, best iteration is:
# [6]	training's auc: 0.694694	valid_0's auc: 0.693826
# *****
# 0.6938264727117818
# ********************
#
#
# media_id_dev_height_median
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.790869	valid_0's auc: 0.78935
# [20]	training's auc: 0.790872	valid_0's auc: 0.789363
# [30]	training's auc: 0.79087	valid_0's auc: 0.789346
# [40]	training's auc: 0.790873	valid_0's auc: 0.789352
# Early stopping, best iteration is:
# [20]	training's auc: 0.790872	valid_0's auc: 0.789363
# *****
# 0.7893634416733414
# ********************
#
#
# media_id_dev_height_mean
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.836072	valid_0's auc: 0.833554
# [20]	training's auc: 0.836086	valid_0's auc: 0.833546
# [30]	training's auc: 0.836099	valid_0's auc: 0.833555
# Early stopping, best iteration is:
# [13]	training's auc: 0.836082	valid_0's auc: 0.833578
# *****
# 0.8335781691867464
# ********************
#
#
# media_id_dev_height_sum
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.588878	valid_0's auc: 0.586141
# [20]	training's auc: 0.588898	valid_0's auc: 0.586165
# Early stopping, best iteration is:
# [1]	training's auc: 0.588811	valid_0's auc: 0.586227
# *****
# 0.5862269203207904
# ********************
#
#
# media_id_dev_height_count
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.836228	valid_0's auc: 0.833708
# [20]	training's auc: 0.836244	valid_0's auc: 0.83369
# [30]	training's auc: 0.836244	valid_0's auc: 0.833704
# Early stopping, best iteration is:
# [13]	training's auc: 0.836234	valid_0's auc: 0.833718
# *****
# 0.8337184124001212
# ********************
#
#
# media_id_dev_height_std
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.592149	valid_0's auc: 0.590267
# [20]	training's auc: 0.592167	valid_0's auc: 0.590282
# Early stopping, best iteration is:
# [1]	training's auc: 0.59216	valid_0's auc: 0.590291
# *****
# 0.5902913199920737
# ********************
#
#
# media_id_dev_height_nunique
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.820776	valid_0's auc: 0.818007
# [20]	training's auc: 0.820777	valid_0's auc: 0.818008
# [30]	training's auc: 0.820777	valid_0's auc: 0.817996
# Early stopping, best iteration is:
# [11]	training's auc: 0.820777	valid_0's auc: 0.818011
# *****
# 0.8180110060888683
# ********************
#
#
# media_id_dev_height_skew
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.500588	valid_0's auc: 0.500705
# [20]	training's auc: 0.500588	valid_0's auc: 0.500705
# [30]	training's auc: 0.500588	valid_0's auc: 0.500705
# [40]	training's auc: 0.500588	valid_0's auc: 0.500705
# Early stopping, best iteration is:
# [21]	training's auc: 0.500588	valid_0's auc: 0.500705
# *****
# 0.5007046069774402
# ********************
#
#
# media_id_dev_width_min
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.748606	valid_0's auc: 0.744858
# [20]	training's auc: 0.748606	valid_0's auc: 0.744858
# Early stopping, best iteration is:
# [6]	training's auc: 0.748606	valid_0's auc: 0.744859
# *****
# 0.7448586391773994
# ********************
#
#
# media_id_dev_width_max
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.784052	valid_0's auc: 0.782484
# [20]	training's auc: 0.784053	valid_0's auc: 0.782498
# [30]	training's auc: 0.784053	valid_0's auc: 0.782498
# [40]	training's auc: 0.784052	valid_0's auc: 0.782493
# [50]	training's auc: 0.784052	valid_0's auc: 0.782491
# Early stopping, best iteration is:
# [36]	training's auc: 0.784052	valid_0's auc: 0.782501
# *****
# 0.7825008024943627
# ********************
#
#
# media_id_dev_width_median
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.678647	valid_0's auc: 0.674871
# [20]	training's auc: 0.678647	valid_0's auc: 0.674871
# Early stopping, best iteration is:
# [6]	training's auc: 0.678647	valid_0's auc: 0.674871
# *****
# 0.6748708639884009
# ********************
#
#
# media_id_dev_width_mean
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.83421	valid_0's auc: 0.831881
# [20]	training's auc: 0.834218	valid_0's auc: 0.831926
# Early stopping, best iteration is:
# [1]	training's auc: 0.834208	valid_0's auc: 0.831972
# *****
# 0.8319723278976445
# ********************
#
#
# media_id_dev_width_sum
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.589265	valid_0's auc: 0.586614
# [20]	training's auc: 0.589274	valid_0's auc: 0.586558
# Early stopping, best iteration is:
# [6]	training's auc: 0.589265	valid_0's auc: 0.586614
# *****
# 0.5866140706071834
# ********************
#
#
# media_id_dev_width_count
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.836228	valid_0's auc: 0.833708
# [20]	training's auc: 0.836244	valid_0's auc: 0.83369
# [30]	training's auc: 0.836244	valid_0's auc: 0.833704
# Early stopping, best iteration is:
# [13]	training's auc: 0.836234	valid_0's auc: 0.833718
# *****
# 0.8337184124001212
# ********************
#
#
# media_id_dev_width_std
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.830075	valid_0's auc: 0.827283
# [20]	training's auc: 0.830085	valid_0's auc: 0.827268
# [30]	training's auc: 0.830088	valid_0's auc: 0.827251
# Early stopping, best iteration is:
# [14]	training's auc: 0.830074	valid_0's auc: 0.827287
# *****
# 0.8272874398897816
# ********************
#
#
# media_id_dev_width_nunique
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.794486	valid_0's auc: 0.792012
# [20]	training's auc: 0.794488	valid_0's auc: 0.791979
# Early stopping, best iteration is:
# [7]	training's auc: 0.794486	valid_0's auc: 0.79202
# *****
# 0.7920195223574881
# ********************
#
#
# media_id_dev_width_skew
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.501299	valid_0's auc: 0.501655
# [20]	training's auc: 0.501299	valid_0's auc: 0.501655
# Early stopping, best iteration is:
# [1]	training's auc: 0.501299	valid_0's auc: 0.501655
# *****
# 0.501654810603471
# ********************
#
#
# media_id_fea1_hash_min
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.855065	valid_0's auc: 0.853107
# [20]	training's auc: 0.855086	valid_0's auc: 0.853143
# [30]	training's auc: 0.855089	valid_0's auc: 0.853147
# [40]	training's auc: 0.855094	valid_0's auc: 0.853203
# [50]	training's auc: 0.855097	valid_0's auc: 0.853208
# [60]	training's auc: 0.855092	valid_0's auc: 0.853171
# [70]	training's auc: 0.855098	valid_0's auc: 0.853232
# [80]	training's auc: 0.8551	valid_0's auc: 0.853189
# [90]	training's auc: 0.855101	valid_0's auc: 0.853206
# Early stopping, best iteration is:
# [76]	training's auc: 0.8551	valid_0's auc: 0.853244
# *****
# 0.8532437484167024
# ********************
#
#
# media_id_fea1_hash_max
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.85575	valid_0's auc: 0.853709
# [20]	training's auc: 0.855759	valid_0's auc: 0.853745
# [30]	training's auc: 0.855759	valid_0's auc: 0.853727
# [40]	training's auc: 0.855758	valid_0's auc: 0.85377
# [50]	training's auc: 0.855762	valid_0's auc: 0.853732
# [60]	training's auc: 0.855764	valid_0's auc: 0.853768
# Early stopping, best iteration is:
# [42]	training's auc: 0.85576	valid_0's auc: 0.853772
# *****
# 0.8537716588352859
# ********************
#
#
# media_id_fea1_hash_median
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.865101	valid_0's auc: 0.862454
# [20]	training's auc: 0.865119	valid_0's auc: 0.862464
# [30]	training's auc: 0.865121	valid_0's auc: 0.862471
# [40]	training's auc: 0.865122	valid_0's auc: 0.862485
# [50]	training's auc: 0.865122	valid_0's auc: 0.862481
# [60]	training's auc: 0.865124	valid_0's auc: 0.862479
# Early stopping, best iteration is:
# [43]	training's auc: 0.865122	valid_0's auc: 0.862485
# *****
# 0.8624852756572098
# ********************
#
#
# media_id_fea1_hash_mean
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.871515	valid_0's auc: 0.868959
# [20]	training's auc: 0.871527	valid_0's auc: 0.869033
# [30]	training's auc: 0.871527	valid_0's auc: 0.868986
# [40]	training's auc: 0.871538	valid_0's auc: 0.86904
# [50]	training's auc: 0.871543	valid_0's auc: 0.869068
# [60]	training's auc: 0.871542	valid_0's auc: 0.869065
# [70]	training's auc: 0.871545	valid_0's auc: 0.869067
# Early stopping, best iteration is:
# [50]	training's auc: 0.871543	valid_0's auc: 0.869068
# *****
# 0.8690678810176609
# ********************
#
#
# media_id_fea1_hash_sum
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.871553	valid_0's auc: 0.869762
# [20]	training's auc: 0.871557	valid_0's auc: 0.869766
# [30]	training's auc: 0.871559	valid_0's auc: 0.869765
# Early stopping, best iteration is:
# [13]	training's auc: 0.871557	valid_0's auc: 0.869769
# *****
# 0.8697691739497865
# ********************
#
#
# media_id_fea1_hash_count
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.871831	valid_0's auc: 0.869839
# [20]	training's auc: 0.871845	valid_0's auc: 0.869835
# [30]	training's auc: 0.871846	valid_0's auc: 0.869852
# [40]	training's auc: 0.871846	valid_0's auc: 0.869835
# Early stopping, best iteration is:
# [29]	training's auc: 0.871846	valid_0's auc: 0.869854
# *****
# 0.8698536831942331
# ********************
#
#
# media_id_fea1_hash_std
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.858435	valid_0's auc: 0.855928
# [20]	training's auc: 0.858463	valid_0's auc: 0.855891
# [30]	training's auc: 0.858465	valid_0's auc: 0.855897
# [40]	training's auc: 0.858469	valid_0's auc: 0.855883
# Early stopping, best iteration is:
# [23]	training's auc: 0.85845	valid_0's auc: 0.855978
# *****
# 0.8559784917180557
# ********************
#
#
# media_id_fea1_hash_nunique
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.737482	valid_0's auc: 0.734947
# [20]	training's auc: 0.737482	valid_0's auc: 0.734942
# Early stopping, best iteration is:
# [4]	training's auc: 0.737456	valid_0's auc: 0.735032
# *****
# 0.7350321532816897
# ********************
#
#
# media_id_fea1_hash_skew
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.858406	valid_0's auc: 0.855829
# [20]	training's auc: 0.858422	valid_0's auc: 0.855763
# [30]	training's auc: 0.858423	valid_0's auc: 0.855766
# [40]	training's auc: 0.858424	valid_0's auc: 0.855746
# Early stopping, best iteration is:
# [22]	training's auc: 0.858409	valid_0's auc: 0.855849
# *****
# 0.8558486050724385
# ********************
#
#
# osv_dev_height_min
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.646312	valid_0's auc: 0.645432
# [20]	training's auc: 0.646312	valid_0's auc: 0.645432
# Early stopping, best iteration is:
# [1]	training's auc: 0.646312	valid_0's auc: 0.645432
# *****
# 0.645432077499316
# ********************
#
#
# osv_dev_height_max
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.766284	valid_0's auc: 0.765189
# [20]	training's auc: 0.766284	valid_0's auc: 0.765189
# Early stopping, best iteration is:
# [1]	training's auc: 0.766284	valid_0's auc: 0.765189
# *****
# 0.7651886193496312
# ********************
#
#
# osv_dev_height_median
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.759269	valid_0's auc: 0.757505
# [20]	training's auc: 0.759269	valid_0's auc: 0.757505
# Early stopping, best iteration is:
# [1]	training's auc: 0.759269	valid_0's auc: 0.757505
# *****
# 0.7575045057276615
# ********************
#
#
# osv_dev_height_mean
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.766941	valid_0's auc: 0.765808
# [20]	training's auc: 0.766941	valid_0's auc: 0.765808
# Early stopping, best iteration is:
# [1]	training's auc: 0.766941	valid_0's auc: 0.765808
# *****
# 0.7658075270804243
# ********************
#
#
# osv_dev_height_sum
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.509855	valid_0's auc: 0.50946
# [20]	training's auc: 0.509855	valid_0's auc: 0.50946
# Early stopping, best iteration is:
# [1]	training's auc: 0.509855	valid_0's auc: 0.50946
# *****
# 0.509459864012011
# ********************
#
#
# osv_dev_height_count
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.766947	valid_0's auc: 0.765808
# [20]	training's auc: 0.766947	valid_0's auc: 0.765808
# Early stopping, best iteration is:
# [1]	training's auc: 0.766947	valid_0's auc: 0.765808
# *****
# 0.7658075270804243
# ********************
#
#
# osv_dev_height_std
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.509852	valid_0's auc: 0.50946
# [20]	training's auc: 0.509852	valid_0's auc: 0.50946
# Early stopping, best iteration is:
# [1]	training's auc: 0.509852	valid_0's auc: 0.50946
# *****
# 0.509459864012011
# ********************
#
#
# osv_dev_height_nunique
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.766947	valid_0's auc: 0.765808
# [20]	training's auc: 0.766947	valid_0's auc: 0.765808
# Early stopping, best iteration is:
# [1]	training's auc: 0.766947	valid_0's auc: 0.765808
# *****
# 0.7658075270804243
# ********************
#
#
# osv_dev_height_skew
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.5	valid_0's auc: 0.5
# [20]	training's auc: 0.5	valid_0's auc: 0.5
# Early stopping, best iteration is:
# [1]	training's auc: 0.5	valid_0's auc: 0.5
# *****
# 0.5
# ********************
#
#
# osv_dev_width_min
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.766943	valid_0's auc: 0.765808
# [20]	training's auc: 0.766943	valid_0's auc: 0.765808
# Early stopping, best iteration is:
# [1]	training's auc: 0.766943	valid_0's auc: 0.765808
# *****
# 0.7658075270804243
# ********************
#
#
# osv_dev_width_max
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.649739	valid_0's auc: 0.648243
# [20]	training's auc: 0.649739	valid_0's auc: 0.648243
# Early stopping, best iteration is:
# [1]	training's auc: 0.649739	valid_0's auc: 0.648243
# *****
# 0.6482432950641684
# ********************
#
#
# osv_dev_width_median
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.523936	valid_0's auc: 0.52356
# [20]	training's auc: 0.523936	valid_0's auc: 0.52356
# Early stopping, best iteration is:
# [1]	training's auc: 0.523936	valid_0's auc: 0.52356
# *****
# 0.5235595118866831
# ********************
#
#
# osv_dev_width_mean
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.766944	valid_0's auc: 0.765808
# [20]	training's auc: 0.766944	valid_0's auc: 0.765808
# Early stopping, best iteration is:
# [1]	training's auc: 0.766944	valid_0's auc: 0.765808
# *****
# 0.7658075270804243
# ********************
#
#
# osv_dev_width_sum
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.509855	valid_0's auc: 0.50946
# [20]	training's auc: 0.509855	valid_0's auc: 0.50946
# Early stopping, best iteration is:
# [1]	training's auc: 0.509855	valid_0's auc: 0.50946
# *****
# 0.509459864012011
# ********************
#
#
# osv_dev_width_count
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.766947	valid_0's auc: 0.765808
# [20]	training's auc: 0.766947	valid_0's auc: 0.765808
# Early stopping, best iteration is:
# [1]	training's auc: 0.766947	valid_0's auc: 0.765808
# *****
# 0.7658075270804243
# ********************
#
#
# osv_dev_width_std
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.514904	valid_0's auc: 0.514986
# [20]	training's auc: 0.514904	valid_0's auc: 0.514986
# Early stopping, best iteration is:
# [1]	training's auc: 0.514904	valid_0's auc: 0.514986
# *****
# 0.5149856327609975
# ********************
#
#
# osv_dev_width_nunique
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.766947	valid_0's auc: 0.765808
# [20]	training's auc: 0.766947	valid_0's auc: 0.765808
# Early stopping, best iteration is:
# [1]	training's auc: 0.766947	valid_0's auc: 0.765808
# *****
# 0.7658075270804243
# ********************
#
#
# osv_dev_width_skew
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.5	valid_0's auc: 0.5
# [20]	training's auc: 0.5	valid_0's auc: 0.5
# Early stopping, best iteration is:
# [1]	training's auc: 0.5	valid_0's auc: 0.5
# *****
# 0.5
# ********************
#
#
# osv_fea1_hash_min
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.766947	valid_0's auc: 0.765808
# [20]	training's auc: 0.766947	valid_0's auc: 0.765808
# Early stopping, best iteration is:
# [1]	training's auc: 0.766947	valid_0's auc: 0.765808
# *****
# 0.7658075425815833
# ********************
#
#
# osv_fea1_hash_max
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.766947	valid_0's auc: 0.765808
# [20]	training's auc: 0.766947	valid_0's auc: 0.765808
# Early stopping, best iteration is:
# [1]	training's auc: 0.766947	valid_0's auc: 0.765808
# *****
# 0.7658075270804243
# ********************
#
#
# osv_fea1_hash_median
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.766944	valid_0's auc: 0.765808
# [20]	training's auc: 0.766944	valid_0's auc: 0.765808
# Early stopping, best iteration is:
# [1]	training's auc: 0.766944	valid_0's auc: 0.765808
# *****
# 0.7658075270804243
# ********************
#
#
# osv_fea1_hash_mean
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.766944	valid_0's auc: 0.765808
# [20]	training's auc: 0.766944	valid_0's auc: 0.765808
# Early stopping, best iteration is:
# [1]	training's auc: 0.766944	valid_0's auc: 0.765808
# *****
# 0.7658075270804243
# ********************
#
#
# osv_fea1_hash_sum
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.766947	valid_0's auc: 0.765808
# [20]	training's auc: 0.766947	valid_0's auc: 0.765808
# Early stopping, best iteration is:
# [1]	training's auc: 0.766947	valid_0's auc: 0.765808
# *****
# 0.7658075270804243
# ********************
#
#
# osv_fea1_hash_count
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.766947	valid_0's auc: 0.765808
# [20]	training's auc: 0.766947	valid_0's auc: 0.765808
# Early stopping, best iteration is:
# [1]	training's auc: 0.766947	valid_0's auc: 0.765808
# *****
# 0.7658075270804243
# ********************
#
#
# osv_fea1_hash_std
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.766939	valid_0's auc: 0.765808
# [20]	training's auc: 0.766939	valid_0's auc: 0.765808
# Early stopping, best iteration is:
# [1]	training's auc: 0.766939	valid_0's auc: 0.765808
# *****
# 0.7658075270804243
# ********************
#
#
# osv_fea1_hash_nunique
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.766947	valid_0's auc: 0.765808
# [20]	training's auc: 0.766947	valid_0's auc: 0.765808
# Early stopping, best iteration is:
# [1]	training's auc: 0.766947	valid_0's auc: 0.765808
# *****
# 0.7658075270804243
# ********************
#
#
# osv_fea1_hash_skew
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.766931	valid_0's auc: 0.765808
# [20]	training's auc: 0.766931	valid_0's auc: 0.765808
# Early stopping, best iteration is:
# [1]	training's auc: 0.766931	valid_0's auc: 0.765808
# *****
# 0.7658075270804243
# ********************
#
#
# package_dev_height_min
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.776753	valid_0's auc: 0.77269
# [20]	training's auc: 0.776762	valid_0's auc: 0.772694
# [30]	training's auc: 0.776767	valid_0's auc: 0.772683
# Early stopping, best iteration is:
# [17]	training's auc: 0.776761	valid_0's auc: 0.772695
# *****
# 0.772694645023585
# ********************
#
#
# package_dev_height_max
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.71184	valid_0's auc: 0.709942
# [20]	training's auc: 0.711837	valid_0's auc: 0.709928
# [30]	training's auc: 0.711838	valid_0's auc: 0.709928
# [40]	training's auc: 0.711837	valid_0's auc: 0.709929
# Early stopping, best iteration is:
# [23]	training's auc: 0.711838	valid_0's auc: 0.709964
# *****
# 0.7099644635570427
# ********************
#
#
# package_dev_height_median
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.766494	valid_0's auc: 0.764428
# [20]	training's auc: 0.766495	valid_0's auc: 0.764437
# Early stopping, best iteration is:
# [6]	training's auc: 0.766485	valid_0's auc: 0.764447
# *****
# 0.7644466353626047
# ********************
#
#
# package_dev_height_mean
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.801944	valid_0's auc: 0.798862
# [20]	training's auc: 0.801948	valid_0's auc: 0.798851
# Early stopping, best iteration is:
# [1]	training's auc: 0.801929	valid_0's auc: 0.798899
# *****
# 0.7988990144990562
# ********************
#
#
# package_dev_height_sum
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.561646	valid_0's auc: 0.558876
# [20]	training's auc: 0.561663	valid_0's auc: 0.558932
# [30]	training's auc: 0.561672	valid_0's auc: 0.558942
# [40]	training's auc: 0.561698	valid_0's auc: 0.559028
# [50]	training's auc: 0.561715	valid_0's auc: 0.559027
# [60]	training's auc: 0.561717	valid_0's auc: 0.55905
# Early stopping, best iteration is:
# [48]	training's auc: 0.561713	valid_0's auc: 0.559052
# *****
# 0.5590520260965554
# ********************
#
#
# package_dev_height_count
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.801943	valid_0's auc: 0.798937
# [20]	training's auc: 0.801943	valid_0's auc: 0.798932
# Early stopping, best iteration is:
# [4]	training's auc: 0.801941	valid_0's auc: 0.798959
# *****
# 0.7989593598706342
# ********************
#
#
# package_dev_height_std
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.564941	valid_0's auc: 0.562856
# [20]	training's auc: 0.564941	valid_0's auc: 0.562856
# [30]	training's auc: 0.564941	valid_0's auc: 0.562856
# [40]	training's auc: 0.56495	valid_0's auc: 0.562859
# [50]	training's auc: 0.564964	valid_0's auc: 0.562847
# Early stopping, best iteration is:
# [36]	training's auc: 0.56495	valid_0's auc: 0.562859
# *****
# 0.5628594864984238
# ********************
#
#
# package_dev_height_nunique
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.791581	valid_0's auc: 0.788389
# [20]	training's auc: 0.791584	valid_0's auc: 0.788402
# [30]	training's auc: 0.791585	valid_0's auc: 0.788409
# [40]	training's auc: 0.791584	valid_0's auc: 0.788395
# Early stopping, best iteration is:
# [22]	training's auc: 0.791584	valid_0's auc: 0.788412
# *****
# 0.7884120681581843
# ********************
#
#
# package_dev_height_skew
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.501097	valid_0's auc: 0.501158
# [20]	training's auc: 0.501097	valid_0's auc: 0.501158
# Early stopping, best iteration is:
# [1]	training's auc: 0.501097	valid_0's auc: 0.501158
# *****
# 0.5011579770622504
# ********************
#
#
# package_dev_width_min
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.738253	valid_0's auc: 0.734523
# [20]	training's auc: 0.738253	valid_0's auc: 0.734523
# Early stopping, best iteration is:
# [6]	training's auc: 0.738253	valid_0's auc: 0.734523
# *****
# 0.7345228753843744
# ********************
#
#
# package_dev_width_max
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.756066	valid_0's auc: 0.753047
# [20]	training's auc: 0.756067	valid_0's auc: 0.753031
# [30]	training's auc: 0.756067	valid_0's auc: 0.753031
# Early stopping, best iteration is:
# [11]	training's auc: 0.756066	valid_0's auc: 0.753048
# *****
# 0.753047559829336
# ********************
#
#
# package_dev_width_median
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.65848	valid_0's auc: 0.654823
# [20]	training's auc: 0.65848	valid_0's auc: 0.654823
# [30]	training's auc: 0.65848	valid_0's auc: 0.654824
# [40]	training's auc: 0.65848	valid_0's auc: 0.654823
# [50]	training's auc: 0.658481	valid_0's auc: 0.654837
# [60]	training's auc: 0.658481	valid_0's auc: 0.654838
# Early stopping, best iteration is:
# [46]	training's auc: 0.658481	valid_0's auc: 0.654838
# *****
# 0.6548379676285473
# ********************
#
#
# package_dev_width_mean
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.799868	valid_0's auc: 0.796933
# [20]	training's auc: 0.799872	valid_0's auc: 0.796938
# [30]	training's auc: 0.799878	valid_0's auc: 0.796953
# [40]	training's auc: 0.799881	valid_0's auc: 0.796965
# [50]	training's auc: 0.799882	valid_0's auc: 0.79695
# Early stopping, best iteration is:
# [39]	training's auc: 0.799881	valid_0's auc: 0.796966
# *****
# 0.7969656178340679
# ********************
#
#
# package_dev_width_sum
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.561943	valid_0's auc: 0.559057
# [20]	training's auc: 0.561965	valid_0's auc: 0.559078
# [30]	training's auc: 0.561966	valid_0's auc: 0.55908
# [40]	training's auc: 0.561987	valid_0's auc: 0.559084
# [50]	training's auc: 0.561986	valid_0's auc: 0.559073
# Early stopping, best iteration is:
# [39]	training's auc: 0.561987	valid_0's auc: 0.559084
# *****
# 0.5590842585148647
# ********************
#
#
# package_dev_width_count
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.801943	valid_0's auc: 0.798937
# [20]	training's auc: 0.801943	valid_0's auc: 0.798932
# Early stopping, best iteration is:
# [4]	training's auc: 0.801941	valid_0's auc: 0.798959
# *****
# 0.7989593598706342
# ********************
#
#
# package_dev_width_std
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.794192	valid_0's auc: 0.790798
# [20]	training's auc: 0.794188	valid_0's auc: 0.790784
# [30]	training's auc: 0.794193	valid_0's auc: 0.790795
# Early stopping, best iteration is:
# [10]	training's auc: 0.794192	valid_0's auc: 0.790798
# *****
# 0.7907976664280524
# ********************
#
#
# package_dev_width_nunique
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.774121	valid_0's auc: 0.771609
# [20]	training's auc: 0.774122	valid_0's auc: 0.771606
# [30]	training's auc: 0.774122	valid_0's auc: 0.771611
# Early stopping, best iteration is:
# [15]	training's auc: 0.774119	valid_0's auc: 0.771629
# *****
# 0.7716287791791457
# ********************
#
#
# package_dev_width_skew
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.501791	valid_0's auc: 0.5021
# [20]	training's auc: 0.501791	valid_0's auc: 0.5021
# Early stopping, best iteration is:
# [1]	training's auc: 0.501791	valid_0's auc: 0.5021
# *****
# 0.5020995342442586
# ********************
#
#
# package_fea1_hash_min
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.818812	valid_0's auc: 0.816014
# [20]	training's auc: 0.818831	valid_0's auc: 0.816034
# [30]	training's auc: 0.818833	valid_0's auc: 0.816062
# [40]	training's auc: 0.818836	valid_0's auc: 0.816068
# [50]	training's auc: 0.818836	valid_0's auc: 0.816055
# [60]	training's auc: 0.818836	valid_0's auc: 0.816044
# Early stopping, best iteration is:
# [40]	training's auc: 0.818836	valid_0's auc: 0.816068
# *****
# 0.8160682863094276
# ********************
#
#
# package_fea1_hash_max
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.817934	valid_0's auc: 0.815089
# [20]	training's auc: 0.817937	valid_0's auc: 0.815073
# Early stopping, best iteration is:
# [1]	training's auc: 0.817909	valid_0's auc: 0.815108
# *****
# 0.8151081235089892
# ********************
#
#
# package_fea1_hash_median
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.829427	valid_0's auc: 0.826707
# [20]	training's auc: 0.829439	valid_0's auc: 0.826731
# Early stopping, best iteration is:
# [7]	training's auc: 0.829413	valid_0's auc: 0.826735
# *****
# 0.8267351033597133
# ********************
#
#
# package_fea1_hash_mean
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.833791	valid_0's auc: 0.831251
# [20]	training's auc: 0.833795	valid_0's auc: 0.83126
# [30]	training's auc: 0.833796	valid_0's auc: 0.83126
# [40]	training's auc: 0.833797	valid_0's auc: 0.831254
# Early stopping, best iteration is:
# [29]	training's auc: 0.833796	valid_0's auc: 0.831261
# *****
# 0.8312611278032644
# ********************
#
#
# package_fea1_hash_sum
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.833311	valid_0's auc: 0.831144
# [20]	training's auc: 0.833312	valid_0's auc: 0.831156
# [30]	training's auc: 0.833312	valid_0's auc: 0.831153
# [40]	training's auc: 0.833313	valid_0's auc: 0.831147
# Early stopping, best iteration is:
# [20]	training's auc: 0.833312	valid_0's auc: 0.831156
# *****
# 0.8311555222500243
# ********************
#
#
# package_fea1_hash_count
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.835087	valid_0's auc: 0.832772
# [20]	training's auc: 0.835087	valid_0's auc: 0.832786
# [30]	training's auc: 0.835088	valid_0's auc: 0.832787
# [40]	training's auc: 0.835088	valid_0's auc: 0.8328
# [50]	training's auc: 0.835089	valid_0's auc: 0.832787
# Early stopping, best iteration is:
# [31]	training's auc: 0.835087	valid_0's auc: 0.832804
# *****
# 0.8328038442732973
# ********************
#
#
# package_fea1_hash_std
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.811429	valid_0's auc: 0.8085
# [20]	training's auc: 0.811438	valid_0's auc: 0.808529
# [30]	training's auc: 0.811439	valid_0's auc: 0.808514
# [40]	training's auc: 0.811441	valid_0's auc: 0.808522
# Early stopping, best iteration is:
# [20]	training's auc: 0.811438	valid_0's auc: 0.808529
# *****
# 0.8085291204385454
# ********************
#
#
# package_fea1_hash_nunique
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.728272	valid_0's auc: 0.725291
# [20]	training's auc: 0.728274	valid_0's auc: 0.725308
# [30]	training's auc: 0.728274	valid_0's auc: 0.725291
# Early stopping, best iteration is:
# [18]	training's auc: 0.728273	valid_0's auc: 0.725309
# *****
# 0.7253086970565366
# ********************
#
#
# package_fea1_hash_skew
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.813923	valid_0's auc: 0.810998
# [20]	training's auc: 0.813923	valid_0's auc: 0.810984
# [30]	training's auc: 0.813925	valid_0's auc: 0.810991
# Early stopping, best iteration is:
# [10]	training's auc: 0.813923	valid_0's auc: 0.810998
# *****
# 0.8109983825632034
# ********************
#
#
# apptype_media_id_dev_height_min
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.771242	valid_0's auc: 0.767542
# [20]	training's auc: 0.771244	valid_0's auc: 0.767417
# Early stopping, best iteration is:
# ...
# [20]	training's auc: 0.519691	valid_0's auc: 0.518787
# [30]	training's auc: 0.519675	valid_0's auc: 0.518698
# Early stopping, best iteration is:
# [19]	training's auc: 0.519691	valid_0's auc: 0.518787
# *****
# 0.5187870304161608
# ********************
#
#
# dayofweek_cnt_code
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.511259	valid_0's auc: 0.509348
# [20]	training's auc: 0.511259	valid_0's auc: 0.509348
# Early stopping, best iteration is:
# [1]	training's auc: 0.511172	valid_0's auc: 0.509589
# *****
# 0.5095888394200728
# ********************
#
#
# time_cnt_code
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.526735	valid_0's auc: 0.519472
# [20]	training's auc: 0.526892	valid_0's auc: 0.520078
# [30]	training's auc: 0.526922	valid_0's auc: 0.520239
# [40]	training's auc: 0.526931	valid_0's auc: 0.520211
# Early stopping, best iteration is:
# [26]	training's auc: 0.526931	valid_0's auc: 0.520319
# *****
# 0.5203186326832747
# ********************
#
#
# user_id_day_media_count
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.694905	valid_0's auc: 0.692406
# [20]	training's auc: 0.694906	valid_0's auc: 0.692406
# [30]	training's auc: 0.694906	valid_0's auc: 0.692408
# Early stopping, best iteration is:
# [13]	training's auc: 0.694905	valid_0's auc: 0.692412
# *****
# 0.6924119966898984
# ********************
#
#
# user_id_time_media_count
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.671821	valid_0's auc: 0.669797
# [20]	training's auc: 0.671826	valid_0's auc: 0.669783
# Early stopping, best iteration is:
# [6]	training's auc: 0.671819	valid_0's auc: 0.669801
# *****
# 0.6698005195480685
# ********************
#
#
# user_id_day_app_count
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.694897	valid_0's auc: 0.692399
# [20]	training's auc: 0.694898	valid_0's auc: 0.692399
# [30]	training's auc: 0.694898	valid_0's auc: 0.692401
# Early stopping, best iteration is:
# [13]	training's auc: 0.694898	valid_0's auc: 0.692405
# *****
# 0.6924046085300415
# ********************
#
#
# user_id_time_app_count
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.671823	valid_0's auc: 0.669797
# [20]	training's auc: 0.671828	valid_0's auc: 0.669783
# Early stopping, best iteration is:
# [6]	training's auc: 0.671821	valid_0's auc: 0.669801
# *****
# 0.6698005195480685
# ********************
#
#
# user_id_day_count
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.694906	valid_0's auc: 0.692401
# [20]	training's auc: 0.694907	valid_0's auc: 0.6924
# [30]	training's auc: 0.694907	valid_0's auc: 0.692403
# Early stopping, best iteration is:
# [13]	training's auc: 0.694906	valid_0's auc: 0.692407
# *****
# 0.6924068614505604
# ********************
#
#
# user_id_time_count
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.671855	valid_0's auc: 0.669825
# [20]	training's auc: 0.67186	valid_0's auc: 0.669811
# Early stopping, best iteration is:
# [6]	training's auc: 0.671853	valid_0's auc: 0.669829
# *****
# 0.6698287135941774
# ********************
#
#
# apptype_media_id_labelencode
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.873095	valid_0's auc: 0.87093
# [20]	training's auc: 0.873119	valid_0's auc: 0.870951
# [30]	training's auc: 0.873128	valid_0's auc: 0.870961
# [40]	training's auc: 0.873135	valid_0's auc: 0.870963
# Early stopping, best iteration is:
# [28]	training's auc: 0.873128	valid_0's auc: 0.870972
# *****
# 0.8709724688426377
# ********************
#
#
# apptype_osv_labelencode
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.913071	valid_0's auc: 0.911472
# [20]	training's auc: 0.913084	valid_0's auc: 0.91147
# [30]	training's auc: 0.913084	valid_0's auc: 0.911473
# [40]	training's auc: 0.913086	valid_0's auc: 0.911462
# [50]	training's auc: 0.913085	valid_0's auc: 0.911463
# Early stopping, best iteration is:
# [35]	training's auc: 0.913083	valid_0's auc: 0.911479
# *****
# 0.9114787691440925
# ********************
#
#
# media_id_osv_labelencode
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.877235	valid_0's auc: 0.875322
# [20]	training's auc: 0.877245	valid_0's auc: 0.875343
# [30]	training's auc: 0.877245	valid_0's auc: 0.875347
# [40]	training's auc: 0.877245	valid_0's auc: 0.87535
# [50]	training's auc: 0.877246	valid_0's auc: 0.875343
# [60]	training's auc: 0.877246	valid_0's auc: 0.875321
# Early stopping, best iteration is:
# [42]	training's auc: 0.877245	valid_0's auc: 0.875372
# *****
# 0.8753719894802863
# ********************
#
#
# user_id_labelencode
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.861994	valid_0's auc: 0.861383
# [20]	training's auc: 0.862003	valid_0's auc: 0.861399
# [30]	training's auc: 0.862004	valid_0's auc: 0.861384
# [40]	training's auc: 0.862006	valid_0's auc: 0.861418
# [50]	training's auc: 0.862007	valid_0's auc: 0.861399
# [60]	training's auc: 0.862006	valid_0's auc: 0.861433
# [70]	training's auc: 0.862008	valid_0's auc: 0.861434
# Early stopping, best iteration is:
# [55]	training's auc: 0.862004	valid_0's auc: 0.861443
# *****
# 0.8614431445213188
# ********************
#
#
# user_id_day_fea_hash_count
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.508168	valid_0's auc: 0.508048
# [20]	training's auc: 0.508168	valid_0's auc: 0.508048
# Early stopping, best iteration is:
# [7]	training's auc: 0.508168	valid_0's auc: 0.508048
# *****
# 0.5080478128325921
# ********************
#
#
# user_id_day_fea1_hash_count
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.683013	valid_0's auc: 0.68042
# [20]	training's auc: 0.683017	valid_0's auc: 0.680433
# [30]	training's auc: 0.683018	valid_0's auc: 0.680426
# Early stopping, best iteration is:
# [19]	training's auc: 0.683017	valid_0's auc: 0.680433
# *****
# 0.680432963482793
# ********************
#
#
# user_id_time_fea_hash_count
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.50546	valid_0's auc: 0.505346
# [20]	training's auc: 0.50546	valid_0's auc: 0.505346
# Early stopping, best iteration is:
# [1]	training's auc: 0.50546	valid_0's auc: 0.505346
# *****
# 0.505346481959266
# ********************
#
#
# user_id_time_fea1_hash_count
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.653986	valid_0's auc: 0.652055
# [20]	training's auc: 0.653989	valid_0's auc: 0.65206
# [30]	training's auc: 0.65399	valid_0's auc: 0.652045
# [40]	training's auc: 0.65399	valid_0's auc: 0.652049
# Early stopping, best iteration is:
# [20]	training's auc: 0.653989	valid_0's auc: 0.65206
# *****
# 0.6520599645636996
# ********************
#
#
# android_id_pred_0.0
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.579169	valid_0's auc: 0.579218
# [20]	training's auc: 0.579189	valid_0's auc: 0.579262
# Early stopping, best iteration is:
# [1]	training's auc: 0.579189	valid_0's auc: 0.579262
# *****
# 0.5792618042605214
# ********************
#
#
# android_id_pred_1.0
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.579143	valid_0's auc: 0.579182
# [20]	training's auc: 0.579163	valid_0's auc: 0.579225
# Early stopping, best iteration is:
# [5]	training's auc: 0.579163	valid_0's auc: 0.579226
# *****
# 0.5792256328824036
# ********************
#
#
# apptype_pred_0.0
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.819428	valid_0's auc: 0.81855
# [20]	training's auc: 0.819437	valid_0's auc: 0.8185
# [30]	training's auc: 0.819444	valid_0's auc: 0.818531
# Early stopping, best iteration is:
# [10]	training's auc: 0.819428	valid_0's auc: 0.81855
# *****
# 0.8185500061134906
# ********************
#
#
# apptype_pred_1.0
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.819387	valid_0's auc: 0.818459
# [20]	training's auc: 0.81941	valid_0's auc: 0.818422
# Early stopping, best iteration is:
# [1]	training's auc: 0.819347	valid_0's auc: 0.818467
# *****
# 0.8184669128550838
# ********************
#
#
# carrier_pred_0.0
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.54374	valid_0's auc: 0.540146
# [20]	training's auc: 0.543779	valid_0's auc: 0.540379
# [30]	training's auc: 0.543783	valid_0's auc: 0.540165
# Early stopping, best iteration is:
# [17]	training's auc: 0.54374	valid_0's auc: 0.540394
# *****
# 0.540394079852787
# ********************
#
#
# carrier_pred_1.0
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.54374	valid_0's auc: 0.540146
# [20]	training's auc: 0.543779	valid_0's auc: 0.540379
# [30]	training's auc: 0.543783	valid_0's auc: 0.540165
# Early stopping, best iteration is:
# [17]	training's auc: 0.54374	valid_0's auc: 0.540394
# *****
# 0.540394079852787
# ********************
#
#
# lan_pred_0.0
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.678026	valid_0's auc: 0.67474
# [20]	training's auc: 0.678026	valid_0's auc: 0.67474
# [30]	training's auc: 0.677971	valid_0's auc: 0.674593
# Early stopping, best iteration is:
# [14]	training's auc: 0.678026	valid_0's auc: 0.67474
# *****
# 0.6747404623455993
# ********************
#
#
# lan_pred_1.0
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.678034	valid_0's auc: 0.67474
# [20]	training's auc: 0.678034	valid_0's auc: 0.67474
# [30]	training's auc: 0.677979	valid_0's auc: 0.674593
# Early stopping, best iteration is:
# [12]	training's auc: 0.678034	valid_0's auc: 0.67474
# *****
# 0.674740463498578
# ********************
#
#
# media_id_pred_0.0
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.87331	valid_0's auc: 0.870913
# [20]	training's auc: 0.873328	valid_0's auc: 0.870834
# Early stopping, best iteration is:
# [9]	training's auc: 0.87331	valid_0's auc: 0.870922
# *****
# 0.8709220749589425
# ********************
#
#
# media_id_pred_1.0
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.873371	valid_0's auc: 0.870944
# [20]	training's auc: 0.87339	valid_0's auc: 0.870944
# [30]	training's auc: 0.873395	valid_0's auc: 0.870962
# [40]	training's auc: 0.873395	valid_0's auc: 0.870944
# [50]	training's auc: 0.873393	valid_0's auc: 0.870981
# [60]	training's auc: 0.873394	valid_0's auc: 0.870996
# [70]	training's auc: 0.873397	valid_0's auc: 0.870975
# [80]	training's auc: 0.873397	valid_0's auc: 0.870971
# Early stopping, best iteration is:
# [63]	training's auc: 0.873394	valid_0's auc: 0.871009
# *****
# 0.8710085942297134
# ********************
#
#
# ntt_pred_0.0
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.590384	valid_0's auc: 0.585536
# [20]	training's auc: 0.590426	valid_0's auc: 0.586483
# Early stopping, best iteration is:
# [1]	training's auc: 0.590463	valid_0's auc: 0.586848
# *****
# 0.5868481906331944
# ********************
#
#
# ntt_pred_1.0
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.590384	valid_0's auc: 0.585536
# [20]	training's auc: 0.590426	valid_0's auc: 0.586483
# Early stopping, best iteration is:
# [1]	training's auc: 0.590463	valid_0's auc: 0.586848
# *****
# 0.5868481906331944
# ********************
#
#
# osv_pred_0.0
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.767428	valid_0's auc: 0.764512
# [20]	training's auc: 0.767431	valid_0's auc: 0.764505
# Early stopping, best iteration is:
# [1]	training's auc: 0.767365	valid_0's auc: 0.764592
# *****
# 0.76459160796679
# ********************
#
#
# osv_pred_1.0
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.767428	valid_0's auc: 0.764512
# [20]	training's auc: 0.767431	valid_0's auc: 0.764505
# Early stopping, best iteration is:
# [1]	training's auc: 0.767365	valid_0's auc: 0.764592
# *****
# 0.76459160796679
# ********************
#
#
# version_pred_0.0
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.615754	valid_0's auc: 0.615793
# [20]	training's auc: 0.615751	valid_0's auc: 0.615728
# [30]	training's auc: 0.615754	valid_0's auc: 0.615747
# [40]	training's auc: 0.615758	valid_0's auc: 0.615699
# Early stopping, best iteration is:
# [21]	training's auc: 0.615728	valid_0's auc: 0.615919
# *****
# 0.6159187171119643
# ********************
#
#
# version_pred_1.0
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.615755	valid_0's auc: 0.615793
# [20]	training's auc: 0.615756	valid_0's auc: 0.615736
# [30]	training's auc: 0.615755	valid_0's auc: 0.615747
# [40]	training's auc: 0.615759	valid_0's auc: 0.615699
# Early stopping, best iteration is:
# [21]	training's auc: 0.615729	valid_0's auc: 0.615919
# *****
# 0.6159187171119643
# ********************
#
#
# location_pred_0.0
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.56616	valid_0's auc: 0.564131
# [20]	training's auc: 0.566219	valid_0's auc: 0.563958
# Early stopping, best iteration is:
# [8]	training's auc: 0.566161	valid_0's auc: 0.564154
# *****
# 0.564154235667404
# ********************
#
#
# location_pred_1.0
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.565741	valid_0's auc: 0.564318
# [20]	training's auc: 0.565819	valid_0's auc: 0.564272
# [30]	training's auc: 0.56584	valid_0's auc: 0.564328
# Early stopping, best iteration is:
# [15]	training's auc: 0.565793	valid_0's auc: 0.564393
# *****
# 0.5643930340969421
# ********************
#
#
# cus_type_pred_0.0
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.562893	valid_0's auc: 0.554817
# [20]	training's auc: 0.563093	valid_0's auc: 0.554992
# [30]	training's auc: 0.563143	valid_0's auc: 0.55491
# [40]	training's auc: 0.563197	valid_0's auc: 0.554811
# Early stopping, best iteration is:
# [25]	training's auc: 0.563137	valid_0's auc: 0.555093
# *****
# 0.5550930569819564
# ********************
#
#
# cus_type_pred_1.0
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.563195	valid_0's auc: 0.554042
# [20]	training's auc: 0.563408	valid_0's auc: 0.554095
# [30]	training's auc: 0.563452	valid_0's auc: 0.554056
# [40]	training's auc: 0.563489	valid_0's auc: 0.553963
# Early stopping, best iteration is:
# [23]	training's auc: 0.563447	valid_0's auc: 0.554231
# *****
# 0.5542306812576021
# ********************
#
#
# package_pred_0.0
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.837288	valid_0's auc: 0.834029
# [20]	training's auc: 0.837295	valid_0's auc: 0.833853
# [30]	training's auc: 0.837315	valid_0's auc: 0.833857
# Early stopping, best iteration is:
# [10]	training's auc: 0.837288	valid_0's auc: 0.834029
# *****
# 0.8340286367115545
# ********************
#
#
# package_pred_1.0
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.837352	valid_0's auc: 0.834038
# [20]	training's auc: 0.837369	valid_0's auc: 0.833909
# [30]	training's auc: 0.837389	valid_0's auc: 0.834006
# [40]	training's auc: 0.837388	valid_0's auc: 0.833975
# Early stopping, best iteration is:
# [26]	training's auc: 0.837374	valid_0's auc: 0.834138
# *****
# 0.834137862618136
# ********************
#
#
# apptype_media_id_pred_0.0
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.87331	valid_0's auc: 0.870913
# [20]	training's auc: 0.873328	valid_0's auc: 0.870834
# Early stopping, best iteration is:
# [9]	training's auc: 0.87331	valid_0's auc: 0.870922
# *****
# 0.8709220749589425
# ********************
#
#
# apptype_media_id_pred_1.0
# Training until validation scores don't improve for 20 rounds
# [10]	training's auc: 0.873371	valid_0's auc: 0.870944
# [20]	training's auc: 0.87339	valid_0's auc: 0.870944
# [30]	training's auc: 0.873395	valid_0's auc: 0.870962
# [40]	training's auc: 0.873395	valid_0's auc: 0.870944
# [50]	training's auc: 0.873393	valid_0's auc: 0.870981
# [60]	training's auc: 0.873394	valid_0's auc: 0.870996
# [70]	training's auc: 0.873397	valid_0's auc: 0.870975
# [80]	training's auc: 0.873397	valid_0's auc: 0.870971
# Early stopping, best iteration is:
# [63]	training's auc: 0.873394	valid_0's auc: 0.871009
# *****
# 0.8710085942297134
# ********************

# %%
print(use_cols)
# Out:
# ['android_id', 'apptype', 'carrier', 'dev_height', 'dev_ppi', 'dev_width', 'lan', 'media_id', 'ntt', 'osv', 'package', 'version', 'location', 'fea1_hash', 'cus_type', 'dev_height*dev_width', 'apptype_dev_height_min', 'apptype_dev_height_max', 'apptype_dev_height_median', 'apptype_dev_height_mean', 'apptype_dev_height_sum', 'apptype_dev_height_count', 'apptype_dev_height_std', 'apptype_dev_height_nunique', 'apptype_dev_width_min', 'apptype_dev_width_max', 'apptype_dev_width_median', 'apptype_dev_width_mean', 'apptype_dev_width_sum', 'apptype_dev_width_count', 'apptype_dev_width_std', 'apptype_dev_width_nunique', 'apptype_fea1_hash_min', 'apptype_fea1_hash_max', 'apptype_fea1_hash_median', 'apptype_fea1_hash_mean', 'apptype_fea1_hash_sum', 'apptype_fea1_hash_count', 'apptype_fea1_hash_std', 'apptype_fea1_hash_nunique', 'apptype_fea1_hash_skew', 'media_id_dev_height_min', 'media_id_dev_height_max', 'media_id_dev_height_median', 'media_id_dev_height_mean', 'media_id_dev_height_sum', 'media_id_dev_height_count', 'media_id_dev_height_std', 'media_id_dev_height_nunique', 'media_id_dev_width_min', 'media_id_dev_width_max', 'media_id_dev_width_median', 'media_id_dev_width_mean', 'media_id_dev_width_sum', 'media_id_dev_width_count', 'media_id_dev_width_std', 'media_id_dev_width_nunique', 'media_id_fea1_hash_min', 'media_id_fea1_hash_max', 'media_id_fea1_hash_median', 'media_id_fea1_hash_mean', 'media_id_fea1_hash_sum', 'media_id_fea1_hash_count', 'media_id_fea1_hash_std', 'media_id_fea1_hash_nunique', 'media_id_fea1_hash_skew', 'osv_dev_height_min', 'osv_dev_height_max', 'osv_dev_height_median', 'osv_dev_height_mean', 'osv_dev_height_count', 'osv_dev_height_nunique', 'osv_dev_width_min', 'osv_dev_width_max', 'osv_dev_width_median', 'osv_dev_width_mean', 'osv_dev_width_count', 'osv_dev_width_nunique', 'osv_fea1_hash_min', 'osv_fea1_hash_max', 'osv_fea1_hash_median', 'osv_fea1_hash_mean', 'osv_fea1_hash_sum', 'osv_fea1_hash_count', 'osv_fea1_hash_std', 'osv_fea1_hash_nunique', 'osv_fea1_hash_skew', 'package_dev_height_min', 'package_dev_height_max', 'package_dev_height_median', 'package_dev_height_mean', 'package_dev_height_sum', 'package_dev_height_count', 'package_dev_height_std', 'package_dev_height_nunique', 'package_dev_width_min', 'package_dev_width_max', 'package_dev_width_median', 'package_dev_width_mean', 'package_dev_width_sum', 'package_dev_width_count', 'package_dev_width_std', 'package_dev_width_nunique', 'package_fea1_hash_min', 'package_fea1_hash_max', 'package_fea1_hash_median', 'package_fea1_hash_mean', 'package_fea1_hash_sum', 'package_fea1_hash_count', 'package_fea1_hash_std', 'package_fea1_hash_nunique', 'package_fea1_hash_skew', 'apptype_media_id_dev_height_min', 'apptype_media_id_dev_height_max', 'apptype_media_id_dev_height_median', 'apptype_media_id_dev_height_mean', 'apptype_media_id_dev_height_sum', 'apptype_media_id_dev_height_count', 'apptype_media_id_dev_height_std', 'apptype_media_id_dev_height_nunique', 'apptype_media_id_dev_width_min', 'apptype_media_id_dev_width_max', 'apptype_media_id_dev_width_median', 'apptype_media_id_dev_width_mean', 'apptype_media_id_dev_width_sum', 'apptype_media_id_dev_width_count', 'apptype_media_id_dev_width_std', 'apptype_media_id_dev_width_nunique', 'apptype_media_id_fea1_hash_min', 'apptype_media_id_fea1_hash_max', 'apptype_media_id_fea1_hash_median', 'apptype_media_id_fea1_hash_mean', 'apptype_media_id_fea1_hash_sum', 'apptype_media_id_fea1_hash_count', 'apptype_media_id_fea1_hash_std', 'apptype_media_id_fea1_hash_nunique', 'apptype_media_id_fea1_hash_skew', 'android_id_cnt_code', 'apptype_cnt_code', 'carrier_cnt_code', 'lan_cnt_code', 'media_id_cnt_code', 'ntt_cnt_code', 'osv_cnt_code', 'version_cnt_code', 'location_cnt_code', 'cus_type_cnt_code', 'package_cnt_code', 'apptype_media_id_cnt_code', 'time', 'time_cnt_code', 'user_id_day_media_count', 'user_id_time_media_count', 'user_id_day_app_count', 'user_id_time_app_count', 'user_id_day_count', 'user_id_time_count', 'apptype ...

# %%
print(useless_cols)
# Out:
# ['fea_hash', 'apptype_dev_height_skew', 'apptype_dev_width_skew', 'media_id_dev_height_skew', 'media_id_dev_width_skew', 'osv_dev_height_sum', 'osv_dev_height_std', 'osv_dev_height_skew', 'osv_dev_width_sum', 'osv_dev_width_std', 'osv_dev_width_skew', 'package_dev_height_skew', 'package_dev_width_skew', 'apptype_media_id_dev_height_skew', 'apptype_media_id_dev_width_skew', 'day', 'hour', 'dayofweek', 'day_cnt_code', 'hour_cnt_code', 'dayofweek_cnt_code', 'user_id_day_fea_hash_count', 'user_id_time_fea_hash_count']

# %%
lgb_train = lgb.Dataset(train_data_X_train[use_cols], train_data_y_train)
lgb_eval = lgb.Dataset(train_data_X_val[use_cols], train_data_y_val, reference=lgb_train)

# %%
params = {'task': 'train',
          'boosting_type': 'gbdt',
          'objective': 'binary',
          'metric': 'binary_logloss',
          'num_leaves': 256,
          'learning_rate': 0.01,
          'feature_fraction': 0.95,
          'bagging_fraction': 0.85,
          'bagging_freq': 5, 
          'min_data_in_leaf':15}

# %%
print('Start training...')

gbm_val_1 = lgb.train(params,
                      lgb_train,
                      num_boost_round=2000,
                      valid_sets=[lgb_train, lgb_eval],
                      early_stopping_rounds=50,
                      verbose_eval=200)
# Out:
# Start training...
# Training until validation scores don't improve for 50 rounds
# [200]	training's binary_logloss: 0.312528	valid_1's binary_logloss: 0.318215
# [400]	training's binary_logloss: 0.28245	valid_1's binary_logloss: 0.296268
# [600]	training's binary_logloss: 0.270031	valid_1's binary_logloss: 0.29396
# [800]	training's binary_logloss: 0.260155	valid_1's binary_logloss: 0.293347
# [1000]	training's binary_logloss: 0.251663	valid_1's binary_logloss: 0.293063
# Early stopping, best iteration is:
# [1099]	training's binary_logloss: 0.247829	valid_1's binary_logloss: 0.293012

# %%
train_data_X_val['prob'] = gbm_val_1.predict(train_data_X_val[use_cols])
train_data_X_val['pred'] = np.where(train_data_X_val['prob'] > 0.5, 1, 0)

acc = np.round(accuracy_score(train_data_y_val, train_data_X_val['pred']), 4)
auc = roc_auc_score(train_data_y_val, train_data_X_val['prob'])

print('acc: ', acc)
print('auc: ', auc)
# Out:
# acc:  0.8886
# auc:  0.9435833759133305

# %%
params = {'task': 'train',
          'boosting_type': 'gbdt',
          'objective': 'binary',
          'metric': 'auc',
          'num_leaves': 256,
          'learning_rate': 0.01,
          'feature_fraction': 0.95,
          'bagging_fraction': 0.85,
          'bagging_freq': 5, 
          'min_data_in_leaf': 15}

# %%
lgb_train = lgb.Dataset(train_data_X[use_cols], train_data_y)   

print('Start training...')

gbm_1  = lgb.train(params,
                   lgb_train,
                   num_boost_round=gbm_val_1.best_iteration + 20)
print('Done')
# Out:
# Start training...
# Done

# %%
test1['label'] = np.where(gbm_1.predict(test1_data_X[use_cols]) > 0.5, 1, 0)

test1[['sid', 'label']].to_csv('../sub/sub_{}_{}.csv'.format(time.strftime('%Y%m%d'), acc), index=False)
