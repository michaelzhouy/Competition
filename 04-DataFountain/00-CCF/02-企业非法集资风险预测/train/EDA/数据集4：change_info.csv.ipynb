# %%
import numpy as np
import pandas as pd
from tqdm import tqdm
from sklearn.model_selection import train_test_split
import lightgbm as lgb
import warnings
warnings.filterwarnings('ignore')
from util import *

# %%
data = pd.read_csv('../../input/data.csv')

# %%
# 数据集4：change_info.csv
# 包含数据集7和8中涉及到的企业的变更信息，每一行代表一个企业变更信息，每一行5列，其中id列为企业唯一标识，列之间采用“,”分隔符分割。
# 数据格式如下：
# [id:企业唯一标识, bgxmdm:变更信息代码, bgq:变更前, bgh:变更后, bgrq:变更日期]
change_info = pd.read_csv('../../input/train/change_info.csv')
print(change_info.shape)
change_info.info()
# Out:
# (45940, 5)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45940 entries, 0 to 45939
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      45940 non-null  object
#  1   bgxmdm  45940 non-null  float64
#  2   bgq     45940 non-null  object
#  3   bgh     45940 non-null  object
#  4   bgrq    45940 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 1.8+ MB

# %%
change_info.head()
# Out:
#                                                  id  bgxmdm  \
# 0  9c7fa510616a683058ce97d0bc768a621cd85ab1e87da2a3   939.0
# 1  9c7fa510616a683058ce97d0bc768a621cd85ab1e87da2a3   112.0
# 2  e9f7b28ec10e047000d16ab79e1b5e6da434a1697cce7818   111.0
# 3  e9f7b28ec10e047000d16ab79e1b5e6da434a1697cce7818   128.0
# 4  e9f7b28ec10e047000d16ab79e1b5e6da434a1697cce7818   925.0
#
#                                                  bgq  \
# 0   9dec12da51cdb672a91b4a8ae0e0895f7bfeb243dfa3e0c8
# 1  31487d8f256f16bd6244b7251be2ebb27b17bdfd95c8f3...
# 2                   54ca436ffb87f24c820178b45fcc3a7b
# 3                   f1fdb1c866dc96638cbfb8b788b91393
# 4                   54ca436ffb87f24c820178b45fcc3a7b
#
#                                                  bgh          bgrq
# 0  9dec12da51cdb672a91b4a8ae0e0895f4a56cbe3deca98...  2.019060e+13
# 1  31487d8f256f16bd6244b7251be2ebb27b17bdfd95c8f3...  2.019060e+13
# 2                   f80e3376abcf81ad2a279d6d99046153  2.017013e+13
# 3                   1eca8a0d8beca58d988f7dccab5dc868  2.017013e+13
# 4                   f80e3376abcf81ad2a279d6d99046153  2.017013e+13

# %%
def identify_missing(df, missing_threshold):
    """
    缺失率
    @param df:
    @param missing_threshold:
    @return:
    """
    missing_rate = df.isnull().sum() / len(df)
    missing_rate = missing_rate.sort_values(ascending=False)
    print(missing_rate)
    to_drop = missing_rate[missing_rate > missing_threshold].index.to_list()
    print('{} features with greater than {} missing values.\n'.format(len(to_drop), missing_threshold))
    return to_drop

# %%
to_drop = identify_missing(change_info, missing_threshold=0.5)
change_info.drop(to_drop, axis=1, inplace=True)
to_drop
# Out:
# bgrq      0.0
# bgh       0.0
# bgq       0.0
# bgxmdm    0.0
# id        0.0
# dtype: float64
# 0 features with greater than 0.5 missing values.
# []

# %%
change_info['id'].nunique(), change_info['bgxmdm'].nunique(), change_info['bgq'].nunique(), change_info['bgh'].nunique()
# Out:
# (8726, 45, 28802, 30501)

# %%
change_info['bgxmdm'].unique()
# Out:
# array([939., 112., 111., 128., 925., 120., 137., 121., 922., 131., 921.,
#        117., 113., 930., 110., 190., 133., 115., 150., 129., 118., 907.,
#        134., 135., 136., 172., 116., 144., 143., 138., 301., 132., 119.,
#        902., 114., 908., 130., 125., 124., 903., 180., 126., 935., 901.,
#        140.])

# %%
df = pd.DataFrame(change_info['id'].unique())
df.columns = ['id']
df.shape
# Out:
# (8726, 1)

# %%
tmp = change_info.groupby('id', as_index=False)['bgxmdm'].agg({
    'bgxmdm_mode': lambda x: np.mean(pd.Series.mode(x)),
    'bgxmdm_cnt': 'count',
    'bgxmdm_nunique': 'nunique',
})
# tmp['cnt.nuique'] = tmp['bgxmdm_nunique'] / tmp['bgxmdm_cnt']

df = df.merge(tmp, on='id', how='left')

# %%
change_info['tmp'] = 1
tmp = change_info.pivot_table(values='tmp', index='id', columns='bgxmdm', aggfunc=np.sum).fillna(0)
cols = ['bgxmdm_{}'.format(f) for f in tmp.columns]
tmp.columns = cols
tmp.reset_index(inplace=True)

df = df.merge(tmp, on='id', how='left')

# %%
# for f in tqdm(cols):
#     df[f + '_rate'] = df[f] / df['bgxmdm_cnt']

# %%
tmp1 = change_info.groupby(['id', 'bgxmdm'], as_index=False)['bgq'].agg({'bgxmdm_cnt': 'count'})
tmp2 = tmp1.groupby('id', as_index=False)['bgxmdm_cnt'].agg({
    'bgxmdm_cnt_max': 'max',
    'bgxmdm_cnt_min': 'min',
    'bgxmdm_cnt_mean': 'mean',
    'bgxmdm_cnt_median': 'median',
    'bgxmdm_cnt_std': 'std',
    'bgxmdm_cnt_skew': 'skew'
})

df = df.merge(tmp2, on='id', how='left')

# %%
data = data.merge(df, how='left', on='id')

# %%
train = data[data['label'].notnull()]
test = data[data['label'].isnull()]
train.shape, test.shape

used_cols = [i for i in train.columns if i not in ['id', 'label']]
y = train['label']
train = train[used_cols]
test = test[used_cols]

X_train, X_valid, y_train, y_valid = train_test_split(train, y, test_size=0.25, random_state=2020)

cols = X_train.columns
useful_dict, useless_dict, useful_cols, useless_cols = auc_select(X_train, y_train, X_valid, y_valid, cols, threshold=0.52)
print('AUC useless_cols: \n', useless_cols)

dtrain = lgb.Dataset(X_train, y_train)
dvalid = lgb.Dataset(X_valid, y_valid, reference=dtrain)

params = {
    'objective': 'binary',
    'boosting': 'gbdt',
    'metric': 'auc',
#     'metric': 'None',  # 用自定义评估函数是将metric设置为'None'
    'learning_rate': 0.1,
    'num_leaves': 31,
    'lambda_l1': 0,
    'lambda_l2': 1,
    'num_threads': 23,
    'min_data_in_leaf': 20,
    'first_metric_only': True,
    'is_unbalance': True,
    'max_depth': -1,
    'seed': 2020
}

valid_model = lgb.train(
    params,
    dtrain,
    valid_sets=[dtrain, dvalid],
    early_stopping_rounds=50,
    verbose_eval=300 
)
# Out:
# bgxmdm_mode
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [4]	training's auc: 0.782946	valid_0's auc: 0.761218
# Evaluated only: auc
# **********
# 0.7612176839601044
# bgxmdm_cnt
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.741142	valid_0's auc: 0.735908
# Evaluated only: auc
# **********
# 0.7359082713013269
# bgxmdm_nunique
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [13]	training's auc: 0.743564	valid_0's auc: 0.734871
# Evaluated only: auc
# **********
# 0.7348709954543953
# bgxmdm_110.0
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [8]	training's auc: 0.724706	valid_0's auc: 0.721169
# Evaluated only: auc
# **********
# 0.7211692777539143
# bgxmdm_111.0
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [39]	training's auc: 0.733216	valid_0's auc: 0.724796
# Evaluated only: auc
# **********
# 0.724796203027571
# bgxmdm_112.0
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [53]	training's auc: 0.727018	valid_0's auc: 0.720103
# Evaluated only: auc
# **********
# 0.7201030903503844
# bgxmdm_113.0
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [7]	training's auc: 0.740546	valid_0's auc: 0.735322
# Evaluated only: auc
# **********
# 0.7353217797246204
# bgxmdm_114.0
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.722354	valid_0's auc: 0.719087
# Evaluated only: auc
# **********
# 0.7190870556470761
# bgxmdm_115.0
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [4]	training's auc: 0.73455	valid_0's auc: 0.729557
# Evaluated only: auc
# **********
# 0.729556579326231
# bgxmdm_116.0
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.722258	valid_0's auc: 0.719087
# Evaluated only: auc
# **********
# 0.7190870556470761
# bgxmdm_117.0
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	training's auc: 0.726499	valid_0's auc: 0.719964
# Evaluated only: auc
# **********
# 0.7199644328850665
# bgxmdm_118.0
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.729898	valid_0's auc: 0.728646
# Evaluated only: auc
# **********
# 0.7286455702775038
# bgxmdm_119.0
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.722402	valid_0's auc: 0.717182
# Evaluated only: auc
# **********
# 0.7171818430704309
# bgxmdm_120.0
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [34]	training's auc: 0.751704	valid_0's auc: 0.745192
# Evaluated only: auc
# **********
# 0.7451924211599552
# bgxmdm_121.0
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.729636	valid_0's auc: 0.725954
# Evaluated only: auc
# **********
# 0.7259544353868013
# bgxmdm_124.0
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.722258	valid_0's auc: 0.719087
# Evaluated only: auc
# **********
# 0.7190870556470761
# bgxmdm_125.0
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.722258	valid_0's auc: 0.719087
# Evaluated only: auc
# **********
# 0.7190870556470761
# bgxmdm_126.0
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.722258	valid_0's auc: 0.719087
# Evaluated only: auc
# **********
# 0.7190870556470761
# bgxmdm_128.0
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [6]	training's auc: 0.723867	valid_0's auc: 0.720792
# Evaluated only: auc
# **********
# 0.7207922474546029
# bgxmdm_129.0
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [23]	training's auc: 0.725306	valid_0's auc: 0.721307
# Evaluated only: auc
# **********
# 0.7213067551556975
# bgxmdm_130.0
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.722258	valid_0's auc: 0.719087
# Evaluated only: auc
# **********
# 0.7190870556470761
# bgxmdm_131.0
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.75473	valid_0's auc: 0.744923
# Evaluated only: auc
# **********
# 0.7449227766422944
# bgxmdm_132.0
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.722306	valid_0's auc: 0.719087
# Evaluated only: auc
# **********
# 0.7190870556470761
# bgxmdm_133.0
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [3]	training's auc: 0.722592	valid_0's auc: 0.719366
# Evaluated only: auc
# **********
# 0.7193655506412465
# bgxmdm_134.0
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.722402	valid_0's auc: 0.719087
# Evaluated only: auc
# **********
# 0.7190870556470761
# bgxmdm_135.0
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.722402	valid_0's auc: 0.717038
# Evaluated only: auc
# **********
# 0.7170378753192072
# bgxmdm_136.0
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.722306	valid_0's auc: 0.719087
# Evaluated only: auc
# **********
# 0.7190870556470761
# bgxmdm_137.0
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.727994	valid_0's auc: 0.719576
# Evaluated only: auc
# **********
# 0.719575601950409
# bgxmdm_138.0
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.72245	valid_0's auc: 0.719087
# Evaluated only: auc
# **********
# 0.7190870556470761
# bgxmdm_140.0
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.722258	valid_0's auc: 0.719087
# Evaluated only: auc
# **********
# 0.7190870556470761
# bgxmdm_143.0
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.722306	valid_0's auc: 0.719087
# Evaluated only: auc
# **********
# 0.7190870556470761
# bgxmdm_144.0
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.722258	valid_0's auc: 0.719087
# Evaluated only: auc
# **********
# 0.7190870556470761
# bgxmdm_150.0
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.723356	valid_0's auc: 0.71927
# Evaluated only: auc
# **********
# 0.7192699654949423
# bgxmdm_172.0
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.722498	valid_0's auc: 0.719375
# Evaluated only: auc
# **********
# 0.7193749911495235
# bgxmdm_180.0
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.722258	valid_0's auc: 0.719087
# Evaluated only: auc
# **********
# 0.7190870556470761
# bgxmdm_190.0
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.730492	valid_0's auc: 0.726701
# Evaluated only: auc
# **********
# 0.7267008255724489
# bgxmdm_301.0
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.722354	valid_0's auc: 0.719087
# Evaluated only: auc
# **********
# 0.7190870556470761
# bgxmdm_901.0
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.722258	valid_0's auc: 0.719087
# Evaluated only: auc
# **********
# 0.7190870556470761
# bgxmdm_902.0
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.722402	valid_0's auc: 0.719087
# Evaluated only: auc
# **********
# 0.7190870556470761
# bgxmdm_903.0
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.722258	valid_0's auc: 0.719087
# Evaluated only: auc
# **********
# 0.7190870556470761
# bgxmdm_907.0
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.722258	valid_0's auc: 0.719087
# Evaluated only: auc
# **********
# 0.7190870556470761
# bgxmdm_908.0
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.722258	valid_0's auc: 0.719087
# Evaluated only: auc
# **********
# 0.7190870556470761
# bgxmdm_921.0
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [35]	training's auc: 0.737345	valid_0's auc: 0.733847
# Evaluated only: auc
# **********
# 0.7338467003063445
# bgxmdm_922.0
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [35]	training's auc: 0.7358	valid_0's auc: 0.732937
# Evaluated only: auc
# **********
# 0.7329368713211519
# bgxmdm_925.0
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [20]	training's auc: 0.724802	valid_0's auc: 0.72032
# Evaluated only: auc
# **********
# 0.7203202220407546
# bgxmdm_930.0
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [5]	training's auc: 0.72468	valid_0's auc: 0.720621
# Evaluated only: auc
# **********
# 0.720621138242083
# bgxmdm_935.0
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.722258	valid_0's auc: 0.719087
# Evaluated only: auc
# **********
# 0.7190870556470761
# bgxmdm_939.0
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [30]	training's auc: 0.734424	valid_0's auc: 0.731384
# Evaluated only: auc
# **********
# 0.7313844977413584
# bgxmdm_cnt_max
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [21]	training's auc: 0.739286	valid_0's auc: 0.734466
# Evaluated only: auc
# **********
# 0.7344662336620204
# bgxmdm_cnt_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [4]	training's auc: 0.725653	valid_0's auc: 0.715688
# Evaluated only: auc
# **********
# 0.7156884726673685
# bgxmdm_cnt_mean
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [13]	training's auc: 0.745385	valid_0's auc: 0.731935
# Evaluated only: auc
# **********
# 0.7319349973802589
# bgxmdm_cnt_median
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [3]	training's auc: 0.7321	valid_0's auc: 0.730256
# Evaluated only: auc
# **********
# 0.7302557669704937
# bgxmdm_cnt_std
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [4]	training's auc: 0.724437	valid_0's auc: 0.708287
# Evaluated only: auc
# **********
# 0.7082865241464601
# bgxmdm_cnt_skew
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [8]	training's auc: 0.679018	valid_0's auc: 0.654719
# Evaluated only: auc
# **********
# 0.6547193100876552
# AUC useless_cols:
#  []
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [10]	training's auc: 0.826542	valid_1's auc: 0.743248
# Evaluated only: auc

# %%
importance = valid_model.feature_importance(importance_type='gain')
feature_name = valid_model.feature_name()

df_importance = pd.DataFrame({
    'feature_name': feature_name,
    'importance': importance
}).sort_values(by='importance', ascending=False)
df_importance['normalized_importance'] = df_importance['importance'] / df_importance['importance'].sum()
df_importance['cumulative_importance'] = np.cumsum(df_importance['normalized_importance'])
df_importance
# Out:
#          feature_name    importance  normalized_importance  \
# 35       bgxmdm_190.0  17993.220595               0.443818
# 21       bgxmdm_131.0   3959.180775               0.097657
# 0         bgxmdm_mode   3281.359104               0.080938
# 49     bgxmdm_cnt_min   2429.864635               0.059935
# 19       bgxmdm_129.0   1661.057955               0.040971
# 14       bgxmdm_121.0   1477.551707               0.036445
# 6        bgxmdm_113.0   1155.903811               0.028511
# 53    bgxmdm_cnt_skew   1043.688211               0.025743
# 13       bgxmdm_120.0    991.960702               0.024468
# 3        bgxmdm_110.0    923.616497               0.022782
# 4        bgxmdm_111.0    906.319596               0.022355
# 47       bgxmdm_939.0    704.943994               0.017388
# 1          bgxmdm_cnt    612.553403               0.015109
# 52     bgxmdm_cnt_std    604.995501               0.014923
# 11       bgxmdm_118.0    563.769997               0.013906
# 2      bgxmdm_nunique    529.985508               0.013073
# 8        bgxmdm_115.0    515.620600               0.012718
# 50    bgxmdm_cnt_mean    365.110703               0.009006
# 27       bgxmdm_137.0    351.136161               0.008661
# 10       bgxmdm_117.0    155.751200               0.003842
# 48     bgxmdm_cnt_max    122.650198               0.003025
# 51  bgxmdm_cnt_median     92.230199               0.002275
# 23       bgxmdm_133.0     57.218301               0.001411
# 45       bgxmdm_930.0     42.196051               0.001041
# 5        bgxmdm_112.0      0.000000               0.000000
# 43       bgxmdm_922.0      0.000000               0.000000
# 39       bgxmdm_903.0      0.000000               0.000000
# 40       bgxmdm_907.0      0.000000               0.000000
# 41       bgxmdm_908.0      0.000000               0.000000
# 42       bgxmdm_921.0      0.000000               0.000000
# 46       bgxmdm_935.0      0.000000               0.000000
# 44       bgxmdm_925.0      0.000000               0.000000
# 37       bgxmdm_901.0      0.000000               0.000000
# 15       bgxmdm_124.0      0.000000               0.000000
# 7        bgxmdm_114.0      0.000000               0.000000
# 12       bgxmdm_119.0      0.000000               0.000000
# 38       bgxmdm_902.0      0.000000               0.000000
# 36       bgxmdm_301.0      0.000000               0.000000
# 20       bgxmdm_130.0      0.000000               0.000000
# 16       bgxmdm_125.0      0.000000               0.000000
# 34       bgxmdm_180.0      0.000000               0.000000
# 33       bgxmdm_172.0      0.000000               0.000000
# 32       bgxmdm_150.0      0.000000               0.000000
# 9        bgxmdm_116.0      0.000000               0.000000
# 30       bgxmdm_143.0      0.000000               0.000000
# 29       bgxmdm_140.0      0.000000               0.000000
# 28       bgxmdm_138.0      0.000000               0.000000
# 17       bgxmdm_126.0      0.000000               0.000000
# 26       bgxmdm_136.0      0.000000               0.000000
# 25       bgxmdm_135.0      0.000000               0.000000
# 24       bgxmdm_134.0      0.000000               0.000000
# 22       bgxmdm_132.0      0.000000               0.000000
# 18       bgxmdm_128.0      0.000000               0.000000
# 31       bgxmdm_144.0      0.000000               0.000000
#
#     cumulative_importance
# 35               0.443818
# 21               0.541475
# 0                0.622412
# 49               0.682347
# 19               0.723318
# 14               0.759763
# 6                0.788275
# 53               0.814018
# 13               0.838486
# 3                0.861267
# 4                0.883623
# 47               0.901011
# 1                0.916120
# 52               0.931042
# 11               0.944948
# 2                0.958021
# 8                0.970739
# 50               0.979745
# 27               0.988406
# 10               0.992248
# 48               0.995273
# 51               0.997548
# 23               0.998959
# 45               1.000000
# 5                1.000000
# 43               1.000000
# 39               1.000000
# 40               1.000000
# 41               1.000000
# 42               1.000000
# 46               1.000000
# 44               1.000000
# 37               1.000000
# 15               1.000000
# 7                1.000000
# 12               1.000000
# 38               1.000000
# 36               1.000000
# 20               1.000000
# 16               1.000000
# 34               1.000000
# 33               1.000000
# 32               1.000000
# 9                1.000000
# 30               1.000000
# 29               1.000000
# 28               1.000000
# 17               1.000000
# 26               1.000000
# 25               1.000000
# 24               1.000000
# 22               1.000000
# 18               1.000000
# 31               1.000000

# %%
record_low_importance = df_importance[df_importance['importance'] == 0.0]
to_drop = list(record_low_importance['feature_name'])
print(to_drop)

df.drop(to_drop, axis=1, inplace=True)
df.to_csv('../../input/change_info.csv', index=False)
# Out:
# ['bgxmdm_112.0', 'bgxmdm_922.0', 'bgxmdm_903.0', 'bgxmdm_907.0', 'bgxmdm_908.0', 'bgxmdm_921.0', 'bgxmdm_935.0', 'bgxmdm_925.0', 'bgxmdm_901.0', 'bgxmdm_124.0', 'bgxmdm_114.0', 'bgxmdm_119.0', 'bgxmdm_902.0', 'bgxmdm_301.0', 'bgxmdm_130.0', 'bgxmdm_125.0', 'bgxmdm_180.0', 'bgxmdm_172.0', 'bgxmdm_150.0', 'bgxmdm_116.0', 'bgxmdm_143.0', 'bgxmdm_140.0', 'bgxmdm_138.0', 'bgxmdm_126.0', 'bgxmdm_136.0', 'bgxmdm_135.0', 'bgxmdm_134.0', 'bgxmdm_132.0', 'bgxmdm_128.0', 'bgxmdm_144.0']
