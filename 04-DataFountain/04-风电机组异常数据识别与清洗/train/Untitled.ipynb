# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from sklearn.ensemble import IsolationForest

import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df = pd.read_csv('../input/dataset.csv')
sub = pd.read_csv('../input/submission.csv')
df.head()
# Out:
#    WindNumber            Time  WindSpeed       Power  RotorSpeed
# 0           1  2017/11/1 0:20   4.188333   65.750000    5.779167
# 1           1  2017/11/1 0:30   4.042500  120.700000    8.636500
# 2           1  2017/11/1 0:40   4.137368  135.157895    8.668421
# 3           1  2017/11/1 0:50   4.274737  157.315789    8.727895
# 4           1  2017/11/1 1:00   4.108947  129.894737    8.656842

# %%
WindNumber1 = df.loc[df['WindNumber'] == 1, :]
# WindNumber2 = df.loc[df['WindNumber'] == 2, :]
# WindNumber3 = df.loc[df['WindNumber'] == 3, :]
# WindNumber4 = df.loc[df['WindNumber'] == 4, :]
# WindNumber5 = df.loc[df['WindNumber'] == 5, :]
# WindNumber6 = df.loc[df['WindNumber'] == 6, :]
# WindNumber7 = df.loc[df['WindNumber'] == 7, :]
# WindNumber8 = df.loc[df['WindNumber'] == 8, :]
# WindNumber9 = df.loc[df['WindNumber'] == 9, :]
# WindNumber10 = df.loc[df['WindNumber'] == 10, :]
# WindNumber11 = df.loc[df['WindNumber'] == 11, :]
# WindNumber12 = df.loc[df['WindNumber'] == 12, :]

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.scatter(WindNumber1['WindSpeed'], WindNumber1['Power'], s=5, cmap='viridis')
plt.xlabel('WindSpeed')
plt.ylabel('Power')
plt.show()

# %%
df = WindNumber1[['WindSpeed', 'Power']]
clf = IsolationForest(n_estimators=500,
                      random_state=2020,
                      contamination=0.05,
                      n_jobs=-1)
clf.fit(df)
y_pred = clf.predict(df)
y_pred = np.where(y_pred == -1, 1, 0)
df['label'] = y_pred

df1 = df.loc[df['label']==1, :]
df0 = df.loc[df['label']==0, :]

fig = plt.figure()
ax = fig.add_subplot(111)
ax.scatter(df1['WindSpeed'], df1['Power'], s=5, c='r', cmap='viridis', label='1')
ax.scatter(df0['WindSpeed'], df0['Power'], s=5, c='b', cmap='viridis', label='0')
plt.xlabel('WindSpeed')
plt.ylabel('Power')
plt.legend(loc='best')
plt.show()

# %%
WindNumber1.plot.scatter(x='WindSpeed', y='Power')
# Out:
#   File "<ipython-input-17-6392ef15013e>", line 1
#     WindNumber1.plot.scatter(x='WindSpeed', y='Power', color_map＝'virids')
#                                                                 ^
# SyntaxError: invalid character in identifier

# %%
WindNumber2.plot.scatter(x='WindSpeed', y='Power')

# %%
WindNumber3.plot.scatter(x='WindSpeed', y='Power')

# %%
WindNumber4.plot.scatter(x='WindSpeed', y='Power')

# %%
WindNumber5.plot.scatter(x='WindSpeed', y='Power')

# %%
WindNumber6.plot.scatter(x='WindSpeed', y='Power')

# %%
WindNumber7.plot.scatter(x='WindSpeed', y='Power')

# %%
WindNumber8.plot.scatter(x='WindSpeed', y='Power')

# %%
WindNumber9.plot.scatter(x='WindSpeed', y='Power')

# %%
WindNumber10.plot.scatter(x='WindSpeed', y='Power')

# %%
WindNumber11.plot.scatter(x='WindSpeed', y='Power')

# %%
WindNumber12.plot.scatter(x='WindSpeed', y='Power')
