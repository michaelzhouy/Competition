# %%
import time
import numpy as np
import pandas as pd
import gc
import warnings
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, roc_auc_score
import lightgbm as lgb

warnings.filterwarnings('ignore')
warnings.simplefilter(action='ignore', category=FutureWarning)
pd.set_option('max_columns', None)
pd.set_option('max_rows', None)

# %%
act_1 = pd.read_hdf('../input/act_1_features.h5')
act_1.head()
# Out:
#   item_id                                   course_id  watching_count_sum  \
# 0     V_0       C_course-v1:GXUST+2017041901X+2017_T1                   2
# 1     V_0          C_course-v1:TsinghuaX+00310222X+sp                   3
# 2     V_0  C_course-v1:TsinghuaX+00740043X_2015_T2+sp                   1
# 3     V_0           C_course-v1:TsinghuaX+30240184+sp                   5
# 4     V_1   C_course-v1:TsinghuaX+2019032101X+2019_T2                   9
#
#    watching_count_count  watching_count_mean  watching_count_max  \
# 0                     2             1.000000                   1
# 1                     2             1.500000                   2
# 2                     1             1.000000                   1
# 3                     3             1.666667                   3
# 4                     3             3.000000                   4
#
#    watching_count_min  watching_count_std  watching_count_skew  \
# 0                   1            0.000000                  NaN
# 1                   1            0.707107                  NaN
# 2                   1                 NaN                  NaN
# 3                   1            1.154701             1.732051
# 4                   1            1.732051            -1.732051
#
#    video_duration_sum  video_duration_count  video_duration_mean  \
# 0              1069.0                     2           534.500000
# 1              1899.0                     2           949.500000
# 2               937.0                     1           937.000000
# 3               730.0                     3           243.333333
# 4              3850.0                     3          1283.333333
#
#    video_duration_max  video_duration_min  video_duration_std  \
# 0               601.0               468.0           94.045202
# 1              1132.0               767.0          258.093975
# 2               937.0               937.0                 NaN
# 3               288.0               209.0           40.501029
# 4              2291.0               774.0          872.682264
#
#    video_duration_skew  local_watching_time_sum  local_watching_time_count  \
# 0                  NaN                     1079                          2
# 1                  NaN                      879                          2
# 2                  NaN                      223                          1
# 3             1.073382                     1035                          3
# 4             1.731741                     3150                          3
#
#    local_watching_time_mean  local_watching_time_max  local_watching_time_min  \
# 0                     539.5                      600                      479
# 1                     439.5                      774                      105
# 2                     223.0                      223                      223
# 3                     345.0                      613                      186
# 4                    1050.0                     1231                      774
#
#    local_watching_time_std  local_watching_time_skew  video_progress_time_sum  \
# 0                85.559921                       NaN              1069.000000
# 1               473.054437                       NaN               871.230011
# 2                      NaN                       NaN               222.869995
# 3               233.437358                  1.643084               729.280000
# 4               242.860042                 -1.490924              3537.209961
#
#    video_progress_time_count  video_progress_time_mean  \
# 0                          2                534.500000
# 1                          2                435.615005
# 2                          1                222.869995
# 3                          3                243.093333
# 4                          3               1179.069987
#
#    video_progress_time_max  video_progress_time_min  video_progress_time_std  \
# 0               601.000000               468.000000                94.045202
# 1               767.000000               104.230011               468.649154
# 2               222.869995               222.869995                      NaN
# 3               287.280000               209.000000                40.104191
# 4              1505.460022               774.000000               372.023309
#
#    video_progress_time_skew  video_watching_duration_sum  \
# 0                       NaN                  1069.000000
# 1                       NaN                   998.550003
# 2                       NaN                   222.869995
# 3                  1.060812                   729.280000
# 4                 -0.909145                  2717.890015
#
#    video_watching_duration_count  video_watching_duration_mean  \
# 0                              2                    534.500000
# 1                              2                    499.275002
# 2                              1                    222.869995
# 3                              3                    243.093333
# 4                              3                    905.963338
#
#    video_watching_duration_max  video_watching_duration_min  \
# 0                   601.000000                   468.000000
# 1                   767.000000                   231.550003
# 2                   222.869995                   222.869995
# 3                   287.280000                   209.000000
# 4                  1158.890015                   774.000000
#
#    video_watching_duration_std  video_watching_duration_skew  \
# 0                    94.045202                           NaN
# 1                   378.620324                           NaN
# 2                          NaN                           NaN
# 3                    40.104191                      1.060812
# 4                   219.109967                      1.727141
#
#    local_watching_duration_sum  local_watching_duration_count  \
# 0                         1079                              2
# 1                          879                              2
# 2                          223                              1
# 3                         1051                              3
# 4                         5421                              3
#
#    local_watching_duration_mean  local_watching_duration_max  \
# 0                    539.500000                          600
# 1                    439.500000                          774
# 2                    223.000000                          223
# 3                    350.333333                          629
# 4                   1807.000000                         3416
#
#    local_watching_duration_min  local_watching_duration_std  \
# 0                          479                    85.559921
# 1                          105                   473.054437
# 2                          223                          NaN
# 3                          186                   242.623852
# 4                          774                  1412.045679
#
#    local_watching_duration_skew  video_is_end_sum  video_is_end_count  \
# 0                           NaN          0.000000                   2
# 1                           NaN       -900.449997                   2
# 2                           NaN       -714.130005                   1
# 3                      1.649664          0.000000                   3
# 4                      1.530189      -1132.109985                   3
#
#    video_is_end_mean  video_is_end_max  video_is_end_min  video_is_end_std  \
# 0           0.000000          0.000000          0.000000          0.000000
# 1        -450.224998          0.000000       -900.449997        636.714299
# 2        -714.130005       -714.130005       -714.130005               NaN
# 3           0.000000          0.000000          0.000000          0.000000
# 4        -377.369995          0.000000      -1132.109985        653.624005
#
#    video_is_end_skew  video_is_start_sum  video_is_start_count  \
# 0                NaN                   0                     2
# 1                NaN                   0                     2
# 2                NaN                   0                     1
# 3           0.000000                   1                     3
# 4          -1.732051                   0                     3
#
#    video_is_start_mean  video_is_start_max  video_is_start_min  \
# 0             0.000000                   0                   0
# 1             0.000000                   0                   0
# 2             0.000000                   0                   0
# 3             0.333333                   1                   0
# 4             0.000000                   0                   0
#
#    video_is_start_std  video_is_start_skew  video_is_start_end_sum  \
# 0             0.00000                  NaN                0.000000
# 1             0.00000                  NaN             -900.449997
# 2                 NaN                  NaN             -714.130005
# 3             0.57735             1.732051               -0.720000
# 4             0.00000             0.000000            -1132.109985
#
#    video_is_start_end_count  video_is_start_end_mean  video_is_start_end_max  \
# 0                         2                 0.000000                0.000000
# 1                         2              -450.224998                0.000000
# 2                         1              -714.130005             -714.130005
# 3                         3                -0.240000                0.000000
# 4                         3              -377.369995                0.000000
#
#    video_is_start_end_min  video_is_start_end_std  video_is_start_end_skew  \
# 0                0.000000                0.000000                      NaN
# 1             -900.449997              636.714299                      NaN
# 2             -714.130005                     NaN                      NaN
# 3               -0.720000                0.415692                -1.732051
# 4            -1132.109985              653.624005                -1.732051
#
#    forward_seconds_sum  forward_seconds_count  forward_seconds_mean  \
# 0         0.000000e+00                      2          0.000000e+00
# 1         1.273200e+02                      2          6.366000e+01
# 2         0.000000e+00                      1          0.000000e+00
# 3         5.684342e-14                      3          1.894781e-14
# 4        -8.193199e+02                      3         -2.731066e+02
#
#    forward_seconds_max  forward_seconds_min  forward_seconds_std  \
# 0         0.000000e+00             0.000000         0.000000e+00
# 1         1.273200e+02             0.000000         9.002883e+01
# 2         0.000000e+00             0.000000                  NaN
# 3         5.684342e-14             0.000000         3.281856e-14
# 4         0.000000e+00          -720.460022         3.905600e+02
#
#    forward_seconds_skew  local_watching_diff_sum  local_watching_diff_count  \
# 0                   NaN                        0                          2
# 1                   NaN                        0                          2
# 2                   NaN                        0                          1
# 3               0.00000                       16                          3
# 4              -1.60804                     2271                          3
#
#    local_watching_diff_mean  local_watching_diff_max  local_watching_diff_min  \
# 0                  0.000000                        0                        0
# 1                  0.000000                        0                        0
# 2                  0.000000                        0                        0
# 3                  5.333333                       16                        0
# 4                757.000000                     2271                        0
#
#    local_watching_diff_std  local_watching_diff_skew  speed_sum  speed_count  \
# 0                 0.000000                       NaN   2.021837            2
# 1                 0.000000                       NaN   2.016503            2
# 2                      NaN                       NaN   1.000579            1
# 3                 9.237604                  1.732051   4.552775            3
# 4              1311.162461                  1.732051   2.739294            3
#
#    speed_mean  speed_max  speed_min  speed_std  speed_skew  course_id_count  \
# 0    1.010918   1.023502   0.998334   0.017796         NaN                8
# 1    1.008251   1.009125   1.007378   0.001236         NaN                8
# 2    1.000579   1.000579   1.000579        NaN         NaN                8
# 3    1.517592   2.933000   0.798280   1.225835    1.731352                8
# 4    0.913098   0.999999   0.760564   0.132525   -1.682003               23
#
#    local_watching_duration  local_watching_diff  \
# 0                     1196                  117
# 1                    53088                52209
# 2                      223                    0
# 3                     1585                  550
# 4                      408                -2742
#
#    local_watching_video_duration  label
# 0                          127.0      0
# 1                        51189.0      1
# 2                         -714.0      0
# 3                          855.0      0
# 4                        -3442.0      1

# %%
act_1.shape
# Out:
# (187207, 91)

# %%
act_2 = pd.read_hdf('../input/act_2_features.h5')
act_2.head()
# Out:
#   item_id                                  course_id  watching_count_sum  \
# 0     U_0         C_course-v1:TsinghuaX+00691153X+sp                  14
# 1     U_0  C_course-v1:TsinghuaX+10421075X_2015_2+sp                   2
# 2     U_0         C_course-v1:TsinghuaX+20430064X+sp                  14
# 3     U_0         C_course-v1:TsinghuaX+34000888X+sp                   9
# 4     U_0           C_course-v1:TsinghuaX+400182X+sp                   8
#
#    watching_count_count  watching_count_mean  watching_count_max  \
# 0                     8             1.750000                   4
# 1                     1             2.000000                   2
# 2                    14             1.000000                   1
# 3                     7             1.285714                   3
# 4                     6             1.333333                   2
#
#    watching_count_min  watching_count_std  watching_count_skew  \
# 0                   1            1.164965             1.355361
# 1                   2                 NaN                  NaN
# 2                   1            0.000000             0.000000
# 3                   1            0.755929             2.645751
# 4                   1            0.516398             0.968246
#
#    video_duration_sum  video_duration_count  video_duration_mean  \
# 0              4867.0                     8           608.375000
# 1               748.0                     1           748.000000
# 2              5381.0                    14           384.357143
# 3              1387.0                     7           198.142857
# 4              4106.0                     6           684.333333
#
#    video_duration_max  video_duration_min  video_duration_std  \
# 0               929.0               282.0          264.815266
# 1               748.0               748.0                 NaN
# 2               896.0               173.0          191.134913
# 3               319.0                63.0           80.140353
# 4              1150.0               392.0          348.773088
#
#    video_duration_skew  local_watching_time_sum  local_watching_time_count  \
# 0             0.014851                     3982                          8
# 1                  NaN                      192                          1
# 2             1.525479                     4584                         14
# 3            -0.219097                     1211                          7
# 4             0.735545                     5129                          6
#
#    local_watching_time_mean  local_watching_time_max  local_watching_time_min  \
# 0                497.750000                      930                      202
# 1                192.000000                      192                      192
# 2                327.428571                      563                       93
# 3                173.000000                      319                       19
# 4                854.833333                     2097                      393
#
#    local_watching_time_std  local_watching_time_skew  video_progress_time_sum  \
# 0               269.890851                  0.720634              3976.209992
# 1                      NaN                       NaN               191.349991
# 2               139.177095                  0.194791              4577.169999
# 3               106.103723                 -0.255813              1210.180001
# 4               674.410978                  1.635015              5099.380005
#
#    video_progress_time_count  video_progress_time_mean  \
# 0                          8                497.026249
# 1                          1                191.349991
# 2                         14                326.940714
# 3                          7                172.882857
# 4                          6                849.896667
#
#    video_progress_time_max  video_progress_time_min  video_progress_time_std  \
# 0               929.000000               201.529999               269.829949
# 1               191.349991               191.349991                      NaN
# 2               563.000000                92.209999               139.322856
# 3               319.000000                18.820000               105.969758
# 4              2081.559998               392.000000               668.262523
#
#    video_progress_time_skew  video_watching_duration_sum  \
# 0                  0.723786                  3944.460001
# 1                       NaN                   191.539993
# 2                  0.196968                  4577.169999
# 3                 -0.252013                  1210.349999
# 4                  1.638153                  4106.000000
#
#    video_watching_duration_count  video_watching_duration_mean  \
# 0                              8                    493.057500
# 1                              1                    191.539993
# 2                             14                    326.940714
# 3                              7                    172.907143
# 4                              6                    684.333333
#
#    video_watching_duration_max  video_watching_duration_min  \
# 0                   929.000000                   201.529999
# 1                   191.539993                   191.539993
# 2                   563.000000                    92.209999
# 3                   319.000000                    18.820000
# 4                  1150.000000                   392.000000
#
#    video_watching_duration_std  video_watching_duration_skew  \
# 0                   273.672031                      0.694879
# 1                          NaN                           NaN
# 2                   139.322856                      0.196968
# 3                   105.993556                     -0.252014
# 4                   348.773088                      0.735545
#
#    local_watching_duration_sum  local_watching_duration_count  \
# 0                        19541                              8
# 1                          256                              1
# 2                         4584                             14
# 3                         1213                              7
# 4                        14100                              6
#
#    local_watching_duration_mean  local_watching_duration_max  \
# 0                   2442.625000                        15377
# 1                    256.000000                          256
# 2                    327.428571                          563
# 3                    173.285714                          319
# 4                   2350.000000                         9859
#
#    local_watching_duration_min  local_watching_duration_std  \
# 0                          202                  5232.548490
# 1                          256                          NaN
# 2                           93                   139.177095
# 3                           19                   106.385642
# 4                          393                  3757.462548
#
#    local_watching_duration_skew  video_is_end_sum  video_is_end_count  \
# 0                      2.814853       -922.529999                   8
# 1                           NaN       -556.460007                   1
# 2                      0.194791       -803.790001                  14
# 3                     -0.255646       -176.630001                   7
# 4                      2.242306          0.000000                   6
#
#    video_is_end_mean  video_is_end_max  video_is_end_min  video_is_end_std  \
# 0        -115.316250          0.000000       -696.470001        241.414980
# 1        -556.460007       -556.460007       -556.460007               NaN
# 2         -57.413571          0.000000       -803.790001        214.821914
# 3         -25.232857          0.000000       -132.450001         50.063286
# 4           0.000000          0.000000          0.000000          0.000000
#
#    video_is_end_skew  video_is_start_sum  video_is_start_count  \
# 0          -2.553037                   1                     8
# 1                NaN                   0                     1
# 2          -3.741657                   4                    14
# 3          -2.155254                   2                     7
# 4           0.000000                   0                     6
#
#    video_is_start_mean  video_is_start_max  video_is_start_min  \
# 0             0.125000                   1                   0
# 1             0.000000                   0                   0
# 2             0.285714                   1                   0
# 3             0.285714                   1                   0
# 4             0.000000                   0                   0
#
#    video_is_start_std  video_is_start_skew  video_is_start_end_sum  \
# 0            0.353553             2.828427             -922.539999
# 1                 NaN                  NaN             -556.460007
# 2            0.468807             1.066536             -803.830001
# 3            0.487950             1.229634             -176.650001
# 4            0.000000             0.000000                0.000000
#
#    video_is_start_end_count  video_is_start_end_mean  video_is_start_end_max  \
# 0                         8              -115.317500                0.000000
# 1                         1              -556.460007             -556.460007
# 2                        14               -57.416429                0.000000
# 3                         7               -25.235714                0.000000
# 4                         6                 0.000000                0.000000
#
#    video_is_start_end_min  video_is_start_end_std  video_is_start_end_skew  \
# 0             -696.470001              241.414711                -2.553025
# 1             -556.460007                     NaN                      NaN
# 2             -803.790001              214.821092                -3.741657
# 3             -132.460001               50.066015                -2.155338
# 4                0.000000                0.000000                 0.000000
#
#    forward_seconds_sum  forward_seconds_count  forward_seconds_mean  \
# 0        -3.174999e+01                      8         -3.968749e+00
# 1         1.900024e-01                      1          1.900024e-01
# 2         1.705303e-13                     14          1.218073e-14
# 3         1.699982e-01                      7          2.428545e-02
# 4        -9.933800e+02                      6         -1.655633e+02
#
#    forward_seconds_max  forward_seconds_min  forward_seconds_std  \
# 0         1.900024e-01        -2.771001e+01         9.708359e+00
# 1         1.900024e-01         1.900024e-01                  NaN
# 2         5.684342e-14         0.000000e+00         2.420480e-14
# 3         1.699982e-01        -5.684342e-14         6.425327e-02
# 4         1.799927e-01        -9.935600e+02         4.056339e+02
#
#    forward_seconds_skew  local_watching_diff_sum  local_watching_diff_count  \
# 0             -2.705540                    15559                          8
# 1                   NaN                       64                          1
# 2              0.000000                        0                         14
# 3              2.645751                        2                          7
# 4             -2.449490                     8971                          6
#
#    local_watching_diff_mean  local_watching_diff_max  local_watching_diff_min  \
# 0               1944.875000                    14962                        0
# 1                 64.000000                       64                       64
# 2                  0.000000                        0                        0
# 3                  0.285714                        2                        0
# 4               1495.166667                     8699                        0
#
#    local_watching_diff_std  local_watching_diff_skew  speed_sum  speed_count  \
# 0              5263.090657                  2.821294   8.013482            8
# 1                      NaN                       NaN   1.003392            1
# 2                 0.000000                  0.000000  14.029990           14
# 3                 0.755929                  2.645751   7.005751            7
# 4              3530.819872                  2.444324   6.025158            6
#
#    speed_mean  speed_max  speed_min  speed_std  speed_skew  course_id_count  \
# 0    1.001685   1.003349   0.999999   0.001311    0.090651               36
# 1    1.003392   1.003392   1.003392        NaN         NaN               36
# 2    1.002142   1.008556   0.999995   0.002872    1.048917               36
# 3    1.000822   1.009511   0.990759   0.005702   -0.376631               36
# 4    1.004193   1.008853   1.001571   0.003107    1.002772               36
#
#    local_watching_duration  local_watching_diff  \
# 0                    15882                11900
# 1                      256                   64
# 2                     5853                 1269
# 3                     1352                  141
# 4                    21057                15928
#
#    local_watching_video_duration  label
# 0                        11015.0      0
# 1                         -492.0      0
# 2                          472.0      1
# 3                          -35.0      1
# 4                        16951.0      0

# %%
act_2.shape
# Out:
# (40727, 91)

# %%
train = pd.concat([act_1, act_2], ignore_index=False, axis=0)
train.drop(['item_id', 'course_id'], axis=1, inplace=True)
train.shape
# Out:
# (227934, 89)

# %%
test = pd.read_hdf('../input/test_features.h5')
submit = test[['item_id', 'course_id']]
test.drop(['item_id', 'course_id'], axis=1, inplace=True)
test.shape
# Out:
# (20023, 88)

# %%
y = train['label']
train.drop('label', axis=1, inplace=True)
train.shape
# Out:
# (227934, 88)

# %%
X_train, X_valid, y_train, y_valid = train_test_split(train, y, stratify=y, random_state=2020, shuffle=True)

# %%
lgb_train = lgb.Dataset(X_train, label=y_train)
lgb_valid = lgb.Dataset(X_valid, label=y_valid, reference=lgb_train)
lgb_all = lgb.Dataset(train, y, reference=lgb_train)

# %%
params = {
    'objective': 'binary',
    'boosting': 'gbdt',
    'metric': 'binary_error',
    'learning_rate': 0.1,
    'num_leaves': 31,
    'lambda_l1': 0,
    'lambda_l2': 1,
    'min_data_in_leaf': 20,
    'is_unbalance': True,
    'max_depth': -1,
    'seed': 2020
}

# %%
lgb_model_valid = lgb.train(params,
                            lgb_train,
                            valid_sets=[lgb_train, lgb_valid],
                            early_stopping_rounds=500,
                            num_boost_round=100000,
                            verbose_eval=500)
# Out:
# Training until validation scores don't improve for 500 rounds
# [500]	training's binary_error: 0.171793	valid_1's binary_error: 0.209129
# [1000]	training's binary_error: 0.131846	valid_1's binary_error: 0.200284
# [1500]	training's binary_error: 0.103463	valid_1's binary_error: 0.195599
# [2000]	training's binary_error: 0.0816321	valid_1's binary_error: 0.190878
# [2500]	training's binary_error: 0.066148	valid_1's binary_error: 0.188807
# [3000]	training's binary_error: 0.0544955	valid_1's binary_error: 0.186789
# [3500]	training's binary_error: 0.0445393	valid_1's binary_error: 0.18528
# [4000]	training's binary_error: 0.03673	valid_1's binary_error: 0.18421
# [4500]	training's binary_error: 0.0302954	valid_1's binary_error: 0.182823
# [5000]	training's binary_error: 0.024165	valid_1's binary_error: 0.182367
# [5500]	training's binary_error: 0.0196373	valid_1's binary_error: 0.181384
# [6000]	training's binary_error: 0.0160105	valid_1's binary_error: 0.180665
# [6500]	training's binary_error: 0.0132202	valid_1's binary_error: 0.179278
# [7000]	training's binary_error: 0.0100965	valid_1's binary_error: 0.179068
# [7500]	training's binary_error: 0.00826557	valid_1's binary_error: 0.179103
# [8000]	training's binary_error: 0.00690845	valid_1's binary_error: 0.178296
# [8500]	training's binary_error: 0.00564493	valid_1's binary_error: 0.178471
# Early stopping, best iteration is:
# [8210]	training's binary_error: 0.00635273	valid_1's binary_error: 0.177804

# %%
y_prob = lgb_model_valid.predict(X_valid)
y_pred = np.where(y_prob > 0.5, 1, 0)

acc = np.round(accuracy_score(y_valid, y_pred), 4)
auc = np.round(roc_auc_score(y_valid, y_prob), 4)

print('acc: ', acc)
print('auc: ', auc)
# Out:
# acc:  0.8222
# auc:  0.8893

# %%
importance = lgb_model_valid.feature_importance(importance_type='gain')
feature_name = lgb_model_valid.feature_name()
feature_importance = pd.DataFrame({'feature_name': feature_name, 'importance': importance}).sort_values(by='importance', ascending=False)
feature_importance.to_csv('../input/feature_importance.csv', index=False)

# %%
lgb_model = lgb.train(params,
                      lgb_all,
                      num_boost_round=lgb_model_valid.best_iteration + 100)

# %%
submit['label'] = np.where(lgb_model.predict(test) > 0.5, 1, 0).astype(int)

# %%
test_label = pd.read_hdf('../input/test_label.h5')
test_label = test_label.merge(submit, how='left', on=['item_id', 'course_id'])
test_label.head()
# Out:
#   item_id                             course_id  label
# 0     T_1    C_course-v1:TsinghuaX+00612642X+sp      0
# 1     T_1    C_course-v1:TsinghuaX+80000271X+sp      0
# 2     T_1    C_course-v1:TsinghuaX+00701032X+sp      0
# 3     T_1  C_course-v1:TsinghuaX+80000901X_1+sp      0
# 4     T_2         C_course-v1:GZHU+136300904+sp      0

# %%
def fun1(dx):
    return list(dx.values)

sub = test_label.groupby('item_id')['label'].apply(fun1).reset_index()
sub.columns = ['item_id', 'label_list']
sub = sub[['label_list', 'item_id']]

sub.to_json('../sub/sub_{}_{}.json'.format(time.strftime('%Y%m%d'), str(acc)), orient='records', lines=True)
