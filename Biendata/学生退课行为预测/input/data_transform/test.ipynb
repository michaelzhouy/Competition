# %%
import pandas as pd
import gc
pd.set_option('max_columns', None)
pd.set_option('max_rows', None)

# %%
df = pd.read_json('../Track1/user_video_act_val_triple_withId_noLabel_1.json', lines=True)
df.head()
# Out:
#                                          course_list  \
# 0  [C_course-v1:TsinghuaX+00612642X+sp, C_course-...
# 1  [C_course-v1:GZHU+136300904+sp, C_course-v1:Ts...
# 2  [C_course-v1:LZU+2018122505X+2018_T2, C_course...
# 3  [C_course-v1:TsinghuaX+00740043_2x_2015_T2+sp,...
# 4  [C_course-v1:TsinghuaX+80240372X+2019_T1, C_co...
#
#                                             activity item_id
# 0  [{'video_start_time': 1.179999947547912, 'loca...     T_1
# 1  [{'video_start_time': 0.0, 'local_start_time':...     T_2
# 2  [{'video_start_time': 0.03999999910593, 'local...     T_3
# 3  [{'video_start_time': 0.0, 'local_start_time':...     T_4
# 4  [{'video_start_time': 0.0, 'local_start_time':...     T_5

# %%
df.iloc[0, 1]
# Out:
# [{'video_start_time': 1.179999947547912,
#   'local_start_time': '2018-05-12 17:49:32',
#   'video_progress_time': 1080.6599601507187,
#   'local_watching_time': 722,
#   'local_end_time': '2018-05-12 18:02:07',
#   'course_id': 'C_course-v1:TsinghuaX+00612642X+sp',
#   'watching_count': 2,
#   'video_end_time': 1081.9599609375,
#   'video_id': 'V_01292610aa1748e79c8981de6f0464f8',
#   'video_duration': 1084.0},
#  {'video_start_time': 0.0,
#   'local_start_time': '2018-10-19 20:46:03',
#   'video_progress_time': 345.5700033307075,
#   'local_watching_time': 279,
#   'local_end_time': '2018-10-20 17:05:31',
#   'course_id': 'C_course-v1:TsinghuaX+80000271X+sp',
#   'watching_count': 2,
#   'video_end_time': 276.85000610351557,
#   'video_id': 'V_01e873de29224ade99abd7f5a3018b3f',
#   'video_duration': 277.0},
#  {'video_start_time': 0.019999999552965,
#   'local_start_time': '2018-05-04 16:58:41',
#   'video_progress_time': 84.98000000044703,
#   'local_watching_time': 69,
#   'local_end_time': '2018-05-04 16:59:50',
#   'course_id': 'C_course-v1:TsinghuaX+00612642X+sp',
#   'watching_count': 1,
#   'video_end_time': 85.0,
#   'video_id': 'V_0255c95155a9478291d4bb7818f22c07',
#   'video_duration': 85.0},
#  {'video_start_time': 0.0,
#   'local_start_time': '2018-09-08 03:50:39',
#   'video_progress_time': 592.7900145053864,
#   'local_watching_time': 601,
#   'local_end_time': '2018-09-08 04:01:40',
#   'course_id': 'C_course-v1:TsinghuaX+00701032X+sp',
#   'watching_count': 3,
#   'video_end_time': 636.0,
#   'video_id': 'V_03a50bdfedf54152ba7d1ee662563cfb',
#   'video_duration': 636.0},
#  {'video_start_time': 0.0,
#   'local_start_time': '2018-05-04 18:29:10',
#   'video_progress_time': 1165.0,
#   'local_watching_time': 778,
#   'local_end_time': '2018-05-04 18:42:08',
#   'course_id': 'C_course-v1:TsinghuaX+00612642X+sp',
#   'watching_count': 1,
#   'video_end_time': 1165.0,
#   'video_id': 'V_03df78abe20a439699d16f7608ae9425',
#   'video_duration': 1165.0},
#  {'video_start_time': 0.0,
#   'local_start_time': '2018-08-01 07:49:04',
#   'video_progress_time': 1166.0,
#   'local_watching_time': 1202,
#   'local_end_time': '2018-08-01 08:09:06',
#   'course_id': 'C_course-v1:TsinghuaX+80000901X_1+sp',
#   'watching_count': 1,
#   'video_end_time': 1166.0,
#   'video_id': 'V_0568e5237f9246adb961ba8caaed23bc',
#   'video_duration': 1166.0},
#  {'video_start_time': 0.0,
#   'local_start_time': '2018-05-09 16:37:49',
#   'video_progress_time': 532.0,
#   'local_watching_time': 426,
#   'local_end_time': '2018-05-09 16:44:55',
#   'course_id': 'C_course-v1:TsinghuaX+00612642X+sp',
#   'watching_count': 1,
#   'video_end_time': 532.0,
#   'video_id': 'V_0585e40baa8644319760cfca62354112',
#   'video_duration': 532.0},
#  {'video_start_time': 0.0,
#   'local_start_time': '2018-05-31 20:33:50',
#   'video_progress_time': 430.0,
#   'local_watching_time': 355,
#   'local_end_time': '2018-05-31 20:39:45',
#   'course_id': 'C_course-v1:TsinghuaX+80000901X_1+sp',
#   'watching_count': 2,
#   'video_end_time': 430.0,
#   'video_id': 'V_06cc1822c71f4ccd9e05748379b31471',
#   'video_duration': 430.0},
#  {'video_start_time': 27.96999931335449,
#   'local_start_time': '2018-09-08 02:54:24',
#   'video_progress_time': 550.0300006866455,
#   'local_watching_time': 552,
#   'local_end_time': '2018-09-08 03:03:36',
#   'course_id': 'C_course-v1:TsinghuaX+00701032X+sp',
#   'watching_count': 1,
#   'video_end_time': 578.0,
#   'video_id': 'V_06ff0b3ae1a2470a8105fa34969b75f3',
#   'video_duration': 578.0},
#  {'video_start_time': 0.0,
#   'local_start_time': '2018-05-17 11:21:50',
#   'video_progress_time': 772.0500192642212,
#   'local_watching_time': 617,
#   'local_end_time': '2018-05-17 11:33:48',
#   'course_id': 'C_course-v1:TsinghuaX+80000901X_1+sp',
#   'watching_count': 4,
#   'video_end_time': 774.0,
#   'video_id': 'V_0a5d5880e7a54a018f3c5fe367931687',
#   'video_duration': 774.0},
#  {'video_start_time': 0.270000010728836,
#   'local_start_time': '2018-05-10 18:16:35',
#   'video_progress_time': 931.9999737441541,
#   'local_watching_time': 747,
#   'local_end_time': '2018-05-10 18:35:03',
#   'course_id': 'C_course-v1:TsinghuaX+00612642X+sp',
#   'watching_count': 4,
#   'video_end_time': 937.0,
#   'video_id': 'V_0b4c5734035e4eb4a2a50d21707f0af3',
#   'video_duration': 937.0},
#  {'video_start_time': 0.0,
#   'local_start_time': '2018-05-10 12:09:04',
#   'video_progress_time': 960.0,
#   'local_watching_time': 769,
#   'local_end_time': '2018-05-10 12:21:53',
#   'course_id': 'C_course-v1:TsinghuaX+00612642X+sp',
#   'watching_count': 1,
#   'video_end_time': 960.0,
#   'video_id': 'V_0bc07303336a4556b5f7fb4cf1e1cff9',
#   'video_duration': 960.0},
#  {'video_start_time': 0.0,
#   'local_start_time': '2018-10-19 16:24:36',
#   'video_progress_time': 617.0,
#   'local_watching_time': 622,
#   'local_end_time': '2018-10-19 16:34:58',
#   'course_id': 'C_course-v1:TsinghuaX+80000271X+sp',
#   'watching_count': 1,
#   'video_end_time': 617.0,
#   'video_id': 'V_0c0e653d322f4ed78abb052975b2fc05',
#   'video_duration': 617.0},
#  {'video_start_time': 0.0,
#   'local_start_time': '2018-05-13 11:54:04',
#   'video_progress_time': 448.8300018310547,
#   'local_watching_time': 302,
#   'local_end_time': '2018-05-13 11:59:41',
#   'course_id': 'C_course-v1:TsinghuaX+00612642X+sp',
#   'watching_count': 2,
#   'video_end_time': 449.0,
#   'video_id': 'V_0fccd7788a774a99ba8cdf4652011a0c',
#   'video_duration': 449.0},
#  {'video_start_time': 0.44999998807907104,
#   'local_start_time': '2018-10-25 20:04:18',
#   'video_progress_time': 1098.090039074421,
#   'local_watching_time': 1098,
#   'local_end_time': '2018-10-25 20:22:36',
#   'course_id': 'C_course-v1:TsinghuaX+80000271X+sp',
#   'watching_count': 1,
#   'video_end_time': 1098.5400390625,
#   'video_id': 'V_14aaa797edfd4c8895b85cf0b631b763',
#   'video_duration': 1099.0},
#  {'video_start_time': 0.7099999785423271,
#   'local_start_time': '2018-05-10 18:57:53',
#   'video_progress_time': 920.2900000214577,
#   'local_watching_time': 736,
#   'local_end_time': '2018-05-10 19:10:09',
#   'course_id': 'C_course-v1:TsinghuaX+00612642X+sp',
#   'watching_count': 1,
#   'video_end_time': 921.0,
#   'video_id': 'V_14d23841c74b480cb1d8ad9ca7e4e443',
#   'video_duration': 921.0},
#  {'video_start_time': 0.46000000834465005,
#   'local_start_time': '2018-10-25 18:00:16',
#   'video_progress_time': 1374.5399999916553,
#   'local_watching_time': 1375,
#   'local_end_time': '2018-10-25 18:23:11',
#   'course_id': 'C_course-v1:TsinghuaX+80000271X+sp',
#   'watching_count': 1,
#   'video_end_time': 1375.0,
#   'video_id': 'V_1586025fd2114c869ee9435808cb339b',
#   'video_duration': 1375.0},
#  {'video_start_time': 0.070000000298023,
#   'local_start_time': '2018-05-12 17:21:47',
#   'video_progress_time': 391.1399914547801,
#   'local_watching_time': 261,
#   'local_end_time': '2018-05-12 17:26:08',
#   'course_id': 'C_course-v1:TsinghuaX+00612642X+sp',
#   'watching_count': 1,
#   'video_end_time': 391.2099914550781,
#   'video_id': 'V_1733d9bb932c4b409e247879ab6b441f',
#   'video_duration': 392.0},
#  {'video_start_time': 0.0,
#   'local_start_time': '2018-10-25 17:01:44',
#   'video_progress_time': 733.0,
#   'local_watching_time': 756,
#   'local_end_time': '2018-10-25 17:14:20',
#   'course_id': 'C_course-v1:TsinghuaX+80000271X+sp',
#   'watching_count': 1,
#   'video_end_time': 733.0,
#   'video_id': 'V_1752bf63225e41a692c425bd3009f549',
#   'video_duration': 733.0},
#  {'video_start_time': 0.889999985694885,
#   'local_start_time': '2018-05-15 17:34:01',
#   'video_progress_time': 13.049999594688414,
#   'local_watching_time': 10,
#   'local_end_time': '2018-05-15 17:34:11',
#   'course_id': 'C_course-v1:TsinghuaX+00612642X+sp',
#   'watching_count': 1,
#   'video_end_time': 13.9399995803833,
#   'video_id': 'V_1791ff3ae3e2483382ed888d3478a0cd',
#   'video_duration': 539.0},
#  {'video_start_time': 0.0,
#   'local_start_time': '2018-06-04 20:20:59',
#   'video_progress_time': 663.0,
#   'local_watching_time': 531,
#   'local_end_time': '2018-06-04 20:29:50',
#   'course_id': 'C_course-v1:TsinghuaX+80000901X_1+sp',
#   'watching_count': 1,
#   'video_end_time': 663.0,
#   'video_id': 'V_1c0548692a6f48e69e130163526930dc',
#   'video_duration': 663.0},
#  {'video_start_time': 0.0,
#   'local_start_time': '2018-05-23 19:52:17',
#   'video_progress_time': 667.0,
#   'local_watching_time': 537,
#   'local_end_time': '2018-05-23 20:01:14',
#   'course_id': 'C_course-v1:TsinghuaX+00612642X+sp',
#   'watching_count': 1,
#   'video_end_time': 667.0,
#   'video_id': 'V_1d8f9a5c762f427297a601a185c00d77',
#   'video_duration': 667.0},
#  {'video_start_time': 0.009999999776482001,
#   'local_start_time': '2018-05-15 17:34:25',
#   'video_progress_time': 401.99000000022346,
#   'local_watching_time': 268,
#   'local_end_time': '2018-05-15 17:38:53',
#   'course_id': 'C_course-v1:TsinghuaX+00612642X+sp',
#   'watching_count': 1,
#   'video_end_time': 402.0,
#   'video_id': 'V_1dc242d0682246d69725c0b2369a024d',
#   'video_duration': 402.0},
#  {'video_start_time': 0.0,
#   'local_start_time': '2018-05-23 20:01:21',
#   'video_progress_time': 760.0,
#   'local_watching_time': 609,
#   'local_end_time': '2018-05-23 20:11:30',
#   'course_id': 'C_course-v1:TsinghuaX+00612642X+sp',
#   'watching_count': 1,
#   'video_end_time': 760.0,
#   'video_id': 'V_1dc6b6cc2e484cc18231eff1da1349e1',
#   'video_duration': 760.0},
#  {'video_start_time': 0.0,
#   'local_start_time': '2018-08-04 22:25:32',
#   'video_progress_time': 451.3500046543776,
#   'local_watching_time': 354,
#   'local_end_time': '2018-08-05 23:12:19',
#   'course_id': 'C_course-v1:TsinghuaX+00701032X+sp',
#   'watching_count': 3,
#   'video_end_time': 353.0,
#   'video_id': 'V_22a77413ebef47c9b75e4c383e7bf597',
#   'video_duration': 353.0},
#  {'video_start_time': 0.560000002384185,
#   'local_start_time': '2018-05-10 11:57:59',
#   'video_progress_time': 818.9000219702721,
#   'local_watching_time': 655,
#   'local_end_time': '2018-05-10 12:08:54',
#   'course_id': 'C_course-v1:TsinghuaX+00612642X+sp',
#   'watching_count': 1,
#   'video_end_time': 819.4600219726562,
#   'video_id': 'V_23884e3601c542d5b2f20cd32f6bc9a3',
#   'video_duration': 821.0},
#  {'video_start_time': 0.009999999776482001,
#   'local_start_time': '2018-09-08 03:30:25',
#   'video_progress_time': 544.7599964048713,
#   'local_watching_time': 552,
#   'local_end_time': '2018-09-08 03:40:29',
#   'course_id': 'C_course-v1:TsinghuaX+00701032X+sp',
#   'watching_count': 3,
#   'video_end_time': 575.0,
#   'video_id': 'V_288d8b2e14f74922ab8e7c0c97a728b9',
#   'video_duration': 575.0},
#  {'video_start_time': 30.61000061035156,
#   'local_start_time': '2018-09-08 03:20:23',
#   'video_progress_time': 518.3899993896483,
#   'local_watching_time': 522,
#   'local_end_time': '2018-09-08 03:29:05',
#   'course_id': 'C_course-v1:TsinghuaX+00701032X+sp',
#   'watching_count': 1,
#   'video_end_time': 549.0,
#   'video_id': 'V_2a1b31d31ae040ec801f14bb1c661cd3',
#   'video_duration': 549.0},
#  {'video_start_time': 0.019999999552965,
#   'local_start_time': '2018-05-09 17:45:45',
#   'video_progress_time': 689.9800000004469,
#   'local_watching_time': 553,
#   'local_end_time': '2018-05-09 17:54:58',
#   'course_id': 'C_course-v1:TsinghuaX+00612642X+sp',
#   'watching_count': 1,
#   'video_end_time': 690.0,
#   'video_id': 'V_2a3c23e2e1ad4005bdca9754c753af1d',
#   'video_duration': 690.0},
#  {'video_start_time': 0.46000000834465005,
#   'local_start_time': '2018-10-25 19:34:05',
#   'video_progress_time': 853.5399999916552,
#   'local_watching_time': 854,
#   'local_end_time': '2018-10-25 19:48:19',
#   'course_id': 'C_course-v1:TsinghuaX+80000271X+sp',
#   'watching_count': 1,
#   'video_end_time': 854.0,
#   'video_id': 'V_2d2525ac688149f68046be13dad9c905',
#   'video_duration': 854.0},
#  {'video_start_time': 0.0,
#   'local_start_time': '2018-10-19 16:12:22',
#   'video_progress_time': 705.0,
#   'local_watching_time': 709,
#   'local_end_time': '2018-10-19 16:24:11',
#   'course_id': 'C_course-v1:TsinghuaX+80000271X+sp',
#   'watching_count': 1,
#   'video_end_time': 705.0,
#   'video_id': 'V_2de4d7f127874a8491964f64725caf3d',
#   'video_duration': 705.0},
#  {'video_start_time': 3.7300000190734863,
#   'local_start_time': '2018-05-23 15:41:24',
#   'video_progress_time': 383.2699999809265,
#   'local_watching_time': 307,
#   'local_end_time': '2018-05-23 15:46:31',
#   'course_id': 'C_course-v1:TsinghuaX+00612642X+sp',
#   'watching_count': 1,
#   'video_end_time': 387.0,
#   'video_id': 'V_2e333186c0c6470ebc7b3bd4d1960fcb',
#   'video_duration': 387.0},
#  {'video_start_time': 0.270000010728836,
#   'local_start_time': '2018-10-21 17:30:25',
#   'video_progress_time': 545.519978016615,
#   'local_watching_time': 546,
#   'local_end_time': '2018-10-21 17:39:31',
#   'course_id': 'C_course-v1:TsinghuaX+80000271X+sp',
#   'watching_count': 1,
#   'video_end_time': 545.7899780273439,
#   'video_id': 'V_2ea53273ca434b5abcbb5338e4624703',
#   'video_duration': 549.0},
#  {'video_start_time': 0.0,
#   'local_start_time': '2018-05-21 17:31:12',
#   'video_progress_time': 516.0,
#   'local_watching_time': 345,
#   'local_end_time': '2018-05-21 17:36:57',
#   'course_id': 'C_course-v1:TsinghuaX+00612642X+sp',
#   'watching_count': 1,
#   'video_end_time': 516.0,
#   'video_id': 'V_2fe24e44d2bb4b11b99b7dbda59fae51',
#   'video_duration': 516.0},
#  {'video_start_time': 0.0,
#   'local_start_time': '2018-08-04 22:14:37',
#   'video_progress_time': 635.0,
#   'local_watching_time': 638,
#   'local_end_time': '2018-08-04 22:25:15',
#   'course_id': 'C_course-v1:TsinghuaX+00701032X+sp',
#   'watching_count': 1,
#   'video_end_time': 635.0,
#   'video_id': 'V_3350dca110f94bdd958f325c5bf2ba29',
#   'video_duration': 635.0},
#  {'video_start_time': 0.009999999776482001,
#   'local_start_time': '2018-05-13 11:39:55',
#   'video_progress_time': 69.72000335715714,
#   'local_watching_time': 47,
#   'local_end_time': '2018-05-13 11:40:42',
#   'course_id': 'C_course-v1:TsinghuaX+00612642X+sp',
#   'watching_count': 1,
#   'video_end_time': 69.73000335693361,
#   'video_id': 'V_34677859b865415487083371b4a7e3e1',
#   'video_duration': 735.0},
#  {'video_start_time': 0.070000000298023,
#   'local_start_time': '2018-10-20 18:01:58',
#   'video_progress_time': 523.8400036618114,
#   'local_watching_time': 525,
#   'local_end_time': '2018-10-20 18:12:08',
#   'course_id': 'C_course-v1:TsinghuaX+80000271X+sp',
#   'watching_count': 2,
#   'video_end_time': 524.0,
#   'video_id': 'V_34afad55f557478aa3c2b78fac2b977e',
#   'video_duration': 524.0},
#  {'video_start_time': 0.0,
#   'local_start_time': '2018-06-04 20:52:45',
#   'video_progress_time': 684.5299987792969,
#   'local_watching_time': 549,
#   'local_end_time': '2018-06-06 12:10:46',
#   'course_id': 'C_course-v1:TsinghuaX+80000901X_1+sp',
#   'watching_count': 2,
#   'video_end_time': 684.0,
#   'video_id': 'V_38dbbb27ae2e42758b495c05f47e82c7',
#   'video_duration': 684.0},
#  {'video_start_time': 0.019999999552965,
#   'local_start_time': '2018-10-20 17:46:01',
#   'video_progress_time': 379.98000000044715,
#   'local_watching_time': 380,
#   'local_end_time': '2018-10-20 17:52:21',
#   'course_id': 'C_course-v1:TsinghuaX+80000271X+sp',
#   'watching_count': 1,
#   'video_end_time': 380.0,
#   'video_id': 'V_3aed740ae06945098c625633fd66a079',
#   'video_duration': 380.0},
#  {'video_start_time': 0.0,
#   'local_start_time': '2018-10-20 18:23:47',
#   'video_progress_time': 520.1799926757811,
#   'local_watching_time': 520,
#   'local_end_time': '2018-10-20 18:32:27',
#   'course_id': 'C_course-v1:TsinghuaX+80000271X+sp',
#   'watching_count': 1,
#   'video_end_time': 520.1799926757811,
#   'video_id': 'V_3af7e78a9b9f47ec98e26561a04ce24c',
#   'video_duration': 777.0},
#  {'video_start_time': 0.6700000166893001,
#   'local_start_time': '2018-10-21 17:40:51',
#   'video_progress_time': 896.3299999833107,
#   'local_watching_time': 898,
#   'local_end_time': '2018-10-21 17:55:49',
#   'course_id': 'C_course-v1:TsinghuaX+80000271X+sp',
#   'watching_count': 1,
#   'video_end_time': 897.0,
#   'video_id': 'V_3c2687029c40459ea4f59de46f290a6f',
#   'video_duration': 897.0},
#  {'video_start_time': 0.009999999776482001,
#   'local_start_time': '2018-06-04 20:15:20',
#   'video_progress_time': 392.99000000022346,
#   'local_watching_time': 315,
#   'local_end_time': '2018-06-04 20:20:35',
#   'course_id': 'C_course-v1:TsinghuaX+80000901X_1+sp',
#   'watching_count': 1,
#   'video_end_time': 393.0,
#   'video_id': 'V_3c8439ff9f9a4ab4aa009f926eb4df17',
#   'video_duration': 393.0},
#  {'video_start_time': 0.019999999552965,
#   'local_start_time': '2018-10-25 17:26:35',
#   'video_progress_time': 917.3799938969313,
#   'local_watching_time': 918,
#   'local_end_time': '2018-10-25 18:00:10',
#   'course_id': 'C_course-v1:TsinghuaX+80000271X+sp',
#   'watching_count': 2,
#   'video_end_time': 917.489990234375,
#   'video_id': 'V_3eeebdb7309c4e538da68f55c48fe767',
#   'video_duration': 931.0},
#  {'video_start_time': 0.0,
#   'local_start_time': '2018-05-13 11:40:48',
#   'video_progress_time': 742.0,
#   'local_watching_time': 496,
#   'local_end_time': '2018-05-13 11:49:04',
#   'course_id': 'C_course-v1:TsinghuaX+00612642X+sp',
#   'watching_count': 1,
#   'video_end_time': 742.0,
#   'video_id': 'V_40844304428b42bfa935ba2330769eb9',
#   'video_duration': 742.0},
#  {'video_start_time': 272.85000610351557,
#   'local_start_time': '2018-10-20 17:10:39',
#   'video_progress_time': 130.14999389648443,
#   'local_watching_time': 132,
#   'local_end_time': '2018-10-20 17:12:51',
#   'course_id': 'C_course-v1:TsinghuaX+80000271X+sp',
#   'watching_count': 1,
#   'video_end_time': 403.0,
#   'video_id': 'V_417421648c7748c5ae55285785c4b1a7',
#   'video_duration': 403.0},
#  {'video_start_time': 0.0,
#   'local_start_time': '2018-05-12 17:29:17',
#   'video_progress_time': 660.0,
#   'local_watching_time': 441,
#   'local_end_time': '2018-05-12 17:36:38',
#   'course_id': 'C_course-v1:TsinghuaX+00612642X+sp',
#   'watching_count': 1,
#   'video_end_time': 660.0,
#   'video_id': 'V_41dadf0628154ea8a1cbb308931a4f3b',
#   'video_duration': 660.0},
#  {'video_start_time': 0.029999999329447004,
#   'local_start_time': '2018-05-09 16:04:55',
#   'video_progress_time': 679.9700000006708,
#   'local_watching_time': 545,
#   'local_end_time': '2018-05-09 16:14:00',
#   'course_id': 'C_course-v1:TsinghuaX+00612642X+sp',
#   'watching_count': 1,
#   'video_end_time': 680.0,
#   'video_id': 'V_43136997c9774ca5b6c42ad7d18d3987',
#   'video_duration': 680.0},
#  {'video_start_time': 0.699999988079071,
#   'local_start_time': '2018-05-15 17:39:11',
#   'video_progress_time': 751.3000000119209,
#   'local_watching_time': 501,
#   'local_end_time': '2018-05-15 17:47:32',
#   'course_id': 'C_course-v1:TsinghuaX+00612642X+sp',
#   'watching_count': 1,
#   'video_end_time': 752.0,
#   'video_id': 'V_479577ec86a3487ab3207ce9681d41a4',
#   'video_duration': 752.0},
#  {'video_start_time': 0.870000004768371,
#   'local_start_time': '2018-10-25 19:12:55',
#   'video_progress_time': 1263.6199902296064,
#   'local_watching_time': 1264,
#   'local_end_time': '2018-10-25 19:33:59',
#   'course_id': 'C_course-v1:TsinghuaX+80000271X+sp',
#   'watching_count': 1,
#   'video_end_time': 1264.489990234375,
#   'video_id': 'V_48a83d6ff128423fa146dc992ceae2e6',
#   'video_duration': 1265.0},
#  {'video_start_time': 0.009999999776482001,
#   'local_start_time': '2018-05-23 15:36:48',
#   'video_progress_time': 326.9900000002235,
#   'local_watching_time': 262,
#   'local_end_time': '2018-05-23 15:41:10',
#   'course_id': 'C_course-v1:TsinghuaX+00612642X+sp',
#   'watching_count': 1,
#   'video_end_time': 327.0,
#   'video_id': 'V_4ac03cfe78d347d8aee9936a9920e0a5',
#   'video_duration': 327.0},
#  {'video_start_time': 0.289999991655349,
#   'local_start_time': '2018-10-20 17:53:20',
#   'video_progress_time': 500.71000000834465,
#   'local_watching_time': 502,
#   'local_end_time': '2018-10-20 18:01:42',
#   'course_id': 'C_course-v1:TsinghuaX+80000271X+sp',
#   'watching_count': 1,
#   'video_end_time': 501.0,
#   'video_id': 'V_4ad9e51373d440c1a42981094622c64f',
#   'video_duration': 501.0},
#  {'video_start_time': 0.6100000143051141,
#   'local_start_time': '2018-10-19 15:44:35',
#   'video_progress_time': 577.3899999856949,
#   'local_watching_time': 579,
#   'local_end_time': '2018-10-19 15:54:14',
#   'course_id': 'C_course-v1:TsinghuaX+80000271X+sp',
#   'watching_count': 1,
#   'video_end_time': 578.0,
#   'video_id': 'V_5017403b54d448b398e4c7f1673d491a',
#   'video_duration': 578.0},
#  {'video_start_time': 0.0,
#   'local_start_time': '2018-05-09 17:32:47',
#   'video_progress_time': 466.66000747680664,
#   'local_watching_time': 374,
#   'local_end_time': '2018-05-09 17:40:34',
#   'course_id': 'C_course-v1:TsinghuaX+00612642X+sp',
#   'watching_count': 5,
#   'video_end_time': 468.45001220703125,
#   'video_id': 'V_516c6abfdb1b4f0e9e393c8e07e64e5e',
#   'video_duration': 469.0},
#  {'video_start_time': 0.0,
#   'local_start_time': '2018-05-13 11:49:15',
#   'video_progress_time': 421.0,
#   'local_watching_time': 281,
#   'local_end_time': '2018-05-13 11:53:56',
#   'course_id': 'C_course-v1:TsinghuaX+00612642X+sp',
#   'watching_count': 1,
#   'video_end_time': 421.0,
#   'video_id': 'V_529e42e1cd19422a9bc5fb0b83f5e9bf',
#   'video_duration': 421.0},
#  {'video_start_time': 0.0,
#   'local_start_time': '2018-10-20 17:12:58',
#   'video_progress_time': 535.9099884033203,
#   'local_watching_time': 538,
#   'local_end_time': '2018-10-20 17:23:23',
#   'course_id': 'C_course-v1:TsinghuaX+80000271X+sp',
#   'watching_count': 2,
#   'video_end_time': 536.0,
#   'video_id': 'V_5379ed7c9dfe4605b65b6366bdeeaaa0',
#   'video_duration': 536.0},
#  {'video_start_time': 0.019999999552965,
#   'local_start_time': '2018-05-21 17:44:24',
#   'video_progress_time': 623.980000000447,
#   'local_watching_time': 417,
#   'local_end_time': '2018-05-21 17:51:21',
#   'course_id': 'C_course-v1:TsinghuaX+00612642X+sp',
#   'watching_count': 1,
#   'video_end_time': 624.0,
#   'video_id': 'V_547842a5a5ab4c2f9e07c993886a5b7f',
#   'video_duration': 624.0},
#  {'video_start_time': 0.8199999928474421,
#   'local_start_time': '2018-10-17 21:12:38',
#   'video_progress_time': 380.18000000715256,
#   'local_watching_time': 380,
#   'local_end_time': '2018-10-17 21:18:58',
#   'course_id': 'C_course-v1:TsinghuaX+80000271X+sp',
#   'watching_count': 1,
#   'video_end_time': 381.0,
#   'video_id': 'V_547e40fd8afd4a7ba4885216b79d726e',
#   'video_duration': 381.0},
#  {'video_start_time': 0.0,
#   'local_start_time': '2018-05-04 18:19:45',
#   'video_progress_time': 828.0,
#   'local_watching_time': 553,
#   'local_end_time': '2018-05-04 18:28:58',
#   'course_id': 'C_course-v1:TsinghuaX+00612642X+sp',
#   'watching_count': 1,
#   'video_end_time': 828.0,
#   'video_id': 'V_5608ae6a57b14bfebb6ee05259da16d1',
#   'video_duration': 828.0},
#  {'video_start_time': 0.019999999552965,
#   'local_start_time': '2018-05-12 22:25:10',
#   'video_progress_time': 920.9800000004468,
#   'local_watching_time': 615,
#   'local_end_time': '2018-05-12 22:35:25',
#   'course_id': 'C_course-v1:TsinghuaX+00612642X+sp',
#   'watching_count': 1,
#   'video_end_time': 921.0,
#   'video_id': 'V_5659a2308d044e20a426b366603def3a',
#   'video_duration': 921.0},
#  {'video_start_time': 0.0,
#   'local_start_time': '2018-05-31 20:39:55',
#   'video_progress_time': 846.8399658203125,
#   'local_watching_time': 850,
#   'local_end_time': '2018-05-31 20:57:10',
#   'course_id': 'C_course-v1:TsinghuaX+80000901X_1+sp',
#   'watching_count': 3,
#   'video_end_time': 847.0,
#   'video_id': 'V_56fac3eda25f442a83fb8755efde6044',
#   'video_duration': 847.0},
#  {'video_start_time': 0.310000002384185,
#   'local_start_time': '2018-10-17 21:05:58',
#   'video_progress_time': 380.6899999976158,
#   'local_watching_time': 395,
#   'local_end_time': '2018-10-17 21:12:33',
#   'course_id': 'C_course-v1:TsinghuaX+80000271X+sp',
#   'watching_count': 1,
#   'video_end_time': 381.0,
#   'video_id': 'V_5ac0253bf4c040f99e89027999968666',
#   'video_duration': 381.0},
#  {'video_start_time': 0.8199999928474421,
#   'local_start_time': '2018-05-10 17:59:08',
#   'video_progress_time': 1000.8599926829338,
#   'local_watching_time': 801,
#   'local_end_time': '2018-05-10 18:16:25',
#   'course_id': 'C_course-v1:TsinghuaX+00612642X+sp',
#   'watching_count': 3,
#   'video_end_time': 1001.9199829101562,
#   'video_id': 'V_5ac631ccd7884d598e32ce28ce9ca1c2',
#   'video_duration': 1003.0},
#  {'video_start_time': 33.029998779296875,
#   'local_start_time': '2018-09-08 03:03:52',
#   'video_progress_time': 944.9700012207032,
#   'local_watching_time': 948,
#   'local_end_time': '2018-09-08 03:19:40',
#   'course_id': 'C_course-v1:TsinghuaX+00701032X+sp',
#   'watching_count': 1,
#   'video_end_time': 978.0,
#   'video_id': 'V_5bff82b99cc04e00b0082eeb93969515',
#   'video_duration': 978.0},
#  {'video_start_time': 0.0,
#   'local_start_time': '2018-05-09 14:42:14',
#   'video_progress_time': 413.0,
#   'local_watching_time': 331,
#   'local_end_time': '2018-05-09 14:47:45',
#   'course_id': 'C_course-v1:TsinghuaX+00612642X+sp',
#   'watching_count': 1,
#   'video_end_time': 413.0,
#   'video_id': 'V_601e2c5ab3de4e1d9342192da83464f1',
#   'video_duration': 413.0},
#  {'video_start_time': 0.0,
#   'local_start_time': '2018-05-09 14:05:39',
#   'video_progress_time': 368.0,
#   'local_watching_time': 248,
#   'local_end_time': '2018-05-09 14:09:47',
#   'course_id': 'C_course-v1:TsinghuaX+00612642X+sp',
#   'watching_count': 2,
#   'video_end_time': 368.0,
#   'video_id': 'V_6035b936640d414790b330ba8cf69540',
#   'video_duration': 368.0},
#  {'video_start_time': 0.029999999329447004,
#   'local_start_time': '2018-05-23 20:18:01',
#   'video_progress_time': 1313.7900073248893,
#   'local_watching_time': 1050,
#   'local_end_time': '2018-05-23 20:36:55',
#   'course_id': 'C_course-v1:TsinghuaX+00612642X+sp',
#   'watching_count': 3,
#   'video_end_time': 1314.0,
#   'video_id': 'V_616e631f56854ea69c7b02ee1e15b837',
#   'video_duration': 1314.0},
#  {'video_start_time': 0.0,
#   'local_start_time': '2018-05-12 22:19:35',
#   'video_progress_time': 461.0,
#   'local_watching_time': 308,
#   'local_end_time': '2018-05-12 22:24:43',
#   'course_id': 'C_course-v1:TsinghuaX+00612642X+sp',
#   'watching_count': 1,
#   'video_end_time': 461.0,
#   'video_id': 'V_62863e1fe6cf4a4baeb862dd8dec437e',
#   'video_duration': 461.0},
#  {'video_start_time': 15.869999885559082,
#   'local_start_time': '2018-10-21 17:15:57',
#   'video_progress_time': 745.1300001144409,
#   'local_watching_time': 757,
#   'local_end_time': '2018-10-21 17:28:34',
#   'course_id': 'C_course-v1:TsinghuaX+80000271X+sp',
#   'watching_count': 1,
#   'video_end_time': 761.0,
#   'video_id': 'V_63cb85b576d0485eb0bf9fe43f05aeb3',
#   'video_duration': 761.0},
#  {'video_start_time': 0.0,
#   'local_start_time': '2018-06-04 20:44:39',
#   'video_progress_time': 358.0,
#   'local_watching_time': 287,
#   'local_end_time': '2018-06-04 20:49:26',
#   'course_id': 'C_course-v1:TsinghuaX+80000901X_1+sp',
#   'watching_count': 1,
#   'video_end_time': 358.0,
#   'video_id': 'V_650f5d04572a43cd9f3d4250cb165ecb',
#   'video_duration': 358.0},
#  {'video_start_time': 0.21999999880790702,
#   'local_start_time': '2018-08-05 23:17:44',
#   'video_progress_time': 935.3600087463857,
#   'local_watching_time': 970,
#   'local_end_time': '2018-09-08 02:37:02',
#   'course_id': 'C_course-v1:TsinghuaX+00701032X+sp',
#   'watching_count': 4,
#   'video_end_time': 640.0,
#   'video_id': 'V_6518e67a610940538c3e8dd380c4831c',
#   'video_duration': 640.0},
#  {'video_start_time': 0.07999999821186,
#   'local_start_time': '2018-05-10 19:10:23',
#   'video_progress_time': 1074.3699998110533,
#   'local_watching_time': 723,
#   'local_end_time': '2018-05-12 17:13:49',
#   'course_id': 'C_course-v1:TsinghuaX+00612642X+sp',
#   'watching_count': 3,
#   'video_end_time': 1074.0,
#   'video_id': 'V_6535c509ef934cc7952d3d51d3ef37d6',
#   'video_duration': 1074.0},
#  {'video_start_time': 0.0,
#   'local_start_time': '2018-10-19 16:35:14',
#   'video_progress_time': 689.1599731445312,
#   'local_watching_time': 691,
#   'local_end_time': '2018-10-19 16:46:45',
#   'course_id': 'C_course-v1:TsinghuaX+80000271X+sp',
#   'watching_count': 1,
#   'video_end_time': 689.1599731445312,
#   'video_id': 'V_6a7331d947984d4a9a2c28024330b9e6',
#   'video_duration': 691.0},
#  {'video_start_time': 0.0,
#   'local_start_time': '2018-05-17 11:33:56',
#   'video_progress_time': 981.2400054931641,
#   'local_watching_time': 787,
#   'local_end_time': '2018-05-17 19:00:07',
#   'course_id': 'C_course-v1:TsinghuaX+80000901X_1+sp',
#   'watching_count': 2,
#   'video_end_time': 981.0,
#   'video_id': 'V_6c632a9f758f4b808589c589e828fd75',
#   'video_duration': 981.0},
#  {'video_start_time': 0.0,
#   'local_start_time': '2018-05-09 17:40:44',
#   'video_progress_time': 345.75,
#   'local_watching_time': 277,
#   'local_end_time': '2018-05-09 17:45:21',
#   'course_id': 'C_course-v1:TsinghuaX+00612642X+sp',
#   'watching_count': 1,
#   'video_end_time': 345.75,
#   'video_id': 'V_6c71eff47c8848db9cbe7122517ca20d',
#   'video_duration': 346.0},
#  {'video_start_time': 0.0,
#   'local_start_time': '2018-05-23 15:33:23',
#   'video_progress_time': 240.0,
#   'local_watching_time': 193,
#   'local_end_time': '2018-05-23 15:36:36',
#   'course_id': 'C_course-v1:TsinghuaX+00612642X+sp',
#   'watching_count': 1,
#   'video_end_time': 240.0,
#   'video_id': 'V_6f8b27a2bcb64651b835a1795a5e9eb8',
#   'video_duration': 240.0},
#  {'video_start_time': 0.009999999776482001,
#   'local_start_time': '2018-06-06 12:11:02',
#   'video_progress_time': 361.99000000022346,
#   'local_watching_time': 291,
#   'local_end_time': '2018-06-06 12:15:53',
#   'course_id': 'C_course-v1:TsinghuaX+80000901X_1+sp',
#   'watching_count': 1,
#   'video_end_time': 362.0,
#   'video_id': 'V_70ac8f9e54f341b0a1fba3b9d8e95a74',
#   'video_duration': 362.0},
#  {'video_start_time': 0.009999999776482001,
#   'local_start_time': '2018-05-09 16:45:42',
#   'video_progress_time': 554.9900000002235,
#   'local_watching_time': 446,
#   'local_end_time': '2018-05-09 16:53:08',
#   'course_id': 'C_course-v1:TsinghuaX+00612642X+sp',
#   'watching_count': 1,
#   'video_end_time': 555.0,
#   'video_id': 'V_7486663115d3464d9ed17bf2540be24e',
#   'video_duration': 555.0},
#  {'video_start_time': 0.0,
#   'local_start_time': '2018-05-31 20:01:36',
#   'video_progress_time': 625.5800094604492,
#   'local_watching_time': 629,
#   'local_end_time': '2018-05-31 20:33:22',
#   'course_id': 'C_course-v1:TsinghuaX+80000901X_1+sp',
#   'watching_count': 6,
#   'video_end_time': 626.0,
#   'video_id': 'V_78211d7a2f9f4442ab48a810904640ce',
#   'video_duration': 626.0},
#  {'video_start_time': 0.0,
#   'local_start_time': '2018-05-23 17:45:36',
#   'video_progress_time': 655.9100036621094,
#   'local_watching_time': 525,
#   'local_end_time': '2018-05-23 17:55:12',
#   'course_id': 'C_course-v1:TsinghuaX+00612642X+sp',
#   'watching_count': 2,
#   'video_end_time': 656.0,
#   'video_id': 'V_7a05e6f6126c4d92b4077061e79530f7',
#   'video_duration': 656.0},
#  {'video_start_time': 0.009999999776482001,
#   'local_start_time': '2018-05-09 14:20:13',
#   'video_progress_time': 871.9900000002235,
#   'local_watching_time': 699,
#   'local_end_time': '2018-05-09 14:31:52',
#   'course_id': 'C_course-v1:TsinghuaX+00612642X+sp',
#   'watching_count': 1,
#   'video_end_time': 872.0,
#   'video_id': 'V_7a5f84164eb545c2a23dcd38db39e169',
#   'video_duration': 872.0},
#  {'video_start_time': 0.0,
#   'local_start_time': '2018-10-19 20:31:04',
#   'video_progress_time': 570.0,
#   'local_watching_time': 570,
#   'local_end_time': '2018-10-19 20:40:34',
#   'course_id': 'C_course-v1:TsinghuaX+80000271X+sp',
#   'watching_count': 1,
#   'video_end_time': 570.0,
#   'video_id': 'V_7b49ead1abc7493bac3412d97bc88bee',
#   'video_duration': 570.0},
#  {'video_start_time': 0.300000011920928,
#   'local_start_time': '2018-10-25 18:23:20',
#   'video_progress_time': 742.6300002932549,
#   'local_watching_time': 743,
#   'local_end_time': '2018-10-25 18:43:15',
#   'course_id': 'C_course-v1:TsinghuaX+80000271X+sp',
#   'watching_count': 2,
#   'video_end_time': 743.0,
#   'video_id': 'V_7e39b1cc47ba49bda8d14debe0be21ae',
#   'video_duration': 743.0},
#  {'video_start_time': 0.0,
#   'local_start_time': '2018-05-12 17:26:15',
#   'video_progress_time': 260.0,
#   'local_watching_time': 174,
#   'local_end_time': '2018-05-12 17:29:09',
#   'course_id': 'C_course-v1:TsinghuaX+00612642X+sp',
#   'watching_count': 1,
#   'video_end_time': 260.0,
#   'video_id': 'V_7ed8295e6fdb4e6dbe536b011034d6ad',
#   'video_duration': 260.0},
#  {'video_start_time': 0.0,
#   'local_start_time': '2018-06-06 17:48:52',
#   'video_progress_time': 1067.7799987792966,
#   'local_watching_time': 855,
#   'local_end_time': '2018-06-06 18:04:29',
#   'course_id': 'C_course-v1:TsinghuaX+80000901X_1+sp',
#   'watching_count': 3,
#   'video_end_time': 1068.0,
#   'video_id': 'V_80ebb56956fa44d297423fed93d85f07',
#   'video_duration': 1068.0},
#  {'video_start_time': 0.0,
#   'local_start_time': '2018-05-21 17:51:33',
#   'video_progress_time': 1331.0,
#   'local_watching_time': 888,
#   'local_end_time': '2018-05-21 18:06:21',
#   'course_id': 'C_course-v1:TsinghuaX+00612642X+sp',
#   'watching_count': 1,
#   'video_end_time': 1331.0,
#   'video_id': 'V_8155c79d1c5442dfaa69801bfead2665',
#   'video_duration': 1331.0},
#  {'video_start_time': 0.019999999552965,
#   'local_start_time': '2018-05-09 18:11:27',
#   'video_progress_time': 626.980000000447,
#   'local_watching_time': 502,
#   'local_end_time': '2018-05-09 18:19:49',
#   'course_id': 'C_course-v1:TsinghuaX+00612642X+sp',
#   'watching_count': 1,
#   'video_end_time': 627.0,
#   'video_id': 'V_825a76d487f841da9bc52b9c760082c2',
#   'video_duration': 627.0},
#  {'video_start_time': 0.0,
#   'local_start_time': '2018-05-12 17:40:45',
#   'video_progress_time': 665.4400024414062,
#   'local_watching_time': 457,
#   'local_end_time': '2018-05-12 17:49:10',
#   'course_id': 'C_course-v1:TsinghuaX+00612642X+sp',
#   'watching_count': 2,
#   'video_end_time': 695.0,
#   'video_id': 'V_82bf0782927d4f6f8da44aca4867ca95',
#   'video_duration': 695.0},
#  {'video_start_time': 0.019999999552965,
#   'local_start_time': '2018-05-12 17:36:47',
#   'video_progress_time': 346.98000000044715,
#   'local_watching_time': 233,
#   'local_end_time': '2018-05-12 17:40:40',
#   'course_id': 'C_course-v1:TsinghuaX+00612642X+sp',
#   'watching_count': 1,
#   'video_end_time': 347.0,
#   'video_id': 'V_83bd706592c54e8fa30f340313e16239',
#   'video_duration': 347.0},
#  {'video_start_time': 0.019999999552965,
#   'local_start_time': '2018-06-06 12:16:11',
#   'video_progress_time': 1089.8800244145095,
#   'local_watching_time': 872,
#   'local_end_time': '2018-06-06 12:31:48',
#   'course_id': 'C_course-v1:TsinghuaX+80000901X_1+sp',
#   'watching_count': 2,
#   'video_end_time': 1090.0,
#   'video_id': 'V_842d697d9bd64ed9bd26076177018976',
#   'video_duration': 1090.0},
#  {'video_start_time': 0.009999999776482001,
#   'local_start_time': '2018-05-05 12:53:45',
#   'video_progress_time': 392.99000000022346,
#   'local_watching_time': 263,
#   'local_end_time': '2018-05-05 12:58:08',
#   'course_id': 'C_course-v1:TsinghuaX+00612642X+sp',
#   'watching_count': 1,
#   'video_end_time': 393.0,
#   'video_id': 'V_84e3bf3b0bae47b4a8050bc785813a86',
#   'video_duration': 393.0},
#  {'video_start_time': 0.019999999552965,
#   'local_start_time': '2018-05-16 18:50:10',
#   'video_progress_time': 591.980000000447,
#   'local_watching_time': 395,
#   'local_end_time': '2018-05-16 18:56:45',
#   'course_id': 'C_course-v1:TsinghuaX+00612642X+sp',
#   'watching_count': 1,
#   'video_end_time': 592.0,
#   'video_id': 'V_853e78c95de3409f8eac79cfb5cd56ff',
#   'video_duration': 592.0},
#  {'video_start_time': 0.0,
#   'local_start_time': '2018-05-05 13:04:47',
#   'video_progress_time': 930.7699980139732,
#   'local_watching_time': 638,
#   'local_end_time': '2018-05-09 14:02:12',
#   'course_id': 'C_course-v1:TsinghuaX+00612642X+sp',
#   'watching_count': 7,
#   'video_end_time': 857.0,
#   'video_id': 'V_8a472dc9cbf5465a823c511685743f38',
#   'video_duration': 857.0},
#  {'video_start_time': 0.029999999329447004,
#   'local_start_time': '2018-05-09 17:26:19',
#   'video_progress_time': 474.97000000067055,
#   'local_watching_time': 380,
#   'local_end_time': '2018-05-09 17:32:39',
#   'course_id': 'C_course-v1:TsinghuaX+00612642X+sp',
#   'watching_count': 1,
#   'video_end_time': 475.0,
#   'video_id': 'V_8c0a4c0744c84dda833cef86508c5335',
#   'video_duration': 475.0},
#  {'video_start_time': 0.129999995231628,
#   'local_start_time': '2018-05-17 19:04:09',
#   'video_progress_time': 186.56000244617462,
#   'local_watching_time': 150,
#   'local_end_time': '2018-05-17 19:06:39',
#   'course_id': 'C_course-v1:TsinghuaX+80000901X_1+sp',
#   'watching_count': 1,
#   'video_end_time': 186.69000244140625,
#   'video_id': 'V_8db0cb5bddac496a8042a7aa6e71b1de',
#   'video_duration': 1405.0},
#  {'video_start_time': 0.0,
#   'local_start_time': '2018-06-01 10:33:36',
#   'video_progress_time': 817.8999938964844,
#   'local_watching_time': 655,
#   'local_end_time': '2018-06-01 10:57:56',
#   'course_id': 'C_course-v1:TsinghuaX+80000901X_1+sp',
#   'watching_count': 2,
#   'video_end_time': 818.0,
#   'video_id': 'V_8f10a04a15e94271965c125a99bb0b20',
#   'video_duration': 818.0},
#  {'video_start_time': 1.110000014305114,
#   'local_start_time': '2018-05-09 16:18:31',
#   'video_progress_time': 718.7900015115738,
#   'local_watching_time': 575,
#   'local_end_time': '2018-05-09 16:37:40',
#   'course_id': 'C_course-v1:TsinghuaX+00612642X+sp',
#   'watching_count': 2,
#   'video_end_time': 720.0,
#   'video_id': 'V_9164c5456ce941b2b2dd61469460f8fe',
#   'video_duration': 720.0},
#  {'video_start_time': 0.019999999552965,
#   'local_start_time': '2018-05-04 13:34:34',
#   'video_progress_time': 1037.4500317387283,
#   'local_watching_time': 830,
#   'local_end_time': '2018-05-04 16:58:35',
#   'course_id': 'C_course-v1:TsinghuaX+00612642X+sp',
#   'watching_count': 2,
#   'video_end_time': 1037.2900390625,
#   'video_id': 'V_92dc45268cab47e088192e32bfc8a5f0',
#   'video_duration': 1039.0},
#  {'video_start_time': 0.0,
#   'local_start_time': '2018-10-19 20:42:47',
#   'video_progress_time': 166.0,
#   'local_watching_time': 166,
#   'local_end_time': '2018-10-19 20:45:33',
#   'course_id': 'C_course-v1:TsinghuaX+80000271X+sp',
#   'watching_count': 1,
#   'video_end_time': 166.0,
#   'video_id': 'V_94023b4b20a1442cb6f4db6f9adf8189',
#   'video_duration': 166.0}]

# %%
df.iloc[0, 1][0]
# Out:
# {'video_start_time': 1.179999947547912,
#  'local_start_time': '2018-05-12 17:49:32',
#  'video_progress_time': 1080.6599601507187,
#  'local_watching_time': 722,
#  'local_end_time': '2018-05-12 18:02:07',
#  'course_id': 'C_course-v1:TsinghuaX+00612642X+sp',
#  'watching_count': 2,
#  'video_end_time': 1081.9599609375,
#  'video_id': 'V_01292610aa1748e79c8981de6f0464f8',
#  'video_duration': 1084.0}

# %%
test = pd.DataFrame()

# %%
for i in range(len(df)):
    print('*' * 10)
    print(i)
    course_id = []
    video_id = []
    watching_count = []
    video_duration = []
    local_watching_time = []
    video_progress_time = []
    video_start_time = []
    video_end_time = []
    local_start_time = []
    local_end_time = []
    # drop = []
    for j in df.iloc[i, 1]:
        course_id.append(j['course_id'].split(':')[1])
        video_id.append(j['video_id'])
        watching_count.append(j['watching_count'])
        video_duration.append(j['video_duration'])
        local_watching_time.append(j['local_watching_time'])
        video_progress_time.append(j['video_progress_time'])
        video_start_time.append(j['video_start_time'])
        video_end_time.append(j['video_end_time'])
        local_start_time.append(j['local_start_time'])
        local_end_time.append(j['local_end_time'])
        drop.append(j['drop'])
    tmp = pd.DataFrame({'item_id': df.iloc[i, 2],
                        'course_id': course_id,
                        'video_id': video_id,
                        'watching_count': watching_count,
                        'video_duration': video_duration,
                        'local_watching_time': local_watching_time,
                        'video_progress_time': video_progress_time,
                        'video_start_time': video_start_time,
                        'video_end_time': video_end_time,
                        'local_start_time': local_start_time,
                        'local_end_time': local_end_time,
                        'drop': -1})
    test = pd.concat([test, tmp], ignore_index=False, axis=1)
    del tmp
    gc.collect()

# %%
test.head().append(test.tail())

# %%
test.shape
