# %%
import pandas as pd
import gc
pd.set_option('max_columns', None)
pd.set_option('max_rows', None)

# %%
df = pd.read_json('../Track1/user_video_act_train_4.json', lines=True)
df.head()
# Out:
#            id                                           activity
# 0   U_7140103  [{'course_id': 'C_course-v1:TsinghuaX+20430064...
# 1   U_8484300  [{'course_id': 'C_course-v1:TsinghuaX+30640014...
# 2   U_7095434  [{'course_id': 'C_course-v1:TsinghuaX+30240184...
# 3  U_11084623  [{'course_id': 'C_course-v1:TsinghuaX+20740042...
# 4   U_9339288  [{'course_id': 'C_course-v1:TsinghuaX+00690092...

# %%
df.iloc[0, :]
# Out:
# id                                                  U_7140103
# activity    [{'course_id': 'C_course-v1:TsinghuaX+20430064...
# Name: 0, dtype: object

# %%
df.iloc[0, 1]
# Out:
# [{'course_id': 'C_course-v1:TsinghuaX+20430064X+sp',
#   'video_id': 'V_05f095f52ac6446ba05b883171c66713',
#   'watching_count': 1,
#   'video_duration': 563.0,
#   'local_watching_time': 563,
#   'video_progress_time': 563.0,
#   'video_start_time': 0.0,
#   'video_end_time': 563.0,
#   'local_start_time': '2017-07-24 13:26:56',
#   'local_end_time': '2017-07-24 13:36:19',
#   'drop': 0},
#  {'course_id': 'C_course-v1:TsinghuaX+34000888X+sp',
#   'video_id': 'V_0d166f12024942fca500891c0346b86a',
#   'watching_count': 1,
#   'video_duration': 166.0,
#   'local_watching_time': 166,
#   'video_progress_time': 166.0,
#   'video_start_time': 0.0,
#   'video_end_time': 166.0,
#   'local_start_time': '2017-07-06 14:47:00',
#   'local_end_time': '2017-07-06 14:49:46',
#   'drop': 0},
#  {'course_id': 'C_course-v1:TsinghuaX+00691153X+sp',
#   'video_id': 'V_0d2ed7b0f77647388d3ad5420d1d6549',
#   'watching_count': 2,
#   'video_duration': 415.0,
#   'local_watching_time': 415,
#   'video_progress_time': 414.8099975585936,
#   'video_start_time': 0.0,
#   'video_end_time': 415.0,
#   'local_start_time': '2017-07-13 09:01:58',
#   'local_end_time': '2017-07-13 13:18:15',
#   'drop': 0},
#  {'course_id': 'C_course-v1:TsinghuaX+20430064X+sp',
#   'video_id': 'V_10355a6a239c4a1dbc28e99bfb7633c1',
#   'watching_count': 1,
#   'video_duration': 173.0,
#   'local_watching_time': 174,
#   'video_progress_time': 173.0,
#   'video_start_time': 0.0,
#   'video_end_time': 173.0,
#   'local_start_time': '2017-07-24 13:11:47',
#   'local_end_time': '2017-07-24 13:14:41',
#   'drop': 0},
#  {'course_id': 'C_course-v1:TsinghuaX+34000888X+sp',
#   'video_id': 'V_11f15f23fca948808b5f44e25b75f6a2',
#   'watching_count': 1,
#   'video_duration': 63.0,
#   'local_watching_time': 19,
#   'video_progress_time': 18.81999969482422,
#   'video_start_time': 0.0,
#   'video_end_time': 18.81999969482422,
#   'local_start_time': '2017-07-06 14:56:18',
#   'local_end_time': '2017-07-06 14:56:37',
#   'drop': 0},
#  {'course_id': 'C_course-v1:TsinghuaX+34000888X+sp',
#   'video_id': 'V_1dfe758f74c64404aa98b30048d3bc77',
#   'watching_count': 3,
#   'video_duration': 262.0,
#   'local_watching_time': 262,
#   'video_progress_time': 261.8300018310547,
#   'video_start_time': 0.0,
#   'video_end_time': 262.0,
#   'local_start_time': '2017-07-06 14:35:15',
#   'local_end_time': '2017-07-06 14:39:39',
#   'drop': 0},
#  {'course_id': 'C_course-v1:TsinghuaX+400182X+sp',
#   'video_id': 'V_1f6a60f535af482e99550cf8c74e78ca',
#   'watching_count': 2,
#   'video_duration': 1088.0,
#   'local_watching_time': 2097,
#   'video_progress_time': 2081.5599975585933,
#   'video_start_time': 0.0,
#   'video_end_time': 1088.0,
#   'local_start_time': '2017-07-15 14:33:10',
#   'local_end_time': '2017-07-15 15:12:39',
#   'drop': 0},
#  {'course_id': 'C_course-v1:TsinghuaX+20430064X+sp',
#   'video_id': 'V_202664057afb470998c92d870d0b8fb3',
#   'watching_count': 1,
#   'video_duration': 254.0,
#   'local_watching_time': 254,
#   'video_progress_time': 254.0,
#   'video_start_time': 0.0,
#   'video_end_time': 254.0,
#   'local_start_time': '2017-07-24 13:07:28',
#   'local_end_time': '2017-07-24 13:11:42',
#   'drop': 0},
#  {'course_id': 'C_course-v1:TsinghuaX+400182X+sp',
#   'video_id': 'V_21528e8bc6ee48d0ab996657ad4bb1ab',
#   'watching_count': 1,
#   'video_duration': 441.0,
#   'local_watching_time': 442,
#   'video_progress_time': 441.0,
#   'video_start_time': 0.0,
#   'video_end_time': 441.0,
#   'local_start_time': '2017-07-15 09:21:42',
#   'local_end_time': '2017-07-15 09:29:04',
#   'drop': 0},
#  {'course_id': 'C_course-v1:TsinghuaX+20430064X+sp',
#   'video_id': 'V_2b0abbba1fdb442cb483dd9129891827',
#   'watching_count': 1,
#   'video_duration': 326.0,
#   'local_watching_time': 327,
#   'video_progress_time': 326.0,
#   'video_start_time': 0.0,
#   'video_end_time': 326.0,
#   'local_start_time': '2017-07-24 13:15:00',
#   'local_end_time': '2017-07-24 13:20:27',
#   'drop': 0},
#  {'course_id': 'C_course-v1:TsinghuaX+20430064X+sp',
#   'video_id': 'V_2cee346b1e444e819d6a62060bd2ea78',
#   'watching_count': 1,
#   'video_duration': 520.0,
#   'local_watching_time': 520,
#   'video_progress_time': 520.0,
#   'video_start_time': 0.0,
#   'video_end_time': 520.0,
#   'local_start_time': '2017-07-24 13:43:13',
#   'local_end_time': '2017-07-24 13:51:53',
#   'drop': 0},
#  {'course_id': 'C_course-v1:TsinghuaX+20430064X+sp',
#   'video_id': 'V_2e55b72c02934e7bbfb4e8c964d92419',
#   'watching_count': 1,
#   'video_duration': 196.0,
#   'local_watching_time': 196,
#   'video_progress_time': 196.0,
#   'video_start_time': 0.0,
#   'video_end_time': 196.0,
#   'local_start_time': '2017-07-24 12:44:17',
#   'local_end_time': '2017-07-24 12:47:33',
#   'drop': 0},
#  {'course_id': 'C_course-v1:TsinghuaX+20430064X+sp',
#   'video_id': 'V_2f574616483546e598d409bd4cfeb31e',
#   'watching_count': 1,
#   'video_duration': 347.0,
#   'local_watching_time': 347,
#   'video_progress_time': 346.99000000022346,
#   'video_start_time': 0.009999999776482001,
#   'video_end_time': 347.0,
#   'local_start_time': '2017-07-24 13:37:19',
#   'local_end_time': '2017-07-24 13:43:06',
#   'drop': 0},
#  {'course_id': 'C_course-v1:TsinghuaX+00691153X+sp',
#   'video_id': 'V_330acdbc14db49a88adbbc10c082155e',
#   'watching_count': 4,
#   'video_duration': 282.0,
#   'local_watching_time': 240,
#   'video_progress_time': 239.8500006105752,
#   'video_start_time': 0.009999999776482001,
#   'video_end_time': 212.1499938964844,
#   'local_start_time': '2017-07-13 08:25:40',
#   'local_end_time': '2017-07-13 08:38:45',
#   'drop': 0},
#  {'course_id': 'C_course-v1:TsinghuaX+00691153X+sp',
#   'video_id': 'V_42b82d4372ed4350b661f68a825594be',
#   'watching_count': 1,
#   'video_duration': 306.0,
#   'local_watching_time': 307,
#   'video_progress_time': 306.0,
#   'video_start_time': 0.0,
#   'video_end_time': 306.0,
#   'local_start_time': '2017-07-06 09:45:38',
#   'local_end_time': '2017-07-06 09:50:45',
#   'drop': 0},
#  {'course_id': 'C_course-v1:TsinghuaX+34000888X+sp',
#   'video_id': 'V_55157703dc544641bc9d012c074edbef',
#   'watching_count': 1,
#   'video_duration': 191.0,
#   'local_watching_time': 58,
#   'video_progress_time': 58.53999923728406,
#   'video_start_time': 0.009999999776482001,
#   'video_end_time': 58.54999923706055,
#   'local_start_time': '2017-07-06 14:34:05',
#   'local_end_time': '2017-07-06 14:35:03',
#   'drop': 0},
#  {'course_id': 'C_course-v1:TsinghuaX+20430064X+sp',
#   'video_id': 'V_595dbd67825a40d9b0c8eb90296967a7',
#   'watching_count': 1,
#   'video_duration': 402.0,
#   'local_watching_time': 404,
#   'video_progress_time': 402.0,
#   'video_start_time': 0.0,
#   'video_end_time': 402.0,
#   'local_start_time': '2017-07-24 14:06:51',
#   'local_end_time': '2017-07-24 14:13:35',
#   'drop': 0},
#  {'course_id': 'C_course-v1:TsinghuaX+34000888X+sp',
#   'video_id': 'V_611fd1ea64ed4d65905364cd4e7db046',
#   'watching_count': 1,
#   'video_duration': 208.0,
#   'local_watching_time': 209,
#   'video_progress_time': 207.99000000022357,
#   'video_start_time': 0.009999999776482001,
#   'video_end_time': 208.0,
#   'local_start_time': '2017-07-06 14:40:00',
#   'local_end_time': '2017-07-06 14:43:29',
#   'drop': 0},
#  {'course_id': 'C_course-v1:TsinghuaX+20430064X+sp',
#   'video_id': 'V_64ff414b669e44c8b55ca3eb794bb3ca',
#   'watching_count': 1,
#   'video_duration': 510.0,
#   'local_watching_time': 510,
#   'video_progress_time': 509.99000000022346,
#   'video_start_time': 0.009999999776482001,
#   'video_end_time': 510.0,
#   'local_start_time': '2017-07-24 13:58:14',
#   'local_end_time': '2017-07-24 14:06:44',
#   'drop': 0},
#  {'course_id': 'C_course-v1:TsinghuaX+00691153X+sp',
#   'video_id': 'V_6d701687d50e4ee4a897b3c74c45afa1',
#   'watching_count': 1,
#   'video_duration': 851.0,
#   'local_watching_time': 851,
#   'video_progress_time': 851.0,
#   'video_start_time': 0.0,
#   'video_end_time': 851.0,
#   'local_start_time': '2017-07-13 13:18:57',
#   'local_end_time': '2017-07-13 13:33:08',
#   'drop': 0},
#  {'course_id': 'C_course-v1:TsinghuaX+00691153X+sp',
#   'video_id': 'V_74598872443d4c10848782f021e1d0af',
#   'watching_count': 1,
#   'video_duration': 898.0,
#   'local_watching_time': 202,
#   'video_progress_time': 201.52999877929688,
#   'video_start_time': 0.0,
#   'video_end_time': 201.52999877929688,
#   'local_start_time': '2017-07-13 08:41:20',
#   'local_end_time': '2017-07-13 08:44:42',
#   'drop': 0},
#  {'course_id': 'C_course-v1:TsinghuaX+10421075X_2015_2+sp',
#   'video_id': 'V_74e609663dbc4406b38b042e559f3609',
#   'watching_count': 2,
#   'video_duration': 748.0,
#   'local_watching_time': 192,
#   'video_progress_time': 191.34999084472656,
#   'video_start_time': 0.0,
#   'video_end_time': 191.5399932861328,
#   'local_start_time': '2017-07-09 10:13:15',
#   'local_end_time': '2017-07-09 10:17:31',
#   'drop': 0},
#  {'course_id': 'C_course-v1:TsinghuaX+34000888X+sp',
#   'video_id': 'V_891d45ab4be741f2bca0fb11cd91cf61',
#   'watching_count': 1,
#   'video_duration': 178.0,
#   'local_watching_time': 178,
#   'video_progress_time': 178.0,
#   'video_start_time': 0.0,
#   'video_end_time': 178.0,
#   'local_start_time': '2017-07-06 14:43:47',
#   'local_end_time': '2017-07-06 14:46:45',
#   'drop': 0},
#  {'course_id': 'C_course-v1:TsinghuaX+34000888X+sp',
#   'video_id': 'V_8bc4f6e95fa7471199294d03b0567353',
#   'watching_count': 1,
#   'video_duration': 319.0,
#   'local_watching_time': 319,
#   'video_progress_time': 319.0,
#   'video_start_time': 0.0,
#   'video_end_time': 319.0,
#   'local_start_time': '2017-07-06 14:50:01',
#   'local_end_time': '2017-07-06 14:55:20',
#   'drop': 1},
#  {'course_id': 'C_course-v1:TsinghuaX+00691153X+sp',
#   'video_id': 'V_90e2e31ebc8b43e18a49ca8a26b4c4e3',
#   'watching_count': 3,
#   'video_duration': 524.0,
#   'local_watching_time': 530,
#   'video_progress_time': 528.2299866676329,
#   'video_start_time': 0.0,
#   'video_end_time': 524.0,
#   'local_start_time': '2017-07-06 09:08:26',
#   'local_end_time': '2017-07-06 09:18:08',
#   'drop': 0},
#  {'course_id': 'C_course-v1:TsinghuaX+400182X+sp',
#   'video_id': 'V_90fc89b04d4e4767ac5b5d233f74e247',
#   'watching_count': 2,
#   'video_duration': 1150.0,
#   'local_watching_time': 1160,
#   'video_progress_time': 1149.8200073242188,
#   'video_start_time': 0.0,
#   'video_end_time': 1150.0,
#   'local_start_time': '2017-07-15 10:58:01',
#   'local_end_time': '2017-07-15 13:42:20',
#   'drop': 0},
#  {'course_id': 'C_course-v1:TsinghuaX+400182X+sp',
#   'video_id': 'V_922af5607c2d46fc9e50300b95d33b58',
#   'watching_count': 1,
#   'video_duration': 636.0,
#   'local_watching_time': 637,
#   'video_progress_time': 636.0,
#   'video_start_time': 0.0,
#   'video_end_time': 636.0,
#   'local_start_time': '2017-07-15 13:42:29',
#   'local_end_time': '2017-07-15 13:53:06',
#   'drop': 0},
#  {'course_id': 'C_course-v1:TsinghuaX+400182X+sp',
#   'video_id': 'V_9799c75fdae4485b8e6cce82710b27e1',
#   'watching_count': 1,
#   'video_duration': 399.0,
#   'local_watching_time': 400,
#   'video_progress_time': 399.0,
#   'video_start_time': 0.0,
#   'video_end_time': 399.0,
#   'local_start_time': '2017-07-15 09:29:21',
#   'local_end_time': '2017-07-15 09:36:01',
#   'drop': 0},
#  {'course_id': 'C_course-v1:TsinghuaX+00691153X+sp',
#   'video_id': 'V_99b57582cf4d4a92a7b1ab9744f496e8',
#   'watching_count': 1,
#   'video_duration': 929.0,
#   'local_watching_time': 930,
#   'video_progress_time': 929.0,
#   'video_start_time': 0.0,
#   'video_end_time': 929.0,
#   'local_start_time': '2017-07-13 08:09:23',
#   'local_end_time': '2017-07-13 08:24:53',
#   'drop': 0},
#  {'course_id': 'C_course-v1:TsinghuaX+00691153X+sp',
#   'video_id': 'V_a687a87739224c478f4f5e7f5109f1d2',
#   'watching_count': 1,
#   'video_duration': 662.0,
#   'local_watching_time': 507,
#   'video_progress_time': 505.7900085449219,
#   'video_start_time': 0.0,
#   'video_end_time': 505.7900085449219,
#   'local_start_time': '2017-07-06 09:51:21',
#   'local_end_time': '2017-07-06 09:59:48',
#   'drop': 0},
#  {'course_id': 'C_course-v1:TsinghuaX+20430064X+sp',
#   'video_id': 'V_a8407c2dc8ab4f07bad87467b10b4571',
#   'watching_count': 1,
#   'video_duration': 279.0,
#   'local_watching_time': 279,
#   'video_progress_time': 279.0,
#   'video_start_time': 0.0,
#   'video_end_time': 279.0,
#   'local_start_time': '2017-07-24 12:47:49',
#   'local_end_time': '2017-07-24 12:52:28',
#   'drop': 0},
#  {'course_id': 'C_course-v1:TsinghuaX+400182X+sp',
#   'video_id': 'V_a977526a9e0644a0a07a7fc45651a898',
#   'watching_count': 1,
#   'video_duration': 392.0,
#   'local_watching_time': 393,
#   'video_progress_time': 392.0,
#   'video_start_time': 0.0,
#   'video_end_time': 392.0,
#   'local_start_time': '2017-07-15 09:48:27',
#   'local_end_time': '2017-07-15 09:55:00',
#   'drop': 0},
#  {'course_id': 'C_course-v1:TsinghuaX+20430064X+sp',
#   'video_id': 'V_ac0255b7307b4d06a62bb73a3614fd03',
#   'watching_count': 1,
#   'video_duration': 896.0,
#   'local_watching_time': 93,
#   'video_progress_time': 92.20999908447266,
#   'video_start_time': 0.0,
#   'video_end_time': 92.20999908447266,
#   'local_start_time': '2017-07-24 14:13:44',
#   'local_end_time': '2017-07-24 14:15:17',
#   'drop': 0},
#  {'course_id': 'C_course-v1:TsinghuaX+20430064X+sp',
#   'video_id': 'V_ae3956ffc939458dbf29c59d51e742b3',
#   'watching_count': 1,
#   'video_duration': 207.0,
#   'local_watching_time': 208,
#   'video_progress_time': 207.0,
#   'video_start_time': 0.0,
#   'video_end_time': 207.0,
#   'local_start_time': '2017-07-24 13:20:36',
#   'local_end_time': '2017-07-24 13:24:04',
#   'drop': 0},
#  {'course_id': 'C_course-v1:TsinghuaX+20430064X+sp',
#   'video_id': 'V_b576e9cb159846368cc7a960369acd44',
#   'watching_count': 1,
#   'video_duration': 340.0,
#   'local_watching_time': 340,
#   'video_progress_time': 339.9900000002235,
#   'video_start_time': 0.009999999776482001,
#   'video_end_time': 340.0,
#   'local_start_time': '2017-07-24 13:52:12',
#   'local_end_time': '2017-07-24 13:57:52',
#   'drop': 0},
#  {'course_id': 'C_course-v1:TsinghuaX+20430064X+sp',
#   'video_id': 'V_bd0128cb7dd2477487a687b6943e6a97',
#   'watching_count': 1,
#   'video_duration': 368.0,
#   'local_watching_time': 369,
#   'video_progress_time': 367.99000000022346,
#   'video_start_time': 0.009999999776482001,
#   'video_end_time': 368.0,
#   'local_start_time': '2017-07-24 12:37:44',
#   'local_end_time': '2017-07-24 12:43:53',
#   'drop': 1},
#  {'course_id': 'C_course-v1:TsinghuaX+400182X+sp',
#   'video_id': 'V_c165c1d75ad7476cad1198302f92de3a',
#   'watching_count': 1,
#   'video_duration': 673.0,
#   'local_watching_time': 664,
#   'video_progress_time': 651.0399780273438,
#   'video_start_time': 0.0,
#   'video_end_time': 651.0399780273438,
#   'local_start_time': '2017-07-15 13:53:13',
#   'local_end_time': '2017-07-15 14:04:17',
#   'drop': 0},
#  {'course_id': 'C_course-v1:TsinghuaX+400182X+sp',
#   'video_id': 'V_c2108cc1e2344761b1d38646025d852e',
#   'watching_count': 1,
#   'video_duration': 1094.0,
#   'local_watching_time': 1095,
#   'video_progress_time': 1094.0,
#   'video_start_time': 0.0,
#   'video_end_time': 1094.0,
#   'local_start_time': '2017-07-15 10:05:54',
#   'local_end_time': '2017-07-15 10:24:09',
#   'drop': 0},
#  {'course_id': 'C_course-v1:TsinghuaX+400182X+sp',
#   'video_id': 'V_d1bce1cb624e45ae91dbfe9c03cd4a6d',
#   'watching_count': 1,
#   'video_duration': 612.0,
#   'local_watching_time': 607,
#   'video_progress_time': 607.1900024414062,
#   'video_start_time': 0.0,
#   'video_end_time': 607.1900024414062,
#   'local_start_time': '2017-07-15 14:22:57',
#   'local_end_time': '2017-07-15 14:33:04',
#   'drop': 0},
#  {'course_id': 'C_course-v1:TsinghuaX+400182X+sp',
#   'video_id': 'V_d493e77bdee54a99bc9e1fcf94a422ba',
#   'watching_count': 1,
#   'video_duration': 1097.0,
#   'local_watching_time': 1098,
#   'video_progress_time': 1097.0,
#   'video_start_time': 0.0,
#   'video_end_time': 1097.0,
#   'local_start_time': '2017-07-15 14:04:30',
#   'local_end_time': '2017-07-15 14:22:48',
#   'drop': 0},
#  {'course_id': 'C_course-v1:TsinghuaX+400182X+sp',
#   'video_id': 'V_dcc1ea27e7714ccab9fedd387093acb4',
#   'watching_count': 1,
#   'video_duration': 569.0,
#   'local_watching_time': 569,
#   'video_progress_time': 568.5,
#   'video_start_time': 0.0,
#   'video_end_time': 568.5,
#   'local_start_time': '2017-07-15 09:56:17',
#   'local_end_time': '2017-07-15 10:05:46',
#   'drop': 0},
#  {'course_id': 'C_course-v1:TsinghuaX+00691153X+sp',
#   'video_id': 'V_e23ef91e861a49ffae35e59517fb1742',
#   'watching_count': 2,
#   'video_duration': 478.0,
#   'local_watching_time': 479,
#   'video_progress_time': 477.8300018310547,
#   'video_start_time': 0.0,
#   'video_end_time': 478.0,
#   'local_start_time': '2017-07-13 07:51:35',
#   'local_end_time': '2017-07-13 08:09:02',
#   'drop': 1},
#  {'course_id': 'C_course-v1:TsinghuaX+400182X+sp',
#   'video_id': 'V_e6ab3fa789a8442d83b8aedae64cb2e3',
#   'watching_count': 2,
#   'video_duration': 1137.0,
#   'local_watching_time': 1138,
#   'video_progress_time': 1136.8399658203127,
#   'video_start_time': 0.0,
#   'video_end_time': 1137.0,
#   'local_start_time': '2017-07-15 10:38:48',
#   'local_end_time': '2017-07-15 10:57:50',
#   'drop': 0},
#  {'course_id': 'C_course-v1:TsinghuaX+400182X+sp',
#   'video_id': 'V_e862906eb36d4839b2514c61b4f4a368',
#   'watching_count': 1,
#   'video_duration': 850.0,
#   'local_watching_time': 851,
#   'video_progress_time': 850.0,
#   'video_start_time': 0.0,
#   'video_end_time': 850.0,
#   'local_start_time': '2017-07-15 10:24:25',
#   'local_end_time': '2017-07-15 10:38:36',
#   'drop': 0},
#  {'course_id': 'C_course-v1:TsinghuaX+400182X+sp',
#   'video_id': 'V_e997726d382f4d77b741e157715ac652',
#   'watching_count': 2,
#   'video_duration': 381.0,
#   'local_watching_time': 249,
#   'video_progress_time': 248.75999450683602,
#   'video_start_time': 0.0,
#   'video_end_time': 248.92999267578125,
#   'local_start_time': '2017-07-15 09:36:14',
#   'local_end_time': '2017-07-15 09:48:14',
#   'drop': 1},
#  {'course_id': 'C_course-v1:TsinghuaX+10421075X_2015_2+sp',
#   'video_id': 'V_fb94cb32620149ac95d5d0b8ecb47aaf',
#   'watching_count': 1,
#   'video_duration': 194.0,
#   'local_watching_time': 195,
#   'video_progress_time': 194.0,
#   'video_start_time': 0.0,
#   'video_end_time': 194.0,
#   'local_start_time': '2017-07-09 10:09:40',
#   'local_end_time': '2017-07-09 10:12:55',
#   'drop': 1}]

# %%
df.iloc[0, 1][0]
# Out:
# {'course_id': 'C_course-v1:TsinghuaX+20430064X+sp',
#  'video_id': 'V_05f095f52ac6446ba05b883171c66713',
#  'watching_count': 1,
#  'video_duration': 563.0,
#  'local_watching_time': 563,
#  'video_progress_time': 563.0,
#  'video_start_time': 0.0,
#  'video_end_time': 563.0,
#  'local_start_time': '2017-07-24 13:26:56',
#  'local_end_time': '2017-07-24 13:36:19',
#  'drop': 0}

# %%
act_4 = pd.DataFrame()

for i in range(len(df)):
    if i % 500 == 1:
        print('*' * 10)
        print(i)
    course_id = []
    video_id = []
    watching_count = []
    video_duration = []
    local_watching_time = []
    video_progress_time = []
    video_start_time = []
    video_end_time = []
    local_start_time = []
    local_end_time = []
    drop = []
    for j in df.iloc[i, 1]:
        course_id.append(j['course_id'].split(':')[1])
        video_id.append(j['video_id'])
        watching_count.append(j['watching_count'])
        video_duration.append(j['video_duration'])
        local_watching_time.append(j['local_watching_time'])
        video_progress_time.append(j['video_progress_time'])
        video_start_time.append(j['video_start_time'])
        video_end_time.append(j['video_end_time'])
        local_start_time.append(j['local_start_time'])
        local_end_time.append(j['local_end_time'])
        drop.append(j['drop'])
    tmp = pd.DataFrame({'item_id': df.iloc[i, 0],
                        'course_id': course_id,
                        'video_id': video_id,
                        'watching_count': watching_count,
                        'video_duration': video_duration,
                        'local_watching_time': local_watching_time,
                        'video_progress_time': video_progress_time,
                        'video_start_time': video_start_time,
                        'video_end_time': video_end_time,
                        'local_start_time': local_start_time,
                        'local_end_time': local_end_time,
                        'drop': drop})
    act_4 = pd.concat([act_4, tmp], ignore_index=False, axis=0)
    del tmp
    gc.collect()
# Out:
# **********
# 1
# **********
# 501
# **********
# 1001
# **********
# 1501
# **********
# 2001
# **********
# 2501
# **********
# 3001
# **********
# 3501
# **********
# 4001
# **********
# 4501
# **********
# 5001

# %%
act_4.head().append(act_4.tail())

# %%
act_4.shape

# %%
act_4.to_csv('../../input/act_4.csv', index=False)
act_4.to_hdf('../../input/act_4.h5', 'df', index=False)
