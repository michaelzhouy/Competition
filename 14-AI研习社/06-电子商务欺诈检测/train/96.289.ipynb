# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import lightgbm as lgb
import gc
import warnings
warnings.filterwarnings('ignore')
pd.set_option('max_columns', None)
pd.set_option('max_rows', None)

# %%
train_transaction = pd.read_csv('../input/train_transaction.csv')
test_transaction = pd.read_csv('../input/test_transaction.csv')
train_identity = pd.read_csv('../input/train_identity.csv')
test_identity = pd.read_csv('../input/test_identity.csv')

# %%
train = train_transaction.merge(train_identity, on='TransactionID', how='left')
test = test_transaction.merge(test_identity, on='TransactionID', how='left')
data = pd.concat([train, test], axis=0, ignore_index=True)
del train, test
gc.collect()
# Out:
# 125

# %%
object_cols = ['ProductCD', 'card4', 'card6', 'DeviceType', 'DeviceInfo', 'P_emaildomain', 'R_emaildomain']
M_cols = ['M{}'.format(i) for i in range(1, 10)]
id_cols = ['id_12', 'id_16', 'id_27', 'id_28', 'id_29', 'id_35', 'id_36', 'id_37', 'id_38', 'id_15',
           'id_23', 'id_34', 'id_30', 'id_31', 'id_33']
cat_cols = object_cols + M_cols + id_cols

# %%
for i in cat_cols:
    le = LabelEncoder()
    data[i] = le.fit_transform(data[i].astype(str))

# %%
train = data[data['isFraud'].notnull()]
test = data[data['isFraud'].isnull()]

y = train['isFraud']
train.drop(['isFraud', 'TransactionID'], axis=1, inplace=True)
test.drop(['isFraud', 'TransactionID'], axis=1, inplace=True)
used_cols = train.columns
test = test[used_cols]

X_train, X_valid, y_train, y_valid = train_test_split(train, y, random_state=2020)

# %%
def auc_select(X_train, y_train, X_valid, y_valid, cols, threshold=0.52):
    """
    基于AUC的单特征筛选
    @param X_train:
    @param y_train:
    @param X_valid:
    @param y_valid:
    @param cols:
    @param threshold:
    @return:
    """
    useful_dict = dict()
    useless_dict = dict()
    params = {
        'objective': 'binary',
        'boosting': 'gbdt',
        'metric': 'auc',
        'learning_rate': 0.1,
        'num_leaves': 31,
        'lambda_l1': 0,
        'lambda_l2': 1,
        'num_threads': 23,
        'min_data_in_leaf': 20,
        'first_metric_only': True,
        'is_unbalance': True,
        'max_depth': -1,
        'seed': 2020
    }
    for i in cols:
        print(i)
        try:
            lgb_train = lgb.Dataset(X_train[[i]].values, y_train)
            lgb_valid = lgb.Dataset(X_valid[[i]].values, y_valid, reference=lgb_train)
            lgb_model = lgb.train(
                params,
                lgb_train,
                valid_sets=[lgb_valid, lgb_train],
                num_boost_round=1000,
                early_stopping_rounds=50,
                verbose_eval=500
            )
            print('*' * 10)
            print(lgb_model.best_score['valid_0']['auc'])
            if lgb_model.best_score['valid_0']['auc'] > threshold:
                useful_dict[i] = lgb_model.best_score['valid_0']['auc']
            else:
                useless_dict[i] = lgb_model.best_score['valid_0']['auc']
        except:
            print('Error: ', i)
    useful_cols = list(useful_dict.keys())
    useless_cols = list(useless_dict.keys())
    return useful_dict, useless_dict, useful_cols, useless_cols


useful_dict, useless_dict, useful_cols, useless_cols = auc_select(X_train, y_train, X_valid, y_valid, used_cols, threshold=0.52)
# Out:
# TransactionDT
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [49]	training's auc: 0.595394	valid_0's auc: 0.576889
# Evaluated only: auc
# **********
# 0.5768888775675678
# TransactionAmt
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [141]	training's auc: 0.718328	valid_0's auc: 0.707581
# Evaluated only: auc
# **********
# 0.7075814699342213
# ProductCD
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.678102	valid_0's auc: 0.679011
# Evaluated only: auc
# **********
# 0.6790110038541265
# card1
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [191]	training's auc: 0.702453	valid_0's auc: 0.691196
# Evaluated only: auc
# **********
# 0.6911962587253155
# card2
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [82]	training's auc: 0.734264	valid_0's auc: 0.731876
# Evaluated only: auc
# **********
# 0.7318764547675676
# card3
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [28]	training's auc: 0.642112	valid_0's auc: 0.642262
# Evaluated only: auc
# **********
# 0.6422616916478823
# card4
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.508658	valid_0's auc: 0.507253
# Evaluated only: auc
# **********
# 0.5072533302151658
# card5
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [7]	training's auc: 0.648161	valid_0's auc: 0.645991
# Evaluated only: auc
# **********
# 0.6459905160123429
# card6
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.621337	valid_0's auc: 0.616249
# Evaluated only: auc
# **********
# 0.6162488905966955
# addr1
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [63]	training's auc: 0.687184	valid_0's auc: 0.691244
# Evaluated only: auc
# **********
# 0.691244054752875
# addr2
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [215]	training's auc: 0.643782	valid_0's auc: 0.646648
# Evaluated only: auc
# **********
# 0.6466481939051543
# dist1
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [135]	training's auc: 0.616977	valid_0's auc: 0.610271
# Evaluated only: auc
# **********
# 0.6102706607243099
# dist2
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [76]	training's auc: 0.567939	valid_0's auc: 0.56756
# Evaluated only: auc
# **********
# 0.5675598311715302
# P_emaildomain
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [11]	training's auc: 0.601377	valid_0's auc: 0.603689
# Evaluated only: auc
# **********
# 0.6036888749314964
# R_emaildomain
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [71]	training's auc: 0.68412	valid_0's auc: 0.683033
# Evaluated only: auc
# **********
# 0.6830332467826691
# C1
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [20]	training's auc: 0.634434	valid_0's auc: 0.638824
# Evaluated only: auc
# **********
# 0.6388236079999672
# C2
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [87]	training's auc: 0.640854	valid_0's auc: 0.645559
# Evaluated only: auc
# **********
# 0.6455594264238569
# C3
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.502077	valid_0's auc: 0.50208
# Evaluated only: auc
# **********
# 0.5020803042402431
# C4
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [4]	training's auc: 0.688007	valid_0's auc: 0.688892
# Evaluated only: auc
# **********
# 0.6888916993755195
# C5
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	training's auc: 0.648042	valid_0's auc: 0.644861
# Evaluated only: auc
# **********
# 0.644860519705245
# C6
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [64]	training's auc: 0.602155	valid_0's auc: 0.602891
# Evaluated only: auc
# **********
# 0.6028911802866808
# C7
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [3]	training's auc: 0.646911	valid_0's auc: 0.649893
# Evaluated only: auc
# **********
# 0.6498925054138944
# C8
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	training's auc: 0.682772	valid_0's auc: 0.685465
# Evaluated only: auc
# **********
# 0.6854650247784971
# C9
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [28]	training's auc: 0.663919	valid_0's auc: 0.667501
# Evaluated only: auc
# **********
# 0.6675009258365425
# C10
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	training's auc: 0.67846	valid_0's auc: 0.67898
# Evaluated only: auc
# **********
# 0.6789799005087733
# C11
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [36]	training's auc: 0.624946	valid_0's auc: 0.621518
# Evaluated only: auc
# **********
# 0.6215180548491479
# C12
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	training's auc: 0.663847	valid_0's auc: 0.666661
# Evaluated only: auc
# **********
# 0.6666614843423779
# C13
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [79]	training's auc: 0.654745	valid_0's auc: 0.64547
# Evaluated only: auc
# **********
# 0.6454702845974377
# C14
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [21]	training's auc: 0.633945	valid_0's auc: 0.633872
# Evaluated only: auc
# **********
# 0.6338722626828901
# D1
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [48]	training's auc: 0.642822	valid_0's auc: 0.639537
# Evaluated only: auc
# **********
# 0.6395373870075496
# D2
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [37]	training's auc: 0.651224	valid_0's auc: 0.648055
# Evaluated only: auc
# **********
# 0.6480546059066403
# D3
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [50]	training's auc: 0.646874	valid_0's auc: 0.645922
# Evaluated only: auc
# **********
# 0.6459217577859122
# D4
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [28]	training's auc: 0.617948	valid_0's auc: 0.608121
# Evaluated only: auc
# **********
# 0.6081211157437665
# D5
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [26]	training's auc: 0.674758	valid_0's auc: 0.673322
# Evaluated only: auc
# **********
# 0.6733218760310535
# D6
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [12]	training's auc: 0.637802	valid_0's auc: 0.636594
# Evaluated only: auc
# **********
# 0.6365939030529164
# D7
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [4]	training's auc: 0.615524	valid_0's auc: 0.61073
# Evaluated only: auc
# **********
# 0.6107304525772261
# D8
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [84]	training's auc: 0.648128	valid_0's auc: 0.645496
# Evaluated only: auc
# **********
# 0.6454962661938365
# D9
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [15]	training's auc: 0.634993	valid_0's auc: 0.634913
# Evaluated only: auc
# **********
# 0.6349133030671809
# D10
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [3]	training's auc: 0.641811	valid_0's auc: 0.641027
# Evaluated only: auc
# **********
# 0.6410265438712733
# D11
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [11]	training's auc: 0.651015	valid_0's auc: 0.647642
# Evaluated only: auc
# **********
# 0.6476419406193993
# D12
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [51]	training's auc: 0.640092	valid_0's auc: 0.639659
# Evaluated only: auc
# **********
# 0.6396593867752118
# D13
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [14]	training's auc: 0.622811	valid_0's auc: 0.625083
# Evaluated only: auc
# **********
# 0.6250832391256335
# D14
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [33]	training's auc: 0.632946	valid_0's auc: 0.6327
# Evaluated only: auc
# **********
# 0.6327002949799455
# D15
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [19]	training's auc: 0.648593	valid_0's auc: 0.638329
# Evaluated only: auc
# **********
# 0.6383292004767112
# M1
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.621833	valid_0's auc: 0.621232
# Evaluated only: auc
# **********
# 0.6212320108098146
# M2
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.628238	valid_0's auc: 0.629067
# Evaluated only: auc
# **********
# 0.6290672193309511
# M3
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.630694	valid_0's auc: 0.631031
# Evaluated only: auc
# **********
# 0.6310310842014588
# M4
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.669566	valid_0's auc: 0.671165
# Evaluated only: auc
# **********
# 0.6711648071762304
# M5
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.527762	valid_0's auc: 0.52686
# Evaluated only: auc
# **********
# 0.5268599387460131
# M6
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.663356	valid_0's auc: 0.664149
# Evaluated only: auc
# **********
# 0.6641494419398111
# M7
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.59549	valid_0's auc: 0.592708
# Evaluated only: auc
# **********
# 0.5927078524839798
# M8
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.597551	valid_0's auc: 0.595579
# Evaluated only: auc
# **********
# 0.5955787107904086
# M9
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.598679	valid_0's auc: 0.596015
# Evaluated only: auc
# **********
# 0.5960153513772006
# V1
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	training's auc: 0.620778	valid_0's auc: 0.62071
# Evaluated only: auc
# **********
# 0.6207102430791036
# V2
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [18]	training's auc: 0.622638	valid_0's auc: 0.622919
# Evaluated only: auc
# **********
# 0.6229187894796477
# V3
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [15]	training's auc: 0.627777	valid_0's auc: 0.628761
# Evaluated only: auc
# **********
# 0.628761473686341
# V4
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	training's auc: 0.623994	valid_0's auc: 0.62384
# Evaluated only: auc
# **********
# 0.623840382615535
# V5
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [55]	training's auc: 0.627765	valid_0's auc: 0.629627
# Evaluated only: auc
# **********
# 0.629626557346152
# V6
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [7]	training's auc: 0.622124	valid_0's auc: 0.622438
# Evaluated only: auc
# **********
# 0.6224382453527256
# V7
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	training's auc: 0.623689	valid_0's auc: 0.624196
# Evaluated only: auc
# **********
# 0.62419564546272
# V8
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [9]	training's auc: 0.621997	valid_0's auc: 0.621912
# Evaluated only: auc
# **********
# 0.6219116932150079
# V9
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [8]	training's auc: 0.624865	valid_0's auc: 0.624969
# Evaluated only: auc
# **********
# 0.6249687151897445
# V10
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [4]	training's auc: 0.643366	valid_0's auc: 0.641798
# Evaluated only: auc
# **********
# 0.641797739940544
# V11
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.643438	valid_0's auc: 0.641815
# Evaluated only: auc
# **********
# 0.6418145631730396
# V12
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.604513	valid_0's auc: 0.604119
# Evaluated only: auc
# **********
# 0.6041192104615106
# V13
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.61122	valid_0's auc: 0.608426
# Evaluated only: auc
# **********
# 0.6084262817450914
# V14
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.530896	valid_0's auc: 0.528822
# Evaluated only: auc
# **********
# 0.5288223278760492
# V15
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [49]	training's auc: 0.672817	valid_0's auc: 0.672541
# Evaluated only: auc
# **********
# 0.6725407800722357
# V16
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [9]	training's auc: 0.672831	valid_0's auc: 0.672503
# Evaluated only: auc
# **********
# 0.6725030092625013
# V17
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [35]	training's auc: 0.669121	valid_0's auc: 0.669032
# Evaluated only: auc
# **********
# 0.6690320467852968
# V18
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [6]	training's auc: 0.669279	valid_0's auc: 0.669066
# Evaluated only: auc
# **********
# 0.6690662572275382
# V19
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	training's auc: 0.555622	valid_0's auc: 0.552611
# Evaluated only: auc
# **********
# 0.5526110313762164
# V20
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [12]	training's auc: 0.560508	valid_0's auc: 0.558856
# Evaluated only: auc
# **********
# 0.558855697678867
# V21
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.666724	valid_0's auc: 0.666967
# Evaluated only: auc
# **********
# 0.6669670461721804
# V22
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	training's auc: 0.667071	valid_0's auc: 0.667156
# Evaluated only: auc
# **********
# 0.667156137300178
# V23
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [22]	training's auc: 0.573648	valid_0's auc: 0.568047
# Evaluated only: auc
# **********
# 0.5680468579036236
# V24
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [13]	training's auc: 0.572167	valid_0's auc: 0.56676
# Evaluated only: auc
# **********
# 0.5667603975968595
# V25
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	training's auc: 0.536739	valid_0's auc: 0.535593
# Evaluated only: auc
# **********
# 0.5355925008696999
# V26
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [45]	training's auc: 0.540855	valid_0's auc: 0.538488
# Evaluated only: auc
# **********
# 0.5384878451884119
# V27
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.531101	valid_0's auc: 0.529055
# Evaluated only: auc
# **********
# 0.529055279723682
# V28
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.531105	valid_0's auc: 0.529055
# Evaluated only: auc
# **********
# 0.529055279723682
# V29
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [7]	training's auc: 0.639063	valid_0's auc: 0.637105
# Evaluated only: auc
# **********
# 0.637105017880011
# V30
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.63958	valid_0's auc: 0.637141
# Evaluated only: auc
# **********
# 0.6371411604665358
# V31
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	training's auc: 0.668922	valid_0's auc: 0.668883
# Evaluated only: auc
# **********
# 0.6688830513065875
# V32
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [26]	training's auc: 0.668915	valid_0's auc: 0.668912
# Evaluated only: auc
# **********
# 0.6689119718511017
# V33
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [20]	training's auc: 0.680044	valid_0's auc: 0.682395
# Evaluated only: auc
# **********
# 0.6823953143600315
# V34
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [5]	training's auc: 0.683652	valid_0's auc: 0.683961
# Evaluated only: auc
# **********
# 0.6839610990216322
# V35
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.60142	valid_0's auc: 0.597681
# Evaluated only: auc
# **********
# 0.5976812399119222
# V36
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.607529	valid_0's auc: 0.601889
# Evaluated only: auc
# **********
# 0.6018890981975569
# V37
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [3]	training's auc: 0.597157	valid_0's auc: 0.591621
# Evaluated only: auc
# **********
# 0.5916208510869977
# V38
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [30]	training's auc: 0.619162	valid_0's auc: 0.611992
# Evaluated only: auc
# **********
# 0.611991906759354
# V39
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [28]	training's auc: 0.669005	valid_0's auc: 0.666564
# Evaluated only: auc
# **********
# 0.6665640280291263
# V40
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [12]	training's auc: 0.670736	valid_0's auc: 0.667942
# Evaluated only: auc
# **********
# 0.6679418150519533
# V41
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.50498	valid_0's auc: 0.502362
# Evaluated only: auc
# **********
# 0.5023619304577825
# V42
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [9]	training's auc: 0.664741	valid_0's auc: 0.662663
# Evaluated only: auc
# **********
# 0.6626625587399277
# V43
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.666559	valid_0's auc: 0.664023
# Evaluated only: auc
# **********
# 0.6640228687344099
# V44
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [52]	training's auc: 0.615016	valid_0's auc: 0.611611
# Evaluated only: auc
# **********
# 0.6116107792888295
# V45
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [119]	training's auc: 0.629043	valid_0's auc: 0.621349
# Evaluated only: auc
# **********
# 0.6213493097226556
# V46
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [10]	training's auc: 0.542348	valid_0's auc: 0.536921
# Evaluated only: auc
# **********
# 0.5369207487575033
# V47
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [4]	training's auc: 0.565845	valid_0's auc: 0.555642
# Evaluated only: auc
# **********
# 0.555641766789078
# V48
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.642606	valid_0's auc: 0.643084
# Evaluated only: auc
# **********
# 0.6430841219171346
# V49
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.64336	valid_0's auc: 0.643815
# Evaluated only: auc
# **********
# 0.6438154406172009
# V50
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.670126	valid_0's auc: 0.667394
# Evaluated only: auc
# **********
# 0.6673942871381343
# V51
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [30]	training's auc: 0.680543	valid_0's auc: 0.679374
# Evaluated only: auc
# **********
# 0.6793737320890617
# V52
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [40]	training's auc: 0.683905	valid_0's auc: 0.681846
# Evaluated only: auc
# **********
# 0.6818457634389278
# V53
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [19]	training's auc: 0.617738	valid_0's auc: 0.617953
# Evaluated only: auc
# **********
# 0.6179531630053107
# V54
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	training's auc: 0.624846	valid_0's auc: 0.623521
# Evaluated only: auc
# **********
# 0.62352062422506
# V55
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	training's auc: 0.57658	valid_0's auc: 0.58053
# Evaluated only: auc
# **********
# 0.5805299878035742
# V56
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [4]	training's auc: 0.592213	valid_0's auc: 0.595409
# Evaluated only: auc
# **********
# 0.5954086486725965
# V57
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.669168	valid_0's auc: 0.669989
# Evaluated only: auc
# **********
# 0.6699891924204006
# V58
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [6]	training's auc: 0.670731	valid_0's auc: 0.671003
# Evaluated only: auc
# **********
# 0.6710026135854621
# V59
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [9]	training's auc: 0.66326	valid_0's auc: 0.664221
# Evaluated only: auc
# **********
# 0.6642205699150953
# V60
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [18]	training's auc: 0.665121	valid_0's auc: 0.665658
# Evaluated only: auc
# **********
# 0.6656575432171328
# V61
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [4]	training's auc: 0.582303	valid_0's auc: 0.584792
# Evaluated only: auc
# **********
# 0.5847922667606545
# V62
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [5]	training's auc: 0.595717	valid_0's auc: 0.598351
# Evaluated only: auc
# **********
# 0.5983511310454093
# V63
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [18]	training's auc: 0.661365	valid_0's auc: 0.663028
# Evaluated only: auc
# **********
# 0.6630282248785759
# V64
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [22]	training's auc: 0.663165	valid_0's auc: 0.664412
# Evaluated only: auc
# **********
# 0.6644122584716511
# V65
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.545021	valid_0's auc: 0.544096
# Evaluated only: auc
# **********
# 0.5440963629075797
# V66
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	training's auc: 0.569323	valid_0's auc: 0.569923
# Evaluated only: auc
# **********
# 0.569922636838453
# V67
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [5]	training's auc: 0.587732	valid_0's auc: 0.58618
# Evaluated only: auc
# **********
# 0.5861798262559462
# V68
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.545124	valid_0's auc: 0.544179
# Evaluated only: auc
# **********
# 0.5441790545052994
# V69
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [18]	training's auc: 0.648898	valid_0's auc: 0.646846
# Evaluated only: auc
# **********
# 0.6468458982190465
# V70
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [5]	training's auc: 0.650024	valid_0's auc: 0.647008
# Evaluated only: auc
# **********
# 0.6470082683138061
# V71
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [12]	training's auc: 0.66372	valid_0's auc: 0.664957
# Evaluated only: auc
# **********
# 0.6649573027967642
# V72
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [12]	training's auc: 0.66536	valid_0's auc: 0.666031
# Evaluated only: auc
# **********
# 0.6660306298342316
# V73
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	training's auc: 0.676029	valid_0's auc: 0.678028
# Evaluated only: auc
# **********
# 0.6780281575668468
# V74
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [18]	training's auc: 0.682515	valid_0's auc: 0.68384
# Evaluated only: auc
# **********
# 0.6838395211925052
# V75
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.597107	valid_0's auc: 0.601463
# Evaluated only: auc
# **********
# 0.6014632222654291
# V76
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [4]	training's auc: 0.601943	valid_0's auc: 0.604673
# Evaluated only: auc
# **********
# 0.6046727363778267
# V77
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [34]	training's auc: 0.5998	valid_0's auc: 0.597226
# Evaluated only: auc
# **********
# 0.5972256298458766
# V78
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [3]	training's auc: 0.612896	valid_0's auc: 0.608182
# Evaluated only: auc
# **********
# 0.6081818581824269
# V79
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [33]	training's auc: 0.680891	valid_0's auc: 0.68099
# Evaluated only: auc
# **********
# 0.6809900094249998
# V80
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	training's auc: 0.671609	valid_0's auc: 0.672702
# Evaluated only: auc
# **********
# 0.6727018916622053
# V81
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [93]	training's auc: 0.672664	valid_0's auc: 0.674172
# Evaluated only: auc
# **********
# 0.6741723328364381
# V82
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	training's auc: 0.569268	valid_0's auc: 0.563234
# Evaluated only: auc
# **********
# 0.5632337152117292
# V83
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [18]	training's auc: 0.581116	valid_0's auc: 0.57647
# Evaluated only: auc
# **********
# 0.5764696878990628
# V84
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [4]	training's auc: 0.668991	valid_0's auc: 0.670488
# Evaluated only: auc
# **********
# 0.6704883248197312
# V85
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [5]	training's auc: 0.66998	valid_0's auc: 0.671848
# Evaluated only: auc
# **********
# 0.671847765871487
# V86
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [57]	training's auc: 0.622817	valid_0's auc: 0.619616
# Evaluated only: auc
# **********
# 0.6196156436552773
# V87
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [22]	training's auc: 0.631923	valid_0's auc: 0.626658
# Evaluated only: auc
# **********
# 0.6266577779674413
# V88
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.529543	valid_0's auc: 0.526436
# Evaluated only: auc
# **********
# 0.5264358226317867
# V89
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.529823	valid_0's auc: 0.526779
# Evaluated only: auc
# **********
# 0.5267794163719024
# V90
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [11]	training's auc: 0.638708	valid_0's auc: 0.637788
# Evaluated only: auc
# **********
# 0.6377875212158581
# V91
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	training's auc: 0.639681	valid_0's auc: 0.637946
# Evaluated only: auc
# **********
# 0.6379456928133099
# V92
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	training's auc: 0.676041	valid_0's auc: 0.676137
# Evaluated only: auc
# **********
# 0.676137208688387
# V93
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [91]	training's auc: 0.677012	valid_0's auc: 0.677181
# Evaluated only: auc
# **********
# 0.6771808997657541
# V94
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	training's auc: 0.687329	valid_0's auc: 0.687734
# Evaluated only: auc
# **********
# 0.6877344117915194
# V95
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [13]	training's auc: 0.587089	valid_0's auc: 0.584803
# Evaluated only: auc
# **********
# 0.584803214185724
# V96
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [61]	training's auc: 0.533638	valid_0's auc: 0.532807
# Evaluated only: auc
# **********
# 0.5328074255918442
# V97
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [15]	training's auc: 0.585477	valid_0's auc: 0.583541
# Evaluated only: auc
# **********
# 0.5835410717424703
# V98
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [48]	training's auc: 0.517107	valid_0's auc: 0.519017
# Evaluated only: auc
# **********
# 0.5190169964257315
# V99
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [6]	training's auc: 0.547608	valid_0's auc: 0.548948
# Evaluated only: auc
# **********
# 0.5489479490042998
# V100
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.521104	valid_0's auc: 0.518784
# Evaluated only: auc
# **********
# 0.5187835662418383
# V101
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [8]	training's auc: 0.573983	valid_0's auc: 0.573142
# Evaluated only: auc
# **********
# 0.5731420393519722
# V102
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [15]	training's auc: 0.591862	valid_0's auc: 0.594839
# Evaluated only: auc
# **********
# 0.594839246796685
# V103
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [7]	training's auc: 0.586457	valid_0's auc: 0.588778
# Evaluated only: auc
# **********
# 0.5887775482912571
# V104
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [26]	training's auc: 0.512192	valid_0's auc: 0.51337
# Evaluated only: auc
# **********
# 0.5133703256455819
# V105
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	training's auc: 0.518369	valid_0's auc: 0.517994
# Evaluated only: auc
# **********
# 0.5179943458774093
# V106
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [13]	training's auc: 0.51686	valid_0's auc: 0.518139
# Evaluated only: auc
# **********
# 0.5181393287624231
# V107
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	training's auc: 0.500278	valid_0's auc: 0.500639
# Evaluated only: auc
# **********
# 0.5006388577630889
# V108
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [33]	training's auc: 0.516079	valid_0's auc: 0.518371
# Evaluated only: auc
# **********
# 0.518371092080221
# V109
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [4]	training's auc: 0.515844	valid_0's auc: 0.518887
# Evaluated only: auc
# **********
# 0.5188871208202093
# V110
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [24]	training's auc: 0.516073	valid_0's auc: 0.519146
# Evaluated only: auc
# **********
# 0.5191463999614072
# V111
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	training's auc: 0.516982	valid_0's auc: 0.519593
# Evaluated only: auc
# **********
# 0.5195934020635697
# V112
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	training's auc: 0.517688	valid_0's auc: 0.520571
# Evaluated only: auc
# **********
# 0.5205712028432642
# V113
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	training's auc: 0.516918	valid_0's auc: 0.519993
# Evaluated only: auc
# **********
# 0.5199931104956866
# V114
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [4]	training's auc: 0.520781	valid_0's auc: 0.523119
# Evaluated only: auc
# **********
# 0.5231193867879536
# V115
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.520706	valid_0's auc: 0.524275
# Evaluated only: auc
# **********
# 0.5242753291817714
# V116
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	training's auc: 0.521293	valid_0's auc: 0.525565
# Evaluated only: auc
# **********
# 0.5255648662977566
# V117
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	training's auc: 0.504712	valid_0's auc: 0.506218
# Evaluated only: auc
# **********
# 0.5062183316982692
# V118
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	training's auc: 0.504391	valid_0's auc: 0.506028
# Evaluated only: auc
# **********
# 0.506028059351253
# V119
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	training's auc: 0.504692	valid_0's auc: 0.506282
# Evaluated only: auc
# **********
# 0.5062815754804749
# V120
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [3]	training's auc: 0.50216	valid_0's auc: 0.502839
# Evaluated only: auc
# **********
# 0.5028393633102073
# V121
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [19]	training's auc: 0.502306	valid_0's auc: 0.502991
# Evaluated only: auc
# **********
# 0.5029912402949045
# V122
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [3]	training's auc: 0.502365	valid_0's auc: 0.50326
# Evaluated only: auc
# **********
# 0.5032599190569407
# V123
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [6]	training's auc: 0.540762	valid_0's auc: 0.539373
# Evaluated only: auc
# **********
# 0.539373370934741
# V124
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [75]	training's auc: 0.534274	valid_0's auc: 0.532663
# Evaluated only: auc
# **********
# 0.532663106946703
# V125
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [15]	training's auc: 0.540175	valid_0's auc: 0.539259
# Evaluated only: auc
# **********
# 0.539259333690331
# V126
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [188]	training's auc: 0.591778	valid_0's auc: 0.586743
# Evaluated only: auc
# **********
# 0.5867432917490975
# V127
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [8]	training's auc: 0.576461	valid_0's auc: 0.570615
# Evaluated only: auc
# **********
# 0.57061468496706
# V128
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [36]	training's auc: 0.59857	valid_0's auc: 0.591533
# Evaluated only: auc
# **********
# 0.5915331192037042
# V129
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [15]	training's auc: 0.52436	valid_0's auc: 0.523553
# Evaluated only: auc
# **********
# 0.5235525568258517
# V130
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [23]	training's auc: 0.573856	valid_0's auc: 0.567428
# Evaluated only: auc
# **********
# 0.5674282281245784
# V131
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [132]	training's auc: 0.551178	valid_0's auc: 0.543332
# Evaluated only: auc
# **********
# 0.5433322165539375
# V132
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [88]	training's auc: 0.57554	valid_0's auc: 0.573072
# Evaluated only: auc
# **********
# 0.5730715881493883
# V133
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [48]	training's auc: 0.593923	valid_0's auc: 0.595306
# Evaluated only: auc
# **********
# 0.595305979747389
# V134
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [67]	training's auc: 0.58806	valid_0's auc: 0.589538
# Evaluated only: auc
# **********
# 0.5895381499434409
# V135
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [37]	training's auc: 0.521983	valid_0's auc: 0.517649
# Evaluated only: auc
# **********
# 0.5176494445455948
# V136
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [181]	training's auc: 0.53347	valid_0's auc: 0.528959
# Evaluated only: auc
# **********
# 0.528958719507617
# V137
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [44]	training's auc: 0.527085	valid_0's auc: 0.526742
# Evaluated only: auc
# **********
# 0.5267422335606715
# V138
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [26]	training's auc: 0.519947	valid_0's auc: 0.517568
# Evaluated only: auc
# **********
# 0.5175681232037129
# V139
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	training's auc: 0.537349	valid_0's auc: 0.536608
# Evaluated only: auc
# **********
# 0.5366075774124313
# V140
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [23]	training's auc: 0.544473	valid_0's auc: 0.542652
# Evaluated only: auc
# **********
# 0.54265175189141
# V141
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	training's auc: 0.520183	valid_0's auc: 0.517844
# Evaluated only: auc
# **********
# 0.517843515383832
# V142
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [6]	training's auc: 0.520195	valid_0's auc: 0.517854
# Evaluated only: auc
# **********
# 0.5178540220711244
# V143
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [23]	training's auc: 0.535185	valid_0's auc: 0.533239
# Evaluated only: auc
# **********
# 0.5332394248547468
# V144
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [15]	training's auc: 0.534047	valid_0's auc: 0.531342
# Evaluated only: auc
# **********
# 0.5313421072109682
# V145
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.535032	valid_0's auc: 0.534327
# Evaluated only: auc
# **********
# 0.5343273244377201
# V146
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [16]	training's auc: 0.526059	valid_0's auc: 0.528684
# Evaluated only: auc
# **********
# 0.5286837440440216
# V147
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [22]	training's auc: 0.530064	valid_0's auc: 0.532285
# Evaluated only: auc
# **********
# 0.5322845643719091
# V148
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	training's auc: 0.526317	valid_0's auc: 0.524306
# Evaluated only: auc
# **********
# 0.5243064607259872
# V149
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [75]	training's auc: 0.529134	valid_0's auc: 0.530594
# Evaluated only: auc
# **********
# 0.5305942712882847
# V150
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [17]	training's auc: 0.543353	valid_0's auc: 0.539532
# Evaluated only: auc
# **********
# 0.5395320354900858
# V151
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	training's auc: 0.534316	valid_0's auc: 0.532564
# Evaluated only: auc
# **********
# 0.5325640662751391
# V152
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [87]	training's auc: 0.535044	valid_0's auc: 0.532889
# Evaluated only: auc
# **********
# 0.5328888806172225
# V153
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [6]	training's auc: 0.525905	valid_0's auc: 0.523867
# Evaluated only: auc
# **********
# 0.5238672070446022
# V154
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [3]	training's auc: 0.52625	valid_0's auc: 0.524386
# Evaluated only: auc
# **********
# 0.5243859219873456
# V155
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [48]	training's auc: 0.526419	valid_0's auc: 0.524269
# Evaluated only: auc
# **********
# 0.5242694533743454
# V156
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [84]	training's auc: 0.531228	valid_0's auc: 0.529004
# Evaluated only: auc
# **********
# 0.5290037426470291
# V157
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [57]	training's auc: 0.52924	valid_0's auc: 0.53092
# Evaluated only: auc
# **********
# 0.530919796868345
# V158
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [56]	training's auc: 0.53727	valid_0's auc: 0.537869
# Evaluated only: auc
# **********
# 0.5378692258533897
# V159
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [6]	training's auc: 0.534727	valid_0's auc: 0.530365
# Evaluated only: auc
# **********
# 0.5303649602271232
# V160
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [21]	training's auc: 0.537504	valid_0's auc: 0.533375
# Evaluated only: auc
# **********
# 0.5333747355299182
# V161
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [195]	training's auc: 0.520548	valid_0's auc: 0.518193
# Evaluated only: auc
# **********
# 0.5181927781397154
# V162
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [8]	training's auc: 0.520739	valid_0's auc: 0.518401
# Evaluated only: auc
# **********
# 0.518400949453612
# V163
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [268]	training's auc: 0.520751	valid_0's auc: 0.518319
# Evaluated only: auc
# **********
# 0.5183193127022309
# V164
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [3]	training's auc: 0.535167	valid_0's auc: 0.532497
# Evaluated only: auc
# **********
# 0.5324969007622393
# V165
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [13]	training's auc: 0.5383	valid_0's auc: 0.534502
# Evaluated only: auc
# **********
# 0.5345019704372943
# V166
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [22]	training's auc: 0.534492	valid_0's auc: 0.530983
# Evaluated only: auc
# **********
# 0.5309833508380384
# V167
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [8]	training's auc: 0.676949	valid_0's auc: 0.675445
# Evaluated only: auc
# **********
# 0.6754445454068163
# V168
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [47]	training's auc: 0.679211	valid_0's auc: 0.677568
# Evaluated only: auc
# **********
# 0.6775675834565963
# V169
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [13]	training's auc: 0.65647	valid_0's auc: 0.655294
# Evaluated only: auc
# **********
# 0.6552936956962363
# V170
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [8]	training's auc: 0.676646	valid_0's auc: 0.674779
# Evaluated only: auc
# **********
# 0.6747791065603995
# V171
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [27]	training's auc: 0.678145	valid_0's auc: 0.6766
# Evaluated only: auc
# **********
# 0.6766001045049844
# V172
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [62]	training's auc: 0.655123	valid_0's auc: 0.65386
# Evaluated only: auc
# **********
# 0.6538595099039783
# V173
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [20]	training's auc: 0.654932	valid_0's auc: 0.654957
# Evaluated only: auc
# **********
# 0.6549569835229764
# V174
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [12]	training's auc: 0.65641	valid_0's auc: 0.655114
# Evaluated only: auc
# **********
# 0.6551144501488655
# V175
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [3]	training's auc: 0.658654	valid_0's auc: 0.657403
# Evaluated only: auc
# **********
# 0.6574029100369705
# V176
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [42]	training's auc: 0.672005	valid_0's auc: 0.671214
# Evaluated only: auc
# **********
# 0.671214061189422
# V177
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [10]	training's auc: 0.674666	valid_0's auc: 0.673472
# Evaluated only: auc
# **********
# 0.673472408869971
# V178
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [16]	training's auc: 0.677443	valid_0's auc: 0.675927
# Evaluated only: auc
# **********
# 0.6759271470062996
# V179
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [28]	training's auc: 0.676559	valid_0's auc: 0.67524
# Evaluated only: auc
# **********
# 0.675239756912019
# V180
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [5]	training's auc: 0.663804	valid_0's auc: 0.662738
# Evaluated only: auc
# **********
# 0.6627382946182272
# V181
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [71]	training's auc: 0.661287	valid_0's auc: 0.660611
# Evaluated only: auc
# **********
# 0.6606108596346996
# V182
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	training's auc: 0.66296	valid_0's auc: 0.662426
# Evaluated only: auc
# **********
# 0.6624257446925328
# V183
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# ...
# Early stopping, best iteration is:
# [6]	training's auc: 0.657631	valid_0's auc: 0.657263
# Evaluated only: auc
# **********
# 0.6572631418527173
# V303
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [23]	training's auc: 0.662533	valid_0's auc: 0.663086
# Evaluated only: auc
# **********
# 0.6630856325406435
# V304
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	training's auc: 0.659987	valid_0's auc: 0.660314
# Evaluated only: auc
# **********
# 0.6603138765255154
# V305
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.5	valid_0's auc: 0.5
# Evaluated only: auc
# **********
# 0.5
# V306
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [55]	training's auc: 0.590833	valid_0's auc: 0.590306
# Evaluated only: auc
# **********
# 0.5903061720740753
# V307
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [21]	training's auc: 0.598466	valid_0's auc: 0.592383
# Evaluated only: auc
# **********
# 0.5923828062845823
# V308
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [25]	training's auc: 0.610964	valid_0's auc: 0.609652
# Evaluated only: auc
# **********
# 0.6096521729839796
# V309
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [87]	training's auc: 0.535993	valid_0's auc: 0.532866
# Evaluated only: auc
# **********
# 0.5328657638163747
# V310
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [112]	training's auc: 0.582295	valid_0's auc: 0.578815
# Evaluated only: auc
# **********
# 0.5788148630105003
# V311
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [65]	training's auc: 0.511277	valid_0's auc: 0.504618
# Evaluated only: auc
# **********
# 0.5046181841116893
# V312
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [24]	training's auc: 0.565088	valid_0's auc: 0.558788
# Evaluated only: auc
# **********
# 0.5587875692270325
# V313
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [91]	training's auc: 0.57234	valid_0's auc: 0.563655
# Evaluated only: auc
# **********
# 0.5636551493008097
# V314
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [84]	training's auc: 0.567817	valid_0's auc: 0.562744
# Evaluated only: auc
# **********
# 0.5627437839967967
# V315
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [114]	training's auc: 0.575289	valid_0's auc: 0.570412
# Evaluated only: auc
# **********
# 0.57041172208751
# V316
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [45]	training's auc: 0.568346	valid_0's auc: 0.57239
# Evaluated only: auc
# **********
# 0.572389680122861
# V317
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [17]	training's auc: 0.60789	valid_0's auc: 0.613328
# Evaluated only: auc
# **********
# 0.6133280377958337
# V318
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [77]	training's auc: 0.594558	valid_0's auc: 0.599579
# Evaluated only: auc
# **********
# 0.5995789993378803
# V319
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [31]	training's auc: 0.518816	valid_0's auc: 0.516274
# Evaluated only: auc
# **********
# 0.5162735416245446
# V320
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [93]	training's auc: 0.538894	valid_0's auc: 0.532295
# Evaluated only: auc
# **********
# 0.5322953969127238
# V321
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [32]	training's auc: 0.527476	valid_0's auc: 0.526421
# Evaluated only: auc
# **********
# 0.526421191599751
# V322
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.523782	valid_0's auc: 0.521291
# Evaluated only: auc
# **********
# 0.5212912524423479
# V323
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.52465	valid_0's auc: 0.522315
# Evaluated only: auc
# **********
# 0.5223150570552285
# V324
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	training's auc: 0.524239	valid_0's auc: 0.521846
# Evaluated only: auc
# **********
# 0.5218459919541544
# V325
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	training's auc: 0.520285	valid_0's auc: 0.51814
# Evaluated only: auc
# **********
# 0.5181398645408108
# V326
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [15]	training's auc: 0.522755	valid_0's auc: 0.519798
# Evaluated only: auc
# **********
# 0.5197977853302687
# V327
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [29]	training's auc: 0.522549	valid_0's auc: 0.520449
# Evaluated only: auc
# **********
# 0.5204491090793935
# V328
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [41]	training's auc: 0.52274	valid_0's auc: 0.520219
# Evaluated only: auc
# **********
# 0.5202193854793175
# V329
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [5]	training's auc: 0.523409	valid_0's auc: 0.520952
# Evaluated only: auc
# **********
# 0.5209516201202142
# V330
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [44]	training's auc: 0.523033	valid_0's auc: 0.520605
# Evaluated only: auc
# **********
# 0.5206054623724143
# V331
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [28]	training's auc: 0.524745	valid_0's auc: 0.5216
# Evaluated only: auc
# **********
# 0.5215999902995913
# V332
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [3]	training's auc: 0.525208	valid_0's auc: 0.521951
# Evaluated only: auc
# **********
# 0.5219514922540388
# V333
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [3]	training's auc: 0.525083	valid_0's auc: 0.522223
# Evaluated only: auc
# **********
# 0.5222228624408415
# V334
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [5]	training's auc: 0.522389	valid_0's auc: 0.518929
# Evaluated only: auc
# **********
# 0.5189290410403425
# V335
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [30]	training's auc: 0.525399	valid_0's auc: 0.52117
# Evaluated only: auc
# **********
# 0.5211704537373483
# V336
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [35]	training's auc: 0.524291	valid_0's auc: 0.52054
# Evaluated only: auc
# **********
# 0.5205400577218183
# V337
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [23]	training's auc: 0.523203	valid_0's auc: 0.52086
# Evaluated only: auc
# **********
# 0.5208603874003597
# V338
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [6]	training's auc: 0.523516	valid_0's auc: 0.521072
# Evaluated only: auc
# **********
# 0.5210717953170316
# V339
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [20]	training's auc: 0.523331	valid_0's auc: 0.521013
# Evaluated only: auc
# **********
# 0.5210131824146922
# id_01
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [19]	training's auc: 0.6719	valid_0's auc: 0.671962
# Evaluated only: auc
# **********
# 0.6719616809208261
# id_02
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [3]	training's auc: 0.665875	valid_0's auc: 0.66393
# Evaluated only: auc
# **********
# 0.6639299305055744
# id_03
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [70]	training's auc: 0.621744	valid_0's auc: 0.617384
# Evaluated only: auc
# **********
# 0.6173841590466813
# id_04
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.620924	valid_0's auc: 0.616477
# Evaluated only: auc
# **********
# 0.6164766966741206
# id_05
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [32]	training's auc: 0.662767	valid_0's auc: 0.661789
# Evaluated only: auc
# **********
# 0.6617885684171716
# id_06
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [50]	training's auc: 0.662752	valid_0's auc: 0.661538
# Evaluated only: auc
# **********
# 0.6615375233438278
# id_07
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [7]	training's auc: 0.506367	valid_0's auc: 0.505844
# Evaluated only: auc
# **********
# 0.5058441160822676
# id_08
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [290]	training's auc: 0.507316	valid_0's auc: 0.506865
# Evaluated only: auc
# **********
# 0.5068646788703615
# id_09
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [33]	training's auc: 0.631917	valid_0's auc: 0.63206
# Evaluated only: auc
# **********
# 0.6320601463355949
# id_10
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [82]	training's auc: 0.63129	valid_0's auc: 0.631591
# Evaluated only: auc
# **********
# 0.6315911888079592
# id_11
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.660284	valid_0's auc: 0.657311
# Evaluated only: auc
# **********
# 0.6573110423205082
# id_12
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.659052	valid_0's auc: 0.658664
# Evaluated only: auc
# **********
# 0.6586640999853126
# id_13
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [5]	training's auc: 0.661451	valid_0's auc: 0.663372
# Evaluated only: auc
# **********
# 0.6633721058293284
# id_14
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	training's auc: 0.524524	valid_0's auc: 0.524213
# Evaluated only: auc
# **********
# 0.5242127642610708
# id_15
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.668781	valid_0's auc: 0.667841
# Evaluated only: auc
# **********
# 0.6678412641746413
# id_16
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.651361	valid_0's auc: 0.650077
# Evaluated only: auc
# **********
# 0.6500770721910619
# id_17
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [84]	training's auc: 0.673586	valid_0's auc: 0.673732
# Evaluated only: auc
# **********
# 0.6737321987239012
# id_18
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [19]	training's auc: 0.555859	valid_0's auc: 0.551536
# Evaluated only: auc
# **********
# 0.5515355915128651
# id_19
# Training until validation scores don't improve for 50 rounds
# [500]	training's auc: 0.688348	valid_0's auc: 0.684619
# Early stopping, best iteration is:
# [511]	training's auc: 0.688347	valid_0's auc: 0.684622
# Evaluated only: auc
# **********
# 0.684622425011731
# id_20
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [145]	training's auc: 0.68488	valid_0's auc: 0.681117
# Evaluated only: auc
# **********
# 0.6811171257196049
# id_21
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [258]	training's auc: 0.508518	valid_0's auc: 0.507598
# Evaluated only: auc
# **********
# 0.507598250346222
# id_22
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [119]	training's auc: 0.505835	valid_0's auc: 0.505961
# Evaluated only: auc
# **********
# 0.505961449460385
# id_23
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.50578	valid_0's auc: 0.50591
# Evaluated only: auc
# **********
# 0.5059100220459751
# id_24
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	training's auc: 0.505562	valid_0's auc: 0.505793
# Evaluated only: auc
# **********
# 0.5057932317570618
# id_25
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [140]	training's auc: 0.507901	valid_0's auc: 0.507298
# Evaluated only: auc
# **********
# 0.5072980755435621
# id_26
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [10]	training's auc: 0.506293	valid_0's auc: 0.506878
# Evaluated only: auc
# **********
# 0.5068776263258649
# id_27
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.505775	valid_0's auc: 0.505924
# Evaluated only: auc
# **********
# 0.5059241246104392
# id_28
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.667406	valid_0's auc: 0.667785
# Evaluated only: auc
# **********
# 0.6677848925596706
# id_29
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.66799	valid_0's auc: 0.668354
# Evaluated only: auc
# **********
# 0.6683537586571944
# id_30
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [4]	training's auc: 0.533591	valid_0's auc: 0.53156
# Evaluated only: auc
# **********
# 0.5315603288083455
# id_31
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [80]	training's auc: 0.679118	valid_0's auc: 0.676636
# Evaluated only: auc
# **********
# 0.6766362784235788
# id_32
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.520336	valid_0's auc: 0.51887
# Evaluated only: auc
# **********
# 0.5188702547672187
# id_33
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [436]	training's auc: 0.541855	valid_0's auc: 0.537189
# Evaluated only: auc
# **********
# 0.5371886953935163
# id_34
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [4]	training's auc: 0.520163	valid_0's auc: 0.516783
# Evaluated only: auc
# **********
# 0.5167830418056596
# id_35
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.673139	valid_0's auc: 0.673914
# Evaluated only: auc
# **********
# 0.6739138892170923
# id_36
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.658794	valid_0's auc: 0.658916
# Evaluated only: auc
# **********
# 0.6589163680537676
# id_37
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.659552	valid_0's auc: 0.659908
# Evaluated only: auc
# **********
# 0.6599079977645195
# id_38
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.665078	valid_0's auc: 0.665344
# Evaluated only: auc
# **********
# 0.665343720165016
# DeviceType
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.66422	valid_0's auc: 0.663965
# Evaluated only: auc
# **********
# 0.6639654192962497
# DeviceInfo
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [160]	training's auc: 0.635954	valid_0's auc: 0.636182
# Evaluated only: auc
# **********
# 0.6361822821679908

# %%
X_train = X_train[useful_cols]
X_valid = X_valid[useful_cols]

# %%
dtrain = lgb.Dataset(X_train, y_train)
dvalid = lgb.Dataset(X_valid, y_valid, reference=dtrain)
params = {
    'objective': 'binary',
    'boosting': 'gbdt',
    'metric': 'auc',
    # 'metric': 'None',  # 用自定义评估函数是将metric设置为'None'
    'learning_rate': 0.1,
    'num_leaves': 31,
    'lambda_l1': 0,
    'lambda_l2': 1,
    'num_threads': 23,
    'min_data_in_leaf': 20,
    'first_metric_only': True,
    'is_unbalance': True,
    'max_depth': -1,
    'seed': 2020
}
valid_model = lgb.train(
    params,
    dtrain,
    valid_sets=[dtrain, dvalid],
    num_boost_round=1000000,
    early_stopping_rounds=200,
    verbose_eval=300
)
pred = valid_model.predict(test)
sub = pd.DataFrame({'id': range(len(test))})
sub['isFraud'] = pred
sub.to_csv('../sub/basline.csv', index=False, header=None)
# Out:
# Training until validation scores don't improve for 200 rounds
# [300]	training's auc: 0.978573	valid_1's auc: 0.946165
# [600]	training's auc: 0.991448	valid_1's auc: 0.953023
# [900]	training's auc: 0.996447	valid_1's auc: 0.956686
# [1200]	training's auc: 0.99837	valid_1's auc: 0.958197
# [1500]	training's auc: 0.999275	valid_1's auc: 0.95968
# [1800]	training's auc: 0.999699	valid_1's auc: 0.960455
# [2100]	training's auc: 0.999865	valid_1's auc: 0.961002
# [2400]	training's auc: 0.999947	valid_1's auc: 0.961269
# [2700]	training's auc: 0.99998	valid_1's auc: 0.961845
# [3000]	training's auc: 0.999993	valid_1's auc: 0.962234
# Early stopping, best iteration is:
# [2951]	training's auc: 0.999992	valid_1's auc: 0.962304
# Evaluated only: auc
# ---------------------------------------------------------------------------
# LightGBMError                             Traceback (most recent call last)
# <ipython-input-9-dee3b5430027> in <module>
#      25     verbose_eval=300
#      26 )
# ---> 27 pred = valid_model.predict(test)
#      28 sub = pd.DataFrame({'id': range(len(test))})
#      29 sub['isFraud'] = pred
#
# ~\Anaconda3\lib\site-packages\lightgbm\basic.py in predict(self, data, num_iteration, raw_score, pred_leaf, pred_contrib, data_has_header, is_reshape, **kwargs)
#    2413         return predictor.predict(data, num_iteration,
#    2414                                  raw_score, pred_leaf, pred_contrib,
# -> 2415                                  data_has_header, is_reshape)
#    2416
#    2417     def refit(self, data, label, decay_rate=0.9, **kwargs):
#
# ~\Anaconda3\lib\site-packages\lightgbm\basic.py in predict(self, data, num_iteration, raw_score, pred_leaf, pred_contrib, data_has_header, is_reshape)
#     533             preds, nrow = self.__pred_for_csc(data, num_iteration, predict_type)
#     534         elif isinstance(data, np.ndarray):
# --> 535             preds, nrow = self.__pred_for_np2d(data, num_iteration, predict_type)
#     536         elif isinstance(data, list):
#     537             try:
#
# ~\Anaconda3\lib\site-packages\lightgbm\basic.py in __pred_for_np2d(self, mat, num_iteration, predict_type)
#     621             return preds, nrow
#     622         else:
# --> 623             return inner_predict(mat, num_iteration, predict_type)
#     624
#     625     def __pred_for_csr(self, csr, num_iteration, predict_type):
#
# ~\Anaconda3\lib\site-packages\lightgbm\basic.py in inner_predict(mat, num_iteration, predict_type, preds)
#     603                 c_str(self.pred_parameter),
#     604                 ctypes.byref(out_num_preds),
# --> 605                 preds.ctypes.data_as(ctypes.POINTER(ctypes.c_double))))
#     606             if n_preds != out_num_preds.value:
#     607                 raise ValueError("Wrong length for predict results")
#
# ~\Anaconda3\lib\site-packages\lightgbm\basic.py in _safe_call(ret)
#      43     """
#      44     if ret != 0:
# ---> 45         raise LightGBMError(decode_string(_LIB.LGBM_GetLastError()))
#      46
#      47
#
# LightGBMError: The number of features in data (432) is not the same as it was in training data (383).
