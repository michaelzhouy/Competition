# %%
# 查看当前挂载的数据集目录, 该目录下的变更重启环境后会自动还原
# View dataset directory. 
# This directory will be recovered automatically after resetting environment. 
# !ls /home/aistudio/data
# Out:
# data63881

# %%
# 查看工作区文件, 该目录下的变更将会持久保存. 请及时清理不必要的文件, 避免加载过慢.
# View personal work directory. 
# All changes under this directory will be kept even after reset. 
# Please clean unnecessary files in time to speed up environment loading. 
# !ls /home/aistudio/work

# %%
# 如果需要进行持久化安装, 需要使用持久化路径, 如下方代码示例:
# If a persistence installation is required, 
# you need to use the persistence path as the following: 
# !mkdir /home/aistudio/external-libraries
# !pip install beautifulsoup4 -t /home/aistudio/external-libraries
# !pip install lightgbm==2.3.1 -t /home/aistudio/external-libraries
# !pip install catboost==0.23 -t /home/aistudio/external-libraries
# !pip install jieba -t /home/aistudio/external-libraries
# !pip install gensim -t /home/aistudio/external-libraries
# !pip uninstall --yes pandas
# !pip install pandas==1.0.5 -t /home/aistudio/external-libraries
# Out:
# mkdir: cannot create directory ‘/home/aistudio/external-libraries’: File exists
# Looking in indexes: https://mirror.baidu.com/pypi/simple/
# Collecting lightgbm==2.3.1
#   Downloading https://mirror.baidu.com/pypi/packages/0b/9d/ddcb2f43aca194987f1a99e27edf41cf9bc39ea750c3371c2a62698c509a/lightgbm-2.3.1-py2.py3-none-manylinux1_x86_64.whl (1.2MB)
#      |████████████████████████████████| 1.2MB 12.6MB/s eta 0:00:01
# Collecting numpy (from lightgbm==2.3.1)
#   Downloading https://mirror.baidu.com/pypi/packages/a5/bb/87d668b353848b93baab0a64cddf6408c40717f099539668c3d26fe39f7e/numpy-1.19.4-cp37-cp37m-manylinux2010_x86_64.whl (14.5MB)
#      |████████████████████████████████| 14.5MB 9.3MB/s eta 0:00:011
# Collecting scipy (from lightgbm==2.3.1)
#   Downloading https://mirror.baidu.com/pypi/packages/dc/7e/8f6a79b102ca1ea928bae8998b05bf5dc24a90571db13cd119f275ba6252/scipy-1.5.4-cp37-cp37m-manylinux1_x86_64.whl (25.9MB)
#      |████████████████████████████████| 25.9MB 8.6MB/s eta 0:00:012    |█████████                       | 7.4MB 13.7MB/s eta 0:00:02     |████████████████████            | 16.1MB 8.6MB/s eta 0:00:02
# Collecting scikit-learn (from lightgbm==2.3.1)
#   Downloading https://mirror.baidu.com/pypi/packages/f4/cb/64623369f348e9bfb29ff898a57ac7c91ed4921f228e9726546614d63ccb/scikit_learn-0.23.2-cp37-cp37m-manylinux1_x86_64.whl (6.8MB)
#      |████████████████████████████████| 6.8MB 21.0MB/s eta 0:00:01
# Collecting joblib>=0.11 (from scikit-learn->lightgbm==2.3.1)
#   Downloading https://mirror.baidu.com/pypi/packages/fc/c9/f58220ac44a1592f79a343caba12f6837f9e0c04c196176a3d66338e1ea8/joblib-0.17.0-py3-none-any.whl (301kB)
#      |████████████████████████████████| 307kB 18.0MB/s eta 0:00:01
# Collecting threadpoolctl>=2.0.0 (from scikit-learn->lightgbm==2.3.1)
#   Downloading https://mirror.baidu.com/pypi/packages/f7/12/ec3f2e203afa394a149911729357aa48affc59c20e2c1c8297a60f33f133/threadpoolctl-2.1.0-py3-none-any.whl
# ERROR: seaborn 0.10.0 requires pandas>=0.22.0, which is not installed.
# ERROR: paddlehub 1.6.0 requires pandas; python_version >= "3", which is not installed.
# Installing collected packages: numpy, scipy, joblib, threadpoolctl, scikit-learn, lightgbm
# Successfully installed joblib-0.17.0 lightgbm-2.3.1 numpy-1.19.4 scikit-learn-0.23.2 scipy-1.5.4 threadpoolctl-2.1.0
# WARNING: Target directory /home/aistudio/external-libraries/__pycache__ already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/aistudio/external-libraries/scikit_learn-0.23.2.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/aistudio/external-libraries/scipy already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/aistudio/external-libraries/numpy.libs already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/aistudio/external-libraries/threadpoolctl-2.1.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/aistudio/external-libraries/threadpoolctl.py already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/aistudio/external-libraries/numpy already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/aistudio/external-libraries/scikit_learn.libs already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/aistudio/external-libraries/sklearn already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/aistudio/external-libraries/lightgbm-2.3.1.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/aistudio/external-libraries/scipy-1.5.4.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/aistudio/external-libraries/joblib already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/aistudio/external-libraries/scipy.libs already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/aistudio/external-libraries/lightgbm already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/aistudio/external-libraries/numpy-1.19.4.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/aistudio/external-libraries/joblib-0.17.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/aistudio/external-libraries/bin already exists. Specify --upgrade to force replacement.
# WARNING: Skipping pandas as it is not installed.
# Looking in indexes: https://mirror.baidu.com/pypi/simple/
# Collecting pandas==1.0.5
#   Downloading https://mirror.baidu.com/pypi/packages/af/f3/683bf2547a3eaeec15b39cef86f61e921b3b187f250fcd2b5c5fb4386369/pandas-1.0.5-cp37-cp37m-manylinux1_x86_64.whl (10.1MB)
#      |████████████████████████████████| 10.1MB 15.0MB/s eta 0:00:01    |█████████████▌                  | 4.2MB 15.0MB/s eta 0:00:01
# Collecting python-dateutil>=2.6.1 (from pandas==1.0.5)
#   Downloading https://mirror.baidu.com/pypi/packages/d4/70/d60450c3dd48ef87586924207ae8907090de0b306af2bce5d134d78615cb/python_dateutil-2.8.1-py2.py3-none-any.whl (227kB)
#      |████████████████████████████████| 235kB 21.7MB/s eta 0:00:01
# Collecting numpy>=1.13.3 (from pandas==1.0.5)
#   Downloading https://mirror.baidu.com/pypi/packages/a5/bb/87d668b353848b93baab0a64cddf6408c40717f099539668c3d26fe39f7e/numpy-1.19.4-cp37-cp37m-manylinux2010_x86_64.whl (14.5MB)
#      |████████████████████████████████| 14.5MB 9.8MB/s eta 0:00:011
# Collecting pytz>=2017.2 (from pandas==1.0.5)
#   Downloading https://mirror.baidu.com/pypi/packages/12/f8/ff09af6ff61a3efaad5f61ba5facdf17e7722c4393f7d8a66674d2dbd29f/pytz-2020.4-py2.py3-none-any.whl (509kB)
#      |████████████████████████████████| 512kB 22.8MB/s eta 0:00:01
# Collecting six>=1.5 (from python-dateutil>=2.6.1->pandas==1.0.5)
#   Downloading https://mirror.baidu.com/pypi/packages/ee/ff/48bde5c0f013094d729fe4b0316ba2a24774b3ff1c52d924a8a4cb04078a/six-1.15.0-py2.py3-none-any.whl
# Installing collected packages: six, python-dateutil, numpy, pytz, pandas
# Successfully installed numpy-1.19.4 pandas-1.0.5 python-dateutil-2.8.1 pytz-2020.4 six-1.15.0
# WARNING: Target directory /home/aistudio/external-libraries/six.py already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/aistudio/external-libraries/__pycache__ already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/aistudio/external-libraries/dateutil already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/aistudio/external-libraries/pandas-1.0.5.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/aistudio/external-libraries/python_dateutil-2.8.1.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/aistudio/external-libraries/six-1.15.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/aistudio/external-libraries/numpy.libs already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/aistudio/external-libraries/numpy already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/aistudio/external-libraries/pytz already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/aistudio/external-libraries/pytz-2020.4.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/aistudio/external-libraries/pandas already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/aistudio/external-libraries/numpy-1.19.4.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/aistudio/external-libraries/bin already exists. Specify --upgrade to force replacement.

# %%
# 同时添加如下代码, 这样每次环境(kernel)启动的时候只要运行下方代码即可: 
# Also add the following code, 
# so that every time the environment (kernel) starts, 
# just run the following code: 
import sys 
sys.path.append('/home/aistudio/external-libraries')

# %%
import time
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import lightgbm as lgb
import gc
import warnings
warnings.filterwarnings('ignore')
pd.set_option('max_columns', None)
pd.set_option('max_rows', None)

# %%
train_transaction = pd.read_csv('data/data63881/train_transaction.csv')
test_transaction = pd.read_csv('data/data63881/test_transaction.csv')
train_identity = pd.read_csv('data/data63881/train_identity.csv')
test_identity = pd.read_csv('data/data63881/test_identity.csv')

# %%
train = train_transaction.merge(train_identity, on='TransactionID', how='left')
test = test_transaction.merge(test_identity, on='TransactionID', how='left')
data = pd.concat([train, test], axis=0, ignore_index=True)
del train, test
gc.collect()
# Out:
# 0

# %%
C = ['C{}'.format(i) for i in range(1, 15)]
data['C_sum'] = data[C].sum(1)

D = ['D{}'.format(i) for i in range(1, 16)]
data['D_sum'] = data[D].sum(1)

V = ['V{}'.format(i) for i in range(1, 340)]
data['V_sum'] = data[V].sum(1)

# %%
data['P_emaildomain_R_emaildomain'] = data['P_emaildomain'].astype(str) + data['R_emaildomain'].astype(str)
data['addr1_addr2'] = data['addr1'].astype(str) + data['addr2'].astype(str)

object_cols = ['ProductCD', 'card4', 'card6', 'DeviceType', 'DeviceInfo', 'P_emaildomain', 'R_emaildomain',
               'P_emaildomain_R_emaildomain', 'addr1_addr2']
M_cols = ['M{}'.format(i) for i in range(1, 10)]
id_cols = ['id_12', 'id_16', 'id_27', 'id_28', 'id_29', 'id_35', 'id_36', 'id_37', 'id_38', 'id_15',
           'id_23', 'id_34', 'id_30', 'id_31', 'id_33']
cat_cols = object_cols + M_cols + id_cols

# %%
for i in cat_cols:
    le = LabelEncoder()
    data[i] = le.fit_transform(data[i].astype(str))
    data[i] = data[i].astype('category')

for i in ['addr1', 'addr2']:
    data[i] = data[i].astype('category')

# %%
train = data[data['isFraud'].notnull()]
test = data[data['isFraud'].isnull()]

y = train['isFraud']
train.drop(['isFraud', 'TransactionID'], axis=1, inplace=True)
test.drop(['isFraud', 'TransactionID'], axis=1, inplace=True)
used_cols = train.columns
test = test[used_cols]

X_train, X_valid, y_train, y_valid = train_test_split(train, y, random_state=2020)

# %%
# def auc_select(X_train, y_train, X_valid, y_valid, cols, threshold=0.52):
#     useful_dict = dict()
#     useless_dict = dict()
#     params = {
#         'objective': 'binary',
#         'boosting': 'gbdt',
#         'metric': 'auc',
#         'learning_rate': 0.1,
#         'num_leaves': 31,
#         'lambda_l1': 0,
#         'lambda_l2': 1,
#         'num_threads': 23,
#         'min_data_in_leaf': 20,
#         'first_metric_only': True,
#         'is_unbalance': True,
#         'max_depth': -1,
#         'seed': 2020
#     }
#     for i in cols:
#         print(i)
#         try:
#             lgb_train = lgb.Dataset(X_train[[i]].values, y_train)
#             lgb_valid = lgb.Dataset(X_valid[[i]].values, y_valid, reference=lgb_train)
#             lgb_model = lgb.train(
#                 params,
#                 lgb_train,
#                 valid_sets=[lgb_valid, lgb_train],
#                 num_boost_round=1000,
#                 early_stopping_rounds=50,
#                 verbose_eval=500
#             )
#             print('*' * 10)
#             print(lgb_model.best_score['valid_0']['auc'])
#             if lgb_model.best_score['valid_0']['auc'] > threshold:
#                 useful_dict[i] = lgb_model.best_score['valid_0']['auc']
#             else:
#                 useless_dict[i] = lgb_model.best_score['valid_0']['auc']
#         except:
#             print('Error: ', i)
#     useful_cols = list(useful_dict.keys())
#     useless_cols = list(useless_dict.keys())
#     return useful_dict, useless_dict, useful_cols, useless_cols


# useful_dict, useless_dict, useful_cols, useless_cols = auc_select(X_train, y_train, X_valid, y_valid, used_cols, threshold=0.52)
# print(useless_cols)

# %%
auc_to_drop = ['card4', 'C3', 'V41', 'V98', 'V100', 'V104', 'V105', 'V106', 'V107', 'V108', 'V109', 'V110', 'V111', 'V113', 'V117', 'V118', 'V119', 'V120', 'V121', 'V122', 'V135', 'V138', 'V141', 'V142', 'V161', 'V162', 'V163', 'V286', 'V297', 'V299', 'V300', 'V301', 'V305', 'V311', 'V319', 'V325', 'V326', 'V334', 'id_07', 'id_08', 'id_21', 'id_22', 'id_23', 'id_24', 'id_25', 'id_26', 'id_27', 'id_32', 'id_34']

X_train.drop(auc_to_drop, axis=1, inplace=True)
X_valid.drop(auc_to_drop, axis=1, inplace=True)
train.drop(auc_to_drop, axis=1, inplace=True)
test.drop(auc_to_drop, axis=1, inplace=True)
gc.collect()
# Out:
# 40

# %%
# %%time
dtrain = lgb.Dataset(X_train, y_train)
dvalid = lgb.Dataset(X_valid, y_valid, reference=dtrain)
params = {
    'objective': 'binary',
    'boosting': 'gbdt',
    'metric': 'auc',
    # 'metric': 'None',  # 用自定义评估函数是将metric设置为'None'
    'learning_rate': 0.1,
    'num_leaves': 31,
    'lambda_l1': 0,
    'lambda_l2': 1,
    'num_threads': 23,
    'min_data_in_leaf': 20,
    'first_metric_only': True,
    'is_unbalance': True,
    'max_depth': -1,
    'seed': 2020
}
valid_model = lgb.train(
    params,
    dtrain,
    valid_sets=[dtrain, dvalid],
    num_boost_round=1000000,
    early_stopping_rounds=200,
    verbose_eval=300
)

importance = valid_model.feature_importance(importance_type='gain')
feature_name = valid_model.feature_name()
df_importance = pd.DataFrame({
    'feature_name': feature_name,
    'importance': importance
}).sort_values(by='importance', ascending=False)
df_importance['normalized_importance'] = df_importance['importance'] / df_importance['importance'].sum()
df_importance['cumulative_importance'] = np.cumsum(df_importance['normalized_importance'])
record_low_importance = df_importance[df_importance['cumulative_importance'] > 0.95]
to_drop = list(record_low_importance['feature_name'])
print(to_drop)
df_importance.to_csv('sub/imp_{}_2.csv'.format(time.strftime('%Y%m%d')), index=False)
# Out:
# Training until validation scores don't improve for 200 rounds
# [300]	training's auc: 0.989606	valid_1's auc: 0.954804
# [600]	training's auc: 0.99709	valid_1's auc: 0.961037
# [900]	training's auc: 0.999049	valid_1's auc: 0.963161
# [1200]	training's auc: 0.999668	valid_1's auc: 0.963748
# Early stopping, best iteration is:
# [1234]	training's auc: 0.999703	valid_1's auc: 0.963877
# Evaluated only: auc
# ['id_14', 'V94', 'V25', 'id_18', 'V321', 'V4', 'V69', 'V77', 'V160', 'V257', 'V81', 'V11', 'V10', 'V306', 'V96', 'V215', 'D7', 'id_11', 'V129', 'V66', 'V6', 'V267', 'V124', 'V74', 'V206', 'C4', 'V207', 'V26', 'V73', 'V133', 'V217', 'V292', 'V137', 'V289', 'V99', 'V30', 'V143', 'id_04', 'C7', 'id_15', 'V339', 'V316', 'V8', 'V3', 'V265', 'V7', 'V251', 'V261', 'V221', 'V318', 'V271', 'V322', 'V166', 'V264', 'V270', 'V132', 'V47', 'V2', 'V85', 'V209', 'V224', 'V338', 'V40', 'V288', 'V277', 'V234', 'V178', 'V253', 'V290', 'V260', 'V205', 'V276', 'V46', 'V60', 'V52', 'V274', 'V293', 'V188', 'V329', 'V220', 'V159', 'V222', 'V115', 'V125', 'V203', 'V266', 'V259', 'V57', 'V42', 'V139', 'V228', 'V298', 'V95', 'V171', 'V59', 'V33', 'V17', 'V238', 'V34', 'id_10', 'V63', 'V140', 'V303', 'V256', 'V134', 'V164', 'V263', 'V51', 'id_38', 'V39', 'V64', 'V332', 'V72', 'V295', 'V214', 'V9', 'V245', 'V229', 'V262', 'V243', 'V275', 'V331', 'V278', 'V268', 'V80', 'DeviceType', 'V101', 'V210', 'V233', 'V246', 'id_36', 'V272', 'V103', 'V157', 'V287', 'V242', 'V302', 'V123', 'V184', 'V212', 'V116', 'V337', 'V144', 'V174', 'V336', 'V324', 'V211', 'V181', 'V176', 'V170', 'V58', 'V79', 'V273', 'V155', 'V192', 'V84', 'V202', 'id_37', 'V279', 'V239', 'V151', 'V218', 'V16', 'V199', 'V248', 'V204', 'V43', 'V200', 'V71', 'M1', 'V145', 'V185', 'V328', 'V168', 'V255', 'V323', 'V333', 'V97', 'V213', 'V304', 'V114', 'V175', 'V172', 'V216', 'V227', 'V196', 'V190', 'V112', 'V32', 'V232', 'V50', 'V147', 'V225', 'V92', 'V231', 'V195', 'V230', 'V183', 'V197', 'V244', 'V158', 'V180', 'V223', 'V254', 'V236', 'V327', 'V18', 'V182', 'V21', 'id_12', 'V335', 'V15', 'id_16', 'V150', 'V194', 'V177', 'V330', 'V31', 'V173', 'V93', 'V284', 'V191', 'V22', 'id_35', 'V237', 'V186', 'id_28', 'V146', 'V250', 'V167', 'V219', 'V241', 'V14', 'V247', 'V27', 'V249', 'addr2', 'V89', 'V68', 'V65', 'V88', 'V148', 'V240', 'id_29', 'V1', 'V235', 'V269', 'V226', 'V28', 'V153', 'V154', 'V198', 'V193', 'V179', 'V252']
# CPU times: user 53min 27s, sys: 12.9 s, total: 53min 40s
# Wall time: 13min 37s

# %%
X_train.drop(to_drop, axis=1, inplace=True)
X_valid.drop(to_drop, axis=1, inplace=True)
train.drop(to_drop, axis=1, inplace=True)
test.drop(to_drop, axis=1, inplace=True)
gc.collect()
# Out:
# 216

# %%
# %%time
dtrain = lgb.Dataset(X_train, y_train)
dvalid = lgb.Dataset(X_valid, y_valid, reference=dtrain)
dall = lgb.Dataset(train, y)

valid_model2 = lgb.train(
    params,
    dtrain,
    valid_sets=[dtrain, dvalid],
    num_boost_round=1000000,
    early_stopping_rounds=200,
    verbose_eval=300
)
# Out:
# Training until validation scores don't improve for 200 rounds
# [300]	training's auc: 0.989964	valid_1's auc: 0.954877
# [600]	training's auc: 0.997098	valid_1's auc: 0.960662
# [900]	training's auc: 0.999041	valid_1's auc: 0.963168
# [1200]	training's auc: 0.999667	valid_1's auc: 0.964254
# [1500]	training's auc: 0.999888	valid_1's auc: 0.964813
# [1800]	training's auc: 0.999964	valid_1's auc: 0.965323
# [2100]	training's auc: 0.999988	valid_1's auc: 0.96579
# [2400]	training's auc: 0.999996	valid_1's auc: 0.966189
# Early stopping, best iteration is:
# [2742]	training's auc: 0.999999	valid_1's auc: 0.966717
# Evaluated only: auc
# CPU times: user 1h 5min 19s, sys: 10.6 s, total: 1h 5min 30s
# Wall time: 16min 30s

# %%
# %%time
model = lgb.train(
    params,
    dall,
    num_boost_round=valid_model2.best_iteration
)
# Out:
# CPU times: user 39min 1s, sys: 6.62 s, total: 39min 8s
# Wall time: 9min 53s

# %%
# %%time
pred = model.predict(test)
sub = pd.DataFrame({'id': range(len(test))})
sub['isFraud'] = pred
sub.to_csv('./sub/baseline_{}_02.csv'.format(time.strftime('%Y%m%d')), index=False, header=None)
# Out:
# CPU times: user 48.8 s, sys: 574 ms, total: 49.4 s
# Wall time: 13.3 s
