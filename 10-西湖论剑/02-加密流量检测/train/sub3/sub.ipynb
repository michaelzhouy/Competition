# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
import lightgbm as lgb

# %%
def auc_select(X_train, y_train, X_valid, y_valid, cols, threshold=0.52):
    """
    基于AUC的单特征筛选
    @param X_train:
    @param y_train:
    @param X_valid:
    @param y_valid:
    @param cols:
    @param threshold:
    @return:
    """
    useful_dict = dict()
    useless_dict = dict()
    params = {
        'objective': 'binary',
        'boosting': 'gbdt',
        'metric': 'auc',
        'learning_rate': 0.1,
        'num_leaves': 31,
        'lambda_l1': 0,
        'lambda_l2': 1,
        'num_threads': 23,
        'min_data_in_leaf': 20,
        'first_metric_only': True,
        'is_unbalance': True,
        'max_depth': -1,
        'seed': 2020
    }
    for i in cols:
        print(i)
        lgb_train = lgb.Dataset(X_train[[i]].values, y_train)
        lgb_valid = lgb.Dataset(X_valid[[i]].values, y_valid, reference=lgb_train)
        lgb_model = lgb.train(
            params,
            lgb_train,
            valid_sets=[lgb_valid, lgb_train],
            num_boost_round=1000,
            early_stopping_rounds=50,
            verbose_eval=500
        )
        print('*' * 10)
        print(lgb_model.best_score['valid_0']['auc'])
        if lgb_model.best_score['valid_0']['auc'] > threshold:
            useful_dict[i] = lgb_model.best_score['valid_0']['auc']
        else:
            useless_dict[i] = lgb_model.best_score['valid_0']['auc']
    useful_cols = list(useful_dict.keys())
    useless_cols = list(useless_dict.keys())
    return useful_dict, useless_dict, useful_cols, useless_cols


def correlation(df, useful_dict, threshold=0.98):
    """
    去除特征相关系数大于阈值的特征
    @param df:
    @param threshold:
    @param useful_dict:
    @return:
    """
    col_corr = set()
    corr_matrix = df.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold:
                colName_i = corr_matrix.columns[i]
                colName_j = corr_matrix.columns[j]
                if useful_dict[colName_i] >= useful_dict[colName_j]:
                    col_corr.add(colName_j)
                else:
                    col_corr.add(colName_i)
    return col_corr

# %%
psi_drop = ['tlsVersion_map_count', 'tlsVersion_bytesOut_max', 'tlsVersion_bytesOut_median', 'tlsVersion_bytesOut_mean', 'tlsVersion_bytesOut_std', 'tlsVersion_bytesOut_max_min', 'tlsVersion_bytesOut_quantile_25', 'tlsVersion_bytesOut_quantile_75', 'tlsVersion_bytesIn_median', 'tlsVersion_bytesIn_mean', 'tlsVersion_bytesIn_std', 'tlsVersion_bytesIn_quantile_25', 'tlsVersion_bytesIn_quantile_75', 'tlsVersion_pktsIn_median', 'tlsVersion_pktsIn_mean', 'tlsVersion_pktsIn_std', 'tlsVersion_pktsIn_quantile_75', 'tlsVersion_pktsOut_max', 'tlsVersion_pktsOut_mean', 'tlsVersion_pktsOut_sum', 'tlsVersion_pktsOut_skew', 'tlsVersion_pktsOut_std', 'tlsVersion_pktsOut_max_min', 'tlsIssuerDn_bytesIn_mean', 'tlsVersion_map_bytesOut_skew', 'tlsVersion_map_bytesOut_std', 'tlsVersion_map_bytesIn_median', 'tlsVersion_map_bytesIn_std', 'tlsVersion_map_pktsIn_skew', 'tlsVersion_map_pktsIn_std', 'tlsVersion_map_pktsIn_max_min', 'tlsVersion_map_pktsOut_max', 'tlsVersion_map_pktsOut_median', 'tlsVersion_map_pktsOut_skew']

psi_error = ['tlsVersion_pktsIn_median', 'destAddress', 'tlsVersion_map_bytesIn_std', 'tlsVersion_bytesIn_quantile_25', 'tlsVersion_map_pktsIn_std', 'tlsSni', 'tlsVersion_bytesOut_max_min', 'tlsVersion_bytesIn_median', 'tlsVersion_map_count', 'tlsVersion_pktsIn_mean', 'tlsVersion_pktsOut_max_min', 'tlsVersion_pktsIn_quantile_75', 'tlsVersion_pktsOut_std', 'tlsVersion_map_bytesOut_std', 'tlsVersion_map_bytesIn_median', 'tlsVersion_bytesIn_quantile_75', 'tlsVersion_bytesOut_quantile_25', 'tlsIssuerDn', 'tlsVersion', 'tlsIssuerDn_bytesIn_mean', 'tlsSubject', 'tlsVersion_bytesOut_std', 'tlsVersion_map_pktsOut_skew', 'tlsVersion_map_pktsIn_skew', 'tlsVersion_pktsOut_max', 'tlsVersion_pktsOut_mean', 'tlsVersion_bytesOut_max', 'tlsVersion_bytesOut_quantile_75', 'tlsVersion_pktsOut_sum', 'tlsVersion_bytesIn_mean', 'tlsVersion_map_bytesOut_skew', 'srcAddress', 'tlsVersion_map_pktsOut_max', 'tlsVersion_pktsOut_skew', 'tlsVersion_bytesIn_std', 'tlsVersion_bytesOut_mean', 'tlsVersion_pktsIn_std', 'tlsVersion_bytesOut_median', 'tlsVersion_map_pktsIn_max_min', 'destAddressPort', 'srcAddressPort', 'tlsVersion_map_pktsOut_median']

to_drop = psi_drop + psi_error

# %%
train = pd.read_csv('fe_train.csv')
test = pd.read_csv('fe_test_1.csv')

sub = pd.read_csv('sub.csv')

# %%
train.drop(to_drop, axis=1, inplace=True)
y = train['label']
train.drop('label', axis=1, inplace=True)

# %%
cols = train.columns.to_list()
test = test[cols]

# %%
X_train, X_valid, y_train, y_valid = train_test_split(train, y, test_size=0.25, random_state=2020)
    
print('y_train mean: ', y_train.mean())
print('y_valid mean: ', y_valid.mean())

used_cols = [i for i in cols if i not in ['eventId', 'label']]

useful_dict, useless_dict, useful_cols, useless_cols = auc_select(X_train, y_train, X_valid, y_valid, used_cols, threshold=0.52)
print('AUC drop features: \n', useless_cols)

train = train[useful_cols]
X_train = X_train[useful_cols]
X_valid = X_valid[useful_cols]
test = test[useful_cols]

col_corr = correlation(X_train, useful_dict, threshold=0.98)
print('Correlation drop features: \n', col_corr)

train.drop(col_corr, axis=1, inplace=True)
X_train.drop(col_corr, axis=1, inplace=True)
X_valid.drop(col_corr, axis=1, inplace=True)
test.drop(col_corr, axis=1, inplace=True)

used_cols = X_train.columns.to_list()
print('used_cols:\n', used_cols)

train_dataset = lgb.Dataset(X_train, y_train)
valid_dataset = lgb.Dataset(X_valid, y_valid, reference=train_dataset)
# all_dataset = lgb.Dataset(train, y, reference=train_dataset)

params = {
    'objective': 'binary',
    'boosting': 'gbdt',
    'metric': 'auc',
    'learning_rate': 0.1,
    'num_leaves': 31,
    'lambda_l1': 0,
    'lambda_l2': 1,
    'num_threads': 23,
    'min_data_in_leaf': 20,
    'first_metric_only': True,
    'is_unbalance': True,
    'max_depth': -1,
    'seed': 2020
}
valid_model = lgb.train(
    params,
    train_dataset,
    valid_sets=[train_dataset, valid_dataset],
    early_stopping_rounds=200,
    num_boost_round=100000,
    verbose_eval=300
)
pred = valid_model.predict(X_valid)

f1_best = 0
for i in np.arange(0.1, 1, 0.01):
    y_valid_pred = np.where(pred > i, 1, 0)
    f1 = np.round(f1_score(y_valid, y_valid_pred), 5)
    if f1 > f1_best:
        threshold = i
        f1_best = f1

print('threshold: ', threshold)
y_valid_pred = np.where(pred > threshold, 1, 0)
print('Valid F1: ', np.round(f1_score(y_valid, y_valid_pred), 5))
print('Valid mean label: ', np.mean(y_valid_pred))

# 导出特征重要性
importance = valid_model.feature_importance(importance_type='gain')
feature_name = valid_model.feature_name()

df_importance = pd.DataFrame({
    'feature_name': feature_name,
    'importance': importance
}).sort_values(by='importance', ascending=False)

df_importance['normalized_importance'] = df_importance['importance'] / df_importance['importance'].sum()
df_importance['cumulative_importance'] = np.cumsum(df_importance['normalized_importance'])
record_low_importance = df_importance[df_importance['cumulative_importance'] > 0.99]
to_drop = list(record_low_importance['feature_name'])
print('to drop: \n', to_drop)
print('len(to_drop): \n', len(to_drop))
# df_importance.to_csv('imp.csv', index=False)

print('After train.shape', train.shape)
train.drop(to_drop, axis=1, inplace=True)
X_train.drop(to_drop, axis=1, inplace=True)
X_valid.drop(to_drop, axis=1, inplace=True)
test.drop(to_drop, axis=1, inplace=True)
print('Before train.shape', train.shape)
print('Final cols:\n', X_train.columns.to_list())

train_dataset = lgb.Dataset(X_train, y_train)
valid_dataset = lgb.Dataset(X_valid, y_valid, reference=train_dataset)
all_dataset = lgb.Dataset(train, y, reference=train_dataset)

valid_model_2 = lgb.train(
    params,
    train_dataset,
    valid_sets=[train_dataset, valid_dataset],
    early_stopping_rounds=200,
    num_boost_round=100000,
    verbose_eval=300
)
pred_2 = valid_model_2.predict(X_valid)

f1_best = 0
for i in np.arange(0.1, 1, 0.01):
    y_valid_pred = np.where(pred_2 > i, 1, 0)
    f1 = np.round(f1_score(y_valid, y_valid_pred), 5)
    if f1 > f1_best:
        threshold = i
        f1_best = f1

print('threshold: ', threshold)
y_valid_pred = np.where(pred_2 > threshold, 1, 0)
print('Valid F1: ', np.round(f1_score(y_valid, y_valid_pred), 5))
print('Valid mean label: ', np.mean(y_valid_pred))

print('Best iteration: \n', valid_model_2.best_iteration)

train_model = lgb.train(
    params,
    all_dataset,
    num_boost_round=valid_model_2.best_iteration
)
y_test_pred = np.where(train_model.predict(test) > threshold, 1, 0)

print('Test mean label: ', np.mean(y_test_pred))

sub['label'] = y_test_pred
sub.to_csv('机器不学习原子弹也不学习_eta_submission_1028.csv', index=False)
# Out:
# y_train mean:  0.09
# y_valid mean:  0.09363636363636364
# srcPort
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [4]	training's auc: 0.930248	valid_0's auc: 0.935111
# Evaluated only: auc
# **********
# 0.9351113534779094
# destPort
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [118]	training's auc: 0.644376	valid_0's auc: 0.624224
# Evaluated only: auc
# **********
# 0.6242243234558043
# bytesOut
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [31]	training's auc: 0.921089	valid_0's auc: 0.911637
# Evaluated only: auc
# **********
# 0.911637241822555
# bytesIn
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [10]	training's auc: 0.853758	valid_0's auc: 0.857264
# Evaluated only: auc
# **********
# 0.8572644146030324
# pktsIn
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [14]	training's auc: 0.826356	valid_0's auc: 0.818071
# Evaluated only: auc
# **********
# 0.8180705222463507
# pktsOut
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [5]	training's auc: 0.796766	valid_0's auc: 0.788401
# Evaluated only: auc
# **********
# 0.78840073618915
# srcAddress_gp_destAddress_nunique_rate
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [27]	training's auc: 0.878121	valid_0's auc: 0.893444
# Evaluated only: auc
# **********
# 0.8934440213845419
# srcAddress_gp_srcAddressPort_nunique_rate
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.53683	valid_0's auc: 0.534905
# Evaluated only: auc
# **********
# 0.5349047141424272
# srcAddress_gp_destAddressPort_nunique_rate
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [301]	training's auc: 0.875532	valid_0's auc: 0.890661
# Evaluated only: auc
# **********
# 0.8906611095422189
# destAddress_gp_srcAddress_nunique_rate
# Training until validation scores don't improve for 50 rounds
# [500]	training's auc: 0.879205	valid_0's auc: 0.894043
# Early stopping, best iteration is:
# [531]	training's auc: 0.87929	valid_0's auc: 0.894132
# Evaluated only: auc
# **********
# 0.8941322998120576
# destAddress_gp_srcAddressPort_nunique_rate
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.53683	valid_0's auc: 0.534905
# Evaluated only: auc
# **********
# 0.5349047141424272
# destAddress_gp_destAddressPort_nunique_rate
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [301]	training's auc: 0.875282	valid_0's auc: 0.890519
# Evaluated only: auc
# **********
# 0.8905191302061525
# srcAddressPort_gp_srcAddress_nunique_rate
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [20]	training's auc: 0.565603	valid_0's auc: 0.553292
# Evaluated only: auc
# **********
# 0.5532915250606187
# srcAddressPort_gp_destAddress_nunique_rate
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.559008	valid_0's auc: 0.555567
# Evaluated only: auc
# **********
# 0.5555667001003008
# srcAddressPort_gp_destAddressPort_nunique_rate
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.558974	valid_0's auc: 0.555466
# Evaluated only: auc
# **********
# 0.5554663991975928
# destAddressPort_gp_srcAddress_nunique_rate
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [144]	training's auc: 0.879223	valid_0's auc: 0.894704
# Evaluated only: auc
# **********
# 0.8947041123370111
# destAddressPort_gp_destAddress_nunique_rate
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [303]	training's auc: 0.877881	valid_0's auc: 0.893263
# Evaluated only: auc
# **********
# 0.8932630902415986
# destAddressPort_gp_srcAddressPort_nunique_rate
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.53683	valid_0's auc: 0.534905
# Evaluated only: auc
# **********
# 0.5349047141424272
# tlsVersion_map
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.505352	valid_0's auc: 0.506018
# Evaluated only: auc
# **********
# 0.5060180541624875
# srcAddress_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [412]	training's auc: 0.868121	valid_0's auc: 0.889393
# Evaluated only: auc
# **********
# 0.8893926439512713
# destAddress_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [27]	training's auc: 0.877894	valid_0's auc: 0.893326
# Evaluated only: auc
# **********
# 0.8933261921687392
# tlsVersion_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [43]	training's auc: 0.746003	valid_0's auc: 0.732784
# Evaluated only: auc
# **********
# 0.7327837882579779
# tlsSubject_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [8]	training's auc: 0.971016	valid_0's auc: 0.971879
# Evaluated only: auc
# **********
# 0.9718789377842265
# tlsIssuerDn_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [74]	training's auc: 0.989946	valid_0's auc: 0.985596
# Evaluated only: auc
# **********
# 0.9855956218169071
# tlsSni_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [30]	training's auc: 0.88338	valid_0's auc: 0.89236
# Evaluated only: auc
# **********
# 0.8923599925991567
# srcAddressPort_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.53683	valid_0's auc: 0.534905
# Evaluated only: auc
# **********
# 0.5349047141424272
# destAddressPort_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [301]	training's auc: 0.875282	valid_0's auc: 0.890519
# Evaluated only: auc
# **********
# 0.8905191302061525
# srcAddress_bytesOut_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [412]	training's auc: 0.868121	valid_0's auc: 0.889393
# Evaluated only: auc
# **********
# 0.8893926439512713
# srcAddress_bytesOut_max
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [88]	training's auc: 0.909593	valid_0's auc: 0.905792
# Evaluated only: auc
# **********
# 0.9057923284416356
# srcAddress_bytesOut_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [105]	training's auc: 0.950419	valid_0's auc: 0.944002
# Evaluated only: auc
# **********
# 0.9440022981566057
# srcAddress_bytesOut_median
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [73]	training's auc: 0.939023	valid_0's auc: 0.930013
# Evaluated only: auc
# **********
# 0.9300127567167522
# srcAddress_bytesOut_mean
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [74]	training's auc: 0.890801	valid_0's auc: 0.882729
# Evaluated only: auc
# **********
# 0.8827285740717298
# srcAddress_bytesOut_sum
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [34]	training's auc: 0.912635	valid_0's auc: 0.917012
# Evaluated only: auc
# **********
# 0.9170118121354355
# srcAddress_bytesOut_skew
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [193]	training's auc: 0.912189	valid_0's auc: 0.918205
# Evaluated only: auc
# **********
# 0.9182052954981449
# srcAddress_bytesOut_std
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [241]	training's auc: 0.897127	valid_0's auc: 0.882863
# Evaluated only: auc
# **********
# 0.8828625682873864
# srcAddress_bytesOut_nunique
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [160]	training's auc: 0.823592	valid_0's auc: 0.840964
# Evaluated only: auc
# **********
# 0.8409640572202043
# srcAddress_bytesOut_max_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [155]	training's auc: 0.90751	valid_0's auc: 0.903204
# Evaluated only: auc
# **********
# 0.9032037861156285
# srcAddress_bytesOut_quantile_25
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [122]	training's auc: 0.950159	valid_0's auc: 0.929296
# Evaluated only: auc
# **********
# 0.9292958487111821
# srcAddress_bytesOut_quantile_75
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [87]	training's auc: 0.924233	valid_0's auc: 0.913402
# Evaluated only: auc
# **********
# 0.9134017586740805
# srcAddress_bytesIn_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [412]	training's auc: 0.868121	valid_0's auc: 0.889393
# Evaluated only: auc
# **********
# 0.8893926439512713
# srcAddress_bytesIn_max
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [157]	training's auc: 0.860396	valid_0's auc: 0.851528
# Evaluated only: auc
# **********
# 0.8515281767632996
# srcAddress_bytesIn_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [103]	training's auc: 0.946906	valid_0's auc: 0.939495
# Evaluated only: auc
# **********
# 0.939494795064806
# srcAddress_bytesIn_median
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [142]	training's auc: 0.92588	valid_0's auc: 0.899146
# Evaluated only: auc
# **********
# 0.8991463711522918
# srcAddress_bytesIn_mean
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [91]	training's auc: 0.894116	valid_0's auc: 0.877326
# Evaluated only: auc
# **********
# 0.8773257636988636
# srcAddress_bytesIn_sum
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [49]	training's auc: 0.91924	valid_0's auc: 0.909983
# Evaluated only: auc
# **********
# 0.9099829585844913
# srcAddress_bytesIn_skew
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [193]	training's auc: 0.909217	valid_0's auc: 0.900477
# Evaluated only: auc
# **********
# 0.9004765753571394
# srcAddress_bytesIn_std
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [64]	training's auc: 0.894195	valid_0's auc: 0.897403
# Evaluated only: auc
# **********
# 0.8974030830355143
# srcAddress_bytesIn_nunique
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [25]	training's auc: 0.836345	valid_0's auc: 0.851749
# Evaluated only: auc
# **********
# 0.8517486439902231
# srcAddress_bytesIn_max_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [177]	training's auc: 0.900252	valid_0's auc: 0.895976
# Evaluated only: auc
# **********
# 0.8959762783496119
# srcAddress_bytesIn_quantile_25
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [44]	training's auc: 0.937725	valid_0's auc: 0.919328
# Evaluated only: auc
# **********
# 0.919327691813304
# srcAddress_bytesIn_quantile_75
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [214]	training's auc: 0.896722	valid_0's auc: 0.886512
# Evaluated only: auc
# **********
# 0.8865115735556183
# srcAddress_pktsIn_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [412]	training's auc: 0.868121	valid_0's auc: 0.889393
# Evaluated only: auc
# **********
# 0.8893926439512713
# srcAddress_pktsIn_max
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [198]	training's auc: 0.844582	valid_0's auc: 0.838723
# Evaluated only: auc
# **********
# 0.8387227702525051
# srcAddress_pktsIn_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.883645	valid_0's auc: 0.88793
# Evaluated only: auc
# **********
# 0.8879296140849734
# srcAddress_pktsIn_median
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	training's auc: 0.870699	valid_0's auc: 0.859399
# Evaluated only: auc
# **********
# 0.8593987788608544
# srcAddress_pktsIn_mean
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [158]	training's auc: 0.905282	valid_0's auc: 0.895304
# Evaluated only: auc
# **********
# 0.8953041649219503
# srcAddress_pktsIn_sum
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [69]	training's auc: 0.919183	valid_0's auc: 0.906403
# Evaluated only: auc
# **********
# 0.9064025084963628
# srcAddress_pktsIn_skew
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [82]	training's auc: 0.90316	valid_0's auc: 0.905787
# Evaluated only: auc
# **********
# 0.9057872647067415
# srcAddress_pktsIn_std
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [137]	training's auc: 0.895763	valid_0's auc: 0.896489
# Evaluated only: auc
# **********
# 0.8964890788871469
# srcAddress_pktsIn_nunique
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [6]	training's auc: 0.79421	valid_0's auc: 0.810951
# Evaluated only: auc
# **********
# 0.8109513005034521
# srcAddress_pktsIn_max_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [149]	training's auc: 0.902825	valid_0's auc: 0.903557
# Evaluated only: auc
# **********
# 0.9035572737630366
# srcAddress_pktsIn_quantile_25
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [30]	training's auc: 0.900715	valid_0's auc: 0.893857
# Evaluated only: auc
# **********
# 0.8938569105374375
# srcAddress_pktsIn_quantile_75
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [82]	training's auc: 0.861677	valid_0's auc: 0.849421
# Evaluated only: auc
# **********
# 0.8494212735293258
# srcAddress_pktsOut_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [412]	training's auc: 0.868121	valid_0's auc: 0.889393
# Evaluated only: auc
# **********
# 0.8893926439512713
# srcAddress_pktsOut_max
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [234]	training's auc: 0.861048	valid_0's auc: 0.837998
# Evaluated only: auc
# **********
# 0.8379980718855596
# srcAddress_pktsOut_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [3]	training's auc: 0.848401	valid_0's auc: 0.856082
# Evaluated only: auc
# **********
# 0.8560818377462485
# srcAddress_pktsOut_median
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [65]	training's auc: 0.84532	valid_0's auc: 0.824322
# Evaluated only: auc
# **********
# 0.8243217029729967
# srcAddress_pktsOut_mean
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [112]	training's auc: 0.896685	valid_0's auc: 0.888326
# Evaluated only: auc
# **********
# 0.888326338238015
# srcAddress_pktsOut_sum
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [118]	training's auc: 0.917692	valid_0's auc: 0.905356
# Evaluated only: auc
# **********
# 0.9053556786865451
# srcAddress_pktsOut_skew
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [147]	training's auc: 0.914916	valid_0's auc: 0.910824
# Evaluated only: auc
# **********
# 0.9108235385768957
# srcAddress_pktsOut_std
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [102]	training's auc: 0.896799	valid_0's auc: 0.892613
# Evaluated only: auc
# **********
# 0.8926131793438569
# srcAddress_pktsOut_nunique
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [5]	training's auc: 0.796447	valid_0's auc: 0.8138
# Evaluated only: auc
# **********
# 0.8138002356584316
# srcAddress_pktsOut_max_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [123]	training's auc: 0.899609	valid_0's auc: 0.905793
# Evaluated only: auc
# **********
# 0.9057931074777731
# srcAddress_pktsOut_quantile_25
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [54]	training's auc: 0.881417	valid_0's auc: 0.87352
# Evaluated only: auc
# **********
# 0.8735197826489176
# srcAddress_pktsOut_quantile_75
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [153]	training's auc: 0.867168	valid_0's auc: 0.852827
# Evaluated only: auc
# **********
# 0.8528270247636113
# destAddress_bytesOut_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [27]	training's auc: 0.877894	valid_0's auc: 0.893326
# Evaluated only: auc
# **********
# 0.8933261921687392
# destAddress_bytesOut_max
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [178]	training's auc: 0.915689	valid_0's auc: 0.915864
# Evaluated only: auc
# **********
# 0.9158644866638751
# destAddress_bytesOut_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [34]	training's auc: 0.956225	valid_0's auc: 0.960089
# Evaluated only: auc
# **********
# 0.9600888101196794
# destAddress_bytesOut_median
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [98]	training's auc: 0.948804	valid_0's auc: 0.943354
# Evaluated only: auc
# **********
# 0.9433535558130702
# destAddress_bytesOut_mean
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [179]	training's auc: 0.908752	valid_0's auc: 0.905836
# Evaluated only: auc
# **********
# 0.9058363439834065
# destAddress_bytesOut_sum
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [31]	training's auc: 0.918142	valid_0's auc: 0.91659
# Evaluated only: auc
# **********
# 0.9165897693079238
# destAddress_bytesOut_skew
# Training until validation scores don't improve for 50 rounds
# [500]	training's auc: 0.912356	valid_0's auc: 0.917377
# Early stopping, best iteration is:
# [510]	training's auc: 0.912356	valid_0's auc: 0.917408
# Evaluated only: auc
# **********
# 0.9174083415294427
# destAddress_bytesOut_std
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [126]	training's auc: 0.914753	valid_0's auc: 0.914626
# Evaluated only: auc
# **********
# 0.9146260139642227
# destAddress_bytesOut_nunique
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [110]	training's auc: 0.841558	valid_0's auc: 0.851168
# Evaluated only: auc
# **********
# 0.8511680673087223
# destAddress_bytesOut_max_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [160]	training's auc: 0.920242	valid_0's auc: 0.921942
# Evaluated only: auc
# **********
# 0.9219421370908844
# destAddress_bytesOut_quantile_25
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [67]	training's auc: 0.954228	valid_0's auc: 0.945397
# Evaluated only: auc
# **********
# 0.9453973571199034
# destAddress_bytesOut_quantile_75
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [90]	training's auc: 0.937376	valid_0's auc: 0.928256
# Evaluated only: auc
# **********
# 0.9282560302266022
# destAddress_bytesIn_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [27]	training's auc: 0.877894	valid_0's auc: 0.893326
# Evaluated only: auc
# **********
# 0.8933261921687392
# destAddress_bytesIn_max
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [443]	training's auc: 0.872084	valid_0's auc: 0.867109
# Evaluated only: auc
# **********
# 0.8671085099960074
# destAddress_bytesIn_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [75]	training's auc: 0.951377	valid_0's auc: 0.940598
# Evaluated only: auc
# **********
# 0.9405982997536299
# destAddress_bytesIn_median
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [130]	training's auc: 0.929943	valid_0's auc: 0.916689
# Evaluated only: auc
# **********
# 0.9166889016564256
# destAddress_bytesIn_mean
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [124]	training's auc: 0.90489	valid_0's auc: 0.895777
# Evaluated only: auc
# **********
# 0.895776845098402
# destAddress_bytesIn_sum
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [271]	training's auc: 0.927003	valid_0's auc: 0.91951
# Evaluated only: auc
# **********
# 0.9195103757875569
# destAddress_bytesIn_skew
# Training until validation scores don't improve for 50 rounds
# [500]	training's auc: 0.912411	valid_0's auc: 0.919846
# Early stopping, best iteration is:
# [506]	training's auc: 0.912586	valid_0's auc: 0.920023
# Evaluated only: auc
# **********
# 0.9200233710841261
# destAddress_bytesIn_std
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [164]	training's auc: 0.917811	valid_0's auc: 0.919471
# Evaluated only: auc
# **********
# 0.9194712292216455
# destAddress_bytesIn_nunique
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [28]	training's auc: 0.846145	valid_0's auc: 0.855253
# Evaluated only: auc
# **********
# 0.8552527485368727
# destAddress_bytesIn_max_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [100]	training's auc: 0.908337	valid_0's auc: 0.907116
# Evaluated only: auc
# **********
# 0.9071159108393141
# destAddress_bytesIn_quantile_25
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [77]	training's auc: 0.947217	valid_0's auc: 0.935666
# Evaluated only: auc
# **********
# 0.9356664167259059
# destAddress_bytesIn_quantile_75
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [128]	training's auc: 0.901038	valid_0's auc: 0.888117
# Evaluated only: auc
# **********
# 0.8881165827579827
# destAddress_pktsIn_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [27]	training's auc: 0.877894	valid_0's auc: 0.893326
# Evaluated only: auc
# **********
# 0.8933261921687392
# destAddress_pktsIn_max
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [155]	training's auc: 0.854617	valid_0's auc: 0.850314
# Evaluated only: auc
# **********
# 0.8503144384610141
# destAddress_pktsIn_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	training's auc: 0.896322	valid_0's auc: 0.896554
# Evaluated only: auc
# **********
# 0.8965537388865626
# destAddress_pktsIn_median
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [7]	training's auc: 0.874879	valid_0's auc: 0.866275
# Evaluated only: auc
# **********
# 0.8662747465698065
# destAddress_pktsIn_mean
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [142]	training's auc: 0.927929	valid_0's auc: 0.92168
# Evaluated only: auc
# **********
# 0.9216796019125337
# destAddress_pktsIn_sum
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [71]	training's auc: 0.922606	valid_0's auc: 0.919846
# Evaluated only: auc
# **********
# 0.9198463351218704
# destAddress_pktsIn_skew
# Training until validation scores don't improve for 50 rounds
# [500]	training's auc: 0.909334	valid_0's auc: 0.920512
# Early stopping, best iteration is:
# [472]	training's auc: 0.909313	valid_0's auc: 0.920604
# Evaluated only: auc
# **********
# 0.9206041425246614
# destAddress_pktsIn_std
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [235]	training's auc: 0.912035	valid_0's auc: 0.912476
# Evaluated only: auc
# **********
# 0.91247606898365
# destAddress_pktsIn_nunique
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [47]	training's auc: 0.816671	valid_0's auc: 0.826234
# Evaluated only: auc
# **********
# 0.8262336524135513
# destAddress_pktsIn_max_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [369]	training's auc: 0.903089	valid_0's auc: 0.905008
# Evaluated only: auc
# **********
# 0.905007839051134
# destAddress_pktsIn_quantile_25
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [36]	training's auc: 0.902541	valid_0's auc: 0.895559
# Evaluated only: auc
# **********
# 0.8955589097389255
# destAddress_pktsIn_quantile_75
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [78]	training's auc: 0.87264	valid_0's auc: 0.857052
# Evaluated only: auc
# **********
# 0.857052127255553
# destAddress_pktsOut_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [27]	training's auc: 0.877894	valid_0's auc: 0.893326
# Evaluated only: auc
# **********
# 0.8933261921687392
# destAddress_pktsOut_max
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [38]	training's auc: 0.851028	valid_0's auc: 0.854588
# Evaluated only: auc
# **********
# 0.854587646434449
# destAddress_pktsOut_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [9]	training's auc: 0.868489	valid_0's auc: 0.871158
# Evaluated only: auc
# **********
# 0.8711583293570031
# destAddress_pktsOut_median
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [47]	training's auc: 0.835574	valid_0's auc: 0.829198
# Evaluated only: auc
# **********
# 0.8291978849168866
# destAddress_pktsOut_mean
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [102]	training's auc: 0.912652	valid_0's auc: 0.903725
# Evaluated only: auc
# **********
# 0.9037253508097107
# destAddress_pktsOut_sum
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [47]	training's auc: 0.913781	valid_0's auc: 0.913867
# Evaluated only: auc
# **********
# 0.9138666484891568
# destAddress_pktsOut_skew
# Training until validation scores don't improve for 50 rounds
# [500]	training's auc: 0.914998	valid_0's auc: 0.920471
# Early stopping, best iteration is:
# [554]	training's auc: 0.915101	valid_0's auc: 0.920648
# Evaluated only: auc
# **********
# 0.9206481580664323
# destAddress_pktsOut_std
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [237]	training's auc: 0.916506	valid_0's auc: 0.917231
# Evaluated only: auc
# **********
# 0.9172307212900839
# destAddress_pktsOut_nunique
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [8]	training's auc: 0.814211	valid_0's auc: 0.82279
# Evaluated only: auc
# **********
# 0.8227901179265953
# destAddress_pktsOut_max_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [383]	training's auc: 0.901411	valid_0's auc: 0.909667
# Evaluated only: auc
# **********
# 0.9096670594307193
# destAddress_pktsOut_quantile_25
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [49]	training's auc: 0.877388	valid_0's auc: 0.878171
# Evaluated only: auc
# **********
# 0.878171407426162
# destAddress_pktsOut_quantile_75
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [60]	training's auc: 0.868405	valid_0's auc: 0.866963
# Evaluated only: auc
# **********
# 0.8669634145153908
# tlsVersion_bytesOut_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [43]	training's auc: 0.746003	valid_0's auc: 0.732784
# Evaluated only: auc
# **********
# 0.7327837882579779
# tlsVersion_bytesOut_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [37]	training's auc: 0.557393	valid_0's auc: 0.561306
# Evaluated only: auc
# **********
# 0.5613060540845839
# tlsVersion_bytesOut_sum
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [43]	training's auc: 0.746003	valid_0's auc: 0.732784
# Evaluated only: auc
# **********
# 0.7327837882579779
# tlsVersion_bytesOut_skew
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [46]	training's auc: 0.746003	valid_0's auc: 0.732784
# Evaluated only: auc
# **********
# 0.7327837882579779
# tlsVersion_bytesOut_nunique
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [43]	training's auc: 0.746003	valid_0's auc: 0.732784
# Evaluated only: auc
# **********
# 0.7327837882579779
# tlsVersion_bytesIn_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [43]	training's auc: 0.746003	valid_0's auc: 0.732784
# Evaluated only: auc
# **********
# 0.7327837882579779
# tlsVersion_bytesIn_max
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [43]	training's auc: 0.746003	valid_0's auc: 0.732784
# Evaluated only: auc
# **********
# 0.7327837882579779
# tlsVersion_bytesIn_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [46]	training's auc: 0.745951	valid_0's auc: 0.732724
# Evaluated only: auc
# **********
# 0.7327241919934561
# tlsVersion_bytesIn_sum
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [43]	training's auc: 0.746003	valid_0's auc: 0.732784
# Evaluated only: auc
# **********
# 0.7327837882579779
# tlsVersion_bytesIn_skew
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [36]	training's auc: 0.746003	valid_0's auc: 0.732784
# Evaluated only: auc
# **********
# 0.7327837882579779
# tlsVersion_bytesIn_nunique
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [43]	training's auc: 0.746003	valid_0's auc: 0.732784
# Evaluated only: auc
# **********
# 0.7327837882579779
# tlsVersion_bytesIn_max_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [43]	training's auc: 0.746003	valid_0's auc: 0.732784
# Evaluated only: auc
# **********
# 0.7327837882579779
# tlsVersion_pktsIn_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [43]	training's auc: 0.746003	valid_0's auc: 0.732784
# Evaluated only: auc
# **********
# 0.7327837882579779
# tlsVersion_pktsIn_max
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [43]	training's auc: 0.746003	valid_0's auc: 0.732784
# Evaluated only: auc
# **********
# 0.7327837882579779
# tlsVersion_pktsIn_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.716854	valid_0's auc: 0.70013
# Evaluated only: auc
# **********
# 0.7001295147578658
# tlsVersion_pktsIn_sum
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [43]	training's auc: 0.746003	valid_0's auc: 0.732784
# Evaluated only: auc
# **********
# 0.7327837882579779
# tlsVersion_pktsIn_skew
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [36]	training's auc: 0.746003	valid_0's auc: 0.732784
# Evaluated only: auc
# **********
# 0.7327837882579779
# tlsVersion_pktsIn_nunique
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [43]	training's auc: 0.746003	valid_0's auc: 0.732784
# Evaluated only: auc
# **********
# 0.7327837882579779
# tlsVersion_pktsIn_max_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [43]	training's auc: 0.746003	valid_0's auc: 0.732784
# Evaluated only: auc
# **********
# 0.7327837882579779
# tlsVersion_pktsIn_quantile_25
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.745556	valid_0's auc: 0.732545
# Evaluated only: auc
# **********
# 0.7325450136818221
# tlsVersion_pktsOut_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [43]	training's auc: 0.746003	valid_0's auc: 0.732784
# Evaluated only: auc
# **********
# 0.7327837882579779
# tlsVersion_pktsOut_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.665442	valid_0's auc: 0.645117
# Evaluated only: auc
# **********
# 0.6451169041103895
# tlsVersion_pktsOut_median
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [37]	training's auc: 0.746003	valid_0's auc: 0.732783
# Evaluated only: auc
# **********
# 0.732783398739909
# tlsVersion_pktsOut_nunique
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [43]	training's auc: 0.746003	valid_0's auc: 0.732784
# Evaluated only: auc
# **********
# 0.7327837882579779
# tlsVersion_pktsOut_quantile_25
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [37]	training's auc: 0.746003	valid_0's auc: 0.732783
# Evaluated only: auc
# **********
# 0.732783398739909
# tlsVersion_pktsOut_quantile_75
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [37]	training's auc: 0.746003	valid_0's auc: 0.732783
# Evaluated only: auc
# **********
# 0.732783398739909
# tlsSubject_bytesOut_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [8]	training's auc: 0.971016	valid_0's auc: 0.971879
# Evaluated only: auc
# **********
# 0.9718789377842265
# tlsSubject_bytesOut_max
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [232]	training's auc: 0.98296	valid_0's auc: 0.975857
# Evaluated only: auc
# **********
# 0.9758572805796029
# tlsSubject_bytesOut_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [74]	training's auc: 0.984894	valid_0's auc: 0.980142
# Evaluated only: auc
# **********
# 0.9801415898179977
# tlsSubject_bytesOut_median
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [39]	training's auc: 0.981804	valid_0's auc: 0.977018
# Evaluated only: auc
# **********
# 0.9770180444245358
# tlsSubject_bytesOut_mean
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [123]	training's auc: 0.983386	valid_0's auc: 0.978703
# Evaluated only: auc
# **********
# 0.978703489108101
# tlsSubject_bytesOut_sum
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [93]	training's auc: 0.987023	valid_0's auc: 0.98547
# Evaluated only: auc
# **********
# 0.9854700022397289
# tlsSubject_bytesOut_skew
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [41]	training's auc: 0.967251	valid_0's auc: 0.972721
# Evaluated only: auc
# **********
# 0.9727212706079403
# tlsSubject_bytesOut_std
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [122]	training's auc: 0.970115	valid_0's auc: 0.972424
# Evaluated only: auc
# **********
# 0.9724236788034005
# tlsSubject_bytesOut_nunique
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.966955	valid_0's auc: 0.964313
# Evaluated only: auc
# **********
# 0.9643131335754838
# tlsSubject_bytesOut_max_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [223]	training's auc: 0.985612	valid_0's auc: 0.985505
# Evaluated only: auc
# **********
# 0.9855052536249526
# tlsSubject_bytesOut_quantile_25
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [67]	training's auc: 0.984512	valid_0's auc: 0.980147
# Evaluated only: auc
# **********
# 0.9801466535528917
# tlsSubject_bytesOut_quantile_75
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [74]	training's auc: 0.982761	valid_0's auc: 0.974467
# Evaluated only: auc
# **********
# 0.974466701074096
# tlsSubject_bytesIn_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [8]	training's auc: 0.971016	valid_0's auc: 0.971879
# Evaluated only: auc
# **********
# 0.9718789377842265
# tlsSubject_bytesIn_max
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [34]	training's auc: 0.981268	valid_0's auc: 0.972674
# Evaluated only: auc
# **********
# 0.9726739441625848
# tlsSubject_bytesIn_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [60]	training's auc: 0.974173	valid_0's auc: 0.966128
# Evaluated only: auc
# **********
# 0.9661284825349836
# tlsSubject_bytesIn_median
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [300]	training's auc: 0.983396	valid_0's auc: 0.970328
# Evaluated only: auc
# **********
# 0.9703276820753522
# tlsSubject_bytesIn_mean
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [66]	training's auc: 0.983524	valid_0's auc: 0.974166
# Evaluated only: auc
# **********
# 0.9741659931250061
# tlsSubject_bytesIn_sum
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [76]	training's auc: 0.986237	valid_0's auc: 0.984054
# Evaluated only: auc
# **********
# 0.9840535197826489
# tlsSubject_bytesIn_skew
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [31]	training's auc: 0.962904	valid_0's auc: 0.969549
# Evaluated only: auc
# **********
# 0.9695492302149166
# tlsSubject_bytesIn_std
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [128]	training's auc: 0.970786	valid_0's auc: 0.973182
# Evaluated only: auc
# **********
# 0.973182265242329
# tlsSubject_bytesIn_nunique
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [19]	training's auc: 0.966184	valid_0's auc: 0.964823
# Evaluated only: auc
# **********
# 0.9648234022455716
# tlsSubject_bytesIn_max_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [85]	training's auc: 0.984708	valid_0's auc: 0.983812
# Evaluated only: auc
# **********
# 0.9838116290619431
# tlsSubject_bytesIn_quantile_25
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [37]	training's auc: 0.97883	valid_0's auc: 0.972775
# Evaluated only: auc
# **********
# 0.9727754136194993
# tlsSubject_bytesIn_quantile_75
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [61]	training's auc: 0.983226	valid_0's auc: 0.974931
# Evaluated only: auc
# **********
# 0.9749308118530349
# tlsSubject_pktsIn_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [8]	training's auc: 0.971016	valid_0's auc: 0.971879
# Evaluated only: auc
# **********
# 0.9718789377842265
# tlsSubject_pktsIn_max
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [255]	training's auc: 0.977975	valid_0's auc: 0.970838
# Evaluated only: auc
# **********
# 0.9708381455044746
# tlsSubject_pktsIn_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	training's auc: 0.891506	valid_0's auc: 0.889262
# Evaluated only: auc
# **********
# 0.8892615711211304
# tlsSubject_pktsIn_median
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [26]	training's auc: 0.95238	valid_0's auc: 0.950716
# Evaluated only: auc
# **********
# 0.9507164211079842
# tlsSubject_pktsIn_mean
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [67]	training's auc: 0.983921	valid_0's auc: 0.97595
# Evaluated only: auc
# **********
# 0.9759497911209356
# tlsSubject_pktsIn_sum
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [267]	training's auc: 0.984791	valid_0's auc: 0.983738
# Evaluated only: auc
# **********
# 0.9837380101469457
# tlsSubject_pktsIn_skew
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [47]	training's auc: 0.965534	valid_0's auc: 0.971547
# Evaluated only: auc
# **********
# 0.9715470683896349
# tlsSubject_pktsIn_std
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [110]	training's auc: 0.970396	valid_0's auc: 0.972462
# Evaluated only: auc
# **********
# 0.972462435851243
# tlsSubject_pktsIn_nunique
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.938912	valid_0's auc: 0.938345
# Evaluated only: auc
# **********
# 0.93834454820773
# tlsSubject_pktsIn_max_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [125]	training's auc: 0.984142	valid_0's auc: 0.982764
# Evaluated only: auc
# **********
# 0.9827640202159877
# tlsSubject_pktsIn_quantile_25
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [72]	training's auc: 0.953724	valid_0's auc: 0.9476
# Evaluated only: auc
# **********
# 0.9475996922807257
# tlsSubject_pktsIn_quantile_75
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [53]	training's auc: 0.956706	valid_0's auc: 0.953511
# Evaluated only: auc
# **********
# 0.9535110184923703
# tlsSubject_pktsOut_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [8]	training's auc: 0.971016	valid_0's auc: 0.971879
# Evaluated only: auc
# **********
# 0.9718789377842265
# tlsSubject_pktsOut_max
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [50]	training's auc: 0.973811	valid_0's auc: 0.966229
# Evaluated only: auc
# **********
# 0.9662285886786574
# tlsSubject_pktsOut_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [8]	training's auc: 0.892605	valid_0's auc: 0.894097
# Evaluated only: auc
# **********
# 0.8940968536677996
# tlsSubject_pktsOut_median
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [23]	training's auc: 0.941159	valid_0's auc: 0.940028
# Evaluated only: auc
# **********
# 0.9400276557828826
# tlsSubject_pktsOut_mean
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [222]	training's auc: 0.983045	valid_0's auc: 0.979987
# Evaluated only: auc
# **********
# 0.9799873406627649
# tlsSubject_pktsOut_sum
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [209]	training's auc: 0.985533	valid_0's auc: 0.985129
# Evaluated only: auc
# **********
# 0.9851285896524525
# tlsSubject_pktsOut_skew
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [34]	training's auc: 0.965584	valid_0's auc: 0.970169
# Evaluated only: auc
# **********
# 0.97016856394426
# tlsSubject_pktsOut_std
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [226]	training's auc: 0.97195	valid_0's auc: 0.974062
# Evaluated only: auc
# **********
# 0.9740617970416102
# tlsSubject_pktsOut_nunique
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [26]	training's auc: 0.942814	valid_0's auc: 0.94331
# Evaluated only: auc
# **********
# 0.9433099297893681
# tlsSubject_pktsOut_max_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [123]	training's auc: 0.982823	valid_0's auc: 0.981818
# Evaluated only: auc
# **********
# 0.9818176860679124
# tlsSubject_pktsOut_quantile_25
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [18]	training's auc: 0.932121	valid_0's auc: 0.93726
# Evaluated only: auc
# **********
# 0.9372595456271727
# tlsSubject_pktsOut_quantile_75
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [149]	training's auc: 0.962481	valid_0's auc: 0.95493
# Evaluated only: auc
# **********
# 0.9549300328168973
# tlsIssuerDn_bytesOut_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [74]	training's auc: 0.989946	valid_0's auc: 0.985596
# Evaluated only: auc
# **********
# 0.9855956218169071
# tlsIssuerDn_bytesOut_max
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [203]	training's auc: 0.990974	valid_0's auc: 0.986296
# Evaluated only: auc
# **********
# 0.9862955857864857
# tlsIssuerDn_bytesOut_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [59]	training's auc: 0.988872	valid_0's auc: 0.982625
# Evaluated only: auc
# **********
# 0.9826247675064027
# tlsIssuerDn_bytesOut_median
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [74]	training's auc: 0.990101	valid_0's auc: 0.985346
# Evaluated only: auc
# **********
# 0.985345551216757
# tlsIssuerDn_bytesOut_mean
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [187]	training's auc: 0.990374	valid_0's auc: 0.985503
# Evaluated only: auc
# **********
# 0.9855029165165399
# tlsIssuerDn_bytesOut_sum
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.98997	valid_0's auc: 0.986612
# Evaluated only: auc
# **********
# 0.9866120692173608
# tlsIssuerDn_bytesOut_skew
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [36]	training's auc: 0.975923	valid_0's auc: 0.976499
# Evaluated only: auc
# **********
# 0.9764990115979005
# tlsIssuerDn_bytesOut_std
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [103]	training's auc: 0.979665	valid_0's auc: 0.978227
# Evaluated only: auc
# **********
# 0.9782269137509616
# tlsIssuerDn_bytesOut_nunique
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [11]	training's auc: 0.98569	valid_0's auc: 0.984507
# Evaluated only: auc
# **********
# 0.9845071135737309
# tlsIssuerDn_bytesOut_max_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [172]	training's auc: 0.991412	valid_0's auc: 0.987892
# Evaluated only: auc
# **********
# 0.9878922203503715
# tlsIssuerDn_bytesOut_quantile_25
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [128]	training's auc: 0.99039	valid_0's auc: 0.986687
# Evaluated only: auc
# **********
# 0.9866874409636677
# tlsIssuerDn_bytesOut_quantile_75
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [27]	training's auc: 0.988543	valid_0's auc: 0.984271
# Evaluated only: auc
# **********
# 0.9842708708650223
# tlsIssuerDn_bytesIn_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [74]	training's auc: 0.989946	valid_0's auc: 0.985596
# Evaluated only: auc
# **********
# 0.9855956218169071
# tlsIssuerDn_bytesIn_max
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [17]	training's auc: 0.988627	valid_0's auc: 0.986171
# Evaluated only: auc
# **********
# ...
# Correlation drop features:
#  {'bytesIn', 'destAddress_bytesIn_quantile_75', 'destAddressPort_pktsOut_min', 'tlsIssuerDn_pktsOut_max', 'destAddressPort_pktsOut_sum', 'tlsSni_bytesIn_nunique', 'destAddressPort_bytesOut_count', 'tlsSubject_pktsIn_sum', 'tlsSubject_bytesOut_count', 'destAddressPort_pktsOut_quantile_75', 'destAddress_pktsOut_quantile_75', 'destAddress_gp_destAddressPort_nunique_rate', 'tlsSni_bytesOut_sum', 'destAddress_pktsIn_std', 'destAddressPort_bytesIn_count', 'srcAddressPort_bytesIn_quantile_25', 'destAddress_bytesOut_count', 'tlsSubject_pktsOut_count', 'tlsIssuerDn_pktsIn_max', 'destAddress_pktsIn_median', 'tlsVersion_pktsIn_nunique', 'tlsSni_pktsOut_count', 'destAddressPort_bytesIn_sum', 'destAddressPort_count', 'destAddressPort_bytesOut_sum', 'destAddressPort_pktsIn_nunique', 'tlsSubject_count', 'pktsIn_pktsOutc_multiply', 'destAddressPort_bytesOut_median', 'srcAddressPort_bytesIn_median', 'tlsIssuerDn_bytesOut_sum', 'destAddress_bytesOut_quantile_25', 'tlsVersion_pktsOut_count', 'destAddressPort_bytesIn_max', 'srcAddress_pktsIn_count', 'tlsSubject_bytesIn_sum', 'tlsIssuerDn_pktsOut_count', 'tlsSni_pktsOut_sum', 'srcAddressPort_bytesIn_min', 'srcAddressPort_pktsOut_quantile_75', 'bytesOut_bytesIn_ratio', 'destAddressPort_gp_srcAddressPort_nunique_rate', 'destAddressPort_pktsOut_nunique', 'destAddressPort_pktsIn_max', 'destAddress_gp_srcAddressPort_nunique_rate', 'destAddressPort_pktsIn_quantile_25', 'srcAddress_bytesOut_count', 'tlsSni_bytesOut_count', 'tlsIssuerDn_count', 'srcAddressPort_bytesIn_count', 'tlsIssuerDn_bytesOut_count', 'destAddressPort_pktsIn_count', 'destAddress_bytesOut_mean', 'srcAddressPort_pktsOut_min', 'destAddress_pktsIn_count', 'tlsVersion_pktsIn_count', 'destAddressPort_bytesIn_std', 'destAddress_bytesIn_skew', 'destAddress_bytesIn_count', 'srcAddress_bytesOut_sum', 'destAddress_pktsOut_max', 'tlsVersion_pktsIn_max', 'tlsSubject_pktsIn_count', 'destAddressPort_bytesOut_skew', 'srcAddress_pktsIn_sum', 'bytesOut', 'destAddressPort_bytesOut_min', 'bytesIn_pktsOutc_multiply', 'destAddress_pktsOut_count', 'srcAddressPort_pktsIn_median', 'tlsSni_pktsIn_count', 'destAddress_bytesOut_sum', 'tlsSubject_bytesIn_count', 'bytesOut_pktsOut_add', 'destAddress_bytesIn_mean', 'pktsIn_pktsOut_add', 'tlsVersion_bytesOut_nunique', 'destAddressPort_pktsIn_sum', 'tlsIssuerDn_bytesIn_max', 'destAddress_pktsIn_quantile_75', 'srcAddress_pktsOut_sum', 'destAddressPort_pktsOut_count', 'srcAddress_gp_destAddressPort_nunique_rate', 'destAddress_pktsOut_median', 'destAddress_gp_srcAddress_nunique_rate', 'destAddressPort_pktsOut_median', 'bytesOut_pktsIn_add', 'srcAddress_gp_srcAddressPort_nunique_rate', 'tlsVersion_bytesIn_sum', 'destAddress_bytesIn_sum', 'srcAddressPort_bytesOut_median', 'bytesOut_bytesIn_add', 'srcAddressPort_count', 'destAddressPort_bytesOut_nunique', 'destAddressPort_pktsOut_skew', 'tlsIssuerDn_bytesOut_nunique', 'destAddress_bytesIn_min', 'destAddress_pktsIn_min', 'destAddressPort_bytesIn_median', 'tlsVersion_bytesOut_sum', 'tlsVersion_bytesIn_nunique', 'tlsVersion_bytesIn_count', 'destAddress_pktsOut_sum', 'srcAddressPort_pktsIn_min', 'tlsVersion_bytesIn_max', 'srcAddressPort_bytesOut_count', 'srcAddressPort_pktsIn_max', 'srcAddressPort_bytesOut_max', 'destAddressPort_pktsIn_quantile_75', 'destAddress_bytesOut_std', 'srcAddressPort_pktsOut_quantile_25', 'destAddress_count', 'destAddressPort_pktsOut_std', 'srcAddressPort_pktsOut_median', 'srcAddressPort_gp_destAddressPort_nunique_rate', 'srcAddressPort_bytesIn_max', 'tlsIssuerDn_bytesIn_count', 'destAddressPort_bytesIn_max_min', 'tlsVersion_bytesIn_skew', 'srcAddressPort_pktsOut_max', 'pktsOut', 'tlsSni_bytesIn_count', 'srcAddressPort_bytesIn_mean', 'srcAddress_count', 'destAddress_pktsIn_max_min', 'destAddressPort_pktsIn_median', 'destAddress_pktsIn_quantile_25', 'tlsSubject_pktsOut_sum', 'destAddressPort_bytesOut_mean', 'tlsSni_pktsIn_sum', 'destAddressPort_bytesIn_mean', 'tlsIssuerDn_pktsIn_count', 'srcAddress_pktsOut_count', 'tlsVersion_bytesIn_max_min', 'destAdd ...
# used_cols:
#  ['srcPort', 'destPort', 'srcAddress_gp_destAddress_nunique_rate', 'srcAddressPort_gp_srcAddress_nunique_rate', 'srcAddressPort_gp_destAddress_nunique_rate', 'destAddressPort_gp_srcAddress_nunique_rate', 'srcAddress_bytesOut_max', 'srcAddress_bytesOut_min', 'srcAddress_bytesOut_median', 'srcAddress_bytesOut_mean', 'srcAddress_bytesOut_skew', 'srcAddress_bytesOut_std', 'srcAddress_bytesOut_nunique', 'srcAddress_bytesOut_max_min', 'srcAddress_bytesOut_quantile_25', 'srcAddress_bytesOut_quantile_75', 'srcAddress_bytesIn_max', 'srcAddress_bytesIn_min', 'srcAddress_bytesIn_median', 'srcAddress_bytesIn_mean', 'srcAddress_bytesIn_skew', 'srcAddress_bytesIn_std', 'srcAddress_bytesIn_nunique', 'srcAddress_bytesIn_max_min', 'srcAddress_bytesIn_quantile_25', 'srcAddress_bytesIn_quantile_75', 'srcAddress_pktsIn_max', 'srcAddress_pktsIn_min', 'srcAddress_pktsIn_median', 'srcAddress_pktsIn_mean', 'srcAddress_pktsIn_skew', 'srcAddress_pktsIn_std', 'srcAddress_pktsIn_nunique', 'srcAddress_pktsIn_max_min', 'srcAddress_pktsIn_quantile_25', 'srcAddress_pktsIn_quantile_75', 'srcAddress_pktsOut_max', 'srcAddress_pktsOut_min', 'srcAddress_pktsOut_median', 'srcAddress_pktsOut_mean', 'srcAddress_pktsOut_skew', 'srcAddress_pktsOut_std', 'srcAddress_pktsOut_nunique', 'srcAddress_pktsOut_max_min', 'srcAddress_pktsOut_quantile_25', 'srcAddress_pktsOut_quantile_75', 'destAddress_bytesOut_min', 'destAddress_bytesOut_median', 'destAddress_bytesOut_skew', 'destAddress_bytesOut_nunique', 'destAddress_bytesOut_quantile_75', 'destAddress_bytesIn_max', 'destAddress_bytesIn_median', 'destAddress_bytesIn_std', 'destAddress_bytesIn_max_min', 'destAddress_pktsIn_max', 'destAddress_pktsIn_mean', 'destAddress_pktsIn_sum', 'destAddress_pktsIn_skew', 'destAddress_pktsIn_nunique', 'destAddress_pktsOut_skew', 'destAddress_pktsOut_std', 'destAddress_pktsOut_nunique', 'destAddress_pktsOut_max_min', 'destAddress_pktsOut_quantile_25', 'tlsVersion_bytesOut_min', 'tlsVersion_bytesOut_skew', 'tlsVersion_bytesIn_min', 'tlsVersion_pktsIn_min', 'tlsVersion_pktsIn_skew', 'tlsVersion_pktsIn_max_min', 'tlsVersion_pktsIn_quantile_25', 'tlsVersion_pktsOut_min', 'tlsVersion_pktsOut_median', 'tlsVersion_pktsOut_nunique', 'tlsVersion_pktsOut_quantile_25', 'tlsVersion_pktsOut_quantile_75', 'tlsSubject_bytesOut_max', 'tlsSubject_bytesOut_min', 'tlsSubject_bytesOut_median', 'tlsSubject_bytesOut_mean', 'tlsSubject_bytesOut_sum', 'tlsSubject_bytesOut_skew', 'tlsSubject_bytesOut_std', 'tlsSubject_bytesOut_nunique', 'tlsSubject_bytesOut_max_min', 'tlsSubject_bytesOut_quantile_25', 'tlsSubject_bytesOut_quantile_75', 'tlsSubject_bytesIn_max', 'tlsSubject_bytesIn_min', 'tlsSubject_bytesIn_median', 'tlsSubject_bytesIn_mean', 'tlsSubject_bytesIn_skew', 'tlsSubject_bytesIn_std', 'tlsSubject_bytesIn_nunique', 'tlsSubject_bytesIn_max_min', 'tlsSubject_bytesIn_quantile_25', 'tlsSubject_bytesIn_quantile_75', 'tlsSubject_pktsIn_max', 'tlsSubject_pktsIn_min', 'tlsSubject_pktsIn_median', 'tlsSubject_pktsIn_mean', 'tlsSubject_pktsIn_skew', 'tlsSubject_pktsIn_std', 'tlsSubject_pktsIn_nunique', 'tlsSubject_pktsIn_max_min', 'tlsSubject_pktsIn_quantile_25', 'tlsSubject_pktsIn_quantile_75', 'tlsSubject_pktsOut_max', 'tlsSubject_pktsOut_min', 'tlsSubject_pktsOut_median', 'tlsSubject_pktsOut_mean', 'tlsSubject_pktsOut_skew', 'tlsSubject_pktsOut_std', 'tlsSubject_pktsOut_nunique', 'tlsSubject_pktsOut_max_min', 'tlsSubject_pktsOut_quantile_25', 'tlsSubject_pktsOut_quantile_75', 'tlsIssuerDn_bytesOut_min', 'tlsIssuerDn_bytesOut_median', 'tlsIssuerDn_bytesOut_mean', 'tlsIssuerDn_bytesOut_skew', 'tlsIssuerDn_bytesOut_std', 'tlsIssuerDn_bytesOut_max_min', 'tlsIssuerDn_bytesOut_quantile_25', 'tlsIssuerDn_bytesOut_quantile_75', 'tlsIssuerDn_bytesIn_min', 'tlsIssuerDn_bytesIn_median', 'tlsIssuerDn_bytesIn_skew', 'tlsIssuerDn_bytesIn_std', 'tlsIssuerDn_bytesIn_max_min', 'tlsIssuerDn_bytesIn_quantile_25', 'tlsIssuerDn_bytesIn_quantile_75', 'tlsIssuerDn_pktsIn_min', 'tlsIssuerDn_pktsIn_median', 'tlsIssuerDn_pktsIn_mean', 'tlsIss ...
# Training until validation scores don't improve for 200 rounds
# [300]	training's auc: 1	valid_1's auc: 0.999965
# Early stopping, best iteration is:
# [288]	training's auc: 1	valid_1's auc: 0.999966
# Evaluated only: auc
# threshold:  0.13
# Valid F1:  0.9913
# Valid mean label:  0.09454545454545454
# to drop:
#  ['destAddress_pktsOut_nunique', 'tlsSni_bytesIn_skew', 'tlsSubject_bytesIn_skew', 'bytesIn_pktsIn_ratio', 'srcAddress_pktsOut_max', 'srcAddress_bytesIn_median', 'tlsSni_bytesIn_min', 'srcAddress_bytesIn_max', 'tlsIssuerDn_pktsIn_median', 'tlsIssuerDn_bytesOut_skew', 'srcAddress_pktsOut_min', 'tlsSni_bytesOut_mean', 'destPort', 'tlsIssuerDn_bytesOut_median', 'srcAddress_pktsIn_max', 'destAddressPort_bytesIn_skew', 'tlsIssuerDn_pktsOut_mean', 'tlsSubject_bytesIn_median', 'tlsSubject_bytesOut_min', 'tlsSni_bytesOut_skew', 'pktsOut_bytesOut_ratio', 'destAddress_pktsIn_mean', 'srcAddress_gp_destAddress_nunique_rate', 'destAddress_bytesOut_median', 'tlsSubject_pktsIn_skew', 'tlsSni_pktsIn_max_min', 'tlsSni_pktsIn_quantile_75', 'destAddress_pktsIn_skew', 'tlsSubject_pktsOut_std', 'tlsIssuerDn_pktsOut_quantile_25', 'tlsIssuerDn_pktsOut_min', 'destAddressPort_pktsIn_std', 'bytesOut_bytesIn_subtract', 'srcAddress_bytesOut_quantile_25', 'srcAddress_bytesOut_mean', 'bytesOut_pktsIn_subtract', 'tlsSni_bytesOut_max', 'tlsSubject_pktsOut_quantile_75', 'srcAddress_pktsIn_std', 'tlsIssuerDn_pktsIn_std', 'bytesOut_pktsIn_ratio', 'tlsSubject_bytesIn_quantile_75', 'bytesOut_pktsOut_ratio', 'tlsSni_pktsOut_min', 'pktsOut_bytesIn_ratio', 'tlsSubject_pktsIn_median', 'tlsSubject_pktsOut_median', 'tlsSni_pktsOut_quantile_25', 'tlsSubject_pktsIn_nunique', 'tlsSni_bytesIn_max_min', 'destAddressPort_pktsOut_max', 'destAddressPort_bytesIn_min', 'tlsSubject_bytesOut_max', 'tlsSni_pktsOut_std', 'srcAddress_pktsIn_min', 'tlsSni_bytesOut_std', 'srcAddress_pktsOut_median', 'tlsSubject_pktsIn_std', 'srcAddress_pktsIn_median', 'destAddress_bytesIn_std', 'tlsIssuerDn_bytesIn_quantile_75', 'pktsIn_bytesOut_ratio', 'srcAddressPort_bytesOut_sum', 'srcAddress_pktsOut_std', 'srcAddressPort_gp_srcAddress_nunique_rate', 'srcAddress_pktsIn_mean', 'destAddress_bytesIn_max_min', 'srcAddress_pktsOut_quantile_25', 'tlsSubject_bytesOut_median', 'destAddressPort_bytesIn_quantile_75', 'pktsIn_bytesIn_ratio', 'tlsSubject_bytesIn_nunique', 'tlsSubject_pktsOut_max', 'destAddressPort_gp_srcAddress_nunique_rate', 'tlsIssuerDn_bytesIn_min', 'destAddress_pktsOut_std', 'destAddressPort_bytesOut_quantile_25', 'srcAddress_bytesIn_mean', 'srcAddress_bytesIn_max_min', 'destAddress_pktsOut_max_min', 'srcAddress_bytesOut_quantile_75', 'destAddress_bytesOut_quantile_75', 'srcAddress_bytesOut_skew', 'tlsSubject_pktsOut_nunique', 'destAddressPort_bytesOut_max', 'tlsSubject_bytesIn_mean', 'srcAddressPort_bytesIn_sum', 'destAddressPort_pktsIn_min', 'srcAddress_bytesIn_quantile_25', 'tlsSubject_bytesOut_skew', 'destAddress_pktsOut_skew', 'tlsIssuerDn_bytesIn_max_min', 'destAddressPort_pktsIn_max_min', 'tlsIssuerDn_pktsIn_max_min', 'srcAddress_pktsOut_max_min', 'srcAddressPort_bytesOut_quantile_75', 'tlsSubject_bytesOut_max_min', 'srcAddress_pktsIn_quantile_25', 'tlsSubject_pktsOut_min', 'tlsSni_pktsOut_mean', 'tlsSni_pktsIn_max', 'destAddressPort_bytesOut_std', 'tlsSni_pktsOut_median', 'tlsVersion_pktsIn_skew', 'destAddress_bytesOut_skew', 'tlsSni_bytesOut_quantile_75', 'srcAddress_pktsOut_quantile_75', 'tlsSni_pktsOut_skew', 'bytesIn_pktsOut_ratio', 'tlsSni_pktsOut_quantile_75', 'tlsSubject_pktsIn_min', 'tlsSubject_pktsOut_mean', 'tlsSni_pktsIn_nunique', 'bytesIn_pktsIn_add', 'destAddress_pktsIn_max', 'bytesOut_pktsOutc_multiply', 'tlsIssuerDn_bytesOut_max_min', 'destAddressPort_pktsOut_max_min', 'tlsSni_pktsIn_std', 'tlsSubject_bytesOut_mean', 'srcAddress_bytesIn_quantile_75', 'tlsVersion_bytesIn_min', 'bytesIn_pktsInc_multiply', 'tlsVersion_pktsIn_min', 'tlsSubject_bytesOut_quantile_75', 'srcAddress_pktsIn_quantile_75', 'tlsVersion_pktsOut_min', 'srcAddressPort_pktsOut_sum', 'destAddress_bytesOut_nunique', 'srcAddress_bytesOut_nunique', 'srcAddress_pktsIn_nunique', 'tlsIssuerDn_bytesOut_mean', 'destAddressPort_bytesOut_max_min', 'tlsVersion_pktsOut_quantile_75', 'srcAddress_pktsOut_nunique', 'srcAddress_pktsIn_max_min', 'tlsIssuerDn_pktsOut_median', 'destAddressPort_bytesIn_nunique', 'srcAddre ...
# len(to_drop):
#  156
# After train.shape (22000, 240)
# Before train.shape (22000, 84)
# Final cols:
#  ['srcPort', 'srcAddressPort_gp_destAddress_nunique_rate', 'srcAddress_bytesOut_max', 'srcAddress_bytesOut_min', 'srcAddress_bytesOut_median', 'srcAddress_bytesOut_std', 'srcAddress_bytesIn_min', 'srcAddress_bytesIn_skew', 'srcAddress_bytesIn_std', 'srcAddress_pktsIn_skew', 'srcAddress_pktsOut_mean', 'srcAddress_pktsOut_skew', 'destAddress_bytesOut_min', 'destAddress_bytesIn_max', 'destAddress_bytesIn_median', 'destAddress_pktsIn_sum', 'destAddress_pktsOut_quantile_25', 'tlsVersion_bytesOut_min', 'tlsVersion_bytesOut_skew', 'tlsSubject_bytesOut_sum', 'tlsSubject_bytesOut_std', 'tlsSubject_bytesOut_nunique', 'tlsSubject_bytesOut_quantile_25', 'tlsSubject_bytesIn_max', 'tlsSubject_bytesIn_min', 'tlsSubject_bytesIn_std', 'tlsSubject_bytesIn_max_min', 'tlsSubject_bytesIn_quantile_25', 'tlsSubject_pktsIn_max', 'tlsSubject_pktsIn_mean', 'tlsSubject_pktsIn_quantile_25', 'tlsSubject_pktsOut_skew', 'tlsSubject_pktsOut_max_min', 'tlsSubject_pktsOut_quantile_25', 'tlsIssuerDn_bytesOut_min', 'tlsIssuerDn_bytesOut_std', 'tlsIssuerDn_bytesOut_quantile_25', 'tlsIssuerDn_bytesOut_quantile_75', 'tlsIssuerDn_bytesIn_median', 'tlsIssuerDn_bytesIn_skew', 'tlsIssuerDn_bytesIn_std', 'tlsIssuerDn_bytesIn_quantile_25', 'tlsIssuerDn_pktsIn_min', 'tlsIssuerDn_pktsIn_mean', 'tlsIssuerDn_pktsIn_sum', 'tlsIssuerDn_pktsIn_skew', 'tlsIssuerDn_pktsIn_nunique', 'tlsIssuerDn_pktsIn_quantile_25', 'tlsIssuerDn_pktsIn_quantile_75', 'tlsIssuerDn_pktsOut_skew', 'tlsIssuerDn_pktsOut_std', 'tlsIssuerDn_pktsOut_nunique', 'tlsIssuerDn_pktsOut_max_min', 'tlsIssuerDn_pktsOut_quantile_75', 'tlsSni_bytesOut_min', 'tlsSni_bytesOut_median', 'tlsSni_bytesOut_nunique', 'tlsSni_bytesOut_max_min', 'tlsSni_bytesOut_quantile_25', 'tlsSni_bytesIn_max', 'tlsSni_bytesIn_median', 'tlsSni_bytesIn_mean', 'tlsSni_bytesIn_sum', 'tlsSni_bytesIn_std', 'tlsSni_bytesIn_quantile_25', 'tlsSni_bytesIn_quantile_75', 'tlsSni_pktsIn_min', 'tlsSni_pktsIn_median', 'tlsSni_pktsIn_mean', 'tlsSni_pktsIn_skew', 'tlsSni_pktsIn_quantile_25', 'tlsSni_pktsOut_max', 'tlsSni_pktsOut_nunique', 'tlsSni_pktsOut_max_min', 'destAddressPort_pktsOut_mean', 'bytesOut_pktsInc_multiply', 'bytesOut_pktsOut_subtract', 'bytesIn_pktsIn_subtract', 'bytesIn_pktsOut_add', 'bytesIn_pktsOut_subtract', 'pktsIn_pktsOut_subtract', 'bytesIn_bytesOut_ratio', 'pktsIn_pktsOut_ratio', 'pktsOut_pktsIn_ratio']
# Training until validation scores don't improve for 200 rounds
# [300]	training's auc: 1	valid_1's auc: 0.999962
# [600]	training's auc: 1	valid_1's auc: 0.999965
# Early stopping, best iteration is:
# [435]	training's auc: 1	valid_1's auc: 0.999966
# Evaluated only: auc
# threshold:  0.11
# Valid F1:  0.99225
# Valid mean label:  0.094
# Best iteration:
#  435
# Test mean label:  0.09212121212121212
