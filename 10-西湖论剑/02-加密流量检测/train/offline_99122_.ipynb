# %%
import numpy as np
import pandas as pd
import re
import gc
from tqdm import tqdm
from joblib import Parallel, delayed
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
import lightgbm as lgb
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
def count_encode(df, cols=[]):
    """
    count编码
    @param df:
    @param cols:
    @return:
    """
    for col in cols:
        print(col)
        vc = df[col].value_counts(dropna=True, normalize=True)
        df[col + '_count'] = df[col].map(vc).astype('float32')
    return df


def cross_cat_num(df, cat_col, num_col):
    """
    类别特征与数据特征groupby统计
    @param df:
    @param cat_col: 类别特征
    @param num_col: 数值特征
    @return:
    """
    def max_min(s):
        return s.max() - s.min()
    def quantile(s, q=0.25):
        return s.quantile(q)
    for f1 in tqdm(cat_col):
        g = df.groupby(f1, as_index=False)
        for f2 in tqdm(num_col):
            tmp = g[f2].agg({
                '{}_{}_count'.format(f1, f2): 'count',
                '{}_{}_max'.format(f1, f2): 'max',
                '{}_{}_min'.format(f1, f2): 'min',
                '{}_{}_median'.format(f1, f2): 'median',
                '{}_{}_mean'.format(f1, f2): 'mean',
                '{}_{}_sum'.format(f1, f2): 'sum',
                '{}_{}_skew'.format(f1, f2): 'skew',
                '{}_{}_std'.format(f1, f2): 'std',
                '{}_{}_nunique'.format(f1, f2): 'nunique',
                '{}_{}_max_min'.format(f1, f2): max_min,
                '{}_{}_quantile_25'.format(f1, f2): lambda x: quantile(x, 0.25),
                '{}_{}_quantile_75'.format(f1, f2): lambda x: quantile(x, 0.75)
            })
            df = df.merge(tmp, on=f1, how='left')
            del tmp
            gc.collect()
    return df


def arithmetic(df, cross_features):
    """
    数值特征之间的加减乘除
    @param df:
    @param cross_features: 交叉用的数值特征
    @return:
    """
    for i in tqdm(range(len(cross_features))):
        for j in range(i + 1, len(cross_features)):
            colname_add = '{}_{}_add'.format(cross_features[i], cross_features[j])
            colname_substract = '{}_{}_subtract'.format(cross_features[i], cross_features[j])
            colname_multiply = '{}_{}c_multiply'.format(cross_features[i], cross_features[j])
            df[colname_add] = df[cross_features[i]] + df[cross_features[j]]
            df[colname_substract] = df[cross_features[i]] - df[cross_features[j]]
            df[colname_multiply] = df[cross_features[i]] * df[cross_features[j]]

    for f1 in tqdm(cross_features):
        for f2 in cross_features:
            if f1 != f2:
                colname_ratio = '{}_{}_ratio'.format(f1, f2)
                df[colname_ratio] = df[f1].values / (df[f2].values + 0.001)
    return df

# %%
def get_psi(c, x_train, x_test):
    psi_res = pd.DataFrame()
    psi_dict={}
    # for c in tqdm(f_cols):
    try:
        t_train = x_train[c].fillna(-998)
        t_test = x_test[c].fillna(-998)
        #获取切分点
        bins=[]
        for i in np.arange(0,1.1,0.2):
            bins.append(t_train.quantile(i))
        bins=sorted(set(bins))
        bins[0]=-np.inf
        bins[-1]=np.inf
        #计算psi
        t_psi = pd.DataFrame()
        t_psi['train'] = pd.cut(t_train,bins).value_counts().sort_index()
        t_psi['test'] = pd.cut(t_test,bins).value_counts()
        t_psi.index=[str(x) for x in t_psi.index]
        t_psi.loc['总计',:] = t_psi.sum()
        t_psi['train_rate'] = t_psi['train']/t_psi.loc['总计','train']
        t_psi['test_rate'] = t_psi['test']/t_psi.loc['总计','test']
        t_psi['psi'] = (t_psi['test_rate']-t_psi['train_rate'])*(np.log(t_psi['test_rate'])-np.log(t_psi['train_rate']))
        t_psi.loc['总计','psi'] = t_psi['psi'].sum()
        t_psi.index.name=c
        #汇总
        t_res = pd.DataFrame([[c,t_psi.loc['总计','psi']]],
                             columns=['变量名','PSI'])
        psi_res = pd.concat([psi_res,t_res])
        psi_dict[c]=t_psi
        print(c,'done')
    except:
        print(c,'error')
    return psi_res #, psi_dict

# %%
def auc_select(X_train, y_train, X_valid, y_valid, cols, threshold=0.52):
    """
    基于AUC的单特征筛选
    @param X_train:
    @param y_train:
    @param X_valid:
    @param y_valid:
    @param cols:
    @return:
    """
    useful_dict = dict()
    useless_dict = dict()
    params = {
        'objective': 'binary',
        'boosting': 'gbdt',
        'metric': 'auc',
        'learning_rate': 0.1,
        'num_leaves': 31,
        'lambda_l1': 0,
        'lambda_l2': 1,
        'num_threads': 23,
        'min_data_in_leaf': 20,
        'first_metric_only': True,
        'is_unbalance': True,
        'max_depth': -1,
        'seed': 2020
    }
    for i in cols:
        print(i)
        lgb_train = lgb.Dataset(X_train[[i]].values, y_train)
        lgb_valid = lgb.Dataset(X_valid[[i]].values, y_valid, reference=lgb_train)
        lgb_model = lgb.train(
            params,
            lgb_train,
            valid_sets=[lgb_valid, lgb_train],
            num_boost_round=1000,
            early_stopping_rounds=50,
            verbose_eval=500
        )
        print('*' * 10)
        print(lgb_model.best_score['valid_0']['auc'])
        if lgb_model.best_score['valid_0']['auc'] > threshold:
            useful_dict[i] = lgb_model.best_score['valid_0']['auc']
        else:
            useless_dict[i] = lgb_model.best_score['valid_0']['auc']
    useful_cols = list(useful_dict.keys())
    useless_cols = list(useless_dict.keys())
    return useful_dict, useless_dict, useful_cols, useless_cols

# %%
def correlation(df, useful_dict, threshold=0.98):
    """
    去除特征相关系数大于阈值的特征
    @param df:
    @param threshold:
    @param useful_dict:
    @return:
    """
    col_corr = set()
    corr_matrix = df.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold:
                colName_i = corr_matrix.columns[i]
                colName_j = corr_matrix.columns[j]
                if useful_dict[colName_i] >= useful_dict[colName_j]:
                    col_corr.add(colName_j)
                else:
                    col_corr.add(colName_i)
    return list(col_corr)

# %%
def train_func(train_path, test_path, save_path):
    # 请填写训练代码
    train = pd.read_csv(train_path)
    test = pd.read_csv(test_path)
    data = pd.concat([train, test])
    del train, test
    gc.collect()

    single_cols = ['appProtocol']
    data.drop(single_cols, axis=1, inplace=True)
    gc.collect()

    cat_cols = ['srcAddress', 'destAddress',
                'tlsVersion', 'tlsSubject', 'tlsIssuerDn', 'tlsSni']

    data['srcAddressPort'] = data['srcAddress'].astype(str) + data['srcPort'].astype(str)
    data['destAddressPort'] = data['destAddress'].astype(str) + data['destPort'].astype(str)
    
    # srcAddress To destAddress
    tmp = data.groupby('srcAddress', as_index=False)['destAddress'].agg({
        's2d_count': 'count',
        's2d_nunique': 'nunique'
    })
    data = data.merge(tmp, on='srcAddress', how='left')
    del tmp
    gc.collect()
    
    # srcAddressPort To destAddressPort
    tmp = data.groupby('srcAddressPort', as_index=False)['destAddressPort'].agg({
        'sp2dp_count': 'count',
        'sp2dp_nunique': 'nunique'
    })
    data = data.merge(tmp, on='srcAddressPort', how='left')
    del tmp
    gc.collect()
    
    # srcAddress To destAddressPort
    tmp = data.groupby('srcAddress', as_index=False)['destAddressPort'].agg({
        's2dp_count': 'count',
        's2dp_nunique': 'nunique'
    })
    data = data.merge(tmp, on='srcAddress', how='left')
    del tmp
    gc.collect()
    
    # srcAddressPort To destAddress
    tmp = data.groupby('srcAddressPort', as_index=False)['destAddress'].agg({
        'sp2d_count': 'count',
        'sp2d_nunique': 'nunique'
    })
    data = data.merge(tmp, on='srcAddressPort', how='left')
    del tmp
    gc.collect()
    
    # destAddress To srcAddress
    tmp = data.groupby('destAddress', as_index=False)['srcAddress'].agg({
        'd2s_count': 'count',
        'd2s_nunique': 'nunique'
    })
    data = data.merge(tmp, on='destAddress', how='left')
    del tmp
    gc.collect()
    
    # destAddressPort To srcAddressPort
    tmp = data.groupby('destAddressPort', as_index=False)['srcAddressPort'].agg({
        'dp2sp_count': 'count',
        'dp2sp_nunique': 'nunique'
    })
    data = data.merge(tmp, on='destAddressPort', how='left')
    del tmp
    gc.collect()
    
    # destAddressPort To srcAddress
    tmp = data.groupby('destAddressPort', as_index=False)['srcAddress'].agg({
        'dp2s_count': 'count',
        'dp2s_nunique': 'nunique'
    })
    data = data.merge(tmp, on='destAddressPort', how='left')
    del tmp
    gc.collect()
    
    # destAddress To srcAddressProt
    tmp = data.groupby('destAddress', as_index=False)['srcAddressPort'].agg({
        'd2sp_count': 'count',
        'd2sp_nunique': 'nunique'
    })
    data = data.merge(tmp, on='destAddress', how='left')
    del tmp
    gc.collect()
    
    cat_cols += ['srcAddressPort', 'destAddressPort']
    num_cols = ['bytesOut', 'bytesIn', 'pktsIn', 'pktsOut']
#     data['bytesOut-bytesIn'] = data['bytesOut'] - data['bytesIn']
#     data['pktsOut-pktsIn'] = data['pktsOut'] - data['pktsIn']
    
    
    tlsVersion_map = {
        'TLSv1': 1,
        'TLS 1.2': 1,
        'TLS 1.3': 1,
        'SSLv2': 2,
        'SSLv3': 3,
        '0x4854': 4,
        '0x4752': 4,
        'UNDETERMINED': 5
    }
    data['tlsVersion_map'] = data['tlsVersion'].map(tlsVersion_map)
    cat_cols.append('tlsVersion_map')
    
    for i in cat_cols:
        print('-' * 20)
        print(i)
        lbl = LabelEncoder()
        data[i] = lbl.fit_transform(data[i].astype(str))
        data[i] = data[i].astype('category')

    data = count_encode(data, cat_cols)
    data = cross_cat_num(data, cat_cols, num_cols)
    data = arithmetic(data, num_cols)

#     for i in ['srcPort', 'destPort']:
#         data[i] = data[i].astype('category')
    
    used_cols = [i for i in data.columns if i not in ['eventId', 'label']]
    train = data.loc[data['label'].notnull(), :]
    test = data.loc[data['label'].isnull(), :]
    sub = test[['eventId']]
    
    print('*' * 20)
    print('srcAddress: ', 'srcAddress' in used_cols)
    print('destAddress: ', 'destAddress' in used_cols)
    print('tlsVersion: ', 'tlsVersion' in used_cols)
    print('tlsSubject: ', 'tlsSubject' in used_cols)
    print('tlsIssuerDn: ', 'tlsIssuerDn' in used_cols)
    print('tlsSni: ', 'tlsSni' in used_cols)
    print('srcAddressPort: ', 'destAddressPort' in used_cols)
    print('tlsVersion_map: ', 'tlsVersion_map' in used_cols)

    y = train['label']
    X = train[used_cols]
    X_test = test[used_cols]
    
    # 调用方法
    psi_res = Parallel(n_jobs=4)(delayed(get_psi)(c, X, X_test) for c in used_cols)
    psi_df = pd.concat(psi_res)
    psi_used_cols = list(psi_df[psi_df['PSI'] <= 0.2]['变量名'].values)
    psi_not_used_cols = list(psi_df[psi_df['PSI'] > 0.2]['变量名'].values)
    print('PSI used features: \n', psi_used_cols)
    print('PSI drop features: \n', psi_not_used_cols)
    print('Error drop features: \n', list(set(used_cols) - set(psi_used_cols)))
    
    X = X[psi_used_cols]
    X_test = X_test[psi_used_cols]
    
    X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.25, random_state=2020)
    
    print('y_train mean: ', y_train.mean())
    print('y_valid mean: ', y_valid.mean())
    
    print('*' * 20)
    print('srcAddress: ', 'srcAddress' in psi_used_cols)
    print('destAddress: ', 'destAddress' in psi_used_cols)
    print('tlsVersion: ', 'tlsVersion' in psi_used_cols)
    print('tlsSubject: ', 'tlsSubject' in psi_used_cols)
    print('tlsIssuerDn: ', 'tlsIssuerDn' in psi_used_cols)
    print('tlsSni: ', 'tlsSni' in psi_used_cols)
    print('srcAddressPort: ', 'destAddressPort' in psi_used_cols)
    print('tlsVersion_map: ', 'tlsVersion_map' in psi_used_cols)
    
    useful_dict, useless_dict, useful_cols, useless_cols = auc_select(X_train, y_train, X_valid, y_valid, psi_used_cols, threshold=0.52)
    print('AUC drop features: \n', useless_cols)
    
    X_train = X_train[useful_cols]
    X_valid = X_valid[useful_cols]
    X_test = X_test[useful_cols]
    
    col_corr = correlation(X_train, useful_dict, threshold=0.98)
    print('Correlation drop features: \n', col_corr)
    
    X_train.drop(col_corr, axis=1, inplace=True)
    X_valid.drop(col_corr, axis=1, inplace=True)
    X_test.drop(col_corr, axis=1, inplace=True)

    used_cols = X_train.columns.to_list()
    
    train_dataset = lgb.Dataset(X_train, y_train)
    valid_dataset = lgb.Dataset(X_valid, y_valid, reference=train_dataset)
    all_dataset = lgb.Dataset(train[used_cols], y, reference=train_dataset)

    params = {'objective': 'binary',
              'boosting': 'gbdt',
              'metric': 'auc',
              # 'metric': 'None',  # 用自定义评估函数是将metric设置为'None'
              'num_boost_round': 1000000,
              'learning_rate': 0.1,
              'num_leaves': 31,
              'lambda_l1': 0,
              'lambda_l2': 1,
              'num_threads': 23,
              'min_data_in_leaf': 20,
              'first_metric_only': True,
              'is_unbalance': True,
              'max_depth': -1,
              'seed': 2020}
    valid_model = lgb.train(params,
                            train_dataset,
                            valid_sets=[valid_dataset, train_dataset],
                            early_stopping_rounds=200,
                            verbose_eval=300)
    pred = valid_model.predict(X_valid)
    
    f1_best = 0
    for i in np.arange(0.1, 1, 0.01):
        y_valid_pred = np.where(pred > i, 1, 0)
        f1 = np.round(f1_score(y_valid, y_valid_pred), 5)
#         print('f1: ', f1)
        if f1 > f1_best:
            threshold = i
            f1_best = f1
        
    print('threshold: ', threshold)
    y_valid_pred = np.where(pred > threshold, 1, 0)
    print('Valid F1: ', np.round(f1_score(y_valid, y_valid_pred), 5))
    print('Valid mean label: ', np.mean(y_valid_pred))
#     binary_classification_report(y_valid, pred)
    
#     plt.figure(figsize=(8, 4))
#     ax = sns.kdeplot(pred, color='Red', shade=True)
#     ax.set_xlabel('pred')
#     ax.set_ylabel('Frequency')

    params = {'objective': 'binary',
              'boosting': 'gbdt',
              'metric': 'auc',
              # 'metric': 'None',  # 用自定义评估函数是将metric设置为'None'
              # 'num_boost_round': 1000000,
              'learning_rate': 0.1,
              'num_leaves': 31,
              'lambda_l1': 0,
              'lambda_l2': 1,
              'num_threads': 23,
              'min_data_in_leaf': 20,
              'first_metric_only': True,
              'is_unbalance': True,
              'max_depth': -1,
              'seed': 2020}
    train_model = lgb.train(params,
                            all_dataset,
                            num_boost_round=valid_model.best_iteration+20)
    y_test_pred = np.where(train_model.predict(X_test) > threshold, 1, 0)

    print('Test mean label: ', np.mean(y_test_pred))
    sub['label'] = y_test_pred
    sub.to_csv(save_path + '机器不学习原子弹也不学习_eta_submission_1020.csv', index=False)

# %%
if __name__ == '__main__':
    train_path = '../大数据队_eta_submission_1011/data/train.csv'
    test_path = '../大数据队_eta_submission_1011/data/test_1.csv'
    save_path = '../大数据队_eta_submission_1011/result/'
    train_func(train_path, test_path, save_path)
# Out:
# --------------------
# srcAddress
# --------------------
# destAddress
# --------------------
# tlsVersion
# --------------------
# tlsSubject
# --------------------
# tlsIssuerDn
# --------------------
# tlsSni
# --------------------
# srcAddressPort
# --------------------
# destAddressPort
# --------------------
# tlsVersion_map
# srcAddress
# destAddress
# tlsVersion
# tlsSubject
# tlsIssuerDn
# tlsSni
# srcAddressPort
#   0%|                                                                                            | 0/9 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/4 [00:00<?, ?it/s]
# destAddressPort
# tlsVersion_map
#  25%|█████████████████████                                                               | 1/4 [00:17<00:52, 17.34s/it]
#  50%|██████████████████████████████████████████                                          | 2/4 [00:34<00:34, 17.32s/it]
#  75%|███████████████████████████████████████████████████████████████                     | 3/4 [00:52<00:17, 17.50s/it]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 4/4 [01:09<00:00, 17.47s/it]
#  11%|█████████▎                                                                          | 1/9 [01:09<09:18, 69.87s/it]
#   0%|                                                                                            | 0/4 [00:00<?, ?it/s]
#  25%|█████████████████████                                                               | 1/4 [00:23<01:09, 23.31s/it]
#  50%|██████████████████████████████████████████                                          | 2/4 [00:47<00:46, 23.47s/it]
#  75%|███████████████████████████████████████████████████████████████                     | 3/4 [01:10<00:23, 23.57s/it]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 4/4 [01:34<00:00, 23.72s/it]
#  22%|██████████████████▋                                                                 | 2/9 [02:44<09:01, 77.37s/it]
#   0%|                                                                                            | 0/4 [00:00<?, ?it/s]
#  50%|██████████████████████████████████████████                                          | 2/4 [00:00<00:00, 10.45it/s]
#  75%|███████████████████████████████████████████████████████████████                     | 3/4 [00:00<00:00,  9.75it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00,  9.37it/s]
#  33%|████████████████████████████                                                        | 3/9 [02:45<05:25, 54.29s/it]
#   0%|                                                                                            | 0/4 [00:00<?, ?it/s]
#  25%|█████████████████████                                                               | 1/4 [00:02<00:07,  2.56s/it]
#  50%|██████████████████████████████████████████                                          | 2/4 [00:05<00:05,  2.57s/it]
#  75%|███████████████████████████████████████████████████████████████                     | 3/4 [00:07<00:02,  2.55s/it]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:10<00:00,  2.55s/it]
#  44%|█████████████████████████████████████▎                                              | 4/9 [02:55<03:25, 41.07s/it]
#   0%|                                                                                            | 0/4 [00:00<?, ?it/s]
#  25%|█████████████████████                                                               | 1/4 [00:00<00:01,  2.11it/s]
#  50%|██████████████████████████████████████████                                          | 2/4 [00:00<00:00,  2.09it/s]
#  75%|███████████████████████████████████████████████████████████████                     | 3/4 [00:01<00:00,  2.05it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:01<00:00,  2.04it/s]
#  56%|██████████████████████████████████████████████▋                                     | 5/9 [02:57<01:57, 29.34s/it]
#   0%|                                                                                            | 0/4 [00:00<?, ?it/s]
#  25%|█████████████████████                                                               | 1/4 [00:06<00:18,  6.02s/it]
#  50%|██████████████████████████████████████████                                          | 2/4 [00:12<00:12,  6.03s/it]
#  75%|███████████████████████████████████████████████████████████████                     | 3/4 [00:18<00:06,  6.10s/it]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:24<00:00,  6.10s/it]
#  67%|████████████████████████████████████████████████████████                            | 6/9 [03:21<01:23, 27.86s/it]
#   0%|                                                                                            | 0/4 [00:00<?, ?it/s]
#  25%|█████████████████████                                                               | 1/4 [00:38<01:54, 38.04s/it]
#  50%|██████████████████████████████████████████                                          | 2/4 [01:15<01:15, 37.84s/it]
#  75%|███████████████████████████████████████████████████████████████                     | 3/4 [01:52<00:37, 37.47s/it]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 4/4 [02:28<00:00, 37.19s/it]
#  78%|█████████████████████████████████████████████████████████████████▎                  | 7/9 [05:50<02:08, 64.14s/it]
#   0%|                                                                                            | 0/4 [00:00<?, ?it/s]
#  25%|█████████████████████                                                               | 1/4 [00:23<01:09, 23.21s/it]
#  50%|██████████████████████████████████████████                                          | 2/4 [00:46<00:46, 23.23s/it]
#  75%|███████████████████████████████████████████████████████████████                     | 3/4 [01:09<00:23, 23.21s/it]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 4/4 [01:33<00:00, 23.34s/it]
#  89%|██████████████████████████████████████████████████████████████████████████▋         | 8/9 [07:23<01:12, 72.92s/it]
#   0%|                                                                                            | 0/4 [00:00<?, ?it/s]
#  25%|█████████████████████                                                               | 1/4 [00:00<00:00,  6.74it/s]
#  50%|██████████████████████████████████████████                                          | 2/4 [00:00<00:00,  6.31it/s]
#  75%|███████████████████████████████████████████████████████████████                     | 3/4 [00:00<00:00,  6.05it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00,  5.63it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 9/9 [07:24<00:00, 49.41s/it]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 23.08it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 501.43it/s]
# ********************
# srcAddress:  True
# destAddress:  True
# tlsVersion:  True
# tlsSubject:  True
# tlsIssuerDn:  True
# tlsSni:  True
# srcAddressPort:  True
# tlsVersion_map:  True
# PSI used features:
#  ['srcPort', 'destPort', 'bytesOut', 'bytesIn', 'pktsIn', 'pktsOut', 's2d_count', 's2d_nunique', 'sp2dp_count', 'sp2dp_nunique', 's2dp_count', 's2dp_nunique', 'sp2d_count', 'sp2d_nunique', 'd2s_count', 'd2s_nunique', 'dp2sp_count', 'dp2sp_nunique', 'dp2s_count', 'dp2s_nunique', 'd2sp_count', 'd2sp_nunique', 'srcAddress_count', 'destAddress_count', 'tlsVersion_count', 'tlsSubject_count', 'tlsIssuerDn_count', 'tlsSni_count', 'srcAddressPort_count', 'destAddressPort_count', 'tlsVersion_map_count', 'srcAddress_bytesOut_count', 'srcAddress_bytesOut_max', 'srcAddress_bytesOut_min', 'srcAddress_bytesOut_median', 'srcAddress_bytesOut_mean', 'srcAddress_bytesOut_sum', 'srcAddress_bytesOut_skew', 'srcAddress_bytesOut_std', 'srcAddress_bytesOut_nunique', 'srcAddress_bytesOut_max_min', 'srcAddress_bytesOut_quantile_25', 'srcAddress_bytesOut_quantile_75', 'srcAddress_bytesIn_count', 'srcAddress_bytesIn_max', 'srcAddress_bytesIn_min', 'srcAddress_bytesIn_median', 'srcAddress_bytesIn_mean', 'srcAddress_bytesIn_sum', 'srcAddress_bytesIn_skew', 'srcAddress_bytesIn_std', 'srcAddress_bytesIn_nunique', 'srcAddress_bytesIn_max_min', 'srcAddress_bytesIn_quantile_25', 'srcAddress_bytesIn_quantile_75', 'srcAddress_pktsIn_count', 'srcAddress_pktsIn_max', 'srcAddress_pktsIn_min', 'srcAddress_pktsIn_median', 'srcAddress_pktsIn_mean', 'srcAddress_pktsIn_sum', 'srcAddress_pktsIn_skew', 'srcAddress_pktsIn_std', 'srcAddress_pktsIn_nunique', 'srcAddress_pktsIn_max_min', 'srcAddress_pktsIn_quantile_25', 'srcAddress_pktsIn_quantile_75', 'srcAddress_pktsOut_count', 'srcAddress_pktsOut_max', 'srcAddress_pktsOut_min', 'srcAddress_pktsOut_median', 'srcAddress_pktsOut_mean', 'srcAddress_pktsOut_sum', 'srcAddress_pktsOut_skew', 'srcAddress_pktsOut_std', 'srcAddress_pktsOut_nunique', 'srcAddress_pktsOut_max_min', 'srcAddress_pktsOut_quantile_25', 'srcAddress_pktsOut_quantile_75', 'destAddress_bytesOut_count', 'destAddress_bytesOut_max', 'destAddress_bytesOut_min', 'destAddress_bytesOut_median', 'destAddress_bytesOut_mean', 'destAddress_bytesOut_sum', 'destAddress_bytesOut_skew', 'destAddress_bytesOut_std', 'destAddress_bytesOut_nunique', 'destAddress_bytesOut_max_min', 'destAddress_bytesOut_quantile_25', 'destAddress_bytesOut_quantile_75', 'destAddress_bytesIn_count', 'destAddress_bytesIn_max', 'destAddress_bytesIn_min', 'destAddress_bytesIn_median', 'destAddress_bytesIn_mean', 'destAddress_bytesIn_sum', 'destAddress_bytesIn_skew', 'destAddress_bytesIn_std', 'destAddress_bytesIn_nunique', 'destAddress_bytesIn_max_min', 'destAddress_bytesIn_quantile_25', 'destAddress_bytesIn_quantile_75', 'destAddress_pktsIn_count', 'destAddress_pktsIn_max', 'destAddress_pktsIn_min', 'destAddress_pktsIn_median', 'destAddress_pktsIn_mean', 'destAddress_pktsIn_sum', 'destAddress_pktsIn_skew', 'destAddress_pktsIn_std', 'destAddress_pktsIn_nunique', 'destAddress_pktsIn_max_min', 'destAddress_pktsIn_quantile_25', 'destAddress_pktsIn_quantile_75', 'destAddress_pktsOut_count', 'destAddress_pktsOut_max', 'destAddress_pktsOut_min', 'destAddress_pktsOut_median', 'destAddress_pktsOut_mean', 'destAddress_pktsOut_sum', 'destAddress_pktsOut_skew', 'destAddress_pktsOut_std', 'destAddress_pktsOut_nunique', 'destAddress_pktsOut_max_min', 'destAddress_pktsOut_quantile_25', 'destAddress_pktsOut_quantile_75', 'tlsVersion_bytesOut_count', 'tlsVersion_bytesOut_max', 'tlsVersion_bytesOut_min', 'tlsVersion_bytesOut_median', 'tlsVersion_bytesOut_mean', 'tlsVersion_bytesOut_sum', 'tlsVersion_bytesOut_skew', 'tlsVersion_bytesOut_std', 'tlsVersion_bytesOut_nunique', 'tlsVersion_bytesOut_max_min', 'tlsVersion_bytesOut_quantile_25', 'tlsVersion_bytesOut_quantile_75', 'tlsVersion_bytesIn_count', 'tlsVersion_bytesIn_max', 'tlsVersion_bytesIn_min', 'tlsVersion_bytesIn_median', 'tlsVersion_bytesIn_mean', 'tlsVersion_bytesIn_sum', 'tlsVersion_bytesIn_skew', 'tlsVersion_bytesIn_std', 'tlsVersion_bytesIn_nunique', 'tlsVersion_bytesIn_max_min', 'tlsVersion_bytesIn_quantile_25', 'tlsVersion_bytesIn_quantile_75', 'tlsVersio ...
# PSI drop features:
#  []
# Error drop features:
#  ['tlsSubject', 'destAddress', 'srcAddress', 'srcAddressPort', 'tlsIssuerDn', 'tlsSni', 'tlsVersion_map', 'destAddressPort', 'tlsVersion']
# y_train mean:  0.09
# y_valid mean:  0.09363636363636364
# ********************
# srcAddress:  False
# destAddress:  False
# tlsVersion:  False
# tlsSubject:  False
# tlsIssuerDn:  False
# tlsSni:  False
# srcAddressPort:  False
# tlsVersion_map:  False
# srcPort
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [4]	training's auc: 0.930248	valid_0's auc: 0.935111
# Evaluated only: auc
# **********
# 0.9351113534779094
# destPort
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [118]	training's auc: 0.644376	valid_0's auc: 0.624224
# Evaluated only: auc
# **********
# 0.6242243234558043
# bytesOut
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [31]	training's auc: 0.921089	valid_0's auc: 0.911678
# Evaluated only: auc
# **********
# 0.9116779464607414
# bytesIn
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [10]	training's auc: 0.853758	valid_0's auc: 0.857234
# Evaluated only: auc
# **********
# 0.8572344217117371
# pktsIn
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [14]	training's auc: 0.826356	valid_0's auc: 0.818092
# Evaluated only: auc
# **********
# 0.818091945740133
# pktsOut
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [5]	training's auc: 0.796766	valid_0's auc: 0.788396
# Evaluated only: auc
# **********
# 0.7883964514903935
# s2d_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [90]	training's auc: 0.880897	valid_0's auc: 0.898577
# Evaluated only: auc
# **********
# 0.898576895735751
# s2d_nunique
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.508214	valid_0's auc: 0.518826
# Evaluated only: auc
# **********
# 0.5188256030226602
# sp2dp_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.536863	valid_0's auc: 0.534905
# Evaluated only: auc
# **********
# 0.5349047141424272
# sp2dp_nunique
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.5	valid_0's auc: 0.5
# Evaluated only: auc
# **********
# 0.5
# s2dp_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [90]	training's auc: 0.880897	valid_0's auc: 0.898577
# Evaluated only: auc
# **********
# 0.898576895735751
# s2dp_nunique
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	training's auc: 0.508069	valid_0's auc: 0.517954
# Evaluated only: auc
# **********
# 0.5179544458618575
# sp2d_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.536863	valid_0's auc: 0.534905
# Evaluated only: auc
# **********
# 0.5349047141424272
# sp2d_nunique
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.5	valid_0's auc: 0.5
# Evaluated only: auc
# **********
# 0.5
# d2s_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [305]	training's auc: 0.888345	valid_0's auc: 0.899283
# Evaluated only: auc
# **********
# 0.8992834815124987
# d2s_nunique
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.501095	valid_0's auc: 0.500903
# Evaluated only: auc
# **********
# 0.5009027081243731
# dp2sp_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [65]	training's auc: 0.887128	valid_0's auc: 0.899081
# Evaluated only: auc
# **********
# 0.8990805425986698
# dp2sp_nunique
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [30]	training's auc: 0.892082	valid_0's auc: 0.904249
# Evaluated only: auc
# **********
# 0.9042492526122056
# dp2s_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [65]	training's auc: 0.887128	valid_0's auc: 0.899081
# Evaluated only: auc
# **********
# 0.8990805425986698
# dp2s_nunique
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.500995	valid_0's auc: 0.500903
# Evaluated only: auc
# **********
# 0.5009027081243731
# d2sp_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [305]	training's auc: 0.888345	valid_0's auc: 0.899283
# Evaluated only: auc
# **********
# 0.8992834815124987
# d2sp_nunique
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [49]	training's auc: 0.892858	valid_0's auc: 0.904258
# Evaluated only: auc
# **********
# 0.9042582115277873
# srcAddress_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [90]	training's auc: 0.880897	valid_0's auc: 0.898577
# Evaluated only: auc
# **********
# 0.898576895735751
# destAddress_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [305]	training's auc: 0.888345	valid_0's auc: 0.899283
# Evaluated only: auc
# **********
# 0.8992834815124987
# tlsVersion_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [43]	training's auc: 0.746003	valid_0's auc: 0.732784
# Evaluated only: auc
# **********
# 0.7327837882579779
# tlsSubject_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [140]	training's auc: 0.97326	valid_0's auc: 0.973665
# Evaluated only: auc
# **********
# 0.973665267647603
# tlsIssuerDn_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [14]	training's auc: 0.99031	valid_0's auc: 0.987472
# Evaluated only: auc
# **********
# 0.9874715408361006
# tlsSni_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [68]	training's auc: 0.906358	valid_0's auc: 0.911589
# Evaluated only: auc
# **********
# 0.9115887468229933
# srcAddressPort_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.536863	valid_0's auc: 0.534905
# Evaluated only: auc
# **********
# 0.5349047141424272
# destAddressPort_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [65]	training's auc: 0.887128	valid_0's auc: 0.899081
# Evaluated only: auc
# **********
# 0.8990805425986698
# tlsVersion_map_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.505352	valid_0's auc: 0.506018
# Evaluated only: auc
# **********
# 0.5060180541624875
# srcAddress_bytesOut_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [90]	training's auc: 0.880897	valid_0's auc: 0.898577
# Evaluated only: auc
# **********
# 0.898576895735751
# srcAddress_bytesOut_max
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [239]	training's auc: 0.907158	valid_0's auc: 0.90268
# Evaluated only: auc
# **********
# 0.9026796895540992
# srcAddress_bytesOut_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [99]	training's auc: 0.946361	valid_0's auc: 0.93586
# Evaluated only: auc
# **********
# 0.935860396724153
# srcAddress_bytesOut_median
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [53]	training's auc: 0.944299	valid_0's auc: 0.943042
# Evaluated only: auc
# **********
# 0.943041551839986
# srcAddress_bytesOut_mean
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [122]	training's auc: 0.886018	valid_0's auc: 0.87586
# Evaluated only: auc
# **********
# 0.8758596176880155
# srcAddress_bytesOut_sum
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [201]	training's auc: 0.884401	valid_0's auc: 0.876699
# Evaluated only: auc
# **********
# 0.876699223885248
# srcAddress_bytesOut_skew
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [63]	training's auc: 0.911691	valid_0's auc: 0.912741
# Evaluated only: auc
# **********
# 0.9127405517523444
# srcAddress_bytesOut_std
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [80]	training's auc: 0.89915	valid_0's auc: 0.888474
# Evaluated only: auc
# **********
# 0.8884735760680098
# srcAddress_bytesOut_nunique
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [26]	training's auc: 0.82905	valid_0's auc: 0.844143
# Evaluated only: auc
# **********
# 0.8441425246613627
# srcAddress_bytesOut_max_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [80]	training's auc: 0.902771	valid_0's auc: 0.895926
# Evaluated only: auc
# **********
# 0.8959260305187406
# srcAddress_bytesOut_quantile_25
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [20]	training's auc: 0.944988	valid_0's auc: 0.935245
# Evaluated only: auc
# **********
# 0.9352445686574286
# srcAddress_bytesOut_quantile_75
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [131]	training's auc: 0.925043	valid_0's auc: 0.919013
# Evaluated only: auc
# **********
# 0.9190131559727727
# srcAddress_bytesIn_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [90]	training's auc: 0.880897	valid_0's auc: 0.898577
# Evaluated only: auc
# **********
# 0.898576895735751
# srcAddress_bytesIn_max
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [97]	training's auc: 0.863458	valid_0's auc: 0.837164
# Evaluated only: auc
# **********
# 0.8371641137003243
# srcAddress_bytesIn_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [157]	training's auc: 0.946083	valid_0's auc: 0.936184
# Evaluated only: auc
# **********
# 0.9361836967212317
# srcAddress_bytesIn_median
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [87]	training's auc: 0.924939	valid_0's auc: 0.911361
# Evaluated only: auc
# **********
# 0.9113606839937287
# srcAddress_bytesIn_mean
# Training until validation scores don't improve for 50 rounds
# [500]	training's auc: 0.889076	valid_0's auc: 0.879971
# Early stopping, best iteration is:
# [464]	training's auc: 0.889075	valid_0's auc: 0.880026
# Evaluated only: auc
# **********
# 0.8800259029515731
# srcAddress_bytesIn_sum
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [83]	training's auc: 0.880728	valid_0's auc: 0.868049
# Evaluated only: auc
# **********
# 0.8680490013730512
# srcAddress_bytesIn_skew
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [141]	training's auc: 0.918273	valid_0's auc: 0.915313
# Evaluated only: auc
# **********
# 0.9153127343194633
# srcAddress_bytesIn_std
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [241]	training's auc: 0.888142	valid_0's auc: 0.888044
# Evaluated only: auc
# **********
# 0.8880437428791228
# srcAddress_bytesIn_nunique
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [9]	training's auc: 0.838493	valid_0's auc: 0.85349
# Evaluated only: auc
# **********
# 0.8534897897576224
# srcAddress_bytesIn_max_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [90]	training's auc: 0.880856	valid_0's auc: 0.863665
# Evaluated only: auc
# **********
# 0.8636647807500171
# srcAddress_bytesIn_quantile_25
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [66]	training's auc: 0.945833	valid_0's auc: 0.929441
# Evaluated only: auc
# **********
# 0.9294405546737299
# srcAddress_bytesIn_quantile_75
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [119]	training's auc: 0.898405	valid_0's auc: 0.89566
# Evaluated only: auc
# **********
# 0.89566037919584
# srcAddress_pktsIn_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [90]	training's auc: 0.880897	valid_0's auc: 0.898577
# Evaluated only: auc
# **********
# 0.898576895735751
# srcAddress_pktsIn_max
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [95]	training's auc: 0.862757	valid_0's auc: 0.849576
# Evaluated only: auc
# **********
# 0.8495761069616616
# srcAddress_pktsIn_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [12]	training's auc: 0.879724	valid_0's auc: 0.883916
# Evaluated only: auc
# **********
# 0.8839164094224421
# srcAddress_pktsIn_median
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [10]	training's auc: 0.868155	valid_0's auc: 0.871545
# Evaluated only: auc
# **********
# 0.8715449260402567
# srcAddress_pktsIn_mean
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [126]	training's auc: 0.893704	valid_0's auc: 0.881079
# Evaluated only: auc
# **********
# 0.8810789650504913
# srcAddress_pktsIn_sum
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [53]	training's auc: 0.895135	valid_0's auc: 0.883848
# Evaluated only: auc
# **********
# 0.8838482437604074
# srcAddress_pktsIn_skew
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [117]	training's auc: 0.913692	valid_0's auc: 0.910071
# Evaluated only: auc
# **********
# 0.9100711844270676
# srcAddress_pktsIn_std
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [128]	training's auc: 0.899644	valid_0's auc: 0.891153
# Evaluated only: auc
# **********
# 0.8911532656221091
# srcAddress_pktsIn_nunique
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [163]	training's auc: 0.796262	valid_0's auc: 0.81828
# Evaluated only: auc
# **********
# 0.8182800829673487
# srcAddress_pktsIn_max_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [50]	training's auc: 0.851664	valid_0's auc: 0.850607
# Evaluated only: auc
# **********
# 0.8506069665306599
# srcAddress_pktsIn_quantile_25
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [19]	training's auc: 0.895904	valid_0's auc: 0.894413
# Evaluated only: auc
# **********
# 0.8944125580625372
# srcAddress_pktsIn_quantile_75
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [26]	training's auc: 0.854653	valid_0's auc: 0.858498
# Evaluated only: auc
# **********
# 0.8584978235677907
# srcAddress_pktsOut_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [90]	training's auc: 0.880897	valid_0's auc: 0.898577
# Evaluated only: auc
# **********
# 0.898576895735751
# srcAddress_pktsOut_max
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [58]	training's auc: 0.869233	valid_0's auc: 0.856084
# Evaluated only: auc
# **********
# 0.8560837853365924
# srcAddress_pktsOut_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [44]	training's auc: 0.850587	valid_0's auc: 0.84613
# Evaluated only: auc
# **********
# 0.8461300406072587
# srcAddress_pktsOut_median
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [27]	training's auc: 0.835254	valid_0's auc: 0.840954
# Evaluated only: auc
# **********
# 0.8409537349913819
# srcAddress_pktsOut_mean
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [126]	training's auc: 0.885013	valid_0's auc: 0.866151
# Evaluated only: auc
# **********
# 0.8661510745829722
# srcAddress_pktsOut_sum
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [133]	training's auc: 0.910997	valid_0's auc: 0.90447
# Evaluated only: auc
# **********
# 0.904469719839129
# srcAddress_pktsOut_skew
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [126]	training's auc: 0.917501	valid_0's auc: 0.918588
# Evaluated only: auc
# **********
# 0.9185876074826421
# srcAddress_pktsOut_std
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [168]	training's auc: 0.904859	valid_0's auc: 0.88614
# Evaluated only: auc
# **********
# 0.8861403628360811
# srcAddress_pktsOut_nunique
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	training's auc: 0.80498	valid_0's auc: 0.822382
# Evaluated only: auc
# **********
# 0.8223824872676281
# srcAddress_pktsOut_max_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [147]	training's auc: 0.874366	valid_0's auc: 0.865618
# Evaluated only: auc
# **********
# 0.8656178243468269
# srcAddress_pktsOut_quantile_25
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [16]	training's auc: 0.859361	valid_0's auc: 0.861141
# Evaluated only: auc
# **********
# 0.8611414827005288
# srcAddress_pktsOut_quantile_75
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [34]	training's auc: 0.851615	valid_0's auc: 0.849418
# Evaluated only: auc
# **********
# 0.8494175731076725
# destAddress_bytesOut_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [305]	training's auc: 0.888345	valid_0's auc: 0.899283
# Evaluated only: auc
# **********
# 0.8992834815124987
# destAddress_bytesOut_max
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [77]	training's auc: 0.924738	valid_0's auc: 0.919206
# Evaluated only: auc
# **********
# 0.9192063569348823
# destAddress_bytesOut_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [49]	training's auc: 0.957669	valid_0's auc: 0.957147
# Evaluated only: auc
# **********
# 0.9571465853872296
# destAddress_bytesOut_median
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [53]	training's auc: 0.946962	valid_0's auc: 0.949874
# Evaluated only: auc
# **********
# 0.9498735040071671
# destAddress_bytesOut_mean
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [135]	training's auc: 0.889059	valid_0's auc: 0.88011
# Evaluated only: auc
# **********
# 0.8801104283724961
# destAddress_bytesOut_sum
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [72]	training's auc: 0.895066	valid_0's auc: 0.883457
# Evaluated only: auc
# **********
# 0.8834573623783973
# destAddress_bytesOut_skew
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [223]	training's auc: 0.924214	valid_0's auc: 0.925829
# Evaluated only: auc
# **********
# 0.9258289431400999
# destAddress_bytesOut_std
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [174]	training's auc: 0.919233	valid_0's auc: 0.911048
# Evaluated only: auc
# **********
# 0.9110475114664381
# destAddress_bytesOut_nunique
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [12]	training's auc: 0.846698	valid_0's auc: 0.851322
# Evaluated only: auc
# **********
# 0.8513217321868518
# destAddress_bytesOut_max_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [113]	training's auc: 0.920979	valid_0's auc: 0.91607
# Evaluated only: auc
# **********
# 0.9160703469632198
# destAddress_bytesOut_quantile_25
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [35]	training's auc: 0.953468	valid_0's auc: 0.951472
# Evaluated only: auc
# **********
# 0.9514722809204312
# destAddress_bytesOut_quantile_75
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [303]	training's auc: 0.939264	valid_0's auc: 0.934578
# Evaluated only: auc
# **********
# 0.9345779084827297
# destAddress_bytesIn_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [305]	training's auc: 0.888345	valid_0's auc: 0.899283
# Evaluated only: auc
# **********
# 0.8992834815124987
# destAddress_bytesIn_max
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [96]	training's auc: 0.88273	valid_0's auc: 0.85829
# Evaluated only: auc
# **********
# 0.8582902104371366
# destAddress_bytesIn_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [72]	training's auc: 0.95368	valid_0's auc: 0.945044
# Evaluated only: auc
# **********
# 0.9450442589905639
# destAddress_bytesIn_median
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [91]	training's auc: 0.93018	valid_0's auc: 0.917417
# Evaluated only: auc
# **********
# 0.9174169109269557
# destAddress_bytesIn_mean
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [123]	training's auc: 0.880009	valid_0's auc: 0.869604
# Evaluated only: auc
# **********
# 0.86960356798551
# destAddress_bytesIn_sum
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [36]	training's auc: 0.885591	valid_0's auc: 0.889823
# Evaluated only: auc
# **********
# 0.8898234509353302
# destAddress_bytesIn_skew
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [205]	training's auc: 0.925609	valid_0's auc: 0.926435
# Evaluated only: auc
# **********
# 0.9264346437370363
# destAddress_bytesIn_std
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [147]	training's auc: 0.903524	valid_0's auc: 0.905645
# Evaluated only: auc
# **********
# 0.905644701093572
# destAddress_bytesIn_nunique
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [58]	training's auc: 0.84937	valid_0's auc: 0.857722
# Evaluated only: auc
# **********
# 0.8577215140567334
# destAddress_bytesIn_max_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [129]	training's auc: 0.910988	valid_0's auc: 0.897551
# Evaluated only: auc
# **********
# 0.8975514894197154
# destAddress_bytesIn_quantile_25
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [67]	training's auc: 0.949586	valid_0's auc: 0.942282
# Evaluated only: auc
# **********
# 0.9422819916058857
# destAddress_bytesIn_quantile_75
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [91]	training's auc: 0.905637	valid_0's auc: 0.887252
# Evaluated only: auc
# **********
# 0.8872524369224177
# destAddress_pktsIn_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [305]	training's auc: 0.888345	valid_0's auc: 0.899283
# Evaluated only: auc
# **********
# 0.8992834815124987
# destAddress_pktsIn_max
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [134]	training's auc: 0.868273	valid_0's auc: 0.858617
# Evaluated only: auc
# **********
# 0.8586166265787655
# destAddress_pktsIn_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [7]	training's auc: 0.89704	valid_0's auc: 0.899053
# Evaluated only: auc
# **********
# 0.8990528868157872
# destAddress_pktsIn_median
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [10]	training's auc: 0.876606	valid_0's auc: 0.871587
# Evaluated only: auc
# **********
# 0.8715869939916838
# destAddress_pktsIn_mean
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [210]	training's auc: 0.913012	valid_0's auc: 0.905917
# Evaluated only: auc
# **********
# 0.9059167794646075
# destAddress_pktsIn_sum
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [100]	training's auc: 0.913741	valid_0's auc: 0.892571
# Evaluated only: auc
# **********
# 0.8925707218743609
# destAddress_pktsIn_skew
# Training until validation scores don't improve for 50 rounds
# [500]	training's auc: 0.921632	valid_0's auc: 0.922285
# Early stopping, best iteration is:
# [602]	training's auc: 0.921769	valid_0's auc: 0.922537
# Evaluated only: auc
# **********
# 0.922537320699964
# destAddress_pktsIn_std
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [324]	training's auc: 0.923548	valid_0's auc: 0.919859
# Evaluated only: auc
# **********
# 0.9198589944591055
# destAddress_pktsIn_nunique
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [106]	training's auc: 0.820886	valid_0's auc: 0.831944
# Evaluated only: auc
# **********
# 0.8319435977836422
# destAddress_pktsIn_max_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [59]	training's auc: 0.873763	valid_0's auc: 0.877299
# Evaluated only: auc
# **********
# 0.8772994712292217
# destAddress_pktsIn_quantile_25
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [15]	training's auc: 0.900812	valid_0's auc: 0.903208
# Evaluated only: auc
# **********
# 0.9032084603324537
# destAddress_pktsIn_quantile_75
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [66]	training's auc: 0.85719	valid_0's auc: 0.855756
# Evaluated only: auc
# **********
# 0.855755616363654
# destAddress_pktsOut_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [305]	training's auc: 0.888345	valid_0's auc: 0.899283
# Evaluated only: auc
# **********
# 0.8992834815124987
# destAddress_pktsOut_max
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [80]	training's auc: 0.881057	valid_0's auc: 0.879432
# Evaluated only: auc
# **********
# 0.8794322774147686
# destAddress_pktsOut_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [9]	training's auc: 0.867826	valid_0's auc: 0.867885
# Evaluated only: auc
# **********
# 0.8678850142660993
# destAddress_pktsOut_median
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [16]	training's auc: 0.833799	valid_0's auc: 0.846423
# Evaluated only: auc
# **********
# 0.8464233477130421
# destAddress_pktsOut_mean
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [95]	training's auc: 0.905254	valid_0's auc: 0.894446
# Evaluated only: auc
# **********
# 0.8944462513754857
# destAddress_pktsOut_sum
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [54]	training's auc: 0.910891	valid_0's auc: 0.903006
# Evaluated only: auc
# **********
# 0.9030061056957279
# destAddress_pktsOut_skew
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [252]	training's auc: 0.9217	valid_0's auc: 0.92322
# Evaluated only: auc
# **********
# 0.9232197563564479
# destAddress_pktsOut_std
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [235]	training's auc: 0.920443	valid_0's auc: 0.915373
# Evaluated only: auc
# **********
# 0.9153733043791569
# destAddress_pktsOut_nunique
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [9]	training's auc: 0.822425	valid_0's auc: 0.830938
# Evaluated only: auc
# **********
# 0.8309380568891139
# destAddress_pktsOut_max_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [332]	training's auc: 0.876179	valid_0's auc: 0.877796
# Evaluated only: auc
# **********
# 0.8777964962849715
# destAddress_pktsOut_quantile_25
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [24]	training's auc: 0.86643	valid_0's auc: 0.867557
# Evaluated only: auc
# **********
# 0.8675566505341267
# destAddress_pktsOut_quantile_75
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [105]	training's auc: 0.856514	valid_0's auc: 0.849712
# Evaluated only: auc
# **********
# 0.849712438285731
# tlsVersion_bytesOut_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [43]	training's auc: 0.746003	valid_0's auc: 0.732784
# Evaluated only: auc
# **********
# 0.7327837882579779
# tlsVersion_bytesOut_max
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [43]	training's auc: 0.746003	valid_0's auc: 0.732784
# Evaluated only: auc
# **********
# 0.7327837882579779
# tlsVersion_bytesOut_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [37]	training's auc: 0.557393	valid_0's auc: 0.561306
# Evaluated only: auc
# **********
# 0.5613060540845839
# tlsVersion_bytesOut_median
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [46]	training's auc: 0.746003	valid_0's auc: 0.732783
# Evaluated only: auc
# **********
# 0.732783398739909
# tlsVersion_bytesOut_mean
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [37]	training's auc: 0.746003	valid_0's auc: 0.732783
# Evaluated only: auc
# **********
# 0.732783398739909
# tlsVersion_bytesOut_sum
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [43]	training's auc: 0.746003	valid_0's auc: 0.732784
# Evaluated only: auc
# **********
# 0.7327837882579779
# tlsVersion_bytesOut_skew
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [45]	training's auc: 0.746003	valid_0's auc: 0.732784
# Evaluated only: auc
# **********
# 0.7327837882579779
# tlsVersion_bytesOut_std
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [45]	training's auc: 0.746003	valid_0's auc: 0.732784
# Evaluated only: auc
# **********
# 0.7327837882579779
# tlsVersion_bytesOut_nunique
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [43]	training's auc: 0.746003	valid_0's auc: 0.732784
# Evaluated only: auc
# **********
# 0.7327837882579779
# tlsVersion_bytesOut_max_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [43]	training's auc: 0.746003	valid_0's auc: 0.732784
# Evaluated only: auc
# **********
# 0.7327837882579779
# tlsVersion_bytesOut_quantile_25
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [46]	training's auc: 0.7459	valid_0's auc: 0.732624
# Evaluated only: auc
# **********
# 0.7326240858497823
# tlsVersion_bytesOut_quantile_75
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [37]	training's auc: 0.746003	valid_0's auc: 0.732783
# Evaluated only: auc
# **********
# 0.732783398739909
# tlsVersion_bytesIn_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [43]	training's auc: 0.746003	valid_0's auc: 0.732784
# Evaluated only: auc
# **********
# 0.7327837882579779
# tlsVersion_bytesIn_max
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [43]	training's auc: 0.746003	valid_0's auc: 0.732784
# Evaluated only: auc
# **********
# 0.7327837882579779
# tlsVersion_bytesIn_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.744741	valid_0's auc: 0.732085
# Evaluated only: auc
# **********
# 0.7320853823606742
# tlsVersion_bytesIn_median
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [46]	training's auc: 0.746003	valid_0's auc: 0.732783
# Evaluated only: auc
# **********
# 0.732783398739909
# tlsVersion_bytesIn_mean
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [37]	training's auc: 0.746003	valid_0's auc: 0.732783
# Evaluated only: auc
# **********
# 0.732783398739909
# tlsVersion_bytesIn_sum
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [43]	training's auc: 0.746003	valid_0's auc: 0.732784
# Evaluated only: auc
# **********
# 0.7327837882579779
# tlsVersion_bytesIn_skew
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [45]	training's auc: 0.746003	valid_0's auc: 0.732783
# Evaluated only: auc
# **********
# 0.732783398739909
# tlsVersion_bytesIn_std
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [45]	training's auc: 0.746003	valid_0's auc: 0.732783
# Evaluated only: auc
# **********
# 0.732783398739909
# tlsVersion_bytesIn_nunique
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [43]	training's auc: 0.746003	valid_0's auc: 0.732784
# Evaluated only: auc
# **********
# 0.7327837882579779
# tlsVersion_bytesIn_max_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [43]	training's auc: 0.746003	valid_0's auc: 0.732784
# Evaluated only: auc
# **********
# 0.7327837882579779
# tlsVersion_bytesIn_quantile_25
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [46]	training's auc: 0.746003	valid_0's auc: 0.732783
# Evaluated only: auc
# **********
# 0.732783398739909
# tlsVersion_bytesIn_quantile_75
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [37]	training's auc: 0.746003	valid_0's auc: 0.732783
# Evaluated only: auc
# **********
# 0.732783398739909
# tlsVersion_pktsIn_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [43]	training's auc: 0.746003	valid_0's auc: 0.732784
# Evaluated only: auc
# **********
# 0.7327837882579779
# tlsVersion_pktsIn_max
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [43]	training's auc: 0.746003	valid_0's auc: 0.732784
# Evaluated only: auc
# **********
# 0.7327837882579779
# tlsVersion_pktsIn_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.746002	valid_0's auc: 0.732783
# Evaluated only: auc
# **********
# 0.7327828144628059
# tlsVersion_pktsIn_median
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [46]	training's auc: 0.739157	valid_0's auc: 0.723862
# Evaluated only: auc
# **********
# 0.7238618768928143
# tlsVersion_pktsIn_mean
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [37]	training's auc: 0.746003	valid_0's auc: 0.732783
# Evaluated only: auc
# **********
# 0.732783398739909
# tlsVersion_pktsIn_sum
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [43]	training's auc: 0.746003	valid_0's auc: 0.732784
# Evaluated only: auc
# **********
# 0.7327837882579779
# tlsVersion_pktsIn_skew
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [45]	training's auc: 0.746003	valid_0's auc: 0.732783
# Evaluated only: auc
# **********
# 0.732783398739909
# tlsVersion_pktsIn_std
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [45]	training's auc: 0.746003	valid_0's auc: 0.732783
# Evaluated only: auc
# **********
# 0.732783398739909
# tlsVersion_pktsIn_nunique
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [43]	training's auc: 0.746003	valid_0's auc: 0.732784
# Evaluated only: auc
# **********
# 0.7327837882579779
# tlsVersion_pktsIn_max_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [43]	training's auc: 0.746003	valid_0's auc: 0.732784
# Evaluated only: auc
# **********
# 0.7327837882579779
# tlsVersion_pktsIn_quantile_25
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [46]	training's auc: 0.745951	valid_0's auc: 0.732624
# Evaluated only: auc
# **********
# 0.7326240858497823
# tlsVersion_pktsIn_quantile_75
# ...
# tlsVersion_map_pktsOut_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.505352	valid_0's auc: 0.506018
# Evaluated only: auc
# **********
# 0.5060180541624875
# tlsVersion_map_pktsOut_max
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.505352	valid_0's auc: 0.506018
# Evaluated only: auc
# **********
# 0.5060180541624875
# tlsVersion_map_pktsOut_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.505352	valid_0's auc: 0.506018
# Evaluated only: auc
# **********
# 0.5060180541624875
# tlsVersion_map_pktsOut_median
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.505319	valid_0's auc: 0.506018
# Evaluated only: auc
# **********
# 0.5060180541624875
# tlsVersion_map_pktsOut_mean
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.505352	valid_0's auc: 0.506018
# Evaluated only: auc
# **********
# 0.5060180541624875
# tlsVersion_map_pktsOut_sum
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.505352	valid_0's auc: 0.506018
# Evaluated only: auc
# **********
# 0.5060180541624875
# tlsVersion_map_pktsOut_skew
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.505352	valid_0's auc: 0.506018
# Evaluated only: auc
# **********
# 0.5060180541624875
# tlsVersion_map_pktsOut_std
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.505352	valid_0's auc: 0.506018
# Evaluated only: auc
# **********
# 0.5060180541624875
# tlsVersion_map_pktsOut_nunique
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.505352	valid_0's auc: 0.506018
# Evaluated only: auc
# **********
# 0.5060180541624875
# tlsVersion_map_pktsOut_max_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.505352	valid_0's auc: 0.506018
# Evaluated only: auc
# **********
# 0.5060180541624875
# tlsVersion_map_pktsOut_quantile_25
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.505319	valid_0's auc: 0.506018
# Evaluated only: auc
# **********
# 0.5060180541624875
# tlsVersion_map_pktsOut_quantile_75
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.505319	valid_0's auc: 0.506018
# Evaluated only: auc
# **********
# 0.5060180541624875
# bytesOut_bytesIn_add
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [61]	training's auc: 0.895603	valid_0's auc: 0.889278
# Evaluated only: auc
# **********
# 0.8892775413619499
# bytesOut_bytesIn_subtract
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [109]	training's auc: 0.901161	valid_0's auc: 0.896273
# Evaluated only: auc
# **********
# 0.8962727015999454
# bytesOut_bytesInc_multiply
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [48]	training's auc: 0.871923	valid_0's auc: 0.872447
# Evaluated only: auc
# **********
# 0.8724474394055954
# bytesOut_pktsIn_add
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [66]	training's auc: 0.922459	valid_0's auc: 0.912887
# Evaluated only: auc
# **********
# 0.9128868157871673
# bytesOut_pktsIn_subtract
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [42]	training's auc: 0.922402	valid_0's auc: 0.913763
# Evaluated only: auc
# **********
# 0.9137630366828641
# bytesOut_pktsInc_multiply
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	training's auc: 0.882616	valid_0's auc: 0.880694
# Evaluated only: auc
# **********
# 0.8806941211985471
# bytesOut_pktsOut_add
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [95]	training's auc: 0.924142	valid_0's auc: 0.913697
# Evaluated only: auc
# **********
# 0.9136966238521389
# bytesOut_pktsOut_subtract
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [66]	training's auc: 0.925467	valid_0's auc: 0.914246
# Evaluated only: auc
# **********
# 0.9142458443291038
# bytesOut_pktsOutc_multiply
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [71]	training's auc: 0.903317	valid_0's auc: 0.883092
# Evaluated only: auc
# **********
# 0.8830923839479604
# bytesIn_pktsIn_add
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [34]	training's auc: 0.860774	valid_0's auc: 0.862794
# Evaluated only: auc
# **********
# 0.8627942078663174
# bytesIn_pktsIn_subtract
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [34]	training's auc: 0.858671	valid_0's auc: 0.860511
# Evaluated only: auc
# **********
# 0.8605108529471911
# bytesIn_pktsInc_multiply
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [87]	training's auc: 0.872213	valid_0's auc: 0.864236
# Evaluated only: auc
# **********
# 0.8642356194797987
# bytesIn_pktsOut_add
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [69]	training's auc: 0.866699	valid_0's auc: 0.856229
# Evaluated only: auc
# **********
# 0.8562294650943121
# bytesIn_pktsOut_subtract
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [34]	training's auc: 0.85975	valid_0's auc: 0.857406
# Evaluated only: auc
# **********
# 0.8574060044210301
# bytesIn_pktsOutc_multiply
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [81]	training's auc: 0.855165	valid_0's auc: 0.843144
# Evaluated only: auc
# **********
# 0.8431438003330379
# pktsIn_pktsOut_add
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [4]	training's auc: 0.836648	valid_0's auc: 0.833917
# Evaluated only: auc
# **********
# 0.8339170910790624
# pktsIn_pktsOut_subtract
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [3]	training's auc: 0.792831	valid_0's auc: 0.787765
# Evaluated only: auc
# **********
# 0.7877654322189871
# pktsIn_pktsOutc_multiply
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [41]	training's auc: 0.861911	valid_0's auc: 0.843885
# Evaluated only: auc
# **********
# 0.8438846636998374
# bytesOut_bytesIn_ratio
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [15]	training's auc: 0.85025	valid_0's auc: 0.844126
# Evaluated only: auc
# **********
# 0.8441257753844057
# bytesOut_pktsIn_ratio
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [233]	training's auc: 0.896224	valid_0's auc: 0.885914
# Evaluated only: auc
# **********
# 0.8859138580790916
# bytesOut_pktsOut_ratio
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [22]	training's auc: 0.933428	valid_0's auc: 0.936526
# Evaluated only: auc
# **********
# 0.93652608310368
# bytesIn_bytesOut_ratio
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [10]	training's auc: 0.850474	valid_0's auc: 0.843647
# Evaluated only: auc
# **********
# 0.8436472524369224
# bytesIn_pktsIn_ratio
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [38]	training's auc: 0.831445	valid_0's auc: 0.821133
# Evaluated only: auc
# **********
# 0.8211333028210847
# bytesIn_pktsOut_ratio
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [22]	training's auc: 0.827885	valid_0's auc: 0.823937
# Evaluated only: auc
# **********
# 0.8239366643620181
# pktsIn_bytesOut_ratio
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [62]	training's auc: 0.891105	valid_0's auc: 0.885759
# Evaluated only: auc
# **********
# 0.8857588298877214
# pktsIn_bytesIn_ratio
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [37]	training's auc: 0.835047	valid_0's auc: 0.823637
# Evaluated only: auc
# **********
# 0.8236373197261688
# pktsIn_pktsOut_ratio
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [121]	training's auc: 0.892428	valid_0's auc: 0.887116
# Evaluated only: auc
# **********
# 0.8871157160802797
# pktsOut_bytesOut_ratio
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [98]	training's auc: 0.942427	valid_0's auc: 0.935889
# Evaluated only: auc
# **********
# 0.935889221061242
# pktsOut_bytesIn_ratio
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [51]	training's auc: 0.835215	valid_0's auc: 0.824128
# Evaluated only: auc
# **********
# 0.8241281124928183
# pktsOut_pktsIn_ratio
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [188]	training's auc: 0.89372	valid_0's auc: 0.88651
# Evaluated only: auc
# **********
# 0.8865102102423776
# AUC drop features:
#  ['s2d_nunique', 'sp2dp_nunique', 's2dp_nunique', 'sp2d_nunique', 'd2s_nunique', 'dp2s_nunique', 'tlsVersion_map_count', 'srcAddressPort_bytesOut_skew', 'srcAddressPort_bytesOut_nunique', 'srcAddressPort_bytesOut_max_min', 'srcAddressPort_bytesIn_skew', 'srcAddressPort_bytesIn_nunique', 'srcAddressPort_bytesIn_max_min', 'srcAddressPort_pktsIn_skew', 'srcAddressPort_pktsIn_nunique', 'srcAddressPort_pktsIn_max_min', 'srcAddressPort_pktsOut_skew', 'srcAddressPort_pktsOut_nunique', 'srcAddressPort_pktsOut_max_min', 'tlsVersion_map_bytesOut_count', 'tlsVersion_map_bytesOut_max', 'tlsVersion_map_bytesOut_min', 'tlsVersion_map_bytesOut_median', 'tlsVersion_map_bytesOut_mean', 'tlsVersion_map_bytesOut_sum', 'tlsVersion_map_bytesOut_skew', 'tlsVersion_map_bytesOut_std', 'tlsVersion_map_bytesOut_nunique', 'tlsVersion_map_bytesOut_max_min', 'tlsVersion_map_bytesOut_quantile_25', 'tlsVersion_map_bytesOut_quantile_75', 'tlsVersion_map_bytesIn_count', 'tlsVersion_map_bytesIn_max', 'tlsVersion_map_bytesIn_min', 'tlsVersion_map_bytesIn_median', 'tlsVersion_map_bytesIn_mean', 'tlsVersion_map_bytesIn_sum', 'tlsVersion_map_bytesIn_skew', 'tlsVersion_map_bytesIn_std', 'tlsVersion_map_bytesIn_nunique', 'tlsVersion_map_bytesIn_max_min', 'tlsVersion_map_bytesIn_quantile_25', 'tlsVersion_map_bytesIn_quantile_75', 'tlsVersion_map_pktsIn_count', 'tlsVersion_map_pktsIn_max', 'tlsVersion_map_pktsIn_min', 'tlsVersion_map_pktsIn_median', 'tlsVersion_map_pktsIn_mean', 'tlsVersion_map_pktsIn_sum', 'tlsVersion_map_pktsIn_skew', 'tlsVersion_map_pktsIn_std', 'tlsVersion_map_pktsIn_nunique', 'tlsVersion_map_pktsIn_max_min', 'tlsVersion_map_pktsIn_quantile_25', 'tlsVersion_map_pktsIn_quantile_75', 'tlsVersion_map_pktsOut_count', 'tlsVersion_map_pktsOut_max', 'tlsVersion_map_pktsOut_min', 'tlsVersion_map_pktsOut_median', 'tlsVersion_map_pktsOut_mean', 'tlsVersion_map_pktsOut_sum', 'tlsVersion_map_pktsOut_skew', 'tlsVersion_map_pktsOut_std', 'tlsVersion_map_pktsOut_nunique', 'tlsVersion_map_pktsOut_max_min', 'tlsVersion_map_pktsOut_quantile_25', 'tlsVersion_map_pktsOut_quantile_75']
# Correlation drop features:
#  ['bytesIn_pktsOut_subtract', 'destAddressPort_bytesIn_std', 'tlsSni_bytesIn_quantile_25', 'srcAddress_bytesIn_max', 'tlsSni_pktsIn_count', 'destAddress_bytesOut_quantile_25', 'tlsSni_bytesOut_max_min', 'destAddress_bytesOut_median', 'srcAddressPort_pktsIn_std', 'bytesIn_pktsIn_subtract', 'tlsVersion_pktsIn_count', 'srcAddressPort_pktsIn_max', 'destAddressPort_bytesIn_sum', 'srcAddress_pktsIn_max', 'tlsIssuerDn_bytesOut_quantile_75', 'tlsSubject_pktsOut_max_min', 'tlsIssuerDn_pktsOut_min', 'destAddressPort_pktsIn_max', 'tlsSubject_bytesOut_max', 'tlsSubject_pktsIn_max_min', 'tlsVersion_pktsIn_std', 'srcAddressPort_pktsIn_quantile_75', 'srcAddress_pktsOut_median', 'destAddress_pktsIn_quantile_25', 'destAddressPort_pktsOut_skew', 'tlsSni_bytesIn_max_min', 'tlsIssuerDn_bytesOut_median', 'pktsOut', 'tlsVersion_bytesIn_mean', 'tlsIssuerDn_pktsIn_sum', 'destAddressPort_pktsIn_max_min', 'tlsIssuerDn_pktsIn_nunique', 'tlsIssuerDn_bytesIn_sum', 'tlsSni_pktsOut_sum', 'tlsSubject_pktsIn_skew', 'tlsVersion_bytesIn_median', 'srcAddressPort_bytesOut_sum', 'sp2dp_count', 'tlsVersion_pktsOut_mean', 'tlsIssuerDn_pktsOut_sum', 'tlsIssuerDn_pktsIn_count', 'srcAddressPort_bytesIn_max', 'bytesIn_pktsInc_multiply', 'srcAddress_pktsOut_min', 'tlsSni_bytesOut_median', 'tlsIssuerDn_bytesIn_max_min', 'destAddress_bytesIn_quantile_25', 'sp2d_count', 'srcAddress_bytesIn_sum', 'srcAddressPort_pktsOut_min', 'srcAddress_pktsIn_count', 'destAddressPort_bytesIn_quantile_75', 's2dp_count', 'tlsIssuerDn_bytesOut_nunique', 'destAddressPort_pktsOut_count', 'tlsIssuerDn_pktsIn_median', 'destAddress_pktsIn_median', 'tlsSni_bytesOut_count', 'tlsIssuerDn_bytesIn_skew', 'srcAddressPort_pktsIn_median', 'srcAddressPort_pktsIn_quantile_25', 'tlsSubject_bytesOut_count', 'destAddressPort_bytesIn_quantile_25', 'bytesOut_pktsIn_add', 'srcAddress_pktsOut_max', 'srcAddress_count', 'd2s_count', 'tlsVersion_pktsIn_skew', 'tlsSubject_bytesIn_nunique', 'tlsSubject_bytesIn_skew', 'tlsSni_pktsOut_median', 'tlsVersion_bytesIn_sum', 'tlsSubject_bytesOut_skew', 'destAddress_bytesIn_min', 'dp2sp_count', 'srcAddress_bytesIn_mean', 'd2sp_count', 'srcAddressPort_bytesOut_median', 'tlsVersion_bytesOut_sum', 'tlsVersion_pktsOut_skew', 'tlsIssuerDn_bytesIn_count', 'tlsIssuerDn_bytesOut_skew', 'destAddress_bytesIn_max_min', 'destAddressPort_pktsOut_sum', 'pktsIn_pktsOutc_multiply', 'tlsSni_bytesIn_count', 'destAddressPort_pktsOut_quantile_75', 'tlsSni_bytesIn_max', 'destAddress_bytesOut_max_min', 'destAddressPort_bytesOut_count', 'tlsSni_bytesIn_nunique', 'destAddressPort_bytesOut_std', 'srcAddressPort_bytesIn_min', 'destAddressPort_pktsOut_nunique', 'destAddressPort_count', 'tlsVersion_bytesOut_nunique', 'tlsSni_pktsIn_skew', 'destAddressPort_bytesIn_count', 'srcAddressPort_bytesOut_std', 'destAddressPort_bytesOut_max', 'tlsSubject_pktsOut_quantile_25', 'destAddressPort_pktsIn_skew', 'destAddressPort_bytesOut_mean', 'tlsSni_bytesOut_nunique', 'bytesOut', 'tlsSni_pktsOut_nunique', 'destAddressPort_bytesIn_median', 'tlsSni_pktsOut_min', 'srcAddress_bytesOut_max_min', 'tlsVersion_bytesOut_std', 'tlsSubject_pktsIn_nunique', 'tlsSni_pktsIn_max', 'tlsSni_pktsIn_sum', 'destAddress_bytesOut_std', 'tlsIssuerDn_pktsOut_max', 'tlsSni_pktsOut_quantile_75', 'destAddress_bytesIn_quantile_75', 'tlsVersion_bytesOut_mean', 'destAddressPort_bytesOut_skew', 'bytesOut_pktsOut_add', 'srcAddressPort_bytesOut_count', 'tlsVersion_bytesIn_max_min', 'srcAddressPort_pktsIn_count', 'destAddress_pktsOut_std', 'destAddress_pktsOut_max', 'tlsSubject_pktsOut_nunique', 'tlsVersion_bytesIn_min', 'tlsIssuerDn_count', 'tlsIssuerDn_bytesOut_max', 'destAddressPort_bytesOut_sum', 'tlsSubject_bytesIn_max_min', 'tlsVersion_bytesOut_max_min', 'tlsVersion_pktsIn_quantile_25', 'tlsVersion_bytesOut_max', 'tlsSubject_pktsIn_count', 'tlsVersion_pktsOut_max', 'tlsIssuerDn_pktsOut_quantile_75', 's2d_count', 'tlsSubject_pktsOut_quantile_75', 'pktsIn', 'srcAddress_pktsOut_count', 'srcAddressPort_bytesIn_quantile_25', 'tlsSni_pktsOut_mean', 'b ...
# Training until validation scores don't improve for 200 rounds
# [300]	training's auc: 1	valid_0's auc: 0.999893
# [600]	training's auc: 1	valid_0's auc: 0.999902
# [900]	training's auc: 1	valid_0's auc: 0.999903
# Early stopping, best iteration is:
# [867]	training's auc: 1	valid_0's auc: 0.999905
# Evaluated only: auc
# threshold:  0.8299999999999996
# Valid F1:  0.99122
# Valid mean label:  0.09272727272727273
# Test mean label:  0.09
