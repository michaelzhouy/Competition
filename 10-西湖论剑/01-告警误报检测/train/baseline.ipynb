# %%
import numpy as np
import pandas as pd
from sklearn.metrics import f1_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import lightgbm as lgb
from joblib import Parallel, delayed
import warnings
warnings.filterwarnings('ignore')
pd.set_option('max_columns', None)
pd.set_option('max_rows', None)

# %%
def count_encode(df, cols=[]):
    """
    count编码
    @param df:
    @param cols:
    @return:
    """
    for col in cols:
        print(col)
        vc = df[col].value_counts(dropna=True, normalize=True)
        df[col + '_count'] = df[col].map(vc).astype('float32')
    return df


def cross_cat_num(df, cat_col, num_col):
    """
    类别特征与数据特征groupby统计
    @param df:
    @param cat_col: 类别特征
    @param num_col: 数值特征
    @return:
    """
    def max_min(s):
        return s.max() - s.min()
    def quantile(s, q=0.25):
        return s.quantile(q)
    for f1 in cat_col:
        g = df.groupby(f1, as_index=False)
        for f2 in num_col:
            tmp = g[f2].agg({
                '{}_{}_count'.format(f1, f2): 'count',
                '{}_{}_max'.format(f1, f2): 'max',
                '{}_{}_min'.format(f1, f2): 'min',
                '{}_{}_median'.format(f1, f2): 'median',
                '{}_{}_mean'.format(f1, f2): 'mean',
                '{}_{}_sum'.format(f1, f2): 'sum',
                '{}_{}_skew'.format(f1, f2): 'skew',
                '{}_{}_std'.format(f1, f2): 'std',
                '{}_{}_nunique'.format(f1, f2): 'nunique',
                '{}_{}_max_min'.format(f1, f2): max_min,
                '{}_{}_quantile_25'.format(f1, f2): lambda x: quantile(x, 0.25),
                '{}_{}_quantile_75'.format(f1, f2): lambda x: quantile(x, 0.75)
            })
            df = df.merge(tmp, on=f1, how='left')
    return df


def arithmetic(df, cross_features):
    """
    数值特征之间的加减乘除
    @param df:
    @param cross_features: 交叉用的数值特征
    @return:
    """
    for i in range(len(cross_features)):
        for j in range(i + 1, len(cross_features)):
            colname_add = '{}_{}_add'.format(cross_features[i], cross_features[j])
            colname_substract = '{}_{}_subtract'.format(cross_features[i], cross_features[j])
            colname_multiply = '{}_{}c_multiply'.format(cross_features[i], cross_features[j])
            df[colname_add] = df[cross_features[i]] + df[cross_features[j]]
            df[colname_substract] = df[cross_features[i]] - df[cross_features[j]]
            df[colname_multiply] = df[cross_features[i]] * df[cross_features[j]]

    for f1 in cross_features:
        for f2 in cross_features:
            if f1 != f2:
                colname_ratio = '{}_{}_ratio'.format(f1, f2)
                df[colname_ratio] = df[f1].values / (df[f2].values + 0.001)
    return df


def get_psi(c, x_train, x_test):
    psi_res = pd.DataFrame()
    psi_dict={}
    # for c in tqdm(f_cols):
    try:
        t_train = x_train[c].fillna(-998)
        t_test = x_test[c].fillna(-998)
        #获取切分点
        bins=[]
        for i in np.arange(0,1.1,0.2):
            bins.append(t_train.quantile(i))
        bins=sorted(set(bins))
        bins[0]=-np.inf
        bins[-1]=np.inf
        #计算psi
        t_psi = pd.DataFrame()
        t_psi['train'] = pd.cut(t_train,bins).value_counts().sort_index()
        t_psi['test'] = pd.cut(t_test,bins).value_counts()
        t_psi.index=[str(x) for x in t_psi.index]
        t_psi.loc['总计',:] = t_psi.sum()
        t_psi['train_rate'] = t_psi['train']/t_psi.loc['总计','train']
        t_psi['test_rate'] = t_psi['test']/t_psi.loc['总计','test']
        t_psi['psi'] = (t_psi['test_rate']-t_psi['train_rate'])*(np.log(t_psi['test_rate'])-np.log(t_psi['train_rate']))
        t_psi.loc['总计','psi'] = t_psi['psi'].sum()
        t_psi.index.name=c
        #汇总
        t_res = pd.DataFrame([[c,t_psi.loc['总计','psi']]],
                             columns=['变量名','PSI'])
        psi_res = pd.concat([psi_res,t_res])
        psi_dict[c]=t_psi
        print(c,'done')
    except:
        print(c,'error')
    return psi_res #, psi_dict


def auc_select(X_train, y_train, X_valid, y_valid, cols, threshold=0.52):
    """
    基于AUC的单特征筛选
    @param X_train:
    @param y_train:
    @param X_valid:
    @param y_valid:
    @param cols:
    @return:
    """
    useful_dict = dict()
    useless_dict = dict()
    params = {
        'objective': 'binary',
        'boosting': 'gbdt',
        'metric': 'auc',
        'learning_rate': 0.1,
        'num_leaves': 31,
        'lambda_l1': 0,
        'lambda_l2': 1,
        'num_threads': 23,
        'min_data_in_leaf': 20,
        'first_metric_only': True,
        'is_unbalance': True,
        'max_depth': -1,
        'seed': 2020
    }
    for i in cols:
        print(i)
        lgb_train = lgb.Dataset(X_train[[i]].values, y_train)
        lgb_valid = lgb.Dataset(X_valid[[i]].values, y_valid, reference=lgb_train)
        lgb_model = lgb.train(
            params,
            lgb_train,
            valid_sets=[lgb_valid, lgb_train],
            num_boost_round=1000,
            early_stopping_rounds=50,
            verbose_eval=500
        )
        print('*' * 10)
        print(lgb_model.best_score['valid_0']['auc'])
        if lgb_model.best_score['valid_0']['auc'] > threshold:
            useful_dict[i] = lgb_model.best_score['valid_0']['auc']
        else:
            useless_dict[i] = lgb_model.best_score['valid_0']['auc']
    useful_cols = list(useful_dict.keys())
    useless_cols = list(useless_dict.keys())
    return useful_dict, useless_dict, useful_cols, useless_cols


def correlation(df, useful_dict, threshold=0.98):
    """
    去除特征相关系数大于阈值的特征
    @param df:
    @param threshold:
    @param useful_dict:
    @return:
    """
    col_corr = set()
    corr_matrix = df.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold:
                colName_i = corr_matrix.columns[i]
                colName_j = corr_matrix.columns[j]
                if useful_dict[colName_i] >= useful_dict[colName_j]:
                    col_corr.add(colName_j)
                else:
                    col_corr.add(colName_i)
    return col_corr

# %%
train = pd.read_csv('../大数据队_ad_submission_1009_1/data/train.csv')
test = pd.read_csv('../大数据队_ad_submission_1009_1/data/test_1.csv')
train.shape, test.shape
# Out:
# ((10396, 37), (15978, 36))

# %%
data = pd.concat([train, test])

# %%
single_cols = ['transProtocol', 'appProtocol', 'name']
null_cols = ['srcGeoCity', 'srcGeoAddress', 'srcGeoLatitude', 'srcGeoLongitude', 'destGeoAddress']
cat_cols = ['txId', 'destGeoCountry', 'destGeoRegion', 'destGeoCity', 'catOutcome', 'destHostName', 'responseCode']
num_cols = ['bytesOut', 'bytesIn']

drop_cols = ['srcAddress', 'srcPort', 'destAddress', 'destPort', 'destGeoLatitude', 'destGeoLongitude',
             'requestUrlQuery', 'requestUrl', 'httpReferer', 'requestBody', 'startTime']

# %%
drop_cols = drop_cols + single_cols + null_cols
data.drop(drop_cols, axis=1, inplace=True)

# %%
data['requestMethod'] = data['requestMethod'].str.upper()
cat_cols.append('requestMethod')
data['requestMethod'].unique()
# Out:
# array(['GET', 'POST', 'PUT', 'HEAD', 'OPTIONS', 'DELETE'], dtype=object)

# %%
data['httpVersion'] = data['httpVersion'].str.upper()
cat_cols.append('httpVersion')
data['httpVersion'].unique()
# Out:
# array(['HTTP/1.1', 'HTTP/1.0', nan], dtype=object)

# %%
data['accessAgent'] = data['accessAgent'].map(lambda x: np.nan if pd.isnull(x) else str(x).split('/')[0])
cat_cols.append('accessAgent')
data['accessAgent'].unique()
# Out:
# array(['MicroMessenger Client', 'Mozilla',
#        'netdisk;6.8.9.1;PC;PC-Windows;10.0.18362;WindowsBaiduYunGuanJia',
#        'NeteaseMusic 7.0.10', 'Post_Multipart', 'NeteaseMusic 6.4.2',
#        '%E8%99%BE%E7%B1%B3%E9%9F%B3%E4%B9%90', 'sogou_ime', 'SogouPSI',
#        nan, 'NewsApp', 'Dalvik',
#        '7E0BAEBADE98106C1C455C47059C43B2\tBKL-AL00\tcom.baidu.input_huawei-8.2.8.80\t20191211\t1556251334604\t10144',
#        '%E9%92%89%E9%92%89', 'SogouIMEMiniSetup_imepopup',
#        'Youdao Desktop Dict (Windows NT 10.0)',
#        'Android10-AndroidPhone-10042-56-0-Avatar-wifi', 'QYPlayer',
#        'NeteaseMusic 5.6.0', 'LogStatistic', 'HCDNClient_IOS;libcurl',
#        '() { _; OpenVAS-VT; } >_[$($())] { echo Content-Type: text',
#        'ttuploadersdk(15825329774632)', 'SOGOU_POPUP_NEWS', 'Linux',
#        'NeteaseMusic 6.4.4', 'MGTV-iPhone-appstore',
#        '%E7%BD%91%E6%98%93%E4%BA%91%E9%9F%B3%E4%B9%90',
#        'netdisk;10.0.150;iPhoneXR;ios-iphone;13.3.1;zh_CN',
#        'bdtb for iOS 11.1.1', 'Youdao Desktop Dict (Windows NT 6.1)',
#        'MICROSOFT_DEVICE_METADATA_RETRIEVAL_CLIENT',
#        'aliyun-log-sdk-android', 'GDTADNetClient-[Dalvik',
#        'bdtb for Android 11.1.8.2', 'you ku',
#        'netdisk;6.8.9.1;PC;PC-Windows;10.0.17763;WindowsBaiduYunGuanJia',
#        'pingback sdk v1.5.2', 'iPhone', 'pingback sdk v2.5.0', 'okhttp',
#        'NeteaseMusic 7.0.20', 'SOGOU_UPDATER', 'SogouComponentAgent',
#        'Microsoft-ATL-Native',
#        'netdisk;6.8.9.1;PC;PC-Windows;10.0.18363;WindowsBaiduYunGuanJia',
#        'qukan_android', 'SogouIme', 'Baidu%E8%BE%93%E5%85%A5%E6%B3%95',
#        'netdisk;p2sp;', 'HCDNClient_IOS;PRELOAD;libcurl', 'YNote',
#        'ting_6.6.48(SKR-A0,Android28)', 'ting_6.6.48(HMA-AL00,Android28)',
#        'QQ', 'NeteaseMusic 5.5.0', 'Netease Music RestClient 1.0.0.0',
#        'NeteaseMusic 6.5.1',
#        'sgplat=Android;sgver=23;sgfr=android_oem_oppo;sgappver=8.15.22.191370',
#        'pingback sdk v2.4.3', 'bdtb for Android 9.0.0.0',
#        'Chrome Mozilla', 'IPhone-10035-IPhone-10035-cscc',
#        'pid=Android-container; pv=10.1.87.7000; uuid=download_W6mtOHPCEy0DAKDH+U+dSYay_N204+DI',
#        'netdisk;2.2.3;pc;pc-mac;10.15.3;macbaiduyunguanjia',
#        'Android9-AndroidPhone-10042-56-0-AUTHOR_DETAIL-wifi',
#        'HCDNClient_ANDROID_MOBILE;OFFLINE;libcurl', 'KssRC4',
#        'AnQuanWeiShi', 'NeteaseMusic', 'NeteaseMusic 7.0.0', 'QTP;QTP',
#        'Rm94aXRQaGFudG9tUERG', 'Munion-SDK1.8.2.8', 'http generic',
#        'javascript:',
#        '%E7%BD%91%E6%98%93%E6%9C%89%E9%81%93%E8%AF%8D%E5%85%B8',
#        'AiMeiTuan ', '() { OpenVAS-VT:; }; echo Content-Type: text',
#        'Cube;QTP', 'Android9-vivo-PD1831(V1831A)',
#        'netdisk;2.2.3;pc;pc-mac;10.15.2;macbaiduyunguanjia',
#        'HCDNClient_ANDROID_MOBILE;libcurl',
#        'netdisk;10.0.150;iPhone8Plus;ios-iphone;13.3.1;zh_CN', 'WSDAPI',
#        'netdisk;10.0.150;iPhoneXSMax;ios-iphone;13.3;zh_CN',
#        'SogouIMEMiniSetup_skinrecommend', 'zhi hu ri bao',
#        'ting_6.6.48(STF-AL00,Android28)', 'User-Agent',
#        'EML-AL00_10_weibo_10.1.1_android', '(null)',
#        'Foxmail 7.2.9.156[cn]', 'ting_6.6.48(SM-G9730,Android29)',
#        'ikuacc', 'qqpy_win_ime', 'Weibo', 'Post', 'Installer Doctor',
#        '7832', 'qqlive', 'Apache-HttpClient',
#        'ttuploadersdk(15825329624672)', 'netdisk_iPhone',
#        'AMAP_SDK_iOS_Location_2.6.0',
#        '%E9%85%B7%E6%88%91%E9%9F%B3%E4%B9%90',
#        'pid=Android-container; pv=10.1.87.7000; uuid=download_WYbsbHT5mTQDALAVocgDOo7N_N1wkBKq',
#        'sgmac_ime', 'Cupid', '8160', 'IPhone-10042-AsyncImage',
#        'Foxmail 7, 2, 8, 392[cn]', 'Affairs', 'QQClient',
#        'SM-G9600_9_weibo_10.2.0_android', 'EML-AL00',
#        'HCDNClient_ANDROID_MOBILE;PRELOAD;libcurl',
#        'AMAP_Location_SDK_Android 3.3.0',
#        'HCDNClient_WINPC;PREDEPLOY;libcurl',
#        'netdisk;10.0.150;iPhone7Plus;ios-iphone;13.3.1;zh_CN',
#        'IPhone-10042-AdBannerInfo', '191C2DF0F51764420ABFB97663AB43F6',
#        'iflytek.iflyinput.-----', 'sqlmap',
#        'netdisk;10.0.150;iPhone6sPlus;ios-iphone;13.3;zh_CN',
#        'netdisk;10.0.150;iPhoneX;ios-iphone;13.2;zh_CN', 'QIYIVideo',
#        'SimpleHttpFetch',
#        '9473FB5EE99AA47B2703E291B764C32A\tSPN-AL00\tcom.baidu.input_huawei-8.2.8.80\t20191211\t1576249819884\t10137',
#        'netdisk;10.0.154;PCAM00;android-android;9;JSbridge4.1.0',
#        'null HttpURLConnection',
#        'netdisk;10.0.150;iPhone6;ios-iphone;10.2;zh_CN',
#        '{"NetType":"wifi"};QTP',
#        'ting_v6.6.39_c5(CFNetwork, iOS 13.3.1, iPhone8,1)',
#        'cmVmbGVjdGVkYW5vbnltb3Vzc2VjdXJpdHk1',
#        'NotificationServiceExtension', 'qqsports_android_client',
#        'Go-http-client', 'WeRead', 'SogouIMEMiniSetup_RandSkin', 'waimai',
#        'com.iqiyi.player',
#        'pid=Android-container; pv=10.1.87.7000; uuid=download_WYbsbHT5mTQDALAVocgDOo7N_N1',
#        'ttuploadersdk(15826912459962)', 'osee2unifiedRelease',
#        'AMAP_SDK_iOS_Loc_2.4.0', '16968',
#        'apple-iphone11__SNNotificationService__7.27.0__iOS__13.3.1__201911272143.1',
#        'Foxmail 7.2.15.78[cn]', 'iqiyi',
#        'AMAP_Location_SDK_Android 4.7.1', '23188', '%E5%BE%AE%E4%BF%A1',
#        'KWPlayer', 'ONEPLUS A6000', 'com.meituan.itakeaway', 'Ubuntu',
#        'bdtb for Android 9.8.8.7', 'sogou_ime_union_10001', 'ting',
#        'aliyun-sdk-java', 'Android10-AndroidPhone-10026-56-0-Avatar-wifi',
#        'MQQBrowser',
#        'netdisk;P2SP;2.2.61.12;netdisk;10.0.154;MI+9+SE;android-android;9;JSbridge4.1.0',
#        'Java', 'bGlua2Fub3Ztb3dtcnVzNQ==',
#        'AMAP_Location_SDK_Android 2.9.0', 'PY_PC', '5780',
#        'log-c-lite_0.1.0', '14968',
#        'D8BB77423347DE70705CCD1C304E8E02\tEML-AL00\tcom.baidu.input_huawei-8.2.8.80\t20191211\t1569684375891\t10161',
#        'ting_v6.6.48_c5(CFNetwork, iOS 13.3.1, iPhone10,3)',
#        'Microsoft Internet Explorer', 'PRISReader',
#        'QQ%E9%9F%B3%E4%B9%90', 'SOGOU_POPUP',
#        'pid=Android-container; pv=10.1.87.7000; uuid=download_WYBFk9fqEUIDAF1VMg05GzeO_N1RYCdA',
#        'Android9-AndroidPhone-10042-56-0-Avatar-wifi',
#        'Cube_Android_Mobile', '%E8%9C%BB%E8%9C%93FM', '8808',
#        'Foxmail 7, 2, 8, 379[cn]', 'YWFNotificationServiceExtension',
#        'Windows-Update-Agent', '9092', 'Android9-OPPO-PCAM00(PCAM00)',
#        'AMAP_Location_SDK_Android 4.6.0', '[1.0.4;rPY7Gs3TOOgIjSjVfyLmnW',
#        'Sogou%E4%BA%94%E7%AC%94 (unknown version) CFNetwork',
#        'NeteaseMusic 5.7.4', '16024', '<script>alert(12345)<',
#        'python-requests', 'KuGou2012-8391-TransferSession',
#        '%E7%BE%8E%E5%9B%A2', 'iQiYiPhoneVideo',
#        'ting_v6.6.48_c5(CFNetwork, iOS 13.3.1, iPhone11,8)', 'axios',
#        'HeAnimal', 'git', 'HttpPoster2', 'npm',
#        '6114201F1901FA50B01C6DBE18EDBC7A\tALP-AL00\tcom.baidu.input_huawei-8.2.8.80\t20191211\t1519389486873\t10132',
#        'Unified-X(arm-unknown-linux-gnu);libcurl', 'WinHttpClient',
#        'qbhttp', 'HCDNClient_ANDROID_MOBILE;AUDIO;libcurl',
#        'cmns_4.0 1.0.0.1', 'MGMobileMusic', 'xiami mobile',
#        'ttuploadersdk(15826003633702)', '9376', 'SEOCT',
#        'C6CB4C121754A70F692F32BFBC5EC8FB', 'QQ Data Report', '2820',
#        'pid=Android-container; pv=10.1.87.7000; uuid=download_XeJoB3XKHW4DACSI',
#        'Reeder', 'QiYiPadVideo', 'SimCity',
#        'B97A38590B2F3357378CC8A03C2FD117\tV1938CT\tcom.qidian.QDReader-7.9.17\t20191217\t1582257220717\t10160\ta11cd661da2314b9',
#        'User-Agent: Mozilla ', 'Dash',
#        'pid=Android-container; pv=10.1.87.7000; uuid=download_XNI6w52sM8EDAE9YTdo',
#        'KuGou2012-8395-TransferSession', '10468',
#        '6E4A47F0718E54645106180CEEABF6E5',
#        'pid=Android-container; pv=10.1.87.7000; uuid=download_XRSwnVu',
#        'ttuploadersdk(15826005797632)',
#        'pid=Android-container; pv=10.1.68.8258; uuid=download_XkV6xN81RZ8DAG6vAjc9JJBB_N1xE80E',
#        'sgandroid_ime',
#        'QYUniversalFramework 9.7.0 rv:1 (iPhone; iOS 11.2.1; zh_CN)',
#        'AMAP_Location_SDK_Android 4.7.2', 'User-Agent: Mozilla',
#        'ttuploadersdk(15826003636132)', 'huawei; 10; huawei; zh',
#        'netdisk;10.0.154;MI+9+SE;android-android;9;JSbridge4.1.0',
#        'netdisk;6.8.9.1;PC;PC-Windows;10.0.15063;WindowsBaiduYunGuanJia',
#        'AMAP_Location_SDK_Android 3.8.0', 'ting_6.6.45(Mi+A3,Android28)',
#        'YoudaoWordBook (Windows NT 10.0)',
#        'pid=Android-container; pv=10.1.87.7000; uuid=download_WYBFk9fqEUIDAF1VMg05GzeO_N1RYAbg',
#        'pid=Android-container; pv=10.1.87.7000; uuid=download_W6mtOHPCEy0DAKDH+U+dSYay_N1wMdvo',
#        'Android', 'HCDNClient_ANDROID;PRELOAD;libcurl', '21768',
#        'linkayoussecurity5', 'ttuploadersdk(15826003640092)',
#        'live4iphone%20rel',
#        '1BABD4DF093634F76CCEFAF7EA864808\tRedmi Note 7 Pro\tcom.sina.news-7.31.0\t20191217\t1568267452721\t10164\t6776193b851e09af',
#        'qzone', 'Zeus',
#        'pid=Android-container; pv=10.1.87.7000; uuid=download_WYbsbHT5mTQDALAVocgDOo7N_N1wjOTF',
#        'Qiyi List Client PC 7.2.102.1343', 'MI 9_9_weibo_10.2.0_android',
#        'IQooAppstore',
#        'pid=Android-container; pv=10.1.87.7000; uuid=download_WYBFk9fqEUIDAF1VMg05GzeO_N1RalKb',
#        'IPhone-10042-getSpecialAD',
#        'Android9-OnePlus-OnePlus6(ONEPLUS A6000)', 'Darwin',
#        '[1.0.4;YHpuZcMuzkPp4TtY3jjBfIHEAkeFuI1r;iOS;3.22.0;375*812;0.40;Wifi;DBappsecurity;1582613653019;9BCABC0F-56D4-458C-B257-2B103772C595]',
#        'pid=Android-container; pv=10.1.87.7000; uuid=download_XdpDdJ7A',
#        'netdisk;6.8.1.3;PC;PC-Windows;10.0.14393;WindowsBaiduYunGuanJia',
#        'mobilenavi', 'MojiWeather', 'ting_6.6.54(STF-AL00,Android28)',
#        '57192C8D2D3892CBF8FB9F46ED5ACBA9\tOPPO R9st\tcom.qiyi.video-11.2.0\t20191209\t1495904830121\t10111\t1dde6b7a0a412d3b',
#        'AMAP_Location_SDK_Android 4.7.0', 'MovieFilmExtension',
#        'pid=Android-container; pv=10.1.87.7000; uuid=download_Wu5Vu9Ws95QDALz8R4DOCU7A_N1sb',
#        'Google Update',
#        'netdisk;10.0.150;Unknown_iPhone;ios-iphone;13.3.1;zh_CN',
#        'pid=Android-container; pv=10.1.87.7000; uuid=download_VgVQ4zfv0R0DAOpJcM3WK675_N1vrHAu',
#        'KuGou2012-9106-CarrierPigeonProtocol',
#        'ting_6.6.54(HMA-AL00,Android28)',
#        '[1.0.4;YHpuZcMuzkPp4TtY3jjBfIHEAkeFuI1r;iOS;3.22.0;375*812;0.68;Wifi;DBappsecurity;1582617272420;9BCABC0F-56D4-458C-B257-2B103772C595]',
#        'KugouMusic',
#        'sgplat=Android;sgver=22;sgfr=android_oem_oppo;sgappver=8.15.22.191370',
#        'ting_6.6.48(VTR-AL00,Android26)', 'a', '5376'], dtype=object)

# %%
data['responseCode_0'] = data['responseCode'].map(lambda x: np.nan if pd.isnull(x) else str(x)[0])
cat_cols.append('responseCode_0')
data['responseCode_0'].unique()
# Out:
# array(['4', '2', '5', '3', nan, '1'], dtype=object)

# %%
data['requestHeader'] = data['requestHeader'].map(lambda x: np.nan if pd.isnull(x) else str(x).split(':')[0])
cat_cols.append('requestHeader')
data['requestHeader'].unique()
# Out:
# array(['Accept', 'Host', 'User-Agent', 'Origin', 'Accept-Encoding',
#        'Connection', 'HOST', 'Referer', 'Content-MD5', 'Content-Type',
#        'qyid', 'apkbus', 'RC-App-Key', 'Cookie', 'Authorization', 'X-Tk',
#        'Content-Encoding', 'user-agent', 'Accept-Language', 'S-COOKIE',
#        'X-Requested-With', 'wup_version', 'Content-Length', 'sign',
#        'accept-language', 'retrofit_exec_time', 'Cache-Control', 'VER',
#        'Q-UA2', nan, 'gzipped', 'et', 'Pragma', 'XRAY-TRACEID',
#        'Accept-Charset', 'ext', 'townlocalid', 't', 'Add-To-Queue-Millis',
#        'needginfo', 'host', 'connection', 'Charset', 'RTraceID',
#        'x-r-i-i', 'client_ip', 'aps_c_key', 'Expect', 'content-type',
#        'Content-type', 'SN-REQID', 'encrypt', 'X-Unity-Version',
#        'platform'], dtype=object)

# %%
data['responseHeader'] = data['responseHeader'].map(lambda x: np.nan if pd.isnull(x) else str(x).split(':')[0])
cat_cols.append('responseHeader')
data['responseHeader'].unique()
# Out:
# array(['Connection', 'Server', '***,Content-Type', 'Content-Length',
#        'Accept-Ranges', 'X-AREQUESTID', nan, 'Content-Type',
#        'Cache-Control', 'Transfer-Encoding',
#        'Access-Control-Allow-Origin',
#        '***,Content-Type,Accept,Authorization,DNT,X-CustomHeader,Keep-Alive,User-Agent,If-Modified-Since,Cache-Control,Access-Control-Allow-Methods',
#        'content-type', 'Content-Encoding',
#        'Access-Control-Allow-Credentials', 'CONTENT-LENGTH', 'Date',
#        'Set-Cookie', 'Pragma', 'Upgrade', 'Vary', 'status',
#        'Content-Range',
#        '***,Content-Type,Range,accept,origin,user-ssn,user-yd,check-d,user-c,user-u,user-l,user-n,user-id,user-lc,user-d,user-tk,user-da,X-Via',
#        'Location', '***,Content-Type,Authorization,', 'Cache-control',
#        'Abtest', 'Access-Control-Allow-Methods',
#        'Content-Security-Policy'], dtype=object)

# %%
data['requestContentType'] = data['requestContentType'].map(lambda x: np.nan if pd.isnull(x) else str(x).split('/')[0])
cat_cols.append('requestContentType')
data['requestContentType'].unique()
# Out:
# array(['application', nan, 'multipart', 'text', 'binary', 'image',
#        "%{(#nike='multipart",
#        "%{#context['com.opensymphony.xwork2.dispatcher.HttpServletResponse'].addHeader('St2_Head3rIKQY4','St2_Valu36REHPmultipart",
#        'x'], dtype=object)

# %%
data['responseContentType'] = data['responseContentType'].map(lambda x: np.nan if pd.isnull(x) else str(x).split('/')[0])
cat_cols.append('responseContentType')
data['responseContentType'].unique()
# Out:
# array(['application', 'image', 'text', nan, 'audio', 'request', 'video'],
#       dtype=object)

# %%
data['destDetailCity'] = data['destGeoCountry'].astype(str) + data['destGeoRegion'].astype(str) + data['destGeoCity'].astype(str)
cat_cols.append('destDetailCity')
data['destDetailCity'].unique()
# Out:
# array(['中国广东深圳', '局域网局域网nan', '中国浙江杭州', '中国陕西西安', '中国江苏无锡', '中国上海上海',
#        '中国河南郑州', '中国江苏苏州', '中国山东青岛', '中国浙江宁波', '中国北京北京', '中国浙江温州',
#        '中国广西南宁', '中国湖北武汉', '中国江苏南京', '中国浙江金华', '中国辽宁沈阳', '中国江苏常州',
#        '中国宁夏中卫', '中国山东枣庄', '中国天津天津', '日本东京都东京', '美国加利福尼亚州洛杉矶', '中国福建福州',
#        '中国湖北荆州', '中国广东广州', '中国浙江湖州', '中国湖南长沙', '中国广东佛山', '中国浙江嘉兴',
#        '中国江苏镇江', '中国浙江绍兴', '中国四川成都', '中国江苏扬州', '中国河南洛阳', '爱尔兰都柏林郡都柏林',
#        '中国新疆乌鲁木齐', '美国美国nan', '中国香港nan', '中国江西赣州', '中国浙江衢州', '美国华盛顿州西雅图',
#        'nannannan', '中国广东nan', '中国浙江丽水', '中国安徽合肥', '中国中国nan', '中国广东云浮',
#        '中国河北廊坊', '中国山西长治', '中国河北石家庄', '中国江苏盐城', '新加坡新加坡nan',
#        '美国加利福尼亚州圣克拉拉', '中国四川乐山', '中国江西上饶', 'GOOGLE.COMGOOGLE.COMnan',
#        '中国浙江台州', '中国广东茂名', '中国安徽芜湖', '中国浙江舟山', '中国江苏徐州', '中国安徽马鞍山',
#        '中国广西桂林', '中国黑龙江哈尔滨', 'CLOUDFLARE.COMCLOUDFLARE.COMnan', '中国四川自贡',
#        '中国山东济南', '中国江苏南通', '中国海南保亭黎族苗族自治县', '美国怀俄明州夏延', '中国广东东莞',
#        'DNSPOD.COMDNSPOD.COMnan', '中国江苏泰州', '中国台湾台北市', '中国湖南株洲', '中国山东烟台',
#        '中国广西柳州', '美国弗吉尼亚州阿什本', '中国山西太原', '亚太地区亚太地区nan', '中国福建厦门',
#        '中国辽宁锦州', '中国广东中山', '捷克布拉格nan', '中国湖南衡阳', '中国重庆重庆', '中国广西梧州'],
#       dtype=object)

# %%
print(cat_cols)
# Out:
# ['txId', 'destGeoCountry', 'destGeoRegion', 'destGeoCity', 'catOutcome', 'destHostName', 'responseCode', 'requestMethod', 'httpVersion', 'accessAgent', 'responseCode_0', 'requestHeader', 'responseHeader', 'requestContentType', 'responseContentType', 'destDetailCity']

# %%
for i in cat_cols:
    print(i)
    le = LabelEncoder()
    data[i] = le.fit_transform(data[i].astype(str))
    data[i] = data[i].astype('category')
# Out:
# txId
# destGeoCountry
# destGeoRegion
# destGeoCity
# catOutcome
# destHostName
# responseCode
# requestMethod
# httpVersion
# accessAgent
# responseCode_0
# requestHeader
# responseHeader
# requestContentType
# responseContentType
# destDetailCity

# %%
data = count_encode(data, cat_cols)
data = cross_cat_num(data, cat_cols, num_cols)
data = arithmetic(data, num_cols)
# Out:
# txId
# destGeoCountry
# destGeoRegion
# destGeoCity
# catOutcome
# destHostName
# responseCode
# requestMethod
# httpVersion
# accessAgent
# responseCode_0
# requestHeader
# responseHeader
# requestContentType
# responseContentType
# destDetailCity

# %%
used_cols = [i for i in data.columns if i not in ['eventId', 'label']]
train = data.loc[data['label'].notnull(), :]
test = data.loc[data['label'].isnull(), :]
sub = test[['eventId']]

y = train['label']
X = train[used_cols]
X_test = test[used_cols]

# %%
# 调用方法
psi_res = Parallel(n_jobs=4)(delayed(get_psi)(c, X, X_test) for c in used_cols)
psi_df = pd.concat(psi_res)
psi_used_cols = list(psi_df[psi_df['PSI'] <= 0.2]['变量名'].values)
psi_not_used_cols = list(psi_df[psi_df['PSI'] > 0.2]['变量名'].values)
print('PSI used features: \n', psi_used_cols)
print('PSI drop features: \n', psi_not_used_cols)
print('Error drop features: \n', list(set(used_cols) - set(psi_used_cols)))

cat_ = ['accessAgent', 'responseContentType', 'requestContentType', 'httpVersion', 'requestMethod',
        'destGeoCity', 'destDetailCity', 'destGeoCountry', 'responseHeader', 'destGeoRegion',
        'requestHeader', 'destHostName', 'catOutcome', 'responseCode', 'responseCode_0']
psi_used_cols += cat_

X = X[psi_used_cols]
X_test = X_test[psi_used_cols]

X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.25, random_state=2020)

print('y_train mean: ', y_train.mean())
print('y_valid mean: ', y_valid.mean())

useful_dict, useless_dict, useful_cols, useless_cols = auc_select(X_train, y_train, X_valid, y_valid, psi_used_cols, threshold=0.52)
print('AUC drop features: \n', useless_cols)

X_train = X_train[useful_cols]
X_valid = X_valid[useful_cols]
X_test = X_test[useful_cols]

col_corr = correlation(X_train, useful_dict, threshold=0.98)
print('Correlation drop features: \n', col_corr)

X_train.drop(col_corr, axis=1, inplace=True)
X_valid.drop(col_corr, axis=1, inplace=True)
X_test.drop(col_corr, axis=1, inplace=True)

used_cols = X_train.columns.to_list()

train_dataset = lgb.Dataset(X_train, y_train)
valid_dataset = lgb.Dataset(X_valid, y_valid, reference=train_dataset)
all_dataset = lgb.Dataset(train[used_cols], y, reference=train_dataset)

params = {'objective': 'binary',
          'boosting': 'gbdt',
          'metric': 'auc',
          # 'metric': 'None',  # 用自定义评估函数是将metric设置为'None'
          'num_boost_round': 1000000,
          'learning_rate': 0.1,
          'num_leaves': 31,
          'lambda_l1': 0,
          'lambda_l2': 1,
          'num_threads': 23,
          'min_data_in_leaf': 20,
          'first_metric_only': True,
          'is_unbalance': True,
          'max_depth': -1,
          'seed': 2020}
valid_model = lgb.train(params,
                        train_dataset,
                        valid_sets=[valid_dataset, train_dataset],
                        early_stopping_rounds=200,
                        verbose_eval=300)
pred = valid_model.predict(X_valid)

f1_best = 0
for i in np.arange(0.1, 1, 0.01):
    y_valid_pred = np.where(pred > i, 1, 0)
    f1 = np.round(f1_score(y_valid, y_valid_pred), 5)
    if f1 > f1_best:
        threshold = i
        f1_best = f1
        
print('threshold: ', threshold)
y_valid_pred = np.where(pred > threshold, 1, 0)
print('Valid F1: ', np.round(f1_score(y_valid, y_valid_pred), 5))
print('Valid mean label: ', np.mean(y_valid_pred))

params = {
    'objective': 'binary',
    'boosting': 'gbdt',
    'metric': 'auc',
    # 'metric': 'None',  # 用自定义评估函数是将metric设置为'None'
    # 'num_boost_round': 1000000,
    'learning_rate': 0.1,
    'num_leaves': 31,
    'lambda_l1': 0,
    'lambda_l2': 1,
    'num_threads': 23,
    'min_data_in_leaf': 20,
    'first_metric_only': True,
    'is_unbalance': True,
    'max_depth': -1,
    'seed': 2020
}
train_model = lgb.train(
    params,
    all_dataset,
    num_boost_round=valid_model.best_iteration+20
)
y_test_pred = np.where(train_model.predict(X_test) > threshold, 1, 0)

print('Test mean label: ', np.mean(y_test_pred))
sub['label'] = y_test_pred
sub.to_csv('../sub/机器不学习原子弹也不学习_ad_submission_1022.csv', index=False, encoding='utf-8')
# Out:
# PSI used features:
#  ['bytesOut', 'bytesIn', 'txId_count', 'destGeoCountry_count', 'destGeoRegion_count', 'destGeoCity_count', 'catOutcome_count', 'destHostName_count', 'responseCode_count', 'requestMethod_count', 'httpVersion_count', 'accessAgent_count', 'responseCode_0_count', 'requestHeader_count', 'responseHeader_count', 'requestContentType_count', 'responseContentType_count', 'destDetailCity_count', 'txId_bytesOut_count', 'txId_bytesOut_max', 'txId_bytesOut_min', 'txId_bytesOut_median', 'txId_bytesOut_mean', 'txId_bytesOut_sum', 'txId_bytesOut_skew', 'txId_bytesOut_std', 'txId_bytesOut_nunique', 'txId_bytesOut_max_min', 'txId_bytesOut_quantile_25', 'txId_bytesOut_quantile_75', 'txId_bytesIn_count', 'txId_bytesIn_max', 'txId_bytesIn_min', 'txId_bytesIn_median', 'txId_bytesIn_mean', 'txId_bytesIn_sum', 'txId_bytesIn_skew', 'txId_bytesIn_std', 'txId_bytesIn_nunique', 'txId_bytesIn_max_min', 'txId_bytesIn_quantile_25', 'txId_bytesIn_quantile_75', 'destGeoCountry_bytesOut_count', 'destGeoCountry_bytesOut_max', 'destGeoCountry_bytesOut_min', 'destGeoCountry_bytesOut_median', 'destGeoCountry_bytesOut_mean', 'destGeoCountry_bytesOut_sum', 'destGeoCountry_bytesOut_skew', 'destGeoCountry_bytesOut_std', 'destGeoCountry_bytesOut_nunique', 'destGeoCountry_bytesOut_max_min', 'destGeoCountry_bytesOut_quantile_25', 'destGeoCountry_bytesOut_quantile_75', 'destGeoCountry_bytesIn_count', 'destGeoCountry_bytesIn_max', 'destGeoCountry_bytesIn_min', 'destGeoCountry_bytesIn_median', 'destGeoCountry_bytesIn_mean', 'destGeoCountry_bytesIn_sum', 'destGeoCountry_bytesIn_skew', 'destGeoCountry_bytesIn_std', 'destGeoCountry_bytesIn_nunique', 'destGeoCountry_bytesIn_max_min', 'destGeoCountry_bytesIn_quantile_25', 'destGeoCountry_bytesIn_quantile_75', 'destGeoRegion_bytesOut_count', 'destGeoRegion_bytesOut_max', 'destGeoRegion_bytesOut_min', 'destGeoRegion_bytesOut_median', 'destGeoRegion_bytesOut_mean', 'destGeoRegion_bytesOut_sum', 'destGeoRegion_bytesOut_skew', 'destGeoRegion_bytesOut_std', 'destGeoRegion_bytesOut_nunique', 'destGeoRegion_bytesOut_max_min', 'destGeoRegion_bytesOut_quantile_25', 'destGeoRegion_bytesOut_quantile_75', 'destGeoRegion_bytesIn_count', 'destGeoRegion_bytesIn_max', 'destGeoRegion_bytesIn_min', 'destGeoRegion_bytesIn_median', 'destGeoRegion_bytesIn_mean', 'destGeoRegion_bytesIn_sum', 'destGeoRegion_bytesIn_skew', 'destGeoRegion_bytesIn_std', 'destGeoRegion_bytesIn_nunique', 'destGeoRegion_bytesIn_max_min', 'destGeoRegion_bytesIn_quantile_25', 'destGeoRegion_bytesIn_quantile_75', 'destGeoCity_bytesOut_count', 'destGeoCity_bytesOut_max', 'destGeoCity_bytesOut_min', 'destGeoCity_bytesOut_median', 'destGeoCity_bytesOut_mean', 'destGeoCity_bytesOut_sum', 'destGeoCity_bytesOut_skew', 'destGeoCity_bytesOut_std', 'destGeoCity_bytesOut_nunique', 'destGeoCity_bytesOut_max_min', 'destGeoCity_bytesOut_quantile_25', 'destGeoCity_bytesOut_quantile_75', 'destGeoCity_bytesIn_count', 'destGeoCity_bytesIn_max', 'destGeoCity_bytesIn_min', 'destGeoCity_bytesIn_median', 'destGeoCity_bytesIn_mean', 'destGeoCity_bytesIn_sum', 'destGeoCity_bytesIn_skew', 'destGeoCity_bytesIn_std', 'destGeoCity_bytesIn_nunique', 'destGeoCity_bytesIn_max_min', 'destGeoCity_bytesIn_quantile_25', 'destGeoCity_bytesIn_quantile_75', 'catOutcome_bytesOut_count', 'catOutcome_bytesOut_max', 'catOutcome_bytesOut_min', 'catOutcome_bytesOut_median', 'catOutcome_bytesOut_mean', 'catOutcome_bytesOut_sum', 'catOutcome_bytesOut_skew', 'catOutcome_bytesOut_std', 'catOutcome_bytesOut_nunique', 'catOutcome_bytesOut_max_min', 'catOutcome_bytesOut_quantile_25', 'catOutcome_bytesOut_quantile_75', 'catOutcome_bytesIn_count', 'catOutcome_bytesIn_max', 'catOutcome_bytesIn_min', 'catOutcome_bytesIn_median', 'catOutcome_bytesIn_mean', 'catOutcome_bytesIn_sum', 'catOutcome_bytesIn_skew', 'catOutcome_bytesIn_std', 'catOutcome_bytesIn_nunique', 'catOutcome_bytesIn_max_min', 'catOutcome_bytesIn_quantile_25', 'catOutcome_bytesIn_quantile_75', 'destHostName_bytesOut_count', 'destHostName_bytesOut_max', 'destHostName_ ...
# PSI drop features:
#  []
# Error drop features:
#  ['accessAgent', 'destGeoRegion', 'destGeoCountry', 'destGeoCity', 'requestContentType', 'responseCode_0', 'responseContentType', 'requestHeader', 'destHostName', 'httpVersion', 'responseCode', 'catOutcome', 'responseHeader', 'requestMethod', 'destDetailCity', 'txId']
# y_train mean:  0.4786456329357445
# y_valid mean:  0.4690265486725664
# bytesOut
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [256]	training's auc: 0.983016	valid_0's auc: 0.976567
# Evaluated only: auc
# **********
# 0.9765672741971918
# bytesIn
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [223]	training's auc: 0.928302	valid_0's auc: 0.907369
# Evaluated only: auc
# **********
# 0.9073688340407319
# txId_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [15]	training's auc: 0.581509	valid_0's auc: 0.593159
# Evaluated only: auc
# **********
# 0.5931593370664955
# destGeoCountry_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.594929	valid_0's auc: 0.58005
# Evaluated only: auc
# **********
# 0.5800504690230767
# destGeoRegion_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	training's auc: 0.641851	valid_0's auc: 0.629007
# Evaluated only: auc
# **********
# 0.6290066103125631
# destGeoCity_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	training's auc: 0.645221	valid_0's auc: 0.631195
# Evaluated only: auc
# **********
# 0.6311947902176885
# catOutcome_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.78004	valid_0's auc: 0.771951
# Evaluated only: auc
# **********
# 0.7719507555492148
# destHostName_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.725183	valid_0's auc: 0.706858
# Evaluated only: auc
# **********
# 0.7068581992842791
# responseCode_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [70]	training's auc: 0.800561	valid_0's auc: 0.790305
# Evaluated only: auc
# **********
# 0.7903050730582207
# requestMethod_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [19]	training's auc: 0.542971	valid_0's auc: 0.546928
# Evaluated only: auc
# **********
# 0.5469284635778912
# httpVersion_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.502701	valid_0's auc: 0.502461
# Evaluated only: auc
# **********
# 0.5024610336341263
# accessAgent_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.614025	valid_0's auc: 0.59635
# Evaluated only: auc
# **********
# 0.5963500612286146
# responseCode_0_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	training's auc: 0.783011	valid_0's auc: 0.773865
# Evaluated only: auc
# **********
# 0.7738648928202019
# requestHeader_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.541875	valid_0's auc: 0.525351
# Evaluated only: auc
# **********
# 0.5253510242417757
# responseHeader_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [52]	training's auc: 0.599511	valid_0's auc: 0.585431
# Evaluated only: auc
# **********
# 0.5854308592217426
# requestContentType_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.567886	valid_0's auc: 0.55918
# Evaluated only: auc
# **********
# 0.5591801310173461
# responseContentType_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.553082	valid_0's auc: 0.53786
# Evaluated only: auc
# **********
# 0.5378603868697317
# destDetailCity_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [18]	training's auc: 0.647681	valid_0's auc: 0.63147
# Evaluated only: auc
# **********
# 0.6314703189832483
# txId_bytesOut_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [15]	training's auc: 0.581509	valid_0's auc: 0.593159
# Evaluated only: auc
# **********
# 0.5931593370664955
# txId_bytesOut_max
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [7]	training's auc: 0.583578	valid_0's auc: 0.588412
# Evaluated only: auc
# **********
# 0.5884117416271356
# txId_bytesOut_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [24]	training's auc: 0.518819	valid_0's auc: 0.509146
# Evaluated only: auc
# **********
# 0.5091456527683657
# txId_bytesOut_median
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [33]	training's auc: 0.573678	valid_0's auc: 0.589443
# Evaluated only: auc
# **********
# 0.5894434140599921
# txId_bytesOut_mean
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [24]	training's auc: 0.583442	valid_0's auc: 0.591742
# Evaluated only: auc
# **********
# 0.5917424593691669
# txId_bytesOut_sum
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [38]	training's auc: 0.58442	valid_0's auc: 0.593131
# Evaluated only: auc
# **********
# 0.593130506116917
# txId_bytesOut_skew
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [31]	training's auc: 0.585103	valid_0's auc: 0.59208
# Evaluated only: auc
# **********
# 0.5920804056544329
# txId_bytesOut_std
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [39]	training's auc: 0.583546	valid_0's auc: 0.59188
# Evaluated only: auc
# **********
# 0.5918800751388047
# txId_bytesOut_nunique
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [11]	training's auc: 0.581297	valid_0's auc: 0.593248
# Evaluated only: auc
# **********
# 0.5932482077255056
# txId_bytesOut_max_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [20]	training's auc: 0.584764	valid_0's auc: 0.590876
# Evaluated only: auc
# **********
# 0.5908757475241051
# txId_bytesOut_quantile_25
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [49]	training's auc: 0.578457	valid_0's auc: 0.593507
# Evaluated only: auc
# **********
# 0.5935070918191437
# txId_bytesOut_quantile_75
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [39]	training's auc: 0.57985	valid_0's auc: 0.590873
# Evaluated only: auc
# **********
# 0.5908733697138305
# txId_bytesIn_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [15]	training's auc: 0.581509	valid_0's auc: 0.593159
# Evaluated only: auc
# **********
# 0.5931593370664955
# txId_bytesIn_max
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [6]	training's auc: 0.58057	valid_0's auc: 0.594034
# Evaluated only: auc
# **********
# 0.5940343712475181
# txId_bytesIn_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [56]	training's auc: 0.576242	valid_0's auc: 0.586638
# Evaluated only: auc
# **********
# 0.586637895162345
# txId_bytesIn_median
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [12]	training's auc: 0.580226	valid_0's auc: 0.59717
# Evaluated only: auc
# **********
# 0.5971695140944704
# txId_bytesIn_mean
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [17]	training's auc: 0.584431	valid_0's auc: 0.593267
# Evaluated only: auc
# **********
# 0.5932672302077018
# txId_bytesIn_sum
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [28]	training's auc: 0.585245	valid_0's auc: 0.591981
# Evaluated only: auc
# **********
# 0.5919808348491874
# txId_bytesIn_skew
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [18]	training's auc: 0.583615	valid_0's auc: 0.589333
# Evaluated only: auc
# **********
# 0.5893334403347957
# txId_bytesIn_std
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [35]	training's auc: 0.584748	valid_0's auc: 0.591748
# Evaluated only: auc
# **********
# 0.5917481066685689
# txId_bytesIn_nunique
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [22]	training's auc: 0.581128	valid_0's auc: 0.594388
# Evaluated only: auc
# **********
# 0.5943877732995684
# txId_bytesIn_max_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [65]	training's auc: 0.581338	valid_0's auc: 0.590765
# Evaluated only: auc
# **********
# 0.5907654765726242
# txId_bytesIn_quantile_25
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [3]	training's auc: 0.576516	valid_0's auc: 0.587789
# Evaluated only: auc
# **********
# 0.5877890525614962
# txId_bytesIn_quantile_75
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [26]	training's auc: 0.579692	valid_0's auc: 0.591066
# Evaluated only: auc
# **********
# 0.5910662695723509
# destGeoCountry_bytesOut_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.594929	valid_0's auc: 0.58005
# Evaluated only: auc
# **********
# 0.5800504690230767
# destGeoCountry_bytesOut_max
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [24]	training's auc: 0.59493	valid_0's auc: 0.580053
# Evaluated only: auc
# **********
# 0.5800528468333511
# destGeoCountry_bytesOut_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.5	valid_0's auc: 0.5
# Evaluated only: auc
# **********
# 0.5
# destGeoCountry_bytesOut_median
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.594951	valid_0's auc: 0.580684
# Evaluated only: auc
# **********
# 0.5806841554612358
# destGeoCountry_bytesOut_mean
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [14]	training's auc: 0.594857	valid_0's auc: 0.57983
# Evaluated only: auc
# **********
# 0.5798302243463994
# destGeoCountry_bytesOut_sum
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.594929	valid_0's auc: 0.58005
# Evaluated only: auc
# **********
# 0.5800504690230767
# destGeoCountry_bytesOut_skew
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [25]	training's auc: 0.594857	valid_0's auc: 0.580052
# Evaluated only: auc
# **********
# 0.5800516579282139
# destGeoCountry_bytesOut_std
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [11]	training's auc: 0.594858	valid_0's auc: 0.57983
# Evaluated only: auc
# **********
# 0.5798302243463994
# destGeoCountry_bytesOut_nunique
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.594929	valid_0's auc: 0.58005
# Evaluated only: auc
# **********
# 0.5800504690230767
# destGeoCountry_bytesOut_max_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [24]	training's auc: 0.59493	valid_0's auc: 0.580053
# Evaluated only: auc
# **********
# 0.5800528468333511
# destGeoCountry_bytesOut_quantile_25
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.593455	valid_0's auc: 0.579977
# Evaluated only: auc
# **********
# 0.5799767569045666
# destGeoCountry_bytesOut_quantile_75
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.594406	valid_0's auc: 0.581474
# Evaluated only: auc
# **********
# 0.5814738856986601
# destGeoCountry_bytesIn_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.594929	valid_0's auc: 0.58005
# Evaluated only: auc
# **********
# 0.5800504690230767
# destGeoCountry_bytesIn_max
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.594538	valid_0's auc: 0.580777
# Evaluated only: auc
# **********
# 0.5807765928356576
# destGeoCountry_bytesIn_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.501164	valid_0's auc: 0.500677
# Evaluated only: auc
# **********
# 0.5006767842493848
# destGeoCountry_bytesIn_median
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.594048	valid_0's auc: 0.581884
# Evaluated only: auc
# **********
# 0.5818840579710145
# destGeoCountry_bytesIn_mean
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [32]	training's auc: 0.59493	valid_0's auc: 0.580051
# Evaluated only: auc
# **********
# 0.5800507662493609
# destGeoCountry_bytesIn_sum
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.594538	valid_0's auc: 0.580777
# Evaluated only: auc
# **********
# 0.5807765928356576
# destGeoCountry_bytesIn_skew
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [13]	training's auc: 0.59493	valid_0's auc: 0.580052
# Evaluated only: auc
# **********
# 0.5800516579282139
# destGeoCountry_bytesIn_std
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [31]	training's auc: 0.594857	valid_0's auc: 0.580051
# Evaluated only: auc
# **********
# 0.5800507662493609
# destGeoCountry_bytesIn_nunique
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.594929	valid_0's auc: 0.58005
# Evaluated only: auc
# **********
# 0.5800504690230767
# destGeoCountry_bytesIn_max_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.594538	valid_0's auc: 0.580777
# Evaluated only: auc
# **********
# 0.5807765928356576
# destGeoCountry_bytesIn_quantile_25
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [29]	training's auc: 0.594397	valid_0's auc: 0.580749
# Evaluated only: auc
# **********
# 0.5807489507912164
# destGeoCountry_bytesIn_quantile_75
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.594861	valid_0's auc: 0.581503
# Evaluated only: auc
# **********
# 0.5815027166482386
# destGeoRegion_bytesOut_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	training's auc: 0.641851	valid_0's auc: 0.629007
# Evaluated only: auc
# **********
# 0.6290066103125631
# destGeoRegion_bytesOut_max
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.642255	valid_0's auc: 0.630871
# Evaluated only: auc
# **********
# 0.630871408020354
# destGeoRegion_bytesOut_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [3]	training's auc: 0.501968	valid_0's auc: 0.499991
# Evaluated only: auc
# **********
# 0.49999108321147057
# destGeoRegion_bytesOut_median
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [36]	training's auc: 0.64242	valid_0's auc: 0.629695
# Evaluated only: auc
# **********
# 0.6296946891607519
# destGeoRegion_bytesOut_mean
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [51]	training's auc: 0.64274	valid_0's auc: 0.630732
# Evaluated only: auc
# **********
# 0.6307320088930104
# destGeoRegion_bytesOut_sum
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [5]	training's auc: 0.642217	valid_0's auc: 0.630262
# Evaluated only: auc
# **********
# 0.630262391363793
# destGeoRegion_bytesOut_skew
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [48]	training's auc: 0.643235	valid_0's auc: 0.628375
# Evaluated only: auc
# **********
# 0.6283750044583942
# destGeoRegion_bytesOut_std
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [64]	training's auc: 0.642722	valid_0's auc: 0.630548
# Evaluated only: auc
# **********
# 0.6305483230493039
# destGeoRegion_bytesOut_nunique
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [12]	training's auc: 0.642275	valid_0's auc: 0.628669
# Evaluated only: auc
# **********
# 0.6286686640272973
# destGeoRegion_bytesOut_max_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [16]	training's auc: 0.642309	valid_0's auc: 0.631276
# Evaluated only: auc
# **********
# 0.6312759329933064
# destGeoRegion_bytesOut_quantile_25
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.610463	valid_0's auc: 0.607426
# Evaluated only: auc
# **********
# 0.6074259014873203
# destGeoRegion_bytesOut_quantile_75
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.594417	valid_0's auc: 0.581159
# Evaluated only: auc
# **********
# 0.5811594202898551
# destGeoRegion_bytesIn_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	training's auc: 0.641851	valid_0's auc: 0.629007
# Evaluated only: auc
# **********
# 0.6290066103125631
# destGeoRegion_bytesIn_max
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.642492	valid_0's auc: 0.627815
# Evaluated only: auc
# **********
# 0.6278153273650295
# destGeoRegion_bytesIn_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.532837	valid_0's auc: 0.52861
# Evaluated only: auc
# **********
# 0.5286104076755715
# destGeoRegion_bytesIn_median
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [11]	training's auc: 0.64227	valid_0's auc: 0.630502
# Evaluated only: auc
# **********
# 0.6305019557489507
# destGeoRegion_bytesIn_mean
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [5]	training's auc: 0.642847	valid_0's auc: 0.629822
# Evaluated only: auc
# **********
# 0.6298219020104386
# destGeoRegion_bytesIn_sum
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [13]	training's auc: 0.642606	valid_0's auc: 0.629573
# Evaluated only: auc
# **********
# 0.6295725291578985
# destGeoRegion_bytesIn_skew
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.64316	valid_0's auc: 0.629385
# Evaluated only: auc
# **********
# 0.6293846821462116
# destGeoRegion_bytesIn_std
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [12]	training's auc: 0.642835	valid_0's auc: 0.628918
# Evaluated only: auc
# **********
# 0.6289183341061216
# destGeoRegion_bytesIn_nunique
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [21]	training's auc: 0.642433	valid_0's auc: 0.628864
# Evaluated only: auc
# **********
# 0.628863941696092
# destGeoRegion_bytesIn_max_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [12]	training's auc: 0.64286	valid_0's auc: 0.628645
# Evaluated only: auc
# **********
# 0.6286454803771208
# destGeoRegion_bytesIn_quantile_25
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [12]	training's auc: 0.642072	valid_0's auc: 0.632004
# Evaluated only: auc
# **********
# 0.6320038401635933
# destGeoRegion_bytesIn_quantile_75
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [25]	training's auc: 0.642651	valid_0's auc: 0.629458
# Evaluated only: auc
# **********
# 0.6294575025858686
# destGeoCity_bytesOut_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	training's auc: 0.645221	valid_0's auc: 0.631195
# Evaluated only: auc
# **********
# 0.6311947902176885
# destGeoCity_bytesOut_max
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [3]	training's auc: 0.646313	valid_0's auc: 0.632467
# Evaluated only: auc
# **********
# 0.6324669187145557
# destGeoCity_bytesOut_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [43]	training's auc: 0.504296	valid_0's auc: 0.500658
# Evaluated only: auc
# **********
# 0.5006580589934729
# destGeoCity_bytesOut_median
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [24]	training's auc: 0.643187	valid_0's auc: 0.630742
# Evaluated only: auc
# **********
# 0.6307424118129614
# destGeoCity_bytesOut_mean
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [7]	training's auc: 0.646137	valid_0's auc: 0.631718
# Evaluated only: auc
# **********
# 0.6317176112517983
# destGeoCity_bytesOut_sum
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [5]	training's auc: 0.64662	valid_0's auc: 0.63126
# Evaluated only: auc
# **********
# 0.6312604772265221
# destGeoCity_bytesOut_skew
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [40]	training's auc: 0.647878	valid_0's auc: 0.628472
# Evaluated only: auc
# **********
# 0.6284724946796495
# destGeoCity_bytesOut_std
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.646286	valid_0's auc: 0.631507
# Evaluated only: auc
# **********
# 0.6315074722687877
# destGeoCity_bytesOut_nunique
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [4]	training's auc: 0.645294	valid_0's auc: 0.631513
# Evaluated only: auc
# **********
# 0.6315125251156211
# destGeoCity_bytesOut_max_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [19]	training's auc: 0.646362	valid_0's auc: 0.631837
# Evaluated only: auc
# **********
# 0.6318373934443771
# destGeoCity_bytesOut_quantile_25
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [9]	training's auc: 0.617065	valid_0's auc: 0.614177
# Evaluated only: auc
# **********
# 0.6141773965355304
# destGeoCity_bytesOut_quantile_75
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [14]	training's auc: 0.594963	valid_0's auc: 0.579108
# Evaluated only: auc
# **********
# 0.5791076672492301
# destGeoCity_bytesIn_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	training's auc: 0.645221	valid_0's auc: 0.631195
# Evaluated only: auc
# **********
# 0.6311947902176885
# destGeoCity_bytesIn_max
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.644021	valid_0's auc: 0.630111
# Evaluated only: auc
# **********
# 0.6301105087325082
# destGeoCity_bytesIn_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.529454	valid_0's auc: 0.518085
# Evaluated only: auc
# **********
# 0.5180850304954168
# destGeoCity_bytesIn_median
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.645131	valid_0's auc: 0.631806
# Evaluated only: auc
# **********
# 0.6318064819108083
# destGeoCity_bytesIn_mean
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [15]	training's auc: 0.646659	valid_0's auc: 0.629497
# Evaluated only: auc
# **********
# 0.6294973309079669
# destGeoCity_bytesIn_sum
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.645962	valid_0's auc: 0.630192
# Evaluated only: auc
# **********
# 0.6301922459606948
# destGeoCity_bytesIn_skew
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [12]	training's auc: 0.646012	valid_0's auc: 0.632435
# Evaluated only: auc
# **********
# 0.6324354127284184
# destGeoCity_bytesIn_std
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.645648	valid_0's auc: 0.630957
# Evaluated only: auc
# **********
# 0.6309570091902367
# destGeoCity_bytesIn_nunique
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [9]	training's auc: 0.645221	valid_0's auc: 0.632549
# Evaluated only: auc
# **********
# 0.6325486559427423
# destGeoCity_bytesIn_max_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [32]	training's auc: 0.646544	valid_0's auc: 0.63071
# Evaluated only: auc
# **********
# 0.6307100141479711
# destGeoCity_bytesIn_quantile_25
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [6]	training's auc: 0.644001	valid_0's auc: 0.629105
# Evaluated only: auc
# **********
# 0.6291052894389557
# destGeoCity_bytesIn_quantile_75
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [115]	training's auc: 0.646985	valid_0's auc: 0.63239
# Evaluated only: auc
# **********
# 0.6323902343332025
# catOutcome_bytesOut_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.78004	valid_0's auc: 0.771951
# Evaluated only: auc
# **********
# 0.7719507555492148
# catOutcome_bytesOut_max
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.78004	valid_0's auc: 0.771951
# Evaluated only: auc
# **********
# 0.7719507555492148
# catOutcome_bytesOut_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.779734	valid_0's auc: 0.772477
# Evaluated only: auc
# **********
# 0.7724774405250205
# catOutcome_bytesOut_median
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.779734	valid_0's auc: 0.772477
# Evaluated only: auc
# **********
# 0.7724774405250205
# catOutcome_bytesOut_mean
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.78004	valid_0's auc: 0.771951
# Evaluated only: auc
# **********
# 0.7719507555492148
# catOutcome_bytesOut_sum
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.78004	valid_0's auc: 0.771951
# Evaluated only: auc
# **********
# 0.7719507555492148
# catOutcome_bytesOut_skew
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.78004	valid_0's auc: 0.771951
# Evaluated only: auc
# **********
# 0.7719507555492148
# catOutcome_bytesOut_std
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.78004	valid_0's auc: 0.771951
# Evaluated only: auc
# **********
# 0.7719507555492148
# catOutcome_bytesOut_nunique
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.78004	valid_0's auc: 0.771951
# Evaluated only: auc
# **********
# 0.7719507555492148
# catOutcome_bytesOut_max_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.78004	valid_0's auc: 0.771951
# Evaluated only: auc
# **********
# 0.7719507555492148
# catOutcome_bytesOut_quantile_25
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.779734	valid_0's auc: 0.772477
# Evaluated only: auc
# **********
# 0.7724774405250205
# catOutcome_bytesOut_quantile_75
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.779734	valid_0's auc: 0.772477
# Evaluated only: auc
# **********
# 0.7724774405250205
# catOutcome_bytesIn_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.78004	valid_0's auc: 0.771951
# Evaluated only: auc
# **********
# 0.7719507555492148
# catOutcome_bytesIn_max
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.779734	valid_0's auc: 0.772477
# Evaluated only: auc
# **********
# 0.7724774405250205
# catOutcome_bytesIn_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.779734	valid_0's auc: 0.772477
# Evaluated only: auc
# **********
# 0.7724774405250205
# catOutcome_bytesIn_median
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.779734	valid_0's auc: 0.772477
# Evaluated only: auc
# **********
# 0.7724774405250205
# catOutcome_bytesIn_mean
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.779734	valid_0's auc: 0.772477
# Evaluated only: auc
# **********
# 0.7724774405250205
# catOutcome_bytesIn_sum
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.779734	valid_0's auc: 0.772477
# Evaluated only: auc
# **********
# 0.7724774405250205
# catOutcome_bytesIn_skew
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.78004	valid_0's auc: 0.771951
# Evaluated only: auc
# **********
# 0.7719507555492148
# catOutcome_bytesIn_std
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.779734	valid_0's auc: 0.772477
# Evaluated only: auc
# **********
# 0.7724774405250205
# catOutcome_bytesIn_nunique
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.78004	valid_0's auc: 0.771951
# Evaluated only: auc
# **********
# 0.7719507555492148
# catOutcome_bytesIn_max_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.779734	valid_0's auc: 0.772477
# Evaluated only: auc
# **********
# 0.7724774405250205
# catOutcome_bytesIn_quantile_25
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.779734	valid_0's auc: 0.772477
# Evaluated only: auc
# **********
# 0.7724774405250205
# catOutcome_bytesIn_quantile_75
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.78004	valid_0's auc: 0.771951
# Evaluated only: auc
# **********
# 0.7719507555492148
# destHostName_bytesOut_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.725183	valid_0's auc: 0.706858
# Evaluated only: auc
# **********
# 0.7068581992842791
# destHostName_bytesOut_max
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	training's auc: 0.733199	valid_0's auc: 0.702493
# Evaluated only: auc
# **********
# 0.7024934312991167
# destHostName_bytesOut_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [84]	training's auc: 0.560977	valid_0's auc: 0.531228
# Evaluated only: auc
# **********
# 0.5312277823352475
# destHostName_bytesOut_median
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [25]	training's auc: 0.737438	valid_0's auc: 0.714995
# Evaluated only: auc
# **********
# 0.7149953632699647
# destHostName_bytesOut_mean
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [35]	training's auc: 0.746069	valid_0's auc: 0.71367
# Evaluated only: auc
# **********
# 0.7136700312682052
# destHostName_bytesOut_sum
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [58]	training's auc: 0.747412	valid_0's auc: 0.702639
# Evaluated only: auc
# **********
# 0.7026387749521465
# destHostName_bytesOut_skew
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [25]	training's auc: 0.738244	valid_0's auc: 0.703981
# Evaluated only: auc
# **********
# 0.7039813460783964
# destHostName_bytesOut_std
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [43]	training's auc: 0.748943	valid_0's auc: 0.708491
# Evaluated only: auc
# **********
# 0.7084905660377359
# destHostName_bytesOut_nunique
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [6]	training's auc: 0.725378	valid_0's auc: 0.695304
# Evaluated only: auc
# **********
# 0.6953035274815422
# destHostName_bytesOut_max_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [4]	training's auc: 0.736077	valid_0's auc: 0.705278
# Evaluated only: auc
# **********
# 0.7052775499042931
# destHostName_bytesOut_quantile_25
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [132]	training's auc: 0.743001	valid_0's auc: 0.71288
# Evaluated only: auc
# **********
# 0.7128803010307807
# destHostName_bytesOut_quantile_75
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.719128	valid_0's auc: 0.702735
# Evaluated only: auc
# **********
# 0.7027353734945488
# destHostName_bytesIn_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.725183	valid_0's auc: 0.706858
# Evaluated only: auc
# **********
# 0.7068581992842791
# destHostName_bytesIn_max
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [7]	training's auc: 0.735105	valid_0's auc: 0.704641
# Evaluated only: auc
# **********
# 0.7046405939770066
# destHostName_bytesIn_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [441]	training's auc: 0.652475	valid_0's auc: 0.634664
# Evaluated only: auc
# **********
# 0.6346643126344949
# destHostName_bytesIn_median
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [111]	training's auc: 0.746976	valid_0's auc: 0.716006
# Evaluated only: auc
# **********
# 0.7160056354103506
# destHostName_bytesIn_mean
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [3]	training's auc: 0.72868	valid_0's auc: 0.709281
# Evaluated only: auc
# **********
# 0.7092808907277288
# destHostName_bytesIn_sum
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [161]	training's auc: 0.74869	valid_0's auc: 0.708845
# Evaluated only: auc
# **********
# 0.7088445625423547
# destHostName_bytesIn_skew
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [4]	training's auc: 0.734678	valid_0's auc: 0.706455
# Evaluated only: auc
# **********
# 0.7064554576690326
# destHostName_bytesIn_std
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	training's auc: 0.73666	valid_0's auc: 0.707078
# Evaluated only: auc
# **********
# 0.7070781467346721
# destHostName_bytesIn_nunique
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [42]	training's auc: 0.729391	valid_0's auc: 0.699925
# Evaluated only: auc
# **********
# 0.6999245045237841
# destHostName_bytesIn_max_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.734742	valid_0's auc: 0.7045
# Evaluated only: auc
# **********
# 0.70450030317081
# destHostName_bytesIn_quantile_25
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [15]	training's auc: 0.726919	valid_0's auc: 0.70301
# Evaluated only: auc
# **********
# 0.7030100105812557
# destHostName_bytesIn_quantile_75
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [41]	training's auc: 0.749692	valid_0's auc: 0.710391
# Evaluated only: auc
# **********
# 0.7103910308996445
# responseCode_bytesOut_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [70]	training's auc: 0.800561	valid_0's auc: 0.790305
# Evaluated only: auc
# **********
# 0.7903050730582207
# responseCode_bytesOut_max
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [35]	training's auc: 0.799923	valid_0's auc: 0.789266
# Evaluated only: auc
# **********
# 0.7892659699682563
# responseCode_bytesOut_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [138]	training's auc: 0.801382	valid_0's auc: 0.79031
# Evaluated only: auc
# **********
# 0.7903098286787698
# responseCode_bytesOut_median
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [148]	training's auc: 0.800508	valid_0's auc: 0.7893
# Evaluated only: auc
# **********
# 0.7893004482172368
# responseCode_bytesOut_mean
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [93]	training's auc: 0.800612	valid_0's auc: 0.789994
# Evaluated only: auc
# **********
# 0.7899935799122588
# responseCode_bytesOut_sum
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [30]	training's auc: 0.801269	valid_0's auc: 0.790306
# Evaluated only: auc
# **********
# 0.790306261963358
# responseCode_bytesOut_skew
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [53]	training's auc: 0.799722	valid_0's auc: 0.789931
# Evaluated only: auc
# **********
# 0.7899311623925527
# responseCode_bytesOut_std
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [70]	training's auc: 0.800715	valid_0's auc: 0.790917
# Evaluated only: auc
# **********
# 0.7909167647513405
# responseCode_bytesOut_nunique
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [54]	training's auc: 0.799156	valid_0's auc: 0.788849
# Evaluated only: auc
# **********
# 0.7888486642650783
# responseCode_bytesOut_max_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [70]	training's auc: 0.800816	valid_0's auc: 0.791608
# Evaluated only: auc
# **********
# 0.791607518636088
# responseCode_bytesOut_quantile_25
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [33]	training's auc: 0.800999	valid_0's auc: 0.789646
# Evaluated only: auc
# **********
# 0.7896464196121792
# responseCode_bytesOut_quantile_75
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [72]	training's auc: 0.801055	valid_0's auc: 0.790364
# Evaluated only: auc
# **********
# 0.790363923862515
# responseCode_bytesIn_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [70]	training's auc: 0.800561	valid_0's auc: 0.790305
# Evaluated only: auc
# **********
# 0.7903050730582207
# responseCode_bytesIn_max
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [102]	training's auc: 0.801041	valid_0's auc: 0.790306
# Evaluated only: auc
# **********
# 0.7903056675107893
# responseCode_bytesIn_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [3]	training's auc: 0.798954	valid_0's auc: 0.790748
# Evaluated only: auc
# **********
# 0.7907476429955654
# responseCode_bytesIn_median
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [12]	training's auc: 0.800065	valid_0's auc: 0.790259
# Evaluated only: auc
# **********
# 0.7902590029841519
# responseCode_bytesIn_mean
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [32]	training's auc: 0.801162	valid_0's auc: 0.790139
# Evaluated only: auc
# **********
# 0.7901389235652887
# responseCode_bytesIn_sum
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [13]	training's auc: 0.799897	valid_0's auc: 0.790259
# Evaluated only: auc
# **********
# 0.7902587057578676
# responseCode_bytesIn_skew
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [11]	training's auc: 0.801384	valid_0's auc: 0.790318
# Evaluated only: auc
# **********
# 0.7903181510147306
# responseCode_bytesIn_std
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [114]	training's auc: 0.801037	valid_0's auc: 0.790309
# Evaluated only: auc
# **********
# 0.7903086397736324
# responseCode_bytesIn_nunique
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [9]	training's auc: 0.784587	valid_0's auc: 0.776348
# Evaluated only: auc
# **********
# 0.7763482184256518
# responseCode_bytesIn_max_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [5]	training's auc: 0.799229	valid_0's auc: 0.789564
# Evaluated only: auc
# **********
# 0.789564087931424
# responseCode_bytesIn_quantile_25
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.798732	valid_0's auc: 0.789811
# Evaluated only: auc
# **********
# 0.7898110829736895
# responseCode_bytesIn_quantile_75
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [123]	training's auc: 0.801383	valid_0's auc: 0.790309
# Evaluated only: auc
# **********
# 0.7903086397736324
# requestMethod_bytesOut_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [19]	training's auc: 0.542971	valid_0's auc: 0.546928
# Evaluated only: auc
# **********
# 0.5469284635778912
# requestMethod_bytesOut_max
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.539498	valid_0's auc: 0.540375
# Evaluated only: auc
# **********
# 0.540375218461319
# requestMethod_bytesOut_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [18]	training's auc: 0.504561	valid_0's auc: 0.504721
# Evaluated only: auc
# **********
# 0.5047211423000558
# requestMethod_bytesOut_median
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [39]	training's auc: 0.540782	valid_0's auc: 0.546084
# Evaluated only: auc
# **********
# 0.5460843409304371
# requestMethod_bytesOut_mean
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [35]	training's auc: 0.540388	valid_0's auc: 0.542582
# Evaluated only: auc
# **********
# 0.5425818263960719
# requestMethod_bytesOut_sum
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.539498	valid_0's auc: 0.540375
# Evaluated only: auc
# **********
# 0.540375218461319
# requestMethod_bytesOut_skew
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.539498	valid_0's auc: 0.540375
# Evaluated only: auc
# **********
# 0.540375218461319
# requestMethod_bytesOut_std
# Training until validation scores don't improve for 50 rounds
# ...
# Evaluated only: auc
# **********
# 0.5395016704117178
# responseContentType_bytesIn_quantile_75
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.553016	valid_0's auc: 0.538898
# Evaluated only: auc
# **********
# 0.5388980038282746
# destDetailCity_bytesOut_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [18]	training's auc: 0.647681	valid_0's auc: 0.63147
# Evaluated only: auc
# **********
# 0.6314703189832483
# destDetailCity_bytesOut_max
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [11]	training's auc: 0.647897	valid_0's auc: 0.63224
# Evaluated only: auc
# **********
# 0.6322398378333393
# destDetailCity_bytesOut_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.50543	valid_0's auc: 0.498266
# Evaluated only: auc
# **********
# 0.4982659818573076
# destDetailCity_bytesOut_median
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [89]	training's auc: 0.645003	valid_0's auc: 0.631206
# Evaluated only: auc
# **********
# 0.6312057875902082
# destDetailCity_bytesOut_mean
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [17]	training's auc: 0.647562	valid_0's auc: 0.631719
# Evaluated only: auc
# **********
# 0.6317190973832197
# destDetailCity_bytesOut_sum
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [60]	training's auc: 0.64883	valid_0's auc: 0.631418
# Evaluated only: auc
# **********
# 0.6314177099309246
# destDetailCity_bytesOut_skew
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	training's auc: 0.648379	valid_0's auc: 0.629404
# Evaluated only: auc
# **********
# 0.629404001854692
# destDetailCity_bytesOut_std
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [4]	training's auc: 0.647759	valid_0's auc: 0.632576
# Evaluated only: auc
# **********
# 0.6325760007608993
# destDetailCity_bytesOut_nunique
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [11]	training's auc: 0.646536	valid_0's auc: 0.632178
# Evaluated only: auc
# **********
# 0.6321780147662018
# destDetailCity_bytesOut_max_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [26]	training's auc: 0.648148	valid_0's auc: 0.632291
# Evaluated only: auc
# **********
# 0.6322909607542414
# destDetailCity_bytesOut_quantile_25
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.617903	valid_0's auc: 0.61395
# Evaluated only: auc
# **********
# 0.6139500184280297
# destDetailCity_bytesOut_quantile_75
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.595612	valid_0's auc: 0.57905
# Evaluated only: auc
# **********
# 0.5790503025763575
# destDetailCity_bytesIn_count
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [18]	training's auc: 0.647681	valid_0's auc: 0.63147
# Evaluated only: auc
# **********
# 0.6314703189832483
# destDetailCity_bytesIn_max
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.64542	valid_0's auc: 0.630341
# Evaluated only: auc
# **********
# 0.6303408591028522
# destDetailCity_bytesIn_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [35]	training's auc: 0.531534	valid_0's auc: 0.519236
# Evaluated only: auc
# **********
# 0.5192358906682836
# destDetailCity_bytesIn_median
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.646231	valid_0's auc: 0.632649
# Evaluated only: auc
# **********
# 0.6326488212005564
# destDetailCity_bytesIn_mean
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [24]	training's auc: 0.648295	valid_0's auc: 0.630583
# Evaluated only: auc
# **********
# 0.6305825040720001
# destDetailCity_bytesIn_sum
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [10]	training's auc: 0.647248	valid_0's auc: 0.631969
# Evaluated only: auc
# **********
# 0.6319690646883285
# destDetailCity_bytesIn_skew
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [12]	training's auc: 0.646754	valid_0's auc: 0.632346
# Evaluated only: auc
# **********
# 0.6323456503905553
# destDetailCity_bytesIn_std
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [38]	training's auc: 0.6488	valid_0's auc: 0.630487
# Evaluated only: auc
# **********
# 0.6304873916610194
# destDetailCity_bytesIn_nunique
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [18]	training's auc: 0.646975	valid_0's auc: 0.632496
# Evaluated only: auc
# **********
# 0.632496344116703
# destDetailCity_bytesIn_max_min
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [30]	training's auc: 0.64829	valid_0's auc: 0.63086
# Evaluated only: auc
# **********
# 0.6308601134215501
# destDetailCity_bytesIn_quantile_25
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.645494	valid_0's auc: 0.630852
# Evaluated only: auc
# **********
# 0.6308523855381579
# destDetailCity_bytesIn_quantile_75
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [85]	training's auc: 0.64905	valid_0's auc: 0.631856
# Evaluated only: auc
# **********
# 0.6318564159265733
# bytesOut_bytesIn_add
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [359]	training's auc: 0.912351	valid_0's auc: 0.89576
# Evaluated only: auc
# **********
# 0.8957603642805341
# bytesOut_bytesIn_subtract
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [199]	training's auc: 0.896212	valid_0's auc: 0.878314
# Evaluated only: auc
# **********
# 0.8783137758438254
# bytesOut_bytesInc_multiply
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [152]	training's auc: 0.899006	valid_0's auc: 0.880425
# Evaluated only: auc
# **********
# 0.8804249741413133
# bytesOut_bytesIn_ratio
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [95]	training's auc: 0.908389	valid_0's auc: 0.877754
# Evaluated only: auc
# **********
# 0.8777535042978921
# bytesIn_bytesOut_ratio
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [162]	training's auc: 0.908623	valid_0's auc: 0.876691
# Evaluated only: auc
# **********
# 0.8766909203314668
# accessAgent
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [7]	training's auc: 0.619982	valid_0's auc: 0.587588
# Evaluated only: auc
# **********
# 0.5875875331407308
# responseContentType
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.553068	valid_0's auc: 0.538694
# Evaluated only: auc
# **********
# 0.538694403823519
# requestContentType
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.567906	valid_0's auc: 0.559396
# Evaluated only: auc
# **********
# 0.5593962145260429
# httpVersion
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.5	valid_0's auc: 0.5
# Evaluated only: auc
# **********
# 0.5
# requestMethod
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.540685	valid_0's auc: 0.542582
# Evaluated only: auc
# **********
# 0.5425818263960719
# destGeoCity
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [5]	training's auc: 0.646118	valid_0's auc: 0.632478
# Evaluated only: auc
# **********
# 0.6324776188607911
# destDetailCity
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [22]	training's auc: 0.647759	valid_0's auc: 0.631313
# Evaluated only: auc
# **********
# 0.6313130862788459
# destGeoCountry
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.594103	valid_0's auc: 0.581522
# Evaluated only: auc
# **********
# 0.5815217391304348
# responseHeader
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [50]	training's auc: 0.598865	valid_0's auc: 0.583813
# Evaluated only: auc
# **********
# 0.583812759329933
# destGeoRegion
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [13]	training's auc: 0.641693	valid_0's auc: 0.629858
# Evaluated only: auc
# **********
# 0.629858163617125
# requestHeader
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [111]	training's auc: 0.54274	valid_0's auc: 0.524803
# Evaluated only: auc
# **********
# 0.5248032361997836
# destHostName
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [310]	training's auc: 0.753667	valid_0's auc: 0.701148
# Evaluated only: auc
# **********
# 0.7011481851363079
# catOutcome
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.779734	valid_0's auc: 0.772477
# Evaluated only: auc
# **********
# 0.7724774405250205
# responseCode
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [37]	training's auc: 0.79987	valid_0's auc: 0.789649
# Evaluated only: auc
# **********
# 0.7896487974224536
# responseCode_0
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's auc: 0.782889	valid_0's auc: 0.773865
# Evaluated only: auc
# **********
# 0.7738648928202019
# AUC drop features:
#  ['httpVersion_count', 'txId_bytesOut_min', 'destGeoCountry_bytesOut_min', 'destGeoCountry_bytesIn_min', 'destGeoRegion_bytesOut_min', 'destGeoCity_bytesOut_min', 'destGeoCity_bytesIn_min', 'requestMethod_bytesOut_min', 'httpVersion_bytesOut_count', 'httpVersion_bytesOut_max', 'httpVersion_bytesOut_min', 'httpVersion_bytesOut_median', 'httpVersion_bytesOut_mean', 'httpVersion_bytesOut_sum', 'httpVersion_bytesOut_skew', 'httpVersion_bytesOut_std', 'httpVersion_bytesOut_nunique', 'httpVersion_bytesOut_max_min', 'httpVersion_bytesOut_quantile_25', 'httpVersion_bytesOut_quantile_75', 'httpVersion_bytesIn_count', 'httpVersion_bytesIn_max', 'httpVersion_bytesIn_min', 'httpVersion_bytesIn_median', 'httpVersion_bytesIn_mean', 'httpVersion_bytesIn_sum', 'httpVersion_bytesIn_skew', 'httpVersion_bytesIn_std', 'httpVersion_bytesIn_nunique', 'httpVersion_bytesIn_max_min', 'httpVersion_bytesIn_quantile_25', 'httpVersion_bytesIn_quantile_75', 'accessAgent_bytesOut_min', 'requestHeader_bytesOut_min', 'requestHeader_bytesOut_quantile_75', 'requestHeader_bytesIn_min', 'requestHeader_bytesIn_quantile_25', 'requestContentType_bytesOut_min', 'requestContentType_bytesOut_quantile_75', 'requestContentType_bytesIn_min', 'requestContentType_bytesIn_quantile_25', 'responseContentType_bytesOut_min', 'responseContentType_bytesOut_quantile_75', 'responseContentType_bytesIn_min', 'destDetailCity_bytesOut_min', 'destDetailCity_bytesIn_min', 'httpVersion']
# Correlation drop features:
#  {'accessAgent_bytesOut_max', 'responseContentType_bytesOut_max', 'requestContentType_count', 'responseHeader_bytesOut_sum', 'responseCode_0_bytesOut_median', 'catOutcome_bytesOut_sum', 'txId_count', 'responseCode_count', 'destDetailCity_bytesIn_std', 'txId_bytesIn_skew', 'destGeoCountry_bytesIn_nunique', 'txId_bytesOut_max_min', 'responseCode_bytesIn_median', 'accessAgent_bytesOut_sum', 'destDetailCity_bytesOut_nunique', 'responseContentType_bytesOut_count', 'responseCode_0_bytesOut_max_min', 'accessAgent_count', 'responseHeader_bytesIn_std', 'responseCode_0_bytesOut_min', 'requestMethod_count', 'catOutcome_bytesOut_median', 'requestMethod_bytesIn_skew', 'destGeoCity_bytesIn_max_min', 'requestContentType_bytesOut_count', 'responseCode_0_bytesIn_quantile_75', 'requestMethod_bytesOut_sum', 'responseCode_bytesOut_nunique', 'requestMethod_bytesOut_max_min', 'destGeoCountry_bytesOut_sum', 'destDetailCity_count', 'destGeoRegion_bytesIn_max', 'requestMethod_bytesOut_mean', 'requestMethod_bytesIn_std', 'destGeoRegion_bytesOut_nunique', 'responseCode_0_bytesIn_sum', 'responseContentType_count', 'requestMethod_bytesIn_median', 'responseCode_0_bytesOut_nunique', 'destGeoCity_bytesIn_max', 'destGeoCountry_bytesOut_max_min', 'destDetailCity_bytesIn_count', 'requestMethod_bytesIn_sum', 'destGeoRegion_count', 'requestHeader_bytesOut_nunique', 'responseCode_0_bytesOut_count', 'txId_bytesOut_sum', 'requestContentType_bytesOut_sum', 'txId_bytesOut_count', 'responseCode_0_bytesOut_sum', 'responseCode_0_bytesOut_max', 'destGeoCountry_bytesOut_skew', 'requestMethod_bytesOut_max', 'catOutcome_bytesIn_skew', 'requestHeader_bytesIn_count', 'txId_bytesOut_nunique', 'destGeoCity_bytesIn_sum', 'requestMethod_bytesOut_skew', 'responseCode_0_bytesIn_skew', 'catOutcome_bytesOut_count', 'requestContentType_bytesIn_quantile_75', 'catOutcome_bytesOut_skew', 'responseContentType_bytesOut_quantile_25', 'catOutcome_bytesOut_mean', 'responseCode_bytesIn_sum', 'destGeoCountry_bytesIn_std', 'responseCode_0_bytesOut_mean', 'destHostName_bytesOut_quantile_25', 'destGeoCountry_bytesIn_max', 'destGeoCity_bytesIn_quantile_25', 'responseHeader_bytesIn_max', 'requestContentType_bytesOut_nunique', 'destDetailCity_bytesOut_count', 'catOutcome_bytesOut_quantile_75', 'requestMethod_bytesIn_max', 'responseCode_0_bytesIn_std', 'destDetailCity_bytesOut_quantile_75', 'destGeoCity_bytesIn_median', 'responseCode_bytesOut_max', 'responseCode_bytesOut_median', 'responseCode_0_bytesOut_std', 'requestMethod_bytesIn_mean', 'destHostName_bytesOut_count', 'responseCode_bytesIn_max_min', 'bytesOut_bytesIn_subtract', 'txId_bytesIn_max_min', 'requestMethod_bytesIn_count', 'accessAgent_bytesIn_sum', 'requestContentType_bytesIn_count', 'responseCode_0_bytesIn_count', 'responseHeader_bytesOut_max', 'responseCode_bytesOut_mean', 'accessAgent_bytesIn_max_min', 'responseHeader_bytesOut_nunique', 'responseCode_bytesOut_sum', 'destGeoCity_bytesOut_max_min', 'requestMethod_bytesOut_std', 'requestMethod_bytesIn_quantile_25', 'catOutcome_bytesIn_sum', 'catOutcome_bytesIn_mean', 'destDetailCity_bytesOut_max', 'responseCode_bytesIn_nunique', 'destDetailCity_bytesOut_max_min', 'catOutcome_bytesOut_max_min', 'responseCode_0_bytesIn_mean', 'catOutcome_bytesIn_std', 'accessAgent_bytesIn_quantile_25', 'responseHeader_count', 'destGeoCountry_count', 'destDetailCity_bytesOut_sum', 'catOutcome_count', 'responseCode_0_bytesIn_max', 'requestContentType_bytesIn_sum', 'requestMethod_bytesIn_nunique', 'responseCode_bytesIn_count', 'destGeoCity_bytesOut_sum', 'responseContentType_bytesIn_count', 'responseHeader_bytesIn_count', 'responseHeader_bytesOut_count', 'responseHeader_bytesIn_nunique', 'requestHeader_bytesIn_nunique', 'responseContentType_bytesIn_max', 'destHostName_bytesOut_max', 'requestContentType_bytesIn_mean', 'destGeoCity_bytesOut_nunique', 'catOutcome_bytesIn_nunique', 'accessAgent_bytesOut_nunique', 'destHostName_count', 'requestContentType_bytesIn_max', 'destGeoCountry_bytesIn_count', 'catOutcome_byte ...
# Training until validation scores don't improve for 200 rounds
# [300]	training's auc: 1	valid_0's auc: 0.995653
# [600]	training's auc: 1	valid_0's auc: 0.995817
# Early stopping, best iteration is:
# [642]	training's auc: 1	valid_0's auc: 0.995857
# Evaluated only: auc
# threshold:  0.5199999999999998
# Valid F1:  0.9769
# Valid mean label:  0.4636398614851866
# Test mean label:  0.43666291150331704
