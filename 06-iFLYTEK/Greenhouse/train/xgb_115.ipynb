# %%
import numpy as np
import pandas as pd
from datetime import datetime
import os
import gc
import xgboost as xgb
import math
from joblib import Parallel, delayed

from tqdm import tqdm
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.metrics import mean_absolute_error, mean_squared_error
import matplotlib.pyplot as plt
import time
import warnings

warnings.filterwarnings('ignore')

pd.set_option('max_columns', None)
pd.set_option('max_rows', None)

# %%
def timestamp2string(timeStamp):
    try:
        d = datetime.fromtimestamp(timeStamp)
        str1 = d.strftime("%Y-%m-%d %H:%M:%S")
        # 2015-08-28 16:43:37'
        return datetime.strptime(str1,'%Y-%m-%d %H:%M:%S')
    except Exception as e:
        return ''

# %%
def get_psi(c):
    psi_res = pd.DataFrame()
    psi_dict={}
    # for c in tqdm(f_cols):
    try:
        t_train = x_train[c].fillna(-998)
        t_test = x_test[c].fillna(-998)
        #获取切分点
        bins=[]
        for i in np.arange(0,1.1,0.2):
            bins.append(t_train.quantile(i))
        bins=sorted(set(bins))
        bins[0]=-np.inf
        bins[-1]=np.inf
        #计算psi
        t_psi = pd.DataFrame()
        t_psi['train'] = pd.cut(t_train,bins).value_counts().sort_index()
        t_psi['test'] = pd.cut(t_test,bins).value_counts()
        t_psi.index=[str(x) for x in t_psi.index]
        t_psi.loc['总计',:] = t_psi.sum()
        t_psi['train_rate'] = t_psi['train']/t_psi.loc['总计','train']
        t_psi['test_rate'] = t_psi['test']/t_psi.loc['总计','test']
        t_psi['psi'] = (t_psi['test_rate']-t_psi['train_rate'])*(np.log(t_psi['test_rate'])-np.log(t_psi['train_rate']))
        t_psi.loc['总计','psi'] = t_psi['psi'].sum()
        t_psi.index.name=c
        #汇总
        t_res = pd.DataFrame([[c,t_psi.loc['总计','psi']]],
                             columns=['变量名','PSI'])
        psi_res = pd.concat([psi_res,t_res])
        psi_dict[c]=t_psi
        print(c,'done')
    except:
        print(c,'error')
    return psi_res #, psi_dict

# %%
def correlation(df, threshold=0.98):
    """
    特征相关性计算
    @param df: 
    @param threshold: 
    @return: 
    """
    col_corr = set()
    corr_matrix = df.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold:
                colName = corr_matrix.columns[i]
                col_corr.add(colName)
    return col_corr

# %%
train_df = pd.read_hdf('../input/train.h5')
test_df = pd.read_hdf('../input/test.h5')
sub = pd.DataFrame(test_df['time'])

# %%
train_df = train_df[train_df['temperature'].notnull()]
train_df = train_df.fillna(method='bfill')
test_df = test_df.fillna(method='bfill')
gc.collect()
# Out:
# 64

# %%
train_df.columns = ['time', 'year', 'month', 'day', 'hour', 'min', 'sec', 'outdoorTemp', 'outdoorHum', 'outdoorAtmo',
                    'indoorHum', 'indoorAtmo', 'temperature']
test_df.columns = ['time', 'year', 'month', 'day', 'hour', 'min', 'sec', 'outdoorTemp', 'outdoorHum', 'outdoorAtmo',
                   'indoorHum', 'indoorAtmo']

# %%
print('train_df.shape: ', train_df.shape)
train_df = train_df.loc[(train_df['outdoorTemp'] >= test_df['outdoorTemp'].min()) & (train_df['outdoorTemp'] <= test_df['outdoorTemp'].max())]
print('处理后 train_df.shape: ', train_df.shape)
# Out:
# train_df.shape:  (24807, 13)
# 处理后 train_df.shape:  (19338, 13)

# %%
train_count = train_df.shape[0]
y_train = train_df['temperature'].values - train_df['outdoorTemp'].values

# %%
data_df = pd.concat([train_df, test_df], axis=0, ignore_index=True)

del train_df, test_df
gc.collect()
# Out:
# 0

# %%
numerical_features = ['outdoorTemp', 'outdoorHum', 'outdoorAtmo', 'indoorHum', 'indoorAtmo']
diff_features = ['{}_diff'.format(i) for i in numerical_features]
numerical_diff_features = numerical_features + diff_features

# %%
for i in tqdm(numerical_features):
    data_df['{}_diff'.format(i)] = data_df[i].diff()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 1253.68it/s]

# %%
data_df.fillna(method='bfill', inplace=True)

# %%
data_df['datetime'] = data_df['time'].apply(timestamp2string)

# %%
for i in numerical_diff_features:
    for j in ['1D', '2D', '3D']:
        data_df.set_index('datetime', inplace=True)
        tmp = data_df.groupby('hour')[i].rolling(j, closed='left', min_periods=2).agg({
            '{}_{}_rolling_mean'.format(i, j): 'mean',
            '{}_{}_rolling_median'.format(i, j): 'median',
            '{}_{}_rolling_max'.format(i, j): 'max',
            '{}_{}_rolling_min'.format(i, j): 'min',
            '{}_{}_rolling_sum'.format(i, j): 'sum',
            '{}_{}_rolling_std'.format(i, j): 'std',
            '{}_{}_rolling_skew'.format(i, j): 'skew'
        })
        tmp.reset_index(inplace=True)
        data_df.reset_index(inplace=True)
        data_df = data_df.merge(tmp, on=['datetime', 'hour'], how='left')
        del tmp
        gc.collect()


for i in numerical_diff_features:
    data_df.set_index('datetime', inplace=True)
    tmp = data_df.groupby('hour')[i].expanding(min_periods=2).agg({
        '{}_expanding_mean'.format(i): 'mean',
        '{}_expanding_median'.format(i): 'median',
        '{}_expanding_max'.format(i): 'max',
        '{}_expanding_min'.format(i): 'min',
        '{}_expanding_sum'.format(i): 'sum',
        '{}_expanding_std'.format(i): 'std',
        '{}_expanding_skew'.format(i): 'skew',
    })
    tmp.reset_index(inplace=True)
    data_df.reset_index(inplace=True)
    data_df = data_df.merge(tmp, on=['datetime', 'hour'], how='left')
    del tmp
    gc.collect()

# %%
data_df.drop('datetime', axis=1, inplace=True)

# %%
data_df.fillna(method='bfill', inplace=True)

# %%
# 基本聚合特征
group_feats = []
for f in tqdm(numerical_diff_features):
    data_df['MDH_{}_medi'.format(f)] = data_df.groupby(['month', 'day', 'hour'])[f].transform('median')
    data_df['MDH_{}_mean'.format(f)] = data_df.groupby(['month', 'day', 'hour'])[f].transform('mean')
    data_df['MDH_{}_max'.format(f)] = data_df.groupby(['month', 'day', 'hour'])[f].transform('max')
    data_df['MDH_{}_min'.format(f)] = data_df.groupby(['month', 'day', 'hour'])[f].transform('min')
    data_df['MDH_{}_sum'.format(f)] = data_df.groupby(['month', 'day', 'hour'])[f].transform('sum')
    data_df['MDH_{}_std'.format(f)] = data_df.groupby(['month', 'day', 'hour'])[f].transform('std')
    data_df['MDH_{}_skew'.format(f)] = data_df.groupby(['month', 'day', 'hour'])[f].transform('skew')
    
    data_df['MD_{}_medi'.format(f)] = data_df.groupby(['month', 'day'])[f].transform('median')
    data_df['MD_{}_mean'.format(f)] = data_df.groupby(['month', 'day'])[f].transform('mean')
    data_df['MD_{}_max'.format(f)] = data_df.groupby(['month', 'day'])[f].transform('max')
    data_df['MD_{}_min'.format(f)] = data_df.groupby(['month', 'day'])[f].transform('min')
    data_df['MD_{}_sum'.format(f)] = data_df.groupby(['month', 'day'])[f].transform('sum')
    data_df['MD_{}_std'.format(f)] = data_df.groupby(['month', 'day'])[f].transform('std')
    data_df['MD_{}_skew'.format(f)] = data_df.groupby(['month', 'day'])[f].transform('skew')

    group_feats.append('MDH_{}_medi'.format(f))
    group_feats.append('MDH_{}_mean'.format(f))
    group_feats.append('MDH_{}_max'.format(f))
    group_feats.append('MDH_{}_min'.format(f))
    group_feats.append('MDH_{}_sum'.format(f))
#     group_feats.append('MDH_{}_std'.format(f))
#     group_feats.append('MDH_{}_skew'.format(f))
    
    group_feats.append('MD_{}_medi'.format(f))
    group_feats.append('MD_{}_mean'.format(f))
    group_feats.append('MD_{}_max'.format(f))
    group_feats.append('MD_{}_min'.format(f))
    group_feats.append('MD_{}_sum'.format(f))
#     group_feats.append('MD_{}_std'.format(f))
#     group_feats.append('MD_{}_skew'.format(f))
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:12<00:00,  1.21s/it]

# %%
cross_features = numerical_diff_features + group_feats

# 基本交叉特征
for f1 in tqdm(cross_features):
    for f2 in cross_features:
        if f1 != f2:
            # colname_substract = '{}_{}_subtract'.format(f1, f2)
            colname_add = '{}_{}_add'.format(f1, f2)            
            colname_multiply = '{}_{}_multyply'.format(f1, f2)
            colname_ratio = '{}_{}_ratio'.format(f1, f2)
            
            # data_df[colname_substract] = data_df[f1].values - data_df[f2].values
            data_df[colname_add] = data_df[f1].values + data_df[f2].values
            data_df[colname_multiply] = data_df[f1].values / (data_df[f2].values + 0.001)
            data_df[colname_ratio] = data_df[f1].values * data_df[f2].values
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 110/110 [26:53<00:00, 14.66s/it]

# %%
for i in tqdm(range(len(cross_features))):
    for j in range(i + 1, len(cross_features)):
        colname_substract = '{}_{}_subtract'.format(cross_features[i], cross_features[j])
        
        data_df[colname_substract] = data_df[cross_features[i]].values - data_df[cross_features[j]].values
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 110/110 [18:47<00:00, 10.25s/it]

# %%
data_df.fillna(method='bfill', inplace=True)

# %%
# 历史信息提取
# data_df['dt'] = data_df['day'].values + (data_df['month'].values - 3) * 31

# %%
# def get_t_sts(f):
#     tmp_df = pd.DataFrame()
#     for t in tqdm(range(15, 45)):
#         tmp_data = data_df.loc[data_df['dt'] < t, :]
#         tmp = tmp_data.groupby(['hour'], as_index=False)[f].agg({
#             'hit_{}_mean'.format(f): 'mean',
#             'hit_{}_median'.format(f): 'median',
#             'hit_{}_max'.format(f): 'max',
#             'hit_{}_min'.format(f): 'min',
#             'hit_{}_sum'.format(f): 'sum',
#             'hit_{}_std'.format(f): 'std',
#             'hit_{}_skew'.format(f): 'skew'
#         })
#         tmp['dt'] = t
#         tmp_df = tmp_df.append(tmp)
#         del tmp
#         gc.collect()
    
#     data_df = data_df.merge(tmp_df, on=['dt', 'hour'], how='left')
#     del tmp_df
#     gc.collect()
    
# Parallel(n_jobs=4)(delayed(get_t_sts)(f) for f in tqdm(numerical_diff_features + ['temperature']))

# %%
# def get_t_1_sts(f):
#     tmp_df = pd.DataFrame()
#     for t in tqdm(range(15, 45)):
#         tmp = data_df.loc[(data_df['dt'] < t) & (data_df['dt'] >= t - 1), :].groupby(['hour'], as_index=False)[f].agg({
#             'hit_t_1_{}_mean'.format(f): 'mean',
#             'hit_t_1_{}_median'.format(f): 'median',
#             'hit_t_1_{}_max'.format(f): 'max',
#             'hit_t_1_{}_min'.format(f): 'min',
#             'hit_t_1_{}_sum'.format(f): 'sum',
#             'hit_t_1_{}_std'.format(f): 'std',
#             'hit_t_1_{}_skew'.format(f): 'skew'
#         })
#         tmp['dt'] = t
#         tmp_df = tmp_df.append(tmp)
#         del tmp
#         gc.collect()

#     data_df = data_df.merge(tmp_df, on=['dt', 'hour'], how='left')
#     del tmp_df
#     gc.collect()

# Parallel(n_jobs=4)(delayed(get_t_1_sts)(f) for f in tqdm(numerical_diff_features + ['temperature']))

# %%
# def get_t_2_sts(f):
#     tmp_df = pd.DataFrame()
#     for t in tqdm(range(15, 45)):
#         tmp = data_df.loc[(data_df['dt'] < t) & (data_df['dt'] >= t - 2), :].groupby(['hour'], as_index=False)[f].agg({
#             'hit_t_1_{}_mean'.format(f): 'mean',
#             'hit_t_1_{}_median'.format(f): 'median',
#             'hit_t_1_{}_max'.format(f): 'max',
#             'hit_t_1_{}_min'.format(f): 'min',
#             'hit_t_1_{}_sum'.format(f): 'sum',
#             'hit_t_1_{}_std'.format(f): 'std',
#             'hit_t_1_{}_skew'.format(f): 'skew'
#         })
#         tmp['dt'] = t
#         tmp_df = tmp_df.append(tmp)
#         del tmp
#         gc.collect()

#     data_df = data_df.merge(tmp_df, on=['dt', 'hour'], how='left')
#     del tmp_df
#     gc.collect()

# Parallel(n_jobs=4)(delayed(get_t_2_sts)(f) for f in tqdm(numerical_diff_features + ['temperature']))

# %%
data_df.fillna(method='bfill', inplace=True)

# %%
# 离散化
for f in ['outdoorTemp', 'outdoorHum', 'outdoorAtmo', 'indoorHum', 'indoorAtmo']:
    data_df[f + '_20_bin'] = pd.cut(data_df[f], 20, duplicates='drop').apply(lambda x: x.left).astype(int)
    data_df[f + '_50_bin'] = pd.cut(data_df[f], 50, duplicates='drop').apply(lambda x: x.left).astype(int)
    data_df[f + '_100_bin'] = pd.cut(data_df[f], 100, duplicates='drop').apply(lambda x: x.left).astype(int)
    data_df[f + '_200_bin'] = pd.cut(data_df[f], 200, duplicates='drop').apply(lambda x: x.left).astype(int)

# %%
# for f1 in tqdm(['outdoorTemp_20_bin', 'outdoorHum_20_bin', 'outdoorAtmo_20_bin', 'indoorHum_20_bin', 'indoorAtmo_20_bin']):
#     for f2 in ['outdoorTemp', 'outdoorHum', 'outdoorAtmo', 'indoorHum', 'indoorAtmo']:
#         data_df['{}_{}_medi'.format(f1, f2)] = data_df.groupby([f1])[f2].transform('median')
#         data_df['{}_{}_mean'.format(f1, f2)] = data_df.groupby([f1])[f2].transform('mean')
#         data_df['{}_{}_max'.format(f1, f2)] = data_df.groupby([f1])[f2].transform('max')
#         data_df['{}_{}_min'.format(f1, f2)] = data_df.groupby([f1])[f2].transform('min')
#         data_df['{}_{}_sum'.format(f1, f2)] = data_df.groupby([f1])[f2].transform('sum')
#         data_df['{}_{}_std'.format(f1, f2)] = data_df.groupby([f1])[f2].transform('std')
#         data_df['{}_{}_skew'.format(f1, f2)] = data_df.groupby([f1])[f2].transform('skew')

# for f1 in tqdm(['outdoorTemp_50_bin', 'outdoorHum_50_bin', 'outdoorAtmo_50_bin', 'indoorHum_50_bin', 'indoorAtmo_50_bin']):
#     for f2 in ['outdoorTemp', 'outdoorHum', 'outdoorAtmo', 'indoorHum', 'indoorAtmo']:
#         data_df['{}_{}_medi'.format(f1, f2)] = data_df.groupby([f1])[f2].transform('median')
#         data_df['{}_{}_mean'.format(f1, f2)] = data_df.groupby([f1])[f2].transform('mean')
#         data_df['{}_{}_max'.format(f1, f2)] = data_df.groupby([f1])[f2].transform('max')
#         data_df['{}_{}_min'.format(f1, f2)] = data_df.groupby([f1])[f2].transform('min')
#         data_df['{}_{}_sum'.format(f1, f2)] = data_df.groupby([f1])[f2].transform('sum')
#         data_df['{}_{}_std'.format(f1, f2)] = data_df.groupby([f1])[f2].transform('std')
#         data_df['{}_{}_skew'.format(f1, f2)] = data_df.groupby([f1])[f2].transform('skew')

# for f1 in tqdm(['outdoorTemp_100_bin', 'outdoorHum_100_bin', 'outdoorAtmo_100_bin', 'indoorHum_100_bin',
#                 'indoorAtmo_100_bin']):
#     for f2 in ['outdoorTemp', 'outdoorHum', 'outdoorAtmo', 'indoorHum', 'indoorAtmo']:
#         data_df['{}_{}_medi'.format(f1, f2)] = data_df.groupby([f1])[f2].transform('median')
#         data_df['{}_{}_mean'.format(f1, f2)] = data_df.groupby([f1])[f2].transform('mean')
#         data_df['{}_{}_max'.format(f1, f2)] = data_df.groupby([f1])[f2].transform('max')
#         data_df['{}_{}_min'.format(f1, f2)] = data_df.groupby([f1])[f2].transform('min')
#         data_df['{}_{}_sum'.format(f1, f2)] = data_df.groupby([f1])[f2].transform('sum')
#         data_df['{}_{}_std'.format(f1, f2)] = data_df.groupby([f1])[f2].transform('std')
#         data_df['{}_{}_skew'.format(f1, f2)] = data_df.groupby([f1])[f2].transform('skew')

# for f1 in tqdm(['outdoorTemp_200_bin', 'outdoorHum_200_bin', 'outdoorAtmo_200_bin', 'indoorHum_200_bin',
#                 'indoorAtmo_200_bin']):
#     for f2 in ['outdoorTemp', 'outdoorHum', 'outdoorAtmo', 'indoorHum', 'indoorAtmo']:
#         data_df['{}_{}_medi'.format(f1, f2)] = data_df.groupby([f1])[f2].transform('median')
#         data_df['{}_{}_mean'.format(f1, f2)] = data_df.groupby([f1])[f2].transform('mean')
#         data_df['{}_{}_max'.format(f1, f2)] = data_df.groupby([f1])[f2].transform('max')
#         data_df['{}_{}_min'.format(f1, f2)] = data_df.groupby([f1])[f2].transform('min')
#         data_df['{}_{}_sum'.format(f1, f2)] = data_df.groupby([f1])[f2].transform('sum')
#         data_df['{}_{}_std'.format(f1, f2)] = data_df.groupby([f1])[f2].transform('std')
#         data_df['{}_{}_skew'.format(f1, f2)] = data_df.groupby([f1])[f2].transform('skew')

# %%
for f1 in tqdm(['{}_20_bin'.format(i) for i in numerical_features] +
               ['{}_50_bin'.format(i) for i in numerical_features] +
               ['{}_100_bin'.format(i) for i in numerical_features] +
               ['{}_200_bin'.format(i) for i in numerical_features]):
    for f2 in numerical_features:
        tmp = data_df.groupby(f1, as_index=False)[f2].agg({
            '{}_{}_medi'.format(f1, f2): 'median',
            '{}_{}_mean'.format(f1, f2): 'mean',
            '{}_{}_max'.format(f1, f2): 'max',
            '{}_{}_min'.format(f1, f2): 'min',
            '{}_{}_sum'.format(f1, f2): 'sum',
            '{}_{}_std'.format(f1, f2): 'std',
            '{}_{}_skew'.format(f1, f2): 'skew'
        })
        data_df = data_df.merge(tmp, on=f1, how='left')
        del tmp
        gc.collect()
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 20/20 [1:58:28<00:00, 355.40s/it]

# %%
train_df = data_df[:train_count].copy().reset_index(drop=True)
test_df = data_df[train_count:].copy().reset_index(drop=True)

del data_df
gc.collect()
# Out:
# 20

# %%
drop_columns = ["time", "year", "sec", "temperature"]

features = train_df[:1].drop(drop_columns, axis=1).columns
x_train = train_df[features]
x_test = test_df[features]

# %%
psi_res = Parallel(n_jobs=4)(delayed(get_psi)(c) for c in tqdm(features))
psi_df = pd.concat(psi_res)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████| 43119/43119 [1:04:38<00:00, 11.12it/s]

# %%
features = list(psi_df[psi_df['PSI'] <= 0.2]['变量名'].values) + ['outdoorTemp']

# %%
x_train = x_train[features]
x_test = x_test[features]
gc.collect()
# Out:
# 40

# %%
col_corr = correlation(x_train, 0.98)
print(col_corr)
# Out:
# {'MD_outdoorAtmo_diff_sum_MDH_outdoorHum_mean_ratio', 'MDH_outdoorTemp_diff_min_MDH_outdoorHum_diff_sum_subtract', 'MD_indoorAtmo_diff_medi_MDH_indoorHum_max_ratio', 'MD_outdoorHum_medi_MD_outdoorTemp_mean_add', 'MDH_indoorHum_diff_sum_MDH_outdoorTemp_min_multyply', 'MDH_outdoorHum_mean_MDH_outdoorAtmo_max_ratio', 'MD_outdoorAtmo_diff_medi_MDH_outdoorHum_medi_add', 'MD_indoorHum_diff_max_MD_outdoorHum_min_ratio', 'MD_outdoorHum_max_MDH_outdoorHum_min_ratio', 'MDH_indoorHum_diff_mean_MD_indoorAtmo_sum_ratio', 'MD_indoorAtmo_diff_medi_MDH_indoorHum_min_ratio', 'MD_indoorAtmo_medi_indoorHum_add', 'MDH_outdoorHum_diff_min_indoorHum_add', 'MDH_indoorHum_min_MDH_indoorHum_diff_medi_subtract', 'MDH_outdoorTemp_diff_medi_MD_indoorHum_diff_max_ratio', 'MD_indoorAtmo_diff_sum_indoorHum_diff_add', 'outdoorHum_MDH_outdoorHum_max_add', 'MD_outdoorAtmo_diff_mean_MDH_outdoorTemp_diff_medi_ratio', 'MD_outdoorTemp_min_MD_indoorHum_diff_medi_multyply', 'MD_outdoorAtmo_diff_medi_MDH_outdoorAtmo_diff_mean_multyply', 'MD_outdoorHum_diff_medi_MDH_outdoorAtmo_diff_sum_add', 'MDH_indoorHum_mean', 'MDH_outdoorHum_diff_sum_MD_indoorAtmo_min_multyply', 'MD_indoorHum_medi_MDH_indoorHum_diff_sum_ratio', 'outdoorTemp_diff_MDH_outdoorAtmo_diff_sum_add', 'outdoorHum_MD_outdoorTemp_diff_sum_subtract', 'MD_indoorHum_diff_max_MDH_indoorHum_medi_multyply', 'MDH_outdoorTemp_diff_mean_MD_indoorHum_max_add', 'MD_indoorHum_mean_MD_outdoorTemp_diff_mean_subtract', 'MD_indoorAtmo_diff_medi_MD_outdoorTemp_medi_multyply', 'MDH_outdoorAtmo_diff_sum_MDH_indoorHum_min_multyply', 'MD_indoorHum_min_MDH_indoorHum_medi_multyply', 'MD_indoorAtmo_diff_medi_MDH_indoorAtmo_diff_max_multyply', 'MDH_indoorAtmo_mean_MDH_indoorHum_medi_multyply', 'indoorAtmo_diff_MDH_indoorHum_diff_sum_add', 'MDH_outdoorHum_diff_sum_MD_indoorAtmo_mean_ratio', 'MD_outdoorAtmo_diff_sum_MDH_outdoorHum_max_add', 'indoorHum_diff_MD_outdoorHum_mean_subtract', 'MDH_outdoorTemp_diff_medi_MD_outdoorTemp_diff_sum_multyply', 'MDH_outdoorTemp_max_MD_indoorAtmo_medi_add', 'MDH_outdoorTemp_diff_medi_MD_indoorAtmo_diff_sum_subtract', 'MD_indoorAtmo_mean_outdoorHum_ratio', 'MDH_outdoorTemp_max_MDH_indoorHum_min_subtract', 'MDH_outdoorAtmo_diff_sum_MD_indoorHum_max_ratio', 'MDH_indoorAtmo_diff_sum_outdoorHum_multyply', 'indoorAtmo_diff_MD_indoorHum_max_add', 'MDH_indoorHum_medi_outdoorAtmo_multyply', 'MD_outdoorTemp_diff_medi_MD_outdoorHum_max_add', 'MDH_outdoorHum_mean_MDH_indoorAtmo_medi_subtract', 'MDH_indoorHum_diff_sum_MDH_indoorAtmo_max_multyply', 'MDH_outdoorHum_mean_MDH_outdoorHum_diff_medi_subtract', 'MDH_outdoorTemp_diff_min_MDH_indoorHum_medi_add', 'MDH_outdoorHum_min_MD_indoorHum_medi_ratio', 'MDH_outdoorTemp_diff_sum_outdoorHum_multyply', 'indoorAtmo_MDH_indoorHum_max_add', 'outdoorTemp_MD_outdoorTemp_medi_subtract', 'MDH_outdoorHum_mean_MDH_outdoorTemp_diff_medi_ratio', 'MDH_indoorHum_medi_MDH_outdoorHum_min_multyply', 'MDH_outdoorAtmo_diff_max_MD_indoorAtmo_diff_medi_ratio', 'MDH_outdoorAtmo_diff_medi_MDH_indoorHum_mean_add', 'MD_indoorHum_diff_medi_MDH_outdoorHum_diff_sum_add', 'MDH_outdoorAtmo_diff_sum_MDH_indoorHum_max_multyply', 'outdoorHum_MDH_indoorHum_mean_subtract', 'MDH_outdoorHum_diff_mean_MD_indoorAtmo_diff_medi_multyply', 'MDH_indoorAtmo_sum_MDH_outdoorTemp_diff_medi_ratio', 'MDH_indoorAtmo_medi_MDH_outdoorHum_diff_sum_ratio', 'MDH_outdoorHum_mean_MDH_indoorAtmo_diff_mean_add', 'MDH_indoorHum_medi_MD_indoorHum_diff_mean_subtract', 'MDH_outdoorTemp_diff_medi_indoorHum_add', 'MDH_indoorHum_max_MD_indoorHum_mean_ratio', 'MDH_outdoorTemp_medi_MDH_indoorHum_diff_sum_ratio', 'MDH_indoorHum_mean_MD_indoorHum_diff_max_multyply', 'MDH_indoorAtmo_diff_mean_MD_indoorHum_diff_mean_multyply', 'MDH_outdoorTemp_diff_sum_MD_outdoorAtmo_medi_ratio', 'MDH_indoorAtmo_diff_sum_MD_outdoorAtmo_diff_medi_add', 'MDH_indoorHum_sum_MDH_outdoorTemp_diff_mean_ratio', 'MDH_indoorAtmo_mean_indoorAtmo_diff_add', 'MDH_indoorHum_max_MDH_outdoorAtmo_diff_sum_subtract', 'MDH_outdoorHum_medi_MDH_indoorHum_mean_ratio', 'MDH_out ...

# %%
x_train.drop(list(col_corr), axis=1, inplace=True)
x_test.drop(list(col_corr), axis=1, inplace=True)

# %%
nums = int(x_train.shape[0] * 0.8)

trn_x, trn_y, val_x, val_y = x_train[:nums], y_train[:nums], x_train[nums:], y_train[nums:]

train_matrix = xgb.DMatrix(trn_x, label=trn_y, missing=np.nan)
valid_matrix = xgb.DMatrix(val_x, label=val_y, missing=np.nan)
train_all_matrix = xgb.DMatrix(x_train, y_train, missing=np.nan)
test_matrix = xgb.DMatrix(x_test, label=val_y, missing=np.nan)

params = {
    'booster': 'gbtree',
    'eval_metric': 'mae',
    'min_child_weight': 5,
    'max_depth': 8,
    'subsample': 0.5,
    'colsample_bytree': 0.5,
    'eta': 0.01,
    'seed': 2020,
    'nthread': 36,
    'silent': 1
}

watchlist = [(train_matrix, 'train'), (valid_matrix, 'eval')]

model_eval = xgb.train(params,
                       train_matrix,
                       num_boost_round=50000,
                       evals=watchlist,
                       verbose_eval=500,
                       early_stopping_rounds=1000)
val_pred = model_eval.predict(valid_matrix, ntree_limit=model_eval.best_ntree_limit).reshape(-1, 1)
# Out:
# [0]	train-mae:0.72620	eval-mae:0.31611
# Multiple eval metrics have been passed: 'eval-mae' will be used for early stopping.
#
# Will train until eval-mae hasn't improved in 1000 rounds.
# [500]	train-mae:0.04880	eval-mae:0.15094
# [1000]	train-mae:0.03831	eval-mae:0.14967
# [1500]	train-mae:0.03193	eval-mae:0.14952
# [2000]	train-mae:0.02674	eval-mae:0.14956
# Stopping. Best iteration:
# [1389]	train-mae:0.03327	eval-mae:0.14937

# %%
mse = mean_squared_error(val_y, val_pred)
print("mse_score:", mse)
print("mse_score:", str(mse)[2:7])
# Out:
# mse_score: 0.03662676365050391
# mse_score: 03662

# %%
feat_imp_dict = model_eval.get_score(importance_type='gain')

# %%
feat_imp = pd.Series(feat_imp_dict).sort_values(ascending=False).reset_index().rename(columns={'index': 'feature',
                                                                                               0: 'importance'})
feat_imp['normalized_importance'] = feat_imp['importance'] / feat_imp['importance'].sum()
feat_imp['cumulative_importance'] = np.cumsum(feat_imp['normalized_importance'])
record_low_importance = feat_imp[feat_imp['cumulative_importance'] > 0.95]

to_drop = list(record_low_importance['feature'])
print(to_drop)
# Out:
# ['outdoorTemp_MDH_outdoorAtmo_medi_add', 'MD_outdoorHum_diff_max_MDH_outdoorAtmo_diff_sum_multyply', 'outdoorAtmo_50_bin_outdoorTemp_medi', 'MDH_indoorAtmo_diff_sum_MD_outdoorHum_diff_sum_multyply', 'MDH_outdoorHum_diff_min_MDH_indoorAtmo_diff_sum_ratio', 'MD_outdoorHum_diff_mean_MDH_outdoorAtmo_diff_mean_multyply', 'MDH_outdoorTemp_diff_sum_MD_indoorHum_diff_sum_multyply', 'MD_outdoorTemp_diff_mean_MDH_outdoorHum_diff_mean_multyply', 'MDH_indoorHum_diff_sum_MDH_indoorAtmo_min_multyply', 'indoorAtmo_100_bin_outdoorAtmo_std', 'MD_outdoorHum_max_MDH_indoorAtmo_mean_subtract', 'MDH_indoorHum_diff_mean_MDH_indoorAtmo_diff_mean_multyply', 'outdoorHum_MD_indoorAtmo_max_subtract', 'MDH_outdoorAtmo_diff_sum_MDH_outdoorTemp_diff_sum_multyply', 'outdoorHum_diff_expanding_skew', 'indoorHum_50_bin_outdoorHum_min', 'MDH_indoorAtmo_min_MDH_indoorAtmo_diff_sum_ratio', 'MDH_outdoorTemp_diff_sum_MD_outdoorHum_diff_min_multyply', 'indoorHum_MDH_indoorHum_mean_multyply', 'indoorHum_20_bin_outdoorHum_std', 'MDH_outdoorTemp_sum_MD_outdoorAtmo_diff_mean_ratio', 'outdoorTemp_MDH_outdoorHum_diff_sum_ratio', 'MDH_indoorAtmo_diff_sum_MDH_indoorHum_diff_max_multyply', 'MD_outdoorHum_diff_sum_MDH_outdoorHum_diff_min_multyply', 'outdoorTemp_MDH_indoorAtmo_diff_sum_multyply', 'MDH_outdoorHum_diff_sum_MDH_indoorAtmo_diff_sum_multyply', 'indoorHum_100_bin_outdoorHum_sum', 'MDH_indoorHum_max_MD_outdoorHum_medi_multyply', 'outdoorHum_MDH_outdoorAtmo_min_ratio', 'MDH_outdoorAtmo_mean_MDH_outdoorHum_diff_sum_add', 'MDH_outdoorHum_diff_sum_MDH_indoorHum_diff_sum_subtract', 'MD_indoorHum_max_MDH_outdoorHum_diff_max_add', 'MD_indoorHum_min_indoorAtmo_multyply', 'MD_outdoorHum_min_MDH_outdoorAtmo_diff_sum_multyply', 'outdoorHum_3D_rolling_min', 'MDH_indoorHum_diff_sum', 'MDH_outdoorTemp_diff_mean_MD_outdoorTemp_diff_mean_multyply', 'MD_outdoorTemp_mean_MD_outdoorAtmo_mean_add', 'outdoorHum_MDH_indoorAtmo_mean_subtract', 'outdoorTemp_MDH_indoorHum_diff_sum_multyply', 'outdoorTemp_MD_outdoorAtmo_medi_add', 'indoorHum_MDH_indoorHum_medi_subtract', 'MD_outdoorHum_medi_MDH_outdoorAtmo_mean_subtract', 'MDH_outdoorHum_diff_sum_MDH_indoorAtmo_diff_sum_ratio', 'MDH_outdoorAtmo_diff_mean_MDH_outdoorTemp_diff_mean_multyply', 'outdoorTemp_diff_MDH_outdoorHum_diff_min_multyply', 'MD_outdoorHum_medi_indoorHum_multyply', 'indoorHum_20_bin_outdoorAtmo_max', 'outdoorTemp_diff_MDH_indoorHum_diff_min_multyply', 'outdoorTemp_diff_MDH_outdoorHum_diff_max_ratio', 'MD_outdoorTemp_diff_sum_MDH_outdoorAtmo_diff_sum_ratio', 'indoorHum_50_bin_outdoorTemp_max', 'MDH_outdoorAtmo_mean_MD_outdoorTemp_diff_sum_add', 'outdoorTemp_200_bin_outdoorAtmo_std', 'outdoorHum_20_bin_outdoorAtmo_std', 'outdoorTemp_50_bin_outdoorAtmo_std', 'MDH_outdoorTemp_diff_sum_MD_outdoorAtmo_min_multyply', 'indoorHum_MDH_outdoorHum_min_subtract', 'outdoorHum_MDH_outdoorAtmo_diff_sum_ratio', 'MDH_indoorAtmo_min_MDH_outdoorHum_diff_sum_multyply', 'MDH_indoorHum_diff_max_MDH_indoorHum_diff_sum_subtract', 'MD_outdoorAtmo_diff_sum_MDH_indoorHum_diff_max_add', 'MDH_outdoorAtmo_max_MD_outdoorHum_medi_multyply', 'outdoorHum_MDH_indoorHum_diff_sum_multyply', 'outdoorHum_MDH_indoorAtmo_diff_sum_multyply', 'MDH_outdoorTemp_diff_sum_MDH_indoorAtmo_min_multyply', 'MDH_outdoorTemp_sum_MD_outdoorAtmo_sum_multyply', 'MDH_indoorAtmo_diff_mean_MDH_outdoorAtmo_diff_mean_multyply', 'indoorHum_20_bin_indoorAtmo_skew', 'MDH_outdoorAtmo_diff_sum', 'MDH_outdoorAtmo_mean_MD_outdoorAtmo_mean_multyply', 'MD_outdoorAtmo_diff_sum_MDH_outdoorHum_diff_sum_multyply', 'MD_outdoorAtmo_diff_sum_MDH_indoorAtmo_diff_sum_multyply', 'MDH_outdoorAtmo_medi_MD_indoorHum_medi_subtract', 'MDH_outdoorAtmo_medi_MD_outdoorAtmo_mean_multyply', 'MDH_indoorHum_diff_max_MDH_indoorAtmo_diff_sum_ratio', 'MD_outdoorHum_diff_max_MDH_indoorHum_diff_sum_ratio', 'MDH_outdoorTemp_diff_medi_MD_outdoorTemp_diff_max_multyply', 'MDH_outdoorTemp_diff_mean_MDH_indoorHum_diff_mean_multyply', 'MD_outdoorHum_diff_mean_MDH_outdoorTemp_diff_mean_multyply', 'outdoorTemp_diff_MD_outdoorTemp_ ...

# %%
x_train.drop(to_drop, axis=1, inplace=True)
x_test.drop(to_drop, axis=1, inplace=True)

# %%
train_all_matrix = xgb.DMatrix(x_train, y_train, missing=np.nan)
test_matrix = xgb.DMatrix(x_test, label=val_y, missing=np.nan)

model = xgb.train(params,
                  train_all_matrix,
                  num_boost_round=model_eval.best_ntree_limit + 20)

test_pred = model.predict(test_matrix, ntree_limit=model.best_ntree_limit).reshape(-1, 1)

# %%
sub['temperature'] = test_pred[:, 0] + test_df['outdoorTemp'].values
sub.to_csv('../sub/sub_{}_{}.csv'.format(time.strftime('%Y%m%d'), str(mse)[2:7]), index=False)
