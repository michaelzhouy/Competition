# %%
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import lightgbm as lgb
import gc
import warnings
from tqdm import tqdm
from sklearn.metrics import f1_score, roc_auc_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold, KFold
from itertools import product
from sklearn.preprocessing import LabelEncoder
from scipy import stats
from feature_selector import FeatureSelector

warnings.filterwarnings('ignore')

pd.set_option('display.unicode.ambiguous_as_wide', True)
pd.set_option('display.unicode.east_asian_width', True)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option("display.max_colwidth", 100)
pd.set_option('display.width', 1000)

# %%
# 节省内存读文件
def reduce_mem_usage(df):
    """
    iterate through all the columns of a dataframe and modify the data type to reduce memory usage.
    @param df:
    @return:
    """
    start_mem = df.memory_usage().sum()
    print('Memory usage of dataframe is {:.2f} MB'.format(start_mem))

    for col in df.columns:
        col_type = df[col].dtype

        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        else:
            df[col] = df[col].astype('str')

    end_mem = df.memory_usage().sum()
    print('Memory usage after optimization is: {:.2f} MB'.format(end_mem))
    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))
    return df

# %%
def count_encode(df, cols):
    for col in tqdm(cols):
        print(col)
        vc = df[col].value_counts(dropna=True, normalize=True)
        df[col + '_count'] = df[col].map(vc).astype('float32')
    return df
        
        
def label_encode(df, cols):
    le = LabelEncoder()
    for col in tqdm(cols):
        df[col] = df[col].fillna('NA')
        df[col] = le.fit_transform(df[col].astype(str))
    return df


def cross_cat_num(df, cat_col, num_col):
    for f1 in tqdm(cat_col):
        g = df.groupby(f1, as_index=False)
        for f2 in tqdm(num_col):
            df_new = g[f2].agg({
                '{}_{}_max'.format(f1, f2): 'max',
                '{}_{}_min'.format(f1, f2): 'min',
                '{}_{}_median'.format(f1, f2): 'median',
                '{}_{}_mean'.format(f1, f2): 'mean',
                '{}_{}_skew'.format(f1, f2): 'skew',
                '{}_{}_nunique'.format(f1, f2): 'nunique'
            })
            df = df.merge(df_new, on=f1, how='left')
            del df_new
            gc.collect()
    return df

# %% [markdown]
# ## user表

# %%
train_user = pd.read_hdf('../input/train_user.h5')
test_user = pd.read_hdf('../input/test_user.h5')

# %%
# 将city_name和county_name拼接起来
train_user['city_name_county_name'] = train_user['city_name'].astype(str) + '_' + train_user['county_name'].astype(str)
test_user['city_name_county_name'] = test_user['city_name'].astype(str) + '_' + test_user['county_name'].astype(str)

# %%
cat_feat = ['city_name', 'county_name', 'city_name_county_name']
num_feat = ['idcard_cnt', 'arpu_202004', 'idcard_cnt*arpu_202004', 'arpu_202004/idcard_cnt']

# %%
# y = train_user['label']

# %%
# ME = MeanEncoder(categorical_features=cat_feat,
#                  n_splits=3,
#                  target_type='classification',
#                  prior_weight_func=None)
# X_data = ME.fit_transform(train_user.drop('label', axis=1), y)
# X_test = ME.transform(test_user)

# %%
# train_user = X_data.copy()
# train_user['label'] = y
# test_user = X_test.copy()

# train_user.shape, test_user.shape

# %%
df_user = pd.concat([train_user, test_user])

del train_user, test_user
gc.collect()
# Out:
# 0

# %%
# 电话的数量*月消费额
df_user['idcard_cnt*arpu_202004'] = df_user['idcard_cnt'] * df_user['arpu_202004']

# 月消费额/电话的数量
df_user['arpu_202004/idcard_cnt'] = df_user['arpu_202004'] / (df_user['idcard_cnt'] + 0.0001)

# %%
df_user = cross_cat_num(df_user, cat_feat, num_feat)
# Out:
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/4 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 22.53it/s]
#  33%|████████████████████████████                                                        | 1/3 [00:00<00:00,  5.51it/s]
#   0%|                                                                                            | 0/4 [00:00<?, ?it/s]
#  50%|██████████████████████████████████████████                                          | 2/4 [00:00<00:00, 13.45it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 13.55it/s]
#  67%|████████████████████████████████████████████████████████                            | 2/3 [00:00<00:00,  4.61it/s]
#   0%|                                                                                            | 0/4 [00:00<?, ?it/s]
#  50%|██████████████████████████████████████████                                          | 2/4 [00:00<00:00, 13.37it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 13.75it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00,  3.85it/s]

# %%
df_user = count_encode(df_user, cat_feat + ['idcard_cnt'])
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 334.23it/s]
# city_name
# county_name
# city_name_county_name
# idcard_cnt

# %%
df_user = label_encode(df_user, cat_feat)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 334.28it/s]

# %%
df_user.to_hdf('../input/user_features.h5', 'df', index=False)

del df_user
gc.collect()
# Out:
# 77

# %% [markdown]
# ## voc表

# %%
train_voc = pd.read_hdf('../input/train_voc.h5')
test_voc = pd.read_hdf('../input/test_voc.h5')

# %%
df_voc = pd.concat([train_voc, test_voc])

del train_voc, test_voc
gc.collect()
# Out:
# 128

# %%
df_voc['city_name_county_name'] = df_voc['city_name'] + '_' + df_voc['county_name']

# %%
df_voc['voc_day'] = df_voc['start_datetime'].astype('datetime64').dt.day
df_voc['voc_hour'] = df_voc['start_datetime'].astype('datetime64').dt.hour
# df_voc['voc_dayofweek'] = df_voc['start_datetime'].astype('datetime64').dt.dayofweek

# %%
phone_no_m = df_voc[['phone_no_m']].copy()
phone_no_m = phone_no_m.drop_duplicates(subset=['phone_no_m'], keep='last')

# %%
# 通话次数，通话人数
tmp = df_voc.groupby('phone_no_m')['opposite_no_m'].agg(opposite_cnt='count', opposite_nunique='nunique')
phone_no_m = phone_no_m.merge(tmp, how='left', on='phone_no_m')

# 人均通话次数
phone_no_m['voc_cnt_per_capita'] = phone_no_m['opposite_cnt'] / (phone_no_m['opposite_nunique'] + 0.0001)

del tmp
gc.collect()
# Out:
# 0

# %%
"""
主叫通话
"""

df_calltype_id_1 = df_voc.loc[df_voc['calltype_id'] == 1, :].copy()

# 主叫通话次数，主叫通话使用的手机个数
tmp = df_calltype_id_1.groupby('phone_no_m')['imei_m'].agg(voc_calltype_id_1_cnt='count', imeis='nunique')
phone_no_m = phone_no_m.merge(tmp, on='phone_no_m', how='left')
del tmp
gc.collect()

# 主叫通话时长
tmp = df_calltype_id_1.groupby('phone_no_m')['call_dur'].agg(voc_calltype_id_1_call_dur_sum='sum')
phone_no_m = phone_no_m.merge(tmp, on='phone_no_m', how='left')
del tmp
gc.collect()

# 主叫通话时长小于30s的次数
tmp1 = df_calltype_id_1[df_calltype_id_1['call_dur'] < 30]
tmp2 = tmp1.groupby('phone_no_m')['call_dur'].agg(voc_calltype_id_1_30s_cnt='count')
phone_no_m = phone_no_m.merge(tmp2, on='phone_no_m', how='left')
del tmp1, tmp2
gc.collect()

# 主叫通话时长小于60s的次数
tmp1 = df_calltype_id_1[df_calltype_id_1['call_dur'] < 60]
tmp2 = tmp1.groupby('phone_no_m')['call_dur'].agg(voc_calltype_id_1_60s_cnt='count')
phone_no_m = phone_no_m.merge(tmp2, on='phone_no_m', how='left')
del tmp1, tmp2
gc.collect()

# 主叫通话时长大于300s（5分钟）的次数
tmp1 = df_calltype_id_1[df_calltype_id_1['call_dur'] > 300]
tmp2 = tmp1.groupby('phone_no_m')['call_dur'].agg(voc_calltype_id_1_300s_cnt='count')
phone_no_m = phone_no_m.merge(tmp2, on='phone_no_m', how='left')
del tmp1, tmp2
gc.collect()

# 主叫通话时长小于30s的次数的占比
phone_no_m['voc_calltype_id_1_30s_rate'] = phone_no_m['voc_calltype_id_1_30s_cnt'] / phone_no_m['voc_calltype_id_1_cnt']

# 主叫通话时长小于60s的次数的占比
phone_no_m['voc_calltype_id_1_60s_rate'] = phone_no_m['voc_calltype_id_1_60s_cnt'] / phone_no_m['voc_calltype_id_1_cnt']

# 主叫通话时长大于300s（5分钟）的次数的占比
phone_no_m['voc_calltype_id_1_300s_rate'] = phone_no_m['voc_calltype_id_1_300s_cnt'] / phone_no_m['voc_calltype_id_1_cnt']


# 主叫通话次数的占比
phone_no_m["call_type_id_1_rate"] = phone_no_m['voc_calltype_id_1_cnt'] / phone_no_m['opposite_cnt']

# 主叫通话时所在地市变动的个数
tmp = df_calltype_id_1.groupby('phone_no_m')['city_name'].agg(city_name_nunique='nunique')
phone_no_m = phone_no_m.merge(tmp, on='phone_no_m', how='left')
del tmp
gc.collect()

# 主叫通话时所在区县变动的个数
tmp = df_calltype_id_1.groupby("phone_no_m")['county_name'].agg(county_name_nunique='nunique')
phone_no_m = phone_no_m.merge(tmp, on="phone_no_m", how="left")
del tmp
gc.collect()

# 主叫通话时所在地市_区县变动的个数
tmp = df_calltype_id_1.groupby("phone_no_m")['city_name_county_name'].agg(city_name_county_name_nunique='nunique')
phone_no_m = phone_no_m.merge(tmp, on="phone_no_m", how="left")
del tmp
gc.collect()
# Out:
# 0

# %%
"""
被叫通话
"""

df_calltype_id_2 = df_voc.loc[df_voc['calltype_id'] == 2, :].copy()

# 被叫通话的次数
tmp = df_calltype_id_2.groupby('phone_no_m')['imei_m'].agg(voc_calltype_id_2_cnt='count')
phone_no_m = phone_no_m.merge(tmp, on='phone_no_m', how='left')

# 被叫通话次数的占比
phone_no_m["call_type_id_2_rate"] = phone_no_m['voc_calltype_id_2_cnt'] / phone_no_m['opposite_cnt']

del tmp, df_calltype_id_2
gc.collect()
# Out:
# 20

# %%
"""
呼叫转移
"""

df_calltype_id_3 = df_voc.loc[df_voc['calltype_id'] == 3, :].copy()

# 呼叫转移的次数
tmp = df_calltype_id_3.groupby('phone_no_m')['imei_m'].agg(voc_calltype_id_3_cnt='count')
phone_no_m = phone_no_m.merge(tmp, on='phone_no_m', how='left')

# 呼叫转移次数的占比
phone_no_m["call_type_id_3_rate"] = phone_no_m['voc_calltype_id_3_cnt'] / phone_no_m['opposite_cnt']

del tmp, df_calltype_id_3
gc.collect()
# Out:
# 20

# %%
"""
与对端通话统计
"""

# 与对端通话次数，与对端通话时长
tmp = df_voc.groupby(['phone_no_m', 'opposite_no_m'])['call_dur'].agg(call_count='count',
                                                                      call_sum='sum')

# 与对端通话次数的统计量
phone2opposite = tmp.groupby('phone_no_m')['call_count'].agg(phone2opposite_cnt_mean='mean',
                                                             phone2opposite_cnt_median='median',
                                                             phone2opposite_cnt_min='min',
                                                             phone2opposite_cnt_max='max',
                                                             phone2opposite_cnt_std='std')
phone_no_m = phone_no_m.merge(phone2opposite, on='phone_no_m', how='left')
del phone2opposite
gc.collect()


# 与对端总通话时长的统计量
phone2opposite = tmp.groupby('phone_no_m')['call_sum'].agg(phone2opposite_call_dur_mean='mean',
                                                           phone2opposite_call_dur_median='median',
                                                           phone2opposite_call_dur_min='min',
                                                           phone2opposite_call_dur_max='max',
                                                           phone2opposite_call_dur_std='std')
phone_no_m = phone_no_m.merge(phone2opposite, on='phone_no_m', how='left')
del phone2opposite, tmp
gc.collect()
# Out:
# 0

# %%
"""
通话时长的统计
"""

# 通话时长的统计量
tmp = df_voc.groupby('phone_no_m')['call_dur'].agg(call_dur_mean='mean',
                                                   call_dur_median='median',
                                                   call_dur_max='max',
                                                   call_dur_min='min',
                                                   call_dur_std='std',
                                                   call_dur_sum='sum')
phone_no_m = phone_no_m.merge(tmp, on='phone_no_m', how='left')
del tmp
gc.collect()
# Out:
# 0

# %%
"""
收费号码位置变动
"""

# 收费号码所在地市的个数
tmp = df_voc.groupby('phone_no_m')['city_name'].agg(city_name_nunique='nunique')
phone_no_m = phone_no_m.merge(tmp, on='phone_no_m', how='left')

# 收费号码所在区县的个数
tmp = df_voc.groupby('phone_no_m')['county_name'].agg(county_name_nunique='nunique')
phone_no_m = phone_no_m.merge(tmp, on="phone_no_m", how='left')

# 收费号码所在地市_区县的个数
tmp = df_voc.groupby('phone_no_m')['city_name_county_name'].agg(city_name_county_name_nunique='nunique')
phone_no_m = phone_no_m.merge(tmp, on="phone_no_m", how='left')

# 收费号码通话类型的个数
tmp = df_voc.groupby('phone_no_m')['calltype_id'].agg(calltype_id_unique='nunique')
phone_no_m = phone_no_m.merge(tmp, on='phone_no_m', how='left')

del tmp
gc.collect()
# Out:
# 0

# %%
"""
通话时间点的偏好
"""

# hour通话次数最高
tmp = df_voc.groupby('phone_no_m')['voc_hour'].agg(voc_hour_mode=lambda x: stats.mode(x)[0][0],        # 频次最高的元素
                                                   voc_hour_mode_count=lambda x: stats.mode(x)[1][0],  # 频次最高的元素的频次
                                                   voc_hour_nunique='nunique')
phone_no_m = phone_no_m.merge(tmp, on='phone_no_m', how='left')

# day通话次数最高
tmp = df_voc.groupby('phone_no_m')['voc_day'].agg(voc_day_mode=lambda x: stats.mode(x)[0][0],
                                                  voc_day_mode_count=lambda x: stats.mode(x)[1][0],
                                                  voc_day_nunique='nunique')
phone_no_m = phone_no_m.merge(tmp, on='phone_no_m', how='left')

del tmp
gc.collect()
# Out:
# 0

# %%
# 每天的通话次数
voc_day_cnt_res = df_voc.groupby(['phone_no_m', 'voc_day'])['phone_no_m'].count().unstack()
for i in df_voc['voc_day'].unique():
    phone_no_m['voc_day{}_count'.format(i)] = phone_no_m['phone_no_m'].map(voc_day_cnt_res[i])

    
# 每天的通话人数
voc_day_nunique_res = df_voc.groupby(['phone_no_m', 'voc_day'])['opposite_no_m'].nunique().unstack()
for i in df_voc['voc_day'].unique():
    phone_no_m['voc_day{}_nunique'.format(i)] = phone_no_m['phone_no_m'].map(voc_day_nunique_res[i])

    
# 每天的通话时长
voc_day_call_dur_res = df_voc.groupby(['phone_no_m', 'voc_day'])['call_dur'].sum().unstack()
for i in df_voc['voc_day'].unique():
    phone_no_m['voc_day{}_call_dur_sum'.format(i)] = phone_no_m['phone_no_m'].map(voc_day_call_dur_res[i])



# 每小时的通话次数
voc_hour_cnt_res = df_voc.groupby(['phone_no_m', 'voc_hour'])['phone_no_m'].count().unstack()
for i in df_voc['voc_hour'].unique():
    phone_no_m['voc_hour{}_count'.format(i)] = phone_no_m['phone_no_m'].map(voc_hour_cnt_res[i])
    
# 每小时的通话人数
voc_hour_nunique_res = df_voc.groupby(['phone_no_m', 'voc_hour'])['opposite_no_m'].nunique().unstack()
for i in df_voc['voc_hour'].unique():
    phone_no_m['voc_hour{}_nunique'.format(i)] = phone_no_m['phone_no_m'].map(voc_hour_nunique_res[i])
    

# 每小时的通话时长
voc_hour_call_dur_res = df_voc.groupby(['phone_no_m', 'voc_hour'])['call_dur'].sum().unstack()
for i in df_voc['voc_hour'].unique():
    phone_no_m['voc_hour{}_call_dur_sum'.format(i)] = phone_no_m['phone_no_m'].map(voc_hour_call_dur_res[i])

# %%
phone_no_m.to_hdf('../input/voc_features.h5', 'df', index=False)
del phone_no_m
gc.collect()
# Out:
# 75

# %% [markdown]
# ## sms表

# %%
train_sms = pd.read_hdf('../input/train_sms.h5')
test_sms = pd.read_hdf('../input/test_sms.h5')

# %%
df_sms = pd.concat([train_sms, test_sms])

del train_sms, test_sms
gc.collect()
# Out:
# 106

# %%
df_sms['sms_day'] = df_sms['request_datetime'].astype('datetime64').dt.day
df_sms['sms_hour'] = df_sms['request_datetime'].astype('datetime64').dt.hour
# df_sms['sms_dayofweek'] = df_sms['request_datetime'].astype('datetime64').dt.dayofweek

# %%
phone_no_m = df_sms[["phone_no_m"]].copy()
phone_no_m = phone_no_m.drop_duplicates(subset=['phone_no_m'], keep='last')

# %%
# 短信次数，短信人数
tmp = df_sms.groupby('phone_no_m')['opposite_no_m'].agg(sms_cnt='count', sms_nunique='nunique')

# 人均短信次数
tmp['sms_cnt_per_capita'] = tmp['sms_cnt'] / (tmp['sms_nunique'] + 0.0001)
phone_no_m = phone_no_m.merge(tmp, on='phone_no_m', how='left')

del tmp
gc.collect()
# Out:
# 0

# %%
"""
短信上行，短信下行
"""

# 短信上行
df_sms_calltype1 = df_sms[df_sms['calltype_id'] == 1].copy()
tmp = df_sms_calltype1.groupby('phone_no_m')['calltype_id'].agg(sms_calltype1_cnt="count")
phone_no_m = phone_no_m.merge(tmp, on='phone_no_m', how='left')

# 短信上行比例
phone_no_m['sms_calltype1_rate'] = phone_no_m['sms_calltype1_cnt'] / phone_no_m['sms_cnt']

del tmp, df_sms_calltype1

# 短信下行
df_sms_calltype2 = df_sms[df_sms['calltype_id'] == 2].copy()
tmp = df_sms_calltype2.groupby('phone_no_m')['calltype_id'].agg(sms_calltype2_cnt="count")
phone_no_m = phone_no_m.merge(tmp, on='phone_no_m', how='left')

# 短信上行/短信下行
phone_no_m['type1_rate/type2_rate'] = phone_no_m['sms_calltype1_cnt'] / (phone_no_m['sms_calltype2_cnt'] + 0.00001)

# 删除，效果变差
# # 短信下行/短信上行
# phone_no_m['type2_rate/type1_rate'] = phone_no_m['sms_calltype2_cnt'] / (phone_no_m['sms_calltype1_cnt'] + 0.00001)

del tmp, df_sms_calltype2
gc.collect()
# Out:
# 0

# %%
"""
短信时间点的偏好
"""

tmp = df_sms.groupby('phone_no_m')['sms_hour'].agg(sms_hour_mode=lambda x: stats.mode(x)[0][0],        # 频次最高的元素
                                                   sms_hour_mode_count=lambda x: stats.mode(x)[1][0],  # 频次最高的元素的频次
                                                   sms_hour_nunique='nunique')
phone_no_m = phone_no_m.merge(tmp, on='phone_no_m', how='left')

del tmp

tmp = df_sms.groupby('phone_no_m')['sms_day'].agg(sms_day_mode=lambda x: stats.mode(x)[0][0],
                                                  sms_day_mode_count=lambda x: stats.mode(x)[1][0],
                                                  sms_day_nunique='nunique')
phone_no_m = phone_no_m.merge(tmp, on='phone_no_m', how='left')

del tmp
gc.collect()
# Out:
# 0

# %%
# 每天的短信次数
sms_day_res = df_sms.groupby(['phone_no_m', 'sms_day'])['phone_no_m'].count().unstack()
for i in df_sms['sms_day'].unique():
    phone_no_m['sms_day{}_count'.format(i)] = phone_no_m['phone_no_m'].map(sms_day_res[i])


# 每小时的短信次数
sms_hour_res = df_sms.groupby(['phone_no_m', 'sms_hour'])['phone_no_m'].count().unstack()
for i in df_sms['sms_hour'].unique():
    phone_no_m['sms_hour{}_count'.format(i)] = phone_no_m['phone_no_m'].map(sms_hour_res[i])

# %%
phone_no_m.to_hdf('../input/sms_features.h5', 'df', index=False)

del phone_no_m
gc.collect()
# Out:
# 64

# %% [markdown]
# ## app表

# %%
train_app = pd.read_hdf('../input/train_app.h5')
test_app = pd.read_hdf('../input/test_app.h5')

# %%
df_app = pd.concat([train_app, test_app])

del train_app, test_app
gc.collect()
# Out:
# 117

# %%
phone_no_m = df_app[['phone_no_m']].copy()
phone_no_m = phone_no_m.drop_duplicates(subset=['phone_no_m'], keep='last')

# %%
# APP数
tmp = df_app.groupby('phone_no_m')['busi_name'].agg(busi_cnt='count')
phone_no_m = phone_no_m.merge(tmp, on='phone_no_m', how='left')
del tmp
gc.collect()
# Out:
# 40

# %%
"""
流量统计
"""
tmp = df_app.groupby("phone_no_m")["flow"].agg(flow_mean='mean',
                                               flow_median='median',
                                               flow_min='min',
                                               flow_max='max',
                                               flow_std='std',
                                               flow_sum='sum',
                                               flow_skew='skew')
phone_no_m = phone_no_m.merge(tmp, on='phone_no_m', how='left')

del tmp
gc.collect()
# Out:
# 20

# %%
phone_no_m.to_hdf('../input/app_features.h5', 'df', index=False)

del phone_no_m
gc.collect()
# Out:
# 75

# %% [markdown]
# ## 读取数据，建模

# %%
df_user = reduce_mem_usage(pd.read_hdf('../input/user_features.h5'))
df_voc = reduce_mem_usage(pd.read_hdf('../input/voc_features.h5'))
df_sms = reduce_mem_usage(pd.read_hdf('../input/sms_features.h5'))
# df_app = reduce_mem_usage(pd.read_hdf('../input/app_features.h5'))
# Out:
# Memory usage of dataframe is 3445536.00 MB
# Memory usage after optimization is: 1692544.00 MB
# Decreased by 50.9%
# Memory usage of dataframe is 10456560.00 MB
# Memory usage after optimization is: 2756280.00 MB
# Decreased by 73.6%
# Memory usage of dataframe is 3505040.00 MB
# Memory usage after optimization is: 926332.00 MB
# Decreased by 73.6%

# %%
df_user.shape, df_voc.shape, df_sms.shape #, df_app.shape
# Out:
# ((7556, 86), (6180, 212), (6259, 69))

# %%
df = df_user.merge(df_voc, on='phone_no_m', how='left')
df = df.merge(df_sms, on='phone_no_m', how='left')
# df = df.merge(df_app, on='phone_no_m', how='left')

del df_user, df_voc, df_sms#, df_app
gc.collect()
# Out:
# 0

# %%
df.shape
# Out:
# (7556, 365)

# %%
# astype('category')会掉分，不做此处理
# for i in tqdm(cat_feat):
#     print(i)
#     df[i] = df[i].astype('category')

# %%
df_train = df[df.label.notna()]
df_test = df[df.label.isna()]

df_train.shape, df_test.shape
# Out:
# ((6106, 365), (1450, 365))

# %% [markdown]
# ## 特征筛选

# %% [markdown]
# ### 缺失值

# %%
fs = FeatureSelector(data=df_train.drop(['phone_no_m', 'label'], axis=1), labels=df_train['label'])

# %%
fs.identify_missing(missing_threshold=0.98)
missing_features = fs.ops['missing']
print(missing_features)
# Out:
# 6 features with greater than 0.98 missing values.
#
# ['city_name_arpu_202004_skew', 'city_name_idcard_cnt*arpu_202004_skew', 'county_name_idcard_cnt*arpu_202004_skew', 'city_name_county_name_idcard_cnt*arpu_202004_skew', 'voc_calltype_id_3_cnt', 'call_type_id_3_rate']

# %%
fs.missing_stats.head(20)
# Out:
#                                                    missing_fraction
# city_name_arpu_202004_skew                                 1.000000
# city_name_idcard_cnt*arpu_202004_skew                      1.000000
# city_name_county_name_idcard_cnt*arpu_202004_skew          0.989027
# county_name_idcard_cnt*arpu_202004_skew                    0.989027
# voc_calltype_id_3_cnt                                      0.982312
# call_type_id_3_rate                                        0.982312
# voc_hour3_count                                            0.969211
# voc_hour3_call_dur_sum                                     0.969211
# voc_hour3_nunique                                          0.969211
# voc_hour4_call_dur_sum                                     0.966099
# voc_hour4_count                                            0.966099
# voc_hour4_nunique                                          0.966099
# voc_hour2_nunique                                          0.959548
# voc_hour2_count                                            0.959548
# voc_hour2_call_dur_sum                                     0.959548
# sms_hour4_count                                            0.947756
# voc_hour5_count                                            0.945300
# voc_hour5_call_dur_sum                                     0.945300
# voc_hour5_nunique                                          0.945300
# voc_hour1_count                                            0.938094

# %%
df_train.drop(missing_features, axis=1, inplace=True)
df_test.drop(missing_features, axis=1, inplace=True)

# %% [markdown]
# ### 唯一值

# %%
fs.identify_single_unique()
# Out:
# 1 features with a single unique value.

# %%
single_unique = fs.ops['single_unique']
print(single_unique)
# Out:
# ['arpu_202005']

# %%
df_train.drop(single_unique, axis=1, inplace=True)
df_test.drop(single_unique, axis=1, inplace=True)

# %% [markdown]
# ### 单特征AUC

# %%
X_train, X_valid, y_train, y_valid = train_test_split(df_train.drop(['phone_no_m', 'label'], axis=1), df_train['label'],
                                                      test_size=0.2,
                                                      random_state=2020)

# %%
params = {'objective': 'binary',
          'boosting': 'gbdt',
          'metric': 'auc',
          'learning_rate': 0.1,
          'num_leaves': 31,
          'lambda_l1': 0.1,
          'lambda_l2': 0,
          'min_data_in_leaf': 20,
          'is_unbalance': True,
          'max_depth': -1,
          'seed': 2020}

# %%
train_cols = [i for i in df_train.columns if i not in ['phone_no_m', 'label']]

# %%
useful_cols = {}
useless_cols = {}

for i in train_cols:
    print(i)
    
    lgb_train = lgb.Dataset(X_train[[i]].values, y_train) 
    lgb_valid= lgb.Dataset(X_valid[[i]].values, y_valid, reference=lgb_train)
    lgb_test = lgb.train(params,
                         lgb_train,
                         num_boost_round=1000,
                         valid_sets=[lgb_valid, lgb_train],
                         early_stopping_rounds=50,
                         verbose_eval=20)
    
    print('*' * 5)
    print(lgb_test.best_score['valid_0']['auc'])
    if lgb_test.best_score['valid_0']['auc'] > 0.52:
        useful_cols[i] = lgb_test.best_score['valid_0']['auc']
    else:
        useless_cols[i] = lgb_test.best_score['valid_0']['auc']
    print('*' * 20)
    print('\n')
# Out:
# city_name
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.684155	valid_0's auc: 0.671655
# [40]	training's auc: 0.684156	valid_0's auc: 0.672408
# [60]	training's auc: 0.684156	valid_0's auc: 0.672408
# [80]	training's auc: 0.684158	valid_0's auc: 0.671655
# Early stopping, best iteration is:
# [37]	training's auc: 0.684156	valid_0's auc: 0.672408
# *****
# 0.6724078657865786
# ********************
#
#
# county_name
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.767358	valid_0's auc: 0.72344
# [40]	training's auc: 0.772283	valid_0's auc: 0.728765
# [60]	training's auc: 0.77374	valid_0's auc: 0.730307
# [80]	training's auc: 0.774604	valid_0's auc: 0.730896
# [100]	training's auc: 0.775263	valid_0's auc: 0.73182
# [120]	training's auc: 0.775831	valid_0's auc: 0.731191
# [140]	training's auc: 0.776325	valid_0's auc: 0.732008
# Early stopping, best iteration is:
# [90]	training's auc: 0.775065	valid_0's auc: 0.732017
# *****
# 0.7320170875783231
# ********************
#
#
# idcard_cnt
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.728663	valid_0's auc: 0.723062
# [40]	training's auc: 0.728663	valid_0's auc: 0.723062
# Early stopping, best iteration is:
# [1]	training's auc: 0.728663	valid_0's auc: 0.723062
# *****
# 0.7230622518773616
# ********************
#
#
# arpu_202004
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.815215	valid_0's auc: 0.77144
# [40]	training's auc: 0.820254	valid_0's auc: 0.766022
# Early stopping, best iteration is:
# [1]	training's auc: 0.800048	valid_0's auc: 0.773108
# *****
# 0.7731082890897786
# ********************
#
#
# city_name_county_name
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.765288	valid_0's auc: 0.734962
# [40]	training's auc: 0.770757	valid_0's auc: 0.735027
# [60]	training's auc: 0.773065	valid_0's auc: 0.735202
# Early stopping, best iteration is:
# [19]	training's auc: 0.765089	valid_0's auc: 0.735829
# *****
# 0.7358286100349165
# ********************
#
#
# idcard_cnt*arpu_202004
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.835521	valid_0's auc: 0.810472
# [40]	training's auc: 0.83969	valid_0's auc: 0.808623
# Early stopping, best iteration is:
# [5]	training's auc: 0.82961	valid_0's auc: 0.811889
# *****
# 0.8118886616922562
# ********************
#
#
# arpu_202004/idcard_cnt
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.815451	valid_0's auc: 0.761859
# [40]	training's auc: 0.822443	valid_0's auc: 0.763062
# Early stopping, best iteration is:
# [5]	training's auc: 0.802909	valid_0's auc: 0.766286
# *****
# 0.7662864112498207
# ********************
#
#
# city_name_idcard_cnt_max
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.615108	valid_0's auc: 0.635379
# [40]	training's auc: 0.615108	valid_0's auc: 0.635379
# Early stopping, best iteration is:
# [1]	training's auc: 0.615108	valid_0's auc: 0.635379
# *****
# 0.6353792987994452
# ********************
#
#
# city_name_idcard_cnt_min
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.585968	valid_0's auc: 0.574084
# [40]	training's auc: 0.585968	valid_0's auc: 0.574084
# Early stopping, best iteration is:
# [1]	training's auc: 0.585968	valid_0's auc: 0.574084
# *****
# 0.5740840388386664
# ********************
#
#
# city_name_idcard_cnt_median
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.542851	valid_0's auc: 0.538564
# [40]	training's auc: 0.542851	valid_0's auc: 0.538564
# Early stopping, best iteration is:
# [1]	training's auc: 0.542851	valid_0's auc: 0.538564
# *****
# 0.538563638972593
# ********************
#
#
# city_name_idcard_cnt_mean
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.68385	valid_0's auc: 0.672031
# [40]	training's auc: 0.683851	valid_0's auc: 0.671655
# [60]	training's auc: 0.683851	valid_0's auc: 0.671655
# Early stopping, best iteration is:
# [18]	training's auc: 0.68385	valid_0's auc: 0.672031
# *****
# 0.6720311976849859
# ********************
#
#
# city_name_idcard_cnt_skew
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.684159	valid_0's auc: 0.671451
# [40]	training's auc: 0.68417	valid_0's auc: 0.671655
# Early stopping, best iteration is:
# [6]	training's auc: 0.684056	valid_0's auc: 0.672339
# *****
# 0.6723391089108911
# ********************
#
#
# city_name_idcard_cnt_nunique
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.643669	valid_0's auc: 0.649836
# [40]	training's auc: 0.643669	valid_0's auc: 0.649836
# Early stopping, best iteration is:
# [1]	training's auc: 0.643669	valid_0's auc: 0.649836
# *****
# 0.649836179270101
# ********************
#
#
# city_name_arpu_202004_max
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.684056	valid_0's auc: 0.671601
# [40]	training's auc: 0.684058	valid_0's auc: 0.671655
# [60]	training's auc: 0.684058	valid_0's auc: 0.671655
# [80]	training's auc: 0.684058	valid_0's auc: 0.671655
# Early stopping, best iteration is:
# [36]	training's auc: 0.684058	valid_0's auc: 0.671655
# *****
# 0.6716545295833931
# ********************
#
#
# city_name_arpu_202004_min
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.524843	valid_0's auc: 0.524507
# [40]	training's auc: 0.524843	valid_0's auc: 0.524507
# Early stopping, best iteration is:
# [1]	training's auc: 0.524843	valid_0's auc: 0.524507
# *****
# 0.5245073420385516
# ********************
#
#
# city_name_arpu_202004_median
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.684118	valid_0's auc: 0.671655
# [40]	training's auc: 0.684125	valid_0's auc: 0.671655
# [60]	training's auc: 0.684122	valid_0's auc: 0.672408
# [80]	training's auc: 0.684122	valid_0's auc: 0.672408
# Early stopping, best iteration is:
# [48]	training's auc: 0.684122	valid_0's auc: 0.672408
# *****
# 0.6724078657865786
# ********************
#
#
# city_name_arpu_202004_mean
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.684157	valid_0's auc: 0.671465
# [40]	training's auc: 0.68417	valid_0's auc: 0.671655
# Early stopping, best iteration is:
# [1]	training's auc: 0.684026	valid_0's auc: 0.671909
# *****
# 0.6719086310804994
# ********************
#
#
# city_name_arpu_202004_nunique
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.682719	valid_0's auc: 0.66959
# [40]	training's auc: 0.682719	valid_0's auc: 0.66959
# Early stopping, best iteration is:
# [1]	training's auc: 0.682719	valid_0's auc: 0.66959
# *****
# 0.6695903285980772
# ********************
#
#
# city_name_idcard_cnt*arpu_202004_max
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.684058	valid_0's auc: 0.671655
# [40]	training's auc: 0.684058	valid_0's auc: 0.671655
# [60]	training's auc: 0.684058	valid_0's auc: 0.671655
# Early stopping, best iteration is:
# [11]	training's auc: 0.684058	valid_0's auc: 0.671655
# *****
# 0.6716545295833931
# ********************
#
#
# city_name_idcard_cnt*arpu_202004_min
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.545121	valid_0's auc: 0.52069
# [40]	training's auc: 0.545121	valid_0's auc: 0.52069
# Early stopping, best iteration is:
# [1]	training's auc: 0.545025	valid_0's auc: 0.520953
# *****
# 0.5209529105084422
# ********************
#
#
# city_name_idcard_cnt*arpu_202004_median
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.684168	valid_0's auc: 0.671668
# [40]	training's auc: 0.68417	valid_0's auc: 0.671655
# Early stopping, best iteration is:
# [1]	training's auc: 0.684163	valid_0's auc: 0.671668
# *****
# 0.6716679820155929
# ********************
#
#
# city_name_idcard_cnt*arpu_202004_mean
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.684146	valid_0's auc: 0.671655
# [40]	training's auc: 0.684146	valid_0's auc: 0.671655
# Early stopping, best iteration is:
# [1]	training's auc: 0.684146	valid_0's auc: 0.671655
# *****
# 0.6716545295833931
# ********************
#
#
# city_name_idcard_cnt*arpu_202004_nunique
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.683046	valid_0's auc: 0.669835
# [40]	training's auc: 0.683046	valid_0's auc: 0.669835
# Early stopping, best iteration is:
# [1]	training's auc: 0.683046	valid_0's auc: 0.669835
# *****
# 0.6698354618070502
# ********************
#
#
# city_name_arpu_202004/idcard_cnt_max
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.684116	valid_0's auc: 0.671947
# [40]	training's auc: 0.684125	valid_0's auc: 0.671655
# Early stopping, best iteration is:
# [1]	training's auc: 0.684108	valid_0's auc: 0.671947
# *****
# 0.6719474936624097
# ********************
#
#
# city_name_arpu_202004/idcard_cnt_min
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.571119	valid_0's auc: 0.549704
# [40]	training's auc: 0.571448	valid_0's auc: 0.543211
# Early stopping, best iteration is:
# [1]	training's auc: 0.571119	valid_0's auc: 0.549704
# *****
# 0.5497037475486679
# ********************
#
#
# city_name_arpu_202004/idcard_cnt_median
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.683719	valid_0's auc: 0.671399
# [40]	training's auc: 0.683719	valid_0's auc: 0.671399
# Early stopping, best iteration is:
# [1]	training's auc: 0.683719	valid_0's auc: 0.671399
# *****
# 0.6713989333715981
# ********************
#
#
# city_name_arpu_202004/idcard_cnt_mean
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.683493	valid_0's auc: 0.671001
# [40]	training's auc: 0.683497	valid_0's auc: 0.670828
# Early stopping, best iteration is:
# [1]	training's auc: 0.683401	valid_0's auc: 0.671001
# *****
# 0.6710013392643612
# ********************
#
#
# city_name_arpu_202004/idcard_cnt_skew
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.683809	valid_0's auc: 0.67295
# [40]	training's auc: 0.683818	valid_0's auc: 0.672764
# Early stopping, best iteration is:
# [1]	training's auc: 0.683809	valid_0's auc: 0.67295
# *****
# 0.672950447218635
# ********************
#
#
# city_name_arpu_202004/idcard_cnt_nunique
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.683591	valid_0's auc: 0.670732
# [40]	training's auc: 0.683591	valid_0's auc: 0.670732
# Early stopping, best iteration is:
# [1]	training's auc: 0.683591	valid_0's auc: 0.670732
# *****
# 0.6707322906203664
# ********************
#
#
# county_name_idcard_cnt_max
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.62448	valid_0's auc: 0.631506
# [40]	training's auc: 0.624482	valid_0's auc: 0.631542
# [60]	training's auc: 0.624482	valid_0's auc: 0.631542
# Early stopping, best iteration is:
# [26]	training's auc: 0.624482	valid_0's auc: 0.631542
# *****
# 0.6315423661931411
# ********************
#
#
# county_name_idcard_cnt_min
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.612673	valid_0's auc: 0.595793
# [40]	training's auc: 0.612673	valid_0's auc: 0.595793
# Early stopping, best iteration is:
# [1]	training's auc: 0.612673	valid_0's auc: 0.595793
# *****
# 0.5957932749796718
# ********************
#
#
# county_name_idcard_cnt_median
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.574299	valid_0's auc: 0.567609
# [40]	training's auc: 0.574723	valid_0's auc: 0.565202
# Early stopping, best iteration is:
# [1]	training's auc: 0.574299	valid_0's auc: 0.567609
# *****
# 0.5676089348065241
# ********************
#
#
# county_name_idcard_cnt_mean
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.761347	valid_0's auc: 0.724206
# [40]	training's auc: 0.764948	valid_0's auc: 0.726244
# [60]	training's auc: 0.76706	valid_0's auc: 0.72767
# [80]	training's auc: 0.768275	valid_0's auc: 0.728908
# [100]	training's auc: 0.769326	valid_0's auc: 0.728555
# [120]	training's auc: 0.769897	valid_0's auc: 0.728806
# [140]	training's auc: 0.770367	valid_0's auc: 0.728585
# [160]	training's auc: 0.77066	valid_0's auc: 0.728794
# Early stopping, best iteration is:
# [127]	training's auc: 0.770092	valid_0's auc: 0.729207
# *****
# 0.7292070239632659
# ********************
#
#
# county_name_idcard_cnt_skew
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.761966	valid_0's auc: 0.728893
# [40]	training's auc: 0.766633	valid_0's auc: 0.73244
# [60]	training's auc: 0.768493	valid_0's auc: 0.732752
# [80]	training's auc: 0.769663	valid_0's auc: 0.733165
# [100]	training's auc: 0.771072	valid_0's auc: 0.733606
# [120]	training's auc: 0.7721	valid_0's auc: 0.733404
# [140]	training's auc: 0.772639	valid_0's auc: 0.733494
# Early stopping, best iteration is:
# [95]	training's auc: 0.770771	valid_0's auc: 0.733954
# *****
# 0.7339542378150858
# ********************
#
#
# county_name_idcard_cnt_nunique
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.653195	valid_0's auc: 0.644757
# [40]	training's auc: 0.653195	valid_0's auc: 0.644757
# Early stopping, best iteration is:
# [1]	training's auc: 0.653195	valid_0's auc: 0.644757
# *****
# 0.644757138757354
# ********************
#
#
# county_name_arpu_202004_max
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.764106	valid_0's auc: 0.728685
# [40]	training's auc: 0.767523	valid_0's auc: 0.727783
# [60]	training's auc: 0.769599	valid_0's auc: 0.730912
# [80]	training's auc: 0.770146	valid_0's auc: 0.731322
# [100]	training's auc: 0.770579	valid_0's auc: 0.730796
# [120]	training's auc: 0.77096	valid_0's auc: 0.730425
# Early stopping, best iteration is:
# [89]	training's auc: 0.770288	valid_0's auc: 0.731639
# *****
# 0.7316389247620414
# ********************
#
#
# county_name_arpu_202004_min
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.558163	valid_0's auc: 0.544487
# [40]	training's auc: 0.558719	valid_0's auc: 0.545303
# [60]	training's auc: 0.558798	valid_0's auc: 0.545528
# [80]	training's auc: 0.558862	valid_0's auc: 0.545429
# [100]	training's auc: 0.559372	valid_0's auc: 0.546158
# [120]	training's auc: 0.559381	valid_0's auc: 0.546221
# [140]	training's auc: 0.559392	valid_0's auc: 0.546218
# [160]	training's auc: 0.559412	valid_0's auc: 0.546182
# [180]	training's auc: 0.55942	valid_0's auc: 0.54623
# Early stopping, best iteration is:
# [138]	training's auc: 0.559393	valid_0's auc: 0.546242
# *****
# 0.5462419883292677
# ********************
#
#
# county_name_arpu_202004_median
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.760949	valid_0's auc: 0.726531
# [40]	training's auc: 0.766131	valid_0's auc: 0.728768
# [60]	training's auc: 0.768627	valid_0's auc: 0.728599
# [80]	training's auc: 0.770315	valid_0's auc: 0.728084
# Early stopping, best iteration is:
# [37]	training's auc: 0.765626	valid_0's auc: 0.72924
# *****
# 0.7292399076864208
# ********************
#
#
# county_name_arpu_202004_mean
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.759588	valid_0's auc: 0.720704
# [40]	training's auc: 0.76461	valid_0's auc: 0.721249
# [60]	training's auc: 0.767328	valid_0's auc: 0.723363
# [80]	training's auc: 0.769319	valid_0's auc: 0.724439
# [100]	training's auc: 0.770486	valid_0's auc: 0.724437
# [120]	training's auc: 0.771611	valid_0's auc: 0.725289
# Early stopping, best iteration is:
# [79]	training's auc: 0.769214	valid_0's auc: 0.725561
# *****
# 0.7255614148371359
# ********************
#
#
# county_name_arpu_202004_skew
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.509833	valid_0's auc: 0.508178
# [40]	training's auc: 0.509844	valid_0's auc: 0.508219
# [60]	training's auc: 0.509844	valid_0's auc: 0.508219
# Early stopping, best iteration is:
# [28]	training's auc: 0.509844	valid_0's auc: 0.508219
# *****
# 0.5082194360740422
# ********************
#
#
# county_name_arpu_202004_nunique
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.710969	valid_0's auc: 0.688536
# [40]	training's auc: 0.711647	valid_0's auc: 0.689996
# [60]	training's auc: 0.711776	valid_0's auc: 0.690555
# [80]	training's auc: 0.711823	valid_0's auc: 0.690736
# [100]	training's auc: 0.71193	valid_0's auc: 0.691307
# [120]	training's auc: 0.711986	valid_0's auc: 0.69137
# [140]	training's auc: 0.71205	valid_0's auc: 0.691851
# [160]	training's auc: 0.712057	valid_0's auc: 0.691851
# [180]	training's auc: 0.712077	valid_0's auc: 0.691881
# [200]	training's auc: 0.712136	valid_0's auc: 0.692368
# [220]	training's auc: 0.71216	valid_0's auc: 0.692428
# [240]	training's auc: 0.712167	valid_0's auc: 0.692488
# [260]	training's auc: 0.71217	valid_0's auc: 0.692488
# Early stopping, best iteration is:
# [224]	training's auc: 0.712167	valid_0's auc: 0.692488
# *****
# 0.6924878629167265
# ********************
#
#
# county_name_idcard_cnt*arpu_202004_max
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.764981	valid_0's auc: 0.72114
# [40]	training's auc: 0.769919	valid_0's auc: 0.724041
# [60]	training's auc: 0.771852	valid_0's auc: 0.724014
# [80]	training's auc: 0.772875	valid_0's auc: 0.724905
# [100]	training's auc: 0.773368	valid_0's auc: 0.72591
# [120]	training's auc: 0.773882	valid_0's auc: 0.726518
# [140]	training's auc: 0.774129	valid_0's auc: 0.72679
# [160]	training's auc: 0.774405	valid_0's auc: 0.72508
# [180]	training's auc: 0.774529	valid_0's auc: 0.725397
# Early stopping, best iteration is:
# [140]	training's auc: 0.774129	valid_0's auc: 0.72679
# *****
# 0.726790070311379
# ********************
#
#
# county_name_idcard_cnt*arpu_202004_min
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.608074	valid_0's auc: 0.560044
# [40]	training's auc: 0.608054	valid_0's auc: 0.556575
# [60]	training's auc: 0.608298	valid_0's auc: 0.55689
# [80]	training's auc: 0.608983	valid_0's auc: 0.556585
# Early stopping, best iteration is:
# [33]	training's auc: 0.608204	valid_0's auc: 0.560395
# *****
# 0.5603954417180849
# ********************
#
#
# county_name_idcard_cnt*arpu_202004_median
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.758121	valid_0's auc: 0.718321
# [40]	training's auc: 0.761647	valid_0's auc: 0.719677
# [60]	training's auc: 0.764108	valid_0's auc: 0.722292
# [80]	training's auc: 0.765253	valid_0's auc: 0.723726
# [100]	training's auc: 0.766053	valid_0's auc: 0.72528
# [120]	training's auc: 0.766692	valid_0's auc: 0.726079
# [140]	training's auc: 0.767223	valid_0's auc: 0.726668
# [160]	training's auc: 0.767494	valid_0's auc: 0.727077
# [180]	training's auc: 0.767848	valid_0's auc: 0.727678
# [200]	training's auc: 0.76826	valid_0's auc: 0.727466
# [220]	training's auc: 0.768534	valid_0's auc: 0.727369
# [240]	training's auc: 0.768655	valid_0's auc: 0.727433
# [260]	training's auc: 0.768884	valid_0's auc: 0.727648
# [280]	training's auc: 0.768989	valid_0's auc: 0.727068
# Early stopping, best iteration is:
# [244]	training's auc: 0.768706	valid_0's auc: 0.727959
# *****
# 0.7279589371980676
# ********************
#
#
# county_name_idcard_cnt*arpu_202004_mean
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.763774	valid_0's auc: 0.725926
# [40]	training's auc: 0.76834	valid_0's auc: 0.728077
# [60]	training's auc: 0.769873	valid_0's auc: 0.727865
# [80]	training's auc: 0.77091	valid_0's auc: 0.729697
# [100]	training's auc: 0.771562	valid_0's auc: 0.731057
# [120]	training's auc: 0.771873	valid_0's auc: 0.731787
# [140]	training's auc: 0.772096	valid_0's auc: 0.732177
# [160]	training's auc: 0.77231	valid_0's auc: 0.73146
# [180]	training's auc: 0.77249	valid_0's auc: 0.731599
# [200]	training's auc: 0.772619	valid_0's auc: 0.731791
# Early stopping, best iteration is:
# [154]	training's auc: 0.772192	valid_0's auc: 0.732443
# *****
# 0.7324430812646482
# ********************
#
#
# county_name_idcard_cnt*arpu_202004_nunique
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.728596	valid_0's auc: 0.711016
# [40]	training's auc: 0.729269	valid_0's auc: 0.709311
# [60]	training's auc: 0.729526	valid_0's auc: 0.709874
# Early stopping, best iteration is:
# [25]	training's auc: 0.728883	valid_0's auc: 0.711393
# *****
# 0.7113930143014301
# ********************
#
#
# county_name_arpu_202004/idcard_cnt_max
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.763961	valid_0's auc: 0.719131
# [40]	training's auc: 0.768733	valid_0's auc: 0.724907
# [60]	training's auc: 0.771565	valid_0's auc: 0.727615
# [80]	training's auc: 0.772782	valid_0's auc: 0.729237
# [100]	training's auc: 0.773911	valid_0's auc: 0.730472
# [120]	training's auc: 0.774514	valid_0's auc: 0.731306
# [140]	training's auc: 0.774977	valid_0's auc: 0.731975
# [160]	training's auc: 0.775345	valid_0's auc: 0.732267
# [180]	training's auc: 0.775565	valid_0's auc: 0.732521
# [200]	training's auc: 0.775788	valid_0's auc: 0.732787
# [220]	training's auc: 0.775955	valid_0's auc: 0.732987
# [240]	training's auc: 0.776039	valid_0's auc: 0.733319
# [260]	training's auc: 0.776171	valid_0's auc: 0.733385
# [280]	training's auc: 0.776262	valid_0's auc: 0.733477
# [300]	training's auc: 0.776315	valid_0's auc: 0.733564
# [320]	training's auc: 0.776372	valid_0's auc: 0.733699
# [340]	training's auc: 0.776408	valid_0's auc: 0.733627
# [360]	training's auc: 0.776434	valid_0's auc: 0.733908
# [380]	training's auc: 0.776461	valid_0's auc: 0.733833
# [400]	training's auc: 0.776486	valid_0's auc: 0.734016
# [420]	training's auc: 0.776504	valid_0's auc: 0.733902
# [440]	training's auc: 0.776514	valid_0's auc: 0.733914
# Early stopping, best iteration is:
# [393]	training's auc: 0.776484	valid_0's auc: 0.734039
# *****
# 0.7340394365523509
# ********************
#
#
# county_name_arpu_202004/idcard_cnt_min
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.637803	valid_0's auc: 0.621381
# [40]	training's auc: 0.639902	valid_0's auc: 0.624413
# [60]	training's auc: 0.640084	valid_0's auc: 0.624244
# [80]	training's auc: 0.640134	valid_0's auc: 0.624157
# Early stopping, best iteration is:
# [45]	training's auc: 0.639933	valid_0's auc: 0.624416
# *****
# 0.6244155665566556
# ********************
#
#
# county_name_arpu_202004/idcard_cnt_median
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.750586	valid_0's auc: 0.712094
# [40]	training's auc: 0.754787	valid_0's auc: 0.714022
# [60]	training's auc: 0.756615	valid_0's auc: 0.715249
# [80]	training's auc: 0.757632	valid_0's auc: 0.715669
# [100]	training's auc: 0.758206	valid_0's auc: 0.715421
# [120]	training's auc: 0.758879	valid_0's auc: 0.715747
# [140]	training's auc: 0.759372	valid_0's auc: 0.715702
# [160]	training's auc: 0.759738	valid_0's auc: 0.715894
# [180]	training's auc: 0.759971	valid_0's auc: 0.71604
# Early stopping, best iteration is:
# [136]	training's auc: 0.759288	valid_0's auc: 0.716342
# *****
# 0.7163420146362462
# ********************
#
#
# county_name_arpu_202004/idcard_cnt_mean
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.759683	valid_0's auc: 0.717583
# [40]	training's auc: 0.764438	valid_0's auc: 0.722789
# [60]	training's auc: 0.766639	valid_0's auc: 0.724941
# [80]	training's auc: 0.768733	valid_0's auc: 0.727129
# [100]	training's auc: 0.769876	valid_0's auc: 0.72783
# [120]	training's auc: 0.770924	valid_0's auc: 0.72846
# [140]	training's auc: 0.77146	valid_0's auc: 0.729238
# [160]	training's auc: 0.772129	valid_0's auc: 0.729874
# [180]	training's auc: 0.772516	valid_0's auc: 0.729978
# [200]	training's auc: 0.772775	valid_0's auc: 0.729874
# [220]	training's auc: 0.772927	valid_0's auc: 0.729916
# [240]	training's auc: 0.773175	valid_0's auc: 0.729629
# Early stopping, best iteration is:
# [192]	training's auc: 0.772755	valid_0's auc: 0.730289
# *****
# 0.7302891973980007
# ********************
#
#
# county_name_arpu_202004/idcard_cnt_skew
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.763515	valid_0's auc: 0.725381
# [40]	training's auc: 0.769652	valid_0's auc: 0.729017
# [60]	training's auc: 0.77179	valid_0's auc: 0.728292
# [80]	training's auc: 0.773157	valid_0's auc: 0.729288
# [100]	training's auc: 0.774195	valid_0's auc: 0.729268
# [120]	training's auc: 0.77507	valid_0's auc: 0.729962
# [140]	training's auc: 0.775614	valid_0's auc: 0.730135
# [160]	training's auc: 0.775906	valid_0's auc: 0.729872
# [180]	training's auc: 0.776191	valid_0's auc: 0.729895
# Early stopping, best iteration is:
# [135]	training's auc: 0.775365	valid_0's auc: 0.73024
# *****
# 0.7302398718132683
# ********************
#
#
# county_name_arpu_202004/idcard_cnt_nunique
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.723373	valid_0's auc: 0.702199
# [40]	training's auc: 0.723896	valid_0's auc: 0.703652
# [60]	training's auc: 0.724164	valid_0's auc: 0.704042
# [80]	training's auc: 0.724288	valid_0's auc: 0.70468
# [100]	training's auc: 0.724361	valid_0's auc: 0.705018
# [120]	training's auc: 0.724385	valid_0's auc: 0.705132
# [140]	training's auc: 0.724424	valid_0's auc: 0.705538
# [160]	training's auc: 0.724455	valid_0's auc: 0.705574
# [180]	training's auc: 0.724455	valid_0's auc: 0.705574
# Early stopping, best iteration is:
# [137]	training's auc: 0.724426	valid_0's auc: 0.705664
# *****
# 0.705663772899029
# ********************
#
#
# city_name_county_name_idcard_cnt_max
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.628027	valid_0's auc: 0.635801
# [40]	training's auc: 0.62803	valid_0's auc: 0.635837
# [60]	training's auc: 0.62803	valid_0's auc: 0.635837
# Early stopping, best iteration is:
# [26]	training's auc: 0.62803	valid_0's auc: 0.635837
# *****
# 0.6358366814942363
# ********************
#
#
# city_name_county_name_idcard_cnt_min
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.61342	valid_0's auc: 0.597121
# [40]	training's auc: 0.61342	valid_0's auc: 0.597121
# Early stopping, best iteration is:
# [1]	training's auc: 0.61342	valid_0's auc: 0.597121
# *****
# 0.5971205816233798
# ********************
#
#
# city_name_county_name_idcard_cnt_median
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.584501	valid_0's auc: 0.577387
# [40]	training's auc: 0.584501	valid_0's auc: 0.577387
# Early stopping, best iteration is:
# [1]	training's auc: 0.584501	valid_0's auc: 0.577387
# *****
# 0.5773873583010475
# ********************
#
#
# city_name_county_name_idcard_cnt_mean
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.761058	valid_0's auc: 0.725718
# [40]	training's auc: 0.764799	valid_0's auc: 0.727651
# [60]	training's auc: 0.767596	valid_0's auc: 0.730336
# [80]	training's auc: 0.769232	valid_0's auc: 0.731289
# [100]	training's auc: 0.770667	valid_0's auc: 0.730881
# [120]	training's auc: 0.771352	valid_0's auc: 0.731476
# [140]	training's auc: 0.77169	valid_0's auc: 0.731174
# [160]	training's auc: 0.772289	valid_0's auc: 0.730839
# [180]	training's auc: 0.772756	valid_0's auc: 0.731054
# Early stopping, best iteration is:
# [131]	training's auc: 0.771564	valid_0's auc: 0.731715
# *****
# 0.7317151552111733
# ********************
#
#
# city_name_county_name_idcard_cnt_skew
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.761779	valid_0's auc: 0.725922
# [40]	training's auc: 0.766076	valid_0's auc: 0.731122
# [60]	training's auc: 0.768859	valid_0's auc: 0.731156
# [80]	training's auc: 0.770512	valid_0's auc: 0.731189
# [100]	training's auc: 0.772711	valid_0's auc: 0.731392
# [120]	training's auc: 0.773775	valid_0's auc: 0.731796
# [140]	training's auc: 0.774607	valid_0's auc: 0.733005
# [160]	training's auc: 0.775211	valid_0's auc: 0.733518
# [180]	training's auc: 0.775686	valid_0's auc: 0.733316
# [200]	training's auc: 0.776178	valid_0's auc: 0.73351
# [220]	training's auc: 0.77657	valid_0's auc: 0.733767
# [240]	training's auc: 0.77682	valid_0's auc: 0.733691
# [260]	training's auc: 0.777079	valid_0's auc: 0.733682
# [280]	training's auc: 0.777264	valid_0's auc: 0.733877
# [300]	training's auc: 0.77753	valid_0's auc: 0.734455
# [320]	training's auc: 0.777683	valid_0's auc: 0.73424
# [340]	training's auc: 0.777895	valid_0's auc: 0.734622
# [360]	training's auc: 0.778075	valid_0's auc: 0.734745
# [380]	training's auc: 0.778164	valid_0's auc: 0.734452
# [400]	training's auc: 0.778245	valid_0's auc: 0.734506
# Early stopping, best iteration is:
# [353]	training's auc: 0.778009	valid_0's auc: 0.734835
# *****
# 0.7348346247668245
# ********************
#
#
# city_name_county_name_idcard_cnt_nunique
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.655831	valid_0's auc: 0.647708
# [40]	training's auc: 0.655831	valid_0's auc: 0.647708
# Early stopping, best iteration is:
# [1]	training's auc: 0.655831	valid_0's auc: 0.647708
# *****
# 0.647707705553164
# ********************
#
#
# city_name_county_name_arpu_202004_max
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.765314	valid_0's auc: 0.724563
# [40]	training's auc: 0.768804	valid_0's auc: 0.727419
# [60]	training's auc: 0.770874	valid_0's auc: 0.730144
# [80]	training's auc: 0.771944	valid_0's auc: 0.73004
# [100]	training's auc: 0.772788	valid_0's auc: 0.731005
# [120]	training's auc: 0.772981	valid_0's auc: 0.731177
# [140]	training's auc: 0.77322	valid_0's auc: 0.730932
# [160]	training's auc: 0.773412	valid_0's auc: 0.731052
# [180]	training's auc: 0.773623	valid_0's auc: 0.731123
# [200]	training's auc: 0.773724	valid_0's auc: 0.731655
# [220]	training's auc: 0.773815	valid_0's auc: 0.731679
# [240]	training's auc: 0.773902	valid_0's auc: 0.731596
# [260]	training's auc: 0.773974	valid_0's auc: 0.731685
# Early stopping, best iteration is:
# [215]	training's auc: 0.773818	valid_0's auc: 0.731969
# *****
# 0.7319692567082795
# ********************
#
#
# city_name_county_name_arpu_202004_min
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.559833	valid_0's auc: 0.547689
# [40]	training's auc: 0.560397	valid_0's auc: 0.548562
# [60]	training's auc: 0.560452	valid_0's auc: 0.548666
# [80]	training's auc: 0.560539	valid_0's auc: 0.548714
# [100]	training's auc: 0.56104	valid_0's auc: 0.549342
# [120]	training's auc: 0.561054	valid_0's auc: 0.54939
# [140]	training's auc: 0.56107	valid_0's auc: 0.549414
# [160]	training's auc: 0.561089	valid_0's auc: 0.549414
# [180]	training's auc: 0.561096	valid_0's auc: 0.549426
# Early stopping, best iteration is:
# [138]	training's auc: 0.561072	valid_0's auc: 0.549462
# *****
# 0.5494616037690726
# ********************
#
#
# city_name_county_name_arpu_202004_median
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.764627	valid_0's auc: 0.727632
# [40]	training's auc: 0.769164	valid_0's auc: 0.730325
# [60]	training's auc: 0.771904	valid_0's auc: 0.730726
# [80]	training's auc: 0.773436	valid_0's auc: 0.730243
# Early stopping, best iteration is:
# [43]	training's auc: 0.769712	valid_0's auc: 0.731418
# *****
# 0.7314177069880902
# ********************
#
#
# city_name_county_name_arpu_202004_mean
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.765297	valid_0's auc: 0.722315
# [40]	training's auc: 0.768276	valid_0's auc: 0.725065
# [60]	training's auc: 0.77044	valid_0's auc: 0.726369
# [80]	training's auc: 0.771934	valid_0's auc: 0.727286
# [100]	training's auc: 0.773035	valid_0's auc: 0.726857
# [120]	training's auc: 0.774132	valid_0's auc: 0.728195
# [140]	training's auc: 0.77496	valid_0's auc: 0.728584
# [160]	training's auc: 0.775506	valid_0's auc: 0.728551
# [180]	training's auc: 0.775888	valid_0's auc: 0.728518
# [200]	training's auc: 0.776196	valid_0's auc: 0.72844
# Early stopping, best iteration is:
# [150]	training's auc: 0.775252	valid_0's auc: 0.728757
# *****
# 0.728757114841919
# ********************
#
#
# city_name_county_name_arpu_202004_skew
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.509833	valid_0's auc: 0.508178
# [40]	training's auc: 0.509844	valid_0's auc: 0.508219
# [60]	training's auc: 0.509844	valid_0's auc: 0.508219
# Early stopping, best iteration is:
# [28]	training's auc: 0.509844	valid_0's auc: 0.508219
# *****
# 0.5082194360740422
# ********************
#
#
# city_name_county_name_arpu_202004_nunique
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.712532	valid_0's auc: 0.692286
# [40]	training's auc: 0.713131	valid_0's auc: 0.690929
# [60]	training's auc: 0.713272	valid_0's auc: 0.691477
# Early stopping, best iteration is:
# [20]	training's auc: 0.712532	valid_0's auc: 0.692286
# *****
# 0.6922860764337303
# ********************
#
#
# city_name_county_name_idcard_cnt*arpu_202004_max
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.765585	valid_0's auc: 0.720062
# [40]	training's auc: 0.77149	valid_0's auc: 0.724288
# [60]	training's auc: 0.773046	valid_0's auc: 0.725234
# [80]	training's auc: 0.774562	valid_0's auc: 0.726978
# [100]	training's auc: 0.775203	valid_0's auc: 0.727487
# [120]	training's auc: 0.775853	valid_0's auc: 0.728883
# [140]	training's auc: 0.776162	valid_0's auc: 0.728363
# [160]	training's auc: 0.776452	valid_0's auc: 0.72886
# [180]	training's auc: 0.776645	valid_0's auc: 0.727159
# [200]	training's auc: 0.776783	valid_0's auc: 0.727114
# Early stopping, best iteration is:
# [158]	training's auc: 0.776403	valid_0's auc: 0.729055
# *****
# 0.7290545630650022
# ********************
#
#
# city_name_county_name_idcard_cnt*arpu_202004_min
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.608268	valid_0's auc: 0.572527
# [40]	training's auc: 0.608207	valid_0's auc: 0.568836
# [60]	training's auc: 0.608484	valid_0's auc: 0.569159
# Early stopping, best iteration is:
# [22]	training's auc: 0.6083	valid_0's auc: 0.572553
# *****
# 0.5725534509972736
# ********************
#
#
# city_name_county_name_idcard_cnt*arpu_202004_median
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.760971	valid_0's auc: 0.714447
# [40]	training's auc: 0.765305	valid_0's auc: 0.721943
# [60]	training's auc: 0.76733	valid_0's auc: 0.723448
# [80]	training's auc: 0.768362	valid_0's auc: 0.724572
# [100]	training's auc: 0.769103	valid_0's auc: 0.726437
# [120]	training's auc: 0.769636	valid_0's auc: 0.726808
# [140]	training's auc: 0.770156	valid_0's auc: 0.727352
# [160]	training's auc: 0.770424	valid_0's auc: 0.727376
# [180]	training's auc: 0.770676	valid_0's auc: 0.727739
# [200]	training's auc: 0.770946	valid_0's auc: 0.727934
# [220]	training's auc: 0.771193	valid_0's auc: 0.728358
# [240]	training's auc: 0.771383	valid_0's auc: 0.728255
# [260]	training's auc: 0.771486	valid_0's auc: 0.728303
# [280]	training's auc: 0.77162	valid_0's auc: 0.728288
# [300]	training's auc: 0.771705	valid_0's auc: 0.728271
# [320]	training's auc: 0.771818	valid_0's auc: 0.727775
# Early stopping, best iteration is:
# [279]	training's auc: 0.771622	valid_0's auc: 0.728494
# *****
# 0.7284940450566796
# ********************
#
#
# city_name_county_name_idcard_cnt*arpu_202004_mean
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.765579	valid_0's auc: 0.726086
# [40]	training's auc: 0.770161	valid_0's auc: 0.731044
# [60]	training's auc: 0.77184	valid_0's auc: 0.730469
# [80]	training's auc: 0.77283	valid_0's auc: 0.730773
# [100]	training's auc: 0.773484	valid_0's auc: 0.73201
# [120]	training's auc: 0.773867	valid_0's auc: 0.732715
# [140]	training's auc: 0.774085	valid_0's auc: 0.732507
# [160]	training's auc: 0.774297	valid_0's auc: 0.733618
# [180]	training's auc: 0.774443	valid_0's auc: 0.733944
# [200]	training's auc: 0.774717	valid_0's auc: 0.733588
# [220]	training's auc: 0.774857	valid_0's auc: 0.732745
# Early stopping, best iteration is:
# [178]	training's auc: 0.774431	valid_0's auc: 0.734019
# *****
# 0.7340185105467069
# ********************
#
#
# city_name_county_name_idcard_cnt*arpu_202004_nunique
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.730878	valid_0's auc: 0.711125
# [40]	training's auc: 0.731501	valid_0's auc: 0.711275
# [60]	training's auc: 0.731801	valid_0's auc: 0.712024
# [80]	training's auc: 0.731987	valid_0's auc: 0.712953
# [100]	training's auc: 0.732083	valid_0's auc: 0.713375
# [120]	training's auc: 0.732124	valid_0's auc: 0.713545
# [140]	training's auc: 0.732124	valid_0's auc: 0.713545
# [160]	training's auc: 0.732167	valid_0's auc: 0.713626
# [180]	training's auc: 0.73218	valid_0's auc: 0.71365
# Early stopping, best iteration is:
# [149]	training's auc: 0.732147	valid_0's auc: 0.71368
# *****
# 0.7136799277753862
# ********************
#
#
# city_name_county_name_arpu_202004/idcard_cnt_max
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.765222	valid_0's auc: 0.718949
# [40]	training's auc: 0.770613	valid_0's auc: 0.725675
# [60]	training's auc: 0.77308	valid_0's auc: 0.729268
# [80]	training's auc: 0.774686	valid_0's auc: 0.729927
# [100]	training's auc: 0.775749	valid_0's auc: 0.731439
# [120]	training's auc: 0.776476	valid_0's auc: 0.732622
# [140]	training's auc: 0.776971	valid_0's auc: 0.733573
# [160]	training's auc: 0.77732	valid_0's auc: 0.73398
# [180]	training's auc: 0.777609	valid_0's auc: 0.734007
# [200]	training's auc: 0.777903	valid_0's auc: 0.73392
# [220]	training's auc: 0.7781	valid_0's auc: 0.734818
# [240]	training's auc: 0.77819	valid_0's auc: 0.735012
# [260]	training's auc: 0.778374	valid_0's auc: 0.734654
# [280]	training's auc: 0.778442	valid_0's auc: 0.734618
# Early stopping, best iteration is:
# [238]	training's auc: 0.77818	valid_0's auc: 0.735036
# *****
# 0.7350364112498207
# ********************
#
#
# city_name_county_name_arpu_202004/idcard_cnt_min
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.641426	valid_0's auc: 0.630317
# [40]	training's auc: 0.643025	valid_0's auc: 0.628164
# [60]	training's auc: 0.643741	valid_0's auc: 0.63085
# [80]	training's auc: 0.643815	valid_0's auc: 0.630695
# [100]	training's auc: 0.643987	valid_0's auc: 0.630372
# [120]	training's auc: 0.64404	valid_0's auc: 0.630791
# Early stopping, best iteration is:
# [88]	training's auc: 0.643899	valid_0's auc: 0.630943
# *****
# 0.6309429856029081
# ********************
#
#
# city_name_county_name_arpu_202004/idcard_cnt_median
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.755058	valid_0's auc: 0.706824
# [40]	training's auc: 0.759554	valid_0's auc: 0.710191
# [60]	training's auc: 0.760938	valid_0's auc: 0.711901
# [80]	training's auc: 0.762042	valid_0's auc: 0.712623
# [100]	training's auc: 0.762819	valid_0's auc: 0.712583
# [120]	training's auc: 0.763584	valid_0's auc: 0.711312
# [140]	training's auc: 0.763968	valid_0's auc: 0.711955
# Early stopping, best iteration is:
# [106]	training's auc: 0.763024	valid_0's auc: 0.713109
# *****
# 0.7131089467642416
# ********************
#
#
# city_name_county_name_arpu_202004/idcard_cnt_mean
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.76048	valid_0's auc: 0.717775
# [40]	training's auc: 0.765909	valid_0's auc: 0.724113
# [60]	training's auc: 0.768523	valid_0's auc: 0.727496
# [80]	training's auc: 0.770432	valid_0's auc: 0.728478
# [100]	training's auc: 0.7717	valid_0's auc: 0.729241
# [120]	training's auc: 0.772548	valid_0's auc: 0.729454
# [140]	training's auc: 0.773406	valid_0's auc: 0.7303
# [160]	training's auc: 0.77386	valid_0's auc: 0.731123
# [180]	training's auc: 0.774239	valid_0's auc: 0.731309
# [200]	training's auc: 0.774648	valid_0's auc: 0.731503
# [220]	training's auc: 0.774929	valid_0's auc: 0.731802
# [240]	training's auc: 0.775126	valid_0's auc: 0.731802
# [260]	training's auc: 0.775302	valid_0's auc: 0.732104
# [280]	training's auc: 0.775462	valid_0's auc: 0.731548
# [300]	training's auc: 0.775571	valid_0's auc: 0.731353
# Early stopping, best iteration is:
# [267]	training's auc: 0.775316	valid_0's auc: 0.732179
# *****
# 0.7321785167647199
# ********************
#
#
# city_name_county_name_arpu_202004/idcard_cnt_skew
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.765868	valid_0's auc: 0.725549
# [40]	training's auc: 0.771369	valid_0's auc: 0.730902
# [60]	training's auc: 0.773836	valid_0's auc: 0.730588
# [80]	training's auc: 0.77509	valid_0's auc: 0.730617
# [100]	training's auc: 0.776423	valid_0's auc: 0.731549
# [120]	training's auc: 0.777117	valid_0's auc: 0.731766
# [140]	training's auc: 0.777806	valid_0's auc: 0.731945
# [160]	training's auc: 0.778075	valid_0's auc: 0.731903
# [180]	training's auc: 0.77836	valid_0's auc: 0.731727
# Early stopping, best iteration is:
# [134]	training's auc: 0.777519	valid_0's auc: 0.732137
# *****
# 0.7321366647534319
# ********************
#
#
# city_name_county_name_arpu_202004/idcard_cnt_nunique
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.721465	valid_0's auc: 0.699583
# [40]	training's auc: 0.722019	valid_0's auc: 0.70025
# Early stopping, best iteration is:
# [2]	training's auc: 0.718492	valid_0's auc: 0.700967
# *****
# 0.7009673793466303
# ********************
#
#
# city_name_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.684054	valid_0's auc: 0.671828
# [40]	training's auc: 0.684058	valid_0's auc: 0.671655
# Early stopping, best iteration is:
# [1]	training's auc: 0.684054	valid_0's auc: 0.671828
# *****
# 0.6718279164873009
# ********************
#
#
# county_name_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.74653	valid_0's auc: 0.72918
# [40]	training's auc: 0.748207	valid_0's auc: 0.732214
# [60]	training's auc: 0.748748	valid_0's auc: 0.733832
# [80]	training's auc: 0.748873	valid_0's auc: 0.734684
# [100]	training's auc: 0.748929	valid_0's auc: 0.735187
# [120]	training's auc: 0.749009	valid_0's auc: 0.735624
# [140]	training's auc: 0.749034	valid_0's auc: 0.735833
# [160]	training's auc: 0.749053	valid_0's auc: 0.735965
# [180]	training's auc: 0.749053	valid_0's auc: 0.735965
# [200]	training's auc: 0.749088	valid_0's auc: 0.736344
# [220]	training's auc: 0.749112	valid_0's auc: 0.736844
# [240]	training's auc: 0.749119	valid_0's auc: 0.736844
# [260]	training's auc: 0.749124	valid_0's auc: 0.736844
# Early stopping, best iteration is:
# [218]	training's auc: 0.749112	valid_0's auc: 0.736844
# *****
# 0.7368435213086526
# ********************
#
#
# city_name_county_name_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.74872	valid_0's auc: 0.729585
# [40]	training's auc: 0.750428	valid_0's auc: 0.733415
# [60]	training's auc: 0.750971	valid_0's auc: 0.735296
# [80]	training's auc: 0.751049	valid_0's auc: 0.735666
# [100]	training's auc: 0.751105	valid_0's auc: 0.736071
# [120]	training's auc: 0.751183	valid_0's auc: 0.736779
# [140]	training's auc: 0.751219	valid_0's auc: 0.737138
# [160]	training's auc: 0.751243	valid_0's auc: 0.737216
# [180]	training's auc: 0.751243	valid_0's auc: 0.737216
# [200]	training's auc: 0.751287	valid_0's auc: 0.737595
# [220]	training's auc: 0.751301	valid_0's auc: 0.738095
# [240]	training's auc: 0.751314	valid_0's auc: 0.738095
# [260]	training's auc: 0.751314	valid_0's auc: 0.738095
# Early stopping, best iteration is:
# [218]	training's auc: 0.751301	valid_0's auc: 0.738095
# *****
# 0.7380945975032286
# ********************
#
#
# idcard_cnt_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.728639	valid_0's auc: 0.722937
# [40]	training's auc: 0.728657	valid_0's auc: 0.722704
# Early stopping, best iteration is:
# [1]	training's auc: 0.728639	valid_0's auc: 0.722937
# *****
# 0.7229366958434974
# ********************
#
#
# opposite_cnt
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.875081	valid_0's auc: 0.835057
# [40]	training's auc: 0.878333	valid_0's auc: 0.83007
# Early stopping, best iteration is:
# [5]	training's auc: 0.870846	valid_0's auc: 0.837067
# *****
# 0.837067130626106
# ********************
#
#
# opposite_nunique
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.905263	valid_0's auc: 0.872435
# [40]	training's auc: 0.906385	valid_0's auc: 0.872602
# [60]	training's auc: 0.907182	valid_0's auc: 0.872478
# Early stopping, best iteration is:
# [21]	training's auc: 0.905375	valid_0's auc: 0.873454
# *****
# 0.8734544650117185
# ********************
#
#
# voc_cnt_per_capita
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.912874	valid_0's auc: 0.862673
# [40]	training's auc: 0.915995	valid_0's auc: 0.86524
# Early stopping, best iteration is:
# [1]	training's auc: 0.90085	valid_0's auc: 0.866538
# *****
# 0.8665384201463625
# ********************
#
#
# voc_calltype_id_1_cnt
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.866656	valid_0's auc: 0.830659
# [40]	training's auc: 0.870004	valid_0's auc: 0.828389
# Early stopping, best iteration is:
# [7]	training's auc: 0.862664	valid_0's auc: 0.833556
# *****
# 0.8335560458219735
# ********************
#
#
# imeis
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.84359	valid_0's auc: 0.832839
# [40]	training's auc: 0.84359	valid_0's auc: 0.832839
# [60]	training's auc: 0.84359	valid_0's auc: 0.832839
# Early stopping, best iteration is:
# [17]	training's auc: 0.84359	valid_0's auc: 0.832839
# *****
# 0.8328385827713206
# ********************
#
#
# voc_calltype_id_1_call_dur_sum
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.871437	valid_0's auc: 0.84342
# [40]	training's auc: 0.875554	valid_0's auc: 0.839956
# [60]	training's auc: 0.877354	valid_0's auc: 0.837341
# Early stopping, best iteration is:
# [11]	training's auc: 0.869341	valid_0's auc: 0.843964
# *****
# 0.843963744200507
# ********************
#
#
# voc_calltype_id_1_30s_cnt
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.834601	valid_0's auc: 0.792535
# [40]	training's auc: 0.836674	valid_0's auc: 0.788126
# Early stopping, best iteration is:
# [2]	training's auc: 0.832094	valid_0's auc: 0.796179
# *****
# 0.7961792103123356
# ********************
#
#
# voc_calltype_id_1_60s_cnt
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.84792	valid_0's auc: 0.804378
# [40]	training's auc: 0.84954	valid_0's auc: 0.80278
# Early stopping, best iteration is:
# [6]	training's auc: 0.84532	valid_0's auc: 0.807795
# *****
# 0.8077946381594682
# ********************
#
#
# voc_calltype_id_1_300s_cnt
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.673163	valid_0's auc: 0.679384
# [40]	training's auc: 0.673297	valid_0's auc: 0.679185
# [60]	training's auc: 0.674437	valid_0's auc: 0.680079
# [80]	training's auc: 0.675302	valid_0's auc: 0.679905
# [100]	training's auc: 0.675362	valid_0's auc: 0.679801
# Early stopping, best iteration is:
# [56]	training's auc: 0.67381	valid_0's auc: 0.681131
# *****
# 0.6811310207107667
# ********************
#
#
# voc_calltype_id_1_30s_rate
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.82709	valid_0's auc: 0.808035
# [40]	training's auc: 0.831599	valid_0's auc: 0.806886
# [60]	training's auc: 0.834434	valid_0's auc: 0.806668
# Early stopping, best iteration is:
# [14]	training's auc: 0.825174	valid_0's auc: 0.808515
# *****
# 0.8085150906394988
# ********************
#
#
# voc_calltype_id_1_60s_rate
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.839448	valid_0's auc: 0.806246
# [40]	training's auc: 0.843913	valid_0's auc: 0.80508
# [60]	training's auc: 0.846867	valid_0's auc: 0.804535
# Early stopping, best iteration is:
# [28]	training's auc: 0.841367	valid_0's auc: 0.80743
# *****
# 0.8074299277753862
# ********************
#
#
# voc_calltype_id_1_300s_rate
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.692583	valid_0's auc: 0.659096
# [40]	training's auc: 0.69639	valid_0's auc: 0.660308
# [60]	training's auc: 0.69847	valid_0's auc: 0.663771
# [80]	training's auc: 0.700354	valid_0's auc: 0.663215
# [100]	training's auc: 0.700994	valid_0's auc: 0.663561
# Early stopping, best iteration is:
# [56]	training's auc: 0.69826	valid_0's auc: 0.664002
# *****
# 0.6640015903764289
# ********************
#
#
# call_type_id_1_rate
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.882862	valid_0's auc: 0.844037
# [40]	training's auc: 0.885226	valid_0's auc: 0.843858
# [60]	training's auc: 0.886462	valid_0's auc: 0.843689
# Early stopping, best iteration is:
# [18]	training's auc: 0.882519	valid_0's auc: 0.844865
# *****
# 0.8448650571578897
# ********************
#
#
# city_name_nunique_x
# Training until validation scores don't improve for 50 rounds
# ...
# [60]	training's auc: 0.802016	valid_0's auc: 0.791821
# [80]	training's auc: 0.802163	valid_0's auc: 0.792514
# [100]	training's auc: 0.80218	valid_0's auc: 0.792553
# [120]	training's auc: 0.802214	valid_0's auc: 0.792592
# [140]	training's auc: 0.802635	valid_0's auc: 0.792245
# [160]	training's auc: 0.802654	valid_0's auc: 0.792138
# Early stopping, best iteration is:
# [124]	training's auc: 0.802225	valid_0's auc: 0.79264
# *****
# 0.7926397259291147
# ********************
#
#
# sms_day17_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.834824	valid_0's auc: 0.825027
# [40]	training's auc: 0.834877	valid_0's auc: 0.825036
# Early stopping, best iteration is:
# [4]	training's auc: 0.834647	valid_0's auc: 0.82589
# *****
# 0.8258896541828096
# ********************
#
#
# sms_day18_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.816939	valid_0's auc: 0.797693
# [40]	training's auc: 0.817099	valid_0's auc: 0.795744
# [60]	training's auc: 0.817175	valid_0's auc: 0.794363
# Early stopping, best iteration is:
# [14]	training's auc: 0.816878	valid_0's auc: 0.79811
# *****
# 0.798110381690343
# ********************
#
#
# sms_day19_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.852865	valid_0's auc: 0.826189
# [40]	training's auc: 0.852946	valid_0's auc: 0.825909
# Early stopping, best iteration is:
# [2]	training's auc: 0.852679	valid_0's auc: 0.827292
# *****
# 0.8272916965609605
# ********************
#
#
# sms_day20_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.807959	valid_0's auc: 0.766336
# [40]	training's auc: 0.808019	valid_0's auc: 0.766147
# Early stopping, best iteration is:
# [2]	training's auc: 0.807732	valid_0's auc: 0.768407
# *****
# 0.7684074113933133
# ********************
#
#
# sms_day21_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.763335	valid_0's auc: 0.734957
# [40]	training's auc: 0.763367	valid_0's auc: 0.734784
# Early stopping, best iteration is:
# [7]	training's auc: 0.76332	valid_0's auc: 0.735057
# *****
# 0.7350573372554646
# ********************
#
#
# sms_day22_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.735239	valid_0's auc: 0.695329
# [40]	training's auc: 0.735248	valid_0's auc: 0.695328
# [60]	training's auc: 0.735251	valid_0's auc: 0.695328
# Early stopping, best iteration is:
# [27]	training's auc: 0.735246	valid_0's auc: 0.69537
# *****
# 0.6953696728368489
# ********************
#
#
# sms_day23_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.773557	valid_0's auc: 0.754412
# [40]	training's auc: 0.774245	valid_0's auc: 0.754661
# [60]	training's auc: 0.774399	valid_0's auc: 0.754672
# Early stopping, best iteration is:
# [25]	training's auc: 0.774084	valid_0's auc: 0.755384
# *****
# 0.7553839623092744
# ********************
#
#
# sms_day24_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.871818	valid_0's auc: 0.847497
# [40]	training's auc: 0.871907	valid_0's auc: 0.846426
# Early stopping, best iteration is:
# [1]	training's auc: 0.870984	valid_0's auc: 0.848279
# *****
# 0.8482789855072463
# ********************
#
#
# sms_day25_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.849237	valid_0's auc: 0.821914
# [40]	training's auc: 0.849334	valid_0's auc: 0.821976
# [60]	training's auc: 0.849396	valid_0's auc: 0.821971
# Early stopping, best iteration is:
# [12]	training's auc: 0.849125	valid_0's auc: 0.822362
# *****
# 0.8223621275170996
# ********************
#
#
# sms_day26_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.879805	valid_0's auc: 0.855449
# [40]	training's auc: 0.879945	valid_0's auc: 0.855068
# [60]	training's auc: 0.879974	valid_0's auc: 0.855391
# Early stopping, best iteration is:
# [26]	training's auc: 0.879862	valid_0's auc: 0.855693
# *****
# 0.8556927703639929
# ********************
#
#
# sms_day27_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.857405	valid_0's auc: 0.855869
# [40]	training's auc: 0.857486	valid_0's auc: 0.855842
# [60]	training's auc: 0.857611	valid_0's auc: 0.855687
# Early stopping, best iteration is:
# [10]	training's auc: 0.857392	valid_0's auc: 0.856289
# *****
# 0.8562891615248481
# ********************
#
#
# sms_day28_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.865299	valid_0's auc: 0.841279
# [40]	training's auc: 0.865472	valid_0's auc: 0.840789
# [60]	training's auc: 0.86562	valid_0's auc: 0.840634
# Early stopping, best iteration is:
# [16]	training's auc: 0.865353	valid_0's auc: 0.841357
# *****
# 0.8413569617831348
# ********************
#
#
# sms_day29_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.725238	valid_0's auc: 0.718702
# [40]	training's auc: 0.725255	valid_0's auc: 0.718757
# [60]	training's auc: 0.725276	valid_0's auc: 0.718722
# [80]	training's auc: 0.725296	valid_0's auc: 0.718698
# Early stopping, best iteration is:
# [37]	training's auc: 0.725243	valid_0's auc: 0.719349
# *****
# 0.7193493805902329
# ********************
#
#
# sms_day30_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.865293	valid_0's auc: 0.848442
# [40]	training's auc: 0.865487	valid_0's auc: 0.848197
# Early stopping, best iteration is:
# [1]	training's auc: 0.864338	valid_0's auc: 0.849708
# *****
# 0.8497079327497967
# ********************
#
#
# sms_day31_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.864014	valid_0's auc: 0.836226
# [40]	training's auc: 0.864117	valid_0's auc: 0.836182
# [60]	training's auc: 0.864243	valid_0's auc: 0.835806
# Early stopping, best iteration is:
# [21]	training's auc: 0.863997	valid_0's auc: 0.836423
# *****
# 0.8364229085952073
# ********************
#
#
# sms_hour10_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.840865	valid_0's auc: 0.802379
# [40]	training's auc: 0.841822	valid_0's auc: 0.803316
# [60]	training's auc: 0.842539	valid_0's auc: 0.803325
# Early stopping, best iteration is:
# [27]	training's auc: 0.841209	valid_0's auc: 0.804532
# *****
# 0.8045316759936864
# ********************
#
#
# sms_hour14_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.822721	valid_0's auc: 0.804301
# [40]	training's auc: 0.824165	valid_0's auc: 0.807316
# [60]	training's auc: 0.82493	valid_0's auc: 0.806279
# [80]	training's auc: 0.825467	valid_0's auc: 0.805047
# [100]	training's auc: 0.82567	valid_0's auc: 0.804476
# Early stopping, best iteration is:
# [52]	training's auc: 0.824797	valid_0's auc: 0.807702
# *****
# 0.8077019658487588
# ********************
#
#
# sms_hour16_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.810264	valid_0's auc: 0.785918
# [40]	training's auc: 0.81141	valid_0's auc: 0.785679
# [60]	training's auc: 0.812159	valid_0's auc: 0.785795
# Early stopping, best iteration is:
# [18]	training's auc: 0.810118	valid_0's auc: 0.786552
# *****
# 0.7865517530013871
# ********************
#
#
# sms_hour18_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.809284	valid_0's auc: 0.78686
# [40]	training's auc: 0.809683	valid_0's auc: 0.785933
# Early stopping, best iteration is:
# [3]	training's auc: 0.808904	valid_0's auc: 0.788417
# *****
# 0.7884171569330846
# ********************
#
#
# sms_hour13_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.840273	valid_0's auc: 0.825337
# [40]	training's auc: 0.840978	valid_0's auc: 0.825447
# [60]	training's auc: 0.841257	valid_0's auc: 0.825302
# [80]	training's auc: 0.84135	valid_0's auc: 0.825257
# Early stopping, best iteration is:
# [37]	training's auc: 0.840963	valid_0's auc: 0.825725
# *****
# 0.8257252355670349
# ********************
#
#
# sms_hour17_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.819973	valid_0's auc: 0.800204
# [40]	training's auc: 0.820346	valid_0's auc: 0.800278
# Early stopping, best iteration is:
# [5]	training's auc: 0.81952	valid_0's auc: 0.802122
# *****
# 0.8021221959152437
# ********************
#
#
# sms_hour11_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.856739	valid_0's auc: 0.820371
# [40]	training's auc: 0.857336	valid_0's auc: 0.82137
# [60]	training's auc: 0.857683	valid_0's auc: 0.821539
# [80]	training's auc: 0.857895	valid_0's auc: 0.821562
# [100]	training's auc: 0.858038	valid_0's auc: 0.821918
# [120]	training's auc: 0.858225	valid_0's auc: 0.821604
# [140]	training's auc: 0.858361	valid_0's auc: 0.821927
# [160]	training's auc: 0.858474	valid_0's auc: 0.822402
# [180]	training's auc: 0.858602	valid_0's auc: 0.823072
# [200]	training's auc: 0.858633	valid_0's auc: 0.822967
# [220]	training's auc: 0.858784	valid_0's auc: 0.821527
# Early stopping, best iteration is:
# [180]	training's auc: 0.858602	valid_0's auc: 0.823072
# *****
# 0.8230721169943082
# ********************
#
#
# sms_hour9_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.824555	valid_0's auc: 0.787942
# [40]	training's auc: 0.82512	valid_0's auc: 0.787507
# [60]	training's auc: 0.825551	valid_0's auc: 0.787017
# Early stopping, best iteration is:
# [18]	training's auc: 0.82451	valid_0's auc: 0.788218
# *****
# 0.7882183598794662
# ********************
#
#
# sms_hour0_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.560302	valid_0's auc: 0.54383
# [40]	training's auc: 0.561164	valid_0's auc: 0.541803
# Early stopping, best iteration is:
# [3]	training's auc: 0.559975	valid_0's auc: 0.544502
# *****
# 0.5445021404314344
# ********************
#
#
# sms_hour20_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.790886	valid_0's auc: 0.75664
# [40]	training's auc: 0.790954	valid_0's auc: 0.756182
# [60]	training's auc: 0.791129	valid_0's auc: 0.756705
# [80]	training's auc: 0.791151	valid_0's auc: 0.756959
# [100]	training's auc: 0.791246	valid_0's auc: 0.758033
# [120]	training's auc: 0.791278	valid_0's auc: 0.757949
# [140]	training's auc: 0.791318	valid_0's auc: 0.75774
# Early stopping, best iteration is:
# [103]	training's auc: 0.791275	valid_0's auc: 0.758036
# *****
# 0.7580355861673124
# ********************
#
#
# sms_hour8_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.758293	valid_0's auc: 0.733125
# [40]	training's auc: 0.759019	valid_0's auc: 0.732993
# Early stopping, best iteration is:
# [2]	training's auc: 0.757752	valid_0's auc: 0.738477
# *****
# 0.7384772444635768
# ********************
#
#
# sms_hour21_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.762414	valid_0's auc: 0.734663
# [40]	training's auc: 0.762514	valid_0's auc: 0.734767
# [60]	training's auc: 0.762612	valid_0's auc: 0.734884
# [80]	training's auc: 0.762637	valid_0's auc: 0.734881
# [100]	training's auc: 0.762713	valid_0's auc: 0.734857
# [120]	training's auc: 0.762755	valid_0's auc: 0.734857
# Early stopping, best iteration is:
# [79]	training's auc: 0.762636	valid_0's auc: 0.73489
# *****
# 0.7348899292103124
# ********************
#
#
# sms_hour15_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.831972	valid_0's auc: 0.814301
# [40]	training's auc: 0.832531	valid_0's auc: 0.813359
# [60]	training's auc: 0.832827	valid_0's auc: 0.811712
# Early stopping, best iteration is:
# [23]	training's auc: 0.832027	valid_0's auc: 0.814395
# *****
# 0.8143952982254747
# ********************
#
#
# sms_hour2_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.531729	valid_0's auc: 0.522104
# [40]	training's auc: 0.531752	valid_0's auc: 0.522116
# Early stopping, best iteration is:
# [1]	training's auc: 0.530025	valid_0's auc: 0.52276
# *****
# 0.5227600205672741
# ********************
#
#
# sms_hour12_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.83786	valid_0's auc: 0.800333
# [40]	training's auc: 0.838225	valid_0's auc: 0.798852
# Early stopping, best iteration is:
# [1]	training's auc: 0.836301	valid_0's auc: 0.803354
# *****
# 0.8033538408188645
# ********************
#
#
# sms_hour3_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.525914	valid_0's auc: 0.49784
# [40]	training's auc: 0.525916	valid_0's auc: 0.497846
# Early stopping, best iteration is:
# [4]	training's auc: 0.525495	valid_0's auc: 0.500293
# *****
# 0.5002929640790166
# ********************
#
#
# sms_hour7_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.649455	valid_0's auc: 0.626466
# [40]	training's auc: 0.649823	valid_0's auc: 0.626239
# [60]	training's auc: 0.650124	valid_0's auc: 0.624496
# [80]	training's auc: 0.65016	valid_0's auc: 0.624182
# Early stopping, best iteration is:
# [32]	training's auc: 0.649554	valid_0's auc: 0.627248
# *****
# 0.6272480508920457
# ********************
#
#
# sms_hour22_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.689531	valid_0's auc: 0.674786
# [40]	training's auc: 0.689565	valid_0's auc: 0.674808
# [60]	training's auc: 0.689569	valid_0's auc: 0.674814
# [80]	training's auc: 0.690063	valid_0's auc: 0.676001
# [100]	training's auc: 0.690065	valid_0's auc: 0.676004
# [120]	training's auc: 0.690068	valid_0's auc: 0.676013
# [140]	training's auc: 0.690071	valid_0's auc: 0.676013
# [160]	training's auc: 0.690071	valid_0's auc: 0.676013
# [180]	training's auc: 0.690074	valid_0's auc: 0.676022
# [200]	training's auc: 0.690074	valid_0's auc: 0.676022
# [220]	training's auc: 0.690076	valid_0's auc: 0.676025
# Early stopping, best iteration is:
# [187]	training's auc: 0.690075	valid_0's auc: 0.676025
# *****
# 0.6760250753336203
# ********************
#
#
# sms_hour19_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.799209	valid_0's auc: 0.781265
# [40]	training's auc: 0.799179	valid_0's auc: 0.780999
# Early stopping, best iteration is:
# [3]	training's auc: 0.799054	valid_0's auc: 0.781999
# *****
# 0.781998852059119
# ********************
#
#
# sms_hour23_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.577381	valid_0's auc: 0.572232
# [40]	training's auc: 0.5779	valid_0's auc: 0.573691
# [60]	training's auc: 0.577917	valid_0's auc: 0.573652
# [80]	training's auc: 0.577946	valid_0's auc: 0.573766
# Early stopping, best iteration is:
# [34]	training's auc: 0.577481	valid_0's auc: 0.577721
# *****
# 0.5777206796766633
# ********************
#
#
# sms_hour6_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.551104	valid_0's auc: 0.556588
# [40]	training's auc: 0.551152	valid_0's auc: 0.55684
# [60]	training's auc: 0.551189	valid_0's auc: 0.556804
# [80]	training's auc: 0.551257	valid_0's auc: 0.556783
# Early stopping, best iteration is:
# [34]	training's auc: 0.553312	valid_0's auc: 0.557689
# *****
# 0.557688513416559
# ********************
#
#
# sms_hour5_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.525606	valid_0's auc: 0.50978
# [40]	training's auc: 0.526744	valid_0's auc: 0.509774
# Early stopping, best iteration is:
# [6]	training's auc: 0.525603	valid_0's auc: 0.50978
# *****
# 0.5097799182092122
# ********************
#
#
# sms_hour4_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.519223	valid_0's auc: 0.509735
# [40]	training's auc: 0.519106	valid_0's auc: 0.513331
# [60]	training's auc: 0.519226	valid_0's auc: 0.509737
# Early stopping, best iteration is:
# [28]	training's auc: 0.519106	valid_0's auc: 0.513331
# *****
# 0.5133313603099441
# ********************
#
#
# sms_hour1_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.525782	valid_0's auc: 0.520192
# [40]	training's auc: 0.525786	valid_0's auc: 0.520223
# [60]	training's auc: 0.525813	valid_0's auc: 0.52124
# [80]	training's auc: 0.525815	valid_0's auc: 0.521234
# Early stopping, best iteration is:
# [30]	training's auc: 0.525806	valid_0's auc: 0.521244
# *****
# 0.5212443798727698
# ********************

# %%
for key, val in useless_cols.items():
    print(key, val)
# Out:
# county_name_arpu_202004_skew 0.5082194360740422
# city_name_county_name_arpu_202004_skew 0.5082194360740422
# voc_hour1_count 0.509878569378677
# voc_hour3_count 0.5081716052039986
# voc_hour2_count 0.5142610728464151
# voc_hour4_count 0.5153566987133495
# voc_hour1_nunique 0.5102911106328024
# voc_hour3_nunique 0.5055244654900273
# voc_hour2_nunique 0.5119278232171043
# voc_hour4_nunique 0.5162086860859999
# voc_hour1_call_dur_sum 0.5041822116994308
# voc_hour3_call_dur_sum 0.5055543597838045
# voc_hour2_call_dur_sum 0.5092597574974889
# voc_hour4_call_dur_sum 0.5162804323910652
# sms_hour3_count 0.5002929640790166
# sms_hour5_count 0.5097799182092122
# sms_hour4_count 0.5133313603099441

# %%
df_train.drop(list(useless_cols.keys()), axis=1, inplace=True)
df_test.drop(list(useless_cols.keys()), axis=1, inplace=True)

# %% [markdown]
# ### 高共线

# %%
def correlation(df, threshold):
    """
    去除特征相关系数大于阈值的特征
    :param df:
    :param threshold:
    :return:
    """
    col_corr = set()
    corr_matrix = df.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold:
                colName_i = corr_matrix.columns[i]
                colName_j = corr_matrix.columns[j]
                if useful_cols[colName_i] >= useful_cols[colName_j]:
                    col_corr.add(colName_j)
                else:
                    col_corr.add(colName_i)

    return col_corr


col = correlation(df_train.drop(['phone_no_m', 'label'], axis=1), 0.98)
print('Correlated columns: ', col)
# Out:
# Correlated columns:  {'county_name_arpu_202004_nunique', 'county_name_idcard_cnt_nunique', 'county_name_idcard_cnt*arpu_202004_nunique', 'city_name_county_name_arpu_202004/idcard_cnt_nunique', 'call_type_id_2_rate', 'county_name_nunique_y', 'city_name_arpu_202004/idcard_cnt_nunique', 'county_name_idcard_cnt_max', 'county_name_arpu_202004/idcard_cnt_skew', 'city_name', 'county_name_nunique_x', 'city_name_county_name_arpu_202004/idcard_cnt_median', 'city_name_idcard_cnt*arpu_202004_nunique', 'county_name_arpu_202004/idcard_cnt_max', 'county_name_idcard_cnt*arpu_202004_median', 'county_name_count', 'city_name_county_name_arpu_202004_nunique', 'county_name_arpu_202004/idcard_cnt_min', 'county_name_arpu_202004_min', 'city_name_arpu_202004_min', 'city_name_idcard_cnt*arpu_202004_max', 'county_name_arpu_202004/idcard_cnt_nunique', 'county_name_arpu_202004_max', 'city_name_arpu_202004_nunique', 'county_name_arpu_202004/idcard_cnt_mean', 'county_name_idcard_cnt*arpu_202004_min', 'voc_calltype_id_1_60s_cnt', 'voc_cnt_per_capita', 'county_name_idcard_cnt_skew', 'county_name_idcard_cnt*arpu_202004_mean', 'voc_day12_count', 'county_name_arpu_202004_mean', 'county_name_idcard_cnt*arpu_202004_max', 'county_name_arpu_202004_median', 'voc_calltype_id_1_30s_cnt'}

# %%
df_train.drop(list(col), axis=1, inplace=True)
df_test.drop(list(col), axis=1, inplace=True)

# %%
feature_names = [i for i in df_train.columns if i not in ['phone_no_m', 'label']]
ycol = 'label'

# %%
oof = []
prediction = df_test[['phone_no_m', 'arpu_202004']]
prediction['label'] = 0
df_importance_list = []

kfold = StratifiedKFold(n_splits=5)
for fold_id, (trn_idx, val_idx) in enumerate(kfold.split(df_train[feature_names], df_train[ycol])):
    print('\nFold_{} Training ================================\n'.format(fold_id+1))
    
    X_train = df_train.iloc[trn_idx][feature_names]
    Y_train = df_train.iloc[trn_idx][ycol]

    X_val = df_train.iloc[val_idx][feature_names]
    Y_val = df_train.iloc[val_idx][ycol]
    
    lgb_train = lgb.Dataset(X_train, Y_train) 
    lgb_valid= lgb.Dataset(X_val, Y_val, reference=lgb_train)
    
    lgb_model = lgb.train(params,
                          lgb_train,
                          num_boost_round=10000,
                          valid_sets=[lgb_valid, lgb_train],
                          early_stopping_rounds=100,
                          verbose_eval=10)

    pred_val = lgb_model.predict(X_val)
    df_oof = df_train.iloc[val_idx][['phone_no_m', ycol]].copy()
    df_oof['pred'] = pred_val
    oof.append(df_oof)

    pred_test = lgb_model.predict(df_test[feature_names])
    prediction['label_{}'.format(fold_id)] = pred_test

    importance = lgb_model.feature_importance(importance_type='gain')
    feature_name = lgb_model.feature_name()
    df_importance = pd.DataFrame({
        'feature_name': feature_name,
        'importance': importance
    })
    df_importance_list.append(df_importance)

    del lgb_model, pred_val, pred_test, X_train, Y_train, X_val, Y_val
    gc.collect()
# Out:
# Fold_1 Training ================================
#
# Training until validation scores don't improve for 100 rounds
# [10]	training's auc: 0.987644	valid_0's auc: 0.944023
# [20]	training's auc: 0.996809	valid_0's auc: 0.949554
# [30]	training's auc: 0.998786	valid_0's auc: 0.952951
# [40]	training's auc: 0.999539	valid_0's auc: 0.953334
# [50]	training's auc: 0.999754	valid_0's auc: 0.954742
# [60]	training's auc: 0.999877	valid_0's auc: 0.954957
# [70]	training's auc: 0.999947	valid_0's auc: 0.956052
# [80]	training's auc: 1	valid_0's auc: 0.955515
# [90]	training's auc: 1	valid_0's auc: 0.955699
# [100]	training's auc: 1	valid_0's auc: 0.955963
# [110]	training's auc: 1	valid_0's auc: 0.956798
# [120]	training's auc: 1	valid_0's auc: 0.956633
# [130]	training's auc: 1	valid_0's auc: 0.956939
# [140]	training's auc: 1	valid_0's auc: 0.957259
# [150]	training's auc: 1	valid_0's auc: 0.956912
# [160]	training's auc: 1	valid_0's auc: 0.957461
# [170]	training's auc: 1	valid_0's auc: 0.957289
# [180]	training's auc: 1	valid_0's auc: 0.957609
# [190]	training's auc: 1	valid_0's auc: 0.957464
# [200]	training's auc: 1	valid_0's auc: 0.957084
# [210]	training's auc: 1	valid_0's auc: 0.957019
# [220]	training's auc: 1	valid_0's auc: 0.956764
# [230]	training's auc: 1	valid_0's auc: 0.956768
# [240]	training's auc: 1	valid_0's auc: 0.9567
# [250]	training's auc: 1	valid_0's auc: 0.956906
# [260]	training's auc: 1	valid_0's auc: 0.956651
# [270]	training's auc: 1	valid_0's auc: 0.956543
# [280]	training's auc: 1	valid_0's auc: 0.956577
# Early stopping, best iteration is:
# [189]	training's auc: 1	valid_0's auc: 0.95763
#
# Fold_2 Training ================================
#
# Training until validation scores don't improve for 100 rounds
# [10]	training's auc: 0.986178	valid_0's auc: 0.952988
# [20]	training's auc: 0.995832	valid_0's auc: 0.952945
# [30]	training's auc: 0.997951	valid_0's auc: 0.958984
# [40]	training's auc: 0.999263	valid_0's auc: 0.959667
# [50]	training's auc: 0.999647	valid_0's auc: 0.959504
# [60]	training's auc: 0.999802	valid_0's auc: 0.960276
# [70]	training's auc: 0.999875	valid_0's auc: 0.961553
# [80]	training's auc: 0.999986	valid_0's auc: 0.962873
# [90]	training's auc: 0.999999	valid_0's auc: 0.962784
# [100]	training's auc: 1	valid_0's auc: 0.962762
# [110]	training's auc: 1	valid_0's auc: 0.962658
# [120]	training's auc: 1	valid_0's auc: 0.962806
# [130]	training's auc: 1	valid_0's auc: 0.962406
# [140]	training's auc: 1	valid_0's auc: 0.962612
# [150]	training's auc: 1	valid_0's auc: 0.962941
# [160]	training's auc: 1	valid_0's auc: 0.962526
# [170]	training's auc: 1	valid_0's auc: 0.962612
# [180]	training's auc: 1	valid_0's auc: 0.962221
# [190]	training's auc: 1	valid_0's auc: 0.962218
# [200]	training's auc: 1	valid_0's auc: 0.961445
# [210]	training's auc: 1	valid_0's auc: 0.961845
# [220]	training's auc: 1	valid_0's auc: 0.961769
# [230]	training's auc: 1	valid_0's auc: 0.961809
# [240]	training's auc: 1	valid_0's auc: 0.961461
# [250]	training's auc: 1	valid_0's auc: 0.961436
# Early stopping, best iteration is:
# [157]	training's auc: 1	valid_0's auc: 0.963119
#
# Fold_3 Training ================================
#
# Training until validation scores don't improve for 100 rounds
# [10]	training's auc: 0.989618	valid_0's auc: 0.946942
# [20]	training's auc: 0.995967	valid_0's auc: 0.95186
# [30]	training's auc: 0.998726	valid_0's auc: 0.957354
# [40]	training's auc: 0.999494	valid_0's auc: 0.957991
# [50]	training's auc: 0.999763	valid_0's auc: 0.958974
# [60]	training's auc: 0.999885	valid_0's auc: 0.961732
# [70]	training's auc: 0.999952	valid_0's auc: 0.961575
# [80]	training's auc: 0.999999	valid_0's auc: 0.962132
# [90]	training's auc: 1	valid_0's auc: 0.962566
# [100]	training's auc: 1	valid_0's auc: 0.963926
# [110]	training's auc: 1	valid_0's auc: 0.964283
# [120]	training's auc: 1	valid_0's auc: 0.964618
# [130]	training's auc: 1	valid_0's auc: 0.965064
# [140]	training's auc: 1	valid_0's auc: 0.965603
# [150]	training's auc: 1	valid_0's auc: 0.96567
# [160]	training's auc: 1	valid_0's auc: 0.965261
# [170]	training's auc: 1	valid_0's auc: 0.965089
# [180]	training's auc: 1	valid_0's auc: 0.96495
# [190]	training's auc: 1	valid_0's auc: 0.965015
# [200]	training's auc: 1	valid_0's auc: 0.965027
# [210]	training's auc: 1	valid_0's auc: 0.964997
# [220]	training's auc: 1	valid_0's auc: 0.965507
# [230]	training's auc: 1	valid_0's auc: 0.965467
# [240]	training's auc: 1	valid_0's auc: 0.965587
# Early stopping, best iteration is:
# [145]	training's auc: 1	valid_0's auc: 0.965978
#
# Fold_4 Training ================================
#
# Training until validation scores don't improve for 100 rounds
# [10]	training's auc: 0.98831	valid_0's auc: 0.943096
# [20]	training's auc: 0.99605	valid_0's auc: 0.948666
# [30]	training's auc: 0.998203	valid_0's auc: 0.951326
# [40]	training's auc: 0.999457	valid_0's auc: 0.955263
# [50]	training's auc: 0.999719	valid_0's auc: 0.954346
# [60]	training's auc: 0.999837	valid_0's auc: 0.9553
# [70]	training's auc: 0.999896	valid_0's auc: 0.956402
# [80]	training's auc: 0.999961	valid_0's auc: 0.955946
# [90]	training's auc: 0.999994	valid_0's auc: 0.955032
# [100]	training's auc: 1	valid_0's auc: 0.954512
# [110]	training's auc: 1	valid_0's auc: 0.953743
# [120]	training's auc: 1	valid_0's auc: 0.952992
# [130]	training's auc: 1	valid_0's auc: 0.953435
# [140]	training's auc: 1	valid_0's auc: 0.954032
# [150]	training's auc: 1	valid_0's auc: 0.953792
# [160]	training's auc: 1	valid_0's auc: 0.953414
# [170]	training's auc: 1	valid_0's auc: 0.953565
# [180]	training's auc: 1	valid_0's auc: 0.953811
# Early stopping, best iteration is:
# [83]	training's auc: 0.999983	valid_0's auc: 0.95667
#
# Fold_5 Training ================================
#
# Training until validation scores don't improve for 100 rounds
# [10]	training's auc: 0.987191	valid_0's auc: 0.946493
# [20]	training's auc: 0.996083	valid_0's auc: 0.956281
# [30]	training's auc: 0.998615	valid_0's auc: 0.956088
# [40]	training's auc: 0.999504	valid_0's auc: 0.953671
# [50]	training's auc: 0.999767	valid_0's auc: 0.955701
# [60]	training's auc: 0.99989	valid_0's auc: 0.954844
# [70]	training's auc: 0.999951	valid_0's auc: 0.954638
# [80]	training's auc: 0.99999	valid_0's auc: 0.952932
# [90]	training's auc: 1	valid_0's auc: 0.953787
# [100]	training's auc: 1	valid_0's auc: 0.953522
# [110]	training's auc: 1	valid_0's auc: 0.952604
# [120]	training's auc: 1	valid_0's auc: 0.953406
# Early stopping, best iteration is:
# [27]	training's auc: 0.998198	valid_0's auc: 0.957106

# %%
df_importance = pd.concat(df_importance_list)
df_importance = df_importance.groupby(['feature_name'])['importance'].agg(
    'mean').sort_values(ascending=False).reset_index()
df_importance.head(20)
# Out:
#                    feature_name    importance
# 0            voc_day_mode_count  22209.141500
# 1        idcard_cnt*arpu_202004   1609.172232
# 2               sms_day31_count   1096.076836
# 3            sms_cnt_per_capita    966.903712
# 4               sms_day30_count    918.881257
# 5               sms_day26_count    833.563315
# 6               sms_day27_count    592.911115
# 7                   sms_nunique    506.756037
# 8               voc_day_nunique    359.870899
# 9            sms_day_mode_count    353.651290
# 10             opposite_nunique    335.087121
# 11                  arpu_202004    319.652302
# 12          call_type_id_1_rate    277.839423
# 13              sms_hour1_count    268.762201
# 14      phone2opposite_cnt_mean    215.515412
# 15              sms_day24_count    213.301659
# 16       voc_day29_call_dur_sum    212.755086
# 17       voc_day30_call_dur_sum    207.297965
# 18              sms_day19_count    199.641759
# 19  phone2opposite_call_dur_min    188.528460

# %%
df_importance.tail(10)
# Out:
#                                 feature_name  importance
# 294               county_name_idcard_cnt_min    2.278900
# 295                       calltype_id_unique    2.200400
# 296                 city_name_idcard_cnt_min    1.143556
# 297  city_name_county_name_idcard_cnt_median    0.940848
# 298                   phone2opposite_cnt_min    0.486505
# 299     city_name_county_name_idcard_cnt_min    0.042024
# 300              city_name_idcard_cnt_median    0.027063
# 301                        voc_hour5_nunique    0.000000
# 302                          voc_hour5_count    0.000000
# 303                   voc_hour5_call_dur_sum    0.000000

# %%
df_importance['normalized_importance'] = df_importance['importance'] / df_importance['importance'].sum()
df_importance['cumulative_importance'] = np.cumsum(df_importance['normalized_importance'])
record_low_importance = df_importance[df_importance['cumulative_importance'] > 0.99]
to_drop = list(record_low_importance['feature_name'])
print(to_drop)
# Out:
# ['voc_hour7_count', 'voc_hour14_count', 'voc_hour_mode_count', 'voc_day3_nunique', 'voc_day14_nunique', 'voc_day2_nunique', 'sms_hour6_count', 'voc_hour20_count', 'voc_calltype_id_1_300s_cnt', 'voc_day9_count', 'voc_day20_count', 'city_name_idcard_cnt*arpu_202004_median', 'sms_day18_count', 'voc_hour19_nunique', 'voc_hour13_nunique', 'voc_day8_count', 'voc_hour19_count', 'voc_day10_nunique', 'voc_hour14_nunique', 'voc_hour17_nunique', 'voc_day18_nunique', 'voc_day6_nunique', 'city_name_arpu_202004/idcard_cnt_min', 'voc_hour21_nunique', 'voc_hour15_nunique', 'city_name_arpu_202004_max', 'voc_day17_nunique', 'voc_day20_nunique', 'city_name_idcard_cnt*arpu_202004_min', 'voc_hour22_nunique', 'call_dur_sum', 'voc_day1_count', 'voc_hour6_nunique', 'city_name_county_name_arpu_202004_min', 'voc_hour0_nunique', 'voc_hour9_count', 'city_name_nunique_y', 'voc_day1_nunique', 'voc_hour0_count', 'voc_hour6_count', 'voc_day16_nunique', 'county_name_idcard_cnt_median', 'city_name_nunique_x', 'city_name_county_name_idcard_cnt_max', 'voc_day15_nunique', 'voc_hour12_nunique', 'voc_day8_nunique', 'voc_day21_nunique', 'city_name_idcard_cnt_max', 'city_name_idcard_cnt_nunique', 'county_name_idcard_cnt_min', 'calltype_id_unique', 'city_name_idcard_cnt_min', 'city_name_county_name_idcard_cnt_median', 'phone2opposite_cnt_min', 'city_name_county_name_idcard_cnt_min', 'city_name_idcard_cnt_median', 'voc_hour5_nunique', 'voc_hour5_count', 'voc_hour5_call_dur_sum']

# %%
df_train.drop(to_drop, axis=1, inplace=True)
df_test.drop(to_drop, axis=1, inplace=True)

# %%
use_cols = [i for i in df_train.columns if i not in ['phone_no_m', 'label']]

# %%
lgb_train_all = lgb.Dataset(df_train[use_cols].values, df_train['label'])   

print('Start training...')

lgb_model = lgb.train(params,
                      lgb_train_all,
                      num_boost_round=100)

print('Done!')
# Out:
# Start training...
# Done!

# %%
df_test['label'] = np.where(lgb_model.predict(df_test[use_cols]) > 0.4735, 1, 0)
# df_test.loc[df_test['arpu_202004'] <= 0, 'label'] = 1
df_test[['phone_no_m', 'label']].to_csv('../sub/sub_{}.csv'.format(time.strftime('%Y%m%d')), index=False)
