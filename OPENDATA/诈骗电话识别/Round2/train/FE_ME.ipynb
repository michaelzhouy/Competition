# %%
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import lightgbm as lgb
import gc
import warnings
from tqdm import tqdm
from sklearn.metrics import f1_score, roc_auc_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold, KFold
from itertools import product
from sklearn.preprocessing import LabelEncoder
from scipy import stats
from feature_selector import FeatureSelector

warnings.filterwarnings('ignore')

pd.set_option('display.unicode.ambiguous_as_wide', True)
pd.set_option('display.unicode.east_asian_width', True)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option("display.max_colwidth", 100)
pd.set_option('display.width', 1000)

# %%
# 节省内存读文件
def reduce_mem_usage(df):
    """
    iterate through all the columns of a dataframe and modify the data type to reduce memory usage.
    @param df:
    @return:
    """
    start_mem = df.memory_usage().sum()
    print('Memory usage of dataframe is {:.2f} MB'.format(start_mem))

    for col in df.columns:
        col_type = df[col].dtype

        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        else:
            df[col] = df[col].astype('str')

    end_mem = df.memory_usage().sum()
    print('Memory usage after optimization is: {:.2f} MB'.format(end_mem))
    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))
    return df

# %%
def count_encode(df, cols):
    for col in tqdm(cols):
        print(col)
        vc = df[col].value_counts(dropna=True, normalize=True)
        df[col + '_count'] = df[col].map(vc).astype('float32')
    return df
        
        
def label_encode(df, cols):
    le = LabelEncoder()
    for col in tqdm(cols):
        df[col] = df[col].fillna('NA')
        df[col] = le.fit_transform(df[col].astype(str))
    return df


def cross_cat_num(df, cat_col, num_col):
    for f1 in tqdm(cat_col):
        g = df.groupby(f1, as_index=False)
        for f2 in tqdm(num_col):
            df_new = g[f2].agg({
                '{}_{}_sum'.format(f1, f2): 'sum',
                '{}_{}_max'.format(f1, f2): 'max',
                '{}_{}_min'.format(f1, f2): 'min',
                '{}_{}_median'.format(f1, f2): 'median',
                '{}_{}_mean'.format(f1, f2): 'mean',
                '{}_{}_skew'.format(f1, f2): 'skew',
                '{}_{}_nunique'.format(f1, f2): 'nunique'
            })
            df = df.merge(df_new, on=f1, how='left')
            del df_new
            gc.collect()
    return df

# %% [markdown]
# ## user表

# %%
train_user = pd.read_hdf('../input/train_user.h5')
test_user = pd.read_hdf('../input/test_user.h5')

# %%
# 将city_name和county_name拼接起来
train_user['city_name_county_name'] = train_user['city_name'].astype(str) + '_' + train_user['county_name'].astype(str)
test_user['city_name_county_name'] = test_user['city_name'].astype(str) + '_' + test_user['county_name'].astype(str)

# %%
cat_feat = ['city_name', 'county_name', 'city_name_county_name']
num_feat = ['idcard_cnt', 'arpu_202005', 'idcard_cnt*arpu_202005', 'arpu_202005/idcard_cnt', 'idcard_cnt/arpu_202005']

# %%
# y = train_user['label']

# %%
# ME = MeanEncoder(categorical_features=cat_feat,
#                  n_splits=3,
#                  target_type='classification',
#                  prior_weight_func=None)
# X_data = ME.fit_transform(train_user.drop('label', axis=1), y)
# X_test = ME.transform(test_user)

# %%
# train_user = X_data.copy()
# train_user['label'] = y
# test_user = X_test.copy()

# train_user.shape, test_user.shape

# %%
df_user = pd.concat([train_user, test_user])

del train_user, test_user
gc.collect()
# Out:
# 0

# %%
# 电话的数量*月消费额
df_user['idcard_cnt*arpu_202005'] = df_user['idcard_cnt'] * df_user['arpu_202005']

# 月消费额/电话的数量
df_user['arpu_202005/idcard_cnt'] = df_user['arpu_202005'] / (df_user['idcard_cnt'] + 0.0001)

# 电话的数量/月消费额
df_user['idcard_cnt/arpu_202005'] = df_user['idcard_cnt'] / (df_user['arpu_202005'] + 0.0001)

# %%
df_user = cross_cat_num(df_user, cat_feat, num_feat)
# Out:
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
#  60%|██████████████████████████████████████████████████▍                                 | 3/5 [00:00<00:00, 22.28it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 20.72it/s]
#  33%|████████████████████████████                                                        | 1/3 [00:00<00:00,  4.09it/s]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
#  40%|█████████████████████████████████▌                                                  | 2/5 [00:00<00:00, 13.02it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 12.66it/s]
#  67%|████████████████████████████████████████████████████████                            | 2/3 [00:00<00:00,  3.42it/s]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
#  20%|████████████████▊                                                                   | 1/5 [00:00<00:00,  9.64it/s]
#  60%|██████████████████████████████████████████████████▍                                 | 3/5 [00:00<00:00, 10.25it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 11.91it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:01<00:00,  2.78it/s]

# %%
df_user = count_encode(df_user, cat_feat + ['idcard_cnt'])
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 300.27it/s]
# city_name
# county_name
# city_name_county_name
# idcard_cnt

# %%
df_user = label_encode(df_user, cat_feat)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 334.24it/s]

# %%
df_user.to_hdf('../input/user_features.h5', 'df', index=False)

del df_user
gc.collect()
# Out:
# 55

# %% [markdown]
# ## voc表

# %%
train_voc = pd.read_hdf('../input/train_voc.h5')
test_voc = pd.read_hdf('../input/test_voc.h5')

# %%
df_voc = pd.concat([train_voc, test_voc])

del train_voc, test_voc
gc.collect()
# Out:
# 128

# %%
df_voc['city_name_county_name'] = df_voc['city_name'] + '_' + df_voc['county_name']

# %%
df_voc['voc_day'] = df_voc['start_datetime'].astype('datetime64').dt.day
df_voc['voc_hour'] = df_voc['start_datetime'].astype('datetime64').dt.hour
# df_voc['voc_dayofweek'] = df_voc['start_datetime'].astype('datetime64').dt.dayofweek

# %%
phone_no_m = df_voc[['phone_no_m']].copy()
phone_no_m = phone_no_m.drop_duplicates(subset=['phone_no_m'], keep='last')

# %%
# 通话次数，通话人数
tmp = df_voc.groupby('phone_no_m')['opposite_no_m'].agg(opposite_cnt='count',
                                                        opposite_nunique='nunique')
phone_no_m = phone_no_m.merge(tmp, how='left', on='phone_no_m')

# 人均通话次数
phone_no_m['voc_cnt_per_capita'] = phone_no_m['opposite_cnt'] / (phone_no_m['opposite_nunique'] + 0.0001)

del tmp
gc.collect()
# Out:
# 0

# %%
"""
主叫通话
"""

df_calltype_id_1 = df_voc.loc[df_voc['calltype_id'] == 1, :].copy()
print('主叫通话的数据量：', df_calltype_id_1.shape[0])

# 主叫通话次数，主叫通话使用的手机个数
tmp = df_calltype_id_1.groupby('phone_no_m')['imei_m'].agg(voc_calltype_id_1_cnt='count',
                                                           imeis='nunique')
# 每个手机的平均主叫通话次数
tmp['voc_calltype_id_1_cnt/imeis'] = tmp['voc_calltype_id_1_cnt'] / tmp['imeis']
phone_no_m = phone_no_m.merge(tmp, on='phone_no_m', how='left')
del tmp
gc.collect()

# 主叫通话时长的统计量
tmp = df_calltype_id_1.groupby('phone_no_m')['call_dur'].agg(voc_calltype_id_1_call_dur_sum='sum',
                                                             voc_calltype_id_1_call_dur_mean='mean',
                                                             voc_calltype_id_1_call_dur_median='median',
                                                             voc_calltype_id_1_call_dur_max='max',
                                                             voc_calltype_id_1_call_dur_min='min',
                                                             voc_calltype_id_1_call_dur_std='std',
                                                             voc_calltype_id_1_call_dur_skew='skew')
phone_no_m = phone_no_m.merge(tmp, on='phone_no_m', how='left')
del tmp
gc.collect()

# 主叫通话时长小于30s的通话时长的统计量
tmp1 = df_calltype_id_1[df_calltype_id_1['call_dur'] < 30]
tmp2 = tmp1.groupby('phone_no_m')['call_dur'].agg(voc_calltype_id_1_30s_cnt='count',
                                                  voc_calltype_id_1_30s_sum='sum',
                                                  voc_calltype_id_1_30s_mean='mean',
                                                  voc_calltype_id_1_30s_median='median',
                                                  voc_calltype_id_1_30s_max='max',
                                                  voc_calltype_id_1_30s_min='min',
                                                  voc_calltype_id_1_30s_std='std',
                                                  voc_calltype_id_1_30s_skew='skew')
phone_no_m = phone_no_m.merge(tmp2, on='phone_no_m', how='left')
del tmp1, tmp2
gc.collect()

# 主叫通话时长小于60s的通话时长的统计量
tmp1 = df_calltype_id_1[df_calltype_id_1['call_dur'] < 60]
tmp2 = tmp1.groupby('phone_no_m')['call_dur'].agg(voc_calltype_id_1_60s_cnt='count',
                                                  voc_calltype_id_1_60s_sum='sum',
                                                  voc_calltype_id_1_60s_mean='mean',
                                                  voc_calltype_id_1_60s_median='median',
                                                  voc_calltype_id_1_60s_max='max',
                                                  voc_calltype_id_1_60s_min='min',
                                                  voc_calltype_id_1_60s_std='std',
                                                  voc_calltype_id_1_60s_skew='skew')
phone_no_m = phone_no_m.merge(tmp2, on='phone_no_m', how='left')
del tmp1, tmp2
gc.collect()

# 主叫通话时长大于300s（5分钟）的通话时长的统计量
tmp1 = df_calltype_id_1[df_calltype_id_1['call_dur'] > 300]
tmp2 = tmp1.groupby('phone_no_m')['call_dur'].agg(voc_calltype_id_1_300s_cnt='count',
                                                  voc_calltype_id_1_300s_sum='sum',
                                                  voc_calltype_id_1_300s_mean='mean',
                                                  voc_calltype_id_1_300s_median='median',
                                                  voc_calltype_id_1_300s_max='max',
                                                  voc_calltype_id_1_300s_min='min',
                                                  voc_calltype_id_1_300s_std='std',
                                                  voc_calltype_id_1_300s_skew='skew')
phone_no_m = phone_no_m.merge(tmp2, on='phone_no_m', how='left')
del tmp1, tmp2
gc.collect()

# 主叫通话时长小于30s的次数的占比
phone_no_m['voc_calltype_id_1_30s_rate'] = phone_no_m['voc_calltype_id_1_30s_cnt'] / phone_no_m['voc_calltype_id_1_cnt']

# 主叫通话时长小于60s的次数的占比
phone_no_m['voc_calltype_id_1_60s_rate'] = phone_no_m['voc_calltype_id_1_60s_cnt'] / phone_no_m['voc_calltype_id_1_cnt']

# 主叫通话时长大于300s（5分钟）的次数的占比
phone_no_m['voc_calltype_id_1_300s_rate'] = phone_no_m['voc_calltype_id_1_300s_cnt'] / phone_no_m['voc_calltype_id_1_cnt']


# 主叫通话次数的占比
phone_no_m["call_type_id_1_rate"] = phone_no_m['voc_calltype_id_1_cnt'] / phone_no_m['opposite_cnt']

# 主叫通话时所在地市变动的个数
tmp = df_calltype_id_1.groupby('phone_no_m')['city_name'].agg(calltype_id_1_city_name_nunique='nunique')
phone_no_m = phone_no_m.merge(tmp, on='phone_no_m', how='left')
del tmp
gc.collect()

# 主叫通话时所在区县变动的个数
tmp = df_calltype_id_1.groupby('phone_no_m')['county_name'].agg(calltype_id_1_county_name_nunique='nunique')
phone_no_m = phone_no_m.merge(tmp, on="phone_no_m", how="left")
del tmp
gc.collect()

# 主叫通话时所在地市_区县变动的个数
tmp = df_calltype_id_1.groupby('phone_no_m')['city_name_county_name'].agg(calltype_id_1_city_name_county_name_nunique='nunique')
phone_no_m = phone_no_m.merge(tmp, on="phone_no_m", how="left")
del tmp
gc.collect()
# Out:
# 主叫通话的数据量： 557812
# 0

# %%
"""
被叫通话
"""

df_calltype_id_2 = df_voc.loc[df_voc['calltype_id'] == 2, :].copy()
print('被叫通话的数据量：', df_calltype_id_2.shape[0])
# 被叫通话的次数
tmp = df_calltype_id_2.groupby('phone_no_m')['imei_m'].agg(voc_calltype_id_2_cnt='count')
phone_no_m = phone_no_m.merge(tmp, on='phone_no_m', how='left')

# 被叫通话次数的占比
phone_no_m["call_type_id_2_rate"] = phone_no_m['voc_calltype_id_2_cnt'] / phone_no_m['opposite_cnt']

del tmp, df_calltype_id_2
gc.collect()
# Out:
# 被叫通话的数据量： 298137
# 20

# %%
"""
呼叫转移
"""

df_calltype_id_3 = df_voc.loc[df_voc['calltype_id'] == 3, :].copy()

# 呼叫转移的次数
tmp = df_calltype_id_3.groupby('phone_no_m')['imei_m'].agg(voc_calltype_id_3_cnt='count')
phone_no_m = phone_no_m.merge(tmp, on='phone_no_m', how='left')

# 呼叫转移次数的占比
phone_no_m['call_type_id_3_rate'] = phone_no_m['voc_calltype_id_3_cnt'] / phone_no_m['opposite_cnt']

del tmp, df_calltype_id_3
gc.collect()
# Out:
# 0

# %%
"""
与对端通话统计
"""

# 与对端通话次数，与对端通话时长
# tmp = df_voc.groupby(['phone_no_m', 'opposite_no_m'])['call_dur'].agg(p2o_call_count='count',
#                                                                       p2o_call_sum='sum',
#                                                                       p2o_call_mean='mean',
#                                                                       p2o_call_median='median',
#                                                                       p2o_call_max='max',
#                                                                       p2o_call_min='min',
#                                                                       p2o_call_std='std')
tmp = df_voc.groupby(['phone_no_m', 'opposite_no_m'])['call_dur'].agg(p2o_call_count='count',
                                                                      p2o_call_sum='sum',
                                                                      p2o_call_mean='mean',
                                                                      p2o_call_median='median',
                                                                      p2o_call_max='max',
                                                                      p2o_call_min='min',
                                                                      p2o_call_std='std')

# 与对端通话次数的统计量
p2o = tmp.groupby('phone_no_m')['p2o_call_count'].agg(p2o_call_count_std='std',
                                                      p2o_call_count_median='median')
phone_no_m = phone_no_m.merge(p2o, on='phone_no_m', how='left')
del p2o
gc.collect()

p2o = tmp.groupby('phone_no_m')['p2o_call_sum'].agg(p2o_call_sum_std='std',
                                                    p2o_call_sum_median='median')
phone_no_m = phone_no_m.merge(p2o, on='phone_no_m', how='left')
del p2o
gc.collect()

p2o = tmp.groupby('phone_no_m')['p2o_call_mean'].agg(p2o_call_mean_std='std',
                                                     p2o_call_mean_median='median')
phone_no_m = phone_no_m.merge(p2o, on='phone_no_m', how='left')
del p2o
gc.collect()

p2o = tmp.groupby('phone_no_m')['p2o_call_median'].agg(p2o_call_median_std='std',
                                                       p2o_call_median_median='median')
phone_no_m = phone_no_m.merge(p2o, on='phone_no_m', how='left')
del p2o
gc.collect()

p2o = tmp.groupby('phone_no_m')['p2o_call_max'].agg(p2o_call_max_std='std',
                                                    p2o_call_max_median='median')
phone_no_m = phone_no_m.merge(p2o, on='phone_no_m', how='left')
del p2o
gc.collect()

p2o = tmp.groupby('phone_no_m')['p2o_call_min'].agg(p2o_call_min_std='std',
                                                    p2o_call_min_median='median')
phone_no_m = phone_no_m.merge(p2o, on='phone_no_m', how='left')
del p2o
gc.collect()

p2o = tmp.groupby('phone_no_m')['p2o_call_std'].agg(p2o_call_std_std='std',
                                                    p2o_call_std_median='median')
phone_no_m = phone_no_m.merge(p2o, on='phone_no_m', how='left')
del p2o
gc.collect()
# Out:
# 0

# %%
"""
通话时长的统计
"""

# 通话时长的统计量
tmp = df_voc.groupby('phone_no_m')['call_dur'].agg(call_dur_mean='mean',
                                                   call_dur_median='median',
                                                   call_dur_max='max',
                                                   call_dur_min='min',
                                                   call_dur_std='std',
                                                   call_dur_sum='sum',
                                                   call_dur_skew='skew')
phone_no_m = phone_no_m.merge(tmp, on='phone_no_m', how='left')
del tmp
gc.collect()
# Out:
# 20

# %%
"""
收费号码位置变动
"""

# 收费号码所在地市的个数
tmp = df_voc.groupby('phone_no_m')['city_name'].agg(city_name_nunique='nunique')
phone_no_m = phone_no_m.merge(tmp, on='phone_no_m', how='left')
del tmp
gc.collect()

# 收费号码所在区县的个数
tmp = df_voc.groupby('phone_no_m')['county_name'].agg(county_name_nunique='nunique')
phone_no_m = phone_no_m.merge(tmp, on="phone_no_m", how='left')
del tmp
gc.collect()

# 收费号码所在地市_区县的个数
tmp = df_voc.groupby('phone_no_m')['city_name_county_name'].agg(city_name_county_name_nunique='nunique')
phone_no_m = phone_no_m.merge(tmp, on="phone_no_m", how='left')
del tmp
gc.collect()

# 收费号码通话类型的个数
tmp = df_voc.groupby('phone_no_m')['calltype_id'].agg(voc_calltype_id_unique='nunique')
phone_no_m = phone_no_m.merge(tmp, on='phone_no_m', how='left')
del tmp
gc.collect()

# 收费号码与对端的通话类型的个数
# tmp = df_voc.groupby(['phone_no_m', 'opposite_no_m'])['calltype_id'].agg(p2o_calltype_id_unique='nunique')
# phone_no_m = phone_no_m.merge(tmp, on='phone_no_m', how='left')
# del tmp
# gc.collect()
# Out:
# 0

# %%
"""
通话时间点的偏好
"""

# hour通话次数最高
tmp = df_voc.groupby('phone_no_m')['voc_hour'].agg(voc_hour_mode=lambda x: stats.mode(x)[0][0],        # 频次最高的元素
                                                   voc_hour_mode_count=lambda x: stats.mode(x)[1][0],  # 频次最高的元素的频次
                                                   voc_hour_nunique='nunique')
phone_no_m = phone_no_m.merge(tmp, on='phone_no_m', how='left')

# day通话次数最高
tmp = df_voc.groupby('phone_no_m')['voc_day'].agg(voc_day_mode=lambda x: stats.mode(x)[0][0],
                                                  voc_day_mode_count=lambda x: stats.mode(x)[1][0],
                                                  voc_day_nunique='nunique')
phone_no_m = phone_no_m.merge(tmp, on='phone_no_m', how='left')

del tmp
gc.collect()
# Out:
# 0

# %%
# 每天的通话次数
voc_day_cnt_res = df_voc.groupby(['phone_no_m', 'voc_day'])['phone_no_m'].count().unstack()
for i in df_voc['voc_day'].unique():
    phone_no_m['voc_day{}_count'.format(i)] = phone_no_m['phone_no_m'].map(voc_day_cnt_res[i])

    
# 每天的通话人数
voc_day_nunique_res = df_voc.groupby(['phone_no_m', 'voc_day'])['opposite_no_m'].nunique().unstack()
for i in df_voc['voc_day'].unique():
    phone_no_m['voc_day{}_nunique'.format(i)] = phone_no_m['phone_no_m'].map(voc_day_nunique_res[i])

    
# 每天的通话时长
voc_day_call_dur_res = df_voc.groupby(['phone_no_m', 'voc_day'])['call_dur'].sum().unstack()
for i in df_voc['voc_day'].unique():
    phone_no_m['voc_day{}_call_dur_sum'.format(i)] = phone_no_m['phone_no_m'].map(voc_day_call_dur_res[i])



# 每小时的通话次数
voc_hour_cnt_res = df_voc.groupby(['phone_no_m', 'voc_hour'])['phone_no_m'].count().unstack()
for i in df_voc['voc_hour'].unique():
    phone_no_m['voc_hour{}_count'.format(i)] = phone_no_m['phone_no_m'].map(voc_hour_cnt_res[i])
    
# 每小时的通话人数
voc_hour_nunique_res = df_voc.groupby(['phone_no_m', 'voc_hour'])['opposite_no_m'].nunique().unstack()
for i in df_voc['voc_hour'].unique():
    phone_no_m['voc_hour{}_nunique'.format(i)] = phone_no_m['phone_no_m'].map(voc_hour_nunique_res[i])
    

# 每小时的通话时长
voc_hour_call_dur_res = df_voc.groupby(['phone_no_m', 'voc_hour'])['call_dur'].sum().unstack()
for i in df_voc['voc_hour'].unique():
    phone_no_m['voc_hour{}_call_dur_sum'.format(i)] = phone_no_m['phone_no_m'].map(voc_hour_call_dur_res[i])

# %%
phone_no_m.to_hdf('../input/voc_features.h5', 'df', index=False)
del phone_no_m
gc.collect()
# Out:
# 75

# %% [markdown]
# ## sms表

# %%
train_sms = pd.read_hdf('../input/train_sms.h5')
test_sms = pd.read_hdf('../input/test_sms.h5')

# %%
df_sms = pd.concat([train_sms, test_sms])

del train_sms, test_sms
gc.collect()
# Out:
# 106

# %%
df_sms['sms_day'] = df_sms['request_datetime'].astype('datetime64').dt.day
df_sms['sms_hour'] = df_sms['request_datetime'].astype('datetime64').dt.hour
# df_sms['sms_dayofweek'] = df_sms['request_datetime'].astype('datetime64').dt.dayofweek

# %%
phone_no_m = df_sms[['phone_no_m']].copy()
phone_no_m = phone_no_m.drop_duplicates(subset=['phone_no_m'], keep='last')

# %%
# 短信次数，短信人数
tmp = df_sms.groupby('phone_no_m')['opposite_no_m'].agg(sms_cnt='count',
                                                        sms_nunique='nunique')

# 人均短信次数
tmp['sms_cnt_per_capita'] = tmp['sms_cnt'] / (tmp['sms_nunique'] + 0.0001)
phone_no_m = phone_no_m.merge(tmp, on='phone_no_m', how='left')

del tmp
gc.collect()
# Out:
# 0

# %%
# 收费号码短信类型的个数
tmp = df_sms.groupby('phone_no_m')['calltype_id'].agg(sms_calltype_id_unique='nunique')
phone_no_m = phone_no_m.merge(tmp, on='phone_no_m', how='left')
del tmp
gc.collect()

# 收费号码与对端的短信类型的个数
# tmp = df_sms.groupby(['phone_no_m', 'opposite_no_m'])['calltype_id'].agg(p2o_calltype_id_unique='nunique')
# phone_no_m = phone_no_m.merge(tmp, on=['phone_no_m', 'opposite_no_m'], how='left')
# del tmp
# gc.collect()
# Out:
# 20

# %%
"""
短信上行，短信下行
"""

# 短信上行
df_sms_calltype1 = df_sms[df_sms['calltype_id'] == 1].copy()
tmp = df_sms_calltype1.groupby('phone_no_m')['calltype_id'].agg(sms_calltype1_cnt='count')
phone_no_m = phone_no_m.merge(tmp, on='phone_no_m', how='left')

# 短信上行比例
phone_no_m['sms_calltype1_rate'] = phone_no_m['sms_calltype1_cnt'] / phone_no_m['sms_cnt']

del tmp, df_sms_calltype1

# 短信下行
df_sms_calltype2 = df_sms[df_sms['calltype_id'] == 2].copy()
tmp = df_sms_calltype2.groupby('phone_no_m')['calltype_id'].agg(sms_calltype2_cnt='count')
phone_no_m = phone_no_m.merge(tmp, on='phone_no_m', how='left')

# 短信上行/短信下行
phone_no_m['type1_rate/type2_rate'] = phone_no_m['sms_calltype1_cnt'] / (phone_no_m['sms_calltype2_cnt'] + 0.00001)

# 删除，效果变差
# # 短信下行/短信上行
# phone_no_m['type2_rate/type1_rate'] = phone_no_m['sms_calltype2_cnt'] / (phone_no_m['sms_calltype1_cnt'] + 0.00001)

del tmp, df_sms_calltype2
gc.collect()
# Out:
# 0

# %%
"""
短信时间点的偏好
"""

tmp = df_sms.groupby('phone_no_m')['sms_hour'].agg(sms_hour_mode=lambda x: stats.mode(x)[0][0],        # 频次最高的元素
                                                   sms_hour_mode_count=lambda x: stats.mode(x)[1][0],  # 频次最高的元素的频次
                                                   sms_hour_nunique='nunique')
phone_no_m = phone_no_m.merge(tmp, on='phone_no_m', how='left')

del tmp

tmp = df_sms.groupby('phone_no_m')['sms_day'].agg(sms_day_mode=lambda x: stats.mode(x)[0][0],
                                                  sms_day_mode_count=lambda x: stats.mode(x)[1][0],
                                                  sms_day_nunique='nunique')
phone_no_m = phone_no_m.merge(tmp, on='phone_no_m', how='left')

del tmp
gc.collect()
# Out:
# 0

# %%
# 每天的短信次数
sms_day_res = df_sms.groupby(['phone_no_m', 'sms_day'])['phone_no_m'].count().unstack()
for i in df_sms['sms_day'].unique():
    phone_no_m['sms_day{}_count'.format(i)] = phone_no_m['phone_no_m'].map(sms_day_res[i])


# 每小时的短信次数
sms_hour_res = df_sms.groupby(['phone_no_m', 'sms_hour'])['phone_no_m'].count().unstack()
for i in df_sms['sms_hour'].unique():
    phone_no_m['sms_hour{}_count'.format(i)] = phone_no_m['phone_no_m'].map(sms_hour_res[i])

# %%
phone_no_m.to_hdf('../input/sms_features.h5', 'df', index=False)

del phone_no_m
gc.collect()
# Out:
# 64

# %% [markdown]
# ## app表

# %%
train_app = pd.read_hdf('../input/train_app.h5')
test_app = pd.read_hdf('../input/test_app.h5')

# %%
df_app = pd.concat([train_app, test_app])

del train_app, test_app
gc.collect()
# Out:
# 117

# %%
phone_no_m = df_app[['phone_no_m']].copy()
phone_no_m = phone_no_m.drop_duplicates(subset=['phone_no_m'], keep='last')

# %%
# APP数
tmp = df_app.groupby('phone_no_m')['busi_name'].agg(busi_cnt='count')
phone_no_m = phone_no_m.merge(tmp, on='phone_no_m', how='left')
del tmp
gc.collect()
# Out:
# 40

# %%
"""
流量统计
"""
tmp = df_app.groupby("phone_no_m")["flow"].agg(flow_mean='mean',
                                               flow_median='median',
                                               flow_min='min',
                                               flow_max='max',
                                               flow_std='std',
                                               flow_sum='sum',
                                               flow_skew='skew')
phone_no_m = phone_no_m.merge(tmp, on='phone_no_m', how='left')

del tmp
gc.collect()
# Out:
# 20

# %%
phone_no_m.to_hdf('../input/app_features.h5', 'df', index=False)

del phone_no_m
gc.collect()
# Out:
# 75

# %% [markdown]
# ## 读取数据，建模

# %%
df_user = reduce_mem_usage(pd.read_hdf('../input/user_features.h5'))
df_voc = reduce_mem_usage(pd.read_hdf('../input/voc_features.h5'))
df_sms = reduce_mem_usage(pd.read_hdf('../input/sms_features.h5'))
# df_app = reduce_mem_usage(pd.read_hdf('../input/app_features.h5'))
# Out:
# Memory usage of dataframe is 6619056.00 MB
# Memory usage after optimization is: 1949448.00 MB
# Decreased by 70.5%
# Memory usage of dataframe is 12088080.00 MB
# Memory usage after optimization is: 3151800.00 MB
# Decreased by 73.9%
# Memory usage of dataframe is 3555112.00 MB
# Memory usage after optimization is: 932591.00 MB
# Decreased by 73.8%

# %%
df_user.shape, df_voc.shape, df_sms.shape #, df_app.shape
# Out:
# ((7556, 119), (6180, 245), (6259, 70))

# %%
df = df_user.merge(df_voc, on='phone_no_m', how='left')
df = df.merge(df_sms, on='phone_no_m', how='left')
# df = df.merge(df_app, on='phone_no_m', how='left')

del df_user, df_voc, df_sms#, df_app
gc.collect()
# Out:
# 0

# %%
df.shape
# Out:
# (7556, 432)

# %%
# astype('category')会掉分，不做此处理
# for i in tqdm(cat_feat):
#     print(i)
#     df[i] = df[i].astype('category')

# %%
df_train = df[df.label.notna()]
df_test = df[df.label.isna()]

df_train.shape, df_test.shape
# Out:
# ((6106, 432), (1450, 432))

# %% [markdown]
# ## 特征筛选

# %% [markdown]
# ### 缺失值

# %%
fs = FeatureSelector(data=df_train.drop(['phone_no_m', 'label'], axis=1), labels=df_train['label'])

# %%
fs.identify_missing(missing_threshold=0.98)
missing_features = fs.ops['missing']
print(missing_features)
# Out:
# 2 features with greater than 0.98 missing values.
#
# ['voc_calltype_id_3_cnt', 'call_type_id_3_rate']

# %%
fs.missing_stats.head(15)
# Out:
#                         missing_fraction
# voc_calltype_id_3_cnt           0.982312
# call_type_id_3_rate             0.982312
# voc_hour3_nunique               0.969211
# voc_hour3_count                 0.969211
# voc_hour3_call_dur_sum          0.969211
# voc_hour4_count                 0.966099
# voc_hour4_call_dur_sum          0.966099
# voc_hour4_nunique               0.966099
# voc_hour2_call_dur_sum          0.959548
# voc_hour2_nunique               0.959548
# voc_hour2_count                 0.959548
# sms_hour4_count                 0.947756
# voc_hour5_nunique               0.945300
# voc_hour5_call_dur_sum          0.945300
# voc_hour5_count                 0.945300

# %%
df_train.drop(missing_features, axis=1, inplace=True)
df_test.drop(missing_features, axis=1, inplace=True)

# %% [markdown]
# ### 唯一值

# %%
fs.identify_single_unique()
# Out:
# 0 features with a single unique value.

# %%
single_unique = fs.ops['single_unique']
print(single_unique)
# Out:
# []

# %%
df_train.drop(single_unique, axis=1, inplace=True)
df_test.drop(single_unique, axis=1, inplace=True)

# %% [markdown]
# ### 单特征AUC

# %%
X_train, X_valid, y_train, y_valid = train_test_split(df_train.drop(['phone_no_m', 'label'], axis=1), df_train['label'],
                                                      test_size=0.2,
                                                      random_state=2020)

# %%
params = {'objective': 'binary',
          'boosting': 'gbdt',
          'metric': 'auc',
          'learning_rate': 0.1,
          'num_leaves': 31,
          'lambda_l1': 0.1,
          'lambda_l2': 0,
          'min_data_in_leaf': 20,
          'is_unbalance': True,
          'max_depth': -1,
          'seed': 2020}

# %%
train_cols = [i for i in df_train.columns if i not in ['phone_no_m', 'label']]

# %%
useful_cols = {}
useless_cols = {}

for i in train_cols:
    print(i)
    
    lgb_train = lgb.Dataset(X_train[[i]].values, y_train) 
    lgb_valid= lgb.Dataset(X_valid[[i]].values, y_valid, reference=lgb_train)
    lgb_test = lgb.train(params,
                         lgb_train,
                         num_boost_round=1000,
                         valid_sets=[lgb_valid, lgb_train],
                         early_stopping_rounds=50,
                         verbose_eval=20)
    
    print('*' * 5)
    print(lgb_test.best_score['valid_0']['auc'])
    if lgb_test.best_score['valid_0']['auc'] > 0.52:
        useful_cols[i] = lgb_test.best_score['valid_0']['auc']
    else:
        useless_cols[i] = lgb_test.best_score['valid_0']['auc']
    print('*' * 20)
    print('\n')
# Out:
# city_name
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.684155	valid_0's auc: 0.671655
# [40]	training's auc: 0.684156	valid_0's auc: 0.672408
# [60]	training's auc: 0.684156	valid_0's auc: 0.672408
# [80]	training's auc: 0.684158	valid_0's auc: 0.671655
# Early stopping, best iteration is:
# [37]	training's auc: 0.684156	valid_0's auc: 0.672408
# *****
# 0.6724078657865786
# ********************
#
#
# county_name
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.767358	valid_0's auc: 0.72344
# [40]	training's auc: 0.772283	valid_0's auc: 0.728765
# [60]	training's auc: 0.77374	valid_0's auc: 0.730307
# [80]	training's auc: 0.774604	valid_0's auc: 0.730896
# [100]	training's auc: 0.775263	valid_0's auc: 0.73182
# [120]	training's auc: 0.775831	valid_0's auc: 0.731191
# [140]	training's auc: 0.776325	valid_0's auc: 0.732008
# Early stopping, best iteration is:
# [90]	training's auc: 0.775065	valid_0's auc: 0.732017
# *****
# 0.7320170875783231
# ********************
#
#
# idcard_cnt
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.728663	valid_0's auc: 0.723062
# [40]	training's auc: 0.728663	valid_0's auc: 0.723062
# Early stopping, best iteration is:
# [1]	training's auc: 0.728663	valid_0's auc: 0.723062
# *****
# 0.7230622518773616
# ********************
#
#
# arpu_202005
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.815215	valid_0's auc: 0.77144
# [40]	training's auc: 0.820254	valid_0's auc: 0.766022
# Early stopping, best iteration is:
# [1]	training's auc: 0.800048	valid_0's auc: 0.773108
# *****
# 0.7731082890897786
# ********************
#
#
# city_name_county_name
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.765288	valid_0's auc: 0.734962
# [40]	training's auc: 0.770757	valid_0's auc: 0.735027
# [60]	training's auc: 0.773065	valid_0's auc: 0.735202
# Early stopping, best iteration is:
# [19]	training's auc: 0.765089	valid_0's auc: 0.735829
# *****
# 0.7358286100349165
# ********************
#
#
# idcard_cnt*arpu_202005
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.835521	valid_0's auc: 0.810472
# [40]	training's auc: 0.83969	valid_0's auc: 0.808623
# Early stopping, best iteration is:
# [5]	training's auc: 0.82961	valid_0's auc: 0.811889
# *****
# 0.8118886616922562
# ********************
#
#
# arpu_202005/idcard_cnt
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.815451	valid_0's auc: 0.761859
# [40]	training's auc: 0.822443	valid_0's auc: 0.763062
# Early stopping, best iteration is:
# [5]	training's auc: 0.802909	valid_0's auc: 0.766286
# *****
# 0.7662864112498207
# ********************
#
#
# idcard_cnt/arpu_202005
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.813254	valid_0's auc: 0.766279
# [40]	training's auc: 0.82041	valid_0's auc: 0.762719
# [60]	training's auc: 0.823821	valid_0's auc: 0.762012
# Early stopping, best iteration is:
# [15]	training's auc: 0.810613	valid_0's auc: 0.768034
# *****
# 0.7680337327210982
# ********************
#
#
# city_name_idcard_cnt_sum
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.684054	valid_0's auc: 0.671828
# [40]	training's auc: 0.684058	valid_0's auc: 0.671655
# Early stopping, best iteration is:
# [1]	training's auc: 0.684054	valid_0's auc: 0.671828
# *****
# 0.6718279164873009
# ********************
#
#
# city_name_idcard_cnt_max
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.615108	valid_0's auc: 0.635379
# [40]	training's auc: 0.615108	valid_0's auc: 0.635379
# Early stopping, best iteration is:
# [1]	training's auc: 0.615108	valid_0's auc: 0.635379
# *****
# 0.6353792987994452
# ********************
#
#
# city_name_idcard_cnt_min
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.585968	valid_0's auc: 0.574084
# [40]	training's auc: 0.585968	valid_0's auc: 0.574084
# Early stopping, best iteration is:
# [1]	training's auc: 0.585968	valid_0's auc: 0.574084
# *****
# 0.5740840388386664
# ********************
#
#
# city_name_idcard_cnt_median
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.542851	valid_0's auc: 0.538564
# [40]	training's auc: 0.542851	valid_0's auc: 0.538564
# Early stopping, best iteration is:
# [1]	training's auc: 0.542851	valid_0's auc: 0.538564
# *****
# 0.538563638972593
# ********************
#
#
# city_name_idcard_cnt_mean
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.68385	valid_0's auc: 0.672031
# [40]	training's auc: 0.683851	valid_0's auc: 0.671655
# [60]	training's auc: 0.683851	valid_0's auc: 0.671655
# Early stopping, best iteration is:
# [18]	training's auc: 0.68385	valid_0's auc: 0.672031
# *****
# 0.6720311976849859
# ********************
#
#
# city_name_idcard_cnt_skew
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.684159	valid_0's auc: 0.671451
# [40]	training's auc: 0.68417	valid_0's auc: 0.671655
# Early stopping, best iteration is:
# [6]	training's auc: 0.684056	valid_0's auc: 0.672339
# *****
# 0.6723391089108911
# ********************
#
#
# city_name_idcard_cnt_nunique
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.643669	valid_0's auc: 0.649836
# [40]	training's auc: 0.643669	valid_0's auc: 0.649836
# Early stopping, best iteration is:
# [1]	training's auc: 0.643669	valid_0's auc: 0.649836
# *****
# 0.649836179270101
# ********************
#
#
# city_name_arpu_202005_sum
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.684043	valid_0's auc: 0.671625
# [40]	training's auc: 0.684058	valid_0's auc: 0.671655
# [60]	training's auc: 0.684058	valid_0's auc: 0.671655
# Early stopping, best iteration is:
# [25]	training's auc: 0.684054	valid_0's auc: 0.671828
# *****
# 0.6718279164873009
# ********************
#
#
# city_name_arpu_202005_max
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.684056	valid_0's auc: 0.671601
# [40]	training's auc: 0.684058	valid_0's auc: 0.671655
# [60]	training's auc: 0.684058	valid_0's auc: 0.671655
# [80]	training's auc: 0.684058	valid_0's auc: 0.671655
# Early stopping, best iteration is:
# [35]	training's auc: 0.684058	valid_0's auc: 0.671655
# *****
# 0.6716545295833931
# ********************
#
#
# city_name_arpu_202005_min
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.532358	valid_0's auc: 0.526888
# [40]	training's auc: 0.532358	valid_0's auc: 0.526888
# Early stopping, best iteration is:
# [1]	training's auc: 0.532358	valid_0's auc: 0.526888
# *****
# 0.5268884225379059
# ********************
#
#
# city_name_arpu_202005_median
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.669618	valid_0's auc: 0.659449
# [40]	training's auc: 0.66962	valid_0's auc: 0.659502
# [60]	training's auc: 0.66962	valid_0's auc: 0.659502
# [80]	training's auc: 0.66962	valid_0's auc: 0.659502
# Early stopping, best iteration is:
# [34]	training's auc: 0.66962	valid_0's auc: 0.659502
# *****
# 0.6595024991629598
# ********************
#
#
# city_name_arpu_202005_mean
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.68417	valid_0's auc: 0.671655
# [40]	training's auc: 0.68417	valid_0's auc: 0.671655
# Early stopping, best iteration is:
# [8]	training's auc: 0.684166	valid_0's auc: 0.671655
# *****
# 0.6716545295833931
# ********************
#
#
# city_name_arpu_202005_skew
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.684166	valid_0's auc: 0.671601
# [40]	training's auc: 0.68417	valid_0's auc: 0.671655
# [60]	training's auc: 0.68417	valid_0's auc: 0.671655
# [80]	training's auc: 0.684165	valid_0's auc: 0.672408
# [100]	training's auc: 0.684165	valid_0's auc: 0.672408
# [120]	training's auc: 0.684165	valid_0's auc: 0.672408
# Early stopping, best iteration is:
# [71]	training's auc: 0.684165	valid_0's auc: 0.672408
# *****
# 0.6724078657865786
# ********************
#
#
# city_name_arpu_202005_nunique
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.684058	valid_0's auc: 0.671655
# [40]	training's auc: 0.684058	valid_0's auc: 0.671655
# Early stopping, best iteration is:
# [1]	training's auc: 0.684058	valid_0's auc: 0.671655
# *****
# 0.6716545295833931
# ********************
#
#
# city_name_idcard_cnt*arpu_202005_sum
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.684054	valid_0's auc: 0.671828
# [40]	training's auc: 0.684058	valid_0's auc: 0.671655
# Early stopping, best iteration is:
# [1]	training's auc: 0.684054	valid_0's auc: 0.671828
# *****
# 0.6718279164873009
# ********************
#
#
# city_name_idcard_cnt*arpu_202005_max
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.684055	valid_0's auc: 0.671668
# [40]	training's auc: 0.684058	valid_0's auc: 0.671655
# Early stopping, best iteration is:
# [1]	training's auc: 0.684055	valid_0's auc: 0.671668
# *****
# 0.6716679820155929
# ********************
#
#
# city_name_idcard_cnt*arpu_202005_min
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.545636	valid_0's auc: 0.519147
# [40]	training's auc: 0.54568	valid_0's auc: 0.51892
# Early stopping, best iteration is:
# [1]	training's auc: 0.545636	valid_0's auc: 0.519147
# *****
# 0.519147295164299
# ********************
#
#
# city_name_idcard_cnt*arpu_202005_median
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.683595	valid_0's auc: 0.671805
# [40]	training's auc: 0.683599	valid_0's auc: 0.671805
# Early stopping, best iteration is:
# [1]	training's auc: 0.683595	valid_0's auc: 0.671805
# *****
# 0.671805495766968
# ********************
#
#
# city_name_idcard_cnt*arpu_202005_mean
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.684069	valid_0's auc: 0.67156
# [40]	training's auc: 0.684073	valid_0's auc: 0.671655
# [60]	training's auc: 0.684073	valid_0's auc: 0.671655
# Early stopping, best iteration is:
# [26]	training's auc: 0.684073	valid_0's auc: 0.671655
# *****
# 0.6716545295833931
# ********************
#
#
# city_name_idcard_cnt*arpu_202005_skew
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.684164	valid_0's auc: 0.671774
# [40]	training's auc: 0.684169	valid_0's auc: 0.671655
# Early stopping, best iteration is:
# [1]	training's auc: 0.684164	valid_0's auc: 0.671774
# *****
# 0.6717741067585019
# ********************
#
#
# city_name_idcard_cnt*arpu_202005_nunique
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.679384	valid_0's auc: 0.672382
# [40]	training's auc: 0.679384	valid_0's auc: 0.672382
# Early stopping, best iteration is:
# [1]	training's auc: 0.679384	valid_0's auc: 0.672382
# *****
# 0.672382455636868
# ********************
#
#
# city_name_arpu_202005/idcard_cnt_sum
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.684058	valid_0's auc: 0.671655
# [40]	training's auc: 0.684058	valid_0's auc: 0.671655
# Early stopping, best iteration is:
# [1]	training's auc: 0.684058	valid_0's auc: 0.671655
# *****
# 0.6716545295833931
# ********************
#
#
# city_name_arpu_202005/idcard_cnt_max
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.684169	valid_0's auc: 0.671601
# [40]	training's auc: 0.68417	valid_0's auc: 0.671655
# [60]	training's auc: 0.68417	valid_0's auc: 0.671655
# [80]	training's auc: 0.68417	valid_0's auc: 0.671655
# Early stopping, best iteration is:
# [36]	training's auc: 0.68417	valid_0's auc: 0.671655
# *****
# 0.6716545295833931
# ********************
#
#
# city_name_arpu_202005/idcard_cnt_min
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.568765	valid_0's auc: 0.555852
# [40]	training's auc: 0.568765	valid_0's auc: 0.555852
# Early stopping, best iteration is:
# [7]	training's auc: 0.568765	valid_0's auc: 0.555852
# *****
# 0.5558515090639499
# ********************
#
#
# city_name_arpu_202005/idcard_cnt_median
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.683392	valid_0's auc: 0.67093
# [40]	training's auc: 0.683393	valid_0's auc: 0.670553
# Early stopping, best iteration is:
# [1]	training's auc: 0.683392	valid_0's auc: 0.67093
# *****
# 0.6709295929592959
# ********************
#
#
# city_name_arpu_202005/idcard_cnt_mean
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.684163	valid_0's auc: 0.671655
# [40]	training's auc: 0.68417	valid_0's auc: 0.671655
# Early stopping, best iteration is:
# [1]	training's auc: 0.684163	valid_0's auc: 0.671655
# *****
# 0.6716545295833931
# ********************
#
#
# city_name_arpu_202005/idcard_cnt_skew
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.68417	valid_0's auc: 0.671655
# [40]	training's auc: 0.68417	valid_0's auc: 0.671655
# Early stopping, best iteration is:
# [1]	training's auc: 0.68416	valid_0's auc: 0.671668
# *****
# 0.6716679820155929
# ********************
#
#
# city_name_arpu_202005/idcard_cnt_nunique
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.684054	valid_0's auc: 0.671828
# [40]	training's auc: 0.684058	valid_0's auc: 0.671655
# Early stopping, best iteration is:
# [6]	training's auc: 0.684049	valid_0's auc: 0.671855
# *****
# 0.6718548213517004
# ********************
#
#
# city_name_idcard_cnt/arpu_202005_sum
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.684058	valid_0's auc: 0.671655
# [40]	training's auc: 0.684058	valid_0's auc: 0.671655
# Early stopping, best iteration is:
# [1]	training's auc: 0.684058	valid_0's auc: 0.671655
# *****
# 0.6716545295833931
# ********************
#
#
# city_name_idcard_cnt/arpu_202005_max
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.552688	valid_0's auc: 0.530402
# [40]	training's auc: 0.552688	valid_0's auc: 0.530402
# Early stopping, best iteration is:
# [1]	training's auc: 0.552688	valid_0's auc: 0.530402
# *****
# 0.5304024967714163
# ********************
#
#
# city_name_idcard_cnt/arpu_202005_min
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.636249	valid_0's auc: 0.626356
# [40]	training's auc: 0.63625	valid_0's auc: 0.62641
# [60]	training's auc: 0.63625	valid_0's auc: 0.62641
# [80]	training's auc: 0.63625	valid_0's auc: 0.62641
# Early stopping, best iteration is:
# [36]	training's auc: 0.63625	valid_0's auc: 0.62641
# *****
# 0.6264095159515951
# ********************
#
#
# city_name_idcard_cnt/arpu_202005_median
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.683999	valid_0's auc: 0.671211
# [40]	training's auc: 0.683999	valid_0's auc: 0.671211
# Early stopping, best iteration is:
# [1]	training's auc: 0.683999	valid_0's auc: 0.671211
# *****
# 0.6712105993208016
# ********************
#
#
# city_name_idcard_cnt/arpu_202005_mean
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.683481	valid_0's auc: 0.670093
# [40]	training's auc: 0.683481	valid_0's auc: 0.670093
# Early stopping, best iteration is:
# [1]	training's auc: 0.683481	valid_0's auc: 0.670093
# *****
# 0.6700925527335342
# ********************
#
#
# city_name_idcard_cnt/arpu_202005_skew
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.684118	valid_0's auc: 0.671655
# [40]	training's auc: 0.684118	valid_0's auc: 0.671655
# [60]	training's auc: 0.684115	valid_0's auc: 0.672408
# [80]	training's auc: 0.684118	valid_0's auc: 0.671655
# Early stopping, best iteration is:
# [44]	training's auc: 0.684115	valid_0's auc: 0.672408
# *****
# 0.6724078657865786
# ********************
#
#
# city_name_idcard_cnt/arpu_202005_nunique
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.684054	valid_0's auc: 0.671828
# [40]	training's auc: 0.684058	valid_0's auc: 0.671655
# Early stopping, best iteration is:
# [6]	training's auc: 0.684049	valid_0's auc: 0.671855
# *****
# 0.6718548213517004
# ********************
#
#
# county_name_idcard_cnt_sum
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.756037	valid_0's auc: 0.721887
# [40]	training's auc: 0.758793	valid_0's auc: 0.720624
# Early stopping, best iteration is:
# [4]	training's auc: 0.748563	valid_0's auc: 0.72521
# *****
# 0.7252101568852537
# ********************
#
#
# county_name_idcard_cnt_max
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.62448	valid_0's auc: 0.631506
# [40]	training's auc: 0.624482	valid_0's auc: 0.631542
# [60]	training's auc: 0.624482	valid_0's auc: 0.631542
# Early stopping, best iteration is:
# [26]	training's auc: 0.624482	valid_0's auc: 0.631542
# *****
# 0.6315423661931411
# ********************
#
#
# county_name_idcard_cnt_min
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.612673	valid_0's auc: 0.595793
# [40]	training's auc: 0.612673	valid_0's auc: 0.595793
# Early stopping, best iteration is:
# [1]	training's auc: 0.612673	valid_0's auc: 0.595793
# *****
# 0.5957932749796718
# ********************
#
#
# county_name_idcard_cnt_median
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.574299	valid_0's auc: 0.567609
# [40]	training's auc: 0.574723	valid_0's auc: 0.565202
# Early stopping, best iteration is:
# [1]	training's auc: 0.574299	valid_0's auc: 0.567609
# *****
# 0.5676089348065241
# ********************
#
#
# county_name_idcard_cnt_mean
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.761347	valid_0's auc: 0.724206
# [40]	training's auc: 0.764948	valid_0's auc: 0.726244
# [60]	training's auc: 0.76706	valid_0's auc: 0.72767
# [80]	training's auc: 0.768275	valid_0's auc: 0.728908
# [100]	training's auc: 0.769326	valid_0's auc: 0.728555
# [120]	training's auc: 0.769897	valid_0's auc: 0.728806
# [140]	training's auc: 0.770367	valid_0's auc: 0.728585
# [160]	training's auc: 0.77066	valid_0's auc: 0.728794
# Early stopping, best iteration is:
# [127]	training's auc: 0.770092	valid_0's auc: 0.729207
# *****
# 0.7292070239632659
# ********************
#
#
# county_name_idcard_cnt_skew
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.761966	valid_0's auc: 0.728893
# [40]	training's auc: 0.766633	valid_0's auc: 0.73244
# [60]	training's auc: 0.768493	valid_0's auc: 0.732752
# [80]	training's auc: 0.769663	valid_0's auc: 0.733165
# [100]	training's auc: 0.771072	valid_0's auc: 0.733606
# [120]	training's auc: 0.7721	valid_0's auc: 0.733404
# [140]	training's auc: 0.772639	valid_0's auc: 0.733494
# Early stopping, best iteration is:
# [95]	training's auc: 0.770771	valid_0's auc: 0.733954
# *****
# 0.7339542378150858
# ********************
#
#
# county_name_idcard_cnt_nunique
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.653195	valid_0's auc: 0.644757
# [40]	training's auc: 0.653195	valid_0's auc: 0.644757
# Early stopping, best iteration is:
# [1]	training's auc: 0.653195	valid_0's auc: 0.644757
# *****
# 0.644757138757354
# ********************
#
#
# county_name_arpu_202005_sum
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.766114	valid_0's auc: 0.735978
# [40]	training's auc: 0.771123	valid_0's auc: 0.737413
# [60]	training's auc: 0.773547	valid_0's auc: 0.738124
# Early stopping, best iteration is:
# [11]	training's auc: 0.760558	valid_0's auc: 0.740334
# *****
# 0.7403336801071412
# ********************
#
#
# county_name_arpu_202005_max
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.762403	valid_0's auc: 0.725993
# [40]	training's auc: 0.766583	valid_0's auc: 0.730643
# [60]	training's auc: 0.768532	valid_0's auc: 0.73157
# [80]	training's auc: 0.769238	valid_0's auc: 0.731437
# [100]	training's auc: 0.769854	valid_0's auc: 0.73083
# Early stopping, best iteration is:
# [64]	training's auc: 0.768716	valid_0's auc: 0.731877
# *****
# 0.7318765843975702
# ********************
#
#
# county_name_arpu_202005_min
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.545583	valid_0's auc: 0.534266
# [40]	training's auc: 0.545596	valid_0's auc: 0.534338
# [60]	training's auc: 0.545674	valid_0's auc: 0.534227
# [80]	training's auc: 0.545694	valid_0's auc: 0.534296
# Early stopping, best iteration is:
# [36]	training's auc: 0.54559	valid_0's auc: 0.534386
# *****
# 0.5343859114172287
# ********************
#
#
# county_name_arpu_202005_median
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.757943	valid_0's auc: 0.721974
# [40]	training's auc: 0.7623	valid_0's auc: 0.723183
# [60]	training's auc: 0.764528	valid_0's auc: 0.724443
# [80]	training's auc: 0.766058	valid_0's auc: 0.725611
# [100]	training's auc: 0.766866	valid_0's auc: 0.726657
# [120]	training's auc: 0.76768	valid_0's auc: 0.727224
# [140]	training's auc: 0.76819	valid_0's auc: 0.727137
# [160]	training's auc: 0.768535	valid_0's auc: 0.727358
# [180]	training's auc: 0.768846	valid_0's auc: 0.728032
# [200]	training's auc: 0.769136	valid_0's auc: 0.728382
# [220]	training's auc: 0.769317	valid_0's auc: 0.728633
# [240]	training's auc: 0.769405	valid_0's auc: 0.72907
# [260]	training's auc: 0.769549	valid_0's auc: 0.729028
# [280]	training's auc: 0.769681	valid_0's auc: 0.728914
# Early stopping, best iteration is:
# [236]	training's auc: 0.76939	valid_0's auc: 0.729189
# *****
# 0.7291890873869996
# ********************
#
#
# county_name_arpu_202005_mean
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.762395	valid_0's auc: 0.7224
# [40]	training's auc: 0.767479	valid_0's auc: 0.725545
# [60]	training's auc: 0.770352	valid_0's auc: 0.726097
# [80]	training's auc: 0.771637	valid_0's auc: 0.725425
# Early stopping, best iteration is:
# [42]	training's auc: 0.76789	valid_0's auc: 0.726585
# *****
# 0.7265852943990051
# ********************
#
#
# county_name_arpu_202005_skew
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.764733	valid_0's auc: 0.732404
# [40]	training's auc: 0.769374	valid_0's auc: 0.733902
# [60]	training's auc: 0.771069	valid_0's auc: 0.734181
# [80]	training's auc: 0.772336	valid_0's auc: 0.733442
# [100]	training's auc: 0.773078	valid_0's auc: 0.733007
# Early stopping, best iteration is:
# [59]	training's auc: 0.771047	valid_0's auc: 0.734232
# *****
# 0.7342322547472139
# ********************
#
#
# county_name_arpu_202005_nunique
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.729773	valid_0's auc: 0.709193
# [40]	training's auc: 0.730804	valid_0's auc: 0.708384
# [60]	training's auc: 0.730987	valid_0's auc: 0.706719
# Early stopping, best iteration is:
# [27]	training's auc: 0.730238	valid_0's auc: 0.709695
# *****
# 0.7096950184148849
# ********************
#
#
# county_name_idcard_cnt*arpu_202005_sum
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.766062	valid_0's auc: 0.726327
# [40]	training's auc: 0.7697	valid_0's auc: 0.72928
# [60]	training's auc: 0.7721	valid_0's auc: 0.730901
# [80]	training's auc: 0.773807	valid_0's auc: 0.732808
# [100]	training's auc: 0.774751	valid_0's auc: 0.732933
# [120]	training's auc: 0.775567	valid_0's auc: 0.732809
# [140]	training's auc: 0.77596	valid_0's auc: 0.733222
# [160]	training's auc: 0.776337	valid_0's auc: 0.733237
# [180]	training's auc: 0.776556	valid_0's auc: 0.732872
# [200]	training's auc: 0.776669	valid_0's auc: 0.732799
# [220]	training's auc: 0.776838	valid_0's auc: 0.731938
# Early stopping, best iteration is:
# [171]	training's auc: 0.776451	valid_0's auc: 0.733479
# *****
# 0.7334789185440284
# ********************
#
#
# county_name_idcard_cnt*arpu_202005_max
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.761149	valid_0's auc: 0.723198
# [40]	training's auc: 0.766728	valid_0's auc: 0.72498
# [60]	training's auc: 0.769603	valid_0's auc: 0.726714
# [80]	training's auc: 0.770709	valid_0's auc: 0.726916
# [100]	training's auc: 0.771411	valid_0's auc: 0.726582
# [120]	training's auc: 0.772145	valid_0's auc: 0.727651
# [140]	training's auc: 0.772687	valid_0's auc: 0.728706
# [160]	training's auc: 0.772961	valid_0's auc: 0.728588
# [180]	training's auc: 0.77325	valid_0's auc: 0.728865
# [200]	training's auc: 0.773514	valid_0's auc: 0.729002
# [220]	training's auc: 0.773705	valid_0's auc: 0.728904
# [240]	training's auc: 0.773816	valid_0's auc: 0.729062
# [260]	training's auc: 0.773938	valid_0's auc: 0.728225
# Early stopping, best iteration is:
# [227]	training's auc: 0.773736	valid_0's auc: 0.729352
# *****
# 0.7293520112880854
# ********************
#
#
# county_name_idcard_cnt*arpu_202005_min
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.603842	valid_0's auc: 0.562927
# [40]	training's auc: 0.604164	valid_0's auc: 0.562989
# [60]	training's auc: 0.604212	valid_0's auc: 0.563158
# [80]	training's auc: 0.604392	valid_0's auc: 0.564838
# [100]	training's auc: 0.604413	valid_0's auc: 0.564927
# [120]	training's auc: 0.604428	valid_0's auc: 0.564924
# [140]	training's auc: 0.604429	valid_0's auc: 0.564912
# Early stopping, best iteration is:
# [109]	training's auc: 0.604419	valid_0's auc: 0.564945
# *****
# 0.5649453532309753
# ********************
#
#
# county_name_idcard_cnt*arpu_202005_median
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.757325	valid_0's auc: 0.707002
# [40]	training's auc: 0.762164	valid_0's auc: 0.71198
# [60]	training's auc: 0.763476	valid_0's auc: 0.713309
# [80]	training's auc: 0.764425	valid_0's auc: 0.714179
# [100]	training's auc: 0.764957	valid_0's auc: 0.714608
# [120]	training's auc: 0.76549	valid_0's auc: 0.71529
# [140]	training's auc: 0.765742	valid_0's auc: 0.71598
# [160]	training's auc: 0.766007	valid_0's auc: 0.715897
# [180]	training's auc: 0.76614	valid_0's auc: 0.715947
# [200]	training's auc: 0.766271	valid_0's auc: 0.716004
# [220]	training's auc: 0.766357	valid_0's auc: 0.716248
# [240]	training's auc: 0.766417	valid_0's auc: 0.716236
# [260]	training's auc: 0.766477	valid_0's auc: 0.716358
# [280]	training's auc: 0.766533	valid_0's auc: 0.716335
# Early stopping, best iteration is:
# [232]	training's auc: 0.766393	valid_0's auc: 0.716439
# *****
# 0.7164391710910222
# ********************
#
#
# county_name_idcard_cnt*arpu_202005_mean
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.7615	valid_0's auc: 0.726962
# [40]	training's auc: 0.766494	valid_0's auc: 0.728113
# [60]	training's auc: 0.768192	valid_0's auc: 0.726445
# Early stopping, best iteration is:
# [28]	training's auc: 0.764349	valid_0's auc: 0.729368
# *****
# 0.7293684531496628
# ********************
#
#
# county_name_idcard_cnt*arpu_202005_skew
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.764195	valid_0's auc: 0.725488
# [40]	training's auc: 0.769747	valid_0's auc: 0.729942
# [60]	training's auc: 0.771882	valid_0's auc: 0.731578
# [80]	training's auc: 0.773447	valid_0's auc: 0.732362
# [100]	training's auc: 0.774523	valid_0's auc: 0.733655
# [120]	training's auc: 0.775683	valid_0's auc: 0.73298
# [140]	training's auc: 0.776268	valid_0's auc: 0.73332
# Early stopping, best iteration is:
# [103]	training's auc: 0.77472	valid_0's auc: 0.733703
# *****
# 0.7337031257473573
# ********************
#
#
# county_name_idcard_cnt*arpu_202005_nunique
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.735076	valid_0's auc: 0.713442
# [40]	training's auc: 0.735803	valid_0's auc: 0.714124
# [60]	training's auc: 0.736148	valid_0's auc: 0.714234
# Early stopping, best iteration is:
# [27]	training's auc: 0.735444	valid_0's auc: 0.714729
# *****
# 0.714729217486966
# ********************
#
#
# county_name_arpu_202005/idcard_cnt_sum
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.766717	valid_0's auc: 0.73062
# [40]	training's auc: 0.771556	valid_0's auc: 0.732805
# [60]	training's auc: 0.774149	valid_0's auc: 0.733596
# [80]	training's auc: 0.775832	valid_0's auc: 0.734376
# [100]	training's auc: 0.776737	valid_0's auc: 0.735017
# [120]	training's auc: 0.777338	valid_0's auc: 0.735249
# [140]	training's auc: 0.777728	valid_0's auc: 0.73509
# Early stopping, best iteration is:
# [106]	training's auc: 0.776927	valid_0's auc: 0.735657
# *****
# 0.7356567178456976
# ********************
#
#
# county_name_arpu_202005/idcard_cnt_max
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.763782	valid_0's auc: 0.718793
# [40]	training's auc: 0.767744	valid_0's auc: 0.725216
# [60]	training's auc: 0.770082	valid_0's auc: 0.727079
# [80]	training's auc: 0.771836	valid_0's auc: 0.728925
# [100]	training's auc: 0.772953	valid_0's auc: 0.728542
# [120]	training's auc: 0.773525	valid_0's auc: 0.729446
# [140]	training's auc: 0.774325	valid_0's auc: 0.730155
# [160]	training's auc: 0.77486	valid_0's auc: 0.731356
# [180]	training's auc: 0.775116	valid_0's auc: 0.731229
# [200]	training's auc: 0.775377	valid_0's auc: 0.731711
# [220]	training's auc: 0.775695	valid_0's auc: 0.732587
# [240]	training's auc: 0.775963	valid_0's auc: 0.733086
# [260]	training's auc: 0.776123	valid_0's auc: 0.732769
# [280]	training's auc: 0.776339	valid_0's auc: 0.732494
# Early stopping, best iteration is:
# [240]	training's auc: 0.775963	valid_0's auc: 0.733086
# *****
# 0.733085808580858
# ********************
#
#
# county_name_arpu_202005/idcard_cnt_min
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.645365	valid_0's auc: 0.627329
# [40]	training's auc: 0.647066	valid_0's auc: 0.625188
# [60]	training's auc: 0.647778	valid_0's auc: 0.625762
# [80]	training's auc: 0.648631	valid_0's auc: 0.629069
# [100]	training's auc: 0.649017	valid_0's auc: 0.629968
# [120]	training's auc: 0.649188	valid_0's auc: 0.630288
# [140]	training's auc: 0.649236	valid_0's auc: 0.630342
# [160]	training's auc: 0.649365	valid_0's auc: 0.629861
# Early stopping, best iteration is:
# [124]	training's auc: 0.649201	valid_0's auc: 0.630348
# *****
# 0.6303480891567418
# ********************
#
#
# county_name_arpu_202005/idcard_cnt_median
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.753833	valid_0's auc: 0.712314
# [40]	training's auc: 0.758718	valid_0's auc: 0.717015
# [60]	training's auc: 0.761682	valid_0's auc: 0.719964
# [80]	training's auc: 0.763552	valid_0's auc: 0.721766
# [100]	training's auc: 0.764558	valid_0's auc: 0.722527
# [120]	training's auc: 0.765119	valid_0's auc: 0.722624
# [140]	training's auc: 0.765524	valid_0's auc: 0.722834
# [160]	training's auc: 0.765799	valid_0's auc: 0.72288
# [180]	training's auc: 0.766032	valid_0's auc: 0.722793
# Early stopping, best iteration is:
# [149]	training's auc: 0.765681	valid_0's auc: 0.723085
# *****
# 0.7230846725976946
# ********************
#
#
# county_name_arpu_202005/idcard_cnt_mean
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.760368	valid_0's auc: 0.722621
# [40]	training's auc: 0.767846	valid_0's auc: 0.728268
# [60]	training's auc: 0.770085	valid_0's auc: 0.729356
# [80]	training's auc: 0.771961	valid_0's auc: 0.729557
# [100]	training's auc: 0.772811	valid_0's auc: 0.729356
# [120]	training's auc: 0.773349	valid_0's auc: 0.728953
# Early stopping, best iteration is:
# [74]	training's auc: 0.771598	valid_0's auc: 0.730243
# *****
# 0.730242861242646
# ********************
#
#
# county_name_arpu_202005/idcard_cnt_skew
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.767137	valid_0's auc: 0.724532
# [40]	training's auc: 0.771345	valid_0's auc: 0.726717
# [60]	training's auc: 0.773392	valid_0's auc: 0.728633
# [80]	training's auc: 0.774289	valid_0's auc: 0.729766
# [100]	training's auc: 0.775118	valid_0's auc: 0.730001
# [120]	training's auc: 0.775456	valid_0's auc: 0.729824
# [140]	training's auc: 0.775787	valid_0's auc: 0.730582
# [160]	training's auc: 0.776063	valid_0's auc: 0.730693
# [180]	training's auc: 0.776216	valid_0's auc: 0.730038
# [200]	training's auc: 0.776307	valid_0's auc: 0.72959
# Early stopping, best iteration is:
# [154]	training's auc: 0.775995	valid_0's auc: 0.73077
# *****
# 0.7307704955278137
# ********************
#
#
# county_name_arpu_202005/idcard_cnt_nunique
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.724753	valid_0's auc: 0.707477
# [40]	training's auc: 0.725686	valid_0's auc: 0.706238
# Early stopping, best iteration is:
# [5]	training's auc: 0.72304	valid_0's auc: 0.708365
# *****
# 0.7083647223417994
# ********************
#
#
# county_name_idcard_cnt/arpu_202005_sum
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.766112	valid_0's auc: 0.734971
# [40]	training's auc: 0.77119	valid_0's auc: 0.731972
# [60]	training's auc: 0.773809	valid_0's auc: 0.732764
# Early stopping, best iteration is:
# [14]	training's auc: 0.763186	valid_0's auc: 0.736012
# *****
# 0.7360124599416463
# ********************
#
#
# county_name_idcard_cnt/arpu_202005_max
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.643298	valid_0's auc: 0.627507
# [40]	training's auc: 0.645239	valid_0's auc: 0.625309
# [60]	training's auc: 0.645929	valid_0's auc: 0.626097
# Early stopping, best iteration is:
# [23]	training's auc: 0.643414	valid_0's auc: 0.627713
# *****
# 0.6277129071602813
# ********************
#
#
# county_name_idcard_cnt/arpu_202005_min
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.751535	valid_0's auc: 0.707765
# [40]	training's auc: 0.755176	valid_0's auc: 0.711586
# [60]	training's auc: 0.757098	valid_0's auc: 0.712508
# [80]	training's auc: 0.75846	valid_0's auc: 0.711701
# [100]	training's auc: 0.75933	valid_0's auc: 0.711841
# Early stopping, best iteration is:
# [65]	training's auc: 0.757621	valid_0's auc: 0.712813
# *****
# 0.7128129932558473
# ********************
#
#
# county_name_idcard_cnt/arpu_202005_median
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.754674	valid_0's auc: 0.70978
# [40]	training's auc: 0.759183	valid_0's auc: 0.714348
# [60]	training's auc: 0.761001	valid_0's auc: 0.716844
# [80]	training's auc: 0.762088	valid_0's auc: 0.717702
# [100]	training's auc: 0.762786	valid_0's auc: 0.718272
# [120]	training's auc: 0.763084	valid_0's auc: 0.717958
# [140]	training's auc: 0.763389	valid_0's auc: 0.718089
# Early stopping, best iteration is:
# [101]	training's auc: 0.762807	valid_0's auc: 0.718436
# *****
# 0.7184361099153393
# ********************
#
#
# county_name_idcard_cnt/arpu_202005_mean
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.763087	valid_0's auc: 0.718674
# [40]	training's auc: 0.768359	valid_0's auc: 0.722023
# [60]	training's auc: 0.770882	valid_0's auc: 0.723228
# [80]	training's auc: 0.772455	valid_0's auc: 0.724481
# [100]	training's auc: 0.773411	valid_0's auc: 0.724995
# [120]	training's auc: 0.774083	valid_0's auc: 0.725357
# [140]	training's auc: 0.774551	valid_0's auc: 0.725871
# [160]	training's auc: 0.775004	valid_0's auc: 0.72591
# [180]	training's auc: 0.77533	valid_0's auc: 0.726545
# [200]	training's auc: 0.775624	valid_0's auc: 0.726401
# [220]	training's auc: 0.775869	valid_0's auc: 0.726781
# [240]	training's auc: 0.776063	valid_0's auc: 0.726865
# [260]	training's auc: 0.77621	valid_0's auc: 0.72696
# [280]	training's auc: 0.776341	valid_0's auc: 0.726984
# [300]	training's auc: 0.776487	valid_0's auc: 0.727221
# [320]	training's auc: 0.776628	valid_0's auc: 0.727627
# [340]	training's auc: 0.776669	valid_0's auc: 0.727848
# [360]	training's auc: 0.776716	valid_0's auc: 0.727929
# [380]	training's auc: 0.776757	valid_0's auc: 0.727986
# [400]	training's auc: 0.77679	valid_0's auc: 0.727968
# [420]	training's auc: 0.776869	valid_0's auc: 0.728204
# [440]	training's auc: 0.776921	valid_0's auc: 0.727809
# [460]	training's auc: 0.776954	valid_0's auc: 0.728312
# Early stopping, best iteration is:
# [421]	training's auc: 0.776865	valid_0's auc: 0.728354
# *****
# 0.7283535418759267
# ********************
#
#
# county_name_idcard_cnt/arpu_202005_skew
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.761156	valid_0's auc: 0.730513
# [40]	training's auc: 0.76736	valid_0's auc: 0.734906
# [60]	training's auc: 0.769677	valid_0's auc: 0.734908
# [80]	training's auc: 0.771306	valid_0's auc: 0.735252
# [100]	training's auc: 0.772352	valid_0's auc: 0.737477
# [120]	training's auc: 0.77306	valid_0's auc: 0.737423
# [140]	training's auc: 0.773746	valid_0's auc: 0.736676
# [160]	training's auc: 0.774083	valid_0's auc: 0.737456
# Early stopping, best iteration is:
# [127]	training's auc: 0.773308	valid_0's auc: 0.738093
# *****
# 0.7380931027885397
# ********************
#
#
# county_name_idcard_cnt/arpu_202005_nunique
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.717779	valid_0's auc: 0.705106
# [40]	training's auc: 0.718728	valid_0's auc: 0.704183
# [60]	training's auc: 0.719125	valid_0's auc: 0.704168
# Early stopping, best iteration is:
# [17]	training's auc: 0.717478	valid_0's auc: 0.705798
# *****
# 0.7057982972210265
# ********************
#
#
# city_name_county_name_idcard_cnt_sum
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.758396	valid_0's auc: 0.722976
# [40]	training's auc: 0.760836	valid_0's auc: 0.722698
# Early stopping, best iteration is:
# [5]	training's auc: 0.752879	valid_0's auc: 0.726369
# *****
# 0.7263685607691204
# ********************
#
#
# city_name_county_name_idcard_cnt_max
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.628027	valid_0's auc: 0.635801
# [40]	training's auc: 0.62803	valid_0's auc: 0.635837
# [60]	training's auc: 0.62803	valid_0's auc: 0.635837
# Early stopping, best iteration is:
# [26]	training's auc: 0.62803	valid_0's auc: 0.635837
# *****
# 0.6358366814942363
# ********************
#
#
# city_name_county_name_idcard_cnt_min
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.61342	valid_0's auc: 0.597121
# [40]	training's auc: 0.61342	valid_0's auc: 0.597121
# Early stopping, best iteration is:
# [1]	training's auc: 0.61342	valid_0's auc: 0.597121
# *****
# 0.5971205816233798
# ********************
#
#
# city_name_county_name_idcard_cnt_median
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.584501	valid_0's auc: 0.577387
# [40]	training's auc: 0.584501	valid_0's auc: 0.577387
# Early stopping, best iteration is:
# [1]	training's auc: 0.584501	valid_0's auc: 0.577387
# *****
# 0.5773873583010475
# ********************
#
#
# city_name_county_name_idcard_cnt_mean
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.761058	valid_0's auc: 0.725718
# [40]	training's auc: 0.764799	valid_0's auc: 0.727651
# [60]	training's auc: 0.767596	valid_0's auc: 0.730336
# [80]	training's auc: 0.769232	valid_0's auc: 0.731289
# [100]	training's auc: 0.770667	valid_0's auc: 0.730881
# [120]	training's auc: 0.771352	valid_0's auc: 0.731476
# [140]	training's auc: 0.77169	valid_0's auc: 0.731174
# [160]	training's auc: 0.772289	valid_0's auc: 0.730839
# [180]	training's auc: 0.772756	valid_0's auc: 0.731054
# Early stopping, best iteration is:
# [131]	training's auc: 0.771564	valid_0's auc: 0.731715
# *****
# 0.7317151552111733
# ********************
#
#
# city_name_county_name_idcard_cnt_skew
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.761779	valid_0's auc: 0.725922
# [40]	training's auc: 0.766076	valid_0's auc: 0.731122
# [60]	training's auc: 0.768859	valid_0's auc: 0.731156
# [80]	training's auc: 0.770512	valid_0's auc: 0.731189
# [100]	training's auc: 0.772711	valid_0's auc: 0.731392
# [120]	training's auc: 0.773775	valid_0's auc: 0.731796
# [140]	training's auc: 0.774607	valid_0's auc: 0.733005
# [160]	training's auc: 0.775211	valid_0's auc: 0.733518
# [180]	training's auc: 0.775686	valid_0's auc: 0.733316
# [200]	training's auc: 0.776178	valid_0's auc: 0.73351
# [220]	training's auc: 0.77657	valid_0's auc: 0.733767
# [240]	training's auc: 0.77682	valid_0's auc: 0.733691
# [260]	training's auc: 0.777079	valid_0's auc: 0.733682
# [280]	training's auc: 0.777264	valid_0's auc: 0.733877
# [300]	training's auc: 0.77753	valid_0's auc: 0.734455
# [320]	training's auc: 0.777683	valid_0's auc: 0.73424
# [340]	training's auc: 0.777895	valid_0's auc: 0.734622
# [360]	training's auc: 0.778075	valid_0's auc: 0.734745
# [380]	training's auc: 0.778164	valid_0's auc: 0.734452
# [400]	training's auc: 0.778245	valid_0's auc: 0.734506
# Early stopping, best iteration is:
# [353]	training's auc: 0.778009	valid_0's auc: 0.734835
# *****
# 0.7348346247668245
# ********************
#
#
# city_name_county_name_idcard_cnt_nunique
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.655831	valid_0's auc: 0.647708
# [40]	training's auc: 0.655831	valid_0's auc: 0.647708
# Early stopping, best iteration is:
# [1]	training's auc: 0.655831	valid_0's auc: 0.647708
# *****
# 0.647707705553164
# ********************
#
#
# city_name_county_name_arpu_202005_sum
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.768199	valid_0's auc: 0.73727
# [40]	training's auc: 0.773205	valid_0's auc: 0.73822
# [60]	training's auc: 0.775689	valid_0's auc: 0.737733
# [80]	training's auc: 0.776906	valid_0's auc: 0.737415
# Early stopping, best iteration is:
# [39]	training's auc: 0.772899	valid_0's auc: 0.738468
# *****
# 0.7384682761754436
# ********************
#
#
# city_name_county_name_arpu_202005_max
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.765143	valid_0's auc: 0.72549
# [40]	training's auc: 0.768629	valid_0's auc: 0.730907
# [60]	training's auc: 0.770908	valid_0's auc: 0.732956
# [80]	training's auc: 0.771559	valid_0's auc: 0.7329
# [100]	training's auc: 0.772142	valid_0's auc: 0.733935
# [120]	training's auc: 0.772687	valid_0's auc: 0.73392
# [140]	training's auc: 0.773043	valid_0's auc: 0.733729
# [160]	training's auc: 0.773232	valid_0's auc: 0.733782
# Early stopping, best iteration is:
# [121]	training's auc: 0.77274	valid_0's auc: 0.734111
# *****
# 0.7341111828574162
# ********************
#
#
# city_name_county_name_arpu_202005_min
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.546737	valid_0's auc: 0.536661
# [40]	training's auc: 0.547271	valid_0's auc: 0.537609
# [60]	training's auc: 0.547347	valid_0's auc: 0.537495
# [80]	training's auc: 0.547375	valid_0's auc: 0.537592
# Early stopping, best iteration is:
# [31]	training's auc: 0.547265	valid_0's auc: 0.537656
# *****
# 0.5376563471564548
# ********************
#
#
# city_name_county_name_arpu_202005_median
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.755555	valid_0's auc: 0.716964
# [40]	training's auc: 0.760133	valid_0's auc: 0.719179
# [60]	training's auc: 0.762479	valid_0's auc: 0.722899
# [80]	training's auc: 0.763762	valid_0's auc: 0.723436
# [100]	training's auc: 0.764562	valid_0's auc: 0.72395
# [120]	training's auc: 0.7657	valid_0's auc: 0.724865
# [140]	training's auc: 0.766319	valid_0's auc: 0.72456
# [160]	training's auc: 0.766924	valid_0's auc: 0.725044
# [180]	training's auc: 0.767399	valid_0's auc: 0.724993
# [200]	training's auc: 0.767741	valid_0's auc: 0.725297
# Early stopping, best iteration is:
# [162]	training's auc: 0.767042	valid_0's auc: 0.725651
# *****
# 0.7256510977184675
# ********************
#
#
# city_name_county_name_arpu_202005_mean
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.763888	valid_0's auc: 0.723479
# [40]	training's auc: 0.769968	valid_0's auc: 0.724176
# [60]	training's auc: 0.772313	valid_0's auc: 0.724481
# [80]	training's auc: 0.773785	valid_0's auc: 0.725032
# [100]	training's auc: 0.774708	valid_0's auc: 0.725576
# [120]	training's auc: 0.7754	valid_0's auc: 0.725618
# [140]	training's auc: 0.775968	valid_0's auc: 0.726161
# [160]	training's auc: 0.776212	valid_0's auc: 0.727327
# [180]	training's auc: 0.776432	valid_0's auc: 0.727741
# [200]	training's auc: 0.776644	valid_0's auc: 0.728632
# [220]	training's auc: 0.776879	valid_0's auc: 0.728756
# [240]	training's auc: 0.776959	valid_0's auc: 0.728714
# [260]	training's auc: 0.777148	valid_0's auc: 0.728896
# [280]	training's auc: 0.7772	valid_0's auc: 0.729141
# [300]	training's auc: 0.777274	valid_0's auc: 0.728334
# [320]	training's auc: 0.777311	valid_0's auc: 0.728265
# [340]	training's auc: 0.777376	valid_0's auc: 0.728454
# [360]	training's auc: 0.7774	valid_0's auc: 0.728322
# [380]	training's auc: 0.777408	valid_0's auc: 0.728289
# Early stopping, best iteration is:
# [339]	training's auc: 0.777348	valid_0's auc: 0.729614
# *****
# 0.7296135863586358
# ********************
#
#
# city_name_county_name_arpu_202005_skew
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.766298	valid_0's auc: 0.732869
# [40]	training's auc: 0.771236	valid_0's auc: 0.735999
# [60]	training's auc: 0.773278	valid_0's auc: 0.735243
# [80]	training's auc: 0.774191	valid_0's auc: 0.734924
# Early stopping, best iteration is:
# [40]	training's auc: 0.771236	valid_0's auc: 0.735999
# *****
# 0.7359990075094466
# ********************
#
#
# city_name_county_name_arpu_202005_nunique
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.730239	valid_0's auc: 0.711664
# [40]	training's auc: 0.731622	valid_0's auc: 0.708538
# Early stopping, best iteration is:
# [8]	training's auc: 0.72864	valid_0's auc: 0.711758
# *****
# 0.711757724685512
# ********************
#
#
# city_name_county_name_idcard_cnt*arpu_202005_sum
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.767337	valid_0's auc: 0.724706
# [40]	training's auc: 0.771898	valid_0's auc: 0.728739
# [60]	training's auc: 0.774387	valid_0's auc: 0.731682
# [80]	training's auc: 0.775952	valid_0's auc: 0.733516
# [100]	training's auc: 0.776959	valid_0's auc: 0.733687
# [120]	training's auc: 0.777797	valid_0's auc: 0.734328
# [140]	training's auc: 0.778232	valid_0's auc: 0.734147
# [160]	training's auc: 0.778472	valid_0's auc: 0.734295
# [180]	training's auc: 0.778708	valid_0's auc: 0.734621
# [200]	training's auc: 0.778838	valid_0's auc: 0.734607
# [220]	training's auc: 0.778987	valid_0's auc: 0.734316
# [240]	training's auc: 0.779098	valid_0's auc: 0.733613
# Early stopping, best iteration is:
# [191]	training's auc: 0.778772	valid_0's auc: 0.734742
# *****
# 0.7347419524561152
# ********************
#
#
# city_name_county_name_idcard_cnt*arpu_202005_max
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.761816	valid_0's auc: 0.724428
# [40]	training's auc: 0.768242	valid_0's auc: 0.726805
# [60]	training's auc: 0.770974	valid_0's auc: 0.728288
# [80]	training's auc: 0.772493	valid_0's auc: 0.729781
# [100]	training's auc: 0.773268	valid_0's auc: 0.729966
# [120]	training's auc: 0.774057	valid_0's auc: 0.730617
# [140]	training's auc: 0.774678	valid_0's auc: 0.730717
# [160]	training's auc: 0.774997	valid_0's auc: 0.730416
# [180]	training's auc: 0.775256	valid_0's auc: 0.730449
# [200]	training's auc: 0.775533	valid_0's auc: 0.730736
# [220]	training's auc: 0.775695	valid_0's auc: 0.73053
# [240]	training's auc: 0.775872	valid_0's auc: 0.730673
# Early stopping, best iteration is:
# [207]	training's auc: 0.775596	valid_0's auc: 0.731008
# *****
# 0.7310081551633424
# ********************
#
#
# city_name_county_name_idcard_cnt*arpu_202005_min
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.605457	valid_0's auc: 0.567216
# [40]	training's auc: 0.606134	valid_0's auc: 0.567609
# [60]	training's auc: 0.606185	valid_0's auc: 0.567808
# [80]	training's auc: 0.606305	valid_0's auc: 0.569219
# [100]	training's auc: 0.606326	valid_0's auc: 0.569279
# [120]	training's auc: 0.606383	valid_0's auc: 0.569551
# [140]	training's auc: 0.606384	valid_0's auc: 0.569566
# [160]	training's auc: 0.606387	valid_0's auc: 0.56956
# Early stopping, best iteration is:
# [111]	training's auc: 0.606375	valid_0's auc: 0.569586
# *****
# 0.5695864423398862
# ********************
#
#
# city_name_county_name_idcard_cnt*arpu_202005_median
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.759181	valid_0's auc: 0.708239
# [40]	training's auc: 0.763558	valid_0's auc: 0.713883
# [60]	training's auc: 0.764913	valid_0's auc: 0.714895
# [80]	training's auc: 0.76569	valid_0's auc: 0.715607
# [100]	training's auc: 0.766308	valid_0's auc: 0.716396
# [120]	training's auc: 0.76671	valid_0's auc: 0.716926
# [140]	training's auc: 0.766935	valid_0's auc: 0.717481
# [160]	training's auc: 0.767163	valid_0's auc: 0.717731
# [180]	training's auc: 0.767296	valid_0's auc: 0.717524
# [200]	training's auc: 0.767424	valid_0's auc: 0.71788
# [220]	training's auc: 0.767518	valid_0's auc: 0.717817
# [240]	training's auc: 0.767547	valid_0's auc: 0.717841
# Early stopping, best iteration is:
# ...
# [60]	training's auc: 0.802016	valid_0's auc: 0.791821
# [80]	training's auc: 0.802163	valid_0's auc: 0.792514
# [100]	training's auc: 0.80218	valid_0's auc: 0.792553
# [120]	training's auc: 0.802214	valid_0's auc: 0.792592
# [140]	training's auc: 0.802635	valid_0's auc: 0.792245
# [160]	training's auc: 0.802654	valid_0's auc: 0.792138
# Early stopping, best iteration is:
# [124]	training's auc: 0.802225	valid_0's auc: 0.79264
# *****
# 0.7926397259291147
# ********************
#
#
# sms_day17_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.834824	valid_0's auc: 0.825027
# [40]	training's auc: 0.834877	valid_0's auc: 0.825036
# Early stopping, best iteration is:
# [4]	training's auc: 0.834647	valid_0's auc: 0.82589
# *****
# 0.8258896541828096
# ********************
#
#
# sms_day18_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.816939	valid_0's auc: 0.797693
# [40]	training's auc: 0.817099	valid_0's auc: 0.795744
# [60]	training's auc: 0.817175	valid_0's auc: 0.794363
# Early stopping, best iteration is:
# [14]	training's auc: 0.816878	valid_0's auc: 0.79811
# *****
# 0.798110381690343
# ********************
#
#
# sms_day19_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.852865	valid_0's auc: 0.826189
# [40]	training's auc: 0.852946	valid_0's auc: 0.825909
# Early stopping, best iteration is:
# [2]	training's auc: 0.852679	valid_0's auc: 0.827292
# *****
# 0.8272916965609605
# ********************
#
#
# sms_day20_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.807959	valid_0's auc: 0.766336
# [40]	training's auc: 0.808019	valid_0's auc: 0.766147
# Early stopping, best iteration is:
# [2]	training's auc: 0.807732	valid_0's auc: 0.768407
# *****
# 0.7684074113933133
# ********************
#
#
# sms_day21_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.763335	valid_0's auc: 0.734957
# [40]	training's auc: 0.763367	valid_0's auc: 0.734784
# Early stopping, best iteration is:
# [7]	training's auc: 0.76332	valid_0's auc: 0.735057
# *****
# 0.7350573372554646
# ********************
#
#
# sms_day22_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.735239	valid_0's auc: 0.695329
# [40]	training's auc: 0.735248	valid_0's auc: 0.695328
# [60]	training's auc: 0.735251	valid_0's auc: 0.695328
# Early stopping, best iteration is:
# [27]	training's auc: 0.735246	valid_0's auc: 0.69537
# *****
# 0.6953696728368489
# ********************
#
#
# sms_day23_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.773557	valid_0's auc: 0.754412
# [40]	training's auc: 0.774245	valid_0's auc: 0.754661
# [60]	training's auc: 0.774399	valid_0's auc: 0.754672
# Early stopping, best iteration is:
# [25]	training's auc: 0.774084	valid_0's auc: 0.755384
# *****
# 0.7553839623092744
# ********************
#
#
# sms_day24_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.871818	valid_0's auc: 0.847497
# [40]	training's auc: 0.871907	valid_0's auc: 0.846426
# Early stopping, best iteration is:
# [1]	training's auc: 0.870984	valid_0's auc: 0.848279
# *****
# 0.8482789855072463
# ********************
#
#
# sms_day25_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.849237	valid_0's auc: 0.821914
# [40]	training's auc: 0.849334	valid_0's auc: 0.821976
# [60]	training's auc: 0.849396	valid_0's auc: 0.821971
# Early stopping, best iteration is:
# [12]	training's auc: 0.849125	valid_0's auc: 0.822362
# *****
# 0.8223621275170996
# ********************
#
#
# sms_day26_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.879805	valid_0's auc: 0.855449
# [40]	training's auc: 0.879945	valid_0's auc: 0.855068
# [60]	training's auc: 0.879974	valid_0's auc: 0.855391
# Early stopping, best iteration is:
# [26]	training's auc: 0.879862	valid_0's auc: 0.855693
# *****
# 0.8556927703639929
# ********************
#
#
# sms_day27_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.857405	valid_0's auc: 0.855869
# [40]	training's auc: 0.857486	valid_0's auc: 0.855842
# [60]	training's auc: 0.857611	valid_0's auc: 0.855687
# Early stopping, best iteration is:
# [10]	training's auc: 0.857392	valid_0's auc: 0.856289
# *****
# 0.8562891615248481
# ********************
#
#
# sms_day28_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.865299	valid_0's auc: 0.841279
# [40]	training's auc: 0.865472	valid_0's auc: 0.840789
# [60]	training's auc: 0.86562	valid_0's auc: 0.840634
# Early stopping, best iteration is:
# [16]	training's auc: 0.865353	valid_0's auc: 0.841357
# *****
# 0.8413569617831348
# ********************
#
#
# sms_day29_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.725238	valid_0's auc: 0.718702
# [40]	training's auc: 0.725255	valid_0's auc: 0.718757
# [60]	training's auc: 0.725276	valid_0's auc: 0.718722
# [80]	training's auc: 0.725296	valid_0's auc: 0.718698
# Early stopping, best iteration is:
# [37]	training's auc: 0.725243	valid_0's auc: 0.719349
# *****
# 0.7193493805902329
# ********************
#
#
# sms_day30_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.865293	valid_0's auc: 0.848442
# [40]	training's auc: 0.865487	valid_0's auc: 0.848197
# Early stopping, best iteration is:
# [1]	training's auc: 0.864338	valid_0's auc: 0.849708
# *****
# 0.8497079327497967
# ********************
#
#
# sms_day31_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.864014	valid_0's auc: 0.836226
# [40]	training's auc: 0.864117	valid_0's auc: 0.836182
# [60]	training's auc: 0.864243	valid_0's auc: 0.835806
# Early stopping, best iteration is:
# [21]	training's auc: 0.863997	valid_0's auc: 0.836423
# *****
# 0.8364229085952073
# ********************
#
#
# sms_hour10_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.840865	valid_0's auc: 0.802379
# [40]	training's auc: 0.841822	valid_0's auc: 0.803316
# [60]	training's auc: 0.842539	valid_0's auc: 0.803325
# Early stopping, best iteration is:
# [27]	training's auc: 0.841209	valid_0's auc: 0.804532
# *****
# 0.8045316759936864
# ********************
#
#
# sms_hour14_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.822721	valid_0's auc: 0.804301
# [40]	training's auc: 0.824165	valid_0's auc: 0.807316
# [60]	training's auc: 0.82493	valid_0's auc: 0.806279
# [80]	training's auc: 0.825467	valid_0's auc: 0.805047
# [100]	training's auc: 0.82567	valid_0's auc: 0.804476
# Early stopping, best iteration is:
# [52]	training's auc: 0.824797	valid_0's auc: 0.807702
# *****
# 0.8077019658487588
# ********************
#
#
# sms_hour16_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.810264	valid_0's auc: 0.785918
# [40]	training's auc: 0.81141	valid_0's auc: 0.785679
# [60]	training's auc: 0.812159	valid_0's auc: 0.785795
# Early stopping, best iteration is:
# [18]	training's auc: 0.810118	valid_0's auc: 0.786552
# *****
# 0.7865517530013871
# ********************
#
#
# sms_hour18_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.809284	valid_0's auc: 0.78686
# [40]	training's auc: 0.809683	valid_0's auc: 0.785933
# Early stopping, best iteration is:
# [3]	training's auc: 0.808904	valid_0's auc: 0.788417
# *****
# 0.7884171569330846
# ********************
#
#
# sms_hour13_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.840273	valid_0's auc: 0.825337
# [40]	training's auc: 0.840978	valid_0's auc: 0.825447
# [60]	training's auc: 0.841257	valid_0's auc: 0.825302
# [80]	training's auc: 0.84135	valid_0's auc: 0.825257
# Early stopping, best iteration is:
# [37]	training's auc: 0.840963	valid_0's auc: 0.825725
# *****
# 0.8257252355670349
# ********************
#
#
# sms_hour17_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.819973	valid_0's auc: 0.800204
# [40]	training's auc: 0.820346	valid_0's auc: 0.800278
# Early stopping, best iteration is:
# [5]	training's auc: 0.81952	valid_0's auc: 0.802122
# *****
# 0.8021221959152437
# ********************
#
#
# sms_hour11_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.856739	valid_0's auc: 0.820371
# [40]	training's auc: 0.857336	valid_0's auc: 0.82137
# [60]	training's auc: 0.857683	valid_0's auc: 0.821539
# [80]	training's auc: 0.857895	valid_0's auc: 0.821562
# [100]	training's auc: 0.858038	valid_0's auc: 0.821918
# [120]	training's auc: 0.858225	valid_0's auc: 0.821604
# [140]	training's auc: 0.858361	valid_0's auc: 0.821927
# [160]	training's auc: 0.858474	valid_0's auc: 0.822402
# [180]	training's auc: 0.858602	valid_0's auc: 0.823072
# [200]	training's auc: 0.858633	valid_0's auc: 0.822967
# [220]	training's auc: 0.858784	valid_0's auc: 0.821527
# Early stopping, best iteration is:
# [180]	training's auc: 0.858602	valid_0's auc: 0.823072
# *****
# 0.8230721169943082
# ********************
#
#
# sms_hour9_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.824555	valid_0's auc: 0.787942
# [40]	training's auc: 0.82512	valid_0's auc: 0.787507
# [60]	training's auc: 0.825551	valid_0's auc: 0.787017
# Early stopping, best iteration is:
# [18]	training's auc: 0.82451	valid_0's auc: 0.788218
# *****
# 0.7882183598794662
# ********************
#
#
# sms_hour0_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.560302	valid_0's auc: 0.54383
# [40]	training's auc: 0.561164	valid_0's auc: 0.541803
# Early stopping, best iteration is:
# [3]	training's auc: 0.559975	valid_0's auc: 0.544502
# *****
# 0.5445021404314344
# ********************
#
#
# sms_hour20_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.790886	valid_0's auc: 0.75664
# [40]	training's auc: 0.790954	valid_0's auc: 0.756182
# [60]	training's auc: 0.791129	valid_0's auc: 0.756705
# [80]	training's auc: 0.791151	valid_0's auc: 0.756959
# [100]	training's auc: 0.791246	valid_0's auc: 0.758033
# [120]	training's auc: 0.791278	valid_0's auc: 0.757949
# [140]	training's auc: 0.791318	valid_0's auc: 0.75774
# Early stopping, best iteration is:
# [103]	training's auc: 0.791275	valid_0's auc: 0.758036
# *****
# 0.7580355861673124
# ********************
#
#
# sms_hour8_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.758293	valid_0's auc: 0.733125
# [40]	training's auc: 0.759019	valid_0's auc: 0.732993
# Early stopping, best iteration is:
# [2]	training's auc: 0.757752	valid_0's auc: 0.738477
# *****
# 0.7384772444635768
# ********************
#
#
# sms_hour21_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.762414	valid_0's auc: 0.734663
# [40]	training's auc: 0.762514	valid_0's auc: 0.734767
# [60]	training's auc: 0.762612	valid_0's auc: 0.734884
# [80]	training's auc: 0.762637	valid_0's auc: 0.734881
# [100]	training's auc: 0.762713	valid_0's auc: 0.734857
# [120]	training's auc: 0.762755	valid_0's auc: 0.734857
# Early stopping, best iteration is:
# [79]	training's auc: 0.762636	valid_0's auc: 0.73489
# *****
# 0.7348899292103124
# ********************
#
#
# sms_hour15_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.831972	valid_0's auc: 0.814301
# [40]	training's auc: 0.832531	valid_0's auc: 0.813359
# [60]	training's auc: 0.832827	valid_0's auc: 0.811712
# Early stopping, best iteration is:
# [23]	training's auc: 0.832027	valid_0's auc: 0.814395
# *****
# 0.8143952982254747
# ********************
#
#
# sms_hour2_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.531729	valid_0's auc: 0.522104
# [40]	training's auc: 0.531752	valid_0's auc: 0.522116
# Early stopping, best iteration is:
# [1]	training's auc: 0.530025	valid_0's auc: 0.52276
# *****
# 0.5227600205672741
# ********************
#
#
# sms_hour12_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.83786	valid_0's auc: 0.800333
# [40]	training's auc: 0.838225	valid_0's auc: 0.798852
# Early stopping, best iteration is:
# [1]	training's auc: 0.836301	valid_0's auc: 0.803354
# *****
# 0.8033538408188645
# ********************
#
#
# sms_hour3_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.525914	valid_0's auc: 0.49784
# [40]	training's auc: 0.525916	valid_0's auc: 0.497846
# Early stopping, best iteration is:
# [4]	training's auc: 0.525495	valid_0's auc: 0.500293
# *****
# 0.5002929640790166
# ********************
#
#
# sms_hour7_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.649455	valid_0's auc: 0.626466
# [40]	training's auc: 0.649823	valid_0's auc: 0.626239
# [60]	training's auc: 0.650124	valid_0's auc: 0.624496
# [80]	training's auc: 0.65016	valid_0's auc: 0.624182
# Early stopping, best iteration is:
# [32]	training's auc: 0.649554	valid_0's auc: 0.627248
# *****
# 0.6272480508920457
# ********************
#
#
# sms_hour22_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.689531	valid_0's auc: 0.674786
# [40]	training's auc: 0.689565	valid_0's auc: 0.674808
# [60]	training's auc: 0.689569	valid_0's auc: 0.674814
# [80]	training's auc: 0.690063	valid_0's auc: 0.676001
# [100]	training's auc: 0.690065	valid_0's auc: 0.676004
# [120]	training's auc: 0.690068	valid_0's auc: 0.676013
# [140]	training's auc: 0.690071	valid_0's auc: 0.676013
# [160]	training's auc: 0.690071	valid_0's auc: 0.676013
# [180]	training's auc: 0.690074	valid_0's auc: 0.676022
# [200]	training's auc: 0.690074	valid_0's auc: 0.676022
# [220]	training's auc: 0.690076	valid_0's auc: 0.676025
# Early stopping, best iteration is:
# [187]	training's auc: 0.690075	valid_0's auc: 0.676025
# *****
# 0.6760250753336203
# ********************
#
#
# sms_hour19_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.799209	valid_0's auc: 0.781265
# [40]	training's auc: 0.799179	valid_0's auc: 0.780999
# Early stopping, best iteration is:
# [3]	training's auc: 0.799054	valid_0's auc: 0.781999
# *****
# 0.781998852059119
# ********************
#
#
# sms_hour23_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.577381	valid_0's auc: 0.572232
# [40]	training's auc: 0.5779	valid_0's auc: 0.573691
# [60]	training's auc: 0.577917	valid_0's auc: 0.573652
# [80]	training's auc: 0.577946	valid_0's auc: 0.573766
# Early stopping, best iteration is:
# [34]	training's auc: 0.577481	valid_0's auc: 0.577721
# *****
# 0.5777206796766633
# ********************
#
#
# sms_hour6_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.551104	valid_0's auc: 0.556588
# [40]	training's auc: 0.551152	valid_0's auc: 0.55684
# [60]	training's auc: 0.551189	valid_0's auc: 0.556804
# [80]	training's auc: 0.551257	valid_0's auc: 0.556783
# Early stopping, best iteration is:
# [34]	training's auc: 0.553312	valid_0's auc: 0.557689
# *****
# 0.557688513416559
# ********************
#
#
# sms_hour5_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.525606	valid_0's auc: 0.50978
# [40]	training's auc: 0.526744	valid_0's auc: 0.509774
# Early stopping, best iteration is:
# [6]	training's auc: 0.525603	valid_0's auc: 0.50978
# *****
# 0.5097799182092122
# ********************
#
#
# sms_hour4_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.519223	valid_0's auc: 0.509735
# [40]	training's auc: 0.519106	valid_0's auc: 0.513331
# [60]	training's auc: 0.519226	valid_0's auc: 0.509737
# Early stopping, best iteration is:
# [28]	training's auc: 0.519106	valid_0's auc: 0.513331
# *****
# 0.5133313603099441
# ********************
#
#
# sms_hour1_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.525782	valid_0's auc: 0.520192
# [40]	training's auc: 0.525786	valid_0's auc: 0.520223
# [60]	training's auc: 0.525813	valid_0's auc: 0.52124
# [80]	training's auc: 0.525815	valid_0's auc: 0.521234
# Early stopping, best iteration is:
# [30]	training's auc: 0.525806	valid_0's auc: 0.521244
# *****
# 0.5212443798727698
# ********************

# %%
for key, val in useless_cols.items():
    print(key, ':', val)
# Out:
# city_name_idcard_cnt*arpu_202005_min : 0.519147295164299
# voc_hour1_count : 0.509878569378677
# voc_hour3_count : 0.5081716052039986
# voc_hour2_count : 0.5142610728464151
# voc_hour4_count : 0.5153566987133495
# voc_hour1_nunique : 0.5102911106328024
# voc_hour3_nunique : 0.5055244654900273
# voc_hour2_nunique : 0.5119278232171043
# voc_hour4_nunique : 0.5162086860859999
# voc_hour1_call_dur_sum : 0.5041822116994308
# voc_hour3_call_dur_sum : 0.5055543597838045
# voc_hour2_call_dur_sum : 0.5092597574974889
# voc_hour4_call_dur_sum : 0.5162804323910652
# sms_hour3_count : 0.5002929640790166
# sms_hour5_count : 0.5097799182092122
# sms_hour4_count : 0.5133313603099441

# %%
df_train.drop(list(useless_cols.keys()), axis=1, inplace=True)
df_test.drop(list(useless_cols.keys()), axis=1, inplace=True)

# %% [markdown]
# ### 高共线

# %%
def correlation(df, threshold):
    """
    去除特征相关系数大于阈值的特征
    :param df:
    :param threshold:
    :return:
    """
    col_corr = set()
    corr_matrix = df.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold:
                colName_i = corr_matrix.columns[i]
                colName_j = corr_matrix.columns[j]
                if useful_cols[colName_i] >= useful_cols[colName_j]:
                    col_corr.add(colName_j)
                else:
                    col_corr.add(colName_i)

    return col_corr


col = correlation(df_train.drop(['phone_no_m', 'label'], axis=1), 0.98)
print('Correlated columns: ', col)
# Out:
# Correlated columns:  {'county_name_arpu_202005_min', 'county_name_idcard_cnt/arpu_202005_max', 'voc_calltype_id_1_60s_min', 'county_name_arpu_202005/idcard_cnt_nunique', 'city_name_idcard_cnt/arpu_202005_nunique', 'city_name_county_name_arpu_202005/idcard_cnt_max', 'city_name_idcard_cnt*arpu_202005_sum', 'city_name_county_name_arpu_202005_median', 'call_type_id_2_rate', 'calltype_id_1_county_name_nunique', 'voc_calltype_id_1_300s_max', 'county_name_arpu_202005_nunique', 'city_name_arpu_202005_sum', 'county_name_arpu_202005/idcard_cnt_skew', 'county_name_arpu_202005_mean', 'city_name_idcard_cnt_sum', 'city_name_arpu_202005_nunique', 'county_name_idcard_cnt*arpu_202005_nunique', 'county_name_idcard_cnt*arpu_202005_min', 'county_name_idcard_cnt*arpu_202005_sum', 'city_name_county_name_idcard_cnt/arpu_202005_nunique', 'city_name_county_name_arpu_202005_nunique', 'county_name_idcard_cnt_sum', 'county_name_arpu_202005_max', 'county_name_idcard_cnt_nunique', 'city_name', 'city_name_arpu_202005_min', 'city_name_idcard_cnt*arpu_202005_skew', 'city_name_county_name_arpu_202005_sum', 'county_name_arpu_202005/idcard_cnt_median', 'city_name_arpu_202005_max', 'city_name_county_name_arpu_202005/idcard_cnt_nunique', 'voc_calltype_id_1_30s_cnt', 'county_name_idcard_cnt/arpu_202005_mean', 'county_name_arpu_202005_skew', 'county_name_idcard_cnt/arpu_202005_nunique', 'city_name_arpu_202005/idcard_cnt_skew', 'city_name_count', 'city_name_county_name_idcard_cnt/arpu_202005_skew', 'county_name_idcard_cnt_max', 'county_name_idcard_cnt*arpu_202005_mean', 'voc_calltype_id_1_30s_min', 'voc_calltype_id_1_60s_sum', 'city_name_arpu_202005/idcard_cnt_nunique', 'county_name_arpu_202005/idcard_cnt_max', 'county_name_idcard_cnt*arpu_202005_median', 'county_name_idcard_cnt/arpu_202005_min', 'county_name_count', 'voc_day12_count', 'city_name_idcard_cnt/arpu_202005_sum', 'city_name_idcard_cnt*arpu_202005_max', 'voc_calltype_id_1_60s_cnt', 'county_name_arpu_202005/idcard_cnt_min', 'county_name_idcard_cnt_skew', 'county_name_nunique', 'city_name_county_name_idcard_cnt/arpu_202005_median', 'p2o_call_mean_std', 'city_name_arpu_202005/idcard_cnt_sum', 'county_name_idcard_cnt*arpu_202005_max', 'county_name_idcard_cnt*arpu_202005_skew'}

# %%
df_train.drop(list(col), axis=1, inplace=True)
df_test.drop(list(col), axis=1, inplace=True)

# %%
feature_names = [i for i in df_train.columns if i not in ['phone_no_m', 'label']]
ycol = 'label'

# %%
# oof = []
# prediction = df_test[['phone_no_m', 'arpu_202004']]
# prediction['label'] = 0
# df_importance_list = []

# kfold = StratifiedKFold(n_splits=5)
# for fold_id, (trn_idx, val_idx) in enumerate(kfold.split(df_train[feature_names], df_train[ycol])):
#     print('\nFold_{} Training ================================\n'.format(fold_id+1))
    
#     X_train = df_train.iloc[trn_idx][feature_names]
#     Y_train = df_train.iloc[trn_idx][ycol]

#     X_val = df_train.iloc[val_idx][feature_names]
#     Y_val = df_train.iloc[val_idx][ycol]
    
#     lgb_train = lgb.Dataset(X_train, Y_train) 
#     lgb_valid= lgb.Dataset(X_val, Y_val, reference=lgb_train)
    
#     lgb_model = lgb.train(params,
#                           lgb_train,
#                           num_boost_round=10000,
#                           valid_sets=[lgb_valid, lgb_train],
#                           early_stopping_rounds=100,
#                           verbose_eval=10)

#     pred_val = lgb_model.predict(X_val)
#     df_oof = df_train.iloc[val_idx][['phone_no_m', ycol]].copy()
#     df_oof['pred'] = pred_val
#     oof.append(df_oof)

#     pred_test = lgb_model.predict(df_test[feature_names])
#     prediction['label_{}'.format(fold_id)] = pred_test

#     importance = lgb_model.feature_importance(importance_type='gain')
#     feature_name = lgb_model.feature_name()
#     df_importance = pd.DataFrame({
#         'feature_name': feature_name,
#         'importance': importance
#     })
#     df_importance_list.append(df_importance)

#     del lgb_model, pred_val, pred_test, X_train, Y_train, X_val, Y_val
#     gc.collect()

# %%
# df_importance = pd.concat(df_importance_list)
# df_importance = df_importance.groupby(['feature_name'])['importance'].agg(
#     'mean').sort_values(ascending=False).reset_index()
# df_importance.head(20)

# %%
# df_importance.tail(10)

# %%
# df_importance['normalized_importance'] = df_importance['importance'] / df_importance['importance'].sum()
# df_importance['cumulative_importance'] = np.cumsum(df_importance['normalized_importance'])
# record_low_importance = df_importance[df_importance['cumulative_importance'] > 0.99]
# to_drop = list(record_low_importance['feature_name'])
# print(to_drop)

# %%
# df_train.drop(to_drop, axis=1, inplace=True)
# df_test.drop(to_drop, axis=1, inplace=True)

# %%
X_train, X_valid, y_train, y_valid = train_test_split(df_train.drop(['phone_no_m', 'label'], axis=1), df_train['label'],
                                                      test_size=0.2,
                                                      random_state=2020)

# %%
use_cols = [i for i in df_train.columns if i not in ['phone_no_m', 'label']]

# %%
lgb_train = lgb.Dataset(X_train[use_cols].values, y_train) 
lgb_valid= lgb.Dataset(X_valid[use_cols].values, y_valid, reference=lgb_train)  

print('Start training...')

lgb_val_0 = lgb.train(params,
                      lgb_train,
                      num_boost_round=10000,
                      valid_sets=[lgb_valid, lgb_train],
                      early_stopping_rounds=100,
                      verbose_eval=10)

print('Done!')
# Out:
# Start training...
# Training until validation scores don't improve for 100 rounds
# [10]	training's auc: 0.988639	valid_0's auc: 0.952863
# [20]	training's auc: 0.995998	valid_0's auc: 0.952127
# [30]	training's auc: 0.998807	valid_0's auc: 0.95457
# [40]	training's auc: 0.999488	valid_0's auc: 0.955653
# [50]	training's auc: 0.999738	valid_0's auc: 0.955643
# [60]	training's auc: 0.9998	valid_0's auc: 0.955114
# [70]	training's auc: 0.99992	valid_0's auc: 0.955688
# [80]	training's auc: 0.999964	valid_0's auc: 0.955135
# [90]	training's auc: 0.999997	valid_0's auc: 0.955275
# [100]	training's auc: 1	valid_0's auc: 0.955407
# [110]	training's auc: 1	valid_0's auc: 0.955933
# [120]	training's auc: 1	valid_0's auc: 0.956298
# [130]	training's auc: 1	valid_0's auc: 0.956106
# [140]	training's auc: 1	valid_0's auc: 0.956525
# [150]	training's auc: 1	valid_0's auc: 0.957661
# [160]	training's auc: 1	valid_0's auc: 0.957646
# [170]	training's auc: 1	valid_0's auc: 0.958103
# [180]	training's auc: 1	valid_0's auc: 0.958127
# [190]	training's auc: 1	valid_0's auc: 0.95781
# [200]	training's auc: 1	valid_0's auc: 0.957948
# [210]	training's auc: 1	valid_0's auc: 0.958605
# [220]	training's auc: 1	valid_0's auc: 0.958498
# [230]	training's auc: 1	valid_0's auc: 0.959003
# [240]	training's auc: 1	valid_0's auc: 0.959108
# [250]	training's auc: 1	valid_0's auc: 0.959619
# [260]	training's auc: 1	valid_0's auc: 0.959616
# [270]	training's auc: 1	valid_0's auc: 0.959568
# [280]	training's auc: 1	valid_0's auc: 0.959568
# [290]	training's auc: 1	valid_0's auc: 0.959568
# [300]	training's auc: 1	valid_0's auc: 0.959568
# [310]	training's auc: 1	valid_0's auc: 0.959568
# [320]	training's auc: 1	valid_0's auc: 0.959568
# [330]	training's auc: 1	valid_0's auc: 0.959568
# [340]	training's auc: 1	valid_0's auc: 0.959568
# [350]	training's auc: 1	valid_0's auc: 0.959568
# Early stopping, best iteration is:
# [254]	training's auc: 1	valid_0's auc: 0.959735
# Done!

# %%
# 验证集结果
X_valid['prob'] = lgb_val_0.predict(X_valid[use_cols])
X_valid['pred'] = np.where(X_valid['prob'] > 0.5, 1, 0)

f1_05 = np.round(f1_score(y_valid, X_valid['pred']), 4)
auc = roc_auc_score(y_valid, X_valid['prob'])

print('f1_05: ', f1_05)
print('auc: ', auc)
# Out:
# f1_05:  0.8836
# auc:  0.9597353757114842

# %%
lgb_train_all = lgb.Dataset(df_train[use_cols].values, df_train['label'])   

print('Start training...')

lgb_model = lgb.train(params,
                      lgb_train_all,
                      num_boost_round=lgb_val_0.best_iteration + 20)

print('Done!')
# Out:
# Start training...
# Done!

# %%
df_test['label'] = np.where(lgb_model.predict(df_test[use_cols]) > 0.5, 1, 0)
# df_test.loc[df_test['arpu_202004'] <= 0, 'label'] = 1
df_test[['phone_no_m', 'label']].to_csv('../sub/sub_{}_{}.csv'.format(time.strftime('%Y%m%d'), f1_05), index=False)
