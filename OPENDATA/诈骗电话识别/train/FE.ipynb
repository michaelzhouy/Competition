# %%
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import lightgbm as lgb
import gc
import warnings
from tqdm import tqdm
from sklearn.metrics import f1_score, roc_auc_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold, KFold
from itertools import product
from mlxtend.feature_selection import SequentialFeatureSelector
from sklearn.preprocessing import LabelEncoder
from scipy import stats
from feature_selector import FeatureSelector
from sklearn.decomposition import NMF

warnings.filterwarnings('ignore')

pd.set_option('display.unicode.ambiguous_as_wide', True)
pd.set_option('display.unicode.east_asian_width', True)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option("display.max_colwidth", 100)
pd.set_option('display.width', 1000)
# Out:
# C:\Users\z\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# 节省内存读文件
def reduce_mem_usage(df):
    """
    iterate through all the columns of a dataframe and modify the data type to reduce memory usage.
    @param df:
    @return:
    """
    start_mem = df.memory_usage().sum()
    print('Memory usage of dataframe is {:.2f} MB'.format(start_mem))

    for col in df.columns:
        col_type = df[col].dtype

        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        else:
            df[col] = df[col].astype('str')

    end_mem = df.memory_usage().sum()
    print('Memory usage after optimization is: {:.2f} MB'.format(end_mem))
    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))
    return df

# %%
class MeanEncoder:
    def __init__(self, categorical_features, n_splits=10, target_type='classification', prior_weight_func=None):
        """
        :param categorical_features: list of str, the name of the categorical columns to encode
 
        :param n_splits: the number of splits used in mean encoding
 
        :param target_type: str, 'regression' or 'classification'
 
        :param prior_weight_func:
        a function that takes in the number of observations, and outputs prior weight
        when a dict is passed, the default exponential decay function will be used:
        k: the number of observations needed for the posterior to be weighted equally as the prior
        f: larger f --> smaller slope
        """
 
        self.categorical_features = categorical_features
        self.n_splits = n_splits
        self.learned_stats = {}
 
        if target_type == 'classification':
            self.target_type = target_type
            self.target_values = []
        else:
            self.target_type = 'regression'
            self.target_values = None
 
        if isinstance(prior_weight_func, dict):
            self.prior_weight_func = eval('lambda x: 1 / (1 + np.exp((x - k) / f))', dict(prior_weight_func, np=np))
        elif callable(prior_weight_func):
            self.prior_weight_func = prior_weight_func
        else:
            self.prior_weight_func = lambda x: 1 / (1 + np.exp((x - 2) / 1))
 
    @staticmethod
    def mean_encode_subroutine(X_train, y_train, X_test, variable, target, prior_weight_func):
        X_train = X_train[[variable]].copy()
        X_test = X_test[[variable]].copy()
 
        if target is not None:
            nf_name = '{}_pred_{}'.format(variable, target)
            X_train['pred_temp'] = (y_train == target).astype(int)  # classification
        else:
            nf_name = '{}_pred'.format(variable)
            X_train['pred_temp'] = y_train  # regression
        prior = X_train['pred_temp'].mean()
 
        col_avg_y = X_train.groupby(by=variable, axis=0)['pred_temp'].agg(['mean', 'size'])
        col_avg_y['size'] = prior_weight_func(col_avg_y['size'])
        col_avg_y[nf_name] = col_avg_y['size'] * prior + (1 - col_avg_y['size']) * col_avg_y['mean']
        col_avg_y.drop(['size', 'mean'], axis=1, inplace=True)
 
        nf_train = X_train.join(col_avg_y, on=variable)[nf_name].values
        nf_test = X_test.join(col_avg_y, on=variable).fillna(prior, inplace=False)[nf_name].values
 
        return nf_train, nf_test, prior, col_avg_y
 
    def fit_transform(self, X, y):
        """
        :param X: pandas DataFrame, n_samples * n_features
        :param y: pandas Series or numpy array, n_samples
        :return X_new: the transformed pandas DataFrame containing mean-encoded categorical features
        """
        X_new = X.copy()
        if self.target_type == 'classification':
            skf = StratifiedKFold(self.n_splits)
        else:
            skf = KFold(self.n_splits)
 
        if self.target_type == 'classification':
            self.target_values = sorted(set(y))
            self.learned_stats = {'{}_pred_{}'.format(variable, target): [] for variable, target in
                                  product(self.categorical_features, self.target_values)}
            for variable, target in product(self.categorical_features, self.target_values):
                nf_name = '{}_pred_{}'.format(variable, target)
                X_new.loc[:, nf_name] = np.nan
                for large_ind, small_ind in skf.split(X, y):
                    nf_large, nf_small, prior, col_avg_y = MeanEncoder.mean_encode_subroutine(
                        X_new.iloc[large_ind], y.iloc[large_ind], X_new.iloc[small_ind], variable, target, self.prior_weight_func)
                    X_new.iloc[small_ind, -1] = nf_small
                    self.learned_stats[nf_name].append((prior, col_avg_y))
        else:
            self.learned_stats = {'{}_pred'.format(variable): [] for variable in self.categorical_features}
            for variable in self.categorical_features:
                nf_name = '{}_pred'.format(variable)
                X_new.loc[:, nf_name] = np.nan
                for large_ind, small_ind in skf.split(X, y):
                    nf_large, nf_small, prior, col_avg_y = MeanEncoder.mean_encode_subroutine(
                        X_new.iloc[large_ind], y.iloc[large_ind], X_new.iloc[small_ind], variable, None, self.prior_weight_func)
                    X_new.iloc[small_ind, -1] = nf_small
                    self.learned_stats[nf_name].append((prior, col_avg_y))
        return X_new
 
    def transform(self, X):
        """
        :param X: pandas DataFrame, n_samples * n_features
        :return X_new: the transformed pandas DataFrame containing mean-encoded categorical features
        """
        X_new = X.copy()
 
        if self.target_type == 'classification':
            for variable, target in product(self.categorical_features, self.target_values):
                nf_name = '{}_pred_{}'.format(variable, target)
                X_new[nf_name] = 0
                for prior, col_avg_y in self.learned_stats[nf_name]:
                    X_new[nf_name] += X_new[[variable]].join(col_avg_y, on=variable).fillna(prior, inplace=False)[
                        nf_name]
                X_new[nf_name] /= self.n_splits
        else:
            for variable in self.categorical_features:
                nf_name = '{}_pred'.format(variable)
                X_new[nf_name] = 0
                for prior, col_avg_y in self.learned_stats[nf_name]:
                    X_new[nf_name] += X_new[[variable]].join(col_avg_y, on=variable).fillna(prior, inplace=False)[
                        nf_name]
                X_new[nf_name] /= self.n_splits
 
        return X_new

# %%
def count_encode(df, cols):
    for col in tqdm(cols):
        print(col)
        vc = df[col].value_counts(dropna=True, normalize=True)
        df[col + '_count'] = df[col].map(vc).astype('float32')
    return df
        
        
def label_encode(df, cols):
    le = LabelEncoder()
    for col in tqdm(cols):
        df[col] = df[col].fillna('NA')
        df[col] = le.fit_transform(df[col].astype(str))
    return df


def cross_cat_num(df, cat_col, num_col):
    for f1 in tqdm(cat_col):
        g = df.groupby(f1, as_index=False)
        for f2 in tqdm(num_col):
            df_new = g[f2].agg({
                '{}_{}_max'.format(f1, f2): 'max',
                '{}_{}_min'.format(f1, f2): 'min',
                '{}_{}_median'.format(f1, f2): 'median',
                '{}_{}_mean'.format(f1, f2): 'mean',
                '{}_{}_skew'.format(f1, f2): 'skew',
                '{}_{}_nunique'.format(f1, f2): 'nunique'
            })
            df = df.merge(df_new, on=f1, how='left')
            del df_new
            gc.collect()
    return df

# %%
train_user = reduce_mem_usage(pd.read_hdf('../input/train_user.h5'))
test_user = reduce_mem_usage(pd.read_hdf('../input/test_user.h5'))
# Out:
# Memory usage of dataframe is 219816.00 MB
# Memory usage after optimization is: 219816.00 MB
# Decreased by 0.0%
# Memory usage of dataframe is 71575.00 MB
# Memory usage after optimization is: 71575.00 MB
# Decreased by 0.0%

# %%
# 将city_name和county_name拼接起来
train_user['city_name_county_name'] = train_user['city_name'].astype(str) + '_' + train_user['county_name'].astype(str)
test_user['city_name_county_name'] = test_user['city_name'].astype(str) + '_' + test_user['county_name'].astype(str)

# %%
cat_feat = ['city_name', 'county_name', 'city_name_county_name']
num_feat = ['idcard_cnt', 'arpu_202004', 'idcard_cnt*arpu_202004', 'arpu_202004/idcard_cnt']

# %%
y = train_user['label']

ME = MeanEncoder(categorical_features=cat_feat,
                 n_splits=3,
                 target_type='classification',
                 prior_weight_func=None)
X_data = ME.fit_transform(train_user.drop('label', axis=1), y)
X_test = ME.transform(test_user)

train_user = X_data.copy()
train_user['label'] = y
test_user = X_test.copy()

del X_data, X_test
gc.collect()

train_user.shape, test_user.shape
# Out:
# ((6106, 13), (2045, 12))

# %%
df_user = pd.concat([train_user, test_user])

del train_user, test_user
gc.collect()
# Out:
# 20

# %%
user_phone_no_m = df_user[['phone_no_m']].copy()

# %%
# 电话的数量*月消费额
df_user['idcard_cnt*arpu_202004'] = df_user['idcard_cnt'] * df_user['arpu_202004']

# 月消费额/电话的数量
df_user['arpu_202004/idcard_cnt'] = df_user['arpu_202004'] / (df_user['idcard_cnt'] + 0.0001)

# %%
df_user = cross_cat_num(df_user, cat_feat, num_feat)
# Out:
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/4 [00:00<?, ?it/s]
#  50%|██████████████████████████████████████████                                          | 2/4 [00:00<00:00, 11.12it/s]
#  33%|████████████████████████████                                                        | 1/3 [00:00<00:00,  2.69it/s]
#   0%|                                                                                            | 0/4 [00:00<?, ?it/s]
#  25%|█████████████████████                                                               | 1/4 [00:00<00:00,  6.29it/s]
#  50%|██████████████████████████████████████████                                          | 2/4 [00:00<00:00,  6.66it/s]
#  75%|███████████████████████████████████████████████████████████████                     | 3/4 [00:00<00:00,  7.02it/s]
#  67%|████████████████████████████████████████████████████████                            | 2/3 [00:00<00:00,  2.32it/s]
#   0%|                                                                                            | 0/4 [00:00<?, ?it/s]
#  25%|█████████████████████                                                               | 1/4 [00:00<00:00,  5.94it/s]
#  50%|██████████████████████████████████████████                                          | 2/4 [00:00<00:00,  6.14it/s]
#  75%|███████████████████████████████████████████████████████████████                     | 3/4 [00:00<00:00,  6.48it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:01<00:00,  2.06it/s]

# %%
df_user = count_encode(df_user, cat_feat + ['idcard_cnt'])
# Out:
#   0%|                                                                                            | 0/4 [00:00<?, ?it/s]
# city_name
# county_name
# city_name_county_name
# idcard_cnt
# 100%|███████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 121.28it/s]

# %%
df_user = label_encode(df_user, cat_feat)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 100.02it/s]

# %%
df_user.to_hdf('../input/user_features.h5', 'df', index=False)

del df_user
gc.collect()
# Out:
# 77

# %% [markdown]
# ## voc表

# %%
train_voc = pd.read_hdf('../input/train_voc.h5')
test_voc = pd.read_hdf('../input/test_voc.h5')

# %%
df_voc = pd.concat([train_voc, test_voc])

del train_voc, test_voc
gc.collect()
# Out:
# 128

# %%
phone_no_m = user_phone_no_m.merge(df_voc, on='phone_no_m', how='left')
phone_no_m = phone_no_m[phone_no_m['start_datetime'].notnull()]

# %%
opposite_no_m = user_phone_no_m.merge(df_voc,
                                      left_on='phone_no_m',
                                      right_on='opposite_no_m',
                                      how='left')
opposite_no_m = opposite_no_m[opposite_no_m['start_datetime'].notnull()]

opposite_no_m.drop('phone_no_m_y',
                   axis=1,
                   inplace=True)
opposite_no_m.rename(columns={'opposite_no_m': 'phone_no_m',
                              'phone_no_m_x': 'opposite_no_m'},
                     inplace=True)

df_voc = pd.concat([phone_no_m, opposite_no_m])
print(df_voc.shape)

del phone_no_m, opposite_no_m
gc.collect()
# Out:
# (985955, 8)
# 0

# %%
df_voc['city_name_county_name'] = df_voc['city_name'] + '_' + df_voc['county_name']

# %%
df_voc['voc_day'] = df_voc['start_datetime'].astype('datetime64').dt.day
df_voc['voc_hour'] = df_voc['start_datetime'].astype('datetime64').dt.hour
df_voc['voc_dayofweek'] = df_voc['start_datetime'].astype('datetime64').dt.dayofweek

# %%
phone_no_m = df_voc[['phone_no_m']].copy()
phone_no_m = phone_no_m.drop_duplicates(subset=['phone_no_m'],
                                        keep='last')

# %%
# 通话次数，通话人数
tmp = df_voc.groupby('phone_no_m')['opposite_no_m'].agg(opposite_cnt='count',
                                                        opposite_nunique='nunique')
phone_no_m = phone_no_m.merge(tmp, how='left', on='phone_no_m')

# 人均通话次数
phone_no_m['voc_cnt_per_capita'] = phone_no_m['opposite_cnt'] / (phone_no_m['opposite_nunique'] + 0.0001)

del tmp
gc.collect()
# Out:
# 20

# %%
"""
主叫通话
"""

df_calltype_id_1 = df_voc.loc[df_voc['calltype_id'] == 1, :].copy()

# 主叫通话次数，主叫通话使用的手机个数
tmp = df_calltype_id_1.groupby('phone_no_m')['imei_m'].agg(call_1_cnt='count',
                                                           imeis_1='nunique')
phone_no_m = phone_no_m.merge(tmp, on='phone_no_m', how='left')
del tmp
gc.collect()

# 主叫通话人数
tmp = df_calltype_id_1.groupby('phone_no_m')['opposite_no_m'].agg(opposite_no_m_cnt='nunique')
phone_no_m = phone_no_m.merge(tmp, on='phone_no_m', how='left')
del tmp
gc.collect()


# 主叫通话时长
tmp = df_calltype_id_1.groupby('phone_no_m')['call_dur'].agg(call_dur_1_sum='sum',
                                                             call_dur_1_max='max',
                                                             call_dur_1_min='min',
                                                             call_dur_1_std='std',
                                                             call_dur_1_median='median',
                                                             call_dur_1_mean='mean')
phone_no_m = phone_no_m.merge(tmp, on='phone_no_m', how='left')
del tmp
gc.collect()


# 主叫通话时长小于等于30s的次数
tmp1 = df_calltype_id_1[df_calltype_id_1['call_dur'] <= 30]
tmp2 = tmp1.groupby('phone_no_m')['call_dur'].agg(call_dur_30s_cnt='count')
phone_no_m = phone_no_m.merge(tmp2, on='phone_no_m', how='left')
del tmp1, tmp2
gc.collect()

# 主叫通话时长大于30s，小于等于60s的次数
tmp1 = df_calltype_id_1[(df_calltype_id_1['call_dur'] > 30) & (df_calltype_id_1['call_dur'] <= 60)]
tmp2 = tmp1.groupby('phone_no_m')['call_dur'].agg(call_dur_30_60s_cnt='count')
phone_no_m = phone_no_m.merge(tmp2, on='phone_no_m', how='left')
del tmp1, tmp2
gc.collect()

# 主叫通话时长大于60s，小于120s的次数
tmp1 = df_calltype_id_1[(df_calltype_id_1['call_dur'] > 60) & (df_calltype_id_1['call_dur'] <= 120)]
tmp2 = tmp1.groupby('phone_no_m')['call_dur'].agg(call_dur_60_120s_cnt='count')
phone_no_m = phone_no_m.merge(tmp2, on='phone_no_m', how='left')
del tmp1, tmp2
gc.collect()

# 主叫通话时长大于120s，小于300s的次数
tmp1 = df_calltype_id_1[(df_calltype_id_1['call_dur'] > 120) & (df_calltype_id_1['call_dur'] <= 300)]
tmp2 = tmp1.groupby('phone_no_m')['call_dur'].agg(call_dur_120_300s_cnt='count')
phone_no_m = phone_no_m.merge(tmp2, on='phone_no_m', how='left')
del tmp1, tmp2
gc.collect()

# 主叫通话时长大于300s的次数
tmp1 = df_calltype_id_1[df_calltype_id_1['call_dur'] > 300]
tmp2 = tmp1.groupby('phone_no_m')['call_dur'].agg(call_dur_300s_cnt='count')
phone_no_m = phone_no_m.merge(tmp2, on='phone_no_m', how='left')
del tmp1, tmp2
gc.collect()


# 主叫通话时长小于等于30s的次数的占比
phone_no_m['call_dur_30s_cnt_rate'] = phone_no_m['call_dur_30s_cnt'] / phone_no_m['call_1_cnt']

# 主叫通话时长大于30s，小于60s的次数的占比
phone_no_m['call_dur_30_60s_cnt_rate'] = phone_no_m['call_dur_30_60s_cnt'] / phone_no_m['call_1_cnt']

# 主叫通话时长大于60s，小于120s的次数的占比
phone_no_m['call_dur_60_120s_cnt_rate'] = phone_no_m['call_dur_60_120s_cnt'] / phone_no_m['call_1_cnt']

# 主叫通话时长大于120s，小于300s的次数的占比
phone_no_m['call_dur_120_300s_cnt_rate'] = phone_no_m['call_dur_120_300s_cnt'] / phone_no_m['call_1_cnt']

# 主叫通话时长大于300s的次数的占比
phone_no_m['call_dur_300s_cnt_rate'] = phone_no_m['call_dur_300s_cnt'] / phone_no_m['call_1_cnt']



# 主叫通话次数的占比
phone_no_m["call_type_id_1_rate"] = phone_no_m['call_1_cnt'] / phone_no_m['opposite_cnt']

# 主叫通话时所在地市变动的个数
tmp = df_calltype_id_1.groupby('phone_no_m')['city_name'].agg(city_name_nunique='nunique')
phone_no_m = phone_no_m.merge(tmp, on='phone_no_m', how='left')
del tmp
gc.collect()

# 主叫通话时所在区县变动的个数
tmp = df_calltype_id_1.groupby('phone_no_m')['county_name'].agg(county_name_nunique='nunique')
phone_no_m = phone_no_m.merge(tmp, on='phone_no_m', how='left')
del tmp
gc.collect()

# 主叫通话时所在地市_区县变动的个数
tmp = df_calltype_id_1.groupby("phone_no_m")['city_name_county_name'].agg(city_name_county_name_nunique='nunique')
phone_no_m = phone_no_m.merge(tmp, on='phone_no_m', how='left')
del tmp
gc.collect()

# 线上效果变差，不用
# # 主叫通话每天的通话次数
# calltype_id_1_voc_day_cnt_res = df_calltype_id_1.groupby(['phone_no_m', 'voc_day'])['phone_no_m'].count().unstack()
# for i in df_calltype_id_1['voc_day'].unique():
#     phone_no_m['calltype_id_1_voc_day{}_count'.format(i)] = phone_no_m['phone_no_m'].map(calltype_id_1_voc_day_cnt_res[i])

# del calltype_id_1_voc_day_cnt_res
# gc.collect()
# Out:
# 0

# %%
"""
被叫通话
"""

df_calltype_id_2 = df_voc.loc[df_voc['calltype_id'] == 2, :].copy()

# 被叫通话的次数
tmp = df_calltype_id_2.groupby('phone_no_m')['imei_m'].agg(call_2_cnt='count')
phone_no_m = phone_no_m.merge(tmp, on='phone_no_m', how='left')

# 被叫通话次数的占比
phone_no_m["call_type_id_2_rate"] = phone_no_m['call_2_cnt'] / phone_no_m['opposite_cnt']

del tmp, df_calltype_id_2
gc.collect()

# 线上变差，删除
# 主叫次数/被叫次数
phone_no_m['voc_calltype_1/2'] = phone_no_m['call_1_cnt'] / (phone_no_m['call_2_cnt'] + 0.0001)

# %%
"""
呼叫转移
"""

df_calltype_id_3 = df_voc.loc[df_voc['calltype_id'] == 3, :].copy()

# 呼叫转移的次数
tmp = df_calltype_id_3.groupby('phone_no_m')['imei_m'].agg(voc_calltype_id_3_cnt='count')
phone_no_m = phone_no_m.merge(tmp, on='phone_no_m', how='left')

# 呼叫转移次数的占比
phone_no_m["call_type_id_3_rate"] = phone_no_m['voc_calltype_id_3_cnt'] / phone_no_m['opposite_cnt']

del tmp, df_calltype_id_3
gc.collect()

# 线上变差，删除
# # 主叫次数/呼叫转移次数
# phone_no_m['voc_calltype_1/3'] = phone_no_m['voc_calltype_id_1_cnt'] / (phone_no_m['voc_calltype_id_3_cnt'] + 0.0001)
# Out:
# 0

# %%
"""
与对端通话统计
"""

# 与对端通话次数，与对端通话时长
tmp = df_voc.groupby(['phone_no_m', 'opposite_no_m'])['call_dur'].agg(call_count='count',
                                                                      call_sum='sum')

# 与对端通话次数的统计量
phone2opposite = tmp.groupby('phone_no_m')['call_count'].agg(phone2opposite_cnt_mean='mean',
                                                             phone2opposite_cnt_median='median',
                                                             phone2opposite_cnt_min='min',
                                                             phone2opposite_cnt_max='max',
                                                             phone2opposite_cnt_std='std')
phone_no_m = phone_no_m.merge(phone2opposite, on='phone_no_m', how='left')
del phone2opposite
gc.collect()


# 与对端总通话时长的统计量
phone2opposite = tmp.groupby('phone_no_m')['call_sum'].agg(phone2opposite_call_dur_mean='mean',
                                                           phone2opposite_call_dur_median='median',
                                                           phone2opposite_call_dur_min='min',
                                                           phone2opposite_call_dur_max='max',
                                                           phone2opposite_call_dur_std='std')
phone_no_m = phone_no_m.merge(phone2opposite, on='phone_no_m', how='left')
del phone2opposite, tmp
gc.collect()
# Out:
# 0

# %%
"""
通话时长的统计
"""

# 通话时长的统计量
tmp = df_voc.groupby('phone_no_m')['call_dur'].agg(call_dur_mean='mean',
                                                   call_dur_median='median',
                                                   call_dur_max='max',
                                                   call_dur_min='min',
                                                   call_dur_std='std',
                                                   call_dur_sum='sum')
phone_no_m = phone_no_m.merge(tmp, on='phone_no_m', how='left')
del tmp
gc.collect()
# Out:
# 0

# %%
"""
收费号码位置变动
"""

# 收费号码所在地市的个数
tmp = df_voc.groupby('phone_no_m')['city_name'].agg(city_name_nunique='nunique')
phone_no_m = phone_no_m.merge(tmp, on='phone_no_m', how='left')

# 收费号码所在区县的个数
tmp = df_voc.groupby('phone_no_m')['county_name'].agg(county_name_nunique='nunique')
phone_no_m = phone_no_m.merge(tmp, on='phone_no_m', how='left')

# 收费号码所在地市_区县的个数
tmp = df_voc.groupby('phone_no_m')['city_name_county_name'].agg(city_name_county_name_nunique='nunique')
phone_no_m = phone_no_m.merge(tmp, on='phone_no_m', how='left')

# 收费号码通话类型的个数
tmp = df_voc.groupby('phone_no_m')['calltype_id'].agg(calltype_id_unique='nunique')
phone_no_m = phone_no_m.merge(tmp, on='phone_no_m', how='left')

del tmp
gc.collect()
# Out:
# 0

# %%
"""
通话时间点的偏好
"""

# hour通话次数最高
tmp = df_voc.groupby('phone_no_m')['voc_hour'].agg(voc_hour_mode=lambda x: stats.mode(x)[0][0],        # 频次最高的元素
                                                   voc_hour_mode_count=lambda x: stats.mode(x)[1][0],  # 频次最高的元素的频次
                                                   voc_hour_nunique='nunique')
phone_no_m = phone_no_m.merge(tmp, on='phone_no_m', how='left')

# day通话次数最高
tmp = df_voc.groupby('phone_no_m')['voc_day'].agg(voc_day_mode=lambda x: stats.mode(x)[0][0],          # 频次最高的元素
                                                  voc_day_mode_count=lambda x: stats.mode(x)[1][0],    # 频次最高的元素的频次
                                                  voc_day_nunique='nunique')                           # 一个月有多少天打了电话
phone_no_m = phone_no_m.merge(tmp, on='phone_no_m', how='left')

del tmp
gc.collect()


# dayofweek通话次数最高
tmp = df_voc.groupby('phone_no_m')['voc_dayofweek'].agg(voc_dayofweek_mode=lambda x: stats.mode(x)[0][0],          # 频次最高的元素
                                                        voc_dayofweek_mode_count=lambda x: stats.mode(x)[1][0],    # 频次最高的元素的频次
                                                        voc_dayofweek_nunique='nunique')                           
phone_no_m = phone_no_m.merge(tmp, on='phone_no_m', how='left')

del tmp
gc.collect()
# Out:
# 0

# %%
# 每天通话次数的均值、标准差
tmp1 = df_voc.groupby(['phone_no_m', 'voc_day'])['phone_no_m'].agg(voc_day_cnt='count')
tmp2 = tmp1.groupby('phone_no_m')['voc_day_cnt'].agg(voc_day_cnt_mean='mean',
                                                     voc_day_cnt_std='std')
phone_no_m = phone_no_m.merge(tmp2, on='phone_no_m', how='left')

del tmp1, tmp2
gc.collect()
# Out:
# 20

# %%
# 每天的通话次数
voc_day_cnt_res = df_voc.groupby(['phone_no_m', 'voc_day'])['phone_no_m'].count().unstack()
for i in df_voc['voc_day'].unique():
    phone_no_m['voc_day{}_count'.format(i)] = phone_no_m['phone_no_m'].map(voc_day_cnt_res[i])

    
# 每天的通话人数
voc_day_nunique_res = df_voc.groupby(['phone_no_m', 'voc_day'])['opposite_no_m'].nunique().unstack()
for i in df_voc['voc_day'].unique():
    phone_no_m['voc_day{}_nunique'.format(i)] = phone_no_m['phone_no_m'].map(voc_day_nunique_res[i])

    
# 每天的通话时长
voc_day_call_dur_res = df_voc.groupby(['phone_no_m', 'voc_day'])['call_dur'].sum().unstack()
for i in df_voc['voc_day'].unique():
    phone_no_m['voc_day{}_call_dur_sum'.format(i)] = phone_no_m['phone_no_m'].map(voc_day_call_dur_res[i])



# 每小时的通话次数
voc_hour_cnt_res = df_voc.groupby(['phone_no_m', 'voc_hour'])['phone_no_m'].count().unstack()
for i in df_voc['voc_hour'].unique():
    phone_no_m['voc_hour{}_count'.format(i)] = phone_no_m['phone_no_m'].map(voc_hour_cnt_res[i])
    
# 每小时的通话人数
voc_hour_nunique_res = df_voc.groupby(['phone_no_m', 'voc_hour'])['opposite_no_m'].nunique().unstack()
for i in df_voc['voc_hour'].unique():
    phone_no_m['voc_hour{}_nunique'.format(i)] = phone_no_m['phone_no_m'].map(voc_hour_nunique_res[i])
    

# 每小时的通话时长
voc_hour_call_dur_res = df_voc.groupby(['phone_no_m', 'voc_hour'])['call_dur'].sum().unstack()
for i in df_voc['voc_hour'].unique():
    phone_no_m['voc_hour{}_call_dur_sum'.format(i)] = phone_no_m['phone_no_m'].map(voc_hour_call_dur_res[i])

    

# 每周几的通话次数
voc_dayofweek_cnt_res = df_voc.groupby(['phone_no_m', 'voc_dayofweek'])['phone_no_m'].count().unstack()
for i in df_voc['voc_dayofweek'].unique():
    phone_no_m['voc_dayofweek{}_count'.format(i)] = phone_no_m['phone_no_m'].map(voc_dayofweek_cnt_res[i])
    
# 每周几的通话人数
voc_dayoffweek_nunique_res = df_voc.groupby(['phone_no_m', 'voc_dayofweek'])['opposite_no_m'].nunique().unstack()
for i in df_voc['voc_dayofweek'].unique():
    phone_no_m['voc_dayofweek{}_nunique'.format(i)] = phone_no_m['phone_no_m'].map(voc_dayoffweek_nunique_res[i])
    

# 每周几的通话时长
voc_dayofweek_call_dur_res = df_voc.groupby(['phone_no_m', 'voc_dayofweek'])['call_dur'].sum().unstack()
for i in df_voc['voc_dayofweek'].unique():
    phone_no_m['voc_dayofweek{}_call_dur_sum'.format(i)] = phone_no_m['phone_no_m'].map(voc_dayofweek_call_dur_res[i])

# %%
phone_no_m.to_hdf('../input/voc_features.h5', 'df', index=False)
del phone_no_m
gc.collect()
# Out:
# 64

# %% [markdown]
# ## sms表

# %%
train_sms = pd.read_hdf('../input/train_sms.h5')
test_sms = pd.read_hdf('../input/test_sms.h5')

# %%
df_sms = pd.concat([train_sms, test_sms])

del train_sms, test_sms
gc.collect()
# Out:
# 106

# %%
df_sms['sms_day'] = df_sms['request_datetime'].astype('datetime64').dt.day
df_sms['sms_hour'] = df_sms['request_datetime'].astype('datetime64').dt.hour
df_sms['sms_dayofweek'] = df_sms['request_datetime'].astype('datetime64').dt.dayofweek

# %%
phone_no_m = df_sms[["phone_no_m"]].copy()
phone_no_m = phone_no_m.drop_duplicates(subset=['phone_no_m'], keep='last')

# %%
# 短信次数，短信人数
tmp = df_sms.groupby('phone_no_m')['opposite_no_m'].agg(sms_cnt='count', sms_nunique='nunique')

# 人均短信次数
tmp['sms_cnt_per_capita'] = tmp['sms_cnt'] / (tmp['sms_nunique'] + 0.0001)
phone_no_m = phone_no_m.merge(tmp, on='phone_no_m', how='left')

del tmp
gc.collect()
# Out:
# 0

# %%
"""
短信上行，短信下行
"""

# 短信上行
df_sms_calltype1 = df_sms[df_sms['calltype_id'] == 1].copy()
tmp = df_sms_calltype1.groupby('phone_no_m')['calltype_id'].agg(sms_calltype1_cnt="count")
phone_no_m = phone_no_m.merge(tmp, on='phone_no_m', how='left')

# 短信上行比例
phone_no_m['sms_calltype1_rate'] = phone_no_m['sms_calltype1_cnt'] / phone_no_m['sms_cnt']

del tmp, df_sms_calltype1

# 短信下行
df_sms_calltype2 = df_sms[df_sms['calltype_id'] == 2].copy()
tmp = df_sms_calltype2.groupby('opposite_no_m')['calltype_id'].agg(sms_calltype2_cnt="count")
phone_no_m = phone_no_m.merge(tmp, left_on='phone_no_m', right_on='opposite_no_m', how='left')

# 短信下行比例
phone_no_m['sms_calltype2_rate'] = phone_no_m['sms_calltype2_cnt'] / phone_no_m['sms_cnt']

# 短信上行/短信下行
phone_no_m['type1_rate/type2_rate'] = phone_no_m['sms_calltype1_cnt'] / (phone_no_m['sms_calltype2_cnt'] + 0.00001)

# 删除，效果变差
# # 短信下行/短信上行
# phone_no_m['type2_rate/type1_rate'] = phone_no_m['sms_calltype2_cnt'] / (phone_no_m['sms_calltype1_cnt'] + 0.00001)

del tmp, df_sms_calltype2
gc.collect()
# Out:
# 0

# %%
"""
短信时间点的偏好
"""

tmp = df_sms.groupby('phone_no_m')['sms_hour'].agg(sms_hour_mode=lambda x: stats.mode(x)[0][0],        # 频次最高的元素
                                                   sms_hour_mode_count=lambda x: stats.mode(x)[1][0],  # 频次最高的元素的频次
                                                   sms_hour_nunique='nunique')                          # 一个月有多少个小时发了短信
phone_no_m = phone_no_m.merge(tmp, on='phone_no_m', how='left')

del tmp
gc.collect()

tmp = df_sms.groupby('phone_no_m')['sms_day'].agg(sms_day_mode=lambda x: stats.mode(x)[0][0],          # 频次最高的元素
                                                  sms_day_mode_count=lambda x: stats.mode(x)[1][0],    # 频次最高的元素的频次
                                                  sms_day_nunique='nunique')                            # 一个月有多少天发了短信
phone_no_m = phone_no_m.merge(tmp, on='phone_no_m', how='left')

del tmp
gc.collect()


tmp = df_sms.groupby('phone_no_m')['sms_dayofweek'].agg(sms_dayofweek_mode=lambda x: stats.mode(x)[0][0],          # 频次最高的元素
                                                        sms_dayofweek_mode_count=lambda x: stats.mode(x)[1][0],    # 频次最高的元素的频次
                                                        sms_dayofweek_nunique='nunique')                            # 一个月有多少天发了短信
phone_no_m = phone_no_m.merge(tmp, on='phone_no_m', how='left')

del tmp
gc.collect()
# Out:
# 0

# %%
# 每天的短信次数
sms_day_res = df_sms.groupby(['phone_no_m', 'sms_day'])['phone_no_m'].count().unstack()
for i in df_sms['sms_day'].unique():
    phone_no_m['sms_day{}_count'.format(i)] = phone_no_m['phone_no_m'].map(sms_day_res[i])


# 每小时的短信次数
sms_hour_res = df_sms.groupby(['phone_no_m', 'sms_hour'])['phone_no_m'].count().unstack()
for i in df_sms['sms_hour'].unique():
    phone_no_m['sms_hour{}_count'.format(i)] = phone_no_m['phone_no_m'].map(sms_hour_res[i])
    
    
# 每周几的短信次数
sms_dayofweek_res = df_sms.groupby(['phone_no_m', 'sms_dayofweek'])['phone_no_m'].count().unstack()
for i in df_sms['sms_dayofweek'].unique():
    phone_no_m['sms_weekofday{}_count'.format(i)] = phone_no_m['phone_no_m'].map(sms_dayofweek_res[i])

# %%
phone_no_m.to_hdf('../input/sms_features.h5', 'df', index=False)

del phone_no_m, df_sms
gc.collect()
# Out:
# 64

# %% [markdown]
# ## 读取数据，建模

# %%
df_user = reduce_mem_usage(pd.read_hdf('../input/user_features.h5'))
df_voc = reduce_mem_usage(pd.read_hdf('../input/voc_features.h5'))
df_sms = reduce_mem_usage(pd.read_hdf('../input/sms_features.h5'))
# df_app = reduce_mem_usage(pd.read_hdf('../input/app_features.h5'))
# Out:
# Memory usage of dataframe is 4042896.00 MB
# Memory usage after optimization is: 1858428.00 MB
# Decreased by 54.0%
# Memory usage of dataframe is 13576000.00 MB
# Memory usage after optimization is: 3482244.00 MB
# Decreased by 74.3%
# Memory usage of dataframe is 4455000.00 MB
# Memory usage after optimization is: 1292500.00 MB
# Decreased by 71.0%

# %%
df_user.shape, df_voc.shape, df_sms.shape
# Out:
# ((8151, 91), (6788, 249), (6875, 80))

# %%
df = df_user.merge(df_voc, on='phone_no_m', how='left')
df = df.merge(df_sms, on='phone_no_m', how='left')
# df = df.merge(df_app, on='phone_no_m', how='left')

del df_user, df_voc, df_sms#, df_app
gc.collect()
# Out:
# 0

# %%
df_train = df[df.label.notna()]
df_test = df[df.label.isna()]

df_train.shape, df_test.shape
# Out:
# ((6106, 418), (2045, 418))

# %%
fs = FeatureSelector(data=df_train.drop(['phone_no_m', 'label'], axis=1), labels=df_train['label'])

fs.identify_all(selection_params={'missing_threshold': 0.98,
                                  'correlation_threshold': 0.99, 
                                  'task': 'classification',
                                  'eval_metric': 'auc', 
                                  'cumulative_importance': 0.99})
# Out:
# 9 features with greater than 0.98 missing values.
#
# 0 features with a single unique value.
#
# 42 features with a correlation magnitude greater than 0.99.
#
# Training Gradient Boosting Model
#
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [109]	valid_0's auc: 0.96655	valid_0's binary_logloss: 0.169935
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [101]	valid_0's auc: 0.965576	valid_0's binary_logloss: 0.181879
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [87]	valid_0's auc: 0.952403	valid_0's binary_logloss: 0.212199
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [91]	valid_0's auc: 0.952731	valid_0's binary_logloss: 0.195562
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [93]	valid_0's auc: 0.953395	valid_0's binary_logloss: 0.221191
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [125]	valid_0's auc: 0.967545	valid_0's binary_logloss: 0.165975
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [79]	valid_0's auc: 0.944736	valid_0's binary_logloss: 0.208722
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [97]	valid_0's auc: 0.964308	valid_0's binary_logloss: 0.196218
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [91]	valid_0's auc: 0.960463	valid_0's binary_logloss: 0.180851
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [116]	valid_0's auc: 0.964838	valid_0's binary_logloss: 0.1774
#
# 21 features with zero importance after one-hot encoding.
#
# 347 features required for cumulative importance of 0.99 after one hot encoding.
# 69 features do not contribute to cumulative importance of 0.99.
#
# 91 total features out of 416 identified for removal after one-hot encoding.

# %%
train_removed_all_once = fs.remove(methods='all')
# train_removed_all_once
# Out:
# ['missing', 'single_unique', 'collinear', 'zero_importance', 'low_importance'] methods have been run
#
# Removed 91 features.

# %%
use_cols = train_removed_all_once.columns.to_list()

del train_removed_all_once
gc.collect()
# Out:
# 46

# %%
X_train, X_valid, y_train, y_valid = train_test_split(df_train[use_cols], df_train['label'],
                                                      test_size=0.2,
                                                      random_state=2020)

# %%
train_cols = [i for i in X_train.columns if i not in ['phone_no_m', 'opposite_no_m', 'label']]

# %%
params = {'objective': 'binary',
          'boosting': 'gbdt',
          'metric': 'auc',
          'learning_rate': 0.12,
          'num_leaves': 31,
          'lambda_l1': 0.1,
          'lambda_l2': 0,
          'min_data_in_leaf': 20,
          'is_unbalance': True,
          'max_depth': -1,
          'seed': 2020}

# %%
useful_cols = []
useless_cols = []

for i in train_cols:
    print(i)
    
    lgb_train = lgb.Dataset(X_train[[i]].values, y_train) 
    lgb_valid= lgb.Dataset(X_valid[[i]].values, y_valid, reference=lgb_train)
    lgb_test = lgb.train(params,
                         lgb_train,
                         num_boost_round=1000,
                         valid_sets=[lgb_valid, lgb_train],
                         early_stopping_rounds=50,
                         verbose_eval=20)
    
    print('*' * 5)
    print(lgb_test.best_score['valid_0']['auc'])
    if lgb_test.best_score['valid_0']['auc'] > 0.52:
        useful_cols.append(i)
    else:
        useless_cols.append(i)
    print('*' * 20)
    print('\n')
# Out:
# city_name
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.684155	valid_0's auc: 0.671655
# [40]	training's auc: 0.684156	valid_0's auc: 0.672408
# [60]	training's auc: 0.684158	valid_0's auc: 0.671655
# [80]	training's auc: 0.684158	valid_0's auc: 0.671655
# Early stopping, best iteration is:
# [31]	training's auc: 0.684156	valid_0's auc: 0.672408
# *****
# 0.6724078657865786
# ********************
#
#
# county_name
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.769	valid_0's auc: 0.725784
# [40]	training's auc: 0.773026	valid_0's auc: 0.729645
# [60]	training's auc: 0.774292	valid_0's auc: 0.730264
# [80]	training's auc: 0.775225	valid_0's auc: 0.731938
# [100]	training's auc: 0.775908	valid_0's auc: 0.731651
# [120]	training's auc: 0.776536	valid_0's auc: 0.731784
# [140]	training's auc: 0.7769	valid_0's auc: 0.731993
# [160]	training's auc: 0.777141	valid_0's auc: 0.731924
# [180]	training's auc: 0.777322	valid_0's auc: 0.732627
# [200]	training's auc: 0.777449	valid_0's auc: 0.732316
# [220]	training's auc: 0.777562	valid_0's auc: 0.732244
# Early stopping, best iteration is:
# [181]	training's auc: 0.777324	valid_0's auc: 0.732672
# *****
# 0.7326717726120439
# ********************
#
#
# idcard_cnt
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.728663	valid_0's auc: 0.723062
# [40]	training's auc: 0.728663	valid_0's auc: 0.723062
# Early stopping, best iteration is:
# [1]	training's auc: 0.728663	valid_0's auc: 0.723062
# *****
# 0.7230622518773616
# ********************
#
#
# arpu_202004
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.816258	valid_0's auc: 0.769841
# [40]	training's auc: 0.821375	valid_0's auc: 0.767077
# Early stopping, best iteration is:
# [4]	training's auc: 0.807055	valid_0's auc: 0.775595
# *****
# 0.7755954943320419
# ********************
#
#
# city_name_pred_0
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.688273	valid_0's auc: 0.664613
# [40]	training's auc: 0.688344	valid_0's auc: 0.664335
# Early stopping, best iteration is:
# [2]	training's auc: 0.687489	valid_0's auc: 0.667118
# *****
# 0.6671180705027024
# ********************
#
#
# county_name_pred_0
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.77144	valid_0's auc: 0.724059
# [40]	training's auc: 0.774526	valid_0's auc: 0.724313
# Early stopping, best iteration is:
# [7]	training's auc: 0.768377	valid_0's auc: 0.72656
# *****
# 0.7265598842492945
# ********************
#
#
# idcard_cnt*arpu_202004
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.836546	valid_0's auc: 0.810092
# [40]	training's auc: 0.840792	valid_0's auc: 0.808633
# Early stopping, best iteration is:
# [8]	training's auc: 0.83184	valid_0's auc: 0.814282
# *****
# 0.8142816999091214
# ********************
#
#
# arpu_202004/idcard_cnt
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.817225	valid_0's auc: 0.76353
# [40]	training's auc: 0.824213	valid_0's auc: 0.764434
# [60]	training's auc: 0.827466	valid_0's auc: 0.765254
# Early stopping, best iteration is:
# [29]	training's auc: 0.820908	valid_0's auc: 0.766239
# *****
# 0.7662385803797771
# ********************
#
#
# city_name_idcard_cnt_mean
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.683851	valid_0's auc: 0.671655
# [40]	training's auc: 0.683851	valid_0's auc: 0.671655
# Early stopping, best iteration is:
# [1]	training's auc: 0.683743	valid_0's auc: 0.672536
# *****
# 0.6725364112498207
# ********************
#
#
# city_name_idcard_cnt_skew
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.684162	valid_0's auc: 0.671655
# [40]	training's auc: 0.684161	valid_0's auc: 0.672408
# Early stopping, best iteration is:
# [1]	training's auc: 0.684054	valid_0's auc: 0.672536
# *****
# 0.6725364112498207
# ********************
#
#
# city_name_arpu_202004_max
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.684058	valid_0's auc: 0.671655
# [40]	training's auc: 0.684058	valid_0's auc: 0.671655
# Early stopping, best iteration is:
# [1]	training's auc: 0.684058	valid_0's auc: 0.671655
# *****
# 0.6716545295833931
# ********************
#
#
# city_name_arpu_202004_median
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.684163	valid_0's auc: 0.671655
# [40]	training's auc: 0.684165	valid_0's auc: 0.671655
# [60]	training's auc: 0.684163	valid_0's auc: 0.672408
# [80]	training's auc: 0.684163	valid_0's auc: 0.672408
# [100]	training's auc: 0.684163	valid_0's auc: 0.672408
# Early stopping, best iteration is:
# [54]	training's auc: 0.684163	valid_0's auc: 0.672408
# *****
# 0.6724078657865786
# ********************
#
#
# city_name_arpu_202004_mean
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.68414	valid_0's auc: 0.672595
# [40]	training's auc: 0.684149	valid_0's auc: 0.672408
# Early stopping, best iteration is:
# [1]	training's auc: 0.68414	valid_0's auc: 0.672595
# *****
# 0.6725947051226862
# ********************
#
#
# city_name_arpu_202004_nunique
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.678256	valid_0's auc: 0.677562
# [40]	training's auc: 0.67826	valid_0's auc: 0.677388
# Early stopping, best iteration is:
# [1]	training's auc: 0.678256	valid_0's auc: 0.677562
# *****
# 0.6775616420337686
# ********************
#
#
# city_name_idcard_cnt*arpu_202004_max
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.684058	valid_0's auc: 0.671655
# [40]	training's auc: 0.684058	valid_0's auc: 0.671655
# Early stopping, best iteration is:
# [9]	training's auc: 0.684058	valid_0's auc: 0.671655
# *****
# 0.6716545295833931
# ********************
#
#
# city_name_idcard_cnt*arpu_202004_median
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.684079	valid_0's auc: 0.671655
# [40]	training's auc: 0.684079	valid_0's auc: 0.671655
# Early stopping, best iteration is:
# [1]	training's auc: 0.684079	valid_0's auc: 0.671655
# *****
# 0.6716545295833931
# ********************
#
#
# city_name_idcard_cnt*arpu_202004_mean
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.68417	valid_0's auc: 0.671655
# [40]	training's auc: 0.68417	valid_0's auc: 0.671655
# [60]	training's auc: 0.68417	valid_0's auc: 0.671655
# [80]	training's auc: 0.68417	valid_0's auc: 0.671655
# Early stopping, best iteration is:
# [41]	training's auc: 0.684167	valid_0's auc: 0.672408
# *****
# 0.6724078657865786
# ********************
#
#
# city_name_arpu_202004/idcard_cnt_max
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.684116	valid_0's auc: 0.671947
# [40]	training's auc: 0.684125	valid_0's auc: 0.671655
# Early stopping, best iteration is:
# [1]	training's auc: 0.684108	valid_0's auc: 0.671947
# *****
# 0.6719474936624097
# ********************
#
#
# city_name_arpu_202004/idcard_cnt_min
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.578299	valid_0's auc: 0.561841
# [40]	training's auc: 0.578299	valid_0's auc: 0.561841
# Early stopping, best iteration is:
# [1]	training's auc: 0.578299	valid_0's auc: 0.561841
# *****
# 0.5618408308222127
# ********************
#
#
# city_name_arpu_202004/idcard_cnt_median
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.683867	valid_0's auc: 0.670468
# [40]	training's auc: 0.683867	valid_0's auc: 0.670468
# Early stopping, best iteration is:
# [1]	training's auc: 0.683867	valid_0's auc: 0.670468
# *****
# 0.6704677261204381
# ********************
#
#
# city_name_arpu_202004/idcard_cnt_mean
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.682722	valid_0's auc: 0.66981
# [40]	training's auc: 0.682726	valid_0's auc: 0.669637
# Early stopping, best iteration is:
# [1]	training's auc: 0.682722	valid_0's auc: 0.66981
# *****
# 0.6698100516573396
# ********************
#
#
# city_name_arpu_202004/idcard_cnt_skew
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.684158	valid_0's auc: 0.671841
# [40]	training's auc: 0.68417	valid_0's auc: 0.671655
# Early stopping, best iteration is:
# [1]	training's auc: 0.684156	valid_0's auc: 0.671841
# *****
# 0.6718413689195006
# ********************
#
#
# county_name_idcard_cnt_mean
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.760585	valid_0's auc: 0.726375
# [40]	training's auc: 0.76268	valid_0's auc: 0.727183
# [60]	training's auc: 0.763919	valid_0's auc: 0.726448
# [80]	training's auc: 0.764713	valid_0's auc: 0.725953
# Early stopping, best iteration is:
# [42]	training's auc: 0.762833	valid_0's auc: 0.727863
# *****
# 0.7278632754579806
# ********************
#
#
# county_name_idcard_cnt_skew
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.765615	valid_0's auc: 0.722548
# [40]	training's auc: 0.769772	valid_0's auc: 0.727762
# [60]	training's auc: 0.771846	valid_0's auc: 0.7296
# [80]	training's auc: 0.773203	valid_0's auc: 0.728352
# [100]	training's auc: 0.774253	valid_0's auc: 0.72853
# Early stopping, best iteration is:
# [62]	training's auc: 0.771892	valid_0's auc: 0.729878
# *****
# 0.7298781508585641
# ********************
#
#
# county_name_idcard_cnt_nunique
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.666928	valid_0's auc: 0.663023
# [40]	training's auc: 0.666928	valid_0's auc: 0.663023
# Early stopping, best iteration is:
# [1]	training's auc: 0.666928	valid_0's auc: 0.663023
# *****
# 0.6630225522552256
# ********************
#
#
# county_name_arpu_202004_max
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.768495	valid_0's auc: 0.725715
# [40]	training's auc: 0.772349	valid_0's auc: 0.729014
# [60]	training's auc: 0.773658	valid_0's auc: 0.729812
# [80]	training's auc: 0.774374	valid_0's auc: 0.729862
# [100]	training's auc: 0.774936	valid_0's auc: 0.729838
# [120]	training's auc: 0.77524	valid_0's auc: 0.729844
# Early stopping, best iteration is:
# [76]	training's auc: 0.774253	valid_0's auc: 0.730367
# *****
# 0.7303669225618215
# ********************
#
#
# county_name_arpu_202004_median
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.760321	valid_0's auc: 0.720843
# [40]	training's auc: 0.763788	valid_0's auc: 0.720562
# [60]	training's auc: 0.765474	valid_0's auc: 0.720287
# Early stopping, best iteration is:
# [28]	training's auc: 0.762294	valid_0's auc: 0.721947
# *****
# 0.721947194719472
# ********************
#
#
# county_name_arpu_202004_mean
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.761793	valid_0's auc: 0.716874
# [40]	training's auc: 0.766594	valid_0's auc: 0.72071
# [60]	training's auc: 0.768342	valid_0's auc: 0.720913
# [80]	training's auc: 0.769576	valid_0's auc: 0.722579
# [100]	training's auc: 0.770499	valid_0's auc: 0.723074
# [120]	training's auc: 0.771074	valid_0's auc: 0.723807
# [140]	training's auc: 0.771426	valid_0's auc: 0.72441
# [160]	training's auc: 0.771692	valid_0's auc: 0.724862
# [180]	training's auc: 0.771891	valid_0's auc: 0.725911
# [200]	training's auc: 0.772041	valid_0's auc: 0.725687
# [220]	training's auc: 0.77224	valid_0's auc: 0.726733
# [240]	training's auc: 0.77236	valid_0's auc: 0.726796
# [260]	training's auc: 0.772461	valid_0's auc: 0.726682
# [280]	training's auc: 0.77254	valid_0's auc: 0.726691
# Early stopping, best iteration is:
# [241]	training's auc: 0.772347	valid_0's auc: 0.726951
# *****
# 0.7269514994977758
# ********************
#
#
# county_name_arpu_202004_nunique
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.74423	valid_0's auc: 0.715
# [40]	training's auc: 0.745418	valid_0's auc: 0.714324
# [60]	training's auc: 0.74574	valid_0's auc: 0.714315
# Early stopping, best iteration is:
# [13]	training's auc: 0.742646	valid_0's auc: 0.716172
# *****
# 0.7161716171617162
# ********************
#
#
# county_name_idcard_cnt*arpu_202004_max
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.766741	valid_0's auc: 0.723133
# [40]	training's auc: 0.770684	valid_0's auc: 0.725327
# [60]	training's auc: 0.772576	valid_0's auc: 0.726975
# [80]	training's auc: 0.773365	valid_0's auc: 0.727285
# [100]	training's auc: 0.774167	valid_0's auc: 0.727929
# [120]	training's auc: 0.774465	valid_0's auc: 0.727705
# [140]	training's auc: 0.774802	valid_0's auc: 0.728484
# [160]	training's auc: 0.775022	valid_0's auc: 0.729046
# [180]	training's auc: 0.775224	valid_0's auc: 0.72909
# [200]	training's auc: 0.775349	valid_0's auc: 0.729374
# [220]	training's auc: 0.775466	valid_0's auc: 0.729174
# [240]	training's auc: 0.775521	valid_0's auc: 0.729165
# [260]	training's auc: 0.775585	valid_0's auc: 0.729162
# Early stopping, best iteration is:
# [229]	training's auc: 0.775483	valid_0's auc: 0.729566
# *****
# 0.7295657554885924
# ********************
#
#
# county_name_idcard_cnt*arpu_202004_min
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.598679	valid_0's auc: 0.555828
# [40]	training's auc: 0.599431	valid_0's auc: 0.560336
# [60]	training's auc: 0.599818	valid_0's auc: 0.562034
# [80]	training's auc: 0.600406	valid_0's auc: 0.56218
# [100]	training's auc: 0.600439	valid_0's auc: 0.562183
# [120]	training's auc: 0.600466	valid_0's auc: 0.562159
# [140]	training's auc: 0.600611	valid_0's auc: 0.562195
# Early stopping, best iteration is:
# [97]	training's auc: 0.600436	valid_0's auc: 0.562222
# *****
# 0.562221983067872
# ********************
#
#
# county_name_idcard_cnt*arpu_202004_median
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.756886	valid_0's auc: 0.711955
# [40]	training's auc: 0.762021	valid_0's auc: 0.714267
# [60]	training's auc: 0.764122	valid_0's auc: 0.717491
# [80]	training's auc: 0.765652	valid_0's auc: 0.718529
# [100]	training's auc: 0.766986	valid_0's auc: 0.720858
# [120]	training's auc: 0.767813	valid_0's auc: 0.720134
# [140]	training's auc: 0.76846	valid_0's auc: 0.720427
# [160]	training's auc: 0.768873	valid_0's auc: 0.720388
# [180]	training's auc: 0.769199	valid_0's auc: 0.71965
# [200]	training's auc: 0.769417	valid_0's auc: 0.72005
# Early stopping, best iteration is:
# [153]	training's auc: 0.768695	valid_0's auc: 0.721369
# *****
# 0.7213687401348831
# ********************
#
#
# county_name_idcard_cnt*arpu_202004_mean
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.768061	valid_0's auc: 0.719618
# [40]	training's auc: 0.773149	valid_0's auc: 0.72346
# [60]	training's auc: 0.774557	valid_0's auc: 0.722956
# [80]	training's auc: 0.775808	valid_0's auc: 0.724975
# [100]	training's auc: 0.776946	valid_0's auc: 0.726524
# [120]	training's auc: 0.777678	valid_0's auc: 0.726265
# [140]	training's auc: 0.778123	valid_0's auc: 0.727001
# [160]	training's auc: 0.778447	valid_0's auc: 0.727105
# [180]	training's auc: 0.77876	valid_0's auc: 0.727485
# [200]	training's auc: 0.77895	valid_0's auc: 0.727712
# [220]	training's auc: 0.779101	valid_0's auc: 0.727641
# Early stopping, best iteration is:
# [178]	training's auc: 0.77876	valid_0's auc: 0.72785
# *****
# 0.7278498230257808
# ********************
#
#
# county_name_arpu_202004/idcard_cnt_max
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.764858	valid_0's auc: 0.725929
# [40]	training's auc: 0.770001	valid_0's auc: 0.728001
# [60]	training's auc: 0.772197	valid_0's auc: 0.729342
# [80]	training's auc: 0.773721	valid_0's auc: 0.729803
# [100]	training's auc: 0.774572	valid_0's auc: 0.730186
# [120]	training's auc: 0.774962	valid_0's auc: 0.7305
# [140]	training's auc: 0.775304	valid_0's auc: 0.729978
# [160]	training's auc: 0.775639	valid_0's auc: 0.731327
# [180]	training's auc: 0.775838	valid_0's auc: 0.730935
# [200]	training's auc: 0.776179	valid_0's auc: 0.731219
# [220]	training's auc: 0.776295	valid_0's auc: 0.73109
# Early stopping, best iteration is:
# [189]	training's auc: 0.775967	valid_0's auc: 0.732038
# *****
# 0.7320380135839671
# ********************
#
#
# county_name_arpu_202004/idcard_cnt_min
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.643641	valid_0's auc: 0.627623
# [40]	training's auc: 0.64548	valid_0's auc: 0.630362
# [60]	training's auc: 0.645801	valid_0's auc: 0.630305
# [80]	training's auc: 0.646011	valid_0's auc: 0.630158
# [100]	training's auc: 0.646096	valid_0's auc: 0.630125
# Early stopping, best iteration is:
# [66]	training's auc: 0.645879	valid_0's auc: 0.630556
# *****
# 0.6305558544984933
# ********************
# county_name_arpu_202004/idcard_cnt_median
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.754062	valid_0's auc: 0.707916
# [40]	training's auc: 0.756969	valid_0's auc: 0.71085
# [60]	training's auc: 0.758214	valid_0's auc: 0.712689
# [80]	training's auc: 0.759194	valid_0's auc: 0.714019
# [100]	training's auc: 0.760085	valid_0's auc: 0.714756
# [120]	training's auc: 0.760433	valid_0's auc: 0.714819
# [140]	training's auc: 0.760919	valid_0's auc: 0.714885
# [160]	training's auc: 0.761187	valid_0's auc: 0.715426
# [180]	training's auc: 0.76134	valid_0's auc: 0.71571
# [200]	training's auc: 0.76157	valid_0's auc: 0.716346
# [220]	training's auc: 0.761714	valid_0's auc: 0.716275
# [240]	training's auc: 0.76181	valid_0's auc: 0.716385
# [260]	training's auc: 0.761921	valid_0's auc: 0.716415
# [280]	training's auc: 0.762041	valid_0's auc: 0.71681
# [300]	training's auc: 0.762144	valid_0's auc: 0.717333
# [320]	training's auc: 0.762169	valid_0's auc: 0.717273
# [340]	training's auc: 0.762319	valid_0's auc: 0.717444
# [360]	training's auc: 0.762343	valid_0's auc: 0.717387
# [380]	training's auc: 0.76238	valid_0's auc: 0.717432
# Early stopping, best iteration is:
# [335]	training's auc: 0.762311	valid_0's auc: 0.717548
# *****
# 0.7175482493901564
# ********************
#
#
# county_name_arpu_202004/idcard_cnt_mean
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.763984	valid_0's auc: 0.721297
# [40]	training's auc: 0.769551	valid_0's auc: 0.724391
# [60]	training's auc: 0.771943	valid_0's auc: 0.728358
# [80]	training's auc: 0.772809	valid_0's auc: 0.729531
# [100]	training's auc: 0.773549	valid_0's auc: 0.731395
# [120]	training's auc: 0.774244	valid_0's auc: 0.731951
# [140]	training's auc: 0.774763	valid_0's auc: 0.732836
# [160]	training's auc: 0.775085	valid_0's auc: 0.732977
# [180]	training's auc: 0.775453	valid_0's auc: 0.733563
# [200]	training's auc: 0.775742	valid_0's auc: 0.733893
# [220]	training's auc: 0.775956	valid_0's auc: 0.733603
# [240]	training's auc: 0.776168	valid_0's auc: 0.73418
# [260]	training's auc: 0.776319	valid_0's auc: 0.733776
# [280]	training's auc: 0.776356	valid_0's auc: 0.733714
# Early stopping, best iteration is:
# [242]	training's auc: 0.776185	valid_0's auc: 0.734213
# *****
# 0.7342128234562587
# ********************
#
#
# county_name_arpu_202004/idcard_cnt_skew
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.762355	valid_0's auc: 0.721041
# [40]	training's auc: 0.767774	valid_0's auc: 0.723831
# [60]	training's auc: 0.770418	valid_0's auc: 0.724464
# [80]	training's auc: 0.772012	valid_0's auc: 0.726392
# [100]	training's auc: 0.77312	valid_0's auc: 0.726751
# [120]	training's auc: 0.773644	valid_0's auc: 0.727428
# [140]	training's auc: 0.774202	valid_0's auc: 0.72737
# [160]	training's auc: 0.774556	valid_0's auc: 0.727182
# Early stopping, best iteration is:
# [124]	training's auc: 0.773794	valid_0's auc: 0.727742
# *****
# 0.7277422035681829
# ********************
#
#
# city_name_county_name_idcard_cnt_mean
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.758895	valid_0's auc: 0.726198
# [40]	training's auc: 0.761013	valid_0's auc: 0.725777
# [60]	training's auc: 0.762267	valid_0's auc: 0.72696
# [80]	training's auc: 0.76302	valid_0's auc: 0.72708
# [100]	training's auc: 0.763443	valid_0's auc: 0.727638
# [120]	training's auc: 0.763718	valid_0's auc: 0.726149
# Early stopping, best iteration is:
# [71]	training's auc: 0.762527	valid_0's auc: 0.72834
# *****
# 0.728340089443727
# ********************
#
#
# city_name_county_name_idcard_cnt_skew
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.767225	valid_0's auc: 0.725966
# [40]	training's auc: 0.771609	valid_0's auc: 0.731023
# [60]	training's auc: 0.773229	valid_0's auc: 0.732957
# [80]	training's auc: 0.7745	valid_0's auc: 0.733007
# [100]	training's auc: 0.775523	valid_0's auc: 0.732089
# Early stopping, best iteration is:
# [51]	training's auc: 0.772654	valid_0's auc: 0.733323
# *****
# 0.7333234682163868
# ********************
#
#
# city_name_county_name_arpu_202004_median
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.759195	valid_0's auc: 0.722064
# [40]	training's auc: 0.762295	valid_0's auc: 0.721479
# [60]	training's auc: 0.764088	valid_0's auc: 0.721
# Early stopping, best iteration is:
# [13]	training's auc: 0.756147	valid_0's auc: 0.724521
# *****
# 0.7245210934136892
# ********************
#
#
# city_name_county_name_arpu_202004_nunique
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.742008	valid_0's auc: 0.712206
# [40]	training's auc: 0.743087	valid_0's auc: 0.712471
# [60]	training's auc: 0.743305	valid_0's auc: 0.71209
# Early stopping, best iteration is:
# [14]	training's auc: 0.740671	valid_0's auc: 0.712756
# *****
# 0.7127561940976707
# ********************
#
#
# city_name_county_name_idcard_cnt*arpu_202004_max
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.76849	valid_0's auc: 0.724255
# [40]	training's auc: 0.772427	valid_0's auc: 0.725134
# [60]	training's auc: 0.774305	valid_0's auc: 0.726041
# [80]	training's auc: 0.775051	valid_0's auc: 0.727188
# [100]	training's auc: 0.775785	valid_0's auc: 0.728128
# [120]	training's auc: 0.776231	valid_0's auc: 0.729013
# [140]	training's auc: 0.776471	valid_0's auc: 0.729007
# [160]	training's auc: 0.776661	valid_0's auc: 0.729374
# [180]	training's auc: 0.77686	valid_0's auc: 0.729996
# [200]	training's auc: 0.777044	valid_0's auc: 0.729919
# [220]	training's auc: 0.777132	valid_0's auc: 0.72999
# [240]	training's auc: 0.777217	valid_0's auc: 0.730283
# [260]	training's auc: 0.77727	valid_0's auc: 0.730205
# [280]	training's auc: 0.777308	valid_0's auc: 0.730316
# [300]	training's auc: 0.777376	valid_0's auc: 0.730479
# [320]	training's auc: 0.777465	valid_0's auc: 0.730321
# [340]	training's auc: 0.7775	valid_0's auc: 0.73015
# Early stopping, best iteration is:
# [295]	training's auc: 0.777366	valid_0's auc: 0.730596
# *****
# 0.730595613909217
# ********************
#
#
# city_name_county_name_idcard_cnt*arpu_202004_mean
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.769089	valid_0's auc: 0.720409
# [40]	training's auc: 0.774134	valid_0's auc: 0.723298
# [60]	training's auc: 0.775935	valid_0's auc: 0.724402
# [80]	training's auc: 0.777469	valid_0's auc: 0.725454
# [100]	training's auc: 0.778846	valid_0's auc: 0.726682
# [120]	training's auc: 0.779478	valid_0's auc: 0.726878
# [140]	training's auc: 0.779866	valid_0's auc: 0.726905
# [160]	training's auc: 0.780197	valid_0's auc: 0.727339
# [180]	training's auc: 0.780499	valid_0's auc: 0.727506
# [200]	training's auc: 0.780741	valid_0's auc: 0.727783
# [220]	training's auc: 0.780978	valid_0's auc: 0.728055
# [240]	training's auc: 0.781154	valid_0's auc: 0.728084
# [260]	training's auc: 0.781287	valid_0's auc: 0.727977
# Early stopping, best iteration is:
# [219]	training's auc: 0.780955	valid_0's auc: 0.728264
# *****
# 0.7282638589945951
# ********************
#
#
# city_name_county_name_arpu_202004/idcard_cnt_median
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.752586	valid_0's auc: 0.705967
# [40]	training's auc: 0.755852	valid_0's auc: 0.710368
# [60]	training's auc: 0.757192	valid_0's auc: 0.712235
# [80]	training's auc: 0.758353	valid_0's auc: 0.714
# [100]	training's auc: 0.758901	valid_0's auc: 0.714054
# [120]	training's auc: 0.759443	valid_0's auc: 0.714554
# [140]	training's auc: 0.759947	valid_0's auc: 0.715048
# [160]	training's auc: 0.760229	valid_0's auc: 0.714979
# [180]	training's auc: 0.760444	valid_0's auc: 0.715257
# [200]	training's auc: 0.760629	valid_0's auc: 0.715672
# [220]	training's auc: 0.760788	valid_0's auc: 0.715753
# [240]	training's auc: 0.760912	valid_0's auc: 0.715783
# [260]	training's auc: 0.760984	valid_0's auc: 0.715956
# [280]	training's auc: 0.761107	valid_0's auc: 0.716016
# [300]	training's auc: 0.761178	valid_0's auc: 0.716225
# [320]	training's auc: 0.761247	valid_0's auc: 0.716237
# [340]	training's auc: 0.761433	valid_0's auc: 0.716686
# [360]	training's auc: 0.761443	valid_0's auc: 0.716521
# [380]	training's auc: 0.761476	valid_0's auc: 0.716465
# Early stopping, best iteration is:
# [342]	training's auc: 0.761434	valid_0's auc: 0.716719
# *****
# 0.716718682737839
# ********************
#
#
# city_name_county_name_arpu_202004/idcard_cnt_skew
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.764172	valid_0's auc: 0.722228
# [40]	training's auc: 0.768732	valid_0's auc: 0.725926
# [60]	training's auc: 0.771932	valid_0's auc: 0.727908
# [80]	training's auc: 0.773667	valid_0's auc: 0.728729
# [100]	training's auc: 0.774696	valid_0's auc: 0.729602
# [120]	training's auc: 0.775431	valid_0's auc: 0.729265
# [140]	training's auc: 0.775842	valid_0's auc: 0.729747
# [160]	training's auc: 0.776257	valid_0's auc: 0.729458
# [180]	training's auc: 0.776617	valid_0's auc: 0.729007
# Early stopping, best iteration is:
# [142]	training's auc: 0.775878	valid_0's auc: 0.729959
# *****
# 0.7299588654517626
# ********************
#
#
# county_name_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.749138	valid_0's auc: 0.722068
# [40]	training's auc: 0.750786	valid_0's auc: 0.725268
# [60]	training's auc: 0.751275	valid_0's auc: 0.725603
# [80]	training's auc: 0.751443	valid_0's auc: 0.724155
# Early stopping, best iteration is:
# [42]	training's auc: 0.750879	valid_0's auc: 0.725714
# *****
# 0.7257138757353996
# ********************
#
#
# city_name_county_name_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.751066	valid_0's auc: 0.721798
# [40]	training's auc: 0.752513	valid_0's auc: 0.724929
# [60]	training's auc: 0.753036	valid_0's auc: 0.72494
# [80]	training's auc: 0.753185	valid_0's auc: 0.72399
# Early stopping, best iteration is:
# [46]	training's auc: 0.752787	valid_0's auc: 0.725827
# *****
# 0.725827474051753
# ********************
#
#
# idcard_cnt_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.728639	valid_0's auc: 0.722937
# [40]	training's auc: 0.728657	valid_0's auc: 0.722704
# Early stopping, best iteration is:
# [1]	training's auc: 0.728639	valid_0's auc: 0.722937
# *****
# 0.7229366958434974
# ********************
#
#
# opposite_cnt
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.87583	valid_0's auc: 0.834659
# [40]	training's auc: 0.879273	valid_0's auc: 0.829834
# Early stopping, best iteration is:
# [6]	training's auc: 0.871454	valid_0's auc: 0.837444
# *****
# 0.8374437987276988
# ********************
#
#
# opposite_nunique
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.904939	valid_0's auc: 0.872039
# [40]	training's auc: 0.906123	valid_0's auc: 0.871682
# [60]	training's auc: 0.906789	valid_0's auc: 0.87122
# Early stopping, best iteration is:
# [23]	training's auc: 0.905179	valid_0's auc: 0.873069
# *****
# 0.8730688286219926
# ********************
#
#
# voc_cnt_per_capita
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.912836	valid_0's auc: 0.862823
# [40]	training's auc: 0.916068	valid_0's auc: 0.862431
# [60]	training's auc: 0.917994	valid_0's auc: 0.862006
# Early stopping, best iteration is:
# [23]	training's auc: 0.913471	valid_0's auc: 0.864322
# *****
# 0.8643217582627828
# ********************
#
#
# call_1_cnt
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.866756	valid_0's auc: 0.833647
# [40]	training's auc: 0.870532	valid_0's auc: 0.829073
# Early stopping, best iteration is:
# [4]	training's auc: 0.862261	valid_0's auc: 0.834383
# *****
# 0.8343826230449132
# ********************
#
#
# imeis_1
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.843524	valid_0's auc: 0.832824
# [40]	training's auc: 0.843544	valid_0's auc: 0.83301
# [60]	training's auc: 0.843544	valid_0's auc: 0.83301
# Early stopping, best iteration is:
# [27]	training's auc: 0.843544	valid_0's auc: 0.83301
# *****
# 0.8330104749605395
# ********************
#
#
# call_dur_1_sum
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.872818	valid_0's auc: 0.842059
# [40]	training's auc: 0.877438	valid_0's auc: 0.838251
# [60]	training's auc: 0.878929	valid_0's auc: 0.836599
# Early stopping, best iteration is:
# [15]	training's auc: 0.870477	valid_0's auc: 0.844061
# *****
# 0.8440609006552829
# ********************
#
#
# call_dur_1_max
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.854141	valid_0's auc: 0.7982
# [40]	training's auc: 0.858731	valid_0's auc: 0.797079
# [60]	training's auc: 0.861576	valid_0's auc: 0.79607
# Early stopping, best iteration is:
# [15]	training's auc: 0.852845	valid_0's auc: 0.800121
# *****
# 0.8001207729468599
# ********************
#
#
# call_dur_1_min
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.837305	valid_0's auc: 0.835016
# [40]	training's auc: 0.838263	valid_0's auc: 0.835276
# [60]	training's auc: 0.838854	valid_0's auc: 0.835199
# Early stopping, best iteration is:
# [27]	training's auc: 0.837512	valid_0's auc: 0.835578
# *****
# 0.8355783947960014
# ********************
#
#
# call_dur_1_std
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.826227	valid_0's auc: 0.75623
# [40]	training's auc: 0.830166	valid_0's auc: 0.759514
# [60]	training's auc: 0.832941	valid_0's auc: 0.758986
# [80]	training's auc: 0.834337	valid_0's auc: 0.758926
# Early stopping, best iteration is:
# [38]	training's auc: 0.829891	valid_0's auc: 0.759871
# *****
# 0.7598710958052327
# ********************
#
#
# call_dur_1_median
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.840639	valid_0's auc: 0.799399
# [40]	training's auc: 0.845154	valid_0's auc: 0.799547
# Early stopping, best iteration is:
# [4]	training's auc: 0.825937	valid_0's auc: 0.803928
# *****
# 0.8039278112593868
# ********************
#
#
# call_dur_1_mean
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.846738	valid_0's auc: 0.821903
# [40]	training's auc: 0.850723	valid_0's auc: 0.818564
# Early stopping, best iteration is:
# [5]	training's auc: 0.838886	valid_0's auc: 0.824136
# *****
# 0.8241363538527766
# ********************
#
#
# call_dur_30s_cnt
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.83587	valid_0's auc: 0.79924
# [40]	training's auc: 0.839009	valid_0's auc: 0.793015
# Early stopping, best iteration is:
# [5]	training's auc: 0.832818	valid_0's auc: 0.803901
# *****
# 0.8039009063949873
# ********************
#
#
# call_dur_30_60s_cnt
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.798119	valid_0's auc: 0.77612
# [40]	training's auc: 0.798774	valid_0's auc: 0.774131
# Early stopping, best iteration is:
# [4]	training's auc: 0.797138	valid_0's auc: 0.777422
# *****
# 0.7774220356818291
# ********************
#
#
# call_dur_60_120s_cnt
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.77733	valid_0's auc: 0.775636
# [40]	training's auc: 0.778264	valid_0's auc: 0.774857
# Early stopping, best iteration is:
# [3]	training's auc: 0.776632	valid_0's auc: 0.778189
# *****
# 0.7781888243172144
# ********************
#
#
# call_dur_120_300s_cnt
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.737164	valid_0's auc: 0.746958
# [40]	training's auc: 0.737448	valid_0's auc: 0.746286
# [60]	training's auc: 0.737307	valid_0's auc: 0.746695
# [80]	training's auc: 0.737329	valid_0's auc: 0.74668
# [100]	training's auc: 0.737354	valid_0's auc: 0.746576
# Early stopping, best iteration is:
# [52]	training's auc: 0.737417	valid_0's auc: 0.748094
# *****
# 0.7480942387717032
# ********************
#
#
# call_dur_300s_cnt
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.673191	valid_0's auc: 0.679379
# [40]	training's auc: 0.673512	valid_0's auc: 0.679047
# [60]	training's auc: 0.675243	valid_0's auc: 0.680004
# [80]	training's auc: 0.675413	valid_0's auc: 0.680106
# Early stopping, best iteration is:
# [46]	training's auc: 0.673855	valid_0's auc: 0.681128
# *****
# 0.681128031281389
# ********************
#
#
# call_dur_30s_cnt_rate
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.827141	valid_0's auc: 0.805994
# [40]	training's auc: 0.83027	valid_0's auc: 0.80472
# [60]	training's auc: 0.832649	valid_0's auc: 0.803847
# Early stopping, best iteration is:
# [21]	training's auc: 0.827407	valid_0's auc: 0.806194
# *****
# 0.8061937987276988
# ********************
# call_dur_30_60s_cnt_rate
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.795175	valid_0's auc: 0.776364
# [40]	training's auc: 0.799091	valid_0's auc: 0.77741
# [60]	training's auc: 0.800857	valid_0's auc: 0.778038
# [80]	training's auc: 0.801958	valid_0's auc: 0.778848
# [100]	training's auc: 0.803432	valid_0's auc: 0.777455
# [120]	training's auc: 0.804033	valid_0's auc: 0.777781
# Early stopping, best iteration is:
# [84]	training's auc: 0.802209	valid_0's auc: 0.779141
# *****
# 0.7791409575740182
# ********************
#
#
# call_dur_60_120s_cnt_rate
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.777638	valid_0's auc: 0.745012
# [40]	training's auc: 0.780587	valid_0's auc: 0.746341
# [60]	training's auc: 0.782526	valid_0's auc: 0.74806
# [80]	training's auc: 0.783713	valid_0's auc: 0.747967
# [100]	training's auc: 0.784637	valid_0's auc: 0.748429
# [120]	training's auc: 0.785567	valid_0's auc: 0.747776
# [140]	training's auc: 0.786163	valid_0's auc: 0.74809
# [160]	training's auc: 0.786587	valid_0's auc: 0.747987
# Early stopping, best iteration is:
# [112]	training's auc: 0.785071	valid_0's auc: 0.748791
# *****
# 0.748790775816712
# ********************
#
#
# call_dur_120_300s_cnt_rate
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.74798	valid_0's auc: 0.7082
# [40]	training's auc: 0.750219	valid_0's auc: 0.706713
# Early stopping, best iteration is:
# [1]	training's auc: 0.738071	valid_0's auc: 0.714953
# *****
# 0.7149534246902951
# ********************
#
#
# call_dur_300s_cnt_rate
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.695739	valid_0's auc: 0.65654
# [40]	training's auc: 0.697951	valid_0's auc: 0.65716
# [60]	training's auc: 0.700518	valid_0's auc: 0.656344
# Early stopping, best iteration is:
# [24]	training's auc: 0.695808	valid_0's auc: 0.658988
# *****
# 0.6589883173099919
# ********************
#
#
# call_type_id_1_rate
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.88376	valid_0's auc: 0.848295
# [40]	training's auc: 0.886165	valid_0's auc: 0.846151
# Early stopping, best iteration is:
# [5]	training's auc: 0.880669	valid_0's auc: 0.848434
# *****
# 0.8484344358348879
# ********************
#
#
# county_name_nunique_x
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.810992	valid_0's auc: 0.782057
# [40]	training's auc: 0.811049	valid_0's auc: 0.781486
# Early stopping, best iteration is:
# [8]	training's auc: 0.810682	valid_0's auc: 0.782393
# *****
# 0.782393456736978
# ********************
#
#
# call_2_cnt
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.80981	valid_0's auc: 0.759904
# [40]	training's auc: 0.813251	valid_0's auc: 0.758302
# Early stopping, best iteration is:
# [4]	training's auc: 0.806307	valid_0's auc: 0.762361
# *****
# 0.7623612904768737
# ********************
#
#
# voc_calltype_1/2
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.825369	valid_0's auc: 0.784728
# [40]	training's auc: 0.827424	valid_0's auc: 0.783018
# [60]	training's auc: 0.828432	valid_0's auc: 0.78283
# Early stopping, best iteration is:
# [10]	training's auc: 0.823186	valid_0's auc: 0.78658
# *****
# 0.7865801525804754
# ********************
#
#
# phone2opposite_cnt_median
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.854762	valid_0's auc: 0.856237
# [40]	training's auc: 0.854804	valid_0's auc: 0.856274
# [60]	training's auc: 0.854806	valid_0's auc: 0.856277
# [80]	training's auc: 0.854806	valid_0's auc: 0.856277
# [100]	training's auc: 0.854806	valid_0's auc: 0.85628
# Early stopping, best iteration is:
# [52]	training's auc: 0.854793	valid_0's auc: 0.856349
# *****
# 0.8563489501124025
# ********************
#
#
# phone2opposite_cnt_max
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.866435	valid_0's auc: 0.826525
# [40]	training's auc: 0.867399	valid_0's auc: 0.825449
# [60]	training's auc: 0.868045	valid_0's auc: 0.82379
# Early stopping, best iteration is:
# [16]	training's auc: 0.866169	valid_0's auc: 0.826525
# *****
# 0.8265249079255752
# ********************
#
#
# phone2opposite_cnt_std
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.891704	valid_0's auc: 0.847355
# [40]	training's auc: 0.895421	valid_0's auc: 0.842592
# [60]	training's auc: 0.897079	valid_0's auc: 0.841294
# Early stopping, best iteration is:
# [20]	training's auc: 0.891704	valid_0's auc: 0.847355
# *****
# 0.8473552518295308
# ********************
#
#
# phone2opposite_call_dur_mean
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.877958	valid_0's auc: 0.814361
# [40]	training's auc: 0.881893	valid_0's auc: 0.813297
# [60]	training's auc: 0.884125	valid_0's auc: 0.812125
# Early stopping, best iteration is:
# [14]	training's auc: 0.875963	valid_0's auc: 0.815525
# *****
# 0.815525302530253
# ********************
#
#
# phone2opposite_call_dur_median
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.884232	valid_0's auc: 0.845148
# [40]	training's auc: 0.888511	valid_0's auc: 0.843092
# Early stopping, best iteration is:
# [1]	training's auc: 0.87474	valid_0's auc: 0.848182
# *****
# 0.8481818290524704
# ********************
#
#
# phone2opposite_call_dur_min
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.88796	valid_0's auc: 0.862981
# [40]	training's auc: 0.889736	valid_0's auc: 0.86232
# Early stopping, best iteration is:
# [8]	training's auc: 0.886481	valid_0's auc: 0.864719
# *****
# 0.8647193523700196
# ********************
#
#
# phone2opposite_call_dur_max
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.859878	valid_0's auc: 0.790634
# [40]	training's auc: 0.865253	valid_0's auc: 0.786718
# Early stopping, best iteration is:
# [6]	training's auc: 0.851246	valid_0's auc: 0.797212
# *****
# 0.797212058162338
# ********************
#
#
# phone2opposite_call_dur_std
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.858935	valid_0's auc: 0.791271
# [40]	training's auc: 0.862113	valid_0's auc: 0.79438
# Early stopping, best iteration is:
# [1]	training's auc: 0.847028	valid_0's auc: 0.795072
# *****
# 0.7950716267278902
# ********************
#
#
# call_dur_mean
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.860201	valid_0's auc: 0.808551
# [40]	training's auc: 0.864663	valid_0's auc: 0.806255
# Early stopping, best iteration is:
# [9]	training's auc: 0.855756	valid_0's auc: 0.814038
# *****
# 0.8140380614148371
# ********************
#
#
# call_dur_median
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.855249	valid_0's auc: 0.813691
# [40]	training's auc: 0.859461	valid_0's auc: 0.808497
# Early stopping, best iteration is:
# [2]	training's auc: 0.844655	valid_0's auc: 0.819864
# *****
# 0.8198644592720141
# ********************
#
#
# call_dur_max
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.862642	valid_0's auc: 0.800681
# [40]	training's auc: 0.867274	valid_0's auc: 0.802819
# [60]	training's auc: 0.869486	valid_0's auc: 0.804071
# [80]	training's auc: 0.870966	valid_0's auc: 0.805403
# [100]	training's auc: 0.871768	valid_0's auc: 0.804666
# [120]	training's auc: 0.872517	valid_0's auc: 0.805423
# [140]	training's auc: 0.873096	valid_0's auc: 0.806497
# [160]	training's auc: 0.873502	valid_0's auc: 0.806518
# [180]	training's auc: 0.873842	valid_0's auc: 0.806479
# [200]	training's auc: 0.874115	valid_0's auc: 0.806533
# [220]	training's auc: 0.874375	valid_0's auc: 0.806808
# [240]	training's auc: 0.874527	valid_0's auc: 0.80707
# [260]	training's auc: 0.874652	valid_0's auc: 0.807246
# [280]	training's auc: 0.874741	valid_0's auc: 0.807524
# [300]	training's auc: 0.874852	valid_0's auc: 0.807584
# [320]	training's auc: 0.87494	valid_0's auc: 0.807641
# [340]	training's auc: 0.875009	valid_0's auc: 0.807736
# Early stopping, best iteration is:
# [305]	training's auc: 0.874873	valid_0's auc: 0.807817
# *****
# 0.807817058879801
# ********************
#
#
# call_dur_min
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.84223	valid_0's auc: 0.836267
# [40]	training's auc: 0.8436	valid_0's auc: 0.835202
# [60]	training's auc: 0.84419	valid_0's auc: 0.834418
# Early stopping, best iteration is:
# [21]	training's auc: 0.842465	valid_0's auc: 0.836417
# *****
# 0.8364169297364519
# ********************
#
#
# call_dur_std
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.858338	valid_0's auc: 0.80205
# [40]	training's auc: 0.86241	valid_0's auc: 0.802363
# [60]	training's auc: 0.864349	valid_0's auc: 0.801867
# Early stopping, best iteration is:
# [25]	training's auc: 0.85985	valid_0's auc: 0.803348
# *****
# 0.8033478619601091
# ********************
#
#
# call_dur_sum
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.878681	valid_0's auc: 0.828292
# [40]	training's auc: 0.881238	valid_0's auc: 0.828272
# Early stopping, best iteration is:
# [1]	training's auc: 0.863442	valid_0's auc: 0.839296
# *****
# 0.8392957502271966
# ********************
#
#
# county_name_nunique_y
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.833327	valid_0's auc: 0.811718
# [40]	training's auc: 0.833379	valid_0's auc: 0.811503
# [60]	training's auc: 0.83341	valid_0's auc: 0.810291
# Early stopping, best iteration is:
# [15]	training's auc: 0.833237	valid_0's auc: 0.811969
# *****
# 0.8119693762854546
# ********************
#
#
# voc_hour_mode
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.846216	valid_0's auc: 0.821863
# [40]	training's auc: 0.84638	valid_0's auc: 0.822891
# [60]	training's auc: 0.84638	valid_0's auc: 0.822891
# Early stopping, best iteration is:
# [12]	training's auc: 0.846129	valid_0's auc: 0.823077
# *****
# 0.8230766011383747
# ********************
#
#
# voc_hour_mode_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.872382	valid_0's auc: 0.854724
# [40]	training's auc: 0.872673	valid_0's auc: 0.855726
# [60]	training's auc: 0.873008	valid_0's auc: 0.85492
# Early stopping, best iteration is:
# [10]	training's auc: 0.871888	valid_0's auc: 0.855956
# *****
# 0.8559558401492323
# ********************
#
#
# voc_hour_nunique
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.863741	valid_0's auc: 0.840329
# [40]	training's auc: 0.863836	valid_0's auc: 0.840332
# Early stopping, best iteration is:
# [3]	training's auc: 0.863732	valid_0's auc: 0.840338
# *****
# 0.8403375663653322
# ********************
#
#
# voc_day_mode
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.836341	valid_0's auc: 0.819616
# [40]	training's auc: 0.836343	valid_0's auc: 0.81945
# Early stopping, best iteration is:
# [1]	training's auc: 0.836316	valid_0's auc: 0.820355
# *****
# 0.8203547256899603
# ********************
#
#
# voc_day_mode_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.902799	valid_0's auc: 0.886989
# [40]	training's auc: 0.903184	valid_0's auc: 0.886058
# Early stopping, best iteration is:
# [7]	training's auc: 0.902311	valid_0's auc: 0.888591
# *****
# 0.8885914406658058
# ********************
#
#
# voc_day_nunique
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.87395	valid_0's auc: 0.859841
# [40]	training's auc: 0.873947	valid_0's auc: 0.859868
# [60]	training's auc: 0.87395	valid_0's auc: 0.859841
# Early stopping, best iteration is:
# [14]	training's auc: 0.873926	valid_0's auc: 0.86012
# *****
# 0.8601201152723968
# ********************
#
#
# voc_dayofweek_mode
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.819633	valid_0's auc: 0.812501
# [40]	training's auc: 0.819633	valid_0's auc: 0.812501
# Early stopping, best iteration is:
# [1]	training's auc: 0.819633	valid_0's auc: 0.812501
# *****
# 0.8125014947146889
# ********************
#
#
# voc_dayofweek_mode_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.892701	valid_0's auc: 0.877734
# [40]	training's auc: 0.893651	valid_0's auc: 0.876356
# Early stopping, best iteration is:
# [8]	training's auc: 0.891812	valid_0's auc: 0.879069
# *****
# 0.8790686133830774
# ********************
#
#
# voc_day_cnt_mean
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.922615	valid_0's auc: 0.893067
# [40]	training's auc: 0.925022	valid_0's auc: 0.890121
# [60]	training's auc: 0.926486	valid_0's auc: 0.888565
# Early stopping, best iteration is:
# [15]	training's auc: 0.921839	valid_0's auc: 0.894038
# *****
# 0.8940381809920123
# ********************
#
#
# voc_day_cnt_std
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.917844	valid_0's auc: 0.883433
# [40]	training's auc: 0.920868	valid_0's auc: 0.882006
# Early stopping, best iteration is:
# [4]	training's auc: 0.913445	valid_0's auc: 0.887636
# *****
# 0.8876363179796241
# ********************
#
#
# voc_day17_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.761633	valid_0's auc: 0.735965
# [40]	training's auc: 0.761763	valid_0's auc: 0.736012
# Early stopping, best iteration is:
# [5]	training's auc: 0.760866	valid_0's auc: 0.73795
# *****
# 0.7379496101784091
# ********************
#
#
# voc_day22_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.762935	valid_0's auc: 0.741236
# [40]	training's auc: 0.763217	valid_0's auc: 0.740583
# Early stopping, best iteration is:
# [2]	training's auc: 0.762392	valid_0's auc: 0.743124
# *****
# 0.7431243124312431
# ********************
#
#
# voc_day9_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.755416	valid_0's auc: 0.723152
# [40]	training's auc: 0.755424	valid_0's auc: 0.723884
# Early stopping, best iteration is:
# [1]	training's auc: 0.754753	valid_0's auc: 0.727164
# *****
# 0.727163748983594
# ********************
#
#
# voc_day26_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.771969	valid_0's auc: 0.741126
# [40]	training's auc: 0.772034	valid_0's auc: 0.74163
# [60]	training's auc: 0.772064	valid_0's auc: 0.741627
# [80]	training's auc: 0.772072	valid_0's auc: 0.741591
# Early stopping, best iteration is:
# [30]	training's auc: 0.77202	valid_0's auc: 0.741694
# *****
# 0.7416938704740039
# ********************
#
#
# voc_day11_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.760205	valid_0's auc: 0.751087
# [40]	training's auc: 0.760349	valid_0's auc: 0.750677
# Early stopping, best iteration is:
# [5]	training's auc: 0.759946	valid_0's auc: 0.752329
# *****
# 0.7523287654852442
# ********************
#
#
# voc_day13_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.752319	valid_0's auc: 0.730918
# [40]	training's auc: 0.753646	valid_0's auc: 0.73157
# [60]	training's auc: 0.75394	valid_0's auc: 0.731491
# [80]	training's auc: 0.75397	valid_0's auc: 0.731461
# Early stopping, best iteration is:
# [32]	training's auc: 0.752628	valid_0's auc: 0.731706
# *****
# 0.7317061869230401
# ********************
#
#
# voc_day15_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.744287	valid_0's auc: 0.742485
# [40]	training's auc: 0.744413	valid_0's auc: 0.743949
# [60]	training's auc: 0.744431	valid_0's auc: 0.744048
# ...
# 0.8260824723776725
# ********************
#
#
# sms_day18_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.816941	valid_0's auc: 0.797617
# [40]	training's auc: 0.817149	valid_0's auc: 0.794761
# [60]	training's auc: 0.817212	valid_0's auc: 0.794489
# Early stopping, best iteration is:
# [11]	training's auc: 0.816875	valid_0's auc: 0.798101
# *****
# 0.7981014134022097
# ********************
#
#
# sms_day19_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.852873	valid_0's auc: 0.826422
# [40]	training's auc: 0.852993	valid_0's auc: 0.825936
# Early stopping, best iteration is:
# [3]	training's auc: 0.852687	valid_0's auc: 0.827428
# *****
# 0.8274277155976467
# ********************
#
#
# sms_day20_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.807998	valid_0's auc: 0.766327
# [40]	training's auc: 0.808072	valid_0's auc: 0.766135
# Early stopping, best iteration is:
# [2]	training's auc: 0.807732	valid_0's auc: 0.768407
# *****
# 0.7684074113933133
# ********************
#
#
# sms_day21_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.763356	valid_0's auc: 0.734775
# [40]	training's auc: 0.763367	valid_0's auc: 0.734778
# Early stopping, best iteration is:
# [4]	training's auc: 0.763318	valid_0's auc: 0.735057
# *****
# 0.7350573372554646
# ********************
#
#
# sms_day22_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.735245	valid_0's auc: 0.695328
# [40]	training's auc: 0.73525	valid_0's auc: 0.695328
# [60]	training's auc: 0.735251	valid_0's auc: 0.695328
# Early stopping, best iteration is:
# [22]	training's auc: 0.735246	valid_0's auc: 0.69537
# *****
# 0.6953696728368489
# ********************
#
#
# sms_day23_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.773718	valid_0's auc: 0.754532
# [40]	training's auc: 0.774358	valid_0's auc: 0.754616
# Early stopping, best iteration is:
# [3]	training's auc: 0.773158	valid_0's auc: 0.755629
# *****
# 0.7556290955182475
# ********************
#
#
# sms_day24_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.871845	valid_0's auc: 0.847198
# [40]	training's auc: 0.871925	valid_0's auc: 0.846026
# Early stopping, best iteration is:
# [1]	training's auc: 0.870984	valid_0's auc: 0.848279
# *****
# 0.8482789855072463
# ********************
#
#
# sms_day25_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.849236	valid_0's auc: 0.821854
# [40]	training's auc: 0.849367	valid_0's auc: 0.821968
# Early stopping, best iteration is:
# [5]	training's auc: 0.849121	valid_0's auc: 0.822036
# *****
# 0.822036279714928
# ********************
#
#
# sms_day26_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.87986	valid_0's auc: 0.855585
# [40]	training's auc: 0.879958	valid_0's auc: 0.85563
# [60]	training's auc: 0.879996	valid_0's auc: 0.855373
# [80]	training's auc: 0.880007	valid_0's auc: 0.855265
# Early stopping, best iteration is:
# [48]	training's auc: 0.879974	valid_0's auc: 0.85577
# *****
# 0.8557704955278137
# ********************
#
#
# sms_day27_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.857407	valid_0's auc: 0.855863
# [40]	training's auc: 0.857597	valid_0's auc: 0.855681
# [60]	training's auc: 0.857753	valid_0's auc: 0.855325
# Early stopping, best iteration is:
# [10]	training's auc: 0.857379	valid_0's auc: 0.856403
# *****
# 0.8564027598412015
# ********************
#
#
# sms_day28_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.865353	valid_0's auc: 0.841142
# [40]	training's auc: 0.865549	valid_0's auc: 0.840909
# [60]	training's auc: 0.865702	valid_0's auc: 0.840469
# Early stopping, best iteration is:
# [13]	training's auc: 0.865353	valid_0's auc: 0.841357
# *****
# 0.8413569617831348
# ********************
#
#
# sms_day29_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.725226	valid_0's auc: 0.718699
# [40]	training's auc: 0.725258	valid_0's auc: 0.718746
# [60]	training's auc: 0.725295	valid_0's auc: 0.718698
# Early stopping, best iteration is:
# [29]	training's auc: 0.725237	valid_0's auc: 0.719361
# *****
# 0.7193613383077438
# ********************
#
#
# sms_day30_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.865297	valid_0's auc: 0.848454
# [40]	training's auc: 0.865545	valid_0's auc: 0.847898
# Early stopping, best iteration is:
# [1]	training's auc: 0.864338	valid_0's auc: 0.849708
# *****
# 0.8497079327497967
# ********************
#
#
# sms_day31_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.864049	valid_0's auc: 0.836233
# [40]	training's auc: 0.864177	valid_0's auc: 0.836203
# [60]	training's auc: 0.864413	valid_0's auc: 0.835112
# Early stopping, best iteration is:
# [17]	training's auc: 0.864009	valid_0's auc: 0.836384
# *****
# 0.836384046013297
# ********************
#
#
# sms_hour10_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.841104	valid_0's auc: 0.803878
# [40]	training's auc: 0.842168	valid_0's auc: 0.80387
# [60]	training's auc: 0.842854	valid_0's auc: 0.803553
# Early stopping, best iteration is:
# [18]	training's auc: 0.841054	valid_0's auc: 0.804186
# *****
# 0.8041863969005596
# ********************
#
#
# sms_hour14_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.823142	valid_0's auc: 0.806298
# [40]	training's auc: 0.824661	valid_0's auc: 0.807191
# [60]	training's auc: 0.825288	valid_0's auc: 0.805968
# Early stopping, best iteration is:
# [23]	training's auc: 0.823503	valid_0's auc: 0.807889
# *****
# 0.8078888051848663
# ********************
#
#
# sms_hour16_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.81053	valid_0's auc: 0.785499
# [40]	training's auc: 0.811659	valid_0's auc: 0.785496
# [60]	training's auc: 0.812239	valid_0's auc: 0.78596
# Early stopping, best iteration is:
# [11]	training's auc: 0.809792	valid_0's auc: 0.786749
# *****
# 0.7867490553403167
# ********************
#
#
# sms_hour18_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.80929	valid_0's auc: 0.786381
# [40]	training's auc: 0.809843	valid_0's auc: 0.785628
# Early stopping, best iteration is:
# [3]	training's auc: 0.808904	valid_0's auc: 0.788417
# *****
# 0.7884171569330846
# ********************
#
#
# sms_hour13_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.840456	valid_0's auc: 0.825393
# [40]	training's auc: 0.841229	valid_0's auc: 0.825154
# [60]	training's auc: 0.841299	valid_0's auc: 0.825319
# [80]	training's auc: 0.841501	valid_0's auc: 0.8251
# Early stopping, best iteration is:
# [30]	training's auc: 0.840951	valid_0's auc: 0.825686
# *****
# 0.8256863729851246
# ********************
#
#
# sms_hour17_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.82008	valid_0's auc: 0.799668
# [40]	training's auc: 0.820546	valid_0's auc: 0.799628
# Early stopping, best iteration is:
# [4]	training's auc: 0.819503	valid_0's auc: 0.802544
# *****
# 0.8025437054575023
# ********************
#
#
# sms_hour11_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.856889	valid_0's auc: 0.820691
# [40]	training's auc: 0.857407	valid_0's auc: 0.820887
# [60]	training's auc: 0.857804	valid_0's auc: 0.821933
# [80]	training's auc: 0.857977	valid_0's auc: 0.822441
# [100]	training's auc: 0.85819	valid_0's auc: 0.821177
# [120]	training's auc: 0.858411	valid_0's auc: 0.821604
# Early stopping, best iteration is:
# [73]	training's auc: 0.857949	valid_0's auc: 0.822776
# *****
# 0.8227761634859138
# ********************
#
#
# sms_hour9_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.82474	valid_0's auc: 0.787226
# [40]	training's auc: 0.825361	valid_0's auc: 0.78731
# Early stopping, best iteration is:
# [9]	training's auc: 0.82431	valid_0's auc: 0.788223
# *****
# 0.7882228440235328
# ********************
#
#
# sms_hour0_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.560303	valid_0's auc: 0.54383
# [40]	training's auc: 0.561171	valid_0's auc: 0.541788
# Early stopping, best iteration is:
# [3]	training's auc: 0.559975	valid_0's auc: 0.544502
# *****
# 0.5445021404314344
# ********************
#
#
# sms_hour20_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.790873	valid_0's auc: 0.755563
# [40]	training's auc: 0.791157	valid_0's auc: 0.757249
# [60]	training's auc: 0.791175	valid_0's auc: 0.757486
# [80]	training's auc: 0.791214	valid_0's auc: 0.757856
# [100]	training's auc: 0.79126	valid_0's auc: 0.757773
# [120]	training's auc: 0.791315	valid_0's auc: 0.757755
# [140]	training's auc: 0.791393	valid_0's auc: 0.758326
# [160]	training's auc: 0.791439	valid_0's auc: 0.758556
# [180]	training's auc: 0.791487	valid_0's auc: 0.758852
# [200]	training's auc: 0.791521	valid_0's auc: 0.758876
# [220]	training's auc: 0.791555	valid_0's auc: 0.758852
# [240]	training's auc: 0.791579	valid_0's auc: 0.759031
# [260]	training's auc: 0.791581	valid_0's auc: 0.759073
# [280]	training's auc: 0.791586	valid_0's auc: 0.759127
# Early stopping, best iteration is:
# [241]	training's auc: 0.791582	valid_0's auc: 0.75913
# *****
# 0.759129717319558
# ********************
#
#
# sms_hour8_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.758405	valid_0's auc: 0.7333
# [40]	training's auc: 0.759126	valid_0's auc: 0.732891
# Early stopping, best iteration is:
# [2]	training's auc: 0.757752	valid_0's auc: 0.738477
# *****
# 0.7384772444635768
# ********************
#
#
# sms_hour21_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.762416	valid_0's auc: 0.734661
# [40]	training's auc: 0.762593	valid_0's auc: 0.734884
# [60]	training's auc: 0.762617	valid_0's auc: 0.734872
# [80]	training's auc: 0.762663	valid_0's auc: 0.734881
# [100]	training's auc: 0.762755	valid_0's auc: 0.734857
# Early stopping, best iteration is:
# [65]	training's auc: 0.762634	valid_0's auc: 0.734893
# *****
# 0.7348929186396901
# ********************
#
#
# sms_hour15_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.832031	valid_0's auc: 0.814407
# [40]	training's auc: 0.832659	valid_0's auc: 0.81318
# [60]	training's auc: 0.832871	valid_0's auc: 0.81182
# Early stopping, best iteration is:
# [19]	training's auc: 0.83206	valid_0's auc: 0.814452
# *****
# 0.8144520973836514
# ********************
#
#
# sms_hour2_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.531726	valid_0's auc: 0.52211
# [40]	training's auc: 0.531748	valid_0's auc: 0.522116
# Early stopping, best iteration is:
# [1]	training's auc: 0.530025	valid_0's auc: 0.52276
# *****
# 0.5227600205672741
# ********************
#
#
# sms_hour12_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.837971	valid_0's auc: 0.799462
# [40]	training's auc: 0.838295	valid_0's auc: 0.798701
# Early stopping, best iteration is:
# [1]	training's auc: 0.836301	valid_0's auc: 0.803354
# *****
# 0.8033538408188645
# ********************
#
#
# sms_hour7_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.649499	valid_0's auc: 0.627055
# [40]	training's auc: 0.650082	valid_0's auc: 0.624275
# [60]	training's auc: 0.650159	valid_0's auc: 0.624188
# Early stopping, best iteration is:
# [19]	training's auc: 0.649481	valid_0's auc: 0.627055
# *****
# 0.6270552326971828
# ********************
#
#
# sms_hour22_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.68954	valid_0's auc: 0.674801
# [40]	training's auc: 0.689567	valid_0's auc: 0.674808
# Early stopping, best iteration is:
# [2]	training's auc: 0.689485	valid_0's auc: 0.674825
# *****
# 0.6748248194384656
# ********************
#
#
# sms_hour19_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.799202	valid_0's auc: 0.781485
# [40]	training's auc: 0.799316	valid_0's auc: 0.780749
# Early stopping, best iteration is:
# [2]	training's auc: 0.799016	valid_0's auc: 0.781948
# *****
# 0.7819480317596977
# ********************
#
#
# sms_hour23_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.577373	valid_0's auc: 0.572228
# [40]	training's auc: 0.577905	valid_0's auc: 0.573712
# [60]	training's auc: 0.577921	valid_0's auc: 0.57361
# Early stopping, best iteration is:
# [29]	training's auc: 0.577481	valid_0's auc: 0.577721
# *****
# 0.5777206796766633
# ********************
#
#
# sms_hour4_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.519223	valid_0's auc: 0.509735
# [40]	training's auc: 0.519226	valid_0's auc: 0.509735
# [60]	training's auc: 0.519226	valid_0's auc: 0.509737
# Early stopping, best iteration is:
# [24]	training's auc: 0.519106	valid_0's auc: 0.513331
# *****
# 0.5133313603099441
# ********************
#
#
# sms_hour1_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.525783	valid_0's auc: 0.520228
# [40]	training's auc: 0.525789	valid_0's auc: 0.520223
# [60]	training's auc: 0.525814	valid_0's auc: 0.521234
# Early stopping, best iteration is:
# [26]	training's auc: 0.525806	valid_0's auc: 0.521244
# *****
# 0.5212443798727698
# ********************
#
#
# sms_weekofday6_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.85528	valid_0's auc: 0.829954
# [40]	training's auc: 0.85608	valid_0's auc: 0.826815
# Early stopping, best iteration is:
# [6]	training's auc: 0.854148	valid_0's auc: 0.831915
# *****
# 0.831914849093605
# ********************
#
#
# sms_weekofday0_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.85138	valid_0's auc: 0.824513
# [40]	training's auc: 0.852937	valid_0's auc: 0.822583
# Early stopping, best iteration is:
# [7]	training's auc: 0.849781	valid_0's auc: 0.82702
# *****
# 0.8270196584875878
# ********************
#
#
# sms_weekofday1_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.862556	valid_0's auc: 0.823938
# [40]	training's auc: 0.864155	valid_0's auc: 0.821957
# Early stopping, best iteration is:
# [2]	training's auc: 0.859898	valid_0's auc: 0.82757
# *****
# 0.8275697134930884
# ********************
#
#
# sms_weekofday2_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.845736	valid_0's auc: 0.846352
# [40]	training's auc: 0.84668	valid_0's auc: 0.843312
# [60]	training's auc: 0.847369	valid_0's auc: 0.841019
# Early stopping, best iteration is:
# [15]	training's auc: 0.84531	valid_0's auc: 0.846599
# *****
# 0.8465989261969675
# ********************
#
#
# sms_weekofday3_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.859203	valid_0's auc: 0.832399
# [40]	training's auc: 0.860132	valid_0's auc: 0.833384
# [60]	training's auc: 0.860691	valid_0's auc: 0.833856
# [80]	training's auc: 0.861115	valid_0's auc: 0.83422
# [100]	training's auc: 0.861477	valid_0's auc: 0.833957
# [120]	training's auc: 0.861747	valid_0's auc: 0.833706
# Early stopping, best iteration is:
# [82]	training's auc: 0.861193	valid_0's auc: 0.834387
# *****
# 0.8343871071889798
# ********************
#
#
# sms_weekofday4_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.858448	valid_0's auc: 0.840834
# [40]	training's auc: 0.859323	valid_0's auc: 0.837789
# [60]	training's auc: 0.85986	valid_0's auc: 0.836215
# Early stopping, best iteration is:
# [15]	training's auc: 0.858102	valid_0's auc: 0.841906
# *****
# 0.8419055220739465
# ********************
#
#
# sms_weekofday5_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.860853	valid_0's auc: 0.825108
# [40]	training's auc: 0.861272	valid_0's auc: 0.825133
# [60]	training's auc: 0.861583	valid_0's auc: 0.825359
# [80]	training's auc: 0.861807	valid_0's auc: 0.825141
# Early stopping, best iteration is:
# [49]	training's auc: 0.861481	valid_0's auc: 0.825528
# *****
# 0.8255279332281055
# ********************

# %%
print(useless_cols)
# Out:
# ['voc_hour3_call_dur_sum', 'sms_hour4_count']

# %%
lgb_train = lgb.Dataset(X_train[useful_cols].values, y_train) 

lgb_valid= lgb.Dataset(X_valid[useful_cols].values, y_valid, reference=lgb_train)  

print('Start training...')

lgb_val_0 = lgb.train(params,
                      lgb_train,
                      num_boost_round=10000,
                      valid_sets=[lgb_valid, lgb_train],
                      early_stopping_rounds=100,
                      verbose_eval=10)

print('Done!')
# Out:
# Start training...
# Training until validation scores don't improve for 100 rounds
# [10]	training's auc: 0.992065	valid_0's auc: 0.938889
# [20]	training's auc: 0.998078	valid_0's auc: 0.950615
# [30]	training's auc: 0.999342	valid_0's auc: 0.955048
# [40]	training's auc: 0.999611	valid_0's auc: 0.95465
# [50]	training's auc: 0.999769	valid_0's auc: 0.952124
# [60]	training's auc: 0.999897	valid_0's auc: 0.954405
# [70]	training's auc: 1	valid_0's auc: 0.953765
# [80]	training's auc: 1	valid_0's auc: 0.95294
# [90]	training's auc: 1	valid_0's auc: 0.953493
# [100]	training's auc: 1	valid_0's auc: 0.954791
# [110]	training's auc: 1	valid_0's auc: 0.954994
# [120]	training's auc: 1	valid_0's auc: 0.955619
# [130]	training's auc: 1	valid_0's auc: 0.955957
# [140]	training's auc: 1	valid_0's auc: 0.956031
# [150]	training's auc: 1	valid_0's auc: 0.956262
# [160]	training's auc: 1	valid_0's auc: 0.956229
# [170]	training's auc: 1	valid_0's auc: 0.956928
# [180]	training's auc: 1	valid_0's auc: 0.956898
# [190]	training's auc: 1	valid_0's auc: 0.957158
# [200]	training's auc: 1	valid_0's auc: 0.957245
# [210]	training's auc: 1	valid_0's auc: 0.956958
# [220]	training's auc: 1	valid_0's auc: 0.956746
# [230]	training's auc: 1	valid_0's auc: 0.956582
# [240]	training's auc: 1	valid_0's auc: 0.956504
# [250]	training's auc: 1	valid_0's auc: 0.956504
# [260]	training's auc: 1	valid_0's auc: 0.956504
# [270]	training's auc: 1	valid_0's auc: 0.956504
# [280]	training's auc: 1	valid_0's auc: 0.956504
# [290]	training's auc: 1	valid_0's auc: 0.956504
# Early stopping, best iteration is:
# [194]	training's auc: 1	valid_0's auc: 0.957499
# Done!

# %%
# 验证集结果
X_valid['prob'] = lgb_val_0.predict(X_valid[useful_cols])
X_valid['pred'] = np.where(X_valid['prob'] > 0.4735, 1, 0)

f1_04735 = np.round(f1_score(y_valid, X_valid['pred']), 4)
auc_04735 = roc_auc_score(y_valid, X_valid['prob'])

print('f1_04735: ', f1_04735)
print('auc_04735: ', auc_04735)
# Out:
# f1_04735:  0.8804
# auc_04735:  0.9574992825369492

# %%
lgb_train_all = lgb.Dataset(df_train[useful_cols].values, df_train['label'])   

print('Start training...')

lgb_model = lgb.train(params,
                      lgb_train_all,
                      num_boost_round=lgb_val_0.best_iteration + 20)

print('Done!')
# Out:
# Start training...
# Done!

# %%
df_test['label'] = np.where(lgb_model.predict(df_test[useful_cols]) > 0.4735, 1, 0)
df_test[['phone_no_m', 'label']].to_csv('../sub/sub_{}_{}.csv'.format(time.strftime('%Y%m%d'), f1_04735), index=False)
