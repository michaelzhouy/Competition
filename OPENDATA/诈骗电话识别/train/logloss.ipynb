# %%
import time
import numpy as np
import pandas as pd
from tqdm import tqdm
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.preprocessing import LabelEncoder
from itertools import product
import lightgbm as lgb
from sklearn.metrics import f1_score, roc_auc_score
import gc
import warnings
warnings.filterwarnings('ignore')

pd.set_option('max_columns', None)
pd.set_option('max_rows', None)
pd.set_option('max_colwidth', 200)

# %%
# count编码
def count_coding(df, fea_col):
    for f in fea_col:
        df[f + '_count'] = df[f].map(df[f].value_counts())
    return df

# 交叉特征统计
def cross_cat_num(df, num_col, cat_col):
    for f1 in tqdm(cat_col):
        g = df.groupby(f1, as_index=False)
        for f2 in tqdm(num_col):
            feat = g[f2].agg({
                '{}_{}_max'.format(f1, f2): 'max',
                '{}_{}_min'.format(f1, f2): 'min',
                '{}_{}_median'.format(f1, f2): 'median'
            })
            df = df.merge(feat, on=f1, how='left')
    return df

# %%
class MeanEncoder:
    def __init__(self, categorical_features, n_splits=10, target_type='classification', prior_weight_func=None):
        """
        :param categorical_features: list of str, the name of the categorical columns to encode
 
        :param n_splits: the number of splits used in mean encoding
 
        :param target_type: str, 'regression' or 'classification'
 
        :param prior_weight_func:
        a function that takes in the number of observations, and outputs prior weight
        when a dict is passed, the default exponential decay function will be used:
        k: the number of observations needed for the posterior to be weighted equally as the prior
        f: larger f --> smaller slope
        """
 
        self.categorical_features = categorical_features
        self.n_splits = n_splits
        self.learned_stats = {}
 
        if target_type == 'classification':
            self.target_type = target_type
            self.target_values = []
        else:
            self.target_type = 'regression'
            self.target_values = None
 
        if isinstance(prior_weight_func, dict):
            self.prior_weight_func = eval('lambda x: 1 / (1 + np.exp((x - k) / f))', dict(prior_weight_func, np=np))
        elif callable(prior_weight_func):
            self.prior_weight_func = prior_weight_func
        else:
            self.prior_weight_func = lambda x: 1 / (1 + np.exp((x - 2) / 1))
 
    @staticmethod
    def mean_encode_subroutine(X_train, y_train, X_test, variable, target, prior_weight_func):
        X_train = X_train[[variable]].copy()
        X_test = X_test[[variable]].copy()
 
        if target is not None:
            nf_name = '{}_pred_{}'.format(variable, target)
            X_train['pred_temp'] = (y_train == target).astype(int)  # classification
        else:
            nf_name = '{}_pred'.format(variable)
            X_train['pred_temp'] = y_train  # regression
        prior = X_train['pred_temp'].mean()
 
        col_avg_y = X_train.groupby(by=variable, axis=0)['pred_temp'].agg(['mean', 'size'])
        col_avg_y['size'] = prior_weight_func(col_avg_y['size'])
        col_avg_y[nf_name] = col_avg_y['size'] * prior + (1 - col_avg_y['size']) * col_avg_y['mean']
        col_avg_y.drop(['size', 'mean'], axis=1, inplace=True)
 
        nf_train = X_train.join(col_avg_y, on=variable)[nf_name].values
        nf_test = X_test.join(col_avg_y, on=variable).fillna(prior, inplace=False)[nf_name].values
 
        return nf_train, nf_test, prior, col_avg_y
 
    def fit_transform(self, X, y):
        """
        :param X: pandas DataFrame, n_samples * n_features
        :param y: pandas Series or numpy array, n_samples
        :return X_new: the transformed pandas DataFrame containing mean-encoded categorical features
        """
        X_new = X.copy()
        if self.target_type == 'classification':
            skf = StratifiedKFold(self.n_splits)
        else:
            skf = KFold(self.n_splits)
 
        if self.target_type == 'classification':
            self.target_values = sorted(set(y))
            self.learned_stats = {'{}_pred_{}'.format(variable, target): [] for variable, target in
                                  product(self.categorical_features, self.target_values)}
            for variable, target in product(self.categorical_features, self.target_values):
                nf_name = '{}_pred_{}'.format(variable, target)
                X_new.loc[:, nf_name] = np.nan
                for large_ind, small_ind in skf.split(X, y):
                    nf_large, nf_small, prior, col_avg_y = MeanEncoder.mean_encode_subroutine(
                        X_new.iloc[large_ind], y.iloc[large_ind], X_new.iloc[small_ind], variable, target, self.prior_weight_func)
                    X_new.iloc[small_ind, -1] = nf_small
                    self.learned_stats[nf_name].append((prior, col_avg_y))
        else:
            self.learned_stats = {'{}_pred'.format(variable): [] for variable in self.categorical_features}
            for variable in self.categorical_features:
                nf_name = '{}_pred'.format(variable)
                X_new.loc[:, nf_name] = np.nan
                for large_ind, small_ind in skf.split(X, y):
                    nf_large, nf_small, prior, col_avg_y = MeanEncoder.mean_encode_subroutine(
                        X_new.iloc[large_ind], y.iloc[large_ind], X_new.iloc[small_ind], variable, None, self.prior_weight_func)
                    X_new.iloc[small_ind, -1] = nf_small
                    self.learned_stats[nf_name].append((prior, col_avg_y))
        return X_new
 
    def transform(self, X):
        """
        :param X: pandas DataFrame, n_samples * n_features
        :return X_new: the transformed pandas DataFrame containing mean-encoded categorical features
        """
        X_new = X.copy()
 
        if self.target_type == 'classification':
            for variable, target in product(self.categorical_features, self.target_values):
                nf_name = '{}_pred_{}'.format(variable, target)
                X_new[nf_name] = 0
                for prior, col_avg_y in self.learned_stats[nf_name]:
                    X_new[nf_name] += X_new[[variable]].join(col_avg_y, on=variable).fillna(prior, inplace=False)[
                        nf_name]
                X_new[nf_name] /= self.n_splits
        else:
            for variable in self.categorical_features:
                nf_name = '{}_pred'.format(variable)
                X_new[nf_name] = 0
                for prior, col_avg_y in self.learned_stats[nf_name]:
                    X_new[nf_name] += X_new[[variable]].join(col_avg_y, on=variable).fillna(prior, inplace=False)[
                        nf_name]
                X_new[nf_name] /= self.n_splits
 
        return X_new

# %% [markdown]
# ### 用户表

# %%
train_user = pd.read_hdf('../input/train_user.h5')
test_user = pd.read_hdf('../input/test_user.h5')

# %%
df_user = pd.concat([train_user, test_user])

# %%
# 号码量*消费值
df_user['idcard_cnt*arpu_202004'] = df_user['idcard_cnt'] * df_user['arpu_202004']

# 消费值/号码量
df_user['arpu_202004/idcard_cnt'] = df_user['arpu_202004'] / df_user['idcard_cnt']

# %%
# count编码
count_list = ['city_name', 'county_name', 'idcard_cnt']

df_user = count_coding(df_user, count_list)

# %%
lbl = LabelEncoder()

for f in tqdm(['city_name', 'county_name']):
    df_user[f] = df_user[f].fillna('NA')
    df_user[f] = lbl.fit_transform(df_user[f].astype(str))
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 286.48it/s]

# %%
# 交叉特征
cross_cat = ['city_name', 'county_name']
cross_num = ['idcard_cnt', 'arpu_202004']
df_user = cross_cat_num(df_user, cross_num, cross_cat)
# Out:
#   0%|                                                                                            | 0/2 [00:00<?, ?it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 115.03it/s]
#
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 133.69it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 50.32it/s]

# %% [markdown]
# ### 电话表

# %%
cols = ['phone_no_m', 'opposite_no_m', 'calltype_id', 'start_datetime', 'call_dur', 'imei_m']

train_voc = pd.read_hdf('../input/train_voc.h5', usecols=cols)
test_voc = pd.read_hdf('../input/test_voc.h5', usecols=cols)

# %%
df_voc = pd.concat([train_voc, test_voc])

# %%
df_voc['voc_day'] = df_voc['start_datetime'].astype('datetime64').dt.day
df_voc['voc_hour'] = df_voc['start_datetime'].astype('datetime64').dt.hour
df_voc['voc_dayofweek'] = df_voc['start_datetime'].astype('datetime64').dt.dayofweek
df_voc['voc_time'] = (df_voc['voc_day'] - df_voc['voc_day'].min()) * 24 + df_voc['voc_hour']

# %%
# 每个phone_no_m有几个独立的手机
df_voc['voc_phone_nunique'] = df_voc.groupby('phone_no_m')['imei_m'].transform('nunique')

# 每个phone_no_m在该月与多少个不同的人通话
df_voc['voc_opposite_nunique'] = df_voc.groupby('phone_no_m')['opposite_no_m'].transform('nunique')

# 每个phone_no_m在该月打了多少通电话
df_voc['voc_count'] = df_voc.groupby('phone_no_m')['phone_no_m'].transform('count')

# 每个phone_no_m在该月总的通话时长
df_voc['call_dur_sum'] = df_voc.groupby('phone_no_m')['call_dur'].transform('sum')

# 每个phone_no_m在该月与每个opposite_no_m打了多少通电话
df_voc['voc_count_mutual'] = df_voc.groupby(['phone_no_m', 'opposite_no_m'])['phone_no_m'].transform('count')

# 每个phone_no_m在该月与每个opposite_no_m打了多久的电话
df_voc['call_dur_sum_mutual'] = df_voc.groupby(['phone_no_m', 'opposite_no_m'])['call_dur'].transform('sum')

# %% [markdown]
# #### 通话次数

# %% [markdown]
# ##### 每天通话次数统计 day

# %%
## 用户每个小时,每天出现的次数

# for time in ['day','time']:
#     print('user_id_'+time)
#     data['user_id_'+time] = data['user_id']  + '_' + data[time].astype(str)
#     dic_ = data['user_id_'+time].value_counts().to_dict()
#     data['user_id_'+time +'_count'] = data['user_id_'+time].apply(lambda x: dic_[x])
#     data.drop('user_id_'+time, axis=1,inplace = True)

# %%
# 每天通话次数统计

# 每个phone_no_m在每天的通话次数
df_voc['voc_day_count'] = df_voc.groupby(['phone_no_m', 'voc_day'])['phone_no_m'].transform('count')
# 每个phone_no_m每天的通话次数的最大值
df_voc['voc_day_count_max'] = df_voc.groupby('phone_no_m')['voc_day_count'].transform('max')
# df_voc['voc_day_count_min'] = df_voc.groupby('phone_no_m')['voc_day_count'].transform('min')
df_voc['voc_day_count_mean'] = df_voc.groupby('phone_no_m')['voc_day_count'].transform('mean')
df_voc['voc_day_count_std'] = df_voc.groupby('phone_no_m')['voc_day_count'].transform('std')


# 每天与不同的人通话次数统计
df_voc['voc_day_diff_count'] = df_voc.groupby(['phone_no_m', 'opposite_no_m', 'voc_day'])['phone_no_m'].transform('count')
df_voc['voc_day_diff_count_max'] = df_voc.groupby('phone_no_m')['voc_day_diff_count'].transform('max')
df_voc['voc_day_diff_count_min'] = df_voc.groupby('phone_no_m')['voc_day_diff_count'].transform('min')
df_voc['voc_day_diff_count_mean'] = df_voc.groupby('phone_no_m')['voc_day_diff_count'].transform('mean')
df_voc['voc_day_diff_count_std'] = df_voc.groupby('phone_no_m')['voc_day_diff_count'].transform('std')

del df_voc['voc_day_count'], df_voc['voc_day_diff_count']
gc.collect()

# 每个phone_no_m在几号的通话次数
voc_day_res = df_voc.groupby(['phone_no_m', 'voc_day'])['phone_no_m'].count().unstack()

for i in df_voc['voc_day'].unique():
    df_voc['voc_day{}_count'.format(i)] = df_voc['phone_no_m'].map(voc_day_res[i])

# %% [markdown]
# ##### 小时通话次数统计 voc_time

# %%
# 小时通话次数统计
df_voc['voc_time_count'] = df_voc.groupby(['phone_no_m', 'voc_time'])['phone_no_m'].transform('count')
df_voc['voc_time_count_max'] = df_voc.groupby('phone_no_m')['voc_time_count'].transform('max')
# df_voc['voc_time_count_min'] = df_voc.groupby('phone_no_m')['voc_time_count'].transform('min')
df_voc['voc_time_count_mean'] = df_voc.groupby('phone_no_m')['voc_time_count'].transform('mean')
df_voc['voc_time_count_std'] = df_voc.groupby('phone_no_m')['voc_time_count'].transform('std')


# 小时与不同的人通话次数统计
df_voc['voc_time_diff_count'] = df_voc.groupby(['phone_no_m', 'opposite_no_m', 'voc_time'])['phone_no_m'].transform('count')
df_voc['voc_time_diff_count_max'] = df_voc.groupby('phone_no_m')['voc_time_diff_count'].transform('max')
# df_voc['voc_time_diff_count_min'] = df_voc.groupby('phone_no_m')['voc_time_diff_count'].transform('min')
df_voc['voc_time_diff_count_mean'] = df_voc.groupby('phone_no_m')['voc_time_diff_count'].transform('mean')
df_voc['voc_time_diff_count_std'] = df_voc.groupby('phone_no_m')['voc_time_diff_count'].transform('std')

del df_voc['voc_time_count'], df_voc['voc_time_diff_count']
gc.collect()
# Out:
# 0

# %% [markdown]
# ##### 每小时通话次数统计 hour

# %%
# 一小时内通话次数

df_voc['voc_hour_count'] = df_voc.groupby(['phone_no_m', 'voc_hour'])['phone_no_m'].transform('count')
df_voc['voc_hour_count_max'] = df_voc.groupby('phone_no_m')['voc_hour_count'].transform('max')
# df_voc['voc_hour_count_min'] = df_voc.groupby('phone_no_m')['voc_hour_count'].transform('min')
df_voc['voc_hour_count_mean'] = df_voc.groupby('phone_no_m')['voc_hour_count'].transform('mean')
df_voc['voc_hour_count_std'] = df_voc.groupby('phone_no_m')['voc_hour_count'].transform('std')


# 一小时内与不同的人通话次数

df_voc['voc_hour_diff_count'] = df_voc.groupby(['phone_no_m', 'opposite_no_m', 'voc_hour'])['phone_no_m'].transform('count')
df_voc['voc_hour_diff_count_max'] = df_voc.groupby('phone_no_m')['voc_hour_diff_count'].transform('max')
# df_voc['voc_hour_diff_count_min'] = df_voc.groupby('phone_no_m')['voc_hour_diff_count'].transform('min')
df_voc['voc_hour_diff_count_mean'] = df_voc.groupby('phone_no_m')['voc_hour_diff_count'].transform('mean')
df_voc['voc_hour_diff_count_std'] = df_voc.groupby('phone_no_m')['voc_hour_diff_count'].transform('std')

del df_voc['voc_hour_count'], df_voc['voc_hour_diff_count']
gc.collect()
# Out:
# 0

# %% [markdown]
# ##### 按周几通话次数统计

# %%
# 周几通话次数

df_voc['voc_dayofweek_count'] = df_voc.groupby(['phone_no_m', 'voc_dayofweek'])['phone_no_m'].transform('count')
df_voc['voc_dayofweek_count_max'] = df_voc.groupby('phone_no_m')['voc_dayofweek_count'].transform('max')
# df_voc['voc_dayofweek_count_min'] = df_voc.groupby('phone_no_m')['voc_dayofweek_count'].transform('min')
df_voc['voc_dayofweek_count_mean'] = df_voc.groupby('phone_no_m')['voc_dayofweek_count'].transform('mean')
df_voc['voc_dayofweek_count_std'] = df_voc.groupby('phone_no_m')['voc_dayofweek_count'].transform('std')


# 周几与不同的人通话次数

df_voc['voc_dayofweek_diff_count'] = df_voc.groupby(['phone_no_m', 'opposite_no_m', 'voc_dayofweek'])['phone_no_m'].transform('count')
df_voc['voc_dayofweek_diff_count_max'] = df_voc.groupby('phone_no_m')['voc_dayofweek_diff_count'].transform('max')
# df_voc['voc_dayofweek_diff_count_min'] = df_voc.groupby('phone_no_m')['voc_dayofweek_diff_count'].transform('min')
df_voc['voc_dayofweek_diff_count_mean'] = df_voc.groupby('phone_no_m')['voc_dayofweek_diff_count'].transform('mean')
df_voc['voc_dayofweek_diff_count_std'] = df_voc.groupby('phone_no_m')['voc_dayofweek_diff_count'].transform('std')

del df_voc['voc_dayofweek_count'], df_voc['voc_dayofweek_diff_count']
gc.collect()

# 每个phone_no_m在周几的通话次数
voc_dayofweek_res = df_voc.groupby(['phone_no_m', 'voc_dayofweek'])['phone_no_m'].count().unstack()

for i in df_voc['voc_dayofweek'].unique():
    df_voc['voc_dayofweek{}_count'.format(i)] = df_voc['phone_no_m'].map(voc_dayofweek_res[i])

# %% [markdown]
# #### 通话时长

# %% [markdown]
# ##### 每天通话时长统计 voc_day

# %%
# 每天通话时长统计
df_voc['call_dur_day_sum'] = df_voc.groupby(['phone_no_m', 'voc_day'])['call_dur'].transform('sum')
df_voc['call_dur_day_sum_max'] = df_voc.groupby('phone_no_m')['call_dur_day_sum'].transform('max')
df_voc['call_dur_day_sum_min'] = df_voc.groupby('phone_no_m')['call_dur_day_sum'].transform('min')
df_voc['call_dur_day_sum_mean'] = df_voc.groupby('phone_no_m')['call_dur_day_sum'].transform('mean')
df_voc['call_dur_day_sum_std'] = df_voc.groupby('phone_no_m')['call_dur_day_sum'].transform('std')


# 每天与不同的人通话时长统计
df_voc['call_dur_day_diff_sum'] = df_voc.groupby(['phone_no_m', 'opposite_no_m', 'voc_day'])['call_dur'].transform('sum')
df_voc['call_dur_day_diff_sum_max'] = df_voc.groupby('phone_no_m')['call_dur_day_diff_sum'].transform('max')
df_voc['call_dur_day_diff_sum_min'] = df_voc.groupby('phone_no_m')['call_dur_day_diff_sum'].transform('min')
df_voc['call_dur_day_diff_sum_mean'] = df_voc.groupby('phone_no_m')['call_dur_day_diff_sum'].transform('mean')
df_voc['call_dur_day_diff_sum_std'] = df_voc.groupby('phone_no_m')['call_dur_day_diff_sum'].transform('std')

del df_voc['call_dur_day_sum'], df_voc['call_dur_day_diff_sum']
gc.collect()


# 每个phone_no_m在几号的通话时长
voc_day_call_dur_res = df_voc.groupby(['phone_no_m', 'voc_day'])['call_dur'].sum().unstack()

for i in df_voc['voc_day'].unique():
    df_voc['voc_day{}_call_dur_sum'.format(i)] = df_voc['phone_no_m'].map(voc_day_call_dur_res[i])

# %% [markdown]
# ##### 小时通话时长统计 voc_time

# %%
# 小时通话时长统计
df_voc['call_dur_time_sum'] = df_voc.groupby(['phone_no_m', 'voc_time'])['call_dur'].transform('sum')
df_voc['call_dur_time_sum_max'] = df_voc.groupby('phone_no_m')['call_dur_time_sum'].transform('max')
# df_voc['call_dur_time_sum_min'] = df_voc.groupby('phone_no_m')['call_dur_time_sum'].transform('min')
df_voc['call_dur_time_sum_mean'] = df_voc.groupby('phone_no_m')['call_dur_time_sum'].transform('mean')
df_voc['call_dur_time_sum_std'] = df_voc.groupby('phone_no_m')['call_dur_time_sum'].transform('std')


# 小时与不同的人通话时长统计
df_voc['call_dur_time_diff_sum'] = df_voc.groupby(['phone_no_m', 'opposite_no_m', 'voc_time'])['call_dur'].transform('sum')
df_voc['call_dur_time_diff_sum_max'] = df_voc.groupby('phone_no_m')['call_dur_time_diff_sum'].transform('max')
# df_voc['call_dur_time_diff_sum_min'] = df_voc.groupby('phone_no_m')['call_dur_time_diff_sum'].transform('min')
df_voc['call_dur_time_diff_sum_mean'] = df_voc.groupby('phone_no_m')['call_dur_time_diff_sum'].transform('mean')
df_voc['call_dur_time_diff_sum_std'] = df_voc.groupby('phone_no_m')['call_dur_time_diff_sum'].transform('std')

del df_voc['call_dur_time_sum'], df_voc['call_dur_time_diff_sum']
gc.collect()


# 每个phone_no_m在几号的通话时长
# voc_day_call_dur_res = df_voc.groupby(['phone_no_m', 'voc_day'])['call_dur'].sum().unstack()

# for i in df_voc['voc_day'].unique():
#     df_voc['voc_day_call_dur{}_sum'.format(i)] = df_voc['phone_no_m'].map(voc_day_call_dur_res[i])
# Out:
# 0

# %% [markdown]
# ##### 每小时通话时长统计 hour

# %%
# 每小时通话时长统计
df_voc['call_dur_hour_sum'] = df_voc.groupby(['phone_no_m', 'voc_hour'])['call_dur'].transform('sum')
df_voc['call_dur_hour_sum_max'] = df_voc.groupby('phone_no_m')['call_dur_hour_sum'].transform('max')
df_voc['call_dur_hour_sum_min'] = df_voc.groupby('phone_no_m')['call_dur_hour_sum'].transform('min')
df_voc['call_dur_hour_sum_mean'] = df_voc.groupby('phone_no_m')['call_dur_hour_sum'].transform('mean')
df_voc['call_dur_hour_sum_std'] = df_voc.groupby('phone_no_m')['call_dur_hour_sum'].transform('std')


# 每小时与不同的人通话时长统计
df_voc['call_dur_hour_diff_sum'] = df_voc.groupby(['phone_no_m', 'opposite_no_m', 'voc_hour'])['call_dur'].transform('sum')
df_voc['call_dur_hour_diff_sum_max'] = df_voc.groupby('phone_no_m')['call_dur_hour_diff_sum'].transform('max')
df_voc['call_dur_hour_diff_sum_min'] = df_voc.groupby('phone_no_m')['call_dur_hour_diff_sum'].transform('min')
df_voc['call_dur_hour_diff_sum_mean'] = df_voc.groupby('phone_no_m')['call_dur_hour_diff_sum'].transform('mean')
df_voc['call_dur_hour_diff_sum_std'] = df_voc.groupby('phone_no_m')['call_dur_hour_diff_sum'].transform('std')

del df_voc['call_dur_hour_sum'], df_voc['call_dur_hour_diff_sum']
gc.collect()


# 每个phone_no_m在几时的通话时长
voc_hour_call_dur_res = df_voc.groupby(['phone_no_m', 'voc_hour'])['call_dur'].sum().unstack()

for i in df_voc['voc_hour'].unique():
    df_voc['voc_hour{}_call_dur_sum'.format(i)] = df_voc['phone_no_m'].map(voc_hour_call_dur_res[i])

# %% [markdown]
# ##### 周几通话时长统计 dayofweek

# %%
# 周几通话时长统计
df_voc['call_dur_dayofweek_sum'] = df_voc.groupby(['phone_no_m', 'voc_dayofweek'])['call_dur'].transform('sum')
df_voc['call_dur_dayofweek_sum_max'] = df_voc.groupby('phone_no_m')['call_dur_dayofweek_sum'].transform('max')
df_voc['call_dur_dayofweek_sum_min'] = df_voc.groupby('phone_no_m')['call_dur_dayofweek_sum'].transform('min')
df_voc['call_dur_dayofweek_sum_mean'] = df_voc.groupby('phone_no_m')['call_dur_dayofweek_sum'].transform('mean')
df_voc['call_dur_dayofweek_sum_std'] = df_voc.groupby('phone_no_m')['call_dur_dayofweek_sum'].transform('std')


# 周几与不同的人通话时长统计
df_voc['call_dur_dayofweek_diff_sum'] = df_voc.groupby(['phone_no_m', 'opposite_no_m', 'voc_dayofweek'])['call_dur'].transform('sum')
df_voc['call_dur_dayofweek_diff_sum_max'] = df_voc.groupby('phone_no_m')['call_dur_dayofweek_diff_sum'].transform('max')
df_voc['call_dur_dayofweek_diff_sum_min'] = df_voc.groupby('phone_no_m')['call_dur_dayofweek_diff_sum'].transform('min')
df_voc['call_dur_dayofweek_diff_sum_mean'] = df_voc.groupby('phone_no_m')['call_dur_dayofweek_diff_sum'].transform('mean')
df_voc['call_dur_dayofweek_diff_sum_std'] = df_voc.groupby('phone_no_m')['call_dur_dayofweek_diff_sum'].transform('std')

del df_voc['call_dur_dayofweek_sum'], df_voc['call_dur_dayofweek_diff_sum']
gc.collect()


# 每个phone_no_m在周几的通话时长
voc_dayofweek_call_dur_res = df_voc.groupby(['phone_no_m', 'voc_dayofweek'])['call_dur'].sum().unstack()

for i in df_voc['voc_dayofweek'].unique():
    df_voc['voc_dayofweek{}_call_dur_sum'.format(i)] = df_voc['phone_no_m'].map(voc_dayofweek_call_dur_res[i])

# %% [markdown]
# ### 短信表

# %%
train_sms = pd.read_hdf('../input/train_sms.h5')
test_sms = pd.read_hdf('../input/test_sms.h5')

# %%
df_sms = pd.concat([train_sms, test_sms])

# %%
df_sms['sms_day'] = df_sms['request_datetime'].astype('datetime64').dt.day
df_sms['sms_hour'] = df_sms['request_datetime'].astype('datetime64').dt.hour
df_sms['sms_dayofweek'] = df_sms['request_datetime'].astype('datetime64').dt.dayofweek
df_sms['sms_time'] = (df_sms['sms_day'] - df_sms['sms_day'].min()) * 24 + df_sms['sms_hour']

# %%
df_sms.rename(columns={'calltype_id': 'calltype_id_sms'}, inplace=True)

# %%
# 该月总的短信次数
df_sms['sms_count'] = df_sms.groupby('phone_no_m')['phone_no_m'].transform('count')

# 相互发送短信次数
df_sms['sms_count_mutual'] = df_sms.groupby(['phone_no_m', 'opposite_no_m'])['phone_no_m'].transform('count')

# %%
# 一天内短信统计量

df_sms['sms_day_count'] = df_sms.groupby(['phone_no_m', 'sms_day'])['phone_no_m'].transform('count')
df_sms['sms_day_count_max'] = df_sms.groupby('phone_no_m')['sms_day_count'].transform('max')
df_sms['sms_day_count_min'] = df_sms.groupby('phone_no_m')['sms_day_count'].transform('min')
df_sms['sms_day_count_mean'] = df_sms.groupby('phone_no_m')['sms_day_count'].transform('mean')
df_sms['sms_day_count_std'] = df_sms.groupby('phone_no_m')['sms_day_count'].transform('std')

del df_sms['sms_day_count']


# 一天内与不同的人短信统计量
df_sms['sms_day_diff_count'] = df_sms.groupby(['phone_no_m', 'opposite_no_m', 'sms_day'])['phone_no_m'].transform('count')
df_sms['sms_day_diff_count_max'] = df_sms.groupby('phone_no_m')['sms_day_diff_count'].transform('max')
df_sms['sms_day_diff_count_min'] = df_sms.groupby('phone_no_m')['sms_day_diff_count'].transform('min')
df_sms['sms_day_diff_count_mean'] = df_sms.groupby('phone_no_m')['sms_day_diff_count'].transform('mean')
df_sms['sms_day_diff_count_std'] = df_sms.groupby('phone_no_m')['sms_day_diff_count'].transform('std')

del df_sms['sms_day_diff_count']
gc.collect()

# 几号短信次数统计
sms_day_res = df_sms.groupby(['phone_no_m', 'sms_day'])['phone_no_m'].count().unstack()

for i in df_sms['sms_day'].unique():
    df_sms['sms_day{}_count'.format(i)] = df_sms['phone_no_m'].map(sms_day_res[i])

# %%
# 一小时内短信统计量

df_sms['sms_hour_count'] = df_sms.groupby(['phone_no_m', 'sms_hour'])['phone_no_m'].transform('count')
df_sms['sms_hour_count_max'] = df_sms.groupby('phone_no_m')['sms_hour_count'].transform('max')
df_sms['sms_hour_count_min'] = df_sms.groupby('phone_no_m')['sms_hour_count'].transform('min')
df_sms['sms_hour_count_mean'] = df_sms.groupby('phone_no_m')['sms_hour_count'].transform('mean')
df_sms['sms_hour_count_std'] = df_sms.groupby('phone_no_m')['sms_hour_count'].transform('std')




# 一小时内与不同的人短信统计量
df_sms['sms_hour_diff_count'] = df_sms.groupby(['phone_no_m', 'opposite_no_m', 'sms_hour'])['phone_no_m'].transform('count')
df_sms['sms_hour_diff_count_max'] = df_sms.groupby('phone_no_m')['sms_hour_diff_count'].transform('max')
df_sms['sms_hour_diff_count_min'] = df_sms.groupby('phone_no_m')['sms_hour_diff_count'].transform('min')
df_sms['sms_hour_diff_count_mean'] = df_sms.groupby('phone_no_m')['sms_hour_diff_count'].transform('mean')
df_sms['sms_hour_diff_count_std'] = df_sms.groupby('phone_no_m')['sms_hour_diff_count'].transform('std')

del df_sms['sms_hour_count'], df_sms['sms_hour_diff_count']
gc.collect()
# Out:
# 0

# %%
# 周几短信统计量

df_sms['sms_dayofweek_count'] = df_sms.groupby(['phone_no_m', 'sms_dayofweek'])['phone_no_m'].transform('count')
df_sms['sms_dayofweek_count_max'] = df_sms.groupby('phone_no_m')['sms_dayofweek_count'].transform('max')
df_sms['sms_dayofweek_count_min'] = df_sms.groupby('phone_no_m')['sms_dayofweek_count'].transform('min')
df_sms['sms_dayofweek_count_mean'] = df_sms.groupby('phone_no_m')['sms_dayofweek_count'].transform('mean')
df_sms['sms_dayofweek_count_std'] = df_sms.groupby('phone_no_m')['sms_dayofweek_count'].transform('std')

# 周几与不同的人短信统计量
df_sms['sms_dayodweek_diff_count'] = df_sms.groupby(['phone_no_m', 'opposite_no_m', 'sms_dayofweek'])['phone_no_m'].transform('count')
df_sms['sms_dayodweek_diff_count_max'] = df_sms.groupby('phone_no_m')['sms_dayodweek_diff_count'].transform('max')
df_sms['sms_dayodweek_diff_count_min'] = df_sms.groupby('phone_no_m')['sms_dayodweek_diff_count'].transform('min')
df_sms['sms_dayodweek_diff_count_mean'] = df_sms.groupby('phone_no_m')['sms_dayodweek_diff_count'].transform('mean')
df_sms['sms_dayodweek_diff_count_std'] = df_sms.groupby('phone_no_m')['sms_dayodweek_diff_count'].transform('std')

del df_sms['sms_dayofweek_count'], df_sms['sms_dayodweek_diff_count']
gc.collect()

# 周几短信次数统计
sms_dayofweek_res = df_sms.groupby(['phone_no_m', 'sms_dayofweek'])['phone_no_m'].count().unstack()

for i in df_sms['sms_dayofweek'].unique():
    df_sms['sms_dayofweek{}_count'.format(i)] = df_sms['phone_no_m'].map(sms_dayofweek_res[i])

# %% [markdown]
# ### 应用表

# %%
train_app = pd.read_hdf('../input/train_app.h5')
test_app = pd.read_hdf('../input/test_app.h5')

# %%
df_app = pd.concat([train_app, test_app])

# %%
# 用户流量统计

df_app['total_flow'] = df_app.groupby('phone_no_m')['flow'].transform('sum')
df_app['flow_max'] = df_app.groupby('phone_no_m')['flow'].transform('max')
df_app['flow_min'] = df_app.groupby('phone_no_m')['flow'].transform('min')
df_app['flow_mean'] = df_app.groupby('phone_no_m')['flow'].transform('mean')
df_app['flow_std'] = df_app.groupby('phone_no_m')['flow'].transform('std')

# 应用数
df_app['app_count'] = df_app.groupby('phone_no_m')['phone_no_m'].transform('count')

df_app['total_flow/app_count'] = np.round(df_app['total_flow'] / df_app['app_count'], 2)

# %%
# count编码
app_count_list = ['busi_name']

df_app = count_coding(df_app, app_count_list)

# %%
lbl = LabelEncoder()

for f in tqdm(['busi_name']):
    df_app[f] = df_app[f].fillna('NA')
    df_app[f] = lbl.fit_transform(df_app[f].astype(str))
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  4.56it/s]

# %%
# 用户在每个app上的流量统计

df_app['busi_name_total_flow'] = df_app.groupby(['phone_no_m', 'busi_name'])['flow'].transform('sum')
df_app['busi_name_flow_max'] = df_app.groupby(['phone_no_m', 'busi_name'])['flow'].transform('max')
df_app['busi_name_flow_min'] = df_app.groupby(['phone_no_m', 'busi_name'])['flow'].transform('min')
df_app['busi_name_flow_mean'] = df_app.groupby(['phone_no_m', 'busi_name'])['flow'].transform('mean')
df_app['busi_name_flow_std'] = df_app.groupby(['phone_no_m', 'busi_name'])['flow'].transform('std')

# %% [markdown]
# ### 合并数据

# %%
df_user.shape, df_voc.shape, df_sms.shape, df_app.shape
# Out:
# ((8151, 23), (985666, 173), (1319506, 72), (512100, 17))

# %%
print(df_user.columns.tolist())
# Out:
# ['phone_no_m', 'city_name', 'county_name', 'idcard_cnt', 'label', 'arpu_202004', 'idcard_cnt*arpu_202004', 'arpu_202004/idcard_cnt', 'city_name_count', 'county_name_count', 'idcard_cnt_count', 'city_name_idcard_cnt_max', 'city_name_idcard_cnt_min', 'city_name_idcard_cnt_median', 'city_name_arpu_202004_max', 'city_name_arpu_202004_min', 'city_name_arpu_202004_median', 'county_name_idcard_cnt_max', 'county_name_idcard_cnt_min', 'county_name_idcard_cnt_median', 'county_name_arpu_202004_max', 'county_name_arpu_202004_min', 'county_name_arpu_202004_median']

# %%
print(df_voc.columns.tolist())
# Out:
# ['phone_no_m', 'opposite_no_m', 'calltype_id', 'start_datetime', 'call_dur', 'city_name', 'county_name', 'imei_m', 'voc_day', 'voc_hour', 'voc_dayofweek', 'voc_time', 'voc_phone_nunique', 'voc_opposite_nunique', 'voc_count', 'call_dur_sum', 'voc_count_mutual', 'call_dur_sum_mutual', 'voc_day_count_max', 'voc_day_count_mean', 'voc_day_count_std', 'voc_day_diff_count_max', 'voc_day_diff_count_min', 'voc_day_diff_count_mean', 'voc_day_diff_count_std', 'voc_day22_count', 'voc_day23_count', 'voc_day1_count', 'voc_day3_count', 'voc_day9_count', 'voc_day6_count', 'voc_day10_count', 'voc_day26_count', 'voc_day27_count', 'voc_day13_count', 'voc_day28_count', 'voc_day30_count', 'voc_day20_count', 'voc_day16_count', 'voc_day19_count', 'voc_day21_count', 'voc_day29_count', 'voc_day17_count', 'voc_day7_count', 'voc_day14_count', 'voc_day15_count', 'voc_day5_count', 'voc_day2_count', 'voc_day12_count', 'voc_day8_count', 'voc_day18_count', 'voc_day31_count', 'voc_day4_count', 'voc_day24_count', 'voc_day25_count', 'voc_day11_count', 'voc_time_count_max', 'voc_time_count_mean', 'voc_time_count_std', 'voc_time_diff_count_max', 'voc_time_diff_count_mean', 'voc_time_diff_count_std', 'voc_hour_count_max', 'voc_hour_count_mean', 'voc_hour_count_std', 'voc_hour_diff_count_max', 'voc_hour_diff_count_mean', 'voc_hour_diff_count_std', 'voc_dayofweek_count_max', 'voc_dayofweek_count_mean', 'voc_dayofweek_count_std', 'voc_dayofweek_diff_count_max', 'voc_dayofweek_diff_count_mean', 'voc_dayofweek_diff_count_std', 'voc_dayofweek6_count', 'voc_dayofweek0_count', 'voc_dayofweek1_count', 'voc_dayofweek4_count', 'voc_dayofweek3_count', 'voc_dayofweek5_count', 'voc_dayofweek2_count', 'call_dur_day_sum_max', 'call_dur_day_sum_min', 'call_dur_day_sum_mean', 'call_dur_day_sum_std', 'call_dur_day_diff_sum_max', 'call_dur_day_diff_sum_min', 'call_dur_day_diff_sum_mean', 'call_dur_day_diff_sum_std', 'voc_day22_call_dur_sum', 'voc_day23_call_dur_sum', 'voc_day1_call_dur_sum', 'voc_day3_call_dur_sum', 'voc_day9_call_dur_sum', 'voc_day6_call_dur_sum', 'voc_day10_call_dur_sum', 'voc_day26_call_dur_sum', 'voc_day27_call_dur_sum', 'voc_day13_call_dur_sum', 'voc_day28_call_dur_sum', 'voc_day30_call_dur_sum', 'voc_day20_call_dur_sum', 'voc_day16_call_dur_sum', 'voc_day19_call_dur_sum', 'voc_day21_call_dur_sum', 'voc_day29_call_dur_sum', 'voc_day17_call_dur_sum', 'voc_day7_call_dur_sum', 'voc_day14_call_dur_sum', 'voc_day15_call_dur_sum', 'voc_day5_call_dur_sum', 'voc_day2_call_dur_sum', 'voc_day12_call_dur_sum', 'voc_day8_call_dur_sum', 'voc_day18_call_dur_sum', 'voc_day31_call_dur_sum', 'voc_day4_call_dur_sum', 'voc_day24_call_dur_sum', 'voc_day25_call_dur_sum', 'voc_day11_call_dur_sum', 'call_dur_time_sum_max', 'call_dur_time_sum_mean', 'call_dur_time_sum_std', 'call_dur_time_diff_sum_max', 'call_dur_time_diff_sum_mean', 'call_dur_time_diff_sum_std', 'call_dur_hour_sum_max', 'call_dur_hour_sum_min', 'call_dur_hour_sum_mean', 'call_dur_hour_sum_std', 'call_dur_hour_diff_sum_max', 'call_dur_hour_diff_sum_min', 'call_dur_hour_diff_sum_mean', 'call_dur_hour_diff_sum_std', 'voc_hour21_call_dur_sum', 'voc_hour18_call_dur_sum', 'voc_hour11_call_dur_sum', 'voc_hour15_call_dur_sum', 'voc_hour19_call_dur_sum', 'voc_hour9_call_dur_sum', 'voc_hour12_call_dur_sum', 'voc_hour14_call_dur_sum', 'voc_hour6_call_dur_sum', 'voc_hour20_call_dur_sum', 'voc_hour10_call_dur_sum', 'voc_hour13_call_dur_sum', 'voc_hour22_call_dur_sum', 'voc_hour8_call_dur_sum', 'voc_hour16_call_dur_sum', 'voc_hour17_call_dur_sum', 'voc_hour7_call_dur_sum', 'voc_hour5_call_dur_sum', 'voc_hour1_call_dur_sum', 'voc_hour23_call_dur_sum', 'voc_hour0_call_dur_sum', 'voc_hour3_call_dur_sum', 'voc_hour2_call_dur_sum', 'voc_hour4_call_dur_sum', 'call_dur_dayofweek_sum_max', 'call_dur_dayofweek_sum_min', 'call_dur_dayofweek_sum_mean', 'call_dur_dayofweek_sum_std', 'call_dur_dayofweek_diff_sum_max', 'call_dur_dayofweek_diff_sum_min', 'call_dur_dayofweek_diff_sum_mean', 'call_dur_dayofweek_diff_sum_std', 'voc_dayofweek6_call_d ...

# %%
voc_cols = [i for i in df_voc.columns if i not in ['opposite_no_m', 'start_datetime', 'city_name', 'county_name', 'imei_m']]
df_voc = df_voc[voc_cols].drop_duplicates(subset=['phone_no_m'])

# %%
print(df_sms.columns.tolist())
# Out:
# ['phone_no_m', 'opposite_no_m', 'calltype_id_sms', 'request_datetime', 'sms_day', 'sms_hour', 'sms_dayofweek', 'sms_time', 'sms_count', 'sms_count_mutual', 'sms_day_count_max', 'sms_day_count_min', 'sms_day_count_mean', 'sms_day_count_std', 'sms_day_diff_count_max', 'sms_day_diff_count_min', 'sms_day_diff_count_mean', 'sms_day_diff_count_std', 'sms_day1_count', 'sms_day2_count', 'sms_day3_count', 'sms_day4_count', 'sms_day5_count', 'sms_day6_count', 'sms_day7_count', 'sms_day8_count', 'sms_day9_count', 'sms_day10_count', 'sms_day11_count', 'sms_day12_count', 'sms_day13_count', 'sms_day14_count', 'sms_day15_count', 'sms_day16_count', 'sms_day17_count', 'sms_day18_count', 'sms_day19_count', 'sms_day20_count', 'sms_day21_count', 'sms_day22_count', 'sms_day23_count', 'sms_day24_count', 'sms_day25_count', 'sms_day26_count', 'sms_day27_count', 'sms_day28_count', 'sms_day29_count', 'sms_day30_count', 'sms_day31_count', 'sms_hour_count_max', 'sms_hour_count_min', 'sms_hour_count_mean', 'sms_hour_count_std', 'sms_hour_diff_count_max', 'sms_hour_diff_count_min', 'sms_hour_diff_count_mean', 'sms_hour_diff_count_std', 'sms_dayofweek_count_max', 'sms_dayofweek_count_min', 'sms_dayofweek_count_mean', 'sms_dayofweek_count_std', 'sms_dayodweek_diff_count_max', 'sms_dayodweek_diff_count_min', 'sms_dayodweek_diff_count_mean', 'sms_dayodweek_diff_count_std', 'sms_dayofweek6_count', 'sms_dayofweek0_count', 'sms_dayofweek1_count', 'sms_dayofweek2_count', 'sms_dayofweek3_count', 'sms_dayofweek4_count', 'sms_dayofweek5_count']

# %%
sms_cols = [i for i in df_sms.columns if i not in ['opposite_no_m', 'request_datetime']]
df_sms = df_sms[sms_cols].drop_duplicates(subset=['phone_no_m'])

# %%
print(df_app.columns.tolist())
# Out:
# ['phone_no_m', 'busi_name', 'flow', 'month_id', 'total_flow', 'flow_max', 'flow_min', 'flow_mean', 'flow_std', 'app_count', 'total_flow/app_count', 'busi_name_count', 'busi_name_total_flow', 'busi_name_flow_max', 'busi_name_flow_min', 'busi_name_flow_mean', 'busi_name_flow_std']

# %%
app_cols = [i for i in df_app.columns if i not in ['month_id']]
df_app = df_app[app_cols].drop_duplicates(subset=['phone_no_m'])

# %%
df = pd.merge(df_user, df_voc, how='left', on='phone_no_m')
df = pd.merge(df, df_sms, how='left', on='phone_no_m')
df = pd.merge(df, df_app, how='left', on='phone_no_m')

# %%
del df_user, df_voc, df_sms, df_app
gc.collect()
# Out:
# 20

# %%
# 通话费用=消费额-短信次数
df['arpu_202004-sms_count'] = df['arpu_202004'] - df['sms_count']

# 消费额/总流量
df['arpu_202004/total_flow'] = np.round(df['arpu_202004'] / df['total_flow'], 2)

# %%
# 通话费用/多少个不同的人
df['arpu_202004-sms_count/voc_opposite_nunique'] = np.round(df['arpu_202004-sms_count'] / df['voc_opposite_nunique'], 2)

# 每次通话平均通话费用
df['arpu_202004-sms_count/voc_count'] = np.round(df['arpu_202004-sms_count'] / df['voc_count'], 2)

# 每分钟通话费用
df['arpu_202004-sms_count/call_dur_sum'] = np.round(df['arpu_202004-sms_count'] / df['call_dur_sum'], 2)

# %%
df_train = df[df.label.notna()]
df_test = df[df.label.isna()]

df_train.shape, df_test.shape
# Out:
# ((6106, 279), (2045, 279))

# %%
df_train_train = df_train[df_train['voc_day'] <= 23]
df_train_valid = df_train[df_train['voc_day'] > 23]

X_train = df_train_train.drop('label', axis=1)
y_train = df_train_train['label']
X_valid = df_train_valid.drop('label', axis=1)
y_valid = df_train_valid['label']

# %%
train_cols = [i for i in X_train if i not in ['phone_no_m', 'label']]

# %%
params = {'objective': 'binary',
          'boosting': 'gbdt',
          'metric': 'auc',
          'learning_rate': 0.1,
          'num_leaves': 31,
          'lambda_l1': 0,
          'lambda_l2': 1,
          'min_data_in_leaf': 20,
          'is_unbalance': True,
          'max_depth': -1,
          'seed': 2020}

# %%
use_cols = []
useless_cols = []

for i in train_cols:
    print(i)
    
    lgb_train = lgb.Dataset(X_train[[i]].values, y_train) 
    lgb_eval= lgb.Dataset(X_valid[[i]].values, y_valid, reference=lgb_train)
    lgb_test = lgb.train(params,
                         lgb_train,
                         num_boost_round=1000,
                         valid_sets=[lgb_eval, lgb_train],
                         early_stopping_rounds=50,
                         verbose_eval=20)
    
    print('*' * 5)
    print(lgb_test.best_score['valid_0']['auc'])
    if lgb_test.best_score['valid_0']['auc'] > 0.52:
        use_cols.append(i)
    else:
        useless_cols.append(i)
    print('*' * 20)
    print('\n')
# Out:
# city_name
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.646321	valid_0's auc: 0.597995
# [40]	training's auc: 0.646321	valid_0's auc: 0.597995
# Early stopping, best iteration is:
# [1]	training's auc: 0.64515	valid_0's auc: 0.601982
# *****
# 0.601982421875
# ********************
#
#
# county_name
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.748006	valid_0's auc: 0.609027
# [40]	training's auc: 0.753241	valid_0's auc: 0.610905
# Early stopping, best iteration is:
# [2]	training's auc: 0.731584	valid_0's auc: 0.614792
# *****
# 0.6147916666666666
# ********************
#
#
# idcard_cnt
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.689453	valid_0's auc: 0.653587
# [40]	training's auc: 0.689453	valid_0's auc: 0.653587
# Early stopping, best iteration is:
# [3]	training's auc: 0.689453	valid_0's auc: 0.653587
# *****
# 0.6535872395833333
# ********************
#
#
# arpu_202004
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.734007	valid_0's auc: 0.619772
# [40]	training's auc: 0.744921	valid_0's auc: 0.616331
# Early stopping, best iteration is:
# [1]	training's auc: 0.702378	valid_0's auc: 0.63099
# *****
# 0.6309895833333333
# ********************
#
#
# idcard_cnt*arpu_202004
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.788187	valid_0's auc: 0.680902
# [40]	training's auc: 0.794274	valid_0's auc: 0.673766
# Early stopping, best iteration is:
# [1]	training's auc: 0.746841	valid_0's auc: 0.704655
# *****
# 0.7046549479166667
# ********************
#
#
# arpu_202004/idcard_cnt
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.704289	valid_0's auc: 0.593216
# [40]	training's auc: 0.713435	valid_0's auc: 0.591452
# Early stopping, best iteration is:
# [2]	training's auc: 0.668445	valid_0's auc: 0.604671
# *****
# 0.6046712239583333
# ********************
#
#
# city_name_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.644039	valid_0's auc: 0.601159
# [40]	training's auc: 0.644041	valid_0's auc: 0.602956
# Early stopping, best iteration is:
# [1]	training's auc: 0.642902	valid_0's auc: 0.603682
# *****
# 0.603681640625
# ********************
#
#
# county_name_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.734799	valid_0's auc: 0.614883
# [40]	training's auc: 0.736431	valid_0's auc: 0.615306
# Early stopping, best iteration is:
# [1]	training's auc: 0.726267	valid_0's auc: 0.621556
# *****
# 0.6215559895833334
# ********************
#
#
# idcard_cnt_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.689732	valid_0's auc: 0.657913
# [40]	training's auc: 0.689732	valid_0's auc: 0.657913
# Early stopping, best iteration is:
# [3]	training's auc: 0.689732	valid_0's auc: 0.657913
# *****
# 0.6579134114583334
# ********************
#
#
# city_name_idcard_cnt_max
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.624972	valid_0's auc: 0.57112
# [40]	training's auc: 0.624972	valid_0's auc: 0.57112
# Early stopping, best iteration is:
# [1]	training's auc: 0.624972	valid_0's auc: 0.57112
# *****
# 0.5711197916666667
# ********************
#
#
# city_name_idcard_cnt_min
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.554873	valid_0's auc: 0.54724
# [40]	training's auc: 0.554873	valid_0's auc: 0.54724
# Early stopping, best iteration is:
# [1]	training's auc: 0.554873	valid_0's auc: 0.54724
# *****
# 0.5472395833333333
# ********************
#
#
# city_name_idcard_cnt_median
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.543134	valid_0's auc: 0.544427
# [40]	training's auc: 0.543134	valid_0's auc: 0.544427
# Early stopping, best iteration is:
# [1]	training's auc: 0.543134	valid_0's auc: 0.544427
# *****
# 0.5444270833333333
# ********************
#
#
# city_name_arpu_202004_max
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.646317	valid_0's auc: 0.595205
# [40]	training's auc: 0.646325	valid_0's auc: 0.597627
# [60]	training's auc: 0.646325	valid_0's auc: 0.597627
# [80]	training's auc: 0.646325	valid_0's auc: 0.598109
# [100]	training's auc: 0.646325	valid_0's auc: 0.598109
# [120]	training's auc: 0.646325	valid_0's auc: 0.598109
# Early stopping, best iteration is:
# [71]	training's auc: 0.646325	valid_0's auc: 0.598109
# *****
# 0.5981087239583334
# ********************
#
#
# city_name_arpu_202004_min
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.530798	valid_0's auc: 0.473604
# [40]	training's auc: 0.530798	valid_0's auc: 0.473604
# Early stopping, best iteration is:
# [1]	training's auc: 0.530735	valid_0's auc: 0.474411
# *****
# 0.4744108072916667
# ********************
#
#
# city_name_arpu_202004_median
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.646059	valid_0's auc: 0.599014
# [40]	training's auc: 0.646067	valid_0's auc: 0.601436
# [60]	training's auc: 0.646067	valid_0's auc: 0.601436
# [80]	training's auc: 0.646067	valid_0's auc: 0.601436
# Early stopping, best iteration is:
# [39]	training's auc: 0.646067	valid_0's auc: 0.601436
# *****
# 0.601435546875
# ********************
#
#
# county_name_idcard_cnt_max
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.595224	valid_0's auc: 0.55943
# [40]	training's auc: 0.595224	valid_0's auc: 0.55943
# Early stopping, best iteration is:
# [1]	training's auc: 0.595137	valid_0's auc: 0.559775
# *****
# 0.559775390625
# ********************
#
#
# county_name_idcard_cnt_min
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.53452	valid_0's auc: 0.539844
# [40]	training's auc: 0.53452	valid_0's auc: 0.539844
# Early stopping, best iteration is:
# [1]	training's auc: 0.53452	valid_0's auc: 0.539844
# *****
# 0.53984375
# ********************
#
#
# county_name_idcard_cnt_median
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.586438	valid_0's auc: 0.535456
# [40]	training's auc: 0.58646	valid_0's auc: 0.535472
# Early stopping, best iteration is:
# [1]	training's auc: 0.584295	valid_0's auc: 0.539258
# *****
# 0.5392578125
# ********************
#
#
# county_name_arpu_202004_max
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.750828	valid_0's auc: 0.624896
# [40]	training's auc: 0.75397	valid_0's auc: 0.628102
# [60]	training's auc: 0.756155	valid_0's auc: 0.624489
# [80]	training's auc: 0.757328	valid_0's auc: 0.624795
# Early stopping, best iteration is:
# [35]	training's auc: 0.753147	valid_0's auc: 0.628307
# *****
# 0.6283072916666667
# ********************
#
#
# county_name_arpu_202004_min
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.548798	valid_0's auc: 0.525921
# [40]	training's auc: 0.548944	valid_0's auc: 0.525785
# Early stopping, best iteration is:
# [1]	training's auc: 0.548557	valid_0's auc: 0.526654
# *****
# 0.5266536458333333
# ********************
#
#
# county_name_arpu_202004_median
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.748587	valid_0's auc: 0.611253
# [40]	training's auc: 0.752862	valid_0's auc: 0.612949
# [60]	training's auc: 0.754693	valid_0's auc: 0.614642
# [80]	training's auc: 0.755863	valid_0's auc: 0.616673
# [100]	training's auc: 0.756763	valid_0's auc: 0.617282
# [120]	training's auc: 0.757495	valid_0's auc: 0.616702
# [140]	training's auc: 0.758009	valid_0's auc: 0.617646
# Early stopping, best iteration is:
# [96]	training's auc: 0.75667	valid_0's auc: 0.618538
# *****
# 0.6185384114583333
# ********************
#
#
# calltype_id
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.599137	valid_0's auc: 0.585104
# [40]	training's auc: 0.599137	valid_0's auc: 0.585104
# Early stopping, best iteration is:
# [1]	training's auc: 0.599137	valid_0's auc: 0.585104
# *****
# 0.5851041666666666
# ********************
#
#
# call_dur
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.639436	valid_0's auc: 0.451497
# [40]	training's auc: 0.649707	valid_0's auc: 0.461523
# Early stopping, best iteration is:
# [1]	training's auc: 0.56833	valid_0's auc: 0.473245
# *****
# 0.47324544270833335
# ********************
#
#
# voc_day
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.563097	valid_0's auc: 0.5
# [40]	training's auc: 0.563116	valid_0's auc: 0.5
# Early stopping, best iteration is:
# [1]	training's auc: 0.546379	valid_0's auc: 0.5
# *****
# 0.5
# ********************
#
#
# voc_hour
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.582403	valid_0's auc: 0.508031
# [40]	training's auc: 0.582462	valid_0's auc: 0.508415
# Early stopping, best iteration is:
# [1]	training's auc: 0.574698	valid_0's auc: 0.51847
# *****
# 0.5184700520833333
# ********************
#
#
# voc_dayofweek
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.531814	valid_0's auc: 0.509134
# [40]	training's auc: 0.531814	valid_0's auc: 0.509134
# Early stopping, best iteration is:
# [1]	training's auc: 0.523237	valid_0's auc: 0.524248
# *****
# 0.524248046875
# ********************
#
#
# voc_time
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.673209	valid_0's auc: 0.5
# [40]	training's auc: 0.679583	valid_0's auc: 0.5
# Early stopping, best iteration is:
# [1]	training's auc: 0.630534	valid_0's auc: 0.5
# *****
# 0.5
# ********************
#
#
# voc_phone_nunique
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.669052	valid_0's auc: 0.656488
# [40]	training's auc: 0.669119	valid_0's auc: 0.656514
# [60]	training's auc: 0.669119	valid_0's auc: 0.656514
# Early stopping, best iteration is:
# [23]	training's auc: 0.669119	valid_0's auc: 0.656514
# *****
# 0.656513671875
# ********************
#
#
# voc_opposite_nunique
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.786874	valid_0's auc: 0.721227
# [40]	training's auc: 0.788606	valid_0's auc: 0.721077
# Early stopping, best iteration is:
# [3]	training's auc: 0.784462	valid_0's auc: 0.723949
# *****
# 0.7239485677083334
# ********************
#
#
# voc_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.716634	valid_0's auc: 0.614336
# [40]	training's auc: 0.723152	valid_0's auc: 0.612135
# Early stopping, best iteration is:
# [1]	training's auc: 0.689068	valid_0's auc: 0.620107
# *****
# 0.620107421875
# ********************
#
#
# call_dur_sum
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.726326	valid_0's auc: 0.600046
# [40]	training's auc: 0.733792	valid_0's auc: 0.597926
# Early stopping, best iteration is:
# [1]	training's auc: 0.68601	valid_0's auc: 0.604489
# *****
# 0.6044889322916667
# ********************
#
#
# voc_count_mutual
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.69034	valid_0's auc: 0.617038
# [40]	training's auc: 0.691648	valid_0's auc: 0.616497
# [60]	training's auc: 0.692775	valid_0's auc: 0.614974
# Early stopping, best iteration is:
# [14]	training's auc: 0.68944	valid_0's auc: 0.617725
# *****
# 0.617724609375
# ********************
#
#
# call_dur_sum_mutual
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.698616	valid_0's auc: 0.605908
# [40]	training's auc: 0.705913	valid_0's auc: 0.597038
# Early stopping, best iteration is:
# [2]	training's auc: 0.675717	valid_0's auc: 0.61749
# *****
# 0.617490234375
# ********************
#
#
# voc_day_count_max
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.789807	valid_0's auc: 0.703792
# [40]	training's auc: 0.790292	valid_0's auc: 0.703206
# [60]	training's auc: 0.790679	valid_0's auc: 0.702399
# Early stopping, best iteration is:
# [12]	training's auc: 0.789493	valid_0's auc: 0.704668
# *****
# 0.70466796875
# ********************
#
#
# voc_day_count_mean
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.845533	valid_0's auc: 0.728568
# [40]	training's auc: 0.851232	valid_0's auc: 0.726842
# [60]	training's auc: 0.855152	valid_0's auc: 0.723887
# Early stopping, best iteration is:
# [16]	training's auc: 0.844302	valid_0's auc: 0.729111
# *****
# 0.729111328125
# ********************
#
#
# voc_day_count_std
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.820626	valid_0's auc: 0.750062
# [40]	training's auc: 0.827657	valid_0's auc: 0.752718
# [60]	training's auc: 0.831798	valid_0's auc: 0.753682
# [80]	training's auc: 0.834445	valid_0's auc: 0.752965
# [100]	training's auc: 0.836303	valid_0's auc: 0.754701
# [120]	training's auc: 0.837528	valid_0's auc: 0.754014
# [140]	training's auc: 0.838909	valid_0's auc: 0.753757
# Early stopping, best iteration is:
# [98]	training's auc: 0.836052	valid_0's auc: 0.754987
# *****
# 0.7549869791666667
# ********************
#
#
# voc_day_diff_count_max
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.612408	valid_0's auc: 0.541549
# [40]	training's auc: 0.612417	valid_0's auc: 0.541947
# Early stopping, best iteration is:
# [5]	training's auc: 0.610657	valid_0's auc: 0.550993
# *****
# 0.5509928385416667
# ********************
#
#
# voc_day_diff_count_min
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.504931	valid_0's auc: 0.500573
# [40]	training's auc: 0.504931	valid_0's auc: 0.500573
# Early stopping, best iteration is:
# [1]	training's auc: 0.504931	valid_0's auc: 0.500573
# *****
# 0.5005729166666667
# ********************
#
#
# voc_day_diff_count_mean
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.723892	valid_0's auc: 0.650762
# [40]	training's auc: 0.733769	valid_0's auc: 0.649385
# Early stopping, best iteration is:
# [2]	training's auc: 0.70163	valid_0's auc: 0.670169
# *****
# 0.6701692708333333
# ********************
#
#
# voc_day_diff_count_std
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.730046	valid_0's auc: 0.580407
# [40]	training's auc: 0.736655	valid_0's auc: 0.57999
# [60]	training's auc: 0.742687	valid_0's auc: 0.578249
# [80]	training's auc: 0.746304	valid_0's auc: 0.575557
# Early stopping, best iteration is:
# [34]	training's auc: 0.734654	valid_0's auc: 0.581816
# *****
# 0.58181640625
# ********************
#
#
# voc_day22_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.706546	valid_0's auc: 0.616484
# [40]	training's auc: 0.708645	valid_0's auc: 0.618268
# Early stopping, best iteration is:
# [1]	training's auc: 0.700071	valid_0's auc: 0.62083
# *****
# 0.620830078125
# ********************
#
#
# voc_day23_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.707177	valid_0's auc: 0.614469
# [40]	training's auc: 0.707519	valid_0's auc: 0.61415
# Early stopping, best iteration is:
# [3]	training's auc: 0.704264	valid_0's auc: 0.621055
# *****
# 0.6210546875
# ********************
#
#
# voc_day1_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.665204	valid_0's auc: 0.635866
# [40]	training's auc: 0.665259	valid_0's auc: 0.635967
# Early stopping, best iteration is:
# [3]	training's auc: 0.664558	valid_0's auc: 0.637061
# *****
# 0.637060546875
# ********************
#
#
# voc_day3_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.667445	valid_0's auc: 0.646569
# [40]	training's auc: 0.667807	valid_0's auc: 0.645576
# Early stopping, best iteration is:
# [6]	training's auc: 0.6671	valid_0's auc: 0.65083
# *****
# 0.650830078125
# ********************
#
#
# voc_day9_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.692863	valid_0's auc: 0.639899
# [40]	training's auc: 0.694121	valid_0's auc: 0.637559
# Early stopping, best iteration is:
# [2]	training's auc: 0.691558	valid_0's auc: 0.643314
# *****
# 0.6433138020833333
# ********************
#
#
# voc_day6_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.685042	valid_0's auc: 0.667122
# [40]	training's auc: 0.686282	valid_0's auc: 0.664629
# [60]	training's auc: 0.68723	valid_0's auc: 0.66526
# Early stopping, best iteration is:
# [19]	training's auc: 0.685028	valid_0's auc: 0.667389
# *****
# 0.6673893229166666
# ********************
#
#
# voc_day10_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.698647	valid_0's auc: 0.633926
# [40]	training's auc: 0.699356	valid_0's auc: 0.63166
# Early stopping, best iteration is:
# [1]	training's auc: 0.695671	valid_0's auc: 0.63834
# *****
# 0.63833984375
# ********************
#
#
# voc_day26_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.701107	valid_0's auc: 0.621468
# [40]	training's auc: 0.701605	valid_0's auc: 0.621159
# [60]	training's auc: 0.701631	valid_0's auc: 0.621077
# Early stopping, best iteration is:
# [26]	training's auc: 0.701232	valid_0's auc: 0.622995
# *****
# 0.6229947916666667
# ********************
#
#
# voc_day27_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.694287	valid_0's auc: 0.597881
# [40]	training's auc: 0.694549	valid_0's auc: 0.596663
# [60]	training's auc: 0.695961	valid_0's auc: 0.59805
# Early stopping, best iteration is:
# [14]	training's auc: 0.693701	valid_0's auc: 0.602028
# *****
# 0.6020279947916667
# ********************
#
#
# voc_day13_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.689505	valid_0's auc: 0.656032
# [40]	training's auc: 0.689582	valid_0's auc: 0.655882
# Early stopping, best iteration is:
# [1]	training's auc: 0.681876	valid_0's auc: 0.65749
# *****
# 0.657490234375
# ********************
#
#
# voc_day28_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.690149	valid_0's auc: 0.643818
# [40]	training's auc: 0.690381	valid_0's auc: 0.642399
# [60]	training's auc: 0.691194	valid_0's auc: 0.644629
# [80]	training's auc: 0.691253	valid_0's auc: 0.644844
# [100]	training's auc: 0.692258	valid_0's auc: 0.645176
# [120]	training's auc: 0.692653	valid_0's auc: 0.643783
# Early stopping, best iteration is:
# [81]	training's auc: 0.692255	valid_0's auc: 0.645208
# *****
# 0.6452083333333334
# ********************
#
#
# voc_day30_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.699724	valid_0's auc: 0.641191
# [40]	training's auc: 0.700114	valid_0's auc: 0.640156
# [60]	training's auc: 0.700403	valid_0's auc: 0.639176
# Early stopping, best iteration is:
# [10]	training's auc: 0.69943	valid_0's auc: 0.64264
# *****
# 0.6426399739583334
# ********************
#
#
# voc_day20_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.702052	valid_0's auc: 0.643249
# [40]	training's auc: 0.702949	valid_0's auc: 0.644971
# Early stopping, best iteration is:
# [3]	training's auc: 0.699894	valid_0's auc: 0.653896
# *****
# 0.653896484375
# ********************
#
#
# voc_day16_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.694532	valid_0's auc: 0.662044
# [40]	training's auc: 0.69474	valid_0's auc: 0.661081
# [60]	training's auc: 0.694891	valid_0's auc: 0.660713
# Early stopping, best iteration is:
# [17]	training's auc: 0.693517	valid_0's auc: 0.665068
# *****
# 0.665068359375
# ********************
#
#
# voc_day19_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.701403	valid_0's auc: 0.63069
# [40]	training's auc: 0.703027	valid_0's auc: 0.635059
# [60]	training's auc: 0.703997	valid_0's auc: 0.631576
# Early stopping, best iteration is:
# [10]	training's auc: 0.700121	valid_0's auc: 0.637744
# *****
# 0.637744140625
# ********************
#
#
# voc_day21_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.701262	valid_0's auc: 0.632988
# [40]	training's auc: 0.702685	valid_0's auc: 0.633971
# [60]	training's auc: 0.702869	valid_0's auc: 0.633776
# Early stopping, best iteration is:
# [24]	training's auc: 0.702433	valid_0's auc: 0.635814
# *****
# 0.6358138020833334
# ********************
#
#
# voc_day29_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.695526	valid_0's auc: 0.664678
# [40]	training's auc: 0.697036	valid_0's auc: 0.669115
# [60]	training's auc: 0.697646	valid_0's auc: 0.667363
# [80]	training's auc: 0.697861	valid_0's auc: 0.668874
# Early stopping, best iteration is:
# [39]	training's auc: 0.696974	valid_0's auc: 0.67
# *****
# 0.67
# ********************
#
#
# voc_day17_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.706998	valid_0's auc: 0.645752
# [40]	training's auc: 0.707086	valid_0's auc: 0.646921
# Early stopping, best iteration is:
# [3]	training's auc: 0.706487	valid_0's auc: 0.649515
# *****
# 0.6495149739583334
# ********************
#
#
# voc_day7_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.689547	valid_0's auc: 0.633509
# [40]	training's auc: 0.689865	valid_0's auc: 0.629619
# [60]	training's auc: 0.690833	valid_0's auc: 0.630446
# Early stopping, best iteration is:
# [18]	training's auc: 0.689615	valid_0's auc: 0.633796
# *****
# 0.6337955729166667
# ********************
#
#
# voc_day14_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.704348	valid_0's auc: 0.627236
# [40]	training's auc: 0.705353	valid_0's auc: 0.628011
# [60]	training's auc: 0.705476	valid_0's auc: 0.628232
# Early stopping, best iteration is:
# [29]	training's auc: 0.704502	valid_0's auc: 0.62999
# *****
# 0.629990234375
# ********************
#
#
# voc_day15_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.678593	valid_0's auc: 0.636514
# [40]	training's auc: 0.678855	valid_0's auc: 0.637562
# Early stopping, best iteration is:
# [5]	training's auc: 0.6781	valid_0's auc: 0.643883
# *****
# 0.6438834635416667
# ********************
#
#
# voc_day5_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.684325	valid_0's auc: 0.6896
# [40]	training's auc: 0.684542	valid_0's auc: 0.689137
# Early stopping, best iteration is:
# [2]	training's auc: 0.682051	valid_0's auc: 0.69221
# *****
# 0.6922102864583334
# ********************
#
#
# voc_day2_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.67273	valid_0's auc: 0.621784
# [40]	training's auc: 0.672864	valid_0's auc: 0.621781
# Early stopping, best iteration is:
# [3]	training's auc: 0.670456	valid_0's auc: 0.624971
# *****
# 0.624970703125
# ********************
#
#
# voc_day12_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.699124	valid_0's auc: 0.630329
# [40]	training's auc: 0.700689	valid_0's auc: 0.632484
# Early stopping, best iteration is:
# [4]	training's auc: 0.697914	valid_0's auc: 0.638346
# *****
# 0.6383463541666666
# ********************
#
#
# voc_day8_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.681353	valid_0's auc: 0.634355
# [40]	training's auc: 0.681394	valid_0's auc: 0.634076
# Early stopping, best iteration is:
# [6]	training's auc: 0.677833	valid_0's auc: 0.637956
# *****
# 0.6379557291666667
# ********************
#
#
# voc_day18_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.711095	valid_0's auc: 0.663057
# [40]	training's auc: 0.711373	valid_0's auc: 0.664362
# [60]	training's auc: 0.711545	valid_0's auc: 0.665609
# [80]	training's auc: 0.711661	valid_0's auc: 0.66609
# [100]	training's auc: 0.712841	valid_0's auc: 0.667562
# [120]	training's auc: 0.712894	valid_0's auc: 0.667536
# [140]	training's auc: 0.713537	valid_0's auc: 0.66763
# [160]	training's auc: 0.71361	valid_0's auc: 0.667591
# [180]	training's auc: 0.713714	valid_0's auc: 0.665872
# [200]	training's auc: 0.713769	valid_0's auc: 0.666156
# [220]	training's auc: 0.713908	valid_0's auc: 0.666149
# [240]	training's auc: 0.713968	valid_0's auc: 0.666182
# Early stopping, best iteration is:
# [196]	training's auc: 0.71372	valid_0's auc: 0.667848
# *****
# 0.6678483072916667
# ********************
#
#
# voc_day31_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.709531	valid_0's auc: 0.602148
# [40]	training's auc: 0.710121	valid_0's auc: 0.601732
# [60]	training's auc: 0.710354	valid_0's auc: 0.603105
# Early stopping, best iteration is:
# [10]	training's auc: 0.709153	valid_0's auc: 0.608506
# *****
# 0.608505859375
# ********************
#
#
# voc_day4_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.677871	valid_0's auc: 0.64792
# [40]	training's auc: 0.679804	valid_0's auc: 0.645443
# [60]	training's auc: 0.680832	valid_0's auc: 0.640671
# [80]	training's auc: 0.68091	valid_0's auc: 0.640573
# Early stopping, best iteration is:
# [30]	training's auc: 0.678626	valid_0's auc: 0.648193
# *****
# 0.648193359375
# ********************
#
#
# voc_day24_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.688256	valid_0's auc: 0.625326
# [40]	training's auc: 0.688484	valid_0's auc: 0.623083
# Early stopping, best iteration is:
# [3]	training's auc: 0.686792	valid_0's auc: 0.637907
# *****
# 0.6379069010416667
# ********************
#
#
# voc_day25_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.706672	valid_0's auc: 0.640436
# [40]	training's auc: 0.706708	valid_0's auc: 0.640352
# [60]	training's auc: 0.708777	valid_0's auc: 0.637318
# [80]	training's auc: 0.708833	valid_0's auc: 0.636924
# Early stopping, best iteration is:
# [45]	training's auc: 0.707742	valid_0's auc: 0.644368
# *****
# 0.6443684895833334
# ********************
#
#
# voc_day11_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.703522	valid_0's auc: 0.676055
# [40]	training's auc: 0.703746	valid_0's auc: 0.675029
# [60]	training's auc: 0.703916	valid_0's auc: 0.675856
# Early stopping, best iteration is:
# [21]	training's auc: 0.703519	valid_0's auc: 0.676126
# *****
# 0.6761263020833334
# ********************
#
#
# voc_time_count_max
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.782229	valid_0's auc: 0.727926
# [40]	training's auc: 0.78231	valid_0's auc: 0.728027
# Early stopping, best iteration is:
# [2]	training's auc: 0.781536	valid_0's auc: 0.72945
# *****
# 0.7294498697916667
# ********************
#
#
# voc_time_count_mean
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.858719	valid_0's auc: 0.739167
# [40]	training's auc: 0.865208	valid_0's auc: 0.732965
# Early stopping, best iteration is:
# [1]	training's auc: 0.838991	valid_0's auc: 0.755687
# *****
# 0.7556868489583334
# ********************
#
#
# voc_time_count_std
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.84819	valid_0's auc: 0.749645
# [40]	training's auc: 0.853142	valid_0's auc: 0.749023
# [60]	training's auc: 0.855463	valid_0's auc: 0.74877
# Early stopping, best iteration is:
# [12]	training's auc: 0.841773	valid_0's auc: 0.754642
# *****
# 0.7546419270833333
# ********************
#
#
# voc_time_diff_count_max
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.603222	valid_0's auc: 0.558197
# [40]	training's auc: 0.603227	valid_0's auc: 0.558197
# Early stopping, best iteration is:
# [4]	training's auc: 0.602401	valid_0's auc: 0.560143
# *****
# 0.5601432291666667
# ********************
#
#
# voc_time_diff_count_mean
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.718978	valid_0's auc: 0.634303
# [40]	training's auc: 0.728535	valid_0's auc: 0.626344
# Early stopping, best iteration is:
# [1]	training's auc: 0.691181	valid_0's auc: 0.635117
# *****
# 0.6351171875
# ********************
#
#
# voc_time_diff_count_std
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.7055	valid_0's auc: 0.609248
# [40]	training's auc: 0.711153	valid_0's auc: 0.605358
# [60]	training's auc: 0.714904	valid_0's auc: 0.601924
# Early stopping, best iteration is:
# [10]	training's auc: 0.699298	valid_0's auc: 0.612002
# *****
# 0.612001953125
# ********************
#
#
# voc_hour_count_max
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.707729	valid_0's auc: 0.653883
# [40]	training's auc: 0.708225	valid_0's auc: 0.654255
# [60]	training's auc: 0.708568	valid_0's auc: 0.653818
# Early stopping, best iteration is:
# [27]	training's auc: 0.708072	valid_0's auc: 0.65512
# *****
# 0.6551204427083334
# ********************
#
#
# voc_hour_count_mean
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.760594	valid_0's auc: 0.644365
# [40]	training's auc: 0.768054	valid_0's auc: 0.649847
# [60]	training's auc: 0.771784	valid_0's auc: 0.654456
# [80]	training's auc: 0.775521	valid_0's auc: 0.657002
# [100]	training's auc: 0.777535	valid_0's auc: 0.659759
# [120]	training's auc: 0.778763	valid_0's auc: 0.659775
# [140]	training's auc: 0.780271	valid_0's auc: 0.659535
# [160]	training's auc: 0.781322	valid_0's auc: 0.662917
# [180]	training's auc: 0.782054	valid_0's auc: 0.662933
# [200]	training's auc: 0.78293	valid_0's auc: 0.663525
# [220]	training's auc: 0.783415	valid_0's auc: 0.664131
# Early stopping, best iteration is:
# [187]	training's auc: 0.782396	valid_0's auc: 0.664964
# *****
# 0.6649641927083333
# ********************
#
#
# voc_hour_count_std
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.751415	valid_0's auc: 0.656452
# [40]	training's auc: 0.760286	valid_0's auc: 0.642018
# Early stopping, best iteration is:
# [9]	training's auc: 0.740126	valid_0's auc: 0.670469
# *****
# 0.67046875
# ********************
#
#
# voc_hour_diff_count_max
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.601427	valid_0's auc: 0.550788
# [40]	training's auc: 0.60191	valid_0's auc: 0.549583
# [60]	training's auc: 0.60225	valid_0's auc: 0.549388
# Early stopping, best iteration is:
# [14]	training's auc: 0.601164	valid_0's auc: 0.551849
# *****
# 0.5518489583333334
# ********************
#
#
# voc_hour_diff_count_mean
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.740404	valid_0's auc: 0.628193
# [40]	training's auc: 0.746952	valid_0's auc: 0.619658
# Early stopping, best iteration is:
# [2]	training's auc: 0.718071	valid_0's auc: 0.647539
# *****
# 0.6475390625
# ********************
#
#
# voc_hour_diff_count_std
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.721178	valid_0's auc: 0.583096
# [40]	training's auc: 0.728797	valid_0's auc: 0.584772
# Early stopping, best iteration is:
# [1]	training's auc: 0.696014	valid_0's auc: 0.58792
# *****
# 0.587919921875
# ********************
#
#
# voc_dayofweek_count_max
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.765611	valid_0's auc: 0.670029
# [40]	training's auc: 0.767523	valid_0's auc: 0.669469
# Early stopping, best iteration is:
# [3]	training's auc: 0.761466	valid_0's auc: 0.677259
# *****
# 0.6772591145833333
# ********************
#
#
# voc_dayofweek_count_mean
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.802556	valid_0's auc: 0.657699
# [40]	training's auc: 0.807319	valid_0's auc: 0.655843
# Early stopping, best iteration is:
# [2]	training's auc: 0.788749	valid_0's auc: 0.665247
# *****
# 0.6652473958333334
# ********************
#
#
# voc_dayofweek_count_std
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.796237	valid_0's auc: 0.67459
# [40]	training's auc: 0.802446	valid_0's auc: 0.674102
# Early stopping, best iteration is:
# [8]	training's auc: 0.789145	valid_0's auc: 0.675462
# *****
# 0.6754622395833333
# ********************
#
#
# voc_dayofweek_diff_count_max
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.607072	valid_0's auc: 0.547409
# [40]	training's auc: 0.609155	valid_0's auc: 0.545166
# [60]	training's auc: 0.609411	valid_0's auc: 0.544242
# Early stopping, best iteration is:
# [12]	training's auc: 0.605987	valid_0's auc: 0.551742
# *****
# 0.5517415364583333
# ********************
#
#
# voc_dayofweek_diff_count_mean
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.729718	valid_0's auc: 0.620023
# [40]	training's auc: 0.735412	valid_0's auc: 0.616449
# Early stopping, best iteration is:
# [1]	training's auc: 0.69599	valid_0's auc: 0.62862
# *****
# 0.6286197916666667
# ********************
#
#
# voc_dayofweek_diff_count_std
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.716224	valid_0's auc: 0.590426
# [40]	training's auc: 0.723588	valid_0's auc: 0.583711
# Early stopping, best iteration is:
# [3]	training's auc: 0.690758	valid_0's auc: 0.594619
# *****
# 0.594619140625
# ********************
#
#
# voc_dayofweek6_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.73991	valid_0's auc: 0.689609
# [40]	training's auc: 0.742077	valid_0's auc: 0.689359
# [60]	training's auc: 0.742424	valid_0's auc: 0.687204
# Early stopping, best iteration is:
# [11]	training's auc: 0.739324	valid_0's auc: 0.692025
# *****
# 0.6920247395833333
# ********************
#
#
# voc_dayofweek0_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.735684	valid_0's auc: 0.677227
# [40]	training's auc: 0.737915	valid_0's auc: 0.673766
# [60]	training's auc: 0.739231	valid_0's auc: 0.6729
# Early stopping, best iteration is:
# [23]	training's auc: 0.735854	valid_0's auc: 0.677285
# *****
# 0.67728515625
# ********************
#
#
# voc_dayofweek1_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.743164	valid_0's auc: 0.625231
# [40]	training's auc: 0.744759	valid_0's auc: 0.624342
# Early stopping, best iteration is:
# [1]	training's auc: 0.73531	valid_0's auc: 0.644687
# *****
# 0.6446875
# ********************
#
#
# voc_dayofweek4_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.742292	valid_0's auc: 0.663027
# [40]	training's auc: 0.745521	valid_0's auc: 0.662533
# Early stopping, best iteration is:
# [3]	training's auc: 0.737388	valid_0's auc: 0.665049
# *****
# 0.665048828125
# ********************
#
#
# voc_dayofweek3_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.757538	valid_0's auc: 0.619974
# [40]	training's auc: 0.759539	valid_0's auc: 0.618503
# Early stopping, best iteration is:
# [2]	training's auc: 0.754127	valid_0's auc: 0.626322
# *****
# 0.6263216145833334
# ********************
#
#
# voc_dayofweek5_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.74351	valid_0's auc: 0.661227
# [40]	training's auc: 0.745484	valid_0's auc: 0.662201
# [60]	training's auc: 0.747183	valid_0's auc: 0.66251
# Early stopping, best iteration is:
# [17]	training's auc: 0.743467	valid_0's auc: 0.664577
# *****
# 0.6645768229166666
# ********************
#
#
# voc_dayofweek2_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.758277	valid_0's auc: 0.652253
# [40]	training's auc: 0.759812	valid_0's auc: 0.654176
# Early stopping, best iteration is:
# [4]	training's auc: 0.756412	valid_0's auc: 0.655742
# *****
# 0.6557421875
# ********************
#
#
# call_dur_day_sum_max
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.781844	valid_0's auc: 0.67222
# [40]	training's auc: 0.7884	valid_0's auc: 0.673086
# Early stopping, best iteration is:
# [6]	training's auc: 0.771348	valid_0's auc: 0.68043
# *****
# 0.6804296875
# ********************
#
#
# call_dur_day_sum_min
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.761861	valid_0's auc: 0.580371
# [40]	training's auc: 0.76447	valid_0's auc: 0.583099
# [60]	training's auc: 0.766517	valid_0's auc: 0.584111
# [80]	training's auc: 0.76826	valid_0's auc: 0.583822
# [100]	training's auc: 0.769455	valid_0's auc: 0.582295
# Early stopping, best iteration is:
# [62]	training's auc: 0.766628	valid_0's auc: 0.584854
# *****
# 0.584853515625
# ********************
#
#
# call_dur_day_sum_mean
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.833791	valid_0's auc: 0.694434
# [40]	training's auc: 0.839346	valid_0's auc: 0.693411
# Early stopping, best iteration is:
# [2]	training's auc: 0.816918	valid_0's auc: 0.699111
# *****
# 0.699111328125
# ********************
#
#
# call_dur_day_sum_std
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.783658	valid_0's auc: 0.683747
# [40]	training's auc: 0.789895	valid_0's auc: 0.683714
# [60]	training's auc: 0.793182	valid_0's auc: 0.68346
# Early stopping, best iteration is:
# [27]	training's auc: 0.786579	valid_0's auc: 0.685941
# *****
# 0.6859407552083333
# ********************
#
#
# call_dur_day_diff_sum_max
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.679453	valid_0's auc: 0.557699
# [40]	training's auc: 0.688705	valid_0's auc: 0.552594
# Early stopping, best iteration is:
# [2]	training's auc: 0.643988	valid_0's auc: 0.578669
# *****
# 0.5786686197916666
# ********************
#
#
# call_dur_day_diff_sum_min
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.68599	valid_0's auc: 0.652721
# [40]	training's auc: 0.687954	valid_0's auc: 0.648216
# Early stopping, best iteration is:
# [1]	training's auc: 0.680178	valid_0's auc: 0.661204
# *****
# 0.6612044270833334
# ********************
#
#
# call_dur_day_diff_sum_mean
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.704221	valid_0's auc: 0.538317
# [40]	training's auc: 0.712088	valid_0's auc: 0.541237
# Early stopping, best iteration is:
# [2]	training's auc: 0.676409	valid_0's auc: 0.557747
# *****
# 0.5577473958333333
# ********************
#
#
# call_dur_day_diff_sum_std
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.680104	valid_0's auc: 0.58001
# [40]	training's auc: 0.689409	valid_0's auc: 0.573779
# Early stopping, best iteration is:
# [6]	training's auc: 0.664957	valid_0's auc: 0.584899
# *****
# 0.5848990885416666
# ********************
#
#
# voc_day22_call_dur_sum
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.718508	valid_0's auc: 0.604525
# [40]	training's auc: 0.723566	valid_0's auc: 0.605999
# [60]	training's auc: 0.727652	valid_0's auc: 0.606647
# [80]	training's auc: 0.73049	valid_0's auc: 0.604408
# [100]	training's auc: 0.731798	valid_0's auc: 0.603691
# Early stopping, best iteration is:
# [67]	training's auc: 0.728249	valid_0's auc: 0.607018
# *****
# 0.6070182291666667
# ********************
#
#
# voc_day23_call_dur_sum
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.722759	valid_0's auc: 0.630951
# [40]	training's auc: 0.729233	valid_0's auc: 0.626514
# Early stopping, best iteration is:
# [8]	training's auc: 0.716653	valid_0's auc: 0.634626
# *****
# 0.6346256510416667
# ********************
#
#
# voc_day1_call_dur_sum
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.687133	valid_0's auc: 0.600326
# [40]	training's auc: 0.694298	valid_0's auc: 0.600697
# Early stopping, best iteration is:
# [3]	training's auc: 0.670819	valid_0's auc: 0.611768
# *****
# 0.611767578125
# ********************
#
#
# voc_day3_call_dur_sum
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.686932	valid_0's auc: 0.633275
# [40]	training's auc: 0.691727	valid_0's auc: 0.628483
# Early stopping, best iteration is:
# [3]	training's auc: 0.680241	valid_0's auc: 0.647145
# *****
# 0.6471451822916666
# ********************
#
#
# voc_day9_call_dur_sum
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.709504	valid_0's auc: 0.620635
# [40]	training's auc: 0.713822	valid_0's auc: 0.618327
# [60]	training's auc: 0.717549	valid_0's auc: 0.615859
# Early stopping, best iteration is:
# [29]	training's auc: 0.71054	valid_0's auc: 0.621895
# *****
# 0.62189453125
# ********************
#
#
# voc_day6_call_dur_sum
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.695038	valid_0's auc: 0.650895
# [40]	training's auc: 0.699576	valid_0's auc: 0.649046
# Early stopping, best iteration is:
# [4]	training's auc: 0.685881	valid_0's auc: 0.659229
# *****
# 0.659228515625
# ********************
#
#
# voc_day10_call_dur_sum
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.706946	valid_0's auc: 0.621536
# [40]	training's auc: 0.714226	valid_0's auc: 0.619476
# Early stopping, best iteration is:
# [8]	training's auc: 0.702313	valid_0's auc: 0.627617
# *****
# 0.6276171875
# ********************
#
#
# voc_day26_call_dur_sum
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.721207	valid_0's auc: 0.576849
# [40]	training's auc: 0.725886	valid_0's auc: 0.580817
# [60]	training's auc: 0.728519	valid_0's auc: 0.581357
# [80]	training's auc: 0.730653	valid_0's auc: 0.579749
# Early stopping, best iteration is:
# [44]	training's auc: 0.726871	valid_0's auc: 0.583063
# *****
# 0.5830631510416666
# ********************
#
#
# voc_day27_call_dur_sum
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.711691	valid_0's auc: 0.604753
# [40]	training's auc: 0.715636	valid_0's auc: 0.60375
# [60]	training's auc: 0.718403	valid_0's auc: 0.60238
# Early stopping, best iteration is:
# [20]	training's auc: 0.711691	valid_0's auc: 0.604753
# *****
# 0.6047526041666667
# ********************
#
#
# voc_day13_call_dur_sum
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.703637	valid_0's auc: 0.616641
# [40]	training's auc: 0.709217	valid_0's auc: 0.614808
# [60]	training's auc: 0.713398	valid_0's auc: 0.614147
# Early stopping, best iteration is:
# [25]	training's auc: 0.704851	valid_0's auc: 0.620326
# *****
# 0.6203255208333334
# ********************
#
#
# voc_day28_call_dur_sum
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.713848	valid_0's auc: 0.61224
# [40]	training's auc: 0.717207	valid_0's auc: 0.611022
# [60]	training's auc: 0.720065	valid_0's auc: 0.610309
# Early stopping, best iteration is:
# [20]	training's auc: 0.713848	valid_0's auc: 0.61224
# *****
# 0.6122395833333333
# ********************
#
#
# voc_day30_call_dur_sum
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.723038	valid_0's auc: 0.605671
# [40]	training's auc: 0.727278	valid_0's auc: 0.60613
# Early stopping, best iteration is:
# [1]	training's auc: 0.714835	valid_0's auc: 0.617718
# *****
# 0.6177180989583333
# ********************
#
#
# voc_day20_call_dur_sum
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.721194	valid_0's auc: 0.64096
# [40]	training's auc: 0.725916	valid_0's auc: 0.639814
# Early stopping, best iteration is:
# [1]	training's auc: 0.708569	valid_0's auc: 0.649014
# *****
# 0.649013671875
# ********************
#
#
# voc_day16_call_dur_sum
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.707899	valid_0's auc: 0.625638
# [40]	training's auc: 0.713831	valid_0's auc: 0.621888
# Early stopping, best iteration is:
# [8]	training's auc: 0.7004	valid_0's auc: 0.631999
# *****
# 0.6319986979166666
# ********************
#
#
# voc_day19_call_dur_sum
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.717761	valid_0's auc: 0.601191
# [40]	training's auc: 0.723473	valid_0's auc: 0.605208
# [60]	training's auc: 0.729123	valid_0's auc: 0.600911
# [80]	training's auc: 0.731176	valid_0's auc: 0.594954
# Early stopping, best iteration is:
# [38]	training's auc: 0.723143	valid_0's auc: 0.605579
# *****
# 0.6055794270833333
# ********************
#
#
# voc_day21_call_dur_sum
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.711605	valid_0's auc: 0.636904
# [40]	training's auc: 0.716583	valid_0's auc: 0.635133
# [60]	training's auc: 0.720388	valid_0's auc: 0.633685
# [80]	training's auc: 0.724381	valid_0's auc: 0.631172
# Early stopping, best iteration is:
# [30]	training's auc: 0.713906	valid_0's auc: 0.637666
# *****
# 0.637666015625
# ********************
#
#
# voc_day29_call_dur_sum
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.722444	valid_0's auc: 0.657041
# [40]	training's auc: 0.726794	valid_0's auc: 0.655726
# Early stopping, best iteration is:
# [2]	training's auc: 0.714202	valid_0's auc: 0.667441
# *****
# 0.66744140625
# ********************
#
#
# voc_day17_call_dur_sum
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.7199	valid_0's auc: 0.644993
# [40]	training's auc: 0.727394	valid_0's auc: 0.638242
# Early stopping, best iteration is:
# [4]	training's auc: 0.712316	valid_0's auc: 0.649961
# *****
# 0.6499609375
# ********************
#
#
# voc_day7_call_dur_sum
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.706258	valid_0's auc: 0.618864
# [40]	training's auc: 0.711485	valid_0's auc: 0.619867
# Early stopping, best iteration is:
# [2]	training's auc: 0.695554	valid_0's auc: 0.628818
# *****
# 0.628818359375
# ********************
#
#
# voc_day14_call_dur_sum
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.716878	valid_0's auc: 0.60123
# [40]	training's auc: 0.721293	valid_0's auc: 0.594258
# Early stopping, best iteration is:
# [1]	training's auc: 0.706071	valid_0's auc: 0.613551
# *****
# 0.6135514322916666
# ********************
#
#
# voc_day15_call_dur_sum
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.699748	valid_0's auc: 0.622298
# [40]	training's auc: 0.703441	valid_0's auc: 0.618997
# Early stopping, best iteration is:
# [2]	training's auc: 0.690939	valid_0's auc: 0.632451
# *****
# 0.632451171875
# ********************
#
#
# voc_day5_call_dur_sum
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.7011	valid_0's auc: 0.63209
# [40]	training's auc: 0.708495	valid_0's auc: 0.620407
# Early stopping, best iteration is:
# [7]	training's auc: 0.691142	valid_0's auc: 0.641989
# *****
# 0.6419889322916666
# ********************
#
#
# voc_day2_call_dur_sum
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.678211	valid_0's auc: 0.600632
# [40]	training's auc: 0.688761	valid_0's auc: 0.601852
# [60]	training's auc: 0.691864	valid_0's auc: 0.598086
# Early stopping, best iteration is:
# [11]	training's auc: 0.672211	valid_0's auc: 0.6107
# *****
# 0.6106998697916667
# ********************
#
#
# voc_day12_call_dur_sum
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.705611	valid_0's auc: 0.621911
# [40]	training's auc: 0.709865	valid_0's auc: 0.621475
# Early stopping, best iteration is:
# [1]	training's auc: 0.695326	valid_0's auc: 0.633158
# *****
# 0.6331575520833334
# ********************
#
#
# voc_day8_call_dur_sum
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.682277	valid_0's auc: 0.632676
# [40]	training's auc: 0.69156	valid_0's auc: 0.628454
# [60]	training's auc: 0.695919	valid_0's auc: 0.622988
# Early stopping, best iteration is:
# [14]	training's auc: 0.679299	valid_0's auc: 0.635384
# *****
# 0.6353841145833333
# ********************
#
#
# voc_day18_call_dur_sum
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.717706	valid_0's auc: 0.626569
# [40]	training's auc: 0.72473	valid_0's auc: 0.611689
# Early stopping, best iteration is:
# [7]	training's auc: 0.711097	valid_0's auc: 0.636693
# *****
# 0.6366927083333334
# ********************
#
#
# voc_day31_call_dur_sum
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.722775	valid_0's auc: 0.589844
# [40]	training's auc: 0.727162	valid_0's auc: 0.589163
# Early stopping, best iteration is:
# [2]	training's auc: 0.713263	valid_0's auc: 0.595954
# *****
# 0.5959537760416667
# ********************
#
#
# voc_day4_call_dur_sum
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.697116	valid_0's auc: 0.634395
# [40]	training's auc: 0.7043	valid_0's auc: 0.638125
# Early stopping, best iteration is:
# [2]	training's auc: 0.685324	valid_0's auc: 0.639616
# *****
# 0.6396158854166667
# ********************
#
#
# voc_day24_call_dur_sum
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.708257	valid_0's auc: 0.59026
# [40]	training's auc: 0.713367	valid_0's auc: 0.587979
# Early stopping, best iteration is:
# [3]	training's auc: 0.700359	valid_0's auc: 0.592992
# *****
# 0.5929915364583334
# ********************
#
#
# voc_day25_call_dur_sum
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.726581	valid_0's auc: 0.59891
# ...
# [1]	training's auc: 0.659324	valid_0's auc: 0.558633
# *****
# 0.5586328125
# ********************
#
#
# sms_day30_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.789752	valid_0's auc: 0.661777
# [40]	training's auc: 0.7911	valid_0's auc: 0.658206
# Early stopping, best iteration is:
# [1]	training's auc: 0.787748	valid_0's auc: 0.665967
# *****
# 0.665966796875
# ********************
#
#
# sms_day31_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.783709	valid_0's auc: 0.662018
# [40]	training's auc: 0.784382	valid_0's auc: 0.661829
# [60]	training's auc: 0.784573	valid_0's auc: 0.662041
# Early stopping, best iteration is:
# [27]	training's auc: 0.783376	valid_0's auc: 0.662572
# *****
# 0.6625716145833334
# ********************
#
#
# sms_hour_count_max
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.658782	valid_0's auc: 0.569945
# [40]	training's auc: 0.662882	valid_0's auc: 0.568258
# Early stopping, best iteration is:
# [4]	training's auc: 0.645439	valid_0's auc: 0.580908
# *****
# 0.580908203125
# ********************
#
#
# sms_hour_count_min
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.556873	valid_0's auc: 0.507907
# [40]	training's auc: 0.556874	valid_0's auc: 0.507907
# [60]	training's auc: 0.556874	valid_0's auc: 0.507907
# Early stopping, best iteration is:
# [19]	training's auc: 0.556873	valid_0's auc: 0.507907
# *****
# 0.5079069010416667
# ********************
#
#
# sms_hour_count_mean
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.685351	valid_0's auc: 0.571117
# [40]	training's auc: 0.69433	valid_0's auc: 0.569616
# Early stopping, best iteration is:
# [8]	training's auc: 0.673685	valid_0's auc: 0.576647
# *****
# 0.5766471354166667
# ********************
#
#
# sms_hour_count_std
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.692161	valid_0's auc: 0.562803
# [40]	training's auc: 0.701559	valid_0's auc: 0.55347
# Early stopping, best iteration is:
# [7]	training's auc: 0.680298	valid_0's auc: 0.56847
# *****
# 0.5684700520833333
# ********************
#
#
# sms_hour_diff_count_max
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.68642	valid_0's auc: 0.577389
# [40]	training's auc: 0.688513	valid_0's auc: 0.574697
# Early stopping, best iteration is:
# [4]	training's auc: 0.680282	valid_0's auc: 0.584928
# *****
# 0.5849283854166667
# ********************
#
#
# sms_hour_diff_count_min
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.510459	valid_0's auc: 0.506305
# [40]	training's auc: 0.510435	valid_0's auc: 0.506279
# [60]	training's auc: 0.510449	valid_0's auc: 0.506299
# Early stopping, best iteration is:
# [14]	training's auc: 0.510443	valid_0's auc: 0.506315
# *****
# 0.5063151041666667
# ********************
#
#
# sms_hour_diff_count_mean
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.709399	valid_0's auc: 0.582116
# [40]	training's auc: 0.718092	valid_0's auc: 0.57374
# Early stopping, best iteration is:
# [8]	training's auc: 0.698018	valid_0's auc: 0.590231
# *****
# 0.5902311197916666
# ********************
#
#
# sms_hour_diff_count_std
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.709394	valid_0's auc: 0.556237
# [40]	training's auc: 0.717621	valid_0's auc: 0.550003
# Early stopping, best iteration is:
# [3]	training's auc: 0.687629	valid_0's auc: 0.563223
# *****
# 0.56322265625
# ********************
#
#
# sms_dayofweek_count_max
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.658348	valid_0's auc: 0.576696
# [40]	training's auc: 0.663454	valid_0's auc: 0.571038
# Early stopping, best iteration is:
# [3]	training's auc: 0.644412	valid_0's auc: 0.58238
# *****
# 0.5823795572916667
# ********************
#
#
# sms_dayofweek_count_min
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.659905	valid_0's auc: 0.548646
# [40]	training's auc: 0.661163	valid_0's auc: 0.547786
# Early stopping, best iteration is:
# [1]	training's auc: 0.651044	valid_0's auc: 0.560182
# *****
# 0.5601822916666667
# ********************
#
#
# sms_dayofweek_count_mean
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.693188	valid_0's auc: 0.597679
# [40]	training's auc: 0.700632	valid_0's auc: 0.59623
# [60]	training's auc: 0.705976	valid_0's auc: 0.591045
# Early stopping, best iteration is:
# [14]	training's auc: 0.689352	valid_0's auc: 0.599349
# *****
# 0.5993489583333333
# ********************
#
#
# sms_dayofweek_count_std
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.719026	valid_0's auc: 0.623366
# [40]	training's auc: 0.727997	valid_0's auc: 0.617048
# Early stopping, best iteration is:
# [7]	training's auc: 0.708418	valid_0's auc: 0.629915
# *****
# 0.6299153645833333
# ********************
#
#
# sms_dayodweek_diff_count_max
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.696612	valid_0's auc: 0.610628
# [40]	training's auc: 0.69761	valid_0's auc: 0.616849
# Early stopping, best iteration is:
# [1]	training's auc: 0.692115	valid_0's auc: 0.618001
# *****
# 0.6180013020833334
# ********************
#
#
# sms_dayodweek_diff_count_min
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.510899	valid_0's auc: 0.50056
# [40]	training's auc: 0.510894	valid_0's auc: 0.500553
# Early stopping, best iteration is:
# [1]	training's auc: 0.510837	valid_0's auc: 0.500625
# *****
# 0.500625
# ********************
#
#
# sms_dayodweek_diff_count_mean
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.747356	valid_0's auc: 0.587819
# [40]	training's auc: 0.753614	valid_0's auc: 0.590199
# Early stopping, best iteration is:
# [2]	training's auc: 0.727908	valid_0's auc: 0.591602
# *****
# 0.5916015625
# ********************
#
#
# sms_dayodweek_diff_count_std
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.757276	valid_0's auc: 0.592074
# [40]	training's auc: 0.762236	valid_0's auc: 0.589521
# Early stopping, best iteration is:
# [2]	training's auc: 0.73756	valid_0's auc: 0.596029
# *****
# 0.5960286458333334
# ********************
#
#
# sms_dayofweek6_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.684547	valid_0's auc: 0.622624
# [40]	training's auc: 0.685759	valid_0's auc: 0.618796
# Early stopping, best iteration is:
# [3]	training's auc: 0.677694	valid_0's auc: 0.624626
# *****
# 0.6246256510416667
# ********************
#
#
# sms_dayofweek0_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.679702	valid_0's auc: 0.577272
# [40]	training's auc: 0.682837	valid_0's auc: 0.571458
# Early stopping, best iteration is:
# [2]	training's auc: 0.670261	valid_0's auc: 0.582025
# *****
# 0.5820247395833333
# ********************
#
#
# sms_dayofweek1_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.696556	valid_0's auc: 0.553073
# [40]	training's auc: 0.69982	valid_0's auc: 0.548587
# Early stopping, best iteration is:
# [1]	training's auc: 0.686136	valid_0's auc: 0.569001
# *****
# 0.5690006510416666
# ********************
#
#
# sms_dayofweek2_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.697884	valid_0's auc: 0.56598
# [40]	training's auc: 0.699926	valid_0's auc: 0.558818
# Early stopping, best iteration is:
# [1]	training's auc: 0.684973	valid_0's auc: 0.58401
# *****
# 0.5840104166666666
# ********************
#
#
# sms_dayofweek3_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.70453	valid_0's auc: 0.568428
# [40]	training's auc: 0.706332	valid_0's auc: 0.565238
# Early stopping, best iteration is:
# [1]	training's auc: 0.696113	valid_0's auc: 0.585
# *****
# 0.585
# ********************
#
#
# sms_dayofweek4_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.708637	valid_0's auc: 0.60832
# [40]	training's auc: 0.710277	valid_0's auc: 0.606631
# Early stopping, best iteration is:
# [5]	training's auc: 0.705415	valid_0's auc: 0.611048
# *****
# 0.6110481770833334
# ********************
#
#
# sms_dayofweek5_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.715491	valid_0's auc: 0.583955
# [40]	training's auc: 0.716599	valid_0's auc: 0.58363
# Early stopping, best iteration is:
# [1]	training's auc: 0.708147	valid_0's auc: 0.596071
# *****
# 0.5960709635416667
# ********************
#
#
# busi_name
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.616577	valid_0's auc: 0.579424
# [40]	training's auc: 0.616802	valid_0's auc: 0.578851
# [60]	training's auc: 0.616821	valid_0's auc: 0.578434
# Early stopping, best iteration is:
# [19]	training's auc: 0.616577	valid_0's auc: 0.579424
# *****
# 0.579423828125
# ********************
#
#
# flow
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.714794	valid_0's auc: 0.63984
# [40]	training's auc: 0.724611	valid_0's auc: 0.640703
# [60]	training's auc: 0.728915	valid_0's auc: 0.633418
# Early stopping, best iteration is:
# [10]	training's auc: 0.709012	valid_0's auc: 0.643096
# *****
# 0.643095703125
# ********************
#
#
# total_flow
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.730272	valid_0's auc: 0.618558
# [40]	training's auc: 0.737168	valid_0's auc: 0.618271
# [60]	training's auc: 0.741718	valid_0's auc: 0.616351
# Early stopping, best iteration is:
# [28]	training's auc: 0.733646	valid_0's auc: 0.620391
# *****
# 0.620390625
# ********************
#
#
# flow_max
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.715534	valid_0's auc: 0.589639
# [40]	training's auc: 0.721252	valid_0's auc: 0.588965
# Early stopping, best iteration is:
# [3]	training's auc: 0.702837	valid_0's auc: 0.590667
# *****
# 0.5906673177083334
# ********************
#
#
# flow_min
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.70159	valid_0's auc: 0.581777
# [40]	training's auc: 0.709395	valid_0's auc: 0.583034
# [60]	training's auc: 0.715546	valid_0's auc: 0.577617
# Early stopping, best iteration is:
# [29]	training's auc: 0.705057	valid_0's auc: 0.584769
# *****
# 0.5847688802083333
# ********************
#
#
# flow_mean
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.687482	valid_0's auc: 0.599434
# [40]	training's auc: 0.696778	valid_0's auc: 0.606426
# [60]	training's auc: 0.69986	valid_0's auc: 0.607152
# [80]	training's auc: 0.702848	valid_0's auc: 0.602975
# Early stopping, best iteration is:
# [30]	training's auc: 0.691952	valid_0's auc: 0.60916
# *****
# 0.60916015625
# ********************
#
#
# flow_std
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.689921	valid_0's auc: 0.575469
# [40]	training's auc: 0.699298	valid_0's auc: 0.575173
# Early stopping, best iteration is:
# [4]	training's auc: 0.666949	valid_0's auc: 0.583835
# *****
# 0.5838346354166667
# ********************
#
#
# app_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.746014	valid_0's auc: 0.613747
# [40]	training's auc: 0.750842	valid_0's auc: 0.605807
# [60]	training's auc: 0.756616	valid_0's auc: 0.606374
# Early stopping, best iteration is:
# [14]	training's auc: 0.744709	valid_0's auc: 0.617425
# *****
# 0.6174251302083333
# ********************
#
#
# total_flow/app_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.688161	valid_0's auc: 0.591569
# [40]	training's auc: 0.695313	valid_0's auc: 0.589368
# [60]	training's auc: 0.70019	valid_0's auc: 0.587705
# Early stopping, best iteration is:
# [11]	training's auc: 0.680829	valid_0's auc: 0.597575
# *****
# 0.5975748697916666
# ********************
#
#
# busi_name_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.610766	valid_0's auc: 0.581758
# [40]	training's auc: 0.610779	valid_0's auc: 0.581758
# [60]	training's auc: 0.612105	valid_0's auc: 0.57985
# Early stopping, best iteration is:
# [24]	training's auc: 0.612054	valid_0's auc: 0.582676
# *****
# 0.58267578125
# ********************
#
#
# busi_name_total_flow
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.71141	valid_0's auc: 0.602327
# [40]	training's auc: 0.718788	valid_0's auc: 0.599463
# [60]	training's auc: 0.723763	valid_0's auc: 0.598792
# Early stopping, best iteration is:
# [12]	training's auc: 0.705242	valid_0's auc: 0.603867
# *****
# 0.6038671875
# ********************
#
#
# busi_name_flow_max
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.716191	valid_0's auc: 0.635859
# [40]	training's auc: 0.725518	valid_0's auc: 0.638805
# [60]	training's auc: 0.731145	valid_0's auc: 0.639805
# [80]	training's auc: 0.734462	valid_0's auc: 0.637562
# Early stopping, best iteration is:
# [49]	training's auc: 0.72937	valid_0's auc: 0.641396
# *****
# 0.641396484375
# ********************
#
#
# busi_name_flow_min
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.688504	valid_0's auc: 0.553245
# [40]	training's auc: 0.69575	valid_0's auc: 0.556051
# Early stopping, best iteration is:
# [1]	training's auc: 0.657254	valid_0's auc: 0.570156
# *****
# 0.57015625
# ********************
#
#
# busi_name_flow_mean
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.708335	valid_0's auc: 0.592454
# [40]	training's auc: 0.717309	valid_0's auc: 0.589001
# Early stopping, best iteration is:
# [1]	training's auc: 0.685654	valid_0's auc: 0.598089
# *****
# 0.5980891927083334
# ********************
#
#
# busi_name_flow_std
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.687086	valid_0's auc: 0.581185
# [40]	training's auc: 0.694949	valid_0's auc: 0.579141
# Early stopping, best iteration is:
# [2]	training's auc: 0.672145	valid_0's auc: 0.58721
# *****
# 0.5872102864583333
# ********************
#
#
# arpu_202004-sms_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.732989	valid_0's auc: 0.595332
# [40]	training's auc: 0.740922	valid_0's auc: 0.598496
# [60]	training's auc: 0.745843	valid_0's auc: 0.595365
# [80]	training's auc: 0.748625	valid_0's auc: 0.594417
# Early stopping, best iteration is:
# [39]	training's auc: 0.740554	valid_0's auc: 0.598525
# *****
# 0.598525390625
# ********************
#
#
# arpu_202004/total_flow
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.691271	valid_0's auc: 0.620511
# [40]	training's auc: 0.700065	valid_0's auc: 0.622721
# [60]	training's auc: 0.707734	valid_0's auc: 0.625065
# [80]	training's auc: 0.712154	valid_0's auc: 0.627383
# [100]	training's auc: 0.717169	valid_0's auc: 0.625576
# [120]	training's auc: 0.720656	valid_0's auc: 0.623636
# Early stopping, best iteration is:
# [75]	training's auc: 0.711511	valid_0's auc: 0.627826
# *****
# 0.6278255208333333
# ********************
#
#
# arpu_202004-sms_count/voc_opposite_nunique
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.78757	valid_0's auc: 0.659515
# [40]	training's auc: 0.795378	valid_0's auc: 0.660153
# Early stopping, best iteration is:
# [2]	training's auc: 0.767074	valid_0's auc: 0.677178
# *****
# 0.677177734375
# ********************
#
#
# arpu_202004-sms_count/voc_count
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.752539	valid_0's auc: 0.64376
# [40]	training's auc: 0.759451	valid_0's auc: 0.640824
# Early stopping, best iteration is:
# [1]	training's auc: 0.727601	valid_0's auc: 0.659242
# *****
# 0.6592415364583334
# ********************
#
#
# arpu_202004-sms_count/call_dur_sum
# Training until validation scores don't improve for 50 rounds
# [20]	training's auc: 0.688469	valid_0's auc: 0.604873
# [40]	training's auc: 0.691417	valid_0's auc: 0.604795
# [60]	training's auc: 0.692346	valid_0's auc: 0.604645
# [80]	training's auc: 0.693848	valid_0's auc: 0.60388
# [100]	training's auc: 0.695107	valid_0's auc: 0.603285
# Early stopping, best iteration is:
# [62]	training's auc: 0.692456	valid_0's auc: 0.606416
# *****
# 0.606416015625
# ********************

# %%
print(useless_cols)
# Out:
# ['city_name_arpu_202004_min', 'call_dur', 'voc_day', 'voc_hour', 'voc_time', 'voc_day_diff_count_min', 'voc_hour1_call_dur_sum', 'voc_hour3_call_dur_sum', 'voc_hour4_call_dur_sum', 'sms_day', 'sms_dayofweek', 'sms_time', 'sms_day_diff_count_min', 'sms_hour_count_min', 'sms_hour_diff_count_min', 'sms_dayodweek_diff_count_min']

# %%
params = {'objective': 'binary',
          'boosting': 'gbdt',
          'metric': 'binary_logloss',
          'learning_rate': 0.1,
          'num_leaves': 31,
          'lambda_l1': 0,
          'lambda_l2': 1,
          'min_data_in_leaf': 20,
          'is_unbalance': True,
          'max_depth': -1,
          'seed': 2020}

# %%
lgb_train = lgb.Dataset(X_train[use_cols].values, y_train) 

lgb_eval= lgb.Dataset(X_valid[use_cols].values, y_valid, reference=lgb_train)  

print('Start training...')

# train

lgb_val_0 = lgb.train(params,
                      lgb_train,
                      num_boost_round=10000,
                      valid_sets=[lgb_eval, lgb_train],
                      early_stopping_rounds=100,
                      verbose_eval=10)
# Out:
# Start training...
# Training until validation scores don't improve for 100 rounds
# [10]	training's binary_logloss: 0.243228	valid_0's binary_logloss: 0.295694
# [20]	training's binary_logloss: 0.168116	valid_0's binary_logloss: 0.273783
# [30]	training's binary_logloss: 0.12044	valid_0's binary_logloss: 0.253521
# [40]	training's binary_logloss: 0.0875677	valid_0's binary_logloss: 0.238933
# [50]	training's binary_logloss: 0.0636606	valid_0's binary_logloss: 0.230784
# [60]	training's binary_logloss: 0.0466134	valid_0's binary_logloss: 0.225667
# [70]	training's binary_logloss: 0.034559	valid_0's binary_logloss: 0.223033
# [80]	training's binary_logloss: 0.025951	valid_0's binary_logloss: 0.218926
# [90]	training's binary_logloss: 0.0198123	valid_0's binary_logloss: 0.219906
# [100]	training's binary_logloss: 0.0152716	valid_0's binary_logloss: 0.222576
# [110]	training's binary_logloss: 0.0120816	valid_0's binary_logloss: 0.225995
# [120]	training's binary_logloss: 0.00966144	valid_0's binary_logloss: 0.228937
# [130]	training's binary_logloss: 0.00783271	valid_0's binary_logloss: 0.232656
# [140]	training's binary_logloss: 0.00649649	valid_0's binary_logloss: 0.234972
# [150]	training's binary_logloss: 0.00542068	valid_0's binary_logloss: 0.238129
# [160]	training's binary_logloss: 0.00457062	valid_0's binary_logloss: 0.240855
# [170]	training's binary_logloss: 0.00388018	valid_0's binary_logloss: 0.244301
# [180]	training's binary_logloss: 0.00333262	valid_0's binary_logloss: 0.248414
# Early stopping, best iteration is:
# [85]	training's binary_logloss: 0.0226123	valid_0's binary_logloss: 0.217994

# %%
# 验证集结果
X_valid['prob'] = lgb_val_0.predict(X_valid[use_cols])
X_valid['pred'] = np.where(X_valid['prob'] > 0.4735, 1, 0)

f1_04735 = np.round(f1_score(y_valid, X_valid['pred']), 4)
auc_04735 = roc_auc_score(y_valid, X_valid['prob'])

print('f1_04735: ', f1_04735)
print('auc_04735: ', auc_04735)
# Out:
# f1_04735:  0.5751
# auc_04735:  0.8563541666666666

# %%
# 验证集结果
X_valid['prob'] = lgb_val_0.predict(X_valid[use_cols])
X_valid['pred'] = np.where(X_valid['prob'] > 0.5, 1, 0)

f1_05 = np.round(f1_score(y_valid, X_valid['pred']), 4)
auc_05 = roc_auc_score(y_valid, X_valid['prob'])

print('f1_05: ', f1_05)
print('auc_05: ', auc_05)
# Out:
# f1_05:  0.5727
# auc_05:  0.8563541666666666

# %%
lgb_train_all = lgb.Dataset(df_train[use_cols].values, df_train['label'])   

print('Start training...')

# train

lgb_model = lgb.train(params,
                      lgb_train_all,
                      num_boost_round=lgb_val_0.best_iteration + 20)
# Out:
# Start training...

# %%
df_test['label'] = np.where(lgb_model.predict(df_test[use_cols]) > 0.5, 1, 0)
df_test[['phone_no_m', 'label']].to_csv('../sub/sub_{}_{}.csv'.format(time.strftime('%Y%m%d'), f1_05), index=False)

# %%
df_test['label'] = np.where(lgb_model.predict(df_test[use_cols]) > 0.4735, 1, 0)
df_test[['phone_no_m', 'label']].to_csv('../sub/sub_{}_{}.csv'.format(time.strftime('%Y%m%d'), f1_04735), index=False)
